# %% [markdown]
# # Comparisons In A Given Loss Landscape

# %%
import os
import json
from pathlib import Path
import matplotlib.pyplot as plt

from minima_volume.analysis_funcs import (  grab_folder_names,
                                            load_base_train_size,
                                            list_additional_data,
                                            multiple_minima_fixed_landscape,
                                            fixed_landscape_minima_labels,
                                            plot_fixed_landscape_minima_pair,
                                            model_volume_across_targets,
                                            append_cutoff_points,
                                            varying_landscape_minima_labels,
                                            plot_minima_volume_vs_data_level,
)

loss_value = 0.01  # Loss value to analyze
data_level_log = False #Is the data log distributed?
base_output_dir = "analysis"  # Root folder to save all plots
os.makedirs(base_output_dir, exist_ok=True)

# Data for the loss landscape levels
experiment_folders, data_modifications = grab_folder_names()

base_train_size = load_base_train_size(experiment_folders[0])
model_data_sizes = list_additional_data(experiment_folders[0])

base_shift = 0
if data_modifications[0].startswith("data_"):
    base_shift = base_train_size  # Shift to reflect true dataset size

print("Experiment folders: ", experiment_folders)
print("Different data levels where loss landscapes were computed:", data_modifications)
print("The base train size is: ", base_train_size)
print("Data levels where models were trained: ", model_data_sizes)
# Out:
# First entry: Model_0, base_train_size = 94
# Experiment folders:  ['model_0_data_10', 'model_1_data_11', 'model_2_data_12', 'model_3_data_13', 'model_4_data_14', 'model_5_data_15', 'model_6_data_16', 'model_7_data_17', 'model_8_data_18', 'model_9_data_19']
# Different data levels where loss landscapes were computed: ['data_0', 'data_1787', 'data_3669', 'data_5551', 'data_846']
# The base train size is:  94
# Data levels where models were trained:  [0, 1787, 3669, 5551, 846]

# %% [markdown]
# ## Plotting Different Model Volumes In A Landscape

# %%
for data_modification in data_modifications:
    print(f"\nProcessing data modification folder: {data_modification}")

    # Create output folder for this data_modification
    save_dir = os.path.join(base_output_dir, data_modification)
    os.makedirs(save_dir, exist_ok=True)

    # Get axis labels and titles
    labels = fixed_landscape_minima_labels(data_modification, base_train_size)

    # Extract minima landscapes
    all_mdl, all_log_rn, all_test_loss = multiple_minima_fixed_landscape(
        experiment_folders, data_modification, loss_value
    )

    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=data_level_log,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_log_volume",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="log_volume_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )

    ## Rank variant
    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_log_volume",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="log_volume_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )
# Out:
# Processing data modification folder: data_0
# Processing data modification folder: data_1787
# Processing data modification folder: data_3669
# Processing data modification folder: data_5551
# Processing data modification folder: data_846

# %% [markdown]
# # Comparisons Across Loss Landscapes

# %% [markdown]
# Here, we track the performance of all models across all loss landscapes.

# %%
# For the poisoning experiments, this plot has no meaning

labels = varying_landscape_minima_labels(
    data_modification_folder=data_modifications[0], # Random choice to grab datatype from
    base_train_size=base_train_size,
)

results_dict = model_volume_across_targets(
    target_model_data_levels=model_data_sizes,
    loss_value=loss_value,
    experiment_folders=experiment_folders
)
results_with_cutoff = append_cutoff_points(results_dict, threshold=loss_value, base_dir=".")

plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          # NEW: needed for correct legend labels
    base_train_size=base_train_size,  # NEW: used for dataset size shifts
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = data_level_log,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels",
    xlabel_size=15, ylabel_size=15, title_size=15,
    ylim = (90000, 200000)
)
# Out:
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Model_0: first exceedance at index 273 (value=0.010007418692111969, threshold=0.01)
# Appended cutoff for model_0_data_10 | target=0, cutoff_idx=273
# Model_0: first exceedance at index 255 (value=0.010035493411123753, threshold=0.01)
# Appended cutoff for model_1_data_11 | target=0, cutoff_idx=255
# Model_0: first exceedance at index 247 (value=0.010001393035054207, threshold=0.01)
# Appended cutoff for model_2_data_12 | target=0, cutoff_idx=247
# Model_0: first exceedance at index 252 (value=0.0100100701674819, threshold=0.01)
# Appended cutoff for model_3_data_13 | target=0, cutoff_idx=252
# Model_0: first exceedance at index 261 (value=0.01000791136175394, threshold=0.01)
# Appended cutoff for model_4_data_14 | target=0, cutoff_idx=261
# Model_0: first exceedance at index 276 (value=0.010018812492489815, threshold=0.01)
# Appended cutoff for model_5_data_15 | target=0, cutoff_idx=276
# Model_0: first exceedance at index 260 (value=0.010016633197665215, threshold=0.01)
# Appended cutoff for model_6_data_16 | target=0, cutoff_idx=260
# Model_0: first exceedance at index 252 (value=0.010027056559920311, threshold=0.01)
# Appended cutoff for model_7_data_17 | target=0, cutoff_idx=252
# Model_0: first exceedance at index 249 (value=0.010032079182565212, threshold=0.01)
# Appended cutoff for model_8_data_18 | target=0, cutoff_idx=249
# Model_0: first exceedance at index 271 (value=0.010011612437665462, threshold=0.01)
# Appended cutoff for model_9_data_19 | target=0, cutoff_idx=271
# Model_846: first exceedance at index 1496 (value=0.01000184379518032, threshold=0.01)
# Appended cutoff for model_0_data_10 | target=846, cutoff_idx=1496
# Model_846: first exceedance at index 1478 (value=0.01000654511153698, threshold=0.01)
# Appended cutoff for model_1_data_11 | target=846, cutoff_idx=1478
# Model_846: first exceedance at index 1484 (value=0.01000265683978796, threshold=0.01)
# Appended cutoff for model_2_data_12 | target=846, cutoff_idx=1484
# Model_846: first exceedance at index 1487 (value=0.010005857795476913, threshold=0.01)
# Appended cutoff for model_3_data_13 | target=846, cutoff_idx=1487
# Model_846: first exceedance at index 1498 (value=0.010004362091422081, threshold=0.01)
# Appended cutoff for model_4_data_14 | target=846, cutoff_idx=1498
# Model_846: first exceedance at index 1507 (value=0.010001221671700478, threshold=0.01)
# Appended cutoff for model_5_data_15 | target=846, cutoff_idx=1507
# Model_846: first exceedance at index 1476 (value=0.010006090626120567, threshold=0.01)
# Appended cutoff for model_6_data_16 | target=846, cutoff_idx=1476
# Model_846: first exceedance at index 1503 (value=0.010013323277235031, threshold=0.01)
# Appended cutoff for model_7_data_17 | target=846, cutoff_idx=1503
# Model_846: first exceedance at index 1518 (value=0.010008743964135647, threshold=0.01)
# Appended cutoff for model_8_data_18 | target=846, cutoff_idx=1518
# Model_846: first exceedance at index 1502 (value=0.010008101351559162, threshold=0.01)
# Appended cutoff for model_9_data_19 | target=846, cutoff_idx=1502
# Model_1787: first exceedance at index 3134 (value=0.010001188144087791, threshold=0.01)
# Appended cutoff for model_0_data_10 | target=1787, cutoff_idx=3134
# Model_1787: first exceedance at index 3116 (value=0.010001400485634804, threshold=0.01)
# Appended cutoff for model_1_data_11 | target=1787, cutoff_idx=3116
# Model_1787: first exceedance at index 3175 (value=0.010000652633607388, threshold=0.01)
# Appended cutoff for model_2_data_12 | target=1787, cutoff_idx=3175
# Model_1787: first exceedance at index 3143 (value=0.010000302456319332, threshold=0.01)
# Appended cutoff for model_3_data_13 | target=1787, cutoff_idx=3143
# Model_1787: first exceedance at index 3154 (value=0.010003260336816311, threshold=0.01)
# Appended cutoff for model_4_data_14 | target=1787, cutoff_idx=3154
# Model_1787: first exceedance at index 3135 (value=0.010001241229474545, threshold=0.01)
# Appended cutoff for model_5_data_15 | target=1787, cutoff_idx=3135
# Model_1787: first exceedance at index 3088 (value=0.01000035647302866, threshold=0.01)
# Appended cutoff for model_6_data_16 | target=1787, cutoff_idx=3088
# Model_1787: first exceedance at index 3161 (value=0.010001200251281261, threshold=0.01)
# Appended cutoff for model_7_data_17 | target=1787, cutoff_idx=3161
# Model_1787: first exceedance at index 3188 (value=0.010000627487897873, threshold=0.01)
# Appended cutoff for model_8_data_18 | target=1787, cutoff_idx=3188
# Model_1787: first exceedance at index 3157 (value=0.010000948794186115, threshold=0.01)
# Appended cutoff for model_9_data_19 | target=1787, cutoff_idx=3157
# ⚠️ Skipped model_0_data_10 (target=3669): Model_3669: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_1_data_11 (target=3669): Model_3669: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_2_data_12 (target=3669): Model_3669: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_3_data_13 (target=3669): Model_3669: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_4_data_14 (target=3669): Model_3669: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_5_data_15 (target=3669): Model_3669: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_6_data_16 (target=3669): Model_3669: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_7_data_17 (target=3669): Model_3669: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_8_data_18 (target=3669): Model_3669: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_9_data_19 (target=3669): Model_3669: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_0_data_10 (target=5551): Model_5551: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_1_data_11 (target=5551): Model_5551: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_2_data_12 (target=5551): Model_5551: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_3_data_13 (target=5551): Model_5551: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_4_data_14 (target=5551): Model_5551: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_5_data_15 (target=5551): Model_5551: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_6_data_16 (target=5551): Model_5551: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_7_data_17 (target=5551): Model_5551: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_8_data_18 (target=5551): Model_5551: loss curve never exceeds threshold=0.01
# ⚠️ Skipped model_9_data_19 (target=5551): Model_5551: loss curve never exceeds threshold=0.01
# ([94, 940, 1881, 3763, 5645],
#  [195309.24270237942,
#   108252.9784458013,
#   103666.04097589962,
#   112970.22110083664,
#   101466.64767484624])

# %%
plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          # NEW: needed for correct legend labels
    base_train_size=base_train_size,  # NEW: used for dataset size shifts
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = True,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels_log",
    xlabel_size=15, ylabel_size=15, title_size=15,
    ylim = (90000, 200000)
)
# Out:
# ([94, 940, 1881, 3763, 5645],
#  [195309.24270237942,
#   108252.9784458013,
#   103666.04097589962,
#   112970.22110083664,
#   101466.64767484624])
