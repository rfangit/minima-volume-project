# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 12            
model_seed = 2           

# --- Training configuration ---
epochs = 500            

# --- Dataset configuration ---
base_data_size = (int)(0.02*9409)
dataset_type = "data"   
dataset_quantities = [0, (int)(0.03*9409), (int)(0.08*9409), 
                      (int)(0.18*9409), (int)(0.28*9409),
                      (int)(0.33*9409),
                      (int)(0.38*9409), (int)(0.48*9409),
                     (int)(0.58*9409), (int)(0.68*9409),] # modulo arithmetic dataset sizes

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %%
print (base_data_size)
print (dataset_quantities)
# Out:
# 188
# [0, 282, 752, 1693, 2634, 3104, 3575, 4516, 5457, 6398]

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import modulo_arithmetic_model_data as model_module
modulus = 97
# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    modulus = modulus,
    device = device,
)

# MNIST specific initialization parameters
hidden_dims = [250]

# Grab model
model_template = model_module.get_model(N = modulus, hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/500: Train Loss 0.0125 | Test Loss 0.0119 | accs Train 0.0106 Test 0.0108
# Epoch 100/500: Train Loss 0.0014 | Test Loss 0.0158 | accs Train 1.0000 Test 0.0202
# Epoch 200/500: Train Loss 0.0000 | Test Loss 0.0185 | accs Train 1.0000 Test 0.0203
# Epoch 300/500: Train Loss 0.0000 | Test Loss 0.0188 | accs Train 1.0000 Test 0.0203
# Epoch 400/500: Train Loss 0.0000 | Test Loss 0.0188 | accs Train 1.0000 Test 0.0203
# Epoch 500/500: Train Loss 0.0000 | Test Loss 0.0188 | accs Train 1.0000 Test 0.0203
# Completed training with 0 additional samples of data
# Epoch 1/500: Train Loss 0.0125 | Test Loss 0.0119 | accs Train 0.0106 Test 0.0108
# Epoch 100/500: Train Loss 0.0042 | Test Loss 0.0142 | accs Train 1.0000 Test 0.0500
# Epoch 200/500: Train Loss 0.0013 | Test Loss 0.0182 | accs Train 1.0000 Test 0.0500
# Epoch 300/500: Train Loss 0.0004 | Test Loss 0.0210 | accs Train 1.0000 Test 0.0502
# Epoch 400/500: Train Loss 0.0002 | Test Loss 0.0228 | accs Train 1.0000 Test 0.0502
# Epoch 500/500: Train Loss 0.0001 | Test Loss 0.0239 | accs Train 1.0000 Test 0.0504
# Completed training with 282 additional samples of data
# Epoch 1/500: Train Loss 0.0125 | Test Loss 0.0119 | accs Train 0.0106 Test 0.0107
# Epoch 100/500: Train Loss 0.0065 | Test Loss 0.0124 | accs Train 1.0000 Test 0.0999
# Epoch 200/500: Train Loss 0.0039 | Test Loss 0.0151 | accs Train 1.0000 Test 0.1004
# Epoch 300/500: Train Loss 0.0026 | Test Loss 0.0177 | accs Train 1.0000 Test 0.1012
# Epoch 400/500: Train Loss 0.0019 | Test Loss 0.0199 | accs Train 1.0000 Test 0.1022
# Epoch 500/500: Train Loss 0.0016 | Test Loss 0.0218 | accs Train 1.0000 Test 0.1017
# Completed training with 752 additional samples of data
# Epoch 1/500: Train Loss 0.0124 | Test Loss 0.0118 | accs Train 0.0112 Test 0.0105
# Epoch 100/500: Train Loss 0.0082 | Test Loss 0.0111 | accs Train 0.9702 Test 0.1942
# Epoch 200/500: Train Loss 0.0065 | Test Loss 0.0124 | accs Train 0.9989 Test 0.2006
# Epoch 300/500: Train Loss 0.0055 | Test Loss 0.0136 | accs Train 1.0000 Test 0.2023
# Epoch 400/500: Train Loss 0.0050 | Test Loss 0.0145 | accs Train 1.0000 Test 0.2023
# Epoch 500/500: Train Loss 0.0047 | Test Loss 0.0152 | accs Train 1.0000 Test 0.2025
# Completed training with 1693 additional samples of data
# Epoch 1/500: Train Loss 0.0124 | Test Loss 0.0118 | accs Train 0.0110 Test 0.0105
# Epoch 100/500: Train Loss 0.0089 | Test Loss 0.0106 | accs Train 0.8845 Test 0.2659
# Epoch 200/500: Train Loss 0.0076 | Test Loss 0.0111 | accs Train 0.9833 Test 0.2962
# Epoch 300/500: Train Loss 0.0069 | Test Loss 0.0116 | accs Train 0.9922 Test 0.3012
# Epoch 400/500: Train Loss 0.0064 | Test Loss 0.0119 | accs Train 0.9940 Test 0.3052
# Epoch 500/500: Train Loss 0.0061 | Test Loss 0.0121 | accs Train 0.9968 Test 0.3077
# Completed training with 2634 additional samples of data
# Epoch 1/500: Train Loss 0.0125 | Test Loss 0.0118 | accs Train 0.0106 Test 0.0107
# Epoch 100/500: Train Loss 0.0091 | Test Loss 0.0105 | accs Train 0.8211 Test 0.2884
# Epoch 200/500: Train Loss 0.0079 | Test Loss 0.0108 | accs Train 0.9599 Test 0.3372
# Epoch 300/500: Train Loss 0.0072 | Test Loss 0.0110 | accs Train 0.9860 Test 0.3502
# Epoch 400/500: Train Loss 0.0068 | Test Loss 0.0111 | accs Train 0.9951 Test 0.3597
# Epoch 500/500: Train Loss 0.0065 | Test Loss 0.0110 | accs Train 0.9988 Test 0.3721
# Completed training with 3104 additional samples of data
# Epoch 1/500: Train Loss 0.0125 | Test Loss 0.0118 | accs Train 0.0098 Test 0.0106
# Epoch 100/500: Train Loss 0.0093 | Test Loss 0.0104 | accs Train 0.7390 Test 0.2974
# Epoch 200/500: Train Loss 0.0082 | Test Loss 0.0105 | accs Train 0.9314 Test 0.3739
# Epoch 300/500: Train Loss 0.0075 | Test Loss 0.0105 | accs Train 0.9814 Test 0.4003
# Epoch 400/500: Train Loss 0.0070 | Test Loss 0.0102 | accs Train 0.9952 Test 0.4268
# Epoch 500/500: Train Loss 0.0064 | Test Loss 0.0096 | accs Train 0.9987 Test 0.5262
# Completed training with 3575 additional samples of data
# Epoch 1/500: Train Loss 0.0125 | Test Loss 0.0118 | accs Train 0.0096 Test 0.0107
# Epoch 100/500: Train Loss 0.0095 | Test Loss 0.0102 | accs Train 0.6214 Test 0.3126
# Epoch 200/500: Train Loss 0.0086 | Test Loss 0.0100 | accs Train 0.8865 Test 0.4471
# Epoch 300/500: Train Loss 0.0075 | Test Loss 0.0092 | accs Train 0.9870 Test 0.5797
# Epoch 400/500: Train Loss 0.0062 | Test Loss 0.0077 | accs Train 0.9998 Test 0.9355
# Epoch 500/500: Train Loss 0.0045 | Test Loss 0.0056 | accs Train 1.0000 Test 0.9999
# Completed training with 4516 additional samples of data
# Epoch 1/500: Train Loss 0.0125 | Test Loss 0.0118 | accs Train 0.0097 Test 0.0107
# Epoch 100/500: Train Loss 0.0096 | Test Loss 0.0101 | accs Train 0.5059 Test 0.3076
# Epoch 200/500: Train Loss 0.0087 | Test Loss 0.0096 | accs Train 0.8526 Test 0.5242
# Epoch 300/500: Train Loss 0.0071 | Test Loss 0.0080 | accs Train 0.9963 Test 0.8789
# Epoch 400/500: Train Loss 0.0048 | Test Loss 0.0054 | accs Train 1.0000 Test 1.0000
# Epoch 500/500: Train Loss 0.0030 | Test Loss 0.0033 | accs Train 1.0000 Test 1.0000
# Completed training with 5457 additional samples of data
# Epoch 1/500: Train Loss 0.0125 | Test Loss 0.0118 | accs Train 0.0102 Test 0.0107
# Epoch 100/500: Train Loss 0.0097 | Test Loss 0.0100 | accs Train 0.4165 Test 0.2961
# Epoch 200/500: Train Loss 0.0087 | Test Loss 0.0092 | accs Train 0.8583 Test 0.6333
# Epoch 300/500: Train Loss 0.0064 | Test Loss 0.0069 | accs Train 0.9998 Test 0.9944
# Epoch 400/500: Train Loss 0.0036 | Test Loss 0.0038 | accs Train 1.0000 Test 1.0000
# Epoch 500/500: Train Loss 0.0021 | Test Loss 0.0022 | accs Train 1.0000 Test 1.0000
# Completed training with 6398 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 0.0188 | accs: 0.0203
#  282 samples | Test Loss: 0.0239 | accs: 0.0504
#  752 samples | Test Loss: 0.0218 | accs: 0.1017
# 1693 samples | Test Loss: 0.0152 | accs: 0.2025
# 2634 samples | Test Loss: 0.0121 | accs: 0.3077
# 3104 samples | Test Loss: 0.0110 | accs: 0.3721
# 3575 samples | Test Loss: 0.0096 | accs: 0.5262
# 4516 samples | Test Loss: 0.0056 | accs: 0.9999
# 5457 samples | Test Loss: 0.0033 | accs: 1.0000
# 6398 samples | Test Loss: 0.0022 | accs: 1.0000
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  282 | Train Loss: 0.0001 | accs: 1.0000
#  Model  752 | Train Loss: 0.0016 | accs: 1.0000
#  Model 1693 | Train Loss: 0.0047 | accs: 1.0000
#  Model 2634 | Train Loss: 0.0062 | accs: 1.0000
#  Model 3104 | Train Loss: 0.0064 | accs: 1.0000
#  Model 3575 | Train Loss: 0.0065 | accs: 0.9947
#  Model 4516 | Train Loss: 0.0046 | accs: 1.0000
#  Model 5457 | Train Loss: 0.0030 | accs: 1.0000
#  Model 6398 | Train Loss: 0.0021 | accs: 1.0000
#
# Dataset type: data, additional samples: 282
#  Model    0 | Train Loss: 0.0115 | accs: 0.4000
#  Model  282 | Train Loss: 0.0001 | accs: 1.0000
#  Model  752 | Train Loss: 0.0016 | accs: 1.0000
#  Model 1693 | Train Loss: 0.0047 | accs: 1.0000
#  Model 2634 | Train Loss: 0.0062 | accs: 1.0000
#  Model 3104 | Train Loss: 0.0065 | accs: 0.9979
#  Model 3575 | Train Loss: 0.0065 | accs: 0.9979
#  Model 4516 | Train Loss: 0.0046 | accs: 1.0000
#  Model 5457 | Train Loss: 0.0030 | accs: 1.0000
#  Model 6398 | Train Loss: 0.0021 | accs: 1.0000
#
# Dataset type: data, additional samples: 752
#  Model    0 | Train Loss: 0.0153 | accs: 0.2000
#  Model  282 | Train Loss: 0.0126 | accs: 0.5000
#  Model  752 | Train Loss: 0.0016 | accs: 1.0000
#  Model 1693 | Train Loss: 0.0047 | accs: 1.0000
#  Model 2634 | Train Loss: 0.0062 | accs: 1.0000
#  Model 3104 | Train Loss: 0.0065 | accs: 0.9989
#  Model 3575 | Train Loss: 0.0065 | accs: 0.9989
#  Model 4516 | Train Loss: 0.0046 | accs: 1.0000
#  Model 5457 | Train Loss: 0.0030 | accs: 1.0000
#  Model 6398 | Train Loss: 0.0021 | accs: 1.0000
#
# Dataset type: data, additional samples: 1693
#  Model    0 | Train Loss: 0.0172 | accs: 0.0999
#  Model  282 | Train Loss: 0.0188 | accs: 0.2499
#  Model  752 | Train Loss: 0.0128 | accs: 0.5003
#  Model 1693 | Train Loss: 0.0047 | accs: 1.0000
#  Model 2634 | Train Loss: 0.0062 | accs: 0.9968
#  Model 3104 | Train Loss: 0.0065 | accs: 0.9984
#  Model 3575 | Train Loss: 0.0064 | accs: 0.9984
#  Model 4516 | Train Loss: 0.0045 | accs: 1.0000
#  Model 5457 | Train Loss: 0.0030 | accs: 1.0000
#  Model 6398 | Train Loss: 0.0021 | accs: 1.0000
#
# Dataset type: data, additional samples: 2634
#  Model    0 | Train Loss: 0.0179 | accs: 0.0670
#  Model  282 | Train Loss: 0.0209 | accs: 0.1669
#  Model  752 | Train Loss: 0.0165 | accs: 0.3342
#  Model 1693 | Train Loss: 0.0091 | accs: 0.6680
#  Model 2634 | Train Loss: 0.0061 | accs: 0.9965
#  Model 3104 | Train Loss: 0.0065 | accs: 0.9986
#  Model 3575 | Train Loss: 0.0064 | accs: 0.9982
#  Model 4516 | Train Loss: 0.0045 | accs: 1.0000
#  Model 5457 | Train Loss: 0.0030 | accs: 1.0000
#  Model 6398 | Train Loss: 0.0021 | accs: 1.0000
#
# Dataset type: data, additional samples: 3104
#  Model    0 | Train Loss: 0.0181 | accs: 0.0574
#  Model  282 | Train Loss: 0.0215 | accs: 0.1434
#  Model  752 | Train Loss: 0.0176 | accs: 0.2874
#  Model 1693 | Train Loss: 0.0103 | accs: 0.5729
#  Model 2634 | Train Loss: 0.0073 | accs: 0.8554
#  Model 3104 | Train Loss: 0.0065 | accs: 0.9988
#  Model 3575 | Train Loss: 0.0064 | accs: 0.9985
#  Model 4516 | Train Loss: 0.0045 | accs: 1.0000
#  Model 5457 | Train Loss: 0.0030 | accs: 1.0000
#  Model 6398 | Train Loss: 0.0021 | accs: 1.0000
#
# Dataset type: data, additional samples: 3575
#  Model    0 | Train Loss: 0.0182 | accs: 0.0502
#  Model  282 | Train Loss: 0.0220 | accs: 0.1254
#  Model  752 | Train Loss: 0.0184 | accs: 0.2514
#  Model 1693 | Train Loss: 0.0112 | accs: 0.5015
#  Model 2634 | Train Loss: 0.0083 | accs: 0.7499
#  Model 3104 | Train Loss: 0.0074 | accs: 0.8783
#  Model 3575 | Train Loss: 0.0064 | accs: 0.9987
#  Model 4516 | Train Loss: 0.0045 | accs: 1.0000
#  Model 5457 | Train Loss: 0.0030 | accs: 1.0000
#  Model 6398 | Train Loss: 0.0021 | accs: 1.0000
#
# Dataset type: data, additional samples: 4516
#  Model    0 | Train Loss: 0.0184 | accs: 0.0402
#  Model  282 | Train Loss: 0.0226 | accs: 0.1006
#  Model  752 | Train Loss: 0.0195 | accs: 0.2017
#  Model 1693 | Train Loss: 0.0125 | accs: 0.4020
#  Model 2634 | Train Loss: 0.0095 | accs: 0.6023
#  Model 3104 | Train Loss: 0.0086 | accs: 0.7107
#  Model 3575 | Train Loss: 0.0075 | accs: 0.8414
#  Model 4516 | Train Loss: 0.0045 | accs: 1.0000
#  Model 5457 | Train Loss: 0.0030 | accs: 1.0000
#  Model 6398 | Train Loss: 0.0021 | accs: 1.0000
#
# Dataset type: data, additional samples: 5457
#  Model    0 | Train Loss: 0.0186 | accs: 0.0335
#  Model  282 | Train Loss: 0.0230 | accs: 0.0838
#  Model  752 | Train Loss: 0.0203 | accs: 0.1683
#  Model 1693 | Train Loss: 0.0134 | accs: 0.3352
#  Model 2634 | Train Loss: 0.0104 | accs: 0.5049
#  Model 3104 | Train Loss: 0.0094 | accs: 0.5988
#  Model 3575 | Train Loss: 0.0082 | accs: 0.7368
#  Model 4516 | Train Loss: 0.0048 | accs: 1.0000
#  Model 5457 | Train Loss: 0.0030 | accs: 1.0000
#  Model 6398 | Train Loss: 0.0021 | accs: 1.0000
#
# Dataset type: data, additional samples: 6398
#  Model    0 | Train Loss: 0.0186 | accs: 0.0288
#  Model  282 | Train Loss: 0.0233 | accs: 0.0718
#  Model  752 | Train Loss: 0.0208 | accs: 0.1444
#  Model 1693 | Train Loss: 0.0141 | accs: 0.2880
#  Model 2634 | Train Loss: 0.0110 | accs: 0.4353
#  Model 3104 | Train Loss: 0.0099 | accs: 0.5182
#  Model 3575 | Train Loss: 0.0087 | accs: 0.6608
#  Model 4516 | Train Loss: 0.0051 | accs: 1.0000
#  Model 5457 | Train Loss: 0.0031 | accs: 1.0000
#  Model 6398 | Train Loss: 0.0021 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_282.pt
# Saved model: models_and_data/model_additional_282.pt
# ✅ Model saved to models_and_data\model_additional_752.pt
# Saved model: models_and_data/model_additional_752.pt
# ✅ Model saved to models_and_data\model_additional_1693.pt
# Saved model: models_and_data/model_additional_1693.pt
# ✅ Model saved to models_and_data\model_additional_2634.pt
# Saved model: models_and_data/model_additional_2634.pt
# ✅ Model saved to models_and_data\model_additional_3104.pt
# Saved model: models_and_data/model_additional_3104.pt
# ✅ Model saved to models_and_data\model_additional_3575.pt
# Saved model: models_and_data/model_additional_3575.pt
# ✅ Model saved to models_and_data\model_additional_4516.pt
# Saved model: models_and_data/model_additional_4516.pt
# ✅ Model saved to models_and_data\model_additional_5457.pt
# Saved model: models_and_data/model_additional_5457.pt
# ✅ Model saved to models_and_data\model_additional_6398.pt
# Saved model: models_and_data/model_additional_6398.pt
