# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.05, 0.02]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}"
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['data_0', 'data_1787', 'data_3669', 'data_5551', 'data_846']
#
# ==================================================
# Analyzing directory: data_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from data_0
# The number of model parameters is  73097
# The loss landscape is for data trained with 0
# data_0: 1.8389071598789997e-08
# data_1787: 0.004512520506978035
# data_3669: 0.005824447143822908
# data_5551: 0.002471972955390811
# data_846: 0.0015585265355184674
#
# Top perturbations for data_0:
# Top 5 r_vals: [35.841280346074385, 33.98191835208641, 33.94115484195053, 33.88906283690461, 33.874965154349894]
# Top 5 seeds: [590, 264, 633, 365, 420]
#
# Top perturbations for data_1787:
# Top 5 r_vals: [15.978436710858588, 15.95733435204316, 15.94389742596419, 15.936099273989901, 15.934775668618]
# Top 5 seeds: [264, 343, 872, 156, 365]
#
# Top perturbations for data_3669:
# Top 5 r_vals: [18.693338600254442, 18.691237934705327, 18.674043208381963, 18.668658937365294, 18.667890657880896]
# Top 5 seeds: [346, 924, 30, 209, 453]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [12.27683548800326, 12.274816956182924, 12.267552987931518, 12.252619971913742, 12.245572961504248]
# Top 5 seeds: [553, 569, 178, 706, 711]
#
# Top perturbations for data_846:
# Top 5 r_vals: [13.434473861882717, 13.426325291763119, 13.422177915219908, 13.417421694155093, 13.41389823254244]
# Top 5 seeds: [903, 264, 195, 375, 525]
# Plot saved to: data_0/loss_0.1/log_volume.png
# Test loss  [0.01553810762140719, 0.015517971763075133, 0.008813089431868386, 0.0028033899458348734, 0.02233411459287278]
# log_exp_r_n  [261614.58770789087, 202562.43039701306, 214033.33295148038, 183299.47662325835, 189886.23898759935]
# Plot saved to: data_0/loss_0.1/gen_log_volume.png
# Plot saved to: data_0/loss_0.1/test_vs_data.png
# Plot saved to: data_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.95/avg_radius.png
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: divide by zero encountered in divide
#   return n/db/n.sum(), bin_edges
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Plot saved to: data_0/acc_0.95/radius_hist.png
# Plot saved to: data_0/acc_0.95/log_volume.png
# Plot saved to: data_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 3, 2, 1, 4]
# test_loss ranks: [2, 3, 4, 5, 1]
# log_exp_r_n ranks: [1, 3, 2, 5, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.1\results.json
# Successfully analyzed data_0 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from data_0
# The number of model parameters is  73097
# The loss landscape is for data trained with 0
# data_0: 1.8389071598789997e-08
# data_1787: 0.004512520506978035
# data_3669: 0.005824447143822908
# data_5551: 0.002471972955390811
# data_846: 0.0015585265355184674
# Top perturbations for data_0:
# Top 5 r_vals: [26.658468192942887, 26.62648963519547, 26.585623988788015, 26.576751861556698, 26.57456450067775]
# Top 5 seeds: [264, 633, 365, 590, 420]
#
# Top perturbations for data_1787:
# Top 5 r_vals: [11.135451689798876, 11.133620821934628, 11.127032188600019, 11.127001051391442, 11.113487502869608]
# Top 5 seeds: [553, 569, 178, 530, 706]
#
# Top perturbations for data_3669:
# Top 5 r_vals: [13.471681194540896, 13.463708948206019, 13.434473861882717, 13.426325291763119, 13.422177915219908]
# Top 5 seeds: [569, 178, 903, 264, 195]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [9.019715868737087, 9.018232865767045, 9.012896072766013, 9.001924877324381, 8.996747481921489]
# Top 5 seeds: [553, 569, 178, 706, 711]
#
# Top perturbations for data_846:
# Top 5 r_vals: [10.020341041610871, 9.994653053155252, 9.994112383551824, 9.989870206663385, 9.988386456400338]
# Top 5 seeds: [903, 169, 796, 871, 815]
# Plot saved to: data_0/loss_0.05/log_volume.png
# Test loss  [0.01553810762140719, 0.015517971763075133, 0.008813089431868386, 0.0028033899458348734, 0.02233411459287278]
# log_exp_r_n  [239978.35409562697, 176166.64736267243, 190088.40433774027, 160763.57213659212, 168453.69068159236]
# Plot saved to: data_0/loss_0.05/gen_log_volume.png
# Plot saved to: data_0/loss_0.05/test_vs_data.png
# Plot saved to: data_0/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.9/avg_radius.png
# Plot saved to: data_0/acc_0.9/radius_hist.png
# Plot saved to: data_0/acc_0.9/log_volume.png
# Plot saved to: data_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 3, 2, 1, 4]
# test_loss ranks: [2, 3, 4, 5, 1]
# log_exp_r_n ranks: [1, 3, 2, 5, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.05\results.json
# Successfully analyzed data_0 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 5 models from data_0
# The number of model parameters is  73097
# The loss landscape is for data trained with 0
# data_0: 1.8389071598789997e-08
# data_1787: 0.004512520506978035
# data_3669: 0.005824447143822908
# data_5551: 0.002471972955390811
# data_846: 0.0015585265355184674
#
# Top perturbations for data_0:
# Top 5 r_vals: [18.752470862049318, 18.72997605972127, 18.70122977775307, 18.69498882248942, 18.69343331964293]
# Top 5 seeds: [264, 633, 365, 590, 414]
#
# Top perturbations for data_1787:
# Top 5 r_vals: [7.121300600704011, 7.112632001836548, 7.108036648046118, 7.105837414549536, 7.104935083154781]
# Top 5 seeds: [178, 706, 94, 903, 850]
#
# Top perturbations for data_3669:
# Top 5 r_vals: [8.045363845879688, 8.044041043847768, 8.039280756263514, 8.029494720823292, 8.024876611960835]
# Top 5 seeds: [553, 569, 178, 706, 711]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [5.45637132800145, 5.455474202747968, 5.45224577241401, 5.452230515181808, 5.445608876406109]
# Top 5 seeds: [553, 569, 178, 530, 706]
#
# Top perturbations for data_846:
# Top 5 r_vals: [6.263691575511866, 6.262661712338226, 6.258955606087509, 6.247297835196783, 6.245364915131429]
# Top 5 seeds: [553, 569, 178, 94, 903]
# Plot saved to: data_0/loss_0.02/log_volume.png
# Test loss  [0.01553810762140719, 0.015517971763075133, 0.008813089431868386, 0.0028033899458348734, 0.02233411459287278]
# log_exp_r_n  [214264.19400263805, 143489.1095600818, 152407.3549836747, 124022.9106084934, 134109.25446265674]
# Plot saved to: data_0/loss_0.02/gen_log_volume.png
# Plot saved to: data_0/loss_0.02/test_vs_data.png
# Plot saved to: data_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 3, 2, 1, 4]
# test_loss ranks: [2, 3, 4, 5, 1]
# log_exp_r_n ranks: [1, 3, 2, 5, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.02\results.json
# Successfully analyzed data_0 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_1787
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 3 models from data_1787
# The number of model parameters is  73097
# The loss landscape is for data trained with 1787
# data_1787: 0.0046468377113342285
# data_3669: 0.005910046398639679
# data_5551: 0.002519510453566909
#
# Top perturbations for data_1787:
# Top 5 r_vals: [15.978436710858588, 15.94714725378788, 15.94389742596419, 15.937148473370065, 15.929457931588615]
# Top 5 seeds: [264, 169, 872, 815, 590]
#
# Top perturbations for data_3669:
# Top 5 r_vals: [18.704014527774593, 18.674043208381963, 18.66573526557399, 18.6590207133679, 18.648734187778196]
# Top 5 seeds: [815, 30, 443, 313, 826]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [12.27683548800326, 12.274816956182924, 12.267552987931518, 12.252619971913742, 12.244703756985697]
# Top 5 seeds: [553, 569, 178, 706, 94]
# Plot saved to: data_1787/loss_0.1/log_volume.png
# Test loss  [0.015517971763075133, 0.008813089431868386, 0.0028033899458348734]
# log_exp_r_n  [202562.43039701306, 214075.06709414313, 183299.47662325835]
# Plot saved to: data_1787/loss_0.1/gen_log_volume.png
# Plot saved to: data_1787/loss_0.1/test_vs_data.png
# Plot saved to: data_1787/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_1787/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_1787/acc_0.95/avg_radius.png
# Plot saved to: data_1787/acc_0.95/radius_hist.png
# Plot saved to: data_1787/acc_0.95/log_volume.png
# Plot saved to: data_1787/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_1787/loss_0.1\results.json
# Successfully analyzed data_1787 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_1787
# The number of model parameters is  73097
# The loss landscape is for data trained with 1787
# data_1787: 0.0046468377113342285
# data_3669: 0.005910046398639679
# data_5551: 0.002519510453566909
#
# Top perturbations for data_1787:
# Top 5 r_vals: [11.135451689798876, 11.133620821934628, 11.127032188600019, 11.113487502869608, 11.107095656693197]
# Top 5 seeds: [553, 569, 178, 706, 711]
#
# Top perturbations for data_3669:
# Top 5 r_vals: [13.471681194540896, 13.463708948206019, 13.434473861882717, 13.426325291763119, 13.422177915219908]
# Top 5 seeds: [569, 178, 903, 264, 195]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [9.019715868737087, 9.018232865767045, 9.012896072766013, 9.001924877324381, 8.993325477789256]
# Top 5 seeds: [553, 569, 178, 706, 903]
# Plot saved to: data_1787/loss_0.05/log_volume.png
# Test loss  [0.015517971763075133, 0.008813089431868386, 0.0028033899458348734]
# log_exp_r_n  [176166.64736267243, 190088.40433774027, 160763.57213659212]
# Plot saved to: data_1787/loss_0.05/gen_log_volume.png
# Plot saved to: data_1787/loss_0.05/test_vs_data.png
# Plot saved to: data_1787/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_1787/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_1787/acc_0.9/avg_radius.png
# Plot saved to: data_1787/acc_0.9/radius_hist.png
# Plot saved to: data_1787/acc_0.9/log_volume.png
# Plot saved to: data_1787/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_1787/loss_0.05\results.json
# Successfully analyzed data_1787 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_1787
# The number of model parameters is  73097
# The loss landscape is for data trained with 1787
# data_1787: 0.0046468377113342285
# data_3669: 0.005910046398639679
# data_5551: 0.002519510453566909
#
# Top perturbations for data_1787:
# Top 5 r_vals: [7.105837414549536, 7.101527427048262, 7.099759431435569, 7.099333773339456, 7.097288382563004]
# Top 5 seeds: [903, 264, 424, 195, 182]
#
# Top perturbations for data_3669:
# Top 5 r_vals: [8.045363845879688, 8.044041043847768, 8.039280756263514, 8.029494720823292, 8.024876611960835]
# Top 5 seeds: [553, 569, 178, 706, 711]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [5.45637132800145, 5.455474202747968, 5.45224577241401, 5.452230515181808, 5.445608876406109]
# Top 5 seeds: [553, 569, 178, 530, 706]
# Plot saved to: data_1787/loss_0.02/log_volume.png
# Test loss  [0.015517971763075133, 0.008813089431868386, 0.0028033899458348734]
# log_exp_r_n  [143330.2142204563, 152407.3549836747, 124022.9106084934]
# Plot saved to: data_1787/loss_0.02/gen_log_volume.png
# Plot saved to: data_1787/loss_0.02/test_vs_data.png
# Plot saved to: data_1787/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_1787/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_1787/acc_0.85/avg_radius.png
# Plot saved to: data_1787/acc_0.85/radius_hist.png
# Plot saved to: data_1787/acc_0.85/log_volume.png
# Plot saved to: data_1787/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_1787/loss_0.02\results.json
# Successfully analyzed data_1787 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_3669
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_3669
# The number of model parameters is  73097
# The loss landscape is for data trained with 3669
# data_3669: 0.005913993809372187
# data_5551: 0.002527168020606041
#
# Top perturbations for data_3669:
# Top 5 r_vals: [18.704014527774593, 18.674043208381963, 18.668658937365294, 18.66573526557399, 18.6590207133679]
# Top 5 seeds: [815, 30, 209, 443, 313]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [12.27683548800326, 12.274816956182924, 12.267552987931518, 12.252619971913742, 12.244703756985697]
# Top 5 seeds: [553, 569, 178, 706, 94]
# Plot saved to: data_3669/loss_0.1/log_volume.png
# Test loss  [0.008813089431868386, 0.0028033899458348734]
# log_exp_r_n  [214075.06709414313, 183299.47662325835]
# Plot saved to: data_3669/loss_0.1/gen_log_volume.png
# Plot saved to: data_3669/loss_0.1/test_vs_data.png
# Plot saved to: data_3669/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_3669/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_3669/acc_0.95/avg_radius.png
# Plot saved to: data_3669/acc_0.95/radius_hist.png
# Plot saved to: data_3669/acc_0.95/log_volume.png
# Plot saved to: data_3669/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_3669/loss_0.1\results.json
# Successfully analyzed data_3669 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_3669
# The number of model parameters is  73097
# The loss landscape is for data trained with 3669
# data_3669: 0.005913993809372187
# data_5551: 0.002527168020606041
#
# Top perturbations for data_3669:
# Top 5 r_vals: [13.471681194540896, 13.463708948206019, 13.434473861882717, 13.426325291763119, 13.422177915219908]
# Top 5 seeds: [569, 178, 903, 264, 195]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [9.019715868737087, 9.018232865767045, 9.012896072766013, 9.001924877324381, 8.993325477789256]
# Top 5 seeds: [553, 569, 178, 706, 903]
# Plot saved to: data_3669/loss_0.05/log_volume.png
# Test loss  [0.008813089431868386, 0.0028033899458348734]
# log_exp_r_n  [190088.40433774027, 160763.57213659212]
# Plot saved to: data_3669/loss_0.05/gen_log_volume.png
# Plot saved to: data_3669/loss_0.05/test_vs_data.png
# Plot saved to: data_3669/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_3669/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_3669/acc_0.9/avg_radius.png
# Plot saved to: data_3669/acc_0.9/radius_hist.png
# Plot saved to: data_3669/acc_0.9/log_volume.png
# Plot saved to: data_3669/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_3669/loss_0.05\results.json
# Successfully analyzed data_3669 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_3669
# The number of model parameters is  73097
# The loss landscape is for data trained with 3669
# data_3669: 0.005913993809372187
# data_5551: 0.002527168020606041
#
# Top perturbations for data_3669:
# Top 5 r_vals: [8.045363845879688, 8.044041043847768, 8.039280756263514, 8.029494720823292, 8.024306997208315]
# Top 5 seeds: [553, 569, 178, 706, 94]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [5.45637132800145, 5.455474202747968, 5.45224577241401, 5.452230515181808, 5.445608876406109]
# Top 5 seeds: [553, 569, 178, 530, 706]
# Plot saved to: data_3669/loss_0.02/log_volume.png
# Test loss  [0.008813089431868386, 0.0028033899458348734]
# log_exp_r_n  [152407.3549836747, 124022.9106084934]
# Plot saved to: data_3669/loss_0.02/gen_log_volume.png
# Plot saved to: data_3669/loss_0.02/test_vs_data.png
# Plot saved to: data_3669/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_3669/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_3669/acc_0.85/avg_radius.png
# Plot saved to: data_3669/acc_0.85/radius_hist.png
# Plot saved to: data_3669/acc_0.85/log_volume.png
# Plot saved to: data_3669/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_3669/loss_0.02\results.json
# Successfully analyzed data_3669 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_5551
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_5551
# The number of model parameters is  73097
# The loss landscape is for data trained with 5551
# data_5551: 0.002528624376282096
#
# Top perturbations for data_5551:
# Top 5 r_vals: [12.27683548800326, 12.274816956182924, 12.267552987931518, 12.252619971913742, 12.244703756985697]
# Top 5 seeds: [553, 569, 178, 706, 94]
# Plot saved to: data_5551/loss_0.1/log_volume.png
# Test loss  [0.0028033899458348734]
# log_exp_r_n  [183299.47662325835]
# Plot saved to: data_5551/loss_0.1/gen_log_volume.png
# Plot saved to: data_5551/loss_0.1/test_vs_data.png
# Plot saved to: data_5551/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_5551/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_5551/acc_0.95/avg_radius.png
# Plot saved to: data_5551/acc_0.95/radius_hist.png
# Plot saved to: data_5551/acc_0.95/log_volume.png
# Plot saved to: data_5551/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_5551/loss_0.1\results.json
# Successfully analyzed data_5551 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 1 models from data_5551
# The number of model parameters is  73097
# The loss landscape is for data trained with 5551
# data_5551: 0.002528624376282096
#
# Top perturbations for data_5551:
# Top 5 r_vals: [9.019715868737087, 9.018232865767045, 9.012896072766013, 9.001924877324381, 8.993325477789256]
# Top 5 seeds: [553, 569, 178, 706, 903]
# Plot saved to: data_5551/loss_0.05/log_volume.png
# Test loss  [0.0028033899458348734]
# log_exp_r_n  [160763.57213659212]
# Plot saved to: data_5551/loss_0.05/gen_log_volume.png
# Plot saved to: data_5551/loss_0.05/test_vs_data.png
# Plot saved to: data_5551/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_5551/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_5551/acc_0.9/avg_radius.png
# Plot saved to: data_5551/acc_0.9/radius_hist.png
# Plot saved to: data_5551/acc_0.9/log_volume.png
# Plot saved to: data_5551/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_5551/loss_0.05\results.json
# Successfully analyzed data_5551 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 1 models from data_5551
# The number of model parameters is  73097
# The loss landscape is for data trained with 5551
# data_5551: 0.002528624376282096
#
# Top perturbations for data_5551:
# Top 5 r_vals: [5.45637132800145, 5.455474202747968, 5.45224577241401, 5.452230515181808, 5.445608876406109]
# Top 5 seeds: [553, 569, 178, 530, 706]
# Plot saved to: data_5551/loss_0.02/log_volume.png
# Test loss  [0.0028033899458348734]
# log_exp_r_n  [124022.9106084934]
# Plot saved to: data_5551/loss_0.02/gen_log_volume.png
# Plot saved to: data_5551/loss_0.02/test_vs_data.png
# Plot saved to: data_5551/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_5551/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_5551/acc_0.85/avg_radius.png
# Plot saved to: data_5551/acc_0.85/radius_hist.png
# Plot saved to: data_5551/acc_0.85/log_volume.png
# Plot saved to: data_5551/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_5551/loss_0.02\results.json
# Successfully analyzed data_5551 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_846
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from data_846
# The number of model parameters is  73097
# The loss landscape is for data trained with 846
# data_1787: 0.004621617030352354
# data_3669: 0.005883569363504648
# data_5551: 0.0025069669354707003
# data_846: 0.001534287934191525
#
# Top perturbations for data_1787:
# Top 5 r_vals: [15.978436710858588, 15.937148473370065, 15.929457931588615, 15.9281325327135, 15.928051825068872]
# Top 5 seeds: [264, 815, 590, 414, 346]
#
# Top perturbations for data_3669:
# Top 5 r_vals: [18.704014527774593, 18.674043208381963, 18.66573526557399, 18.6590207133679, 18.648734187778196]
# Top 5 seeds: [815, 30, 443, 313, 826]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [12.27683548800326, 12.274816956182924, 12.267552987931518, 12.252619971913742, 12.244703756985697]
# Top 5 seeds: [553, 569, 178, 706, 94]
#
# Top perturbations for data_846:
# Top 5 r_vals: [13.426325291763119, 13.417421694155093, 13.41389823254244, 13.408593448591823, 13.408335744598766]
# Top 5 seeds: [264, 375, 525, 343, 395]
# Plot saved to: data_846/loss_0.1/log_volume.png
# Test loss  [0.015517971763075133, 0.008813089431868386, 0.0028033899458348734, 0.02233411459287278]
# log_exp_r_n  [202562.43039701306, 214075.06709414313, 183299.47662325835, 189841.88914939112]
# Plot saved to: data_846/loss_0.1/gen_log_volume.png
# Plot saved to: data_846/loss_0.1/test_vs_data.png
# Plot saved to: data_846/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_846/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_846/acc_0.95/avg_radius.png
# Plot saved to: data_846/acc_0.95/radius_hist.png
# Plot saved to: data_846/acc_0.95/log_volume.png
# Plot saved to: data_846/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1, 4]
# test_loss ranks: [2, 3, 4, 1]
# log_exp_r_n ranks: [2, 1, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_846/loss_0.1\results.json
# Successfully analyzed data_846 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from data_846
# The number of model parameters is  73097
# The loss landscape is for data trained with 846
# data_1787: 0.004621617030352354
# data_3669: 0.005883569363504648
# data_5551: 0.0025069669354707003
# data_846: 0.001534287934191525
#
# Top perturbations for data_1787:
# Top 5 r_vals: [11.135451689798876, 11.133620821934628, 11.127032188600019, 11.127001051391442, 11.113487502869608]
# Top 5 seeds: [553, 569, 178, 530, 706]
#
# Top perturbations for data_3669:
# Top 5 r_vals: [13.471681194540896, 13.463708948206019, 13.434473861882717, 13.426325291763119, 13.422177915219908]
# Top 5 seeds: [569, 178, 903, 264, 195]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [9.019715868737087, 9.018232865767045, 9.012896072766013, 9.001924877324381, 8.996108882683368]
# Top 5 seeds: [553, 569, 178, 706, 94]
#
# Top perturbations for data_846:
# Top 5 r_vals: [10.014263285798526, 9.994653053155252, 9.989870206663385, 9.988386456400338, 9.987728885261033]
# Top 5 seeds: [264, 169, 871, 815, 156]
# Plot saved to: data_846/loss_0.05/log_volume.png
# Test loss  [0.015517971763075133, 0.008813089431868386, 0.0028033899458348734, 0.02233411459287278]
# log_exp_r_n  [176166.64736267243, 190088.40433774027, 160763.57213659212, 168409.3408433841]
# Plot saved to: data_846/loss_0.05/gen_log_volume.png
# Plot saved to: data_846/loss_0.05/test_vs_data.png
# Plot saved to: data_846/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_846/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_846/acc_0.9/avg_radius.png
# Plot saved to: data_846/acc_0.9/radius_hist.png
# Plot saved to: data_846/acc_0.9/log_volume.png
# Plot saved to: data_846/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1, 4]
# test_loss ranks: [2, 3, 4, 1]
# log_exp_r_n ranks: [2, 1, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_846/loss_0.05\results.json
# Successfully analyzed data_846 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from data_846
# The number of model parameters is  73097
# The loss landscape is for data trained with 846
# data_1787: 0.004621617030352354
# data_3669: 0.005883569363504648
# data_5551: 0.0025069669354707003
# data_846: 0.001534287934191525
#
# Top perturbations for data_1787:
# Top 5 r_vals: [7.105837414549536, 7.101527427048262, 7.099759431435569, 7.099333773339456, 7.097288382563004]
# Top 5 seeds: [903, 264, 424, 195, 182]
#
# Top perturbations for data_3669:
# Top 5 r_vals: [8.045363845879688, 8.044041043847768, 8.039280756263514, 8.029494720823292, 8.024306997208315]
# Top 5 seeds: [553, 569, 178, 706, 94]
#
# Top perturbations for data_5551:
# Top 5 r_vals: [5.45637132800145, 5.455474202747968, 5.45224577241401, 5.452230515181808, 5.445608876406109]
# Top 5 seeds: [553, 569, 178, 530, 706]
#
# Top perturbations for data_846:
# Top 5 r_vals: [6.263691575511866, 6.262661712338226, 6.258955606087509, 6.251336720364153, 6.247297835196783]
# Top 5 seeds: [553, 569, 178, 706, 94]
# Plot saved to: data_846/loss_0.02/log_volume.png
# Test loss  [0.015517971763075133, 0.008813089431868386, 0.0028033899458348734, 0.02233411459287278]
# log_exp_r_n  [143330.2142204563, 152407.3549836747, 124022.9106084934, 134109.25446265674]
# Plot saved to: data_846/loss_0.02/gen_log_volume.png
# Plot saved to: data_846/loss_0.02/test_vs_data.png
# Plot saved to: data_846/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_846/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_846/acc_0.85/avg_radius.png
# Plot saved to: data_846/acc_0.85/radius_hist.png
# Plot saved to: data_846/acc_0.85/log_volume.png
# Plot saved to: data_846/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1, 4]
# test_loss ranks: [2, 3, 4, 1]
# log_exp_r_n ranks: [2, 1, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_846/loss_0.02\results.json
# Successfully analyzed data_846 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
