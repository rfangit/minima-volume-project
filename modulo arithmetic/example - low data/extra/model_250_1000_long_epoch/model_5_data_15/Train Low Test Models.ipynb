# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 15            
model_seed = 5           

# --- Training configuration ---
epochs = 5000            

# --- Dataset configuration ---
base_data_size = (int)(0.01*9409)
dataset_type = "data"   
dataset_quantities = [0, (int)(0.09*9409), (int)(0.19*9409), (int)(0.39*9409), (int)(0.59*9409)] # modulo arithmetic dataset size

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %%
print (base_data_size)
print (dataset_quantities)
# Out:
# 94
# [0, 846, 1787, 3669, 5551]

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import modulo_arithmetic_model_data as model_module
modulus = 97
# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    modulus = modulus,
    device = device,
)

# MNIST specific initialization parameters
hidden_dims = [250]

# Grab model
model_template = model_module.get_model(N = modulus, hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/5000: Train Loss 0.0128 | Test Loss 0.0121 | accs Train 0.0213 Test 0.0102
# Epoch 100/5000: Train Loss 0.0003 | Test Loss 0.0149 | accs Train 1.0000 Test 0.0111
# Epoch 200/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0115
# Epoch 300/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 400/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 500/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 600/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 700/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 800/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 900/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 1000/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 1100/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 1200/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 1300/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 1400/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 1500/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 1600/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 1700/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 1800/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 1900/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 2000/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0113
# Epoch 2100/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 2200/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 2300/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 2400/5000: Train Loss 0.0000 | Test Loss 0.0155 | accs Train 1.0000 Test 0.0114
# Epoch 2500/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0114
# Epoch 2600/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0115
# Epoch 2700/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0114
# Epoch 2800/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0114
# Epoch 2900/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0114
# Epoch 3000/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0114
# Epoch 3100/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0115
# Epoch 3200/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0115
# Epoch 3300/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0114
# Epoch 3400/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0115
# Epoch 3500/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0115
# Epoch 3600/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0115
# Epoch 3700/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0115
# Epoch 3800/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0114
# Epoch 3900/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0115
# Epoch 4000/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0114
# Epoch 4100/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0115
# Epoch 4200/5000: Train Loss 0.0000 | Test Loss 0.0154 | accs Train 1.0000 Test 0.0115
# Epoch 4300/5000: Train Loss 0.0000 | Test Loss 0.0153 | accs Train 1.0000 Test 0.0115
# Epoch 4400/5000: Train Loss 0.0000 | Test Loss 0.0153 | accs Train 1.0000 Test 0.0115
# Epoch 4500/5000: Train Loss 0.0000 | Test Loss 0.0153 | accs Train 1.0000 Test 0.0115
# Epoch 4600/5000: Train Loss 0.0000 | Test Loss 0.0153 | accs Train 1.0000 Test 0.0115
# Epoch 4700/5000: Train Loss 0.0000 | Test Loss 0.0153 | accs Train 1.0000 Test 0.0115
# Epoch 4800/5000: Train Loss 0.0000 | Test Loss 0.0153 | accs Train 1.0000 Test 0.0115
# Epoch 4900/5000: Train Loss 0.0000 | Test Loss 0.0153 | accs Train 1.0000 Test 0.0116
# Epoch 5000/5000: Train Loss 0.0000 | Test Loss 0.0153 | accs Train 1.0000 Test 0.0116
# Completed training with 0 additional samples of data
# Epoch 1/5000: Train Loss 0.0128 | Test Loss 0.0121 | accs Train 0.0085 Test 0.0102
# Epoch 100/5000: Train Loss 0.0065 | Test Loss 0.0124 | accs Train 0.9989 Test 0.0999
# Epoch 200/5000: Train Loss 0.0039 | Test Loss 0.0151 | accs Train 1.0000 Test 0.1010
# Epoch 300/5000: Train Loss 0.0026 | Test Loss 0.0178 | accs Train 1.0000 Test 0.1019
# Epoch 400/5000: Train Loss 0.0020 | Test Loss 0.0200 | accs Train 1.0000 Test 0.1030
# Epoch 500/5000: Train Loss 0.0016 | Test Loss 0.0218 | accs Train 1.0000 Test 0.1028
# Epoch 600/5000: Train Loss 0.0014 | Test Loss 0.0233 | accs Train 1.0000 Test 0.1038
# Epoch 700/5000: Train Loss 0.0013 | Test Loss 0.0246 | accs Train 1.0000 Test 0.1048
# Epoch 800/5000: Train Loss 0.0011 | Test Loss 0.0258 | accs Train 1.0000 Test 0.1053
# Epoch 900/5000: Train Loss 0.0011 | Test Loss 0.0267 | accs Train 1.0000 Test 0.1051
# Epoch 1000/5000: Train Loss 0.0010 | Test Loss 0.0275 | accs Train 1.0000 Test 0.1053
# Epoch 1100/5000: Train Loss 0.0009 | Test Loss 0.0282 | accs Train 1.0000 Test 0.1051
# Epoch 1200/5000: Train Loss 0.0009 | Test Loss 0.0289 | accs Train 1.0000 Test 0.1052
# Epoch 1300/5000: Train Loss 0.0009 | Test Loss 0.0295 | accs Train 1.0000 Test 0.1056
# Epoch 1400/5000: Train Loss 0.0008 | Test Loss 0.0300 | accs Train 1.0000 Test 0.1063
# Epoch 1500/5000: Train Loss 0.0008 | Test Loss 0.0305 | accs Train 1.0000 Test 0.1060
# Epoch 1600/5000: Train Loss 0.0008 | Test Loss 0.0309 | accs Train 1.0000 Test 0.1064
# Epoch 1700/5000: Train Loss 0.0008 | Test Loss 0.0313 | accs Train 1.0000 Test 0.1061
# Epoch 1800/5000: Train Loss 0.0008 | Test Loss 0.0317 | accs Train 1.0000 Test 0.1063
# Epoch 1900/5000: Train Loss 0.0008 | Test Loss 0.0321 | accs Train 1.0000 Test 0.1061
# Epoch 2000/5000: Train Loss 0.0007 | Test Loss 0.0324 | accs Train 1.0000 Test 0.1060
# Epoch 2100/5000: Train Loss 0.0007 | Test Loss 0.0327 | accs Train 1.0000 Test 0.1060
# Epoch 2200/5000: Train Loss 0.0007 | Test Loss 0.0330 | accs Train 1.0000 Test 0.1062
# Epoch 2300/5000: Train Loss 0.0007 | Test Loss 0.0333 | accs Train 1.0000 Test 0.1059
# Epoch 2400/5000: Train Loss 0.0007 | Test Loss 0.0335 | accs Train 1.0000 Test 0.1061
# Epoch 2500/5000: Train Loss 0.0007 | Test Loss 0.0338 | accs Train 1.0000 Test 0.1059
# Epoch 2600/5000: Train Loss 0.0007 | Test Loss 0.0340 | accs Train 1.0000 Test 0.1059
# Epoch 2700/5000: Train Loss 0.0007 | Test Loss 0.0342 | accs Train 1.0000 Test 0.1064
# Epoch 2800/5000: Train Loss 0.0007 | Test Loss 0.0344 | accs Train 1.0000 Test 0.1062
# Epoch 2900/5000: Train Loss 0.0007 | Test Loss 0.0346 | accs Train 1.0000 Test 0.1061
# Epoch 3000/5000: Train Loss 0.0007 | Test Loss 0.0348 | accs Train 1.0000 Test 0.1060
# Epoch 3100/5000: Train Loss 0.0007 | Test Loss 0.0350 | accs Train 1.0000 Test 0.1062
# Epoch 3200/5000: Train Loss 0.0007 | Test Loss 0.0352 | accs Train 1.0000 Test 0.1063
# Epoch 3300/5000: Train Loss 0.0006 | Test Loss 0.0354 | accs Train 1.0000 Test 0.1065
# Epoch 3400/5000: Train Loss 0.0006 | Test Loss 0.0355 | accs Train 1.0000 Test 0.1065
# Epoch 3500/5000: Train Loss 0.0006 | Test Loss 0.0357 | accs Train 1.0000 Test 0.1062
# Epoch 3600/5000: Train Loss 0.0006 | Test Loss 0.0359 | accs Train 1.0000 Test 0.1061
# Epoch 3700/5000: Train Loss 0.0006 | Test Loss 0.0360 | accs Train 1.0000 Test 0.1061
# Epoch 3800/5000: Train Loss 0.0006 | Test Loss 0.0362 | accs Train 1.0000 Test 0.1061
# Epoch 3900/5000: Train Loss 0.0006 | Test Loss 0.0363 | accs Train 1.0000 Test 0.1060
# Epoch 4000/5000: Train Loss 0.0006 | Test Loss 0.0365 | accs Train 1.0000 Test 0.1062
# Epoch 4100/5000: Train Loss 0.0006 | Test Loss 0.0366 | accs Train 1.0000 Test 0.1061
# Epoch 4200/5000: Train Loss 0.0006 | Test Loss 0.0367 | accs Train 1.0000 Test 0.1063
# Epoch 4300/5000: Train Loss 0.0006 | Test Loss 0.0369 | accs Train 1.0000 Test 0.1062
# Epoch 4400/5000: Train Loss 0.0006 | Test Loss 0.0370 | accs Train 1.0000 Test 0.1061
# Epoch 4500/5000: Train Loss 0.0006 | Test Loss 0.0371 | accs Train 1.0000 Test 0.1061
# Epoch 4600/5000: Train Loss 0.0006 | Test Loss 0.0372 | accs Train 1.0000 Test 0.1060
# Epoch 4700/5000: Train Loss 0.0006 | Test Loss 0.0374 | accs Train 1.0000 Test 0.1060
# Epoch 4800/5000: Train Loss 0.0006 | Test Loss 0.0375 | accs Train 1.0000 Test 0.1061
# Epoch 4900/5000: Train Loss 0.0006 | Test Loss 0.0376 | accs Train 1.0000 Test 0.1064
# Epoch 5000/5000: Train Loss 0.0006 | Test Loss 0.0377 | accs Train 1.0000 Test 0.1064
# Completed training with 846 additional samples of data
# Epoch 1/5000: Train Loss 0.0128 | Test Loss 0.0121 | accs Train 0.0069 Test 0.0102
# Epoch 100/5000: Train Loss 0.0082 | Test Loss 0.0111 | accs Train 0.9628 Test 0.1930
# Epoch 200/5000: Train Loss 0.0065 | Test Loss 0.0124 | accs Train 0.9989 Test 0.2007
# Epoch 300/5000: Train Loss 0.0056 | Test Loss 0.0136 | accs Train 0.9995 Test 0.2033
# Epoch 400/5000: Train Loss 0.0051 | Test Loss 0.0145 | accs Train 1.0000 Test 0.2031
# Epoch 500/5000: Train Loss 0.0048 | Test Loss 0.0152 | accs Train 1.0000 Test 0.2035
# Epoch 600/5000: Train Loss 0.0046 | Test Loss 0.0157 | accs Train 0.9995 Test 0.2035
# Epoch 700/5000: Train Loss 0.0045 | Test Loss 0.0161 | accs Train 0.9995 Test 0.2041
# Epoch 800/5000: Train Loss 0.0044 | Test Loss 0.0164 | accs Train 1.0000 Test 0.2037
# Epoch 900/5000: Train Loss 0.0043 | Test Loss 0.0167 | accs Train 1.0000 Test 0.2034
# Epoch 1000/5000: Train Loss 0.0042 | Test Loss 0.0169 | accs Train 1.0000 Test 0.2036
# Epoch 1100/5000: Train Loss 0.0042 | Test Loss 0.0171 | accs Train 1.0000 Test 0.2031
# Epoch 1200/5000: Train Loss 0.0041 | Test Loss 0.0172 | accs Train 1.0000 Test 0.2030
# Epoch 1300/5000: Train Loss 0.0041 | Test Loss 0.0174 | accs Train 1.0000 Test 0.2028
# Epoch 1400/5000: Train Loss 0.0041 | Test Loss 0.0175 | accs Train 0.9995 Test 0.2027
# Epoch 1500/5000: Train Loss 0.0040 | Test Loss 0.0176 | accs Train 0.9995 Test 0.2028
# Epoch 1600/5000: Train Loss 0.0040 | Test Loss 0.0177 | accs Train 1.0000 Test 0.2032
# Epoch 1700/5000: Train Loss 0.0040 | Test Loss 0.0178 | accs Train 1.0000 Test 0.2032
# Epoch 1800/5000: Train Loss 0.0040 | Test Loss 0.0179 | accs Train 0.9995 Test 0.2031
# Epoch 1900/5000: Train Loss 0.0040 | Test Loss 0.0180 | accs Train 0.9995 Test 0.2034
# Epoch 2000/5000: Train Loss 0.0040 | Test Loss 0.0181 | accs Train 0.9995 Test 0.2032
# Epoch 2100/5000: Train Loss 0.0039 | Test Loss 0.0181 | accs Train 0.9995 Test 0.2033
# Epoch 2200/5000: Train Loss 0.0039 | Test Loss 0.0182 | accs Train 0.9995 Test 0.2033
# Epoch 2300/5000: Train Loss 0.0039 | Test Loss 0.0183 | accs Train 0.9995 Test 0.2030
# Epoch 2400/5000: Train Loss 0.0039 | Test Loss 0.0183 | accs Train 0.9995 Test 0.2031
# Epoch 2500/5000: Train Loss 0.0039 | Test Loss 0.0183 | accs Train 1.0000 Test 0.2030
# Epoch 2600/5000: Train Loss 0.0039 | Test Loss 0.0184 | accs Train 1.0000 Test 0.2029
# Epoch 2700/5000: Train Loss 0.0039 | Test Loss 0.0184 | accs Train 1.0000 Test 0.2031
# Epoch 2800/5000: Train Loss 0.0039 | Test Loss 0.0184 | accs Train 0.9995 Test 0.2031
# Epoch 2900/5000: Train Loss 0.0039 | Test Loss 0.0185 | accs Train 0.9995 Test 0.2031
# Epoch 3000/5000: Train Loss 0.0039 | Test Loss 0.0185 | accs Train 1.0000 Test 0.2029
# Epoch 3100/5000: Train Loss 0.0039 | Test Loss 0.0185 | accs Train 0.9995 Test 0.2027
# Epoch 3200/5000: Train Loss 0.0039 | Test Loss 0.0185 | accs Train 1.0000 Test 0.2028
# Epoch 3300/5000: Train Loss 0.0039 | Test Loss 0.0186 | accs Train 1.0000 Test 0.2028
# Epoch 3400/5000: Train Loss 0.0039 | Test Loss 0.0186 | accs Train 1.0000 Test 0.2030
# Epoch 3500/5000: Train Loss 0.0038 | Test Loss 0.0186 | accs Train 0.9995 Test 0.2030
# Epoch 3600/5000: Train Loss 0.0038 | Test Loss 0.0186 | accs Train 0.9995 Test 0.2030
# Epoch 3700/5000: Train Loss 0.0038 | Test Loss 0.0186 | accs Train 0.9995 Test 0.2029
# Epoch 3800/5000: Train Loss 0.0038 | Test Loss 0.0187 | accs Train 0.9995 Test 0.2031
# Epoch 3900/5000: Train Loss 0.0038 | Test Loss 0.0187 | accs Train 0.9995 Test 0.2028
# Epoch 4000/5000: Train Loss 0.0038 | Test Loss 0.0187 | accs Train 0.9995 Test 0.2029
# Epoch 4100/5000: Train Loss 0.0038 | Test Loss 0.0187 | accs Train 0.9995 Test 0.2030
# Epoch 4200/5000: Train Loss 0.0038 | Test Loss 0.0187 | accs Train 1.0000 Test 0.2031
# Epoch 4300/5000: Train Loss 0.0038 | Test Loss 0.0187 | accs Train 1.0000 Test 0.2031
# Epoch 4400/5000: Train Loss 0.0038 | Test Loss 0.0187 | accs Train 1.0000 Test 0.2033
# Epoch 4500/5000: Train Loss 0.0038 | Test Loss 0.0187 | accs Train 1.0000 Test 0.2030
# Epoch 4600/5000: Train Loss 0.0038 | Test Loss 0.0187 | accs Train 1.0000 Test 0.2033
# Epoch 4700/5000: Train Loss 0.0038 | Test Loss 0.0187 | accs Train 1.0000 Test 0.2032
# Epoch 4800/5000: Train Loss 0.0038 | Test Loss 0.0188 | accs Train 1.0000 Test 0.2031
# Epoch 4900/5000: Train Loss 0.0038 | Test Loss 0.0188 | accs Train 0.9995 Test 0.2031
# Epoch 5000/5000: Train Loss 0.0038 | Test Loss 0.0188 | accs Train 0.9995 Test 0.2031
# Completed training with 1787 additional samples of data
# Epoch 1/5000: Train Loss 0.0127 | Test Loss 0.0121 | accs Train 0.0090 Test 0.0099
# Epoch 100/5000: Train Loss 0.0092 | Test Loss 0.0104 | accs Train 0.7420 Test 0.2991
# Epoch 200/5000: Train Loss 0.0082 | Test Loss 0.0105 | accs Train 0.9150 Test 0.3675
# Epoch 300/5000: Train Loss 0.0075 | Test Loss 0.0105 | accs Train 0.9742 Test 0.3964
# Epoch 400/5000: Train Loss 0.0069 | Test Loss 0.0101 | accs Train 0.9947 Test 0.4421
# Epoch 500/5000: Train Loss 0.0063 | Test Loss 0.0095 | accs Train 1.0000 Test 0.5664
# Epoch 600/5000: Train Loss 0.0057 | Test Loss 0.0085 | accs Train 1.0000 Test 0.8208
# Epoch 700/5000: Train Loss 0.0050 | Test Loss 0.0075 | accs Train 1.0000 Test 0.9740
# Epoch 800/5000: Train Loss 0.0042 | Test Loss 0.0063 | accs Train 1.0000 Test 0.9984
# Epoch 900/5000: Train Loss 0.0035 | Test Loss 0.0051 | accs Train 1.0000 Test 0.9999
# Epoch 1000/5000: Train Loss 0.0029 | Test Loss 0.0042 | accs Train 1.0000 Test 1.0000
# Epoch 1100/5000: Train Loss 0.0024 | Test Loss 0.0035 | accs Train 1.0000 Test 1.0000
# Epoch 1200/5000: Train Loss 0.0021 | Test Loss 0.0030 | accs Train 1.0000 Test 1.0000
# Epoch 1300/5000: Train Loss 0.0018 | Test Loss 0.0026 | accs Train 1.0000 Test 1.0000
# Epoch 1400/5000: Train Loss 0.0016 | Test Loss 0.0023 | accs Train 1.0000 Test 1.0000
# Epoch 1500/5000: Train Loss 0.0014 | Test Loss 0.0020 | accs Train 1.0000 Test 1.0000
# Epoch 1600/5000: Train Loss 0.0013 | Test Loss 0.0018 | accs Train 1.0000 Test 1.0000
# Epoch 1700/5000: Train Loss 0.0012 | Test Loss 0.0017 | accs Train 1.0000 Test 1.0000
# Epoch 1800/5000: Train Loss 0.0011 | Test Loss 0.0016 | accs Train 1.0000 Test 1.0000
# Epoch 1900/5000: Train Loss 0.0010 | Test Loss 0.0016 | accs Train 1.0000 Test 1.0000
# Epoch 2000/5000: Train Loss 0.0010 | Test Loss 0.0015 | accs Train 1.0000 Test 1.0000
# Epoch 2100/5000: Train Loss 0.0010 | Test Loss 0.0015 | accs Train 1.0000 Test 1.0000
# Epoch 2200/5000: Train Loss 0.0009 | Test Loss 0.0014 | accs Train 1.0000 Test 1.0000
# Epoch 2300/5000: Train Loss 0.0009 | Test Loss 0.0014 | accs Train 1.0000 Test 1.0000
# Epoch 2400/5000: Train Loss 0.0009 | Test Loss 0.0013 | accs Train 1.0000 Test 1.0000
# Epoch 2500/5000: Train Loss 0.0009 | Test Loss 0.0013 | accs Train 1.0000 Test 1.0000
# Epoch 2600/5000: Train Loss 0.0009 | Test Loss 0.0013 | accs Train 1.0000 Test 1.0000
# Epoch 2700/5000: Train Loss 0.0008 | Test Loss 0.0013 | accs Train 1.0000 Test 1.0000
# Epoch 2800/5000: Train Loss 0.0008 | Test Loss 0.0013 | accs Train 1.0000 Test 1.0000
# Epoch 2900/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 3000/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 3100/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 3200/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 3300/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 3400/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 3500/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 3600/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 3700/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 3800/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 3900/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 4000/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 4100/5000: Train Loss 0.0007 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 4200/5000: Train Loss 0.0008 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 4300/5000: Train Loss 0.0007 | Test Loss 0.0011 | accs Train 1.0000 Test 1.0000
# Epoch 4400/5000: Train Loss 0.0007 | Test Loss 0.0011 | accs Train 1.0000 Test 1.0000
# Epoch 4500/5000: Train Loss 0.0007 | Test Loss 0.0011 | accs Train 1.0000 Test 1.0000
# Epoch 4600/5000: Train Loss 0.0007 | Test Loss 0.0011 | accs Train 1.0000 Test 1.0000
# Epoch 4700/5000: Train Loss 0.0007 | Test Loss 0.0011 | accs Train 1.0000 Test 1.0000
# Epoch 4800/5000: Train Loss 0.0007 | Test Loss 0.0011 | accs Train 1.0000 Test 1.0000
# Epoch 4900/5000: Train Loss 0.0007 | Test Loss 0.0011 | accs Train 1.0000 Test 1.0000
# Epoch 5000/5000: Train Loss 0.0007 | Test Loss 0.0011 | accs Train 1.0000 Test 1.0000
# Completed training with 3669 additional samples of data
# Epoch 1/5000: Train Loss 0.0127 | Test Loss 0.0121 | accs Train 0.0097 Test 0.0103
# Epoch 100/5000: Train Loss 0.0096 | Test Loss 0.0101 | accs Train 0.4925 Test 0.2982
# Epoch 200/5000: Train Loss 0.0087 | Test Loss 0.0096 | accs Train 0.8094 Test 0.4963
# Epoch 300/5000: Train Loss 0.0070 | Test Loss 0.0080 | accs Train 0.9975 Test 0.8906
# Epoch 400/5000: Train Loss 0.0049 | Test Loss 0.0055 | accs Train 1.0000 Test 1.0000
# Epoch 500/5000: Train Loss 0.0030 | Test Loss 0.0033 | accs Train 1.0000 Test 1.0000
# Epoch 600/5000: Train Loss 0.0019 | Test Loss 0.0022 | accs Train 1.0000 Test 1.0000
# Epoch 700/5000: Train Loss 0.0014 | Test Loss 0.0016 | accs Train 1.0000 Test 1.0000
# Epoch 800/5000: Train Loss 0.0012 | Test Loss 0.0013 | accs Train 1.0000 Test 1.0000
# Epoch 900/5000: Train Loss 0.0011 | Test Loss 0.0012 | accs Train 1.0000 Test 1.0000
# Epoch 1000/5000: Train Loss 0.0010 | Test Loss 0.0011 | accs Train 1.0000 Test 1.0000
# Epoch 1100/5000: Train Loss 0.0009 | Test Loss 0.0010 | accs Train 1.0000 Test 1.0000
# Epoch 1200/5000: Train Loss 0.0008 | Test Loss 0.0009 | accs Train 1.0000 Test 1.0000
# Epoch 1300/5000: Train Loss 0.0008 | Test Loss 0.0009 | accs Train 1.0000 Test 1.0000
# Epoch 1400/5000: Train Loss 0.0007 | Test Loss 0.0008 | accs Train 1.0000 Test 1.0000
# Epoch 1500/5000: Train Loss 0.0007 | Test Loss 0.0008 | accs Train 1.0000 Test 1.0000
# Epoch 1600/5000: Train Loss 0.0007 | Test Loss 0.0008 | accs Train 1.0000 Test 1.0000
# Epoch 1700/5000: Train Loss 0.0006 | Test Loss 0.0007 | accs Train 1.0000 Test 1.0000
# Epoch 1800/5000: Train Loss 0.0006 | Test Loss 0.0007 | accs Train 1.0000 Test 1.0000
# Epoch 1900/5000: Train Loss 0.0006 | Test Loss 0.0007 | accs Train 1.0000 Test 1.0000
# Epoch 2000/5000: Train Loss 0.0006 | Test Loss 0.0007 | accs Train 1.0000 Test 1.0000
# Epoch 2100/5000: Train Loss 0.0006 | Test Loss 0.0007 | accs Train 1.0000 Test 1.0000
# Epoch 2200/5000: Train Loss 0.0006 | Test Loss 0.0007 | accs Train 1.0000 Test 1.0000
# Epoch 2300/5000: Train Loss 0.0006 | Test Loss 0.0007 | accs Train 1.0000 Test 1.0000
# Epoch 2400/5000: Train Loss 0.0006 | Test Loss 0.0007 | accs Train 1.0000 Test 1.0000
# Epoch 2500/5000: Train Loss 0.0006 | Test Loss 0.0007 | accs Train 1.0000 Test 1.0000
# Epoch 2600/5000: Train Loss 0.0006 | Test Loss 0.0007 | accs Train 1.0000 Test 1.0000
# Epoch 2700/5000: Train Loss 0.0006 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 2800/5000: Train Loss 0.0006 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 2900/5000: Train Loss 0.0006 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 3000/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 3100/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 3200/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 3300/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 3400/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 3500/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 3600/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 3700/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 3800/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 3900/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 4000/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 4100/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 4200/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 4300/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 4400/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 4500/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 4600/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 4700/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 4800/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 4900/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Epoch 5000/5000: Train Loss 0.0005 | Test Loss 0.0006 | accs Train 1.0000 Test 1.0000
# Completed training with 5551 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 0.0153 | accs: 0.0116
#  846 samples | Test Loss: 0.0377 | accs: 0.1064
# 1787 samples | Test Loss: 0.0188 | accs: 0.2031
# 3669 samples | Test Loss: 0.0011 | accs: 1.0000
# 5551 samples | Test Loss: 0.0006 | accs: 1.0000
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  846 | Train Loss: 0.0006 | accs: 1.0000
#  Model 1787 | Train Loss: 0.0037 | accs: 1.0000
#  Model 3669 | Train Loss: 0.0006 | accs: 1.0000
#  Model 5551 | Train Loss: 0.0005 | accs: 1.0000
#
# Dataset type: data, additional samples: 846
#  Model    0 | Train Loss: 0.0138 | accs: 0.1000
#  Model  846 | Train Loss: 0.0006 | accs: 1.0000
#  Model 1787 | Train Loss: 0.0038 | accs: 0.9989
#  Model 3669 | Train Loss: 0.0007 | accs: 1.0000
#  Model 5551 | Train Loss: 0.0005 | accs: 1.0000
#
# Dataset type: data, additional samples: 1787
#  Model    0 | Train Loss: 0.0147 | accs: 0.0505
#  Model  846 | Train Loss: 0.0212 | accs: 0.5024
#  Model 1787 | Train Loss: 0.0038 | accs: 0.9995
#  Model 3669 | Train Loss: 0.0007 | accs: 1.0000
#  Model 5551 | Train Loss: 0.0005 | accs: 1.0000
#
# Dataset type: data, additional samples: 3669
#  Model    0 | Train Loss: 0.0151 | accs: 0.0258
#  Model  846 | Train Loss: 0.0316 | accs: 0.2535
#  Model 1787 | Train Loss: 0.0132 | accs: 0.5012
#  Model 3669 | Train Loss: 0.0007 | accs: 1.0000
#  Model 5551 | Train Loss: 0.0005 | accs: 1.0000
#
# Dataset type: data, additional samples: 5551
#  Model    0 | Train Loss: 0.0152 | accs: 0.0179
#  Model  846 | Train Loss: 0.0350 | accs: 0.1715
#  Model 1787 | Train Loss: 0.0163 | accs: 0.3353
#  Model 3669 | Train Loss: 0.0009 | accs: 1.0000
#  Model 5551 | Train Loss: 0.0005 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_846.pt
# Saved model: models_and_data/model_additional_846.pt
# ✅ Model saved to models_and_data\model_additional_1787.pt
# Saved model: models_and_data/model_additional_1787.pt
# ✅ Model saved to models_and_data\model_additional_3669.pt
# Saved model: models_and_data/model_additional_3669.pt
# ✅ Model saved to models_and_data\model_additional_5551.pt
# Saved model: models_and_data/model_additional_5551.pt
