# %% [markdown]
# # Model Training
#
# Compared to our pre-refactored model training, our new code generates identical starting models but appears to train them very slightly differently. Thus far it seems like the widest models are sharper for the single case (both seeds = 1) but the effects are minor and imperceptible. The differences are
#
# ### True Generalization (Refactored Results)
#
# | # Samples | Test Loss | Accuracy |
# |-----------|-----------|----------|
# | 0         | 4.5057    | 0.6743   |
# | 10        | 3.8848    | 0.6937   |
# | 50        | 1.1306    | 0.8740   |
# | 100       | 0.2121    | 0.9775   |
# | 200       | 0.0199    | 0.9962   |
# | 350       | 0.0056    | 0.9985   |
# | 750       | 0.0026    | 0.9992   |
#
# ### True Generalization (Original Results)
#
# | # Samples | Test Loss | Accuracy |
# |-----------|-----------|----------|
# | 0         | 4.5061    | 0.6743   |
# | 10        | 3.8846    | 0.6937   |
# | 50        | 1.1292    | 0.8748   |
# | 100       | 0.2125    | 0.9775   |
# | 200       | 0.0199    | 0.9962   |
# | 350       | 0.0056    | 0.9985   |
# | 750       | 0.0010    | 0.9995   |

# %% [markdown]
# # Model Specific Code
#
# Correctly refactored.

# %% [markdown]
# # Random Perturbations
#
# No changes in the results before and after modifications when accounting for the same input models from the earlier code.

# %% [markdown]
# # Volume Estimation
#
# We take the two different models obtained from the training schemes above, and run them into our re-factored and original code. We find that the only differences in volume arise when the different models (from training) are implanted. For a given trained model, the refactored and original code predict the exact same volumes. So there is no question about how our volume codes work.
