# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

import json

# Importing our existing funcs
import os
import sys
from pathlib import Path
parent_dir = Path.cwd().parent.parent.parent
sys.path.append(str(parent_dir))
# Import modules

from volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.05, 0.02]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}"
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['data_0', 'data_540', 'data_5940', 'data_59940']
#
# ==================================================
# Analyzing directory: data_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from data_0
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_0: 2.104399936797563e-05
# data_540: 7.081590592861176e-05
# data_5940: 0.000103119840787258
# data_59940: 0.0003170289855916053
#
# Top perturbations for data_0:
# Top 5 r_vals: [57.137960439603596, 57.0900264133204, 53.869266086154525, 53.83712768554688, 53.83476087782119]
# Top 5 seeds: [1391, 1755, 941, 1313, 1177]
# Top perturbations for data_540:
# Top 5 r_vals: [50.57512945107643, 50.55819878073667, 47.65367055627694, 47.494445047260804, 47.47617714279295]
# Top 5 seeds: [1478, 892, 1363, 1204, 1447]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [33.521208424602726, 33.515750482950565, 33.47076298316978, 30.95473480302453, 30.95009925109783]
# Top 5 seeds: [1363, 1433, 1770, 1152, 392]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [26.13925303854319, 23.986193998360342, 23.941896038290896, 23.928747106481485, 21.828935887640615]
# Top 5 seeds: [1856, 969, 941, 1672, 495]
# Plot saved to: data_0/loss_0.1/log_volume.png
# Plot saved to: data_0/loss_0.1/gen_log_volume.png
# Plot saved to: data_0/loss_0.1/test_vs_data.png
# Plot saved to: data_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.95/avg_radius.png
# Plot saved to: data_0/acc_0.95/radius_hist.png
# Plot saved to: data_0/acc_0.95/log_volume.png
# Plot saved to: data_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 1]
# test_loss ranks: [1, 2, 3, 4]
# log_exp_r_n ranks: [1, 2, 3, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.1\results.json
# Successfully analyzed data_0 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from data_0
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_0: 2.104399936797563e-05
# data_540: 7.081590592861176e-05
# data_5940: 0.000103119840787258
# data_59940: 0.0003170289855916053
# Top perturbations for data_0:
# Top 5 r_vals: [53.82633124457466, 53.78117540147571, 50.653928808284874, 50.623708677685954, 50.62148313947557]
# Top 5 seeds: [1391, 1755, 941, 1313, 1177]
#
# Top perturbations for data_540:
# Top 5 r_vals: [47.46357363523872, 47.44768459793743, 44.628827784234396, 44.462600862137, 41.65554023044424]
# Top 5 seeds: [1478, 892, 1363, 1447, 1650]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [30.99224151682944, 30.89889994982177, 28.55779922807622, 28.527883594467404, 28.5194666838843]
# Top 5 seeds: [1363, 856, 1433, 1152, 1770]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [23.941896038290896, 23.91568709008488, 21.85518915966304, 21.822234911257464, 21.787087740867484]
# Top 5 seeds: [941, 1856, 969, 886, 670]
# Plot saved to: data_0/loss_0.05/log_volume.png
# Plot saved to: data_0/loss_0.05/gen_log_volume.png
# Plot saved to: data_0/loss_0.05/test_vs_data.png
# Plot saved to: data_0/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.9/avg_radius.png
# Plot saved to: data_0/acc_0.9/radius_hist.png
# Plot saved to: data_0/acc_0.9/log_volume.png
# Plot saved to: data_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 1]
# test_loss ranks: [1, 2, 3, 4]
# log_exp_r_n ranks: [1, 2, 3, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.05\results.json
# Successfully analyzed data_0 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from data_0
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_0: 2.104399936797563e-05
# data_540: 7.081590592861176e-05
# data_5940: 0.000103119840787258
# data_59940: 0.0003170289855916053
#
# Top perturbations for data_0:
# Top 5 r_vals: [50.57109606162637, 47.53752498511891, 47.50916410083614, 47.507075485386736, 47.499636663026855]
# Top 5 seeds: [1755, 941, 1313, 1177, 1391]
#
# Top perturbations for data_540:
# Top 5 r_vals: [44.45079736911014, 44.43591689713183, 41.54783036117468, 38.87666775871086, 38.81844371947061]
# Top 5 seeds: [1478, 892, 1447, 1363, 27]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [28.477419794536274, 28.476426193755742, 26.231833219844443, 26.200087537279963, 26.171517575982765]
# Top 5 seeds: [1874, 856, 1363, 1152, 186]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [21.85518915966304, 21.790946294891388, 19.786690940736282, 19.76153083071881, 19.75209750200873]
# Top 5 seeds: [969, 1856, 941, 670, 275]
# Plot saved to: data_0/loss_0.02/log_volume.png
# Plot saved to: data_0/loss_0.02/gen_log_volume.png
# Plot saved to: data_0/loss_0.02/test_vs_data.png
# Plot saved to: data_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 1]
# test_loss ranks: [1, 2, 3, 4]
# log_exp_r_n ranks: [1, 2, 3, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.02\results.json
# Successfully analyzed data_0 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_540
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 3 models from data_540
# The number of model parameters is  235146
# The loss landscape is for data trained with 540
# data_540: 9.006763866636902e-05
# data_5940: 0.0002520430716685951
# data_59940: 0.00162729702424258
#
# Top perturbations for data_540:
# Top 5 r_vals: [47.44768459793743, 44.48142423883724, 41.64070302050353, 41.564490144027275, 41.54783036117468]
# Top 5 seeds: [892, 1872, 27, 1777, 1447]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [26.2266331409851, 26.219787550950443, 26.21286289731577, 26.15506246422958, 26.15374144324599]
# Top 5 seeds: [749, 13, 199, 820, 1874]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [17.847681209586398, 16.063193076898244, 16.0576363555656, 16.056991703254134, 16.053666548295453]
# Top 5 seeds: [1672, 749, 1519, 926, 198]
# Plot saved to: data_540/loss_0.1/log_volume.png
# Plot saved to: data_540/loss_0.1/gen_log_volume.png
# Plot saved to: data_540/loss_0.1/test_vs_data.png
# Plot saved to: data_540/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_540/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_540/acc_0.95/avg_radius.png
# Plot saved to: data_540/acc_0.95/radius_hist.png
# Plot saved to: data_540/acc_0.95/log_volume.png
# Plot saved to: data_540/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [1, 2, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_540/loss_0.1\results.json
# Successfully analyzed data_540 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_540
# The number of model parameters is  235146
# The loss landscape is for data trained with 540
# data_540: 9.006763866636902e-05
# data_5940: 0.0002520430716685951
# data_59940: 0.00162729702424258
#
# Top perturbations for data_540:
# Top 5 r_vals: [41.522895678319856, 38.74826289249823, 36.120422867704036, 36.1131977680301, 36.09521106057917]
# Top 5 seeds: [892, 1872, 695, 1620, 27]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [23.93015166859568, 21.86379057688928, 21.858083761756415, 21.856289053532485, 21.856227261742067]
# Top 5 seeds: [820, 749, 13, 1269, 1519]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [14.31170743660664, 14.306497216358467, 14.300420425799588, 14.288673583810011, 14.28803287969659]
# Top 5 seeds: [1941, 938, 1761, 1214, 1672]
# Plot saved to: data_540/loss_0.05/log_volume.png
# Plot saved to: data_540/loss_0.05/gen_log_volume.png
# Plot saved to: data_540/loss_0.05/test_vs_data.png
# Plot saved to: data_540/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_540/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_540/acc_0.9/avg_radius.png
# Plot saved to: data_540/acc_0.9/radius_hist.png
# Plot saved to: data_540/acc_0.9/log_volume.png
# Plot saved to: data_540/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [1, 2, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_540/loss_0.05\results.json
# Successfully analyzed data_540 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_540
# The number of model parameters is  235146
# The loss landscape is for data trained with 540
# data_540: 9.006763866636902e-05
# data_5940: 0.0002520430716685951
# data_59940: 0.00162729702424258
#
# Top perturbations for data_540:
# Top 5 r_vals: [35.99309268667679, 33.41049198383776, 33.40974475310636, 30.96744073019893, 30.961246371767913]
# Top 5 seeds: [892, 1872, 1777, 695, 1620]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [19.776984850079078, 17.898204030096384, 17.8975700640749, 17.89289849885276, 17.8914293612817]
# Top 5 seeds: [820, 1433, 749, 13, 1269]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [11.144081444998637, 11.142332779365029, 11.138276379517835, 11.133548817139793, 11.133545314203829]
# Top 5 seeds: [978, 1941, 938, 1480, 1761]
# Plot saved to: data_540/loss_0.02/log_volume.png
# Plot saved to: data_540/loss_0.02/gen_log_volume.png
# Plot saved to: data_540/loss_0.02/test_vs_data.png
# Plot saved to: data_540/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_540/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_540/acc_0.85/avg_radius.png
# Plot saved to: data_540/acc_0.85/radius_hist.png
# Plot saved to: data_540/acc_0.85/log_volume.png
# Plot saved to: data_540/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [1, 2, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_540/loss_0.02\results.json
# Successfully analyzed data_540 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_5940
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_5940
# The number of model parameters is  235146
# The loss landscape is for data trained with 5940
# data_5940: 0.00031197749194689095
# data_59940: 0.0019297992112115026
#
# Top perturbations for data_5940:
# Top 5 r_vals: [23.99563410252701, 23.987401138117285, 23.98303524064429, 23.98118610146605, 23.979766468942902]
# Top 5 seeds: [749, 1269, 199, 695, 1461]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [14.34830046016311, 14.337417488888255, 14.327971602541956, 14.326808976538391, 14.322440130371746]
# Top 5 seeds: [675, 484, 749, 1237, 926]
# Plot saved to: data_5940/loss_0.1/log_volume.png
# Plot saved to: data_5940/loss_0.1/gen_log_volume.png
# Plot saved to: data_5940/loss_0.1/test_vs_data.png
# Plot saved to: data_5940/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.95/avg_radius.png
# Plot saved to: data_5940/acc_0.95/radius_hist.png
# Plot saved to: data_5940/acc_0.95/log_volume.png
# Plot saved to: data_5940/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_5940/loss_0.1\results.json
# Successfully analyzed data_5940 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_5940
# The number of model parameters is  235146
# The loss landscape is for data trained with 5940
# data_5940: 0.00031197749194689095
# data_59940: 0.0019297992112115026
#
# Top perturbations for data_5940:
# Top 5 r_vals: [19.831102564071912, 19.825926314518295, 19.82429846125396, 19.82069028152421, 19.81916206732732]
# Top 5 seeds: [749, 13, 1269, 199, 695]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.670849913274157, 11.171428866075528, 11.170822157566432, 11.168997828515984, 11.162518798155562]
# Top 5 seeds: [786, 419, 675, 1850, 788]
# Plot saved to: data_5940/loss_0.05/log_volume.png
# Plot saved to: data_5940/loss_0.05/gen_log_volume.png
# Plot saved to: data_5940/loss_0.05/test_vs_data.png
# Plot saved to: data_5940/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.9/avg_radius.png
# Plot saved to: data_5940/acc_0.9/radius_hist.png
# Plot saved to: data_5940/acc_0.9/log_volume.png
# Plot saved to: data_5940/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_5940/loss_0.05\results.json
# Successfully analyzed data_5940 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_5940
# The number of model parameters is  235146
# The loss landscape is for data trained with 5940
# data_5940: 0.00031197749194689095
# data_59940: 0.0019297992112115026
#
# Top perturbations for data_5940:
# Top 5 r_vals: [16.063193076898244, 16.059000314759814, 16.057681753615704, 16.0576363555656, 16.054759128034608]
# Top 5 seeds: [749, 13, 1269, 1519, 199]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [9.70111946485053, 8.390984348296731, 8.390528642794344, 8.389158368974229, 8.388854740712246]
# Top 5 seeds: [786, 419, 675, 1850, 1014]
# Plot saved to: data_5940/loss_0.02/log_volume.png
# Plot saved to: data_5940/loss_0.02/gen_log_volume.png
# Plot saved to: data_5940/loss_0.02/test_vs_data.png
# Plot saved to: data_5940/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.85/avg_radius.png
# Plot saved to: data_5940/acc_0.85/radius_hist.png
# Plot saved to: data_5940/acc_0.85/log_volume.png
# Plot saved to: data_5940/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_5940/loss_0.02\results.json
# Successfully analyzed data_5940 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_59940
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.0017158286646008492
#
# Top perturbations for data_59940:
# Top 5 r_vals: [14.34830046016311, 14.34068489989363, 14.337635256297592, 14.328479126586856, 14.327971602541956]
# Top 5 seeds: [675, 173, 788, 1433, 749]
# Plot saved to: data_59940/loss_0.1/log_volume.png
# Plot saved to: data_59940/loss_0.1/gen_log_volume.png
# Plot saved to: data_59940/loss_0.1/test_vs_data.png
# Plot saved to: data_59940/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_59940/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_59940/acc_0.95/avg_radius.png
# Plot saved to: data_59940/acc_0.95/radius_hist.png
# Plot saved to: data_59940/acc_0.95/log_volume.png
# Plot saved to: data_59940/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_59940/loss_0.1\results.json
# Successfully analyzed data_59940 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.0017158286646008492
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.65709493929191, 11.171428866075528, 11.170822157566432, 11.170201437313477, 11.168997828515984]
# Top 5 seeds: [1214, 419, 675, 384, 1850]
# Plot saved to: data_59940/loss_0.05/log_volume.png
# Plot saved to: data_59940/loss_0.05/gen_log_volume.png
# Plot saved to: data_59940/loss_0.05/test_vs_data.png
# Plot saved to: data_59940/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_59940/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_59940/acc_0.9/avg_radius.png
# Plot saved to: data_59940/acc_0.9/radius_hist.png
# Plot saved to: data_59940/acc_0.9/log_volume.png
# Plot saved to: data_59940/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_59940/loss_0.05\results.json
# Successfully analyzed data_59940 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.0017158286646008492
#
# Top perturbations for data_59940:
# Top 5 r_vals: [8.390984348296731, 8.390528642794344, 8.390062412915457, 8.386075252878973, 8.384412927611024]
# Top 5 seeds: [419, 675, 384, 173, 981]
# Plot saved to: data_59940/loss_0.02/log_volume.png
# Plot saved to: data_59940/loss_0.02/gen_log_volume.png
# Plot saved to: data_59940/loss_0.02/test_vs_data.png
# Plot saved to: data_59940/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_59940/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_59940/acc_0.85/avg_radius.png
# Plot saved to: data_59940/acc_0.85/radius_hist.png
# Plot saved to: data_59940/acc_0.85/log_volume.png
# Plot saved to: data_59940/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_59940/loss_0.02\results.json
# Successfully analyzed data_59940 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
