# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train_sam

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 12            
model_seed = 2           

# --- Training configuration ---
epochs = 700               

# --- Dataset configuration ---
base_data_size = 50      
dataset_type = "data"   
dataset_quantities = [0, 500-50, 2000 - 50, 5000 - 50, 20000 - 50, 50000 - 50]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the CIFAR-10 model module name
from minima_volume.models import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device=device
)

# CIFAR-10 MLP initialization parameters
# Since input dimension is higher, hidden layers can be larger
hidden_dims = [512, 256]  # adjust as desired

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train_sam(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# [SAM] Epoch 1/700: Train Loss 2.2808 | Test Loss 2.2658 | accs Train 0.0800 Test 0.1757
# [SAM] Epoch 100/700: Train Loss 0.0000 | Test Loss 9.9262 | accs Train 1.0000 Test 0.2097
# [SAM] Epoch 200/700: Train Loss 0.0000 | Test Loss 9.8860 | accs Train 1.0000 Test 0.2091
# [SAM] Epoch 300/700: Train Loss 0.0000 | Test Loss 9.8591 | accs Train 1.0000 Test 0.2095
# [SAM] Epoch 400/700: Train Loss 0.0000 | Test Loss 9.8374 | accs Train 1.0000 Test 0.2086
# [SAM] Epoch 500/700: Train Loss 0.0000 | Test Loss 9.8178 | accs Train 1.0000 Test 0.2085
# [SAM] Epoch 600/700: Train Loss 0.0000 | Test Loss 9.7992 | accs Train 1.0000 Test 0.2076
# [SAM] Epoch 700/700: Train Loss 0.0000 | Test Loss 9.7831 | accs Train 1.0000 Test 0.2075
# Completed training with 0 additional samples of data
# [SAM] Epoch 1/700: Train Loss 2.3039 | Test Loss 2.1710 | accs Train 0.1020 Test 0.2210
# [SAM] Epoch 100/700: Train Loss 0.0005 | Test Loss 4.3680 | accs Train 1.0000 Test 0.3382
# [SAM] Epoch 200/700: Train Loss 0.0002 | Test Loss 4.6070 | accs Train 1.0000 Test 0.3376
# [SAM] Epoch 300/700: Train Loss 0.0001 | Test Loss 4.7804 | accs Train 1.0000 Test 0.3366
# [SAM] Epoch 400/700: Train Loss 0.0001 | Test Loss 4.9165 | accs Train 1.0000 Test 0.3369
# [SAM] Epoch 500/700: Train Loss 0.0001 | Test Loss 5.0285 | accs Train 1.0000 Test 0.3369
# [SAM] Epoch 600/700: Train Loss 0.0000 | Test Loss 5.1239 | accs Train 1.0000 Test 0.3373
# [SAM] Epoch 700/700: Train Loss 0.0000 | Test Loss 5.2066 | accs Train 1.0000 Test 0.3373
# Completed training with 450 additional samples of data
# [SAM] Epoch 1/700: Train Loss 2.3078 | Test Loss 2.1391 | accs Train 0.1100 Test 0.2431
# [SAM] Epoch 100/700: Train Loss 0.0108 | Test Loss 3.2005 | accs Train 1.0000 Test 0.3806
# [SAM] Epoch 200/700: Train Loss 0.0020 | Test Loss 3.8127 | accs Train 1.0000 Test 0.3799
# [SAM] Epoch 300/700: Train Loss 0.0009 | Test Loss 4.1087 | accs Train 1.0000 Test 0.3787
# [SAM] Epoch 400/700: Train Loss 0.0005 | Test Loss 4.3232 | accs Train 1.0000 Test 0.3771
# [SAM] Epoch 500/700: Train Loss 0.0003 | Test Loss 4.4904 | accs Train 1.0000 Test 0.3762
# [SAM] Epoch 600/700: Train Loss 0.0002 | Test Loss 4.6274 | accs Train 1.0000 Test 0.3760
# [SAM] Epoch 700/700: Train Loss 0.0002 | Test Loss 4.7452 | accs Train 1.0000 Test 0.3759
# Completed training with 1950 additional samples of data
# [SAM] Epoch 1/700: Train Loss 2.3066 | Test Loss 2.1370 | accs Train 0.1144 Test 0.2418
# [SAM] Epoch 100/700: Train Loss 0.1670 | Test Loss 2.2028 | accs Train 0.9816 Test 0.4268
# [SAM] Epoch 200/700: Train Loss 0.0128 | Test Loss 3.0002 | accs Train 1.0000 Test 0.4286
# [SAM] Epoch 300/700: Train Loss 0.0037 | Test Loss 3.5076 | accs Train 1.0000 Test 0.4244
# [SAM] Epoch 400/700: Train Loss 0.0020 | Test Loss 3.7404 | accs Train 1.0000 Test 0.4221
# [SAM] Epoch 500/700: Train Loss 0.0013 | Test Loss 3.9213 | accs Train 1.0000 Test 0.4223
# [SAM] Epoch 600/700: Train Loss 0.0009 | Test Loss 4.0755 | accs Train 1.0000 Test 0.4220
# [SAM] Epoch 700/700: Train Loss 0.0006 | Test Loss 4.2163 | accs Train 1.0000 Test 0.4209
# Completed training with 4950 additional samples of data
# [SAM] Epoch 1/700: Train Loss 2.3072 | Test Loss 2.1285 | accs Train 0.1160 Test 0.2454
# [SAM] Epoch 100/700: Train Loss 0.8490 | Test Loss 1.4348 | accs Train 0.7344 Test 0.5132
# [SAM] Epoch 200/700: Train Loss 0.3328 | Test Loss 1.6894 | accs Train 0.9297 Test 0.5001
# [SAM] Epoch 300/700: Train Loss 0.1321 | Test Loss 2.0195 | accs Train 0.9812 Test 0.4982
# [SAM] Epoch 400/700: Train Loss 0.0440 | Test Loss 2.3647 | accs Train 0.9977 Test 0.4978
# [SAM] Epoch 500/700: Train Loss 0.0193 | Test Loss 2.6430 | accs Train 0.9995 Test 0.4981
# [SAM] Epoch 600/700: Train Loss 0.0103 | Test Loss 2.8478 | accs Train 0.9999 Test 0.4988
# [SAM] Epoch 700/700: Train Loss 0.5533 | Test Loss 3.2173 | accs Train 0.9381 Test 0.4780
# Completed training with 19950 additional samples of data
# [SAM] Epoch 1/700: Train Loss 2.3069 | Test Loss 2.1293 | accs Train 0.1178 Test 0.2414
# [SAM] Epoch 100/700: Train Loss 1.1159 | Test Loss 1.3260 | accs Train 0.6170 Test 0.5321
# [SAM] Epoch 200/700: Train Loss 0.7410 | Test Loss 1.3313 | accs Train 0.7613 Test 0.5478
# [SAM] Epoch 300/700: Train Loss 0.5237 | Test Loss 1.4027 | accs Train 0.8458 Test 0.5553
# [SAM] Epoch 400/700: Train Loss 0.3376 | Test Loss 1.5450 | accs Train 0.9158 Test 0.5477
# [SAM] Epoch 500/700: Train Loss 0.2388 | Test Loss 1.6897 | accs Train 0.9456 Test 0.5475
# [SAM] Epoch 600/700: Train Loss 0.1513 | Test Loss 1.8705 | accs Train 0.9732 Test 0.5375
# [SAM] Epoch 700/700: Train Loss 0.0961 | Test Loss 2.0211 | accs Train 0.9875 Test 0.5399
# Completed training with 49950 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 9.7831 | accs: 0.2075
#  450 samples | Test Loss: 5.2066 | accs: 0.3373
# 1950 samples | Test Loss: 4.7452 | accs: 0.3759
# 4950 samples | Test Loss: 4.2163 | accs: 0.4209
# 19950 samples | Test Loss: 3.2173 | accs: 0.4780
# 49950 samples | Test Loss: 2.0211 | accs: 0.5399
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  450 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1950 | Train Loss: 0.0001 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0005 | accs: 1.0000
#  Model 19950 | Train Loss: 0.4882 | accs: 0.8800
#  Model 49950 | Train Loss: 0.0623 | accs: 1.0000
#
# Dataset type: data, additional samples: 450
#  Model    0 | Train Loss: 8.6607 | accs: 0.2980
#  Model  450 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1950 | Train Loss: 0.0002 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 19950 | Train Loss: 0.3460 | accs: 0.9260
#  Model 49950 | Train Loss: 0.0740 | accs: 0.9960
#
# Dataset type: data, additional samples: 1950
#  Model    0 | Train Loss: 9.9042 | accs: 0.2235
#  Model  450 | Train Loss: 4.1180 | accs: 0.4970
#  Model 1950 | Train Loss: 0.0002 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 19950 | Train Loss: 0.3525 | accs: 0.9320
#  Model 49950 | Train Loss: 0.0895 | accs: 0.9905
#
# Dataset type: data, additional samples: 4950
#  Model    0 | Train Loss: 9.8455 | accs: 0.2140
#  Model  450 | Train Loss: 4.8544 | accs: 0.3968
#  Model 1950 | Train Loss: 2.7911 | accs: 0.6254
#  Model 4950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 19950 | Train Loss: 0.3455 | accs: 0.9338
#  Model 49950 | Train Loss: 0.0910 | accs: 0.9896
#
# Dataset type: data, additional samples: 19950
#  Model    0 | Train Loss: 9.7663 | accs: 0.2087
#  Model  450 | Train Loss: 5.1674 | accs: 0.3467
#  Model 1950 | Train Loss: 4.2400 | accs: 0.4375
#  Model 4950 | Train Loss: 3.1246 | accs: 0.5670
#  Model 19950 | Train Loss: 0.3096 | accs: 0.9398
#  Model 49950 | Train Loss: 0.0957 | accs: 0.9864
#
# Dataset type: data, additional samples: 49950
#  Model    0 | Train Loss: 9.8584 | accs: 0.2032
#  Model  450 | Train Loss: 5.2325 | accs: 0.3368
#  Model 1950 | Train Loss: 4.5788 | accs: 0.3973
#  Model 4950 | Train Loss: 3.7724 | accs: 0.4803
#  Model 19950 | Train Loss: 2.0796 | accs: 0.6601
#  Model 49950 | Train Loss: 0.0973 | accs: 0.9864

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_450.pt
# Saved model: models_and_data/model_additional_450.pt
# ✅ Model saved to models_and_data\model_additional_1950.pt
# Saved model: models_and_data/model_additional_1950.pt
# ✅ Model saved to models_and_data\model_additional_4950.pt
# Saved model: models_and_data/model_additional_4950.pt
# ✅ Model saved to models_and_data\model_additional_19950.pt
# Saved model: models_and_data/model_additional_19950.pt
# ✅ Model saved to models_and_data\model_additional_49950.pt
# Saved model: models_and_data/model_additional_49950.pt
