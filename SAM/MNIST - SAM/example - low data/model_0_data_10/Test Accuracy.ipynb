# %% [markdown]
# # Model Analysis
#
# This program takes in datasets and models, and computes the loss landscapes over varying amounts of data.

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

import time
import glob

# Importing our existing funcs
import os
import sys
from pathlib import Path

from minima_volume.dataset_funcs import ( load_models_and_data )

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Model

# %%
# User specifies the model module name
import MNIST_model_data as model_module

# Generate dataset
#x_base, y_base, x_test, y_test = model_module.get_dataset(
#    device = device
#)

# MNIST specific initialization parameters
hidden_dims = [256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=0)

# Grab loss and metrics
loss_fn_per_sample = model_module.get_loss_fn_per_sample()

# %% [markdown]
# ## Loading Model and Datasets

# %%
# Get the relative path
target_dir = Path("models_and_data") #current directory

# Lists to store loaded models and additional data
loaded_models, loaded_additional_data, loaded_dataset = load_models_and_data(model_template=model_template, target_dir=target_dir, device="cpu")

# Print dataset information
print(f"Dataset type: {loaded_dataset['dataset_type']}")
print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")

# Print tensor shapes
print("\nTensor shapes:")
for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
    if loaded_dataset[key] is not None:
        print(f"  {key}: {loaded_dataset[key].shape}")
    else:
        print(f"  {key}: None")
# Out:
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_sam_additional_0.pt
#   - model_sam_additional_1940.pt
#   - model_sam_additional_19940.pt
#   - model_sam_additional_540.pt
#   - model_sam_additional_5940.pt
#   - model_sam_additional_59940.pt
# ✅ Model loaded into provided instance from models_and_data\model_sam_additional_0.pt
# Successfully loaded: model_sam_additional_0.pt
# ✅ Model loaded into provided instance from models_and_data\model_sam_additional_1940.pt
# Successfully loaded: model_sam_additional_1940.pt
# ✅ Model loaded into provided instance from models_and_data\model_sam_additional_19940.pt
# Successfully loaded: model_sam_additional_19940.pt
# ✅ Model loaded into provided instance from models_and_data\model_sam_additional_540.pt
# Successfully loaded: model_sam_additional_540.pt
# ✅ Model loaded into provided instance from models_and_data\model_sam_additional_5940.pt
# Successfully loaded: model_sam_additional_5940.pt
# ✅ Model loaded into provided instance from models_and_data\model_sam_additional_59940.pt
# Successfully loaded: model_sam_additional_59940.pt
#
# Model data loaded from all models:
# Model 0 (model_sam_additional_0.pt):
#   - Additional data: 0
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 1 (model_sam_additional_1940.pt):
#   - Additional data: 1940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 2 (model_sam_additional_19940.pt):
#   - Additional data: 19940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 3 (model_sam_additional_540.pt):
#   - Additional data: 540
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 4 (model_sam_additional_5940.pt):
#   - Additional data: 5940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 5 (model_sam_additional_59940.pt):
#   - Additional data: 59940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
#
# Loading dataset...
# Using dataset file: dataset.pt
# ✅ Dataset loaded from models_and_data\dataset.pt
# Dataset type: data
# Dataset quantities: [0, 540, 1940, 5940, 19940, 59940]
#
# Tensor shapes:
#   x_base_train: torch.Size([60, 1, 28, 28])
#   y_base_train: torch.Size([60])
#   x_additional: torch.Size([59940, 1, 28, 28])
#   y_additional: torch.Size([59940])
#   x_test: torch.Size([10000, 1, 28, 28])
#   y_test: torch.Size([10000])

# %%
base_size = loaded_dataset['x_base_train'].shape[0]
print ("Base dataset size is ", base_size)

# Extract dataset sizes and final test accuracies
dataset_sizes = []
final_test_accuracies = []
for i, model_data in enumerate(loaded_additional_data):
    total_size = base_size + model_data['additional_data']
    final_test_accuracy = model_data['test_accs'][-1]
    dataset_sizes.append(total_size)
    final_test_accuracies.append(final_test_accuracy)

# Convert to numpy arrays for easier manipulation
dataset_sizes = np.array(dataset_sizes)
final_test_accuracies = np.array(final_test_accuracies)

sort_indices = np.argsort(dataset_sizes)
dataset_sizes = dataset_sizes[sort_indices]
final_test_accuracies = final_test_accuracies[sort_indices]

# Print the extracted data
print("\nExtracted data:")
for i, (size, acc) in enumerate(zip(dataset_sizes, final_test_accuracies)):
    print(f"Model {i}: Dataset size = {size}, Final test accuracy = {acc:.4f}")

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(dataset_sizes, final_test_accuracies, 'o-', markersize=8, linewidth=2)

# Customize the plot
plt.xlabel('Total Dataset Size', fontsize=12)
plt.ylabel('Final Test Accuracy', fontsize=12)
plt.title('Test Accuracy vs. Dataset Size', fontsize=14)
plt.grid(True, alpha=0.3)
plt.ylim((0.5, 1.0))
plt.tight_layout()
plt.show()

# Optional: Print summary statistics
print(f"\nSummary statistics:")
print(f"Number of models: {len(dataset_sizes)}")
print(f"Dataset sizes range: {dataset_sizes.min()} to {dataset_sizes.max()}")
print(f"Accuracy range: {final_test_accuracies.min():.4f} to {final_test_accuracies.max():.4f}")
print(f"Mean accuracy: {final_test_accuracies.mean():.4f}")

# Save the arrays to a file
np.savez("test_accuracies.npz", dataset_sizes=dataset_sizes, final_test_accuracies=final_test_accuracies)
print(f"\nSaved data!")
# Out:
# Base dataset size is  60
#
# Extracted data:
# Model 0: Dataset size = 60, Final test accuracy = 0.6314
# Model 1: Dataset size = 600, Final test accuracy = 0.8758
# Model 2: Dataset size = 2000, Final test accuracy = 0.9166
# Model 3: Dataset size = 6000, Final test accuracy = 0.9465
# Model 4: Dataset size = 20000, Final test accuracy = 0.9700
# Model 5: Dataset size = 60000, Final test accuracy = 0.9782
# Summary statistics:
# Number of models: 6
# Dataset sizes range: 60 to 60000
# Accuracy range: 0.6314 to 0.9782
# Mean accuracy: 0.8864
#
# Saved data!
