# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train_sam

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 10            
model_seed = 0           

# --- Training configuration ---
epochs = 500            

# --- Dataset configuration ---
base_data_size = 60      
dataset_type = "data"   
dataset_quantities = [0, 600-60, 2000 - 60, 6000 - 60, 20000 - 60, 60000 - 60]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

test_dataset_size = 2000

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    base_data_size=base_data_size,
    dataset_quantities=dataset_quantities,
    test_dataset_size=test_dataset_size,
    noise=0.3, # default swiss params
    extra_pts=1000,
    dataset_type=dataset_type,
    seed=data_seed
)

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train_sam(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# [SAM] Epoch 1/500: Train Loss 0.6913 | Test Loss 0.6930 | accs Train 0.5333 Test 0.5000
# [SAM] Epoch 100/500: Train Loss 0.5362 | Test Loss 0.6153 | accs Train 0.7500 Test 0.6462
# [SAM] Epoch 200/500: Train Loss 0.3187 | Test Loss 0.6029 | accs Train 0.8667 Test 0.7125
# [SAM] Epoch 300/500: Train Loss 0.1643 | Test Loss 0.6354 | accs Train 0.9167 Test 0.7582
# [SAM] Epoch 400/500: Train Loss 0.0503 | Test Loss 0.5802 | accs Train 1.0000 Test 0.8375
# [SAM] Epoch 500/500: Train Loss 0.0191 | Test Loss 0.6366 | accs Train 1.0000 Test 0.8622
# Completed training with 0 additional samples of data
# [SAM] Epoch 1/500: Train Loss 0.6971 | Test Loss 0.6928 | accs Train 0.4700 Test 0.5000
# [SAM] Epoch 100/500: Train Loss 0.5634 | Test Loss 0.5603 | accs Train 0.6483 Test 0.6675
# [SAM] Epoch 200/500: Train Loss 0.2719 | Test Loss 0.2832 | accs Train 0.9283 Test 0.8978
# [SAM] Epoch 300/500: Train Loss 0.0839 | Test Loss 0.0937 | accs Train 0.9900 Test 0.9828
# [SAM] Epoch 400/500: Train Loss 0.0240 | Test Loss 0.0301 | accs Train 0.9983 Test 0.9962
# [SAM] Epoch 500/500: Train Loss 0.0081 | Test Loss 0.0127 | accs Train 1.0000 Test 0.9988
# Completed training with 540 additional samples of data
# [SAM] Epoch 1/500: Train Loss 0.6954 | Test Loss 0.6927 | accs Train 0.4925 Test 0.5000
# [SAM] Epoch 100/500: Train Loss 0.5815 | Test Loss 0.5801 | accs Train 0.6145 Test 0.6075
# [SAM] Epoch 200/500: Train Loss 0.2803 | Test Loss 0.2817 | accs Train 0.9535 Test 0.9473
# [SAM] Epoch 300/500: Train Loss 0.0450 | Test Loss 0.0477 | accs Train 0.9990 Test 0.9980
# [SAM] Epoch 400/500: Train Loss 0.0133 | Test Loss 0.0154 | accs Train 0.9995 Test 0.9990
# [SAM] Epoch 500/500: Train Loss 0.0039 | Test Loss 0.0048 | accs Train 0.9995 Test 0.9995
# Completed training with 1940 additional samples of data
# [SAM] Epoch 1/500: Train Loss 0.6954 | Test Loss 0.6927 | accs Train 0.4917 Test 0.5000
# [SAM] Epoch 100/500: Train Loss 0.5898 | Test Loss 0.5896 | accs Train 0.6605 Test 0.6623
# [SAM] Epoch 200/500: Train Loss 0.3046 | Test Loss 0.3030 | accs Train 0.8788 Test 0.8820
# [SAM] Epoch 300/500: Train Loss 0.0352 | Test Loss 0.0365 | accs Train 0.9978 Test 0.9960
# [SAM] Epoch 400/500: Train Loss 0.0091 | Test Loss 0.0113 | accs Train 0.9995 Test 0.9982
# [SAM] Epoch 500/500: Train Loss 0.0067 | Test Loss 0.0084 | accs Train 0.9995 Test 0.9990
# Completed training with 5940 additional samples of data
# [SAM] Epoch 1/500: Train Loss 0.6949 | Test Loss 0.6927 | accs Train 0.4968 Test 0.5000
# [SAM] Epoch 100/500: Train Loss 0.5911 | Test Loss 0.5925 | accs Train 0.6653 Test 0.6607
# [SAM] Epoch 200/500: Train Loss 0.3240 | Test Loss 0.3198 | accs Train 0.9048 Test 0.9223
# [SAM] Epoch 300/500: Train Loss 0.0729 | Test Loss 0.0705 | accs Train 0.9930 Test 0.9942
# [SAM] Epoch 400/500: Train Loss 0.0225 | Test Loss 0.0223 | accs Train 0.9974 Test 0.9968
# [SAM] Epoch 500/500: Train Loss 0.0063 | Test Loss 0.0074 | accs Train 0.9997 Test 0.9990
# Completed training with 19940 additional samples of data
# [SAM] Epoch 1/500: Train Loss 0.6947 | Test Loss 0.6927 | accs Train 0.4993 Test 0.5000
# [SAM] Epoch 100/500: Train Loss 0.5902 | Test Loss 0.5918 | accs Train 0.6650 Test 0.6615
# [SAM] Epoch 200/500: Train Loss 0.3605 | Test Loss 0.3582 | accs Train 0.8219 Test 0.8287
# [SAM] Epoch 300/500: Train Loss 0.1050 | Test Loss 0.1004 | accs Train 0.9899 Test 0.9922
# [SAM] Epoch 400/500: Train Loss 0.0264 | Test Loss 0.0258 | accs Train 0.9963 Test 0.9960
# [SAM] Epoch 500/500: Train Loss 0.0108 | Test Loss 0.0120 | accs Train 0.9987 Test 0.9980
# Completed training with 59940 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 0.6366 | accs: 0.8622
#  540 samples | Test Loss: 0.0127 | accs: 0.9988
# 1940 samples | Test Loss: 0.0048 | accs: 0.9995
# 5940 samples | Test Loss: 0.0084 | accs: 0.9990
# 19940 samples | Test Loss: 0.0074 | accs: 0.9990
# 59940 samples | Test Loss: 0.0120 | accs: 0.9980
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0190 | accs: 1.0000
#  Model  540 | Train Loss: 0.0093 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0027 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0065 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0063 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0137 | accs: 1.0000
#
# Dataset type: data, additional samples: 540
#  Model    0 | Train Loss: 0.5984 | accs: 0.8600
#  Model  540 | Train Loss: 0.0080 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0035 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0075 | accs: 0.9983
#  Model 19940 | Train Loss: 0.0072 | accs: 0.9983
#  Model 59940 | Train Loss: 0.0114 | accs: 0.9983
#
# Dataset type: data, additional samples: 1940
#  Model    0 | Train Loss: 0.6362 | accs: 0.8570
#  Model  540 | Train Loss: 0.0100 | accs: 0.9995
#  Model 1940 | Train Loss: 0.0039 | accs: 0.9995
#  Model 5940 | Train Loss: 0.0071 | accs: 0.9990
#  Model 19940 | Train Loss: 0.0068 | accs: 0.9990
#  Model 59940 | Train Loss: 0.0106 | accs: 0.9990
#
# Dataset type: data, additional samples: 5940
#  Model    0 | Train Loss: 0.6797 | accs: 0.8563
#  Model  540 | Train Loss: 0.0097 | accs: 0.9997
#  Model 1940 | Train Loss: 0.0037 | accs: 0.9997
#  Model 5940 | Train Loss: 0.0066 | accs: 0.9995
#  Model 19940 | Train Loss: 0.0061 | accs: 0.9997
#  Model 59940 | Train Loss: 0.0096 | accs: 0.9995
#
# Dataset type: data, additional samples: 19940
#  Model    0 | Train Loss: 0.6759 | accs: 0.8610
#  Model  540 | Train Loss: 0.0102 | accs: 0.9993
#  Model 1940 | Train Loss: 0.0037 | accs: 0.9998
#  Model 5940 | Train Loss: 0.0069 | accs: 0.9994
#  Model 19940 | Train Loss: 0.0062 | accs: 0.9997
#  Model 59940 | Train Loss: 0.0103 | accs: 0.9990
#
# Dataset type: data, additional samples: 59940
#  Model    0 | Train Loss: 0.6859 | accs: 0.8606
#  Model  540 | Train Loss: 0.0104 | accs: 0.9992
#  Model 1940 | Train Loss: 0.0039 | accs: 0.9997
#  Model 5940 | Train Loss: 0.0072 | accs: 0.9994
#  Model 19940 | Train Loss: 0.0064 | accs: 0.9996
#  Model 59940 | Train Loss: 0.0107 | accs: 0.9987

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_540.pt
# Saved model: models_and_data/model_additional_540.pt
# ✅ Model saved to models_and_data\model_additional_1940.pt
# Saved model: models_and_data/model_additional_1940.pt
# ✅ Model saved to models_and_data\model_additional_5940.pt
# Saved model: models_and_data/model_additional_5940.pt
# ✅ Model saved to models_and_data\model_additional_19940.pt
# Saved model: models_and_data/model_additional_19940.pt
# ✅ Model saved to models_and_data\model_additional_59940.pt
# Saved model: models_and_data/model_additional_59940.pt
