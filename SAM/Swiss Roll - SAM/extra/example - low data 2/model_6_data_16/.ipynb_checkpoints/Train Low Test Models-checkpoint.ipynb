# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train_sam

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 16            
model_seed = 6           

# --- Training configuration ---
epochs = 1000            

# --- Dataset configuration ---
base_data_size = 20      
dataset_type = "data"   
dataset_quantities = [0, 30, 100, 300, 700]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

test_dataset_size = 2000

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    base_data_size=base_data_size,
    dataset_quantities=dataset_quantities,
    test_dataset_size=test_dataset_size,
    noise=0.3, # default swiss params
    extra_pts=1000,
    dataset_type=dataset_type,
    seed=data_seed
)

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train_sam(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# [SAM] Epoch 1/1000: Train Loss 0.7152 | Test Loss 0.6949 | accs Train 0.3500 Test 0.5000
# [SAM] Epoch 100/1000: Train Loss 0.3612 | Test Loss 1.1702 | accs Train 0.8500 Test 0.5700
# [SAM] Epoch 200/1000: Train Loss 0.2516 | Test Loss 2.0507 | accs Train 0.9000 Test 0.5797
# [SAM] Epoch 300/1000: Train Loss 0.1891 | Test Loss 2.3743 | accs Train 0.9500 Test 0.5985
# [SAM] Epoch 400/1000: Train Loss 0.1289 | Test Loss 2.6458 | accs Train 0.9500 Test 0.6005
# [SAM] Epoch 500/1000: Train Loss 0.0820 | Test Loss 2.8217 | accs Train 1.0000 Test 0.6025
# [SAM] Epoch 600/1000: Train Loss 0.0514 | Test Loss 2.9675 | accs Train 1.0000 Test 0.6028
# [SAM] Epoch 700/1000: Train Loss 0.0270 | Test Loss 3.2048 | accs Train 1.0000 Test 0.6075
# [SAM] Epoch 800/1000: Train Loss 0.0125 | Test Loss 3.3467 | accs Train 1.0000 Test 0.6075
# [SAM] Epoch 900/1000: Train Loss 0.0058 | Test Loss 3.3878 | accs Train 1.0000 Test 0.6182
# [SAM] Epoch 1000/1000: Train Loss 0.0028 | Test Loss 3.5135 | accs Train 1.0000 Test 0.6272
# Completed training with 0 additional samples of data
# [SAM] Epoch 1/1000: Train Loss 0.7010 | Test Loss 0.6947 | accs Train 0.4800 Test 0.5000
# [SAM] Epoch 100/1000: Train Loss 0.4345 | Test Loss 0.7961 | accs Train 0.7600 Test 0.5757
# [SAM] Epoch 200/1000: Train Loss 0.2868 | Test Loss 1.2939 | accs Train 0.8600 Test 0.5553
# [SAM] Epoch 300/1000: Train Loss 0.2168 | Test Loss 1.6149 | accs Train 0.9400 Test 0.5797
# [SAM] Epoch 400/1000: Train Loss 0.1077 | Test Loss 1.6663 | accs Train 0.9600 Test 0.6440
# [SAM] Epoch 500/1000: Train Loss 0.0470 | Test Loss 1.9681 | accs Train 1.0000 Test 0.6693
# [SAM] Epoch 600/1000: Train Loss 0.0230 | Test Loss 2.1394 | accs Train 1.0000 Test 0.6857
# [SAM] Epoch 700/1000: Train Loss 0.0119 | Test Loss 2.2347 | accs Train 1.0000 Test 0.6945
# [SAM] Epoch 800/1000: Train Loss 0.0059 | Test Loss 2.3994 | accs Train 1.0000 Test 0.6910
# [SAM] Epoch 900/1000: Train Loss 0.0030 | Test Loss 2.5600 | accs Train 1.0000 Test 0.6915
# [SAM] Epoch 1000/1000: Train Loss 0.0017 | Test Loss 2.5924 | accs Train 1.0000 Test 0.6940
# Completed training with 30 additional samples of data
# [SAM] Epoch 1/1000: Train Loss 0.6964 | Test Loss 0.6948 | accs Train 0.5250 Test 0.5000
# [SAM] Epoch 100/1000: Train Loss 0.4975 | Test Loss 0.6413 | accs Train 0.7000 Test 0.6082
# [SAM] Epoch 200/1000: Train Loss 0.2291 | Test Loss 0.5435 | accs Train 0.9417 Test 0.8095
# [SAM] Epoch 300/1000: Train Loss 0.0952 | Test Loss 0.5518 | accs Train 0.9833 Test 0.8480
# [SAM] Epoch 400/1000: Train Loss 0.0356 | Test Loss 0.6330 | accs Train 0.9917 Test 0.8698
# [SAM] Epoch 500/1000: Train Loss 0.0200 | Test Loss 0.6697 | accs Train 1.0000 Test 0.8775
# [SAM] Epoch 600/1000: Train Loss 0.0113 | Test Loss 0.7026 | accs Train 1.0000 Test 0.8905
# [SAM] Epoch 700/1000: Train Loss 0.0064 | Test Loss 0.7500 | accs Train 1.0000 Test 0.8960
# [SAM] Epoch 800/1000: Train Loss 0.0039 | Test Loss 0.7468 | accs Train 1.0000 Test 0.9058
# [SAM] Epoch 900/1000: Train Loss 0.0023 | Test Loss 0.7603 | accs Train 1.0000 Test 0.9120
# [SAM] Epoch 1000/1000: Train Loss 0.0013 | Test Loss 0.7847 | accs Train 1.0000 Test 0.9163
# Completed training with 100 additional samples of data
# [SAM] Epoch 1/1000: Train Loss 0.6946 | Test Loss 0.6943 | accs Train 0.5219 Test 0.5000
# [SAM] Epoch 100/1000: Train Loss 0.5971 | Test Loss 0.6049 | accs Train 0.6375 Test 0.6405
# [SAM] Epoch 200/1000: Train Loss 0.3467 | Test Loss 0.3698 | accs Train 0.9531 Test 0.9213
# [SAM] Epoch 300/1000: Train Loss 0.0702 | Test Loss 0.0966 | accs Train 0.9969 Test 0.9830
# [SAM] Epoch 400/1000: Train Loss 0.0180 | Test Loss 0.0381 | accs Train 1.0000 Test 0.9900
# [SAM] Epoch 500/1000: Train Loss 0.0106 | Test Loss 0.0293 | accs Train 1.0000 Test 0.9930
# [SAM] Epoch 600/1000: Train Loss 0.0037 | Test Loss 0.0177 | accs Train 1.0000 Test 0.9958
# [SAM] Epoch 700/1000: Train Loss 0.0025 | Test Loss 0.0140 | accs Train 1.0000 Test 0.9962
# [SAM] Epoch 800/1000: Train Loss 0.0017 | Test Loss 0.0150 | accs Train 1.0000 Test 0.9962
# [SAM] Epoch 900/1000: Train Loss 0.0012 | Test Loss 0.0134 | accs Train 1.0000 Test 0.9965
# [SAM] Epoch 1000/1000: Train Loss 0.0009 | Test Loss 0.0129 | accs Train 1.0000 Test 0.9968
# Completed training with 300 additional samples of data
# [SAM] Epoch 1/1000: Train Loss 0.6970 | Test Loss 0.6942 | accs Train 0.5000 Test 0.5000
# [SAM] Epoch 100/1000: Train Loss 0.6016 | Test Loss 0.6086 | accs Train 0.6431 Test 0.6345
# [SAM] Epoch 200/1000: Train Loss 0.3305 | Test Loss 0.3354 | accs Train 0.9181 Test 0.9323
# [SAM] Epoch 300/1000: Train Loss 0.0397 | Test Loss 0.0482 | accs Train 1.0000 Test 0.9960
# [SAM] Epoch 400/1000: Train Loss 0.0061 | Test Loss 0.0126 | accs Train 1.0000 Test 0.9970
# [SAM] Epoch 500/1000: Train Loss 0.0047 | Test Loss 0.0088 | accs Train 1.0000 Test 0.9988
# [SAM] Epoch 600/1000: Train Loss 0.0022 | Test Loss 0.0078 | accs Train 1.0000 Test 0.9978
# [SAM] Epoch 700/1000: Train Loss 0.0013 | Test Loss 0.0069 | accs Train 1.0000 Test 0.9978
# [SAM] Epoch 800/1000: Train Loss 0.0009 | Test Loss 0.0065 | accs Train 1.0000 Test 0.9980
# [SAM] Epoch 900/1000: Train Loss 0.0006 | Test Loss 0.0063 | accs Train 1.0000 Test 0.9980
# [SAM] Epoch 1000/1000: Train Loss 0.0005 | Test Loss 0.0061 | accs Train 1.0000 Test 0.9982
# Completed training with 700 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 3.5135 | accs: 0.6272
#   30 samples | Test Loss: 2.5924 | accs: 0.6940
#  100 samples | Test Loss: 0.7847 | accs: 0.9163
#  300 samples | Test Loss: 0.0129 | accs: 0.9968
#  700 samples | Test Loss: 0.0061 | accs: 0.9982
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0028 | accs: 1.0000
#  Model   30 | Train Loss: 0.0031 | accs: 1.0000
#  Model  100 | Train Loss: 0.0018 | accs: 1.0000
#  Model  300 | Train Loss: 0.0004 | accs: 1.0000
#  Model  700 | Train Loss: 0.0003 | accs: 1.0000
#
# Dataset type: data, additional samples: 30
#  Model    0 | Train Loss: 2.5932 | accs: 0.7200
#  Model   30 | Train Loss: 0.0017 | accs: 1.0000
#  Model  100 | Train Loss: 0.0017 | accs: 1.0000
#  Model  300 | Train Loss: 0.0006 | accs: 1.0000
#  Model  700 | Train Loss: 0.0004 | accs: 1.0000
#
# Dataset type: data, additional samples: 100
#  Model    0 | Train Loss: 2.4297 | accs: 0.7083
#  Model   30 | Train Loss: 1.5670 | accs: 0.7917
#  Model  100 | Train Loss: 0.0013 | accs: 1.0000
#  Model  300 | Train Loss: 0.0006 | accs: 1.0000
#  Model  700 | Train Loss: 0.0004 | accs: 1.0000
#
# Dataset type: data, additional samples: 300
#  Model    0 | Train Loss: 3.6119 | accs: 0.5813
#  Model   30 | Train Loss: 2.1014 | accs: 0.7375
#  Model  100 | Train Loss: 0.5695 | accs: 0.9250
#  Model  300 | Train Loss: 0.0009 | accs: 1.0000
#  Model  700 | Train Loss: 0.0004 | accs: 1.0000
#
# Dataset type: data, additional samples: 700
#  Model    0 | Train Loss: 3.6309 | accs: 0.5944
#  Model   30 | Train Loss: 2.5571 | accs: 0.6861
#  Model  100 | Train Loss: 0.7066 | accs: 0.9125
#  Model  300 | Train Loss: 0.0209 | accs: 0.9972
#  Model  700 | Train Loss: 0.0005 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_30.pt
# Saved model: models_and_data/model_additional_30.pt
# ✅ Model saved to models_and_data\model_additional_100.pt
# Saved model: models_and_data/model_additional_100.pt
# ✅ Model saved to models_and_data\model_additional_300.pt
# Saved model: models_and_data/model_additional_300.pt
# ✅ Model saved to models_and_data\model_additional_700.pt
# Saved model: models_and_data/model_additional_700.pt
