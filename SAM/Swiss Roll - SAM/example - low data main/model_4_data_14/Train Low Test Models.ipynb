# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train_sam

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 14            
model_seed = 4           

# --- Training configuration ---
epochs = 1500            

# --- Dataset configuration ---
base_data_size = 20      
dataset_type = "data"   
dataset_quantities = [0, 30, 80, 180, 380, 780]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

test_dataset_size = 2000

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    base_data_size=base_data_size,
    dataset_quantities=dataset_quantities,
    test_dataset_size=test_dataset_size,
    noise=0.3, # default swiss params
    extra_pts=1000,
    dataset_type=dataset_type,
    seed=data_seed
)

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train_sam(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# [SAM] Epoch 1/1500: Train Loss 0.6956 | Test Loss 0.7012 | accs Train 0.6000 Test 0.5000
# [SAM] Epoch 100/1500: Train Loss 0.3739 | Test Loss 1.3474 | accs Train 0.7500 Test 0.5308
# [SAM] Epoch 200/1500: Train Loss 0.1441 | Test Loss 2.7028 | accs Train 0.9500 Test 0.5942
# [SAM] Epoch 300/1500: Train Loss 0.0401 | Test Loss 4.2858 | accs Train 1.0000 Test 0.5935
# [SAM] Epoch 400/1500: Train Loss 0.0135 | Test Loss 5.0348 | accs Train 1.0000 Test 0.5962
# [SAM] Epoch 500/1500: Train Loss 0.0054 | Test Loss 5.9572 | accs Train 1.0000 Test 0.5903
# [SAM] Epoch 600/1500: Train Loss 0.0029 | Test Loss 6.3133 | accs Train 1.0000 Test 0.5948
# [SAM] Epoch 700/1500: Train Loss 0.0016 | Test Loss 6.8538 | accs Train 1.0000 Test 0.5948
# [SAM] Epoch 800/1500: Train Loss 0.0009 | Test Loss 7.2420 | accs Train 1.0000 Test 0.5950
# [SAM] Epoch 900/1500: Train Loss 0.0014 | Test Loss 6.7661 | accs Train 1.0000 Test 0.6010
# [SAM] Epoch 1000/1500: Train Loss 0.0008 | Test Loss 7.1827 | accs Train 1.0000 Test 0.6005
# [SAM] Epoch 1100/1500: Train Loss 0.0006 | Test Loss 7.4725 | accs Train 1.0000 Test 0.5998
# [SAM] Epoch 1200/1500: Train Loss 0.0004 | Test Loss 7.7048 | accs Train 1.0000 Test 0.5975
# [SAM] Epoch 1300/1500: Train Loss 0.0003 | Test Loss 7.9118 | accs Train 1.0000 Test 0.5970
# [SAM] Epoch 1400/1500: Train Loss 0.0004 | Test Loss 7.9941 | accs Train 1.0000 Test 0.6028
# [SAM] Epoch 1500/1500: Train Loss 0.0002 | Test Loss 8.3233 | accs Train 1.0000 Test 0.6028
# Completed training with 0 additional samples of data
# [SAM] Epoch 1/1500: Train Loss 0.7083 | Test Loss 0.7001 | accs Train 0.5000 Test 0.5000
# [SAM] Epoch 100/1500: Train Loss 0.4693 | Test Loss 0.6516 | accs Train 0.7600 Test 0.6268
# [SAM] Epoch 200/1500: Train Loss 0.2652 | Test Loss 0.7945 | accs Train 0.8800 Test 0.6202
# [SAM] Epoch 300/1500: Train Loss 0.1337 | Test Loss 0.9152 | accs Train 0.9800 Test 0.6577
# [SAM] Epoch 400/1500: Train Loss 0.0554 | Test Loss 1.0386 | accs Train 1.0000 Test 0.7003
# [SAM] Epoch 500/1500: Train Loss 0.0219 | Test Loss 1.1420 | accs Train 1.0000 Test 0.7308
# [SAM] Epoch 600/1500: Train Loss 0.0086 | Test Loss 1.2346 | accs Train 1.0000 Test 0.7355
# [SAM] Epoch 700/1500: Train Loss 0.0051 | Test Loss 1.3161 | accs Train 1.0000 Test 0.7385
# [SAM] Epoch 800/1500: Train Loss 0.0027 | Test Loss 1.4063 | accs Train 1.0000 Test 0.7445
# [SAM] Epoch 900/1500: Train Loss 0.0017 | Test Loss 1.4895 | accs Train 1.0000 Test 0.7468
# [SAM] Epoch 1000/1500: Train Loss 0.0021 | Test Loss 1.4200 | accs Train 1.0000 Test 0.7530
# [SAM] Epoch 1100/1500: Train Loss 0.0013 | Test Loss 1.5802 | accs Train 1.0000 Test 0.7570
# [SAM] Epoch 1200/1500: Train Loss 0.0009 | Test Loss 1.6446 | accs Train 1.0000 Test 0.7595
# [SAM] Epoch 1300/1500: Train Loss 0.0007 | Test Loss 1.6909 | accs Train 1.0000 Test 0.7618
# [SAM] Epoch 1400/1500: Train Loss 0.0006 | Test Loss 1.7322 | accs Train 1.0000 Test 0.7628
# [SAM] Epoch 1500/1500: Train Loss 0.0005 | Test Loss 1.7732 | accs Train 1.0000 Test 0.7642
# Completed training with 30 additional samples of data
# [SAM] Epoch 1/1500: Train Loss 0.6936 | Test Loss 0.6989 | accs Train 0.5600 Test 0.5000
# [SAM] Epoch 100/1500: Train Loss 0.5065 | Test Loss 0.6004 | accs Train 0.6900 Test 0.6488
# [SAM] Epoch 200/1500: Train Loss 0.3223 | Test Loss 0.5648 | accs Train 0.8800 Test 0.7075
# [SAM] Epoch 300/1500: Train Loss 0.1595 | Test Loss 0.5036 | accs Train 0.9700 Test 0.8045
# [SAM] Epoch 400/1500: Train Loss 0.0555 | Test Loss 0.4638 | accs Train 1.0000 Test 0.9060
# [SAM] Epoch 500/1500: Train Loss 0.0225 | Test Loss 0.4947 | accs Train 1.0000 Test 0.9290
# [SAM] Epoch 600/1500: Train Loss 0.0107 | Test Loss 0.5235 | accs Train 1.0000 Test 0.9277
# [SAM] Epoch 700/1500: Train Loss 0.0064 | Test Loss 0.5544 | accs Train 1.0000 Test 0.9260
# [SAM] Epoch 800/1500: Train Loss 0.0039 | Test Loss 0.5919 | accs Train 1.0000 Test 0.9260
# [SAM] Epoch 900/1500: Train Loss 0.0046 | Test Loss 0.5776 | accs Train 1.0000 Test 0.9300
# [SAM] Epoch 1000/1500: Train Loss 0.0027 | Test Loss 0.6261 | accs Train 1.0000 Test 0.9257
# [SAM] Epoch 1100/1500: Train Loss 0.0017 | Test Loss 0.6523 | accs Train 1.0000 Test 0.9253
# [SAM] Epoch 1200/1500: Train Loss 0.0012 | Test Loss 0.6751 | accs Train 1.0000 Test 0.9265
# [SAM] Epoch 1300/1500: Train Loss 0.0009 | Test Loss 0.6918 | accs Train 1.0000 Test 0.9267
# [SAM] Epoch 1400/1500: Train Loss 0.0009 | Test Loss 0.6971 | accs Train 1.0000 Test 0.9253
# [SAM] Epoch 1500/1500: Train Loss 0.0007 | Test Loss 0.7052 | accs Train 1.0000 Test 0.9253
# Completed training with 80 additional samples of data
# [SAM] Epoch 1/1500: Train Loss 0.6923 | Test Loss 0.6985 | accs Train 0.5600 Test 0.5000
# [SAM] Epoch 100/1500: Train Loss 0.5415 | Test Loss 0.5997 | accs Train 0.6750 Test 0.6402
# [SAM] Epoch 200/1500: Train Loss 0.4442 | Test Loss 0.5469 | accs Train 0.7200 Test 0.6787
# [SAM] Epoch 300/1500: Train Loss 0.2968 | Test Loss 0.4264 | accs Train 0.8850 Test 0.7798
# [SAM] Epoch 400/1500: Train Loss 0.1307 | Test Loss 0.2835 | accs Train 0.9700 Test 0.8975
# [SAM] Epoch 500/1500: Train Loss 0.0440 | Test Loss 0.1879 | accs Train 1.0000 Test 0.9565
# [SAM] Epoch 600/1500: Train Loss 0.0240 | Test Loss 0.1666 | accs Train 1.0000 Test 0.9600
# [SAM] Epoch 700/1500: Train Loss 0.0100 | Test Loss 0.1638 | accs Train 1.0000 Test 0.9617
# [SAM] Epoch 800/1500: Train Loss 0.0105 | Test Loss 0.1510 | accs Train 1.0000 Test 0.9623
# [SAM] Epoch 900/1500: Train Loss 0.0056 | Test Loss 0.1484 | accs Train 1.0000 Test 0.9647
# [SAM] Epoch 1000/1500: Train Loss 0.0034 | Test Loss 0.1504 | accs Train 1.0000 Test 0.9653
# [SAM] Epoch 1100/1500: Train Loss 0.0023 | Test Loss 0.1524 | accs Train 1.0000 Test 0.9657
# [SAM] Epoch 1200/1500: Train Loss 0.0017 | Test Loss 0.1547 | accs Train 1.0000 Test 0.9663
# [SAM] Epoch 1300/1500: Train Loss 0.0013 | Test Loss 0.1559 | accs Train 1.0000 Test 0.9665
# [SAM] Epoch 1400/1500: Train Loss 0.0022 | Test Loss 0.1562 | accs Train 1.0000 Test 0.9620
# [SAM] Epoch 1500/1500: Train Loss 0.0025 | Test Loss 0.1577 | accs Train 1.0000 Test 0.9650
# Completed training with 180 additional samples of data
# [SAM] Epoch 1/1500: Train Loss 0.6980 | Test Loss 0.6979 | accs Train 0.5250 Test 0.5000
# [SAM] Epoch 100/1500: Train Loss 0.5776 | Test Loss 0.5842 | accs Train 0.6225 Test 0.6322
# [SAM] Epoch 200/1500: Train Loss 0.4134 | Test Loss 0.4314 | accs Train 0.8350 Test 0.7837
# [SAM] Epoch 300/1500: Train Loss 0.1595 | Test Loss 0.1741 | accs Train 0.9800 Test 0.9725
# [SAM] Epoch 400/1500: Train Loss 0.0290 | Test Loss 0.0412 | accs Train 1.0000 Test 0.9960
# [SAM] Epoch 500/1500: Train Loss 0.0145 | Test Loss 0.0298 | accs Train 1.0000 Test 0.9958
# [SAM] Epoch 600/1500: Train Loss 0.0066 | Test Loss 0.0222 | accs Train 1.0000 Test 0.9962
# [SAM] Epoch 700/1500: Train Loss 0.0038 | Test Loss 0.0172 | accs Train 1.0000 Test 0.9968
# [SAM] Epoch 800/1500: Train Loss 0.0027 | Test Loss 0.0205 | accs Train 1.0000 Test 0.9965
# [SAM] Epoch 900/1500: Train Loss 0.0015 | Test Loss 0.0223 | accs Train 1.0000 Test 0.9968
# [SAM] Epoch 1000/1500: Train Loss 0.0010 | Test Loss 0.0234 | accs Train 1.0000 Test 0.9970
# [SAM] Epoch 1100/1500: Train Loss 0.0007 | Test Loss 0.0240 | accs Train 1.0000 Test 0.9970
# [SAM] Epoch 1200/1500: Train Loss 0.0006 | Test Loss 0.0242 | accs Train 1.0000 Test 0.9970
# [SAM] Epoch 1300/1500: Train Loss 0.0004 | Test Loss 0.0246 | accs Train 1.0000 Test 0.9970
# [SAM] Epoch 1400/1500: Train Loss 0.0003 | Test Loss 0.0250 | accs Train 1.0000 Test 0.9970
# [SAM] Epoch 1500/1500: Train Loss 0.0110 | Test Loss 0.0297 | accs Train 1.0000 Test 0.9965
# Completed training with 380 additional samples of data
# [SAM] Epoch 1/1500: Train Loss 0.6979 | Test Loss 0.6978 | accs Train 0.5225 Test 0.5000
# [SAM] Epoch 100/1500: Train Loss 0.5687 | Test Loss 0.5829 | accs Train 0.6500 Test 0.6435
# [SAM] Epoch 200/1500: Train Loss 0.4649 | Test Loss 0.4820 | accs Train 0.7338 Test 0.6847
# [SAM] Epoch 300/1500: Train Loss 0.1993 | Test Loss 0.2122 | accs Train 0.9625 Test 0.9533
# [SAM] Epoch 400/1500: Train Loss 0.0429 | Test Loss 0.0497 | accs Train 1.0000 Test 0.9970
# [SAM] Epoch 500/1500: Train Loss 0.0140 | Test Loss 0.0233 | accs Train 1.0000 Test 0.9970
# [SAM] Epoch 600/1500: Train Loss 0.0049 | Test Loss 0.0175 | accs Train 1.0000 Test 0.9972
# [SAM] Epoch 700/1500: Train Loss 0.0061 | Test Loss 0.0220 | accs Train 1.0000 Test 0.9970
# [SAM] Epoch 800/1500: Train Loss 0.0031 | Test Loss 0.0185 | accs Train 1.0000 Test 0.9972
# [SAM] Epoch 900/1500: Train Loss 0.0018 | Test Loss 0.0178 | accs Train 1.0000 Test 0.9972
# [SAM] Epoch 1000/1500: Train Loss 0.0012 | Test Loss 0.0177 | accs Train 1.0000 Test 0.9972
# [SAM] Epoch 1100/1500: Train Loss 0.0008 | Test Loss 0.0179 | accs Train 1.0000 Test 0.9972
# [SAM] Epoch 1200/1500: Train Loss 0.0026 | Test Loss 0.0205 | accs Train 1.0000 Test 0.9972
# [SAM] Epoch 1300/1500: Train Loss 0.0016 | Test Loss 0.0204 | accs Train 1.0000 Test 0.9972
# [SAM] Epoch 1400/1500: Train Loss 0.0011 | Test Loss 0.0204 | accs Train 1.0000 Test 0.9972
# [SAM] Epoch 1500/1500: Train Loss 0.0008 | Test Loss 0.0207 | accs Train 1.0000 Test 0.9972
# Completed training with 780 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 8.3233 | accs: 0.6028
#   30 samples | Test Loss: 1.7732 | accs: 0.7642
#   80 samples | Test Loss: 0.7052 | accs: 0.9253
#  180 samples | Test Loss: 0.1577 | accs: 0.9650
#  380 samples | Test Loss: 0.0297 | accs: 0.9965
#  780 samples | Test Loss: 0.0207 | accs: 0.9972
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0002 | accs: 1.0000
#  Model   30 | Train Loss: 0.0004 | accs: 1.0000
#  Model   80 | Train Loss: 0.0003 | accs: 1.0000
#  Model  180 | Train Loss: 0.0010 | accs: 1.0000
#  Model  380 | Train Loss: 0.0045 | accs: 1.0000
#  Model  780 | Train Loss: 0.0003 | accs: 1.0000
#
# Dataset type: data, additional samples: 30
#  Model    0 | Train Loss: 6.0021 | accs: 0.7200
#  Model   30 | Train Loss: 0.0005 | accs: 1.0000
#  Model   80 | Train Loss: 0.0009 | accs: 1.0000
#  Model  180 | Train Loss: 0.0016 | accs: 1.0000
#  Model  380 | Train Loss: 0.0179 | accs: 1.0000
#  Model  780 | Train Loss: 0.0008 | accs: 1.0000
#
# Dataset type: data, additional samples: 80
#  Model    0 | Train Loss: 7.2987 | accs: 0.6700
#  Model   30 | Train Loss: 0.3376 | accs: 0.9500
#  Model   80 | Train Loss: 0.0007 | accs: 1.0000
#  Model  180 | Train Loss: 0.0017 | accs: 1.0000
#  Model  380 | Train Loss: 0.0113 | accs: 1.0000
#  Model  780 | Train Loss: 0.0006 | accs: 1.0000
#
# Dataset type: data, additional samples: 180
#  Model    0 | Train Loss: 7.7804 | accs: 0.6200
#  Model   30 | Train Loss: 0.9993 | accs: 0.8200
#  Model   80 | Train Loss: 0.2776 | accs: 0.9600
#  Model  180 | Train Loss: 0.0024 | accs: 1.0000
#  Model  380 | Train Loss: 0.0133 | accs: 1.0000
#  Model  780 | Train Loss: 0.0008 | accs: 1.0000
#
# Dataset type: data, additional samples: 380
#  Model    0 | Train Loss: 7.9029 | accs: 0.6125
#  Model   30 | Train Loss: 1.2921 | accs: 0.7850
#  Model   80 | Train Loss: 0.5673 | accs: 0.9450
#  Model  180 | Train Loss: 0.0584 | accs: 0.9825
#  Model  380 | Train Loss: 0.0101 | accs: 1.0000
#  Model  780 | Train Loss: 0.0008 | accs: 1.0000
#
# Dataset type: data, additional samples: 780
#  Model    0 | Train Loss: 8.3562 | accs: 0.6038
#  Model   30 | Train Loss: 1.3449 | accs: 0.7975
#  Model   80 | Train Loss: 0.6043 | accs: 0.9337
#  Model  180 | Train Loss: 0.0769 | accs: 0.9850
#  Model  380 | Train Loss: 0.0108 | accs: 1.0000
#  Model  780 | Train Loss: 0.0008 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_30.pt
# Saved model: models_and_data/model_additional_30.pt
# ✅ Model saved to models_and_data\model_additional_80.pt
# Saved model: models_and_data/model_additional_80.pt
# ✅ Model saved to models_and_data\model_additional_180.pt
# Saved model: models_and_data/model_additional_180.pt
# ✅ Model saved to models_and_data\model_additional_380.pt
# Saved model: models_and_data/model_additional_380.pt
# ✅ Model saved to models_and_data\model_additional_780.pt
# Saved model: models_and_data/model_additional_780.pt
