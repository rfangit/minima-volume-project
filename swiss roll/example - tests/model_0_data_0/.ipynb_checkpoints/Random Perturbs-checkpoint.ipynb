# %% [markdown]
# # Random Perturbations
#
# Streamlined notebook for evaluating random perturbations on saved models and datasets.

# %% [markdown]
# ## Imports

# %%
# Standard library
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.perturb_funcs import ( analyze_wiggles_metrics )

from minima_volume.dataset_funcs import (
    load_dataset,
    load_model,
    load_models_and_data,
    prepare_datasets,
    tensor_to_list,
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# Perturbation Configuration
perturbation_seed = 1
num_directions = 5
N = 100
x = np.linspace(0, 1, N)
coefficients = x**2

# Other Configuration
dataset_quantities = [0, 30]
base_output_dir = ""

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for model and dataset specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

#test_dataset_size = 2000

# Generate dataset - Not used in random perturbs
#x_base, y_base, x_test, y_test = model_module.get_dataset(
#    base_data_size=base_data_size,
#    dataset_quantities=dataset_quantities,
#    test_dataset_size=test_dataset_size,
#    noise=0.3, # default swiss params
#    extra_pts=1000,
#    dataset_type=dataset_type,
#    seed=data_seed
#)
model_seed = 0 # filler for the template

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Loading Model and Datasets

# %%
# ====================================
# Load Trained Models and Dataset
# ====================================
target_dir = "models_and_data"  # relative path
loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
    model_template=model_template,
    target_dir=target_dir,
    device=device,
)

# Dataset Info
dataset_type = loaded_dataset['dataset_type']
print(f"Dataset type: {dataset_type}")
print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")

print("\nTensor shapes:")
for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
    shape = getattr(loaded_dataset[key], "shape", None)
    print(f"  {key}: {shape if shape is not None else 'None'}")

# Reconstruct trained_model dicts safely.
# If the loss or accuracy or additional metrics happen to be
# tensors, they get safely converted to lists.
all_models = [
    {
        "model": model,
        **{
            k: tensor_to_list(model_data[k], key_path=k)
            for k in ["train_loss", "train_accs", "test_loss", "test_accs", "additional_data", "dataset_type"]
        },
    }
    for model, model_data in zip(loaded_models, loaded_model_data)
]
print(f"Reconstructed {len(all_models)} trained models")
# Out:
# Looking for models and dataset in: models_and_data
# Found 4 model files:
#   - model_additional_0.pt
#   - model_additional_100.pt
#   - model_additional_30.pt
#   - model_additional_300.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_0.pt
# Successfully loaded: model_additional_0.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_100.pt
# Successfully loaded: model_additional_100.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_30.pt
# Successfully loaded: model_additional_30.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_300.pt
# Successfully loaded: model_additional_300.pt
#
# Model data loaded from all models:
# Model 0 (model_additional_0.pt):
#   - Additional data: 0
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 1 (model_additional_100.pt):
#   - Additional data: 100
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 2 (model_additional_30.pt):
#   - Additional data: 30
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 3 (model_additional_300.pt):
#   - Additional data: 300
#   - Dataset type: data
#   - Training accuracies: 100 entries
#   - Test accuracies: 100 entries
#
# Loading dataset...
# Using dataset file: dataset.pt
# ✅ Dataset loaded from models_and_data\dataset.pt
# Dataset type: data
# Dataset quantities: [0, 30, 100]
#
# Tensor shapes:
#   x_base_train: torch.Size([20, 2])
#   y_base_train: torch.Size([20])
#   x_additional: torch.Size([100, 2])
#   y_additional: torch.Size([100])
#   x_test: torch.Size([4000, 2])
#   y_test: torch.Size([4000])
# Reconstructed 4 trained models

# %% [markdown]
# ## Perturbations
#
# Using the saved datasets, we perform model perturbations.

# %%
device = 'cpu' #faster for small files

x_base_train = loaded_dataset['x_base_train'].to(device)
y_base_train = loaded_dataset['y_base_train'].to(device)
x_additional = loaded_dataset['x_additional'].to(device)
y_additional = loaded_dataset['y_additional'].to(device)
x_test = loaded_dataset['x_test'].to(device)
y_test = loaded_dataset['y_test'].to(device)

# Loss function and metrics already grabbed from the model module
analyze_wiggles_metrics(
    model_list = all_models, 
    x_base_train = x_base_train,
    y_base_train = y_base_train, 
    x_additional = x_additional,
    y_additional = y_additional,
    x_test = x_test,
    y_test = y_test, 
    dataset_quantities = dataset_quantities, 
    dataset_type = dataset_type, 
    metrics = {"loss": loss_fn, **other_metrics}, 
    coefficients = coefficients,
    num_directions = num_directions,
    perturbation_seed = perturbation_seed,
    base_output_dir = base_output_dir,
    device = 'cpu',  # can be set to GPU if needed
)


""" Our saved results are structured as follows:
wiggle_results: List of dictionaries containing wiggle test results
Each dictionary is of the form
{
'loss':
'coefficients':
'accs':
'perturbation_seed':
'perturbation_norm':
}
model: PyTorch model used in analysis (state_dict will be saved)
output_dir: Directory to save results (default: "imgs/swiss/random_dirs")
filename: Name of output file (default: "random_directions.npz")
**kwargs: Additional key-value pairs to be saved in the output file
Typically:
'additional_data':
'model_trained_data':
'dataset_type':
'base_dataset_size': 
'test_loss':
'test_accs':
'num_params':
"""
# Out:
# The number of parameters of the perturbation is 4353
# Testing on data with 0 samples - 5 directions
# Testing model trained on 0 additional data.
# test_loss
# [0.6936657381057739, 0.692878355383873, 0.6923398140072823, 0.6918849185109138, 0.6915319460630417]
# test_accs
# [0.5, 0.5, 0.5, 0.5, 0.5]
# Loss: 12.6328
# Accs: 0.5225
# Wiggle completed in 0.25 seconds for data model trained with 0 samples
# Saved to data_0
#
# Testing model trained on 100 additional data.
# test_loss
# [0.692519571185112, 0.6904749113321305, 0.688433244228363, 0.6865056204795837, 0.6846604025363923]
# test_accs
# [0.5, 0.5, 0.5, 0.5, 0.53675]
# Loss: 0.2958
# Accs: 0.9367
# Wiggle completed in 0.31 seconds for data model trained with 100 samples
# Saved to data_0
#
# Testing model trained on 30 additional data.
# test_loss
# [0.6928418017923832, 0.6910518854856491, 0.6892815805971623, 0.687465313822031, 0.6856206387281418]
# test_accs
# [0.5, 0.5, 0.5, 0.49725, 0.5655]
# Loss: 4.2851
# Accs: 0.7137
# Wiggle completed in 0.32 seconds for data model trained with 30 samples
# Saved to data_0
#
# Testing model trained on 300 additional data.
# test_loss
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 11
#       8 y_test = loaded_dataset['y_test'].to(device)
#      10 # Loss function and metrics already grabbed from the model module
# ---> 11 analyze_wiggles_metrics(
#      12     model_list = all_models,
#      13     x_base_train = x_base_train,
#      14     y_base_train = y_base_train,
#      15     x_additional = x_additional,
#      16     y_additional = y_additional,
#      17     x_test = x_test,
#      18     y_test = y_test,
#      19     dataset_quantities = dataset_quantities,
#      20     dataset_type = dataset_type,
#      21     metrics = {"loss": loss_fn, **other_metrics},
#      22     coefficients = coefficients,
#      23     num_directions = num_directions,
#      24     perturbation_seed = perturbation_seed,
#      25     base_output_dir = base_output_dir,
#      26     device = 'cpu',  # can be set to GPU if needed
#      27 )
#      30 """ Our saved results are structured as follows:
#      31 wiggle_results: List of dictionaries containing wiggle test results
#      32 Each dictionary is of the form
#    (...)
#      51 'num_params':
#      52 """
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\perturb_funcs.py:443, in analyze_wiggles_metrics(model_list, x_base_train, y_base_train, x_additional, y_additional, x_test, y_test, dataset_quantities, dataset_type, metrics, coefficients, num_directions, perturbation_seed, base_output_dir, device)
#     441 test_key = f"test_{metric_name}"
#     442 print (test_key)
# --> 443 print (model_data[test_key][0:5])
#     444 if test_key in model_data:
#     445     test_performance[metric_name] = model_data[test_key][-1]
#
# TypeError: 'NoneType' object is not subscriptable
