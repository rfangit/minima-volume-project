# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.5, 2]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}"
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['data_300', 'data_700', 'data_0', 'data_100', 'data_30']
#
# ==================================================
# Analyzing directory: data_300
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_300
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 300
# data_0: 3.36820650100708
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_300/loss_0.1/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_300/loss_0.1/gen_log_volume.png
# Plot saved to: data_300/loss_0.1/test_vs_data.png
# Plot saved to: data_300/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_300/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_300/acc_0.95/avg_radius.png
# Error analyzing data_300 with loss=0.1, acc=0.95: No valid metric values to plot
#
# --- Using thresholds: loss=0.5, acc=0.9 ---
# Loaded data dictionary with 1 models from data_300
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 300
# data_0: 3.36820650100708
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# /Users/brycesandlund/miniconda3/envs/minima-volume-project/lib/python3.10/site-packages/numpy/lib/_histograms_impl.py:901: RuntimeWarning: divide by zero encountered in divide
#   return n/db/n.sum(), bin_edges
# /Users/brycesandlund/miniconda3/envs/minima-volume-project/lib/python3.10/site-packages/numpy/lib/_histograms_impl.py:901: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# /Users/brycesandlund/miniconda3/envs/minima-volume-project/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/brycesandlund/miniconda3/envs/minima-volume-project/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Plot saved to: data_300/loss_0.5/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_300/loss_0.5/gen_log_volume.png
# Plot saved to: data_300/loss_0.5/test_vs_data.png
# Plot saved to: data_300/loss_0.5/other_plots/avg_radius.png
# Plot saved to: data_300/loss_0.5/other_plots/radius_hist.png
# Plot saved to: data_300/acc_0.9/avg_radius.png
# Error analyzing data_300 with loss=0.5, acc=0.9: No valid metric values to plot
#
# --- Using thresholds: loss=2, acc=0.85 ---
# Loaded data dictionary with 1 models from data_300
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 300
# data_0: 3.36820650100708
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_300/loss_2/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_300/loss_2/gen_log_volume.png
# Plot saved to: data_300/loss_2/test_vs_data.png
# Plot saved to: data_300/loss_2/other_plots/avg_radius.png
# Plot saved to: data_300/loss_2/other_plots/radius_hist.png
# Plot saved to: data_300/acc_0.85/avg_radius.png
# Error analyzing data_300 with loss=2, acc=0.85: No valid metric values to plot
#
# ==================================================
# Analyzing directory: data_700
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_700
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 700
# data_0: 3.2518093585968018
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_700/loss_0.1/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_700/loss_0.1/gen_log_volume.png
# Plot saved to: data_700/loss_0.1/test_vs_data.png
# Plot saved to: data_700/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_700/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_700/acc_0.95/avg_radius.png
# Error analyzing data_700 with loss=0.1, acc=0.95: No valid metric values to plot
#
# --- Using thresholds: loss=0.5, acc=0.9 ---
# Loaded data dictionary with 1 models from data_700
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 700
# data_0: 3.2518093585968018
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_700/loss_0.5/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_700/loss_0.5/gen_log_volume.png
# Plot saved to: data_700/loss_0.5/test_vs_data.png
# Plot saved to: data_700/loss_0.5/other_plots/avg_radius.png
# Plot saved to: data_700/loss_0.5/other_plots/radius_hist.png
# Plot saved to: data_700/acc_0.9/avg_radius.png
# Error analyzing data_700 with loss=0.5, acc=0.9: No valid metric values to plot
#
# --- Using thresholds: loss=2, acc=0.85 ---
# Loaded data dictionary with 1 models from data_700
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 700
# data_0: 3.2518093585968018
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_700/loss_2/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_700/loss_2/gen_log_volume.png
# Plot saved to: data_700/loss_2/test_vs_data.png
# Plot saved to: data_700/loss_2/other_plots/avg_radius.png
# Plot saved to: data_700/loss_2/other_plots/radius_hist.png
# Plot saved to: data_700/acc_0.85/avg_radius.png
# Error analyzing data_700 with loss=2, acc=0.85: No valid metric values to plot
#
# ==================================================
# Analyzing directory: data_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_0
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 0
# data_0: 4.153313159942627
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_0/loss_0.1/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_0/loss_0.1/gen_log_volume.png
# Plot saved to: data_0/loss_0.1/test_vs_data.png
# Plot saved to: data_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.95/avg_radius.png
# Error analyzing data_0 with loss=0.1, acc=0.95: No valid metric values to plot
#
# --- Using thresholds: loss=0.5, acc=0.9 ---
# Loaded data dictionary with 1 models from data_0
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 0
# data_0: 4.153313159942627
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_0/loss_0.5/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_0/loss_0.5/gen_log_volume.png
# Plot saved to: data_0/loss_0.5/test_vs_data.png
# Plot saved to: data_0/loss_0.5/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.5/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.9/avg_radius.png
# Error analyzing data_0 with loss=0.5, acc=0.9: No valid metric values to plot
#
# --- Using thresholds: loss=2, acc=0.85 ---
# Loaded data dictionary with 1 models from data_0
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 0
# data_0: 4.153313159942627
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_0/loss_2/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_0/loss_2/gen_log_volume.png
# Plot saved to: data_0/loss_2/test_vs_data.png
# Plot saved to: data_0/loss_2/other_plots/avg_radius.png
# Plot saved to: data_0/loss_2/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Error analyzing data_0 with loss=2, acc=0.85: No valid metric values to plot
#
# ==================================================
# Analyzing directory: data_100
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_100
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 100
# data_0: 3.029109477996826
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_100/loss_0.1/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_100/loss_0.1/gen_log_volume.png
# Plot saved to: data_100/loss_0.1/test_vs_data.png
# Plot saved to: data_100/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_100/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_100/acc_0.95/avg_radius.png
# Error analyzing data_100 with loss=0.1, acc=0.95: No valid metric values to plot
#
# --- Using thresholds: loss=0.5, acc=0.9 ---
# Loaded data dictionary with 1 models from data_100
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 100
# data_0: 3.029109477996826
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_100/loss_0.5/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_100/loss_0.5/gen_log_volume.png
# Plot saved to: data_100/loss_0.5/test_vs_data.png
# Plot saved to: data_100/loss_0.5/other_plots/avg_radius.png
# Plot saved to: data_100/loss_0.5/other_plots/radius_hist.png
# Plot saved to: data_100/acc_0.9/avg_radius.png
# Error analyzing data_100 with loss=0.5, acc=0.9: No valid metric values to plot
#
# --- Using thresholds: loss=2, acc=0.85 ---
# Loaded data dictionary with 1 models from data_100
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 100
# data_0: 3.029109477996826
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_100/loss_2/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_100/loss_2/gen_log_volume.png
# Plot saved to: data_100/loss_2/test_vs_data.png
# Plot saved to: data_100/loss_2/other_plots/avg_radius.png
# Plot saved to: data_100/loss_2/other_plots/radius_hist.png
# Plot saved to: data_100/acc_0.85/avg_radius.png
# Error analyzing data_100 with loss=2, acc=0.85: No valid metric values to plot
#
# ==================================================
# Analyzing directory: data_30
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_30
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 30
# data_0: 4.336297035217285
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_30/loss_0.1/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_30/loss_0.1/gen_log_volume.png
# Plot saved to: data_30/loss_0.1/test_vs_data.png
# Plot saved to: data_30/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_30/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_30/acc_0.95/avg_radius.png
# Error analyzing data_30 with loss=0.1, acc=0.95: No valid metric values to plot
#
# --- Using thresholds: loss=0.5, acc=0.9 ---
# Loaded data dictionary with 1 models from data_30
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 30
# data_0: 4.336297035217285
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_30/loss_0.5/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_30/loss_0.5/gen_log_volume.png
# Plot saved to: data_30/loss_0.5/test_vs_data.png
# Plot saved to: data_30/loss_0.5/other_plots/avg_radius.png
# Plot saved to: data_30/loss_0.5/other_plots/radius_hist.png
# Plot saved to: data_30/acc_0.9/avg_radius.png
# Error analyzing data_30 with loss=0.5, acc=0.9: No valid metric values to plot
#
# --- Using thresholds: loss=2, acc=0.85 ---
# Loaded data dictionary with 1 models from data_30
# The size of the base dataset is  50
# The number of model parameters is  4353
# The loss landscape is for data trained with 30
# data_0: 4.336297035217285
#
# Top perturbations for data_0:
# Top 5 r_vals: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Top 5 seeds: [1, 2, 3, 4, 5]
# Plot saved to: data_30/loss_2/log_volume.png
# Test loss  [4.134291388117708]
# log_exp_r_n  [-inf]
# Plot saved to: data_30/loss_2/gen_log_volume.png
# Plot saved to: data_30/loss_2/test_vs_data.png
# Plot saved to: data_30/loss_2/other_plots/avg_radius.png
# Plot saved to: data_30/loss_2/other_plots/radius_hist.png
# Plot saved to: data_30/acc_0.85/avg_radius.png
# Error analyzing data_30 with loss=2, acc=0.85: No valid metric values to plot
#
# Analysis complete for all directories!
