# %% [markdown]
# # Comparisons In A Given Loss Landscape

# %%
import os
import json
from pathlib import Path
import matplotlib.pyplot as plt

from minima_volume.analysis_funcs import (  grab_folder_names,
                                            load_base_train_size,
                                            list_additional_data,
                                            multiple_minima_fixed_landscape,
                                            fixed_landscape_minima_labels,
                                            plot_fixed_landscape_minima_pair,
                                            model_volume_across_targets,
                                            append_cutoff_points,
                                            varying_landscape_minima_labels,
                                            plot_minima_volume_vs_data_level,
)

loss_value = 0.1  # Loss value to analyze
data_level_log = False #Is the data log distributed?
base_output_dir = "analysis"  # Root folder to save all plots
os.makedirs(base_output_dir, exist_ok=True)

# Data for the loss landscape levels
experiment_folders, data_modifications = grab_folder_names()

base_train_size = load_base_train_size(experiment_folders[0])
model_data_sizes = list_additional_data(experiment_folders[0])
print("Experiment folders: ", experiment_folders)
print("Different data levels where loss landscapes were computed:", data_modifications)
print("The base train size is: ", base_train_size)
print("Data levels where models were trained: ", model_data_sizes)
# Out:
# First entry: Model_0, base_train_size = 400
# Experiment folders:  ['model_0_data_10', 'model_1_data_11', 'model_2_data_12', 'model_3_data_13', 'model_4_data_14', 'model_5_data_15', 'model_6_data_16', 'model_7_data_17', 'model_8_data_18', 'model_9_data_19']
# Different data levels where loss landscapes were computed: ['poison_0']
# The base train size is:  400
# Data levels where models were trained:  [0, 10, 100, 20, 50]

# %% [markdown]
# ## Plotting Different Model Volumes In A Landscape

# %%
for data_modification in data_modifications:
    print(f"\nProcessing data modification folder: {data_modification}")

    # Create output folder for this data_modification
    save_dir = os.path.join(base_output_dir, data_modification)
    os.makedirs(save_dir, exist_ok=True)

    # Get axis labels and titles
    labels = fixed_landscape_minima_labels(data_modification, base_train_size)

    # Extract minima landscapes
    all_mdl, all_log_rn, all_test_loss = multiple_minima_fixed_landscape(
        experiment_folders, data_modification, loss_value
    )

    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=data_level_log,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_log_volume",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title="Log Volume vs Test Loss",
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="log_volume_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )

    ## Rank variant
    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_log_volume",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title="Log Volume vs Test Loss",
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="log_volume_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )
# Out:
# Processing data modification folder: poison_0
# L:\Programming\diffusion-env\Lib\site-packages\numpy\core\_methods.py:173: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %% [markdown]
# # Comparisons Across Loss Landscapes

# %% [markdown]
# Here, we track the performance of all models across all loss landscapes.

# %%
# For the poisoning experiments, this plot has no meaning

labels = varying_landscape_minima_labels(
    data_modification_folder=data_modifications[0], # Random choice to grab datatype from
    base_train_size=base_train_size,
)

results_dict = model_volume_across_targets(
    target_model_data_levels=model_data_sizes,
    loss_value=loss_value,
    experiment_folders=experiment_folders
)
results_with_cutoff = append_cutoff_points(results_dict, threshold=loss_value, base_dir=".")

plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          # NEW: needed for correct legend labels
    base_train_size=base_train_size,  # NEW: used for dataset size shifts
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = data_level_log,
    alpha=0.3,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels",
    xlabel_size=15, ylabel_size=15, title_size=15
)
# Out:
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Model_0: first exceedance at index 404 (value=0.11258216202259064, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=0, cutoff_idx=404
# Model_0: first exceedance at index 402 (value=0.11846901476383209, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=0, cutoff_idx=402
# Model_0: first exceedance at index 404 (value=0.11912485957145691, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=0, cutoff_idx=404
# Model_0: first exceedance at index 404 (value=0.11623942106962204, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=0, cutoff_idx=404
# Model_0: first exceedance at index 404 (value=0.11809317767620087, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=0, cutoff_idx=404
# Model_0: first exceedance at index 403 (value=0.10378075391054153, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=0, cutoff_idx=403
# Model_0: first exceedance at index 402 (value=0.10763860493898392, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=0, cutoff_idx=402
# Model_0: first exceedance at index 403 (value=0.10860830545425415, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=0, cutoff_idx=403
# Model_0: first exceedance at index 402 (value=0.13413429260253906, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=0, cutoff_idx=402
# Model_0: first exceedance at index 404 (value=0.1393834948539734, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=0, cutoff_idx=404
# Model_10: first exceedance at index 411 (value=0.10072251409292221, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=10, cutoff_idx=411
# Model_10: first exceedance at index 414 (value=0.10818757116794586, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=10, cutoff_idx=414
# Model_10: first exceedance at index 1 (value=0.1321869045495987, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=10, cutoff_idx=1
# Model_10: first exceedance at index 412 (value=0.12794245779514313, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=10, cutoff_idx=412
# Model_10: first exceedance at index 414 (value=0.10359273850917816, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=10, cutoff_idx=414
# Model_10: first exceedance at index 410 (value=0.10745425522327423, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=10, cutoff_idx=410
# Model_10: first exceedance at index 412 (value=0.10142777860164642, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=10, cutoff_idx=412
# Model_10: first exceedance at index 412 (value=0.10390201210975647, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=10, cutoff_idx=412
# Model_10: first exceedance at index 0 (value=0.1686069667339325, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=10, cutoff_idx=0
# Model_10: first exceedance at index 412 (value=0.10379424691200256, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=10, cutoff_idx=412
# Model_20: first exceedance at index 421 (value=0.10027118772268295, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=20, cutoff_idx=421
# Model_20: first exceedance at index 421 (value=0.10943034291267395, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=20, cutoff_idx=421
# Model_20: first exceedance at index 1 (value=0.18457871675491333, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=20, cutoff_idx=1
# Model_20: first exceedance at index 2 (value=0.18136568367481232, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=20, cutoff_idx=2
# Model_20: first exceedance at index 421 (value=0.11557590216398239, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=20, cutoff_idx=421
# Model_20: first exceedance at index 421 (value=0.1270165592432022, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=20, cutoff_idx=421
# Model_20: first exceedance at index 420 (value=0.10077569633722305, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=20, cutoff_idx=420
# Model_20: first exceedance at index 420 (value=0.106716088950634, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=20, cutoff_idx=420
# Model_20: first exceedance at index 420 (value=0.11030784994363785, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=20, cutoff_idx=420
# Model_20: first exceedance at index 421 (value=0.11877860128879547, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=20, cutoff_idx=421
# Model_50: first exceedance at index 0 (value=0.14093641936779022, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=50, cutoff_idx=0
# Model_50: first exceedance at index 0 (value=0.10332322120666504, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=50, cutoff_idx=0
# Model_50: first exceedance at index 1 (value=0.18026836216449738, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=50, cutoff_idx=1
# Model_50: first exceedance at index 1 (value=0.14201870560646057, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=50, cutoff_idx=1
# Model_50: first exceedance at index 102 (value=0.10402340441942215, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=50, cutoff_idx=102
# Model_50: first exceedance at index 406 (value=0.10066723078489304, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=50, cutoff_idx=406
# Model_50: first exceedance at index 9 (value=0.10280877351760864, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=50, cutoff_idx=9
# Model_50: first exceedance at index 403 (value=0.10163002461194992, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=50, cutoff_idx=403
# Model_50: first exceedance at index 0 (value=0.5237132906913757, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=50, cutoff_idx=0
# Model_50: first exceedance at index 11 (value=0.10054058581590652, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=50, cutoff_idx=11
# Model_100: first exceedance at index 0 (value=0.6964494585990906, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=100, cutoff_idx=0
# Model_100: first exceedance at index 13 (value=0.10237226635217667, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=100, cutoff_idx=13
# Model_100: first exceedance at index 0 (value=0.4679186940193176, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=100, cutoff_idx=0
# Model_100: first exceedance at index 1 (value=0.27925312519073486, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=100, cutoff_idx=1
# Model_100: first exceedance at index 0 (value=0.8100137710571289, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=100, cutoff_idx=0
# Model_100: first exceedance at index 18 (value=0.12606863677501678, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=100, cutoff_idx=18
# Model_100: first exceedance at index 1 (value=0.16234052181243896, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=100, cutoff_idx=1
# Model_100: first exceedance at index 7 (value=0.14616994559764862, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=100, cutoff_idx=7
# Model_100: first exceedance at index 0 (value=0.8623785972595215, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=100, cutoff_idx=0
# Model_100: first exceedance at index 1 (value=0.41849762201309204, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=100, cutoff_idx=1
