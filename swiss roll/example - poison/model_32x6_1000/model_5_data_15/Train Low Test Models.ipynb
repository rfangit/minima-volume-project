# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 15            
model_seed = 5           

# --- Training configuration ---
epochs = 500            

# --- Dataset configuration ---
base_data_size = 400      
dataset_type = "poison"   
dataset_quantities = [0, 10, 20, 50, 100]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

test_dataset_size = 2000

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    base_data_size=base_data_size,
    dataset_quantities=dataset_quantities,
    test_dataset_size=test_dataset_size,
    noise=0.3, # default swiss params
    extra_pts=1000,
    dataset_type=dataset_type,
    seed=data_seed
)

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*6

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/500: Train Loss 0.6943 | Test Loss 0.6955 | accs Train 0.5125 Test 0.5000
# Epoch 100/500: Train Loss 0.5782 | Test Loss 0.6087 | accs Train 0.6925 Test 0.6610
# Epoch 200/500: Train Loss 0.0072 | Test Loss 0.0189 | accs Train 1.0000 Test 0.9925
# Epoch 300/500: Train Loss 0.0006 | Test Loss 0.0084 | accs Train 1.0000 Test 0.9968
# Epoch 400/500: Train Loss 0.0002 | Test Loss 0.0081 | accs Train 1.0000 Test 0.9965
# Epoch 500/500: Train Loss 0.0001 | Test Loss 0.0086 | accs Train 1.0000 Test 0.9965
# Completed training with 0 additional samples of poison
# Epoch 1/500: Train Loss 0.6947 | Test Loss 0.6956 | accs Train 0.5098 Test 0.5000
# Epoch 100/500: Train Loss 0.5813 | Test Loss 0.6057 | accs Train 0.6927 Test 0.6542
# Epoch 200/500: Train Loss 0.0714 | Test Loss 0.0400 | accs Train 0.9756 Test 0.9975
# Epoch 300/500: Train Loss 0.0505 | Test Loss 0.0259 | accs Train 0.9805 Test 0.9970
# Epoch 400/500: Train Loss 0.0470 | Test Loss 0.0271 | accs Train 0.9780 Test 0.9970
# Epoch 500/500: Train Loss 0.0385 | Test Loss 0.0282 | accs Train 0.9854 Test 0.9925
# Completed training with 10 additional samples of poison
# Epoch 1/500: Train Loss 0.6951 | Test Loss 0.6956 | accs Train 0.5071 Test 0.5000
# Epoch 100/500: Train Loss 0.5954 | Test Loss 0.6037 | accs Train 0.6810 Test 0.6500
# Epoch 200/500: Train Loss 0.1250 | Test Loss 0.0525 | accs Train 0.9548 Test 0.9970
# Epoch 300/500: Train Loss 0.1053 | Test Loss 0.0516 | accs Train 0.9595 Test 0.9910
# Epoch 400/500: Train Loss 0.0906 | Test Loss 0.0549 | accs Train 0.9690 Test 0.9845
# Epoch 500/500: Train Loss 0.0826 | Test Loss 0.0609 | accs Train 0.9690 Test 0.9830
# Completed training with 20 additional samples of poison
# Epoch 1/500: Train Loss 0.6955 | Test Loss 0.6956 | accs Train 0.5044 Test 0.5000
# Epoch 100/500: Train Loss 0.6157 | Test Loss 0.6006 | accs Train 0.6400 Test 0.6538
# Epoch 200/500: Train Loss 0.2553 | Test Loss 0.1534 | accs Train 0.9022 Test 0.9643
# Epoch 300/500: Train Loss 0.2107 | Test Loss 0.1313 | accs Train 0.9156 Test 0.9550
# Epoch 400/500: Train Loss 0.1915 | Test Loss 0.1329 | accs Train 0.9200 Test 0.9513
# Epoch 500/500: Train Loss 0.1798 | Test Loss 0.1317 | accs Train 0.9156 Test 0.9500
# Completed training with 50 additional samples of poison
# Epoch 1/500: Train Loss 0.6970 | Test Loss 0.6956 | accs Train 0.4940 Test 0.5000
# Epoch 100/500: Train Loss 0.6325 | Test Loss 0.5980 | accs Train 0.6300 Test 0.6538
# Epoch 200/500: Train Loss 0.4074 | Test Loss 0.2514 | accs Train 0.8140 Test 0.9517
# Epoch 300/500: Train Loss 0.3586 | Test Loss 0.2519 | accs Train 0.8400 Test 0.9270
# Epoch 400/500: Train Loss 0.3250 | Test Loss 0.2910 | accs Train 0.8500 Test 0.9070
# Epoch 500/500: Train Loss 0.3077 | Test Loss 0.3210 | accs Train 0.8460 Test 0.8735
# Completed training with 100 additional samples of poison

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 0.0086 | accs: 0.9965
#   10 samples | Test Loss: 0.0282 | accs: 0.9925
#   20 samples | Test Loss: 0.0609 | accs: 0.9830
#   50 samples | Test Loss: 0.1317 | accs: 0.9500
#  100 samples | Test Loss: 0.3210 | accs: 0.8735
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: poison, additional samples: 0
#  Model    0 | Train Loss: 0.0001 | accs: 1.0000
#  Model   10 | Train Loss: 0.0165 | accs: 1.0000
#  Model   20 | Train Loss: 0.0334 | accs: 0.9950
#  Model   50 | Train Loss: 0.0810 | accs: 0.9850
#  Model  100 | Train Loss: 0.1717 | accs: 0.9525
#
# Dataset type: poison, additional samples: 10
#  Model    0 | Train Loss: 0.2558 | accs: 0.9756
#  Model   10 | Train Loss: 0.0397 | accs: 0.9878
#  Model   20 | Train Loss: 0.0617 | accs: 0.9756
#  Model   50 | Train Loss: 0.1090 | accs: 0.9659
#  Model  100 | Train Loss: 0.1933 | accs: 0.9415
#
# Dataset type: poison, additional samples: 20
#  Model    0 | Train Loss: 0.6355 | accs: 0.9524
#  Model   10 | Train Loss: 0.3653 | accs: 0.9643
#  Model   20 | Train Loss: 0.0809 | accs: 0.9690
#  Model   50 | Train Loss: 0.1216 | accs: 0.9595
#  Model  100 | Train Loss: 0.2040 | accs: 0.9333
#
# Dataset type: poison, additional samples: 50
#  Model    0 | Train Loss: 1.5464 | accs: 0.8889
#  Model   10 | Train Loss: 1.0898 | accs: 0.9022
#  Model   20 | Train Loss: 0.5902 | accs: 0.9089
#  Model   50 | Train Loss: 0.1770 | accs: 0.9200
#  Model  100 | Train Loss: 0.2521 | accs: 0.9000
#
# Dataset type: poison, additional samples: 100
#  Model    0 | Train Loss: 2.8227 | accs: 0.8000
#  Model   10 | Train Loss: 2.1267 | accs: 0.8140
#  Model   20 | Train Loss: 1.3456 | accs: 0.8220
#  Model   50 | Train Loss: 0.6921 | accs: 0.8340
#  Model  100 | Train Loss: 0.3165 | accs: 0.8520

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_10.pt
# Saved model: models_and_data/model_additional_10.pt
# ✅ Model saved to models_and_data\model_additional_20.pt
# Saved model: models_and_data/model_additional_20.pt
# ✅ Model saved to models_and_data\model_additional_50.pt
# Saved model: models_and_data/model_additional_50.pt
# ✅ Model saved to models_and_data\model_additional_100.pt
# Saved model: models_and_data/model_additional_100.pt
