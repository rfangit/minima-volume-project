# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 14            
model_seed = 4           

# --- Training configuration ---
epochs = 2000            

# --- Dataset configuration ---
base_data_size = 400      
dataset_type = "poison"    
dataset_quantities = [0, 10, 20, 50, 100]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

test_dataset_size = 2000

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    base_data_size=base_data_size,
    dataset_quantities=dataset_quantities,
    test_dataset_size=test_dataset_size,
    noise=0.3, # default swiss params
    extra_pts=1000,
    dataset_type=dataset_type,
    seed=data_seed
)

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %%
# Show the names of all parameters first (helps you locate layers)
print("=== Model Parameters ===")
for name, param in model_template.named_parameters():
    print(name, param.shape)

# Example: print first few weights from the first layer
first_layer_weights = next(model_template.parameters()).data
print("\n=== First layer weights (sample) ===")
print(first_layer_weights[:5, :5])  # first 5 rows, first 5 cols

# Example: print biases if available
for name, param in model_template.named_parameters():
    if "bias" in name:
        print(f"\n{name} (first 5 values):")
        print(param.data[:5])
        break
# Out:
# === Model Parameters ===
# model.0.weight torch.Size([32, 2])
# model.0.bias torch.Size([32])
# model.2.weight torch.Size([32, 32])
# model.2.bias torch.Size([32])
# model.4.weight torch.Size([32, 32])
# model.4.bias torch.Size([32])
# model.6.weight torch.Size([32, 32])
# model.6.bias torch.Size([32])
# model.8.weight torch.Size([32, 32])
# model.8.bias torch.Size([32])
# model.10.weight torch.Size([1, 32])
# model.10.bias torch.Size([1])
#
# === First layer weights (sample) ===
# tensor([[ 0.0843,  0.0836],
#         [-0.5778, -0.4101],
#         [-0.6969, -0.6520],
#         [ 0.6971,  0.5842],
#         [ 0.1677,  0.6709]], device='cuda:0')
#
# model.0.bias (first 5 values):
# tensor([ 0.0767,  0.4368,  0.2793, -0.4892,  0.0073], device='cuda:0')

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_losses, train_other_metrics, test_losses, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_losses": train_losses,
        "test_losses": test_losses,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/2000: Train Loss 0.7008 | Test Loss 0.6975 | accs Train 0.4975 Test 0.5000
# Epoch 100/2000: Train Loss 0.5615 | Test Loss 0.5520 | accs Train 0.5925 Test 0.6175
# Epoch 200/2000: Train Loss 0.0284 | Test Loss 0.0546 | accs Train 0.9950 Test 0.9902
# Epoch 300/2000: Train Loss 0.0013 | Test Loss 0.0386 | accs Train 1.0000 Test 0.9942
# Epoch 400/2000: Train Loss 0.0005 | Test Loss 0.0384 | accs Train 1.0000 Test 0.9942
# Epoch 500/2000: Train Loss 0.0002 | Test Loss 0.0383 | accs Train 1.0000 Test 0.9948
# Epoch 600/2000: Train Loss 0.0001 | Test Loss 0.0382 | accs Train 1.0000 Test 0.9948
# Epoch 700/2000: Train Loss 0.0001 | Test Loss 0.0378 | accs Train 1.0000 Test 0.9948
# Epoch 800/2000: Train Loss 0.0001 | Test Loss 0.0373 | accs Train 1.0000 Test 0.9950
# Epoch 900/2000: Train Loss 0.0000 | Test Loss 0.0375 | accs Train 1.0000 Test 0.9950
# Epoch 1000/2000: Train Loss 0.0000 | Test Loss 0.0373 | accs Train 1.0000 Test 0.9952
# Epoch 1100/2000: Train Loss 0.0000 | Test Loss 0.0372 | accs Train 1.0000 Test 0.9952
# Epoch 1200/2000: Train Loss 0.0000 | Test Loss 0.0370 | accs Train 1.0000 Test 0.9955
# Epoch 1300/2000: Train Loss 0.0000 | Test Loss 0.0369 | accs Train 1.0000 Test 0.9955
# Epoch 1400/2000: Train Loss 0.0000 | Test Loss 0.0370 | accs Train 1.0000 Test 0.9955
# Epoch 1500/2000: Train Loss 0.0000 | Test Loss 0.0371 | accs Train 1.0000 Test 0.9955
# Epoch 1600/2000: Train Loss 0.0000 | Test Loss 0.0371 | accs Train 1.0000 Test 0.9955
# Epoch 1700/2000: Train Loss 0.0000 | Test Loss 0.0371 | accs Train 1.0000 Test 0.9955
# Epoch 1800/2000: Train Loss 0.0000 | Test Loss 0.0370 | accs Train 1.0000 Test 0.9955
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 0.0370 | accs Train 1.0000 Test 0.9955
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 0.0391 | accs Train 1.0000 Test 0.9955
# Completed training with 0 additional samples of poison
# Epoch 1/2000: Train Loss 0.7013 | Test Loss 0.6975 | accs Train 0.4951 Test 0.5000
# Epoch 100/2000: Train Loss 0.5683 | Test Loss 0.5599 | accs Train 0.5902 Test 0.6152
# Epoch 200/2000: Train Loss 0.1080 | Test Loss 0.0819 | accs Train 0.9732 Test 0.9882
# Epoch 300/2000: Train Loss 0.0672 | Test Loss 0.0601 | accs Train 0.9756 Test 0.9900
# Epoch 400/2000: Train Loss 0.0544 | Test Loss 0.0540 | accs Train 0.9756 Test 0.9890
# Epoch 500/2000: Train Loss 0.0527 | Test Loss 0.0417 | accs Train 0.9780 Test 0.9888
# Epoch 600/2000: Train Loss 0.0470 | Test Loss 0.0465 | accs Train 0.9756 Test 0.9868
# Epoch 700/2000: Train Loss 0.0444 | Test Loss 0.0418 | accs Train 0.9756 Test 0.9875
# Epoch 800/2000: Train Loss 0.0419 | Test Loss 0.0446 | accs Train 0.9780 Test 0.9858
# Epoch 900/2000: Train Loss 0.0399 | Test Loss 0.0459 | accs Train 0.9805 Test 0.9850
# Epoch 1000/2000: Train Loss 0.0400 | Test Loss 0.0422 | accs Train 0.9854 Test 0.9858
# Epoch 1100/2000: Train Loss 0.0506 | Test Loss 0.0611 | accs Train 0.9732 Test 0.9842
# Epoch 1200/2000: Train Loss 0.0425 | Test Loss 0.0503 | accs Train 0.9780 Test 0.9878
# Epoch 1300/2000: Train Loss 0.0408 | Test Loss 0.0492 | accs Train 0.9780 Test 0.9880
# Epoch 1400/2000: Train Loss 0.0393 | Test Loss 0.0481 | accs Train 0.9829 Test 0.9880
# Epoch 1500/2000: Train Loss 0.0380 | Test Loss 0.0483 | accs Train 0.9780 Test 0.9870
# Epoch 1600/2000: Train Loss 0.0368 | Test Loss 0.0470 | accs Train 0.9854 Test 0.9872
# Epoch 1700/2000: Train Loss 0.0358 | Test Loss 0.0481 | accs Train 0.9854 Test 0.9865
# Epoch 1800/2000: Train Loss 0.0347 | Test Loss 0.0482 | accs Train 0.9854 Test 0.9855
# Epoch 1900/2000: Train Loss 0.0334 | Test Loss 0.0495 | accs Train 0.9854 Test 0.9850
# Epoch 2000/2000: Train Loss 0.0324 | Test Loss 0.0517 | accs Train 0.9878 Test 0.9828
# Completed training with 10 additional samples of poison
# Epoch 1/2000: Train Loss 0.7011 | Test Loss 0.6976 | accs Train 0.4952 Test 0.5000
# Epoch 100/2000: Train Loss 0.5802 | Test Loss 0.5647 | accs Train 0.5857 Test 0.6270
# Epoch 200/2000: Train Loss 0.1781 | Test Loss 0.1390 | accs Train 0.9524 Test 0.9818
# Epoch 300/2000: Train Loss 0.1166 | Test Loss 0.0946 | accs Train 0.9548 Test 0.9875
# Epoch 400/2000: Train Loss 0.1033 | Test Loss 0.0757 | accs Train 0.9619 Test 0.9890
# Epoch 500/2000: Train Loss 0.0907 | Test Loss 0.0819 | accs Train 0.9595 Test 0.9835
# Epoch 600/2000: Train Loss 0.0852 | Test Loss 0.0690 | accs Train 0.9619 Test 0.9878
# Epoch 700/2000: Train Loss 0.0841 | Test Loss 0.0760 | accs Train 0.9619 Test 0.9858
# Epoch 800/2000: Train Loss 0.0782 | Test Loss 0.0894 | accs Train 0.9619 Test 0.9765
# Epoch 900/2000: Train Loss 0.0766 | Test Loss 0.0772 | accs Train 0.9571 Test 0.9780
# Epoch 1000/2000: Train Loss 0.0736 | Test Loss 0.0739 | accs Train 0.9571 Test 0.9792
# Epoch 1100/2000: Train Loss 0.0763 | Test Loss 0.0885 | accs Train 0.9595 Test 0.9700
# Epoch 1200/2000: Train Loss 0.0707 | Test Loss 0.0772 | accs Train 0.9690 Test 0.9775
# Epoch 1300/2000: Train Loss 0.0723 | Test Loss 0.0931 | accs Train 0.9619 Test 0.9670
# Epoch 1400/2000: Train Loss 0.0683 | Test Loss 0.0811 | accs Train 0.9643 Test 0.9740
# Epoch 1500/2000: Train Loss 0.0652 | Test Loss 0.0943 | accs Train 0.9643 Test 0.9675
# Epoch 1600/2000: Train Loss 0.0661 | Test Loss 0.0945 | accs Train 0.9667 Test 0.9680
# Epoch 1700/2000: Train Loss 0.0656 | Test Loss 0.0721 | accs Train 0.9690 Test 0.9755
# Epoch 1800/2000: Train Loss 0.0627 | Test Loss 0.0717 | accs Train 0.9738 Test 0.9745
# Epoch 1900/2000: Train Loss 0.0605 | Test Loss 0.0714 | accs Train 0.9762 Test 0.9732
# Epoch 2000/2000: Train Loss 0.0585 | Test Loss 0.0781 | accs Train 0.9714 Test 0.9720
# Completed training with 20 additional samples of poison
# Epoch 1/2000: Train Loss 0.7009 | Test Loss 0.6976 | accs Train 0.4956 Test 0.5000
# Epoch 100/2000: Train Loss 0.6014 | Test Loss 0.5645 | accs Train 0.5733 Test 0.6348
# Epoch 200/2000: Train Loss 0.3044 | Test Loss 0.1695 | accs Train 0.8889 Test 0.9818
# Epoch 300/2000: Train Loss 0.2725 | Test Loss 0.1353 | accs Train 0.8911 Test 0.9875
# Epoch 400/2000: Train Loss 0.2495 | Test Loss 0.1352 | accs Train 0.9000 Test 0.9860
# Epoch 500/2000: Train Loss 0.2342 | Test Loss 0.1365 | accs Train 0.9044 Test 0.9805
# Epoch 600/2000: Train Loss 0.2228 | Test Loss 0.1388 | accs Train 0.9000 Test 0.9752
# Epoch 700/2000: Train Loss 0.2167 | Test Loss 0.1469 | accs Train 0.9067 Test 0.9680
# Epoch 800/2000: Train Loss 0.2109 | Test Loss 0.1476 | accs Train 0.9044 Test 0.9673
# Epoch 900/2000: Train Loss 0.2058 | Test Loss 0.1504 | accs Train 0.9111 Test 0.9665
# Epoch 1000/2000: Train Loss 0.2029 | Test Loss 0.1610 | accs Train 0.9178 Test 0.9605
# Epoch 1100/2000: Train Loss 0.1952 | Test Loss 0.1593 | accs Train 0.9178 Test 0.9627
# Epoch 1200/2000: Train Loss 0.1943 | Test Loss 0.1663 | accs Train 0.9200 Test 0.9565
# Epoch 1300/2000: Train Loss 0.1885 | Test Loss 0.1663 | accs Train 0.9178 Test 0.9533
# Epoch 1400/2000: Train Loss 0.1867 | Test Loss 0.1788 | accs Train 0.9178 Test 0.9543
# Epoch 1500/2000: Train Loss 0.1847 | Test Loss 0.1742 | accs Train 0.9156 Test 0.9540
# Epoch 1600/2000: Train Loss 0.1806 | Test Loss 0.1814 | accs Train 0.9222 Test 0.9555
# Epoch 1700/2000: Train Loss 0.1773 | Test Loss 0.1811 | accs Train 0.9178 Test 0.9485
# Epoch 1800/2000: Train Loss 0.1754 | Test Loss 0.1938 | accs Train 0.9244 Test 0.9463
# Epoch 1900/2000: Train Loss 0.1651 | Test Loss 0.2302 | accs Train 0.9267 Test 0.9310
# Epoch 2000/2000: Train Loss 0.1641 | Test Loss 0.2083 | accs Train 0.9244 Test 0.9470
# Completed training with 50 additional samples of poison
# Epoch 1/2000: Train Loss 0.6976 | Test Loss 0.6977 | accs Train 0.5080 Test 0.5000
# Epoch 100/2000: Train Loss 0.6076 | Test Loss 0.5615 | accs Train 0.6680 Test 0.7378
# Epoch 200/2000: Train Loss 0.4396 | Test Loss 0.2829 | accs Train 0.8060 Test 0.9467
# Epoch 300/2000: Train Loss 0.3943 | Test Loss 0.2757 | accs Train 0.8240 Test 0.9163
# Epoch 400/2000: Train Loss 0.3684 | Test Loss 0.2827 | accs Train 0.8320 Test 0.9115
# Epoch 500/2000: Train Loss 0.3505 | Test Loss 0.3071 | accs Train 0.8400 Test 0.8925
# Epoch 600/2000: Train Loss 0.3401 | Test Loss 0.3097 | accs Train 0.8360 Test 0.8962
# Epoch 700/2000: Train Loss 0.3252 | Test Loss 0.3439 | accs Train 0.8460 Test 0.8772
# Epoch 800/2000: Train Loss 0.3185 | Test Loss 0.3483 | accs Train 0.8400 Test 0.8832
# Epoch 900/2000: Train Loss 0.3057 | Test Loss 0.3719 | accs Train 0.8540 Test 0.8765
# Epoch 1000/2000: Train Loss 0.2970 | Test Loss 0.4170 | accs Train 0.8580 Test 0.8578
# Epoch 1100/2000: Train Loss 0.3025 | Test Loss 0.4469 | accs Train 0.8420 Test 0.8568
# Epoch 1200/2000: Train Loss 0.2868 | Test Loss 0.4707 | accs Train 0.8620 Test 0.8470
# Epoch 1300/2000: Train Loss 0.2783 | Test Loss 0.4971 | accs Train 0.8600 Test 0.8323
# Epoch 1400/2000: Train Loss 0.2792 | Test Loss 0.5288 | accs Train 0.8560 Test 0.8377
# Epoch 1500/2000: Train Loss 0.3024 | Test Loss 0.5323 | accs Train 0.8420 Test 0.8468
# Epoch 1600/2000: Train Loss 0.2618 | Test Loss 0.5388 | accs Train 0.8660 Test 0.8560
# Epoch 1700/2000: Train Loss 0.2661 | Test Loss 0.5547 | accs Train 0.8680 Test 0.8353
# Epoch 1800/2000: Train Loss 0.2571 | Test Loss 0.5866 | accs Train 0.8680 Test 0.8538
# Epoch 1900/2000: Train Loss 0.2518 | Test Loss 0.6084 | accs Train 0.8720 Test 0.8370
# Epoch 2000/2000: Train Loss 0.2501 | Test Loss 0.6243 | accs Train 0.8820 Test 0.8452
# Completed training with 100 additional samples of poison

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 0.0391 | accs: 0.9955
#   10 samples | Test Loss: 0.0517 | accs: 0.9828
#   20 samples | Test Loss: 0.0781 | accs: 0.9720
#   50 samples | Test Loss: 0.2083 | accs: 0.9470
#  100 samples | Test Loss: 0.6243 | accs: 0.8452
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: poison, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model   10 | Train Loss: 0.0159 | accs: 0.9950
#  Model   20 | Train Loss: 0.0287 | accs: 0.9900
#  Model   50 | Train Loss: 0.0751 | accs: 0.9900
#  Model  100 | Train Loss: 0.1412 | accs: 0.9650
#
# Dataset type: poison, additional samples: 10
#  Model    0 | Train Loss: 0.3488 | accs: 0.9756
#  Model   10 | Train Loss: 0.0325 | accs: 0.9854
#  Model   20 | Train Loss: 0.0462 | accs: 0.9780
#  Model   50 | Train Loss: 0.0943 | accs: 0.9780
#  Model  100 | Train Loss: 0.1562 | accs: 0.9463
#
# Dataset type: poison, additional samples: 20
#  Model    0 | Train Loss: 0.6882 | accs: 0.9524
#  Model   10 | Train Loss: 0.2262 | accs: 0.9643
#  Model   20 | Train Loss: 0.0584 | accs: 0.9762
#  Model   50 | Train Loss: 0.1122 | accs: 0.9619
#  Model  100 | Train Loss: 0.1679 | accs: 0.9357
#
# Dataset type: poison, additional samples: 50
#  Model    0 | Train Loss: 1.5578 | accs: 0.8889
#  Model   10 | Train Loss: 0.9739 | accs: 0.9000
#  Model   20 | Train Loss: 0.8586 | accs: 0.9111
#  Model   50 | Train Loss: 0.1642 | accs: 0.9289
#  Model  100 | Train Loss: 0.2044 | accs: 0.9111
#
# Dataset type: poison, additional samples: 100
#  Model    0 | Train Loss: 2.7758 | accs: 0.8000
#  Model   10 | Train Loss: 1.8195 | accs: 0.8140
#  Model   20 | Train Loss: 1.9139 | accs: 0.8200
#  Model   50 | Train Loss: 1.0310 | accs: 0.8400
#  Model  100 | Train Loss: 0.2479 | accs: 0.8760

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_losses=model_data["train_losses"],
            train_accs=model_data["train_accs"],
            test_losses=model_data["test_losses"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_10.pt
# Saved model: models_and_data/model_additional_10.pt
# ✅ Model saved to models_and_data\model_additional_20.pt
# Saved model: models_and_data/model_additional_20.pt
# ✅ Model saved to models_and_data\model_additional_50.pt
# Saved model: models_and_data/model_additional_50.pt
# ✅ Model saved to models_and_data\model_additional_100.pt
# Saved model: models_and_data/model_additional_100.pt
