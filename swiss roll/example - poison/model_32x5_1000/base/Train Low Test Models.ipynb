# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 1            # Seed for dataset generation (if applicable)
model_seed = 1           # Seed for model initialization

# --- Training configuration ---
epochs = 2000            # Number of training epochs

# --- Dataset configuration ---
base_data_size = 50      # Base dataset size (small for low-data experiments)
dataset_type = "data"    # Options: "data", "noise"
dataset_quantities = [0, 10, 50, 100, 200, 350, 750]

# --- Output configuration ---
base_output_dir = ""     # Root folder for saving results ("" = current dir)
save_generated_dataset = True   # Save generated datasets to disk
save_generated_models = True    # Save trained models to disk

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

test_dataset_size = 2000

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    base_data_size=base_data_size,
    dataset_quantities=dataset_quantities,
    test_dataset_size=test_dataset_size,
    noise=0.3, # default swiss params
    extra_pts=1000,
    dataset_type=dataset_type,
    seed=data_seed
)

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %%
# Show the names of all parameters first (helps you locate layers)
print("=== Model Parameters ===")
for name, param in model_template.named_parameters():
    print(name, param.shape)

# Example: print first few weights from the first layer
first_layer_weights = next(model_template.parameters()).data
print("\n=== First layer weights (sample) ===")
print(first_layer_weights[:5, :5])  # first 5 rows, first 5 cols

# Example: print biases if available
for name, param in model_template.named_parameters():
    if "bias" in name:
        print(f"\n{name} (first 5 values):")
        print(param.data[:5])
        break
# Out:
# === Model Parameters ===
# model.0.weight torch.Size([32, 2])
# model.0.bias torch.Size([32])
# model.2.weight torch.Size([32, 32])
# model.2.bias torch.Size([32])
# model.4.weight torch.Size([32, 32])
# model.4.bias torch.Size([32])
# model.6.weight torch.Size([32, 32])
# model.6.bias torch.Size([32])
# model.8.weight torch.Size([32, 32])
# model.8.bias torch.Size([32])
# model.10.weight torch.Size([1, 32])
# model.10.bias torch.Size([1])
#
# === First layer weights (sample) ===
# tensor([[ 0.3643, -0.3121],
#         [-0.1371,  0.3319],
#         [-0.6657,  0.4241],
#         [-0.1455,  0.3597],
#         [ 0.0983, -0.0866]], device='cuda:0')
#
# model.0.bias (first 5 values):
# tensor([-0.3964, -0.1164, -0.0137,  0.1033, -0.5366], device='cuda:0')

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_losses, train_other_metrics, test_losses, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_losses": train_losses,
        "test_losses": test_losses,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/2000: Train Loss 0.6951 | Test Loss 0.6917 | accs Train 0.4400 Test 0.4990
# Epoch 100/2000: Train Loss 0.3476 | Test Loss 0.8965 | accs Train 0.8400 Test 0.6218
# Epoch 200/2000: Train Loss 0.0151 | Test Loss 2.4943 | accs Train 1.0000 Test 0.6637
# Epoch 300/2000: Train Loss 0.0023 | Test Loss 3.1072 | accs Train 1.0000 Test 0.6667
# Epoch 400/2000: Train Loss 0.0009 | Test Loss 3.4006 | accs Train 1.0000 Test 0.6680
# Epoch 500/2000: Train Loss 0.0004 | Test Loss 3.5934 | accs Train 1.0000 Test 0.6680
# Epoch 600/2000: Train Loss 0.0003 | Test Loss 3.7346 | accs Train 1.0000 Test 0.6687
# Epoch 700/2000: Train Loss 0.0002 | Test Loss 3.8469 | accs Train 1.0000 Test 0.6700
# Epoch 800/2000: Train Loss 0.0001 | Test Loss 3.9387 | accs Train 1.0000 Test 0.6707
# Epoch 900/2000: Train Loss 0.0001 | Test Loss 4.0171 | accs Train 1.0000 Test 0.6713
# Epoch 1000/2000: Train Loss 0.0001 | Test Loss 4.0856 | accs Train 1.0000 Test 0.6707
# Epoch 1100/2000: Train Loss 0.0001 | Test Loss 4.1472 | accs Train 1.0000 Test 0.6723
# Epoch 1200/2000: Train Loss 0.0001 | Test Loss 4.2019 | accs Train 1.0000 Test 0.6727
# Epoch 1300/2000: Train Loss 0.0000 | Test Loss 4.2514 | accs Train 1.0000 Test 0.6725
# Epoch 1400/2000: Train Loss 0.0000 | Test Loss 4.2959 | accs Train 1.0000 Test 0.6727
# Epoch 1500/2000: Train Loss 0.0000 | Test Loss 4.3369 | accs Train 1.0000 Test 0.6730
# Epoch 1600/2000: Train Loss 0.0000 | Test Loss 4.3753 | accs Train 1.0000 Test 0.6733
# Epoch 1700/2000: Train Loss 0.0000 | Test Loss 4.4101 | accs Train 1.0000 Test 0.6735
# Epoch 1800/2000: Train Loss 0.0000 | Test Loss 4.4446 | accs Train 1.0000 Test 0.6740
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 4.4761 | accs Train 1.0000 Test 0.6743
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 4.5057 | accs Train 1.0000 Test 0.6743
# Completed training with 0 additional samples of data
# Epoch 1/2000: Train Loss 0.6956 | Test Loss 0.6916 | accs Train 0.4333 Test 0.4918
# Epoch 100/2000: Train Loss 0.3093 | Test Loss 0.9380 | accs Train 0.9167 Test 0.6583
# Epoch 200/2000: Train Loss 0.0093 | Test Loss 2.2031 | accs Train 1.0000 Test 0.6823
# Epoch 300/2000: Train Loss 0.0017 | Test Loss 2.7183 | accs Train 1.0000 Test 0.6877
# Epoch 400/2000: Train Loss 0.0007 | Test Loss 2.9691 | accs Train 1.0000 Test 0.6877
# Epoch 500/2000: Train Loss 0.0004 | Test Loss 3.1354 | accs Train 1.0000 Test 0.6887
# Epoch 600/2000: Train Loss 0.0002 | Test Loss 3.2538 | accs Train 1.0000 Test 0.6895
# Epoch 700/2000: Train Loss 0.0002 | Test Loss 3.3488 | accs Train 1.0000 Test 0.6897
# Epoch 800/2000: Train Loss 0.0001 | Test Loss 3.4230 | accs Train 1.0000 Test 0.6905
# Epoch 900/2000: Train Loss 0.0001 | Test Loss 3.4858 | accs Train 1.0000 Test 0.6910
# Epoch 1000/2000: Train Loss 0.0001 | Test Loss 3.5433 | accs Train 1.0000 Test 0.6917
# Epoch 1100/2000: Train Loss 0.0001 | Test Loss 3.5920 | accs Train 1.0000 Test 0.6925
# Epoch 1200/2000: Train Loss 0.0001 | Test Loss 3.6356 | accs Train 1.0000 Test 0.6927
# Epoch 1300/2000: Train Loss 0.0000 | Test Loss 3.6772 | accs Train 1.0000 Test 0.6925
# Epoch 1400/2000: Train Loss 0.0000 | Test Loss 3.7137 | accs Train 1.0000 Test 0.6925
# Epoch 1500/2000: Train Loss 0.0000 | Test Loss 3.7490 | accs Train 1.0000 Test 0.6925
# Epoch 1600/2000: Train Loss 0.0000 | Test Loss 3.7795 | accs Train 1.0000 Test 0.6925
# Epoch 1700/2000: Train Loss 0.0000 | Test Loss 3.8088 | accs Train 1.0000 Test 0.6927
# Epoch 1800/2000: Train Loss 0.0000 | Test Loss 3.8358 | accs Train 1.0000 Test 0.6927
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 3.8597 | accs Train 1.0000 Test 0.6935
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 3.8848 | accs Train 1.0000 Test 0.6937
# Completed training with 10 additional samples of data
# Epoch 1/2000: Train Loss 0.6938 | Test Loss 0.6914 | accs Train 0.4800 Test 0.4873
# Epoch 100/2000: Train Loss 0.4712 | Test Loss 0.6165 | accs Train 0.7600 Test 0.5978
# Epoch 200/2000: Train Loss 0.0828 | Test Loss 0.6118 | accs Train 0.9800 Test 0.8400
# Epoch 300/2000: Train Loss 0.0054 | Test Loss 0.6832 | accs Train 1.0000 Test 0.8785
# Epoch 400/2000: Train Loss 0.0015 | Test Loss 0.8109 | accs Train 1.0000 Test 0.8768
# Epoch 500/2000: Train Loss 0.0007 | Test Loss 0.8740 | accs Train 1.0000 Test 0.8780
# Epoch 600/2000: Train Loss 0.0004 | Test Loss 0.9284 | accs Train 1.0000 Test 0.8740
# Epoch 700/2000: Train Loss 0.0002 | Test Loss 0.9641 | accs Train 1.0000 Test 0.8742
# Epoch 800/2000: Train Loss 0.0002 | Test Loss 0.9863 | accs Train 1.0000 Test 0.8740
# Epoch 900/2000: Train Loss 0.0001 | Test Loss 1.0066 | accs Train 1.0000 Test 0.8742
# Epoch 1000/2000: Train Loss 0.0001 | Test Loss 1.0282 | accs Train 1.0000 Test 0.8745
# Epoch 1100/2000: Train Loss 0.0001 | Test Loss 1.0437 | accs Train 1.0000 Test 0.8732
# Epoch 1200/2000: Train Loss 0.0001 | Test Loss 1.0570 | accs Train 1.0000 Test 0.8750
# Epoch 1300/2000: Train Loss 0.0001 | Test Loss 1.0684 | accs Train 1.0000 Test 0.8735
# Epoch 1400/2000: Train Loss 0.0000 | Test Loss 1.0797 | accs Train 1.0000 Test 0.8742
# Epoch 1500/2000: Train Loss 0.0000 | Test Loss 1.0896 | accs Train 1.0000 Test 0.8742
# Epoch 1600/2000: Train Loss 0.0000 | Test Loss 1.0993 | accs Train 1.0000 Test 0.8742
# Epoch 1700/2000: Train Loss 0.0000 | Test Loss 1.1079 | accs Train 1.0000 Test 0.8740
# Epoch 1800/2000: Train Loss 0.0000 | Test Loss 1.1158 | accs Train 1.0000 Test 0.8740
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 1.1236 | accs Train 1.0000 Test 0.8740
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 1.1306 | accs Train 1.0000 Test 0.8740
# Completed training with 50 additional samples of data
# Epoch 1/2000: Train Loss 0.6922 | Test Loss 0.6915 | accs Train 0.5067 Test 0.4793
# Epoch 100/2000: Train Loss 0.5371 | Test Loss 0.5910 | accs Train 0.6600 Test 0.6392
# Epoch 200/2000: Train Loss 0.0672 | Test Loss 0.2089 | accs Train 0.9800 Test 0.9365
# Epoch 300/2000: Train Loss 0.0034 | Test Loss 0.1502 | accs Train 1.0000 Test 0.9750
# Epoch 400/2000: Train Loss 0.0010 | Test Loss 0.1587 | accs Train 1.0000 Test 0.9750
# Epoch 500/2000: Train Loss 0.0005 | Test Loss 0.1667 | accs Train 1.0000 Test 0.9758
# Epoch 600/2000: Train Loss 0.0003 | Test Loss 0.1725 | accs Train 1.0000 Test 0.9758
# Epoch 700/2000: Train Loss 0.0002 | Test Loss 0.1774 | accs Train 1.0000 Test 0.9760
# Epoch 800/2000: Train Loss 0.0001 | Test Loss 0.1815 | accs Train 1.0000 Test 0.9768
# Epoch 900/2000: Train Loss 0.0001 | Test Loss 0.1851 | accs Train 1.0000 Test 0.9770
# Epoch 1000/2000: Train Loss 0.0001 | Test Loss 0.1885 | accs Train 1.0000 Test 0.9770
# Epoch 1100/2000: Train Loss 0.0001 | Test Loss 0.1916 | accs Train 1.0000 Test 0.9770
# Epoch 1200/2000: Train Loss 0.0001 | Test Loss 0.1945 | accs Train 1.0000 Test 0.9772
# Epoch 1300/2000: Train Loss 0.0000 | Test Loss 0.1970 | accs Train 1.0000 Test 0.9772
# Epoch 1400/2000: Train Loss 0.0000 | Test Loss 0.1998 | accs Train 1.0000 Test 0.9775
# Epoch 1500/2000: Train Loss 0.0000 | Test Loss 0.2023 | accs Train 1.0000 Test 0.9775
# Epoch 1600/2000: Train Loss 0.0000 | Test Loss 0.2046 | accs Train 1.0000 Test 0.9775
# Epoch 1700/2000: Train Loss 0.0000 | Test Loss 0.2067 | accs Train 1.0000 Test 0.9775
# Epoch 1800/2000: Train Loss 0.0000 | Test Loss 0.2087 | accs Train 1.0000 Test 0.9775
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 0.2105 | accs Train 1.0000 Test 0.9775
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 0.2121 | accs Train 1.0000 Test 0.9775
# Completed training with 100 additional samples of data
# Epoch 1/2000: Train Loss 0.6928 | Test Loss 0.6914 | accs Train 0.4960 Test 0.4833
# Epoch 100/2000: Train Loss 0.5604 | Test Loss 0.5778 | accs Train 0.6400 Test 0.6435
# Epoch 200/2000: Train Loss 0.0115 | Test Loss 0.0476 | accs Train 1.0000 Test 0.9852
# Epoch 300/2000: Train Loss 0.0014 | Test Loss 0.0276 | accs Train 1.0000 Test 0.9928
# Epoch 400/2000: Train Loss 0.0006 | Test Loss 0.0245 | accs Train 1.0000 Test 0.9932
# Epoch 500/2000: Train Loss 0.0003 | Test Loss 0.0231 | accs Train 1.0000 Test 0.9940
# Epoch 600/2000: Train Loss 0.0002 | Test Loss 0.0218 | accs Train 1.0000 Test 0.9950
# Epoch 700/2000: Train Loss 0.0001 | Test Loss 0.0214 | accs Train 1.0000 Test 0.9955
# Epoch 800/2000: Train Loss 0.0001 | Test Loss 0.0211 | accs Train 1.0000 Test 0.9955
# Epoch 900/2000: Train Loss 0.0001 | Test Loss 0.0208 | accs Train 1.0000 Test 0.9955
# Epoch 1000/2000: Train Loss 0.0001 | Test Loss 0.0206 | accs Train 1.0000 Test 0.9955
# Epoch 1100/2000: Train Loss 0.0001 | Test Loss 0.0205 | accs Train 1.0000 Test 0.9958
# Epoch 1200/2000: Train Loss 0.0000 | Test Loss 0.0204 | accs Train 1.0000 Test 0.9958
# Epoch 1300/2000: Train Loss 0.0000 | Test Loss 0.0203 | accs Train 1.0000 Test 0.9960
# Epoch 1400/2000: Train Loss 0.0000 | Test Loss 0.0202 | accs Train 1.0000 Test 0.9962
# Epoch 1500/2000: Train Loss 0.0000 | Test Loss 0.0201 | accs Train 1.0000 Test 0.9962
# Epoch 1600/2000: Train Loss 0.0000 | Test Loss 0.0201 | accs Train 1.0000 Test 0.9962
# Epoch 1700/2000: Train Loss 0.0000 | Test Loss 0.0201 | accs Train 1.0000 Test 0.9962
# Epoch 1800/2000: Train Loss 0.0000 | Test Loss 0.0201 | accs Train 1.0000 Test 0.9962
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 0.0201 | accs Train 1.0000 Test 0.9962
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 0.0199 | accs Train 1.0000 Test 0.9962
# Completed training with 200 additional samples of data
# Epoch 1/2000: Train Loss 0.6934 | Test Loss 0.6913 | accs Train 0.4775 Test 0.5088
# Epoch 100/2000: Train Loss 0.5747 | Test Loss 0.5839 | accs Train 0.6500 Test 0.6640
# Epoch 200/2000: Train Loss 0.0219 | Test Loss 0.0397 | accs Train 1.0000 Test 0.9950
# Epoch 300/2000: Train Loss 0.0012 | Test Loss 0.0069 | accs Train 1.0000 Test 0.9980
# Epoch 400/2000: Train Loss 0.0004 | Test Loss 0.0054 | accs Train 1.0000 Test 0.9982
# Epoch 500/2000: Train Loss 0.0002 | Test Loss 0.0052 | accs Train 1.0000 Test 0.9982
# Epoch 600/2000: Train Loss 0.0001 | Test Loss 0.0051 | accs Train 1.0000 Test 0.9982
# Epoch 700/2000: Train Loss 0.0001 | Test Loss 0.0050 | accs Train 1.0000 Test 0.9982
# Epoch 800/2000: Train Loss 0.0001 | Test Loss 0.0050 | accs Train 1.0000 Test 0.9982
# Epoch 900/2000: Train Loss 0.0001 | Test Loss 0.0051 | accs Train 1.0000 Test 0.9982
# Epoch 1000/2000: Train Loss 0.0000 | Test Loss 0.0052 | accs Train 1.0000 Test 0.9982
# Epoch 1100/2000: Train Loss 0.0000 | Test Loss 0.0052 | accs Train 1.0000 Test 0.9982
# Epoch 1200/2000: Train Loss 0.0000 | Test Loss 0.0053 | accs Train 1.0000 Test 0.9982
# Epoch 1300/2000: Train Loss 0.0000 | Test Loss 0.0053 | accs Train 1.0000 Test 0.9985
# Epoch 1400/2000: Train Loss 0.0000 | Test Loss 0.0054 | accs Train 1.0000 Test 0.9982
# Epoch 1500/2000: Train Loss 0.0000 | Test Loss 0.0055 | accs Train 1.0000 Test 0.9982
# Epoch 1600/2000: Train Loss 0.0000 | Test Loss 0.0055 | accs Train 1.0000 Test 0.9982
# Epoch 1700/2000: Train Loss 0.0000 | Test Loss 0.0055 | accs Train 1.0000 Test 0.9985
# Epoch 1800/2000: Train Loss 0.0000 | Test Loss 0.0056 | accs Train 1.0000 Test 0.9985
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 0.0056 | accs Train 1.0000 Test 0.9985
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 0.0056 | accs Train 1.0000 Test 0.9985
# Completed training with 350 additional samples of data
# Epoch 1/2000: Train Loss 0.6933 | Test Loss 0.6913 | accs Train 0.4813 Test 0.4998
# Epoch 100/2000: Train Loss 0.5882 | Test Loss 0.5838 | accs Train 0.6412 Test 0.6647
# Epoch 200/2000: Train Loss 0.0175 | Test Loss 0.0211 | accs Train 0.9988 Test 0.9978
# Epoch 300/2000: Train Loss 0.0019 | Test Loss 0.0043 | accs Train 1.0000 Test 0.9988
# Epoch 400/2000: Train Loss 0.0007 | Test Loss 0.0027 | accs Train 1.0000 Test 0.9990
# Epoch 500/2000: Train Loss 0.0002 | Test Loss 0.0026 | accs Train 1.0000 Test 0.9990
# Epoch 600/2000: Train Loss 0.0001 | Test Loss 0.0029 | accs Train 1.0000 Test 0.9990
# Epoch 700/2000: Train Loss 0.0001 | Test Loss 0.0030 | accs Train 1.0000 Test 0.9988
# Epoch 800/2000: Train Loss 0.0000 | Test Loss 0.0029 | accs Train 1.0000 Test 0.9988
# Epoch 900/2000: Train Loss 0.0000 | Test Loss 0.0029 | accs Train 1.0000 Test 0.9988
# Epoch 1000/2000: Train Loss 0.0000 | Test Loss 0.0029 | accs Train 1.0000 Test 0.9990
# Epoch 1100/2000: Train Loss 0.0000 | Test Loss 0.0029 | accs Train 1.0000 Test 0.9990
# Epoch 1200/2000: Train Loss 0.0000 | Test Loss 0.0029 | accs Train 1.0000 Test 0.9990
# Epoch 1300/2000: Train Loss 0.0000 | Test Loss 0.0029 | accs Train 1.0000 Test 0.9990
# Epoch 1400/2000: Train Loss 0.0000 | Test Loss 0.0029 | accs Train 1.0000 Test 0.9992
# Epoch 1500/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9992
# Epoch 1600/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9992
# Epoch 1700/2000: Train Loss 0.0000 | Test Loss 0.0027 | accs Train 1.0000 Test 0.9992
# Epoch 1800/2000: Train Loss 0.0000 | Test Loss 0.0027 | accs Train 1.0000 Test 0.9992
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 0.0026 | accs Train 1.0000 Test 0.9992
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 0.0026 | accs Train 1.0000 Test 0.9992
# Completed training with 750 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 4.5057 | accs: 0.6743
#   10 samples | Test Loss: 3.8848 | accs: 0.6937
#   50 samples | Test Loss: 1.1306 | accs: 0.8740
#  100 samples | Test Loss: 0.2121 | accs: 0.9775
#  200 samples | Test Loss: 0.0199 | accs: 0.9962
#  350 samples | Test Loss: 0.0056 | accs: 0.9985
#  750 samples | Test Loss: 0.0026 | accs: 0.9992
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model   10 | Train Loss: 0.0000 | accs: 1.0000
#  Model   50 | Train Loss: 0.0000 | accs: 1.0000
#  Model  100 | Train Loss: 0.0000 | accs: 1.0000
#  Model  200 | Train Loss: 0.0000 | accs: 1.0000
#  Model  350 | Train Loss: 0.0000 | accs: 1.0000
#  Model  750 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 10
#  Model    0 | Train Loss: 0.0235 | accs: 0.9833
#  Model   10 | Train Loss: 0.0000 | accs: 1.0000
#  Model   50 | Train Loss: 0.0000 | accs: 1.0000
#  Model  100 | Train Loss: 0.0000 | accs: 1.0000
#  Model  200 | Train Loss: 0.0000 | accs: 1.0000
#  Model  350 | Train Loss: 0.0000 | accs: 1.0000
#  Model  750 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 50
#  Model    0 | Train Loss: 1.4443 | accs: 0.8700
#  Model   10 | Train Loss: 1.3407 | accs: 0.8900
#  Model   50 | Train Loss: 0.0000 | accs: 1.0000
#  Model  100 | Train Loss: 0.0000 | accs: 1.0000
#  Model  200 | Train Loss: 0.0000 | accs: 1.0000
#  Model  350 | Train Loss: 0.0000 | accs: 1.0000
#  Model  750 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 100
#  Model    0 | Train Loss: 2.9089 | accs: 0.7933
#  Model   10 | Train Loss: 2.5618 | accs: 0.8267
#  Model   50 | Train Loss: 1.0657 | accs: 0.8800
#  Model  100 | Train Loss: 0.0000 | accs: 1.0000
#  Model  200 | Train Loss: 0.0000 | accs: 1.0000
#  Model  350 | Train Loss: 0.0000 | accs: 1.0000
#  Model  750 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 200
#  Model    0 | Train Loss: 3.0480 | accs: 0.7760
#  Model   10 | Train Loss: 2.6681 | accs: 0.7960
#  Model   50 | Train Loss: 0.9047 | accs: 0.8960
#  Model  100 | Train Loss: 0.0967 | accs: 0.9840
#  Model  200 | Train Loss: 0.0000 | accs: 1.0000
#  Model  350 | Train Loss: 0.0000 | accs: 1.0000
#  Model  750 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 350
#  Model    0 | Train Loss: 3.2166 | accs: 0.7550
#  Model   10 | Train Loss: 2.7833 | accs: 0.7850
#  Model   50 | Train Loss: 0.9480 | accs: 0.9025
#  Model  100 | Train Loss: 0.1379 | accs: 0.9825
#  Model  200 | Train Loss: 0.0025 | accs: 1.0000
#  Model  350 | Train Loss: 0.0000 | accs: 1.0000
#  Model  750 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 750
#  Model    0 | Train Loss: 3.5684 | accs: 0.7362
#  Model   10 | Train Loss: 3.1190 | accs: 0.7612
#  Model   50 | Train Loss: 0.9873 | accs: 0.8850
#  Model  100 | Train Loss: 0.2302 | accs: 0.9750
#  Model  200 | Train Loss: 0.0212 | accs: 0.9975
#  Model  350 | Train Loss: 0.0204 | accs: 0.9975
#  Model  750 | Train Loss: 0.0000 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_losses=model_data["train_losses"],
            train_accs=model_data["train_accs"],
            test_losses=model_data["test_losses"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_10.pt
# Saved model: models_and_data/model_additional_10.pt
# ✅ Model saved to models_and_data\model_additional_50.pt
# Saved model: models_and_data/model_additional_50.pt
# ✅ Model saved to models_and_data\model_additional_100.pt
# Saved model: models_and_data/model_additional_100.pt
# ✅ Model saved to models_and_data\model_additional_200.pt
# Saved model: models_and_data/model_additional_200.pt
# ✅ Model saved to models_and_data\model_additional_350.pt
# Saved model: models_and_data/model_additional_350.pt
# ✅ Model saved to models_and_data\model_additional_750.pt
# Saved model: models_and_data/model_additional_750.pt
