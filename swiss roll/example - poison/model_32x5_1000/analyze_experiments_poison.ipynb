# %% [markdown]
# # Comparisons In A Given Loss Landscape

# %%
import os
import json
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

from minima_volume.analysis_funcs import (  grab_folder_names,
                                            load_base_train_size,
                                            list_additional_data,
                                            load_param_num,
                                            multiple_minima_fixed_landscape,
                                            fixed_landscape_minima_labels,
                                            plot_fixed_landscape_minima_pair,
                                            plot_perturb_probs,
                                            model_volume_across_targets,
                                            append_cutoff_points,
                                            varying_landscape_minima_labels,
                                            plot_minima_volume_vs_data_level,                    
)

loss_value = 0.1  # Loss value to analyze
data_level_log = False #Is the data log distributed?
base_output_dir = "analysis"  # Root folder to save all plots
os.makedirs(base_output_dir, exist_ok=True)

# Data for the loss landscape levels
experiment_folders, data_modifications = grab_folder_names()

base_train_size = load_base_train_size(experiment_folders[0])
model_data_sizes = list_additional_data(experiment_folders[0])
num_params = load_param_num(experiment_folders[0], data_modifications[0], loss_value = loss_value)

base_shift = 0
if data_modifications[0].startswith("data_"):
    base_shift = base_train_size  # Shift to reflect true dataset size

print("Experiment folders: ", experiment_folders)
print("Different data levels where loss landscapes were computed:", data_modifications)
print("The base train size is: ", base_train_size)
print("Data levels where models were trained: ", model_data_sizes)
print("The number of model parameters is ", num_params)
# Out:
# First entry: Model_0, base_train_size = 400
# Experiment folders:  ['model_0_data_0', 'model_1_data_1', 'model_2_data_2', 'model_3_data_3', 'model_4_data_4', 'model_5_data_5', 'model_6_data_6', 'model_7_data_7', 'model_8_data_8', 'model_9_data_9']
# Different data levels where loss landscapes were computed: ['poison_0']
# The base train size is:  400
# Data levels where models were trained:  [0, 10, 100, 20, 50]
# The number of model parameters is  4353

# %% [markdown]
# ## Plotting Different Model Volumes In A Landscape

# %%
# Preparation for the specific plots
import matplotlib as mpl

#cmap = mpl.colormaps.get_cmap("winter")  # blue → green
#background_colors = [cmap(i) for i in np.linspace(0, 1, 10)]

#natural_label = "Minima (On Base Dataset)"
other_label = "Minima (Poisoned Datasets)"

# %%
for data_modification in data_modifications:
    print(f"\nProcessing data modification folder: {data_modification}")

    # Create output folder for this data_modification
    save_dir = os.path.join(base_output_dir, data_modification)
    os.makedirs(save_dir, exist_ok=True)

    # Get axis labels and titles
    labels = fixed_landscape_minima_labels(data_modification, base_train_size)

    # Extract minima landscapes
    all_mdl, all_log_rn, all_test_loss = multiple_minima_fixed_landscape(
        experiment_folders, data_modification, loss_value #mdl is modification data level
    )
    number_of_minima = len(all_mdl[0]) # Not used currently

    all_mdl = np.array(all_mdl)
    all_log_rn = np.array(all_log_rn)
    all_test_loss = np.array(all_test_loss)
    
    # Print types and shapes
    #for name, var in [("all_mdl", all_mdl), ("all_log_rn", all_log_rn), ("all_test_loss", all_test_loss)]:
    #    print(f"{name}: type={type(var)}, shape={var.shape}")

    # Save the data using np.savez_compressed
    save_dict = {
        'all_mdl': all_mdl,
        'all_log_rn': all_log_rn,
        'all_test_loss': all_test_loss,
        'data_modification': np.array([data_modification], dtype=object),
        'base_train_size': np.array([base_train_size]),
        'base_shift': np.array([base_shift]),
        'labels': labels
    }
    
    output_path = save_dir
    filename = 'minima_data.npz'
    np.savez_compressed(os.path.join(output_path, filename), **save_dict)
    
    print(f"Saved data to {os.path.join(output_path, filename)}")
    
    # Central tendency runs: mean and median
    for ct, suffix in [("mean", "_avg"), ("median", "_median")]:
        for ranking in [False, True]:
            out_dir = save_dir if not ranking else os.path.join(save_dir, "ranks") #handles ranking
            os.makedirs(out_dir, exist_ok=True)

            # --- Data-level plots: loop through shaded + errorbar ---
            #for avg_style in ["shaded", "errorbar"]:
            #    style_suffix = "_shaded" if avg_style == "shaded" else "_errbar"
            style_suffix = "_errbar"
            avg_style = "errorbar"

            # --- Data level vs Log Volume ---
            plot_fixed_landscape_minima_pair(
                all_mdl, all_log_rn,
                xlabel="# of Additional Poisoned Examples", ylabel="Log Volume",
                title=f"Swiss Roll Minima Volumes\n In {base_train_size + int(data_modification.split("_")[1])} Example Loss Landscape",
                #labels["title_volume"],
                log_scale=data_level_log,
                ranking=ranking,
                alpha=0.7,
                output_dir=out_dir,
                filename="data_level_vs_log_volume" + suffix + style_suffix,
                show_plot=not ranking,
                plot_average=True,
                average_style=avg_style,
                central_tendency=ct,
                plot_x_error=(avg_style == "errorbar"),
                xlabel_size=14, ylabel_size=14, title_size=17,
                base_shift=base_shift,
                background_colors=None,#background_colors,         
                natural_label=f"Minima (Trained On {base_train_size + int(data_modification.split("_")[1])} Examples)",
                other_label=other_label,               
                natural_marker="^",            
                other_marker="o",               
            )

            # --- Data level vs Test Loss ---
            plot_fixed_landscape_minima_pair(
                all_mdl, all_test_loss,
                xlabel="# of Additional Poisoned Examples", ylabel="Test Loss",
                title=f"Swiss Roll Test Loss vs Dataset Size",#labels["title_volume"],
                log_scale=False,
                ranking=ranking,
                alpha=0.5,
                output_dir=out_dir,
                filename="data_level_vs_test_loss" + suffix + style_suffix,
                show_plot=not ranking,
                plot_average=True,
                average_style=avg_style,
                central_tendency=ct,
                plot_x_error=(avg_style == "errorbar"),
                xlabel_size=14, ylabel_size=14, title_size=17,
                base_shift=base_shift,
                background_colors=None,#background_colors,         
                natural_label=f"Minima (Trained On {base_train_size + int(data_modification.split("_")[1])} Examples)", 
                other_label=other_label,               
                natural_marker="^",            
                other_marker="o",               
            )

            # --- Log Volume vs Test Loss ---
            # Only error bar version (no shaded version)
            plot_fixed_landscape_minima_pair(
                all_log_rn, all_test_loss,
                xlabel="Log Volume", ylabel="Test Loss",
                title=f"Swiss Roll Minima Volumes\n In {base_train_size + int(data_modification.split("_")[1])} Example Loss Landscape",
                #labels["title_volume"],
                log_scale=False,
                ranking=ranking,
                alpha=0.5,
                output_dir=out_dir,
                filename="log_volume_vs_test_loss" + suffix + "_errbar",
                show_plot=not ranking,
                plot_average=True,
                average_style="errorbar",
                central_tendency=ct,
                plot_x_error=True,  # allow x-error bars
                xlabel_size=14, ylabel_size=14, title_size=17,
                background_colors=None,#background_colors,         
                natural_label=f"Minima (Trained On {base_train_size + int(data_modification.split("_")[1])} Examples)", 
                other_label=other_label,               
                natural_marker="^",            
                other_marker="o",               
            )
# Out:
# Processing data modification folder: poison_0
# Saved data to analysis\poison_0\minima_data.npz
# ⚠️ Inf detected in y_vals: [ 6952.87447879  1820.36282202   558.75718514 -1774.51195514
#            -inf]
# ⚠️ Inf detected in y_vals: [6207.01207358 2952.85051915 1739.18922837 -873.84997472          -inf]
# ⚠️ Inf detected in y_vals: [ 6258.34436253  1813.9676638   1210.44452633 -1798.17381682
#            -inf]
# ⚠️ Inf detected in y_vals: [ 6301.43796696  3378.93849069  1205.30678292 -2626.08494627
#            -inf]
# ⚠️ Inf detected in y_vals: [ 5163.57883128  5481.68619871   577.65184108 -1778.42470402
#            -inf]
# ⚠️ Inf detected in y_vals: [ 5179.10635969  2318.83359681   -94.51866893 -2626.71620603
#            -inf]
# ⚠️ Inf detected in y_vals: [6913.51566842 3874.76144853  617.34425186 -963.50993376          -inf]
# ⚠️ Inf detected in y_vals: [6792.76266981 2883.66909476 1204.1956389  -178.1710429           -inf]
# ⚠️ Inf detected in y_vals: [ 5464.84768284  2863.53069166   546.78641841 -2615.91725223
#            -inf]
# ⚠️ Inf detected in y_vals: [6600.45007585 1237.91339353 1212.95140822 -918.00074234          -inf]
# L:\Programming\diffusion-env\Lib\site-packages\numpy\core\_methods.py:173: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# ⚠️ Inf detected in x_vals: [ 6952.87447879  1820.36282202   558.75718514 -1774.51195514
#            -inf]
# ⚠️ Inf detected in x_vals: [6207.01207358 2952.85051915 1739.18922837 -873.84997472          -inf]
# ⚠️ Inf detected in x_vals: [ 6258.34436253  1813.9676638   1210.44452633 -1798.17381682
#            -inf]
# ⚠️ Inf detected in x_vals: [ 6301.43796696  3378.93849069  1205.30678292 -2626.08494627
#            -inf]
# ⚠️ Inf detected in x_vals: [ 5163.57883128  5481.68619871   577.65184108 -1778.42470402
#            -inf]
# ⚠️ Inf detected in x_vals: [ 5179.10635969  2318.83359681   -94.51866893 -2626.71620603
#            -inf]
# ⚠️ Inf detected in x_vals: [6913.51566842 3874.76144853  617.34425186 -963.50993376          -inf]
# ⚠️ Inf detected in x_vals: [6792.76266981 2883.66909476 1204.1956389  -178.1710429           -inf]
# ⚠️ Inf detected in x_vals: [ 5464.84768284  2863.53069166   546.78641841 -2615.91725223
#            -inf]
# ⚠️ Inf detected in x_vals: [6600.45007585 1237.91339353 1212.95140822 -918.00074234          -inf]
# ⚠️ Inf detected in y_vals: [ 6952.87447879  1820.36282202   558.75718514 -1774.51195514
#            -inf]
# ⚠️ Inf detected in y_vals: [6207.01207358 2952.85051915 1739.18922837 -873.84997472          -inf]
# ⚠️ Inf detected in y_vals: [ 6258.34436253  1813.9676638   1210.44452633 -1798.17381682
#            -inf]
# ⚠️ Inf detected in y_vals: [ 6301.43796696  3378.93849069  1205.30678292 -2626.08494627
#            -inf]
# ⚠️ Inf detected in y_vals: [ 5163.57883128  5481.68619871   577.65184108 -1778.42470402
#            -inf]
# ⚠️ Inf detected in y_vals: [ 5179.10635969  2318.83359681   -94.51866893 -2626.71620603
#            -inf]
# ⚠️ Inf detected in y_vals: [6913.51566842 3874.76144853  617.34425186 -963.50993376          -inf]
# ⚠️ Inf detected in y_vals: [6792.76266981 2883.66909476 1204.1956389  -178.1710429           -inf]
# ⚠️ Inf detected in y_vals: [ 5464.84768284  2863.53069166   546.78641841 -2615.91725223
#            -inf]
# ⚠️ Inf detected in y_vals: [6600.45007585 1237.91339353 1212.95140822 -918.00074234          -inf]
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# ⚠️ Inf detected in x_vals: [ 6952.87447879  1820.36282202   558.75718514 -1774.51195514
#            -inf]
# ⚠️ Inf detected in x_vals: [6207.01207358 2952.85051915 1739.18922837 -873.84997472          -inf]
# ⚠️ Inf detected in x_vals: [ 6258.34436253  1813.9676638   1210.44452633 -1798.17381682
#            -inf]
# ⚠️ Inf detected in x_vals: [ 6301.43796696  3378.93849069  1205.30678292 -2626.08494627
#            -inf]
# ⚠️ Inf detected in x_vals: [ 5163.57883128  5481.68619871   577.65184108 -1778.42470402
#            -inf]
# ⚠️ Inf detected in x_vals: [ 5179.10635969  2318.83359681   -94.51866893 -2626.71620603
#            -inf]
# ⚠️ Inf detected in x_vals: [6913.51566842 3874.76144853  617.34425186 -963.50993376          -inf]
# ⚠️ Inf detected in x_vals: [6792.76266981 2883.66909476 1204.1956389  -178.1710429           -inf]
# ⚠️ Inf detected in x_vals: [ 5464.84768284  2863.53069166   546.78641841 -2615.91725223
#            -inf]
# ⚠️ Inf detected in x_vals: [6600.45007585 1237.91339353 1212.95140822 -918.00074234          -inf]

# %% [markdown]
# # Aggregrate Test Accuracy
#
# Test accuracy vs dataset size across all plots.

# %%
missing_folders = [folder for folder in experiment_folders
                   if not os.path.exists(os.path.join(folder, "test_accuracies.npz"))]

if missing_folders:
    print(f"⚠️ Skipping aggregation — missing test_accuracies.npz in: {missing_folders}")
else:
    # ---------- Step 2: Load all data ----------
    all_dataset_sizes = []
    all_accuracies = []

    for folder in experiment_folders:
        file_path = os.path.join(folder, "test_accuracies.npz")
        data = np.load(file_path)
        all_dataset_sizes.extend(data["dataset_sizes"])
        all_accuracies.extend(data["final_test_accuracies"])

    all_dataset_sizes = np.array(all_dataset_sizes)
    all_accuracies = np.array(all_accuracies)

    # ---------- Step 3: Group by dataset size ----------
    grouped_data = defaultdict(list)
    for size, acc in zip(all_dataset_sizes, all_accuracies):
        grouped_data[size].append(acc)

    sorted_sizes = np.array(sorted(grouped_data.keys()))
    mean_accs = np.array([np.mean(grouped_data[size]) for size in sorted_sizes])
    std_accs = np.array([np.std(grouped_data[size]) for size in sorted_sizes])

    # ---------- Step 4: Plot with error bars ----------
    plt.figure(figsize=(10, 6))
    plt.errorbar(
        sorted_sizes, mean_accs, yerr=std_accs,
        fmt='o-', capsize=4, linewidth=2, markersize=8,
        color='tab:blue', ecolor='black', elinewidth=1, alpha=0.8
    )

    plt.xlabel("Training Dataset Size", fontsize=12)
    plt.ylabel("Final Test Accuracy", fontsize=12)
    plt.title("Test Accuracy vs. Dataset Size (Mean ± Std)", fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.ylim((0.5, 1.0))
    plt.tight_layout()

    os.makedirs(base_output_dir, exist_ok=True)
    plot_path = os.path.join(base_output_dir, "test_acc_plot.png")
    plt.savefig(plot_path, bbox_inches="tight")
    plt.show()
    plt.close()

    print(f"✅ Plot saved to {plot_path}")

    # ---------- Step 5: Save combined data ----------
    save_path = os.path.join(base_output_dir, "test_acc.npz")
    np.savez(
        save_path,
        dataset_sizes=sorted_sizes,
        mean_accuracies=mean_accs,
        std_accuracies=std_accs,
        all_dataset_sizes=all_dataset_sizes,
        all_accuracies=all_accuracies
    )
    print(f"✅ Aggregated data saved to {save_path}")
# Out:
# ✅ Plot saved to analysis\test_acc_plot.png
# ✅ Aggregated data saved to analysis\test_acc.npz

# %% [markdown]
# # Comparisons Across Loss Landscapes

# %% [markdown]
# Here, we track the performance of all models across all loss landscapes.

# %%
# For the poisoning experiments, this plot has no meaning

labels = varying_landscape_minima_labels(
    data_modification_folder=data_modifications[0], # Random choice to grab datatype from
    base_train_size=base_train_size,
)

results_dict = model_volume_across_targets(
    target_model_data_levels=model_data_sizes,
    loss_value=loss_value,
    experiment_folders=experiment_folders
)
results_with_cutoff = append_cutoff_points(results_dict, threshold=loss_value, base_dir=".")

found_minima_vol, found_minima_dataset = plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],        
    base_train_size=base_train_size, 
    xlabel="# Of Examples In Loss Landscape",
    ylabel="Log Volume",
    title="MNIST\nMinima Volumes Across Datasets",
    log_scale = data_level_log,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels",
    xlabel_size=15, ylabel_size=15, title_size=15
)
# Out:
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Model_0: first exceedance at index 403 (value=0.11609593778848648, threshold=0.1)
# Appended cutoff for model_0_data_0 | target=0, cutoff_idx=403
# Model_0: first exceedance at index 403 (value=0.12304888665676117, threshold=0.1)
# Appended cutoff for model_1_data_1 | target=0, cutoff_idx=403
# Model_0: first exceedance at index 402 (value=0.11525923013687134, threshold=0.1)
# Appended cutoff for model_2_data_2 | target=0, cutoff_idx=402
# Model_0: first exceedance at index 402 (value=0.12871699035167694, threshold=0.1)
# Appended cutoff for model_3_data_3 | target=0, cutoff_idx=402
# Model_0: first exceedance at index 403 (value=0.12722551822662354, threshold=0.1)
# Appended cutoff for model_4_data_4 | target=0, cutoff_idx=403
# Model_0: first exceedance at index 402 (value=0.10158401727676392, threshold=0.1)
# Appended cutoff for model_5_data_5 | target=0, cutoff_idx=402
# Model_0: first exceedance at index 402 (value=0.11954203993082047, threshold=0.1)
# Appended cutoff for model_6_data_6 | target=0, cutoff_idx=402
# Model_0: first exceedance at index 402 (value=0.102940633893013, threshold=0.1)
# Appended cutoff for model_7_data_7 | target=0, cutoff_idx=402
# Model_0: first exceedance at index 403 (value=0.10960222035646439, threshold=0.1)
# Appended cutoff for model_8_data_8 | target=0, cutoff_idx=403
# Model_0: first exceedance at index 403 (value=0.13460513949394226, threshold=0.1)
# Appended cutoff for model_9_data_9 | target=0, cutoff_idx=403
# Model_10: first exceedance at index 411 (value=0.1163567379117012, threshold=0.1)
# Appended cutoff for model_0_data_0 | target=10, cutoff_idx=411
# Model_10: first exceedance at index 412 (value=0.170613631606102, threshold=0.1)
# Appended cutoff for model_1_data_1 | target=10, cutoff_idx=412
# Model_10: first exceedance at index 411 (value=0.1511857658624649, threshold=0.1)
# Appended cutoff for model_2_data_2 | target=10, cutoff_idx=411
# Model_10: first exceedance at index 411 (value=0.11108361184597015, threshold=0.1)
# Appended cutoff for model_3_data_3 | target=10, cutoff_idx=411
# Model_10: first exceedance at index 412 (value=0.10569620877504349, threshold=0.1)
# Appended cutoff for model_4_data_4 | target=10, cutoff_idx=412
# Model_10: first exceedance at index 411 (value=0.1250872015953064, threshold=0.1)
# Appended cutoff for model_5_data_5 | target=10, cutoff_idx=411
# Model_10: first exceedance at index 411 (value=0.11130698770284653, threshold=0.1)
# Appended cutoff for model_6_data_6 | target=10, cutoff_idx=411
# Model_10: first exceedance at index 411 (value=0.10221973061561584, threshold=0.1)
# Appended cutoff for model_7_data_7 | target=10, cutoff_idx=411
# Model_10: first exceedance at index 412 (value=0.11206094175577164, threshold=0.1)
# Appended cutoff for model_8_data_8 | target=10, cutoff_idx=412
# Model_10: first exceedance at index 411 (value=0.12943829596042633, threshold=0.1)
# Appended cutoff for model_9_data_9 | target=10, cutoff_idx=411
# Model_20: first exceedance at index 421 (value=0.10682838410139084, threshold=0.1)
# Appended cutoff for model_0_data_0 | target=20, cutoff_idx=421
# Model_20: first exceedance at index 420 (value=0.13360294699668884, threshold=0.1)
# Appended cutoff for model_1_data_1 | target=20, cutoff_idx=420
# Model_20: first exceedance at index 421 (value=0.18149729073047638, threshold=0.1)
# Appended cutoff for model_2_data_2 | target=20, cutoff_idx=421
# Model_20: first exceedance at index 422 (value=0.10395582020282745, threshold=0.1)
# Appended cutoff for model_3_data_3 | target=20, cutoff_idx=422
# Model_20: first exceedance at index 421 (value=0.11633321642875671, threshold=0.1)
# Appended cutoff for model_4_data_4 | target=20, cutoff_idx=421
# Model_20: first exceedance at index 421 (value=0.1280880570411682, threshold=0.1)
# Appended cutoff for model_5_data_5 | target=20, cutoff_idx=421
# Model_20: first exceedance at index 422 (value=0.18264755606651306, threshold=0.1)
# Appended cutoff for model_6_data_6 | target=20, cutoff_idx=422
# Model_20: first exceedance at index 420 (value=0.1069488376379013, threshold=0.1)
# Appended cutoff for model_7_data_7 | target=20, cutoff_idx=420
# Model_20: first exceedance at index 422 (value=0.12524376809597015, threshold=0.1)
# Appended cutoff for model_8_data_8 | target=20, cutoff_idx=422
# Model_20: first exceedance at index 421 (value=0.13196533918380737, threshold=0.1)
# Appended cutoff for model_9_data_9 | target=20, cutoff_idx=421
# Model_50: first exceedance at index 435 (value=0.10280228406190872, threshold=0.1)
# Appended cutoff for model_0_data_0 | target=50, cutoff_idx=435
# Model_50: first exceedance at index 444 (value=0.1008639931678772, threshold=0.1)
# Appended cutoff for model_1_data_1 | target=50, cutoff_idx=444
# Model_50: first exceedance at index 1 (value=0.5602796673774719, threshold=0.1)
# Appended cutoff for model_2_data_2 | target=50, cutoff_idx=1
# Model_50: first exceedance at index 420 (value=0.10201545804738998, threshold=0.1)
# Appended cutoff for model_3_data_3 | target=50, cutoff_idx=420
# Model_50: first exceedance at index 2 (value=0.16747601330280304, threshold=0.1)
# Appended cutoff for model_4_data_4 | target=50, cutoff_idx=2
# Model_50: first exceedance at index 436 (value=0.10103220492601395, threshold=0.1)
# Appended cutoff for model_5_data_5 | target=50, cutoff_idx=436
# Model_50: first exceedance at index 32 (value=0.10008739680051804, threshold=0.1)
# Appended cutoff for model_6_data_6 | target=50, cutoff_idx=32
# Model_50: first exceedance at index 439 (value=0.10014045238494873, threshold=0.1)
# Appended cutoff for model_7_data_7 | target=50, cutoff_idx=439
# Model_50: first exceedance at index 0 (value=0.1540079116821289, threshold=0.1)
# Appended cutoff for model_8_data_8 | target=50, cutoff_idx=0
# Model_50: first exceedance at index 435 (value=0.10264236479997635, threshold=0.1)
# Appended cutoff for model_9_data_9 | target=50, cutoff_idx=435
# Model_100: first exceedance at index 43 (value=0.10404996573925018, threshold=0.1)
# Appended cutoff for model_0_data_0 | target=100, cutoff_idx=43
# Model_100: first exceedance at index 56 (value=0.10172421485185623, threshold=0.1)
# Appended cutoff for model_1_data_1 | target=100, cutoff_idx=56
# Model_100: first exceedance at index 1 (value=0.3824220895767212, threshold=0.1)
# Appended cutoff for model_2_data_2 | target=100, cutoff_idx=1
# Model_100: first exceedance at index 0 (value=0.5491642951965332, threshold=0.1)
# Appended cutoff for model_3_data_3 | target=100, cutoff_idx=0
# Model_100: first exceedance at index 2 (value=0.20120804011821747, threshold=0.1)
# Appended cutoff for model_4_data_4 | target=100, cutoff_idx=2
# Model_100: first exceedance at index 38 (value=0.10067566484212875, threshold=0.1)
# Appended cutoff for model_5_data_5 | target=100, cutoff_idx=38
# Model_100: first exceedance at index 32 (value=0.11058097332715988, threshold=0.1)
# Appended cutoff for model_6_data_6 | target=100, cutoff_idx=32
# Model_100: first exceedance at index 8 (value=0.14255747199058533, threshold=0.1)
# Appended cutoff for model_7_data_7 | target=100, cutoff_idx=8
# Model_100: first exceedance at index 0 (value=0.31214046478271484, threshold=0.1)
# Appended cutoff for model_8_data_8 | target=100, cutoff_idx=0
# Model_100: first exceedance at index 291 (value=0.10343598574399948, threshold=0.1)
# Appended cutoff for model_9_data_9 | target=100, cutoff_idx=291

# %%
_, _, = plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          
    base_train_size=base_train_size, 
    xlabel="# Of Examples In Loss Landscape",
    ylabel="Log Volume",
    title="MNIST\nMinima Volumes Across Datasets",
    log_scale = True,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels_log",
    xlabel_size=15, ylabel_size=15, title_size=15,
)

# %% [markdown]
# ## Customized Plot

# %%
# We experiment a little with making customized graphs.

_, _, = plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          
    base_train_size=base_train_size, 
    xlabel="# Of Examples In Loss Landscape",
    ylabel="Log Volume",
    title="MNIST\nMinima Volumes Across Datasets",
    log_scale = True,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels_log_custom",
    xlabel_size=15, ylabel_size=15, title_size=15,
    ylim = (250000, 1000000)
)

# %%
# Convert to numpy arrays
x = np.array(found_minima_vol)
y = np.array(found_minima_dataset)

# Fit a linear relationship: y = n * log(x) + log(k)
coefficients = np.polyfit(np.log(x), y, 1)

# Extract the exponent n and constant log(k)
exponent = coefficients[0]  # This is your exponent!
log_k = coefficients[1]  # log of the constant

print(f"Fitting to y = a * log(x) + log(k) ")
print(f"Exponent a = {exponent:.4f}")
print(f"Log k = {log_k:.4f}")
#print(f"Power law relationship: z = {k:.4f} × x^{n:.4f}")
print(f"y = {exponent:.4f} × log(x) + {log_k:.4f}")

print("The exponent divided by the number of parameters is ", exponent/num_params)

# Create the fit line for plotting
x_fit = np.linspace(min(x), max(x), 100)
y_fit = exponent * np.log(x_fit) + log_k

# Plot
plt.figure(figsize=(5, 4))
plt.plot(x, y, 'bo', label="Minima Volume (Found At This Dataset Size)")
plt.plot(x_fit, y_fit, 'k-', label=f'Fit: y = {exponent:.3f}·log(x) + {log_k:.3f}')
#plt.plot(xs, a*xs + b, '--', label=f"Fit: y = {np.exp(b):.2f} * x^{a:.2f}")
#plt.loglog(xs, fit_line, '--', label=f"Fit: y = {np.exp(b):.2f} * x^{a:.2f}")
plt.xscale("log")
plt.xlabel("Dataset Size")
plt.ylabel("Log Volume")
#plt.title("Log-Log Fit Through Large Dots")
plt.legend()
plt.grid(True, which="both")
output_path = os.path.join(base_output_dir, "scaling.png")
plt.savefig(output_path, dpi=300, bbox_inches='tight')
plt.show()
plt.close()  # Close the figure to free memory

print(f"Figure saved to: {output_path}")
# Out:
# C:\Users\raymo\AppData\Local\Temp\ipykernel_2176\4096500207.py:6: RuntimeWarning: divide by zero encountered in log
#   coefficients = np.polyfit(np.log(x), y, 1)
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\polynomial.py:668: RuntimeWarning: invalid value encountered in divide
#   lhs /= scale
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[8], line 6
#       3 y = np.array(found_minima_dataset)
#       5 # Fit a linear relationship: y = n * log(x) + log(k)
# ----> 6 coefficients = np.polyfit(np.log(x), y, 1)
#       8 # Extract the exponent n and constant log(k)
#       9 exponent = coefficients[0]  # This is your exponent!
#
# File L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\polynomial.py:669, in polyfit(x, y, deg, rcond, full, w, cov)
#     667 scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     668 lhs /= scale
# --> 669 c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     670 c = (c.T/scale).T  # broadcast scale coefficients
#     672 # warn on rank reduction, which indicates an ill conditioned matrix
#
# File L:\Programming\diffusion-env\Lib\site-packages\numpy\linalg\linalg.py:2326, in lstsq(a, b, rcond)
#    2323 if n_rhs == 0:
#    2324     # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2325     b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2326 x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2327 if m == 0:
#    2328     x[...] = 0
#
# File L:\Programming\diffusion-env\Lib\site-packages\numpy\linalg\linalg.py:124, in _raise_linalgerror_lstsq(err, flag)
#     123 def _raise_linalgerror_lstsq(err, flag):
# --> 124     raise LinAlgError("SVD did not converge in Linear Least Squares")
#
# LinAlgError: SVD did not converge in Linear Least Squares
