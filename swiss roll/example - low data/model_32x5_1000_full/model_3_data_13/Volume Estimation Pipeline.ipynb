# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.05, 0.02]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}"
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['data_0', 'data_180', 'data_30', 'data_380', 'data_780', 'data_80']
#
# ==================================================
# Analyzing directory: data_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 6 models from data_0
# The number of model parameters is  4353
# The loss landscape is for data trained with 0
# data_0: 9.259863145416602e-05
# data_180: 0.0017402084777131677
# data_30: 0.0006969761452637613
# data_380: 0.0001734003162709996
# data_780: 0.000168910512002185
# data_80: 0.015874065458774567
#
# Top perturbations for data_0:
# Top 5 r_vals: [7.111081617947149, 6.706605990460158, 6.069188954306919, 5.736298814767137, 5.715569666533698]
# Top 5 seeds: [306, 127, 304, 591, 520]
#
# Top perturbations for data_180:
# Top 5 r_vals: [6.6002686913798465, 6.19378908716067, 6.134157207058153, 5.7691097097997215, 5.71410650185767]
# Top 5 seeds: [948, 283, 820, 185, 861]
#
# Top perturbations for data_30:
# Top 5 r_vals: [2.9521844897169496, 2.716834476293077, 2.4561153194293994, 2.4538461369721825, 2.4442914035074352]
# Top 5 seeds: [707, 329, 466, 201, 511]
#
# Top perturbations for data_380:
# Top 5 r_vals: [3.8148831173955466, 3.596082250873188, 3.584113586631288, 3.577407181475823, 3.569147094222141]
# Top 5 seeds: [255, 517, 545, 386, 642]
#
# Top perturbations for data_780:
# Top 5 r_vals: [5.5504716636331555, 5.275633545046426, 5.271343211351203, 5.225321296136876, 4.968495392602338]
# Top 5 seeds: [683, 570, 214, 995, 24]
#
# Top perturbations for data_80:
# Top 5 r_vals: [4.582745553133331, 4.208975574846427, 4.178495166764164, 3.614579015380935, 3.5866605052046974]
# Top 5 seeds: [427, 144, 2, 696, 920]
# Plot saved to: data_0/loss_0.1/log_volume.png
# Test loss  [7.1331289306283, 0.04660448273061775, 4.6544929385185245, 0.002548871503677219, 0.0019108597887679934, 1.5104183033108711]
# log_exp_r_n  [8532.173667439845, 8207.683637530052, 4705.412376588545, 5821.367590619728, 7453.6245457949035, 6619.65667613924]
# Plot saved to: data_0/loss_0.1/gen_log_volume.png
# Plot saved to: data_0/loss_0.1/test_vs_data.png
# Plot saved to: data_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.95/avg_radius.png
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: divide by zero encountered in divide
#   return n/db/n.sum(), bin_edges
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Plot saved to: data_0/acc_0.95/radius_hist.png
# Plot saved to: data_0/acc_0.95/log_volume.png
# Plot saved to: data_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 3, 5, 2, 1, 4]
# test_loss ranks: [1, 4, 2, 5, 6, 3]
# log_exp_r_n ranks: [1, 2, 6, 5, 3, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.1\results.json
# Successfully analyzed data_0 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 6 models from data_0
# The number of model parameters is  4353
# The loss landscape is for data trained with 0
# data_0: 9.259863145416602e-05
# data_180: 0.0017402084777131677
# data_30: 0.0006969761452637613
# data_380: 0.0001734003162709996
# data_780: 0.000168910512002185
# data_80: 0.015874065458774567
#
# Top perturbations for data_0:
# Top 5 r_vals: [6.673583432467979, 6.293992535968957, 5.671319900635687, 5.3475128071075355, 5.328188607089681]
# Top 5 seeds: [306, 127, 304, 591, 520]
#
# Top perturbations for data_180:
# Top 5 r_vals: [5.343532500370659, 5.016969160600143, 5.000809724665872, 4.636679825375561, 4.593027342753611]
# Top 5 seeds: [820, 283, 185, 922, 861]
#
# Top perturbations for data_30:
# Top 5 r_vals: [2.416640818112968, 2.2136515467620095, 2.204380508296746, 2.2023439013268336, 2.2006359257973918]
# Top 5 seeds: [707, 690, 466, 201, 329]
#
# Top perturbations for data_380:
# Top 5 r_vals: [3.503599251913619, 3.2792267975983798, 3.273090880594136, 3.2655334472656254, 3.2394710587866515]
# Top 5 seeds: [255, 545, 386, 642, 298]
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.901542348309983, 4.8112887548021055, 4.607274191219727, 4.581960434646538, 4.548888107718601]
# Top 5 seeds: [214, 683, 24, 393, 570]
#
# Top perturbations for data_80:
# Top 5 r_vals: [3.8509011456898534, 3.586201771608775, 3.281557059582369, 3.259430685161073, 3.013287988247622]
# Top 5 seeds: [2, 427, 920, 144, 696]
# Plot saved to: data_0/loss_0.05/log_volume.png
# Test loss  [7.1331289306283, 0.04660448273061775, 4.6544929385185245, 0.002548871503677219, 0.0019108597887679934, 1.5104183033108711]
# log_exp_r_n  [8255.76949991311, 7288.2281432492355, 3834.0857863914557, 5450.843587489692, 6912.403048873881, 5862.273419835811]
# Plot saved to: data_0/loss_0.05/gen_log_volume.png
# Plot saved to: data_0/loss_0.05/test_vs_data.png
# Plot saved to: data_0/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.9/avg_radius.png
# Plot saved to: data_0/acc_0.9/radius_hist.png
# Plot saved to: data_0/acc_0.9/log_volume.png
# Plot saved to: data_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 3, 5, 2, 1, 4]
# test_loss ranks: [1, 4, 2, 5, 6, 3]
# log_exp_r_n ranks: [1, 2, 6, 5, 3, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.05\results.json
# Successfully analyzed data_0 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 6 models from data_0
# The number of model parameters is  4353
# The loss landscape is for data trained with 0
# data_0: 9.259863145416602e-05
# data_180: 0.0017402084777131677
# data_30: 0.0006969761452637613
# data_380: 0.0001734003162709996
# data_780: 0.000168910512002185
# data_80: 0.015874065458774567
#
# Top perturbations for data_0:
# Top 5 r_vals: [6.249974078273861, 5.508062146461906, 4.610865634699865, 4.594203441827326, 4.237005873828893]
# Top 5 seeds: [306, 127, 591, 520, 427]
#
# Top perturbations for data_180:
# Top 5 r_vals: [4.63723919598646, 3.9640250157828287, 3.9507804429235542, 3.546399837634404, 3.4880352528189396]
# Top 5 seeds: [185, 283, 922, 783, 951]
#
# Top perturbations for data_30:
# Top 5 r_vals: [1.9662529842523448, 1.964436381121775, 1.9567873008688332, 1.951700362170574, 1.9346515136693845]
# Top 5 seeds: [466, 201, 511, 930, 707]
#
# Top perturbations for data_380:
# Top 5 r_vals: [3.2055615083670914, 2.9878905325224907, 2.9509723407615756, 2.705033785614989, 2.69010660782382]
# Top 5 seeds: [255, 545, 987, 386, 411]
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.5451887893793534, 4.259683978568534, 4.124904625173273, 4.103999395246908, 3.839011564508724]
# Top 5 seeds: [214, 24, 683, 50, 995]
#
# Top perturbations for data_80:
# Top 5 r_vals: [2.1978419280249226, 2.196463844992898, 2.1661318944505425, 1.735922394717376, 1.7311395202020203]
# Top 5 seeds: [143, 427, 2, 982, 593]
# Plot saved to: data_0/loss_0.02/log_volume.png
# Test loss  [7.1331289306283, 0.04660448273061775, 4.6544929385185245, 0.002548871503677219, 0.0019108597887679934, 1.5104183033108711]
# log_exp_r_n  [7970.301302416151, 6671.113071347021, 2936.3025300162844, 5063.846542548012, 6583.835753455215, 3421.038163851223]
# Plot saved to: data_0/loss_0.02/gen_log_volume.png
# Plot saved to: data_0/loss_0.02/test_vs_data.png
# Plot saved to: data_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 3, 5, 2, 1, 4]
# test_loss ranks: [1, 4, 2, 5, 6, 3]
# log_exp_r_n ranks: [1, 2, 6, 4, 3, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.02\results.json
# Successfully analyzed data_0 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_180
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 3 models from data_180
# The number of model parameters is  4353
# The loss landscape is for data trained with 180
# data_180: 0.0008268019300885499
# data_380: 0.00027627081726677716
# data_780: 0.0005726520903408527
#
# Top perturbations for data_180:
# Top 5 r_vals: [5.338756986691411, 4.223640227047793, 4.219687747634221, 4.1835345293645805, 4.121024637073416]
# Top 5 seeds: [753, 787, 265, 969, 951]
#
# Top perturbations for data_380:
# Top 5 r_vals: [2.982299748640525, 2.965130556385051, 2.7271343535178176, 2.711219192098543, 2.7101047914036203]
# Top 5 seeds: [386, 214, 778, 393, 545]
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.786904894615994, 4.242889833211923, 4.202282534559313, 4.169988384077518, 3.9000637590392566]
# Top 5 seeds: [50, 477, 214, 649, 162]
# Plot saved to: data_180/loss_0.1/log_volume.png
# Test loss  [0.04660448273061775, 0.002548871503677219, 0.0019108597887679934]
# log_exp_r_n  [7284.336128816228, 4749.592407111207, 6809.385482958565]
# Plot saved to: data_180/loss_0.1/gen_log_volume.png
# Plot saved to: data_180/loss_0.1/test_vs_data.png
# Plot saved to: data_180/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_180/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_180/acc_0.95/avg_radius.png
# Plot saved to: data_180/acc_0.95/radius_hist.png
# Plot saved to: data_180/acc_0.95/log_volume.png
# Plot saved to: data_180/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [1, 3, 2]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_180/loss_0.1\results.json
# Successfully analyzed data_180 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_180
# The number of model parameters is  4353
# The loss landscape is for data trained with 180
# data_180: 0.0008268019300885499
# data_380: 0.00027627081726677716
# data_780: 0.0005726520903408527
#
# Top perturbations for data_180:
# Top 5 r_vals: [4.256024383523126, 3.581648614184977, 3.574889088173252, 3.546399837634404, 3.5409436256541813]
# Top 5 seeds: [753, 332, 787, 783, 969]
#
# Top perturbations for data_380:
# Top 5 r_vals: [2.446875320868935, 2.445869574241767, 2.4412929915175274, 2.435656145584485, 2.4353265169749108]
# Top 5 seeds: [393, 545, 386, 642, 510]
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.438885745899056, 3.8728235838498626, 3.563340861096017, 3.5623443303041573, 3.54128252848133]
# Top 5 seeds: [50, 214, 702, 200, 707]
# Plot saved to: data_180/loss_0.05/log_volume.png
# Test loss  [0.04660448273061775, 0.002548871503677219, 0.0019108597887679934]
# log_exp_r_n  [6297.696594533457, 3888.362647941022, 6480.818187539899]
# Plot saved to: data_180/loss_0.05/gen_log_volume.png
# Plot saved to: data_180/loss_0.05/test_vs_data.png
# Plot saved to: data_180/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_180/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_180/acc_0.9/avg_radius.png
# Plot saved to: data_180/acc_0.9/radius_hist.png
# Plot saved to: data_180/acc_0.9/log_volume.png
# Plot saved to: data_180/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [2, 3, 1]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_180/loss_0.05\results.json
# Successfully analyzed data_180 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_180
# The number of model parameters is  4353
# The loss landscape is for data trained with 180
# data_180: 0.0008268019300885499
# data_380: 0.00027627081726677716
# data_780: 0.0005726520903408527
#
# Top perturbations for data_180:
# Top 5 r_vals: [3.295865282600309, 2.985835612203355, 2.9802005442049224, 2.9297753536339965, 2.7435975298080244]
# Top 5 seeds: [753, 332, 787, 260, 922]
#
# Top perturbations for data_380:
# Top 5 r_vals: [2.195184881036932, 2.1784632659155476, 2.177498305139463, 2.1773810268433627, 2.1600757945667612]
# Top 5 seeds: [545, 214, 972, 527, 98]
#
# Top perturbations for data_780:
# Top 5 r_vals: [3.7822458426595507, 3.254247594762732, 3.24003921320409, 2.9705733832577375, 2.9697426269643348]
# Top 5 seeds: [50, 214, 707, 702, 200]
# Plot saved to: data_180/loss_0.02/log_volume.png
# Test loss  [0.04660448273061775, 0.002548871503677219, 0.0019108597887679934]
# log_exp_r_n  [5184.779262168399, 3415.7093234416793, 5783.9663745340895]
# Plot saved to: data_180/loss_0.02/gen_log_volume.png
# Plot saved to: data_180/loss_0.02/test_vs_data.png
# Plot saved to: data_180/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_180/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_180/acc_0.85/avg_radius.png
# Plot saved to: data_180/acc_0.85/radius_hist.png
# Plot saved to: data_180/acc_0.85/log_volume.png
# Plot saved to: data_180/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [2, 3, 1]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_180/loss_0.02\results.json
# Successfully analyzed data_180 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_30
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from data_30
# The number of model parameters is  4353
# The loss landscape is for data trained with 30
# data_180: 0.0010414430871605873
# data_30: 0.0007616329821757972
# data_380: 0.0002713590220082551
# data_780: 0.00019442327902652323
# data_80: 0.008954893797636032
#
# Top perturbations for data_180:
# Top 5 r_vals: [4.806763136682433, 4.652223803245126, 4.603315973218614, 4.2868711403250375, 4.231626434528565]
# Top 5 seeds: [951, 283, 753, 922, 332]
#
# Top perturbations for data_30:
# Top 5 r_vals: [2.396153261924007, 2.204380508296746, 2.202545670438404, 2.1920445970267304, 2.1880654579351755]
# Top 5 seeds: [687, 466, 14, 18, 930]
#
# Top perturbations for data_380:
# Top 5 r_vals: [3.2650915075231484, 3.254247594762732, 3.24459989571277, 2.982167926154299, 2.9754137401738445]
# Top 5 seeds: [510, 214, 595, 130, 642]
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.557465474564937, 4.5451887893793534, 4.525344025053647, 4.438885745899056, 4.209996291465048]
# Top 5 seeds: [851, 214, 707, 50, 702]
#
# Top perturbations for data_80:
# Top 5 r_vals: [3.8230076869547753, 2.9896313445736666, 2.9077949839190023, 2.6937443679017137, 2.451221753694418]
# Top 5 seeds: [949, 427, 951, 144, 983]
# Plot saved to: data_30/loss_0.1/log_volume.png
# Test loss  [0.04660448273061775, 4.6544929385185245, 0.002548871503677219, 0.0019108597887679934, 1.5104183033108711]
# log_exp_r_n  [6827.406338150105, 3797.025039844331, 5143.943991370674, 6595.577488925011, 5830.628331715984]
# Plot saved to: data_30/loss_0.1/gen_log_volume.png
# Plot saved to: data_30/loss_0.1/test_vs_data.png
# Plot saved to: data_30/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_30/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_30/acc_0.95/avg_radius.png
# Plot saved to: data_30/acc_0.95/radius_hist.png
# Plot saved to: data_30/acc_0.95/log_volume.png
# Plot saved to: data_30/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 5, 2, 1, 4]
# test_loss ranks: [3, 1, 4, 5, 2]
# log_exp_r_n ranks: [1, 5, 4, 2, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_30/loss_0.1\results.json
# Successfully analyzed data_30 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from data_30
# The number of model parameters is  4353
# The loss landscape is for data trained with 30
# data_180: 0.0010414430871605873
# data_30: 0.0007616329821757972
# data_380: 0.0002713590220082551
# data_780: 0.00019442327902652323
# data_80: 0.008954893797636032
#
# Top perturbations for data_180:
# Top 5 r_vals: [4.121024637073416, 3.9640250157828287, 3.922352071854913, 3.8998669220615247, 3.8832429407713502]
# Top 5 seeds: [951, 283, 753, 332, 771]
#
# Top perturbations for data_30:
# Top 5 r_vals: [1.9182501182715737, 1.9148209564735208, 1.7417327472961945, 1.740282998864912, 1.7319858544408735]
# Top 5 seeds: [687, 852, 466, 14, 18]
#
# Top perturbations for data_380:
# Top 5 r_vals: [2.965130556385051, 2.956339987622586, 2.940103164826981, 2.7049142187340585, 2.698422733490206]
# Top 5 seeds: [214, 595, 98, 130, 510]
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.202282534559313, 4.183934934406108, 4.103999395246908, 3.8799325822141877, 3.836017759268825]
# Top 5 seeds: [214, 707, 50, 702, 35]
#
# Top perturbations for data_80:
# Top 5 r_vals: [3.2123884036217207, 2.196463844992898, 2.1363391718588587, 1.962335420547609, 1.7268917074788288]
# Top 5 seeds: [949, 427, 951, 983, 370]
# Plot saved to: data_30/loss_0.05/log_volume.png
# Test loss  [0.04660448273061775, 4.6544929385185245, 0.002548871503677219, 0.0019108597887679934, 1.5104183033108711]
# log_exp_r_n  [6157.38351401897, 2828.6950749179596, 4724.459638698436, 6242.380224748092, 5073.107283644267]
# Plot saved to: data_30/loss_0.05/gen_log_volume.png
# Plot saved to: data_30/loss_0.05/test_vs_data.png
# Plot saved to: data_30/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_30/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_30/acc_0.9/avg_radius.png
# Plot saved to: data_30/acc_0.9/radius_hist.png
# Plot saved to: data_30/acc_0.9/log_volume.png
# Plot saved to: data_30/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 5, 2, 1, 4]
# test_loss ranks: [3, 1, 4, 5, 2]
# log_exp_r_n ranks: [2, 5, 4, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_30/loss_0.05\results.json
# Successfully analyzed data_30 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 5 models from data_30
# The number of model parameters is  4353
# The loss landscape is for data trained with 30
# data_180: 0.0010414430871605873
# data_30: 0.0007616329821757972
# data_380: 0.0002713590220082551
# data_780: 0.00019442327902652323
# data_80: 0.008954893797636032
#
# Top perturbations for data_180:
# Top 5 r_vals: [3.5144017280552933, 3.4880352528189396, 3.330882131317516, 3.27697151089892, 3.263002748842593]
# Top 5 seeds: [260, 951, 283, 332, 771]
#
# Top perturbations for data_30:
# Top 5 r_vals: [1.5308197974282958, 1.529545604471114, 1.522253192379674, 1.5022405689193965, 1.4934473239138546]
# Top 5 seeds: [466, 14, 18, 908, 687]
#
# Top perturbations for data_380:
# Top 5 r_vals: [2.689460822117961, 2.666760240205879, 2.426163235047365, 2.190980517174587, 2.1773810268433627]
# Top 5 seeds: [214, 98, 972, 130, 527]
#
# Top perturbations for data_780:
# Top 5 r_vals: [3.7822458426595507, 3.5568119372510028, 3.54128252848133, 3.3009609646267366, 3.2649046344521606]
# Top 5 seeds: [50, 214, 707, 257, 370]
#
# Top perturbations for data_80:
# Top 5 r_vals: [1.5253221145784013, 1.493362377716709, 1.3199815799747001, 1.2923533261862235, 1.1380393763194707]
# Top 5 seeds: [427, 949, 316, 951, 63]
# Plot saved to: data_30/loss_0.02/log_volume.png
# Test loss  [0.04660448273061775, 4.6544929385185245, 0.002548871503677219, 0.0019108597887679934, 1.5104183033108711]
# log_exp_r_n  [5464.244331067897, 1846.640782479735, 4299.692467001239, 5783.9663745340895, 1830.953266920057]
# Plot saved to: data_30/loss_0.02/gen_log_volume.png
# Plot saved to: data_30/loss_0.02/test_vs_data.png
# Plot saved to: data_30/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_30/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_30/acc_0.85/avg_radius.png
# Plot saved to: data_30/acc_0.85/radius_hist.png
# Plot saved to: data_30/acc_0.85/log_volume.png
# Plot saved to: data_30/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 5, 2, 1, 4]
# test_loss ranks: [3, 1, 4, 5, 2]
# log_exp_r_n ranks: [2, 4, 3, 1, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_30/loss_0.02\results.json
# Successfully analyzed data_30 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_380
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_380
# The number of model parameters is  4353
# The loss landscape is for data trained with 380
# data_380: 0.00022176817583385855
# data_780: 0.00039137815474532545
#
# Top perturbations for data_380:
# Top 5 r_vals: [2.9891191592886432, 2.982299748640525, 2.965130556385051, 2.9636575087590216, 2.7271343535178176]
# Top 5 seeds: [393, 386, 214, 527, 778]
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.786904894615994, 4.242889833211923, 4.202282534559313, 3.9257247546487606, 3.9017406845443072]
# Top 5 seeds: [50, 477, 214, 24, 631]
# Plot saved to: data_380/loss_0.1/log_volume.png
# Test loss  [0.002548871503677219, 0.0019108597887679934]
# log_exp_r_n  [4759.534784796785, 6809.385482958565]
# Plot saved to: data_380/loss_0.1/gen_log_volume.png
# Plot saved to: data_380/loss_0.1/test_vs_data.png
# Plot saved to: data_380/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_380/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_380/acc_0.95/avg_radius.png
# Plot saved to: data_380/acc_0.95/radius_hist.png
# Plot saved to: data_380/acc_0.95/log_volume.png
# Plot saved to: data_380/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_380/loss_0.1\results.json
# Successfully analyzed data_380 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_380
# The number of model parameters is  4353
# The loss landscape is for data trained with 380
# data_380: 0.00022176817583385855
# data_780: 0.00039137815474532545
#
# Top perturbations for data_380:
# Top 5 r_vals: [2.446875320868935, 2.445869574241767, 2.4412929915175274, 2.435656145584485, 2.4272383919614593]
# Top 5 seeds: [393, 545, 386, 642, 214]
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.438885745899056, 3.563340861096017, 3.5568119372510028, 3.54128252848133, 3.3283431441695606]
# Top 5 seeds: [50, 702, 214, 707, 931]
# Plot saved to: data_380/loss_0.05/log_volume.png
# Test loss  [0.002548871503677219, 0.0019108597887679934]
# log_exp_r_n  [3888.362647940047, 6480.818187539899]
# Plot saved to: data_380/loss_0.05/gen_log_volume.png
# Plot saved to: data_380/loss_0.05/test_vs_data.png
# Plot saved to: data_380/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_380/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_380/acc_0.9/avg_radius.png
# Plot saved to: data_380/acc_0.9/radius_hist.png
# Plot saved to: data_380/acc_0.9/log_volume.png
# Plot saved to: data_380/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_380/loss_0.05\results.json
# Successfully analyzed data_380 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_380
# The number of model parameters is  4353
# The loss landscape is for data trained with 380
# data_380: 0.00022176817583385855
# data_780: 0.00039137815474532545
#
# Top perturbations for data_380:
# Top 5 r_vals: [2.195184881036932, 2.1784632659155476, 2.177498305139463, 2.1773810268433627, 1.9703545704166234]
# Top 5 seeds: [545, 214, 972, 527, 778]
#
# Top perturbations for data_780:
# Top 5 r_vals: [3.7822458426595507, 2.9705733832577375, 2.965130556385051, 2.957368477645328, 2.9521844897169496]
# Top 5 seeds: [50, 702, 214, 502, 707]
# Plot saved to: data_380/loss_0.02/log_volume.png
# Test loss  [0.002548871503677219, 0.0019108597887679934]
# log_exp_r_n  [3415.7093234416793, 5783.9663745340895]
# Plot saved to: data_380/loss_0.02/gen_log_volume.png
# Plot saved to: data_380/loss_0.02/test_vs_data.png
# Plot saved to: data_380/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_380/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_380/acc_0.85/avg_radius.png
# Plot saved to: data_380/acc_0.85/radius_hist.png
# Plot saved to: data_380/acc_0.85/log_volume.png
# Plot saved to: data_380/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_380/loss_0.02\results.json
# Successfully analyzed data_380 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_780
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_780
# The number of model parameters is  4353
# The loss landscape is for data trained with 780
# data_780: 0.00032658985583111644
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.438885745899056, 3.9318136980601475, 3.910247270288109, 3.9017406845443072, 3.8799325822141877]
# Top 5 seeds: [50, 119, 477, 631, 702]
# Plot saved to: data_780/loss_0.1/log_volume.png
# Test loss  [0.0019108597887679934]
# log_exp_r_n  [6480.818187539899]
# Plot saved to: data_780/loss_0.1/gen_log_volume.png
# Plot saved to: data_780/loss_0.1/test_vs_data.png
# Plot saved to: data_780/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_780/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_780/acc_0.95/avg_radius.png
# Plot saved to: data_780/acc_0.95/radius_hist.png
# Plot saved to: data_780/acc_0.95/log_volume.png
# Plot saved to: data_780/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_780/loss_0.1\results.json
# Successfully analyzed data_780 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 1 models from data_780
# The number of model parameters is  4353
# The loss landscape is for data trained with 780
# data_780: 0.00032658985583111644
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.103999395246908, 3.563340861096017, 3.5568119372510028, 3.54128252848133, 3.3283431441695606]
# Top 5 seeds: [50, 702, 214, 707, 931]
# Plot saved to: data_780/loss_0.05/log_volume.png
# Test loss  [0.0019108597887679934]
# log_exp_r_n  [6139.362658827431]
# Plot saved to: data_780/loss_0.05/gen_log_volume.png
# Plot saved to: data_780/loss_0.05/test_vs_data.png
# Plot saved to: data_780/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_780/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_780/acc_0.9/avg_radius.png
# Plot saved to: data_780/acc_0.9/radius_hist.png
# Plot saved to: data_780/acc_0.9/log_volume.png
# Plot saved to: data_780/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_780/loss_0.05\results.json
# Successfully analyzed data_780 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 1 models from data_780
# The number of model parameters is  4353
# The loss landscape is for data trained with 780
# data_780: 0.00032658985583111644
#
# Top perturbations for data_780:
# Top 5 r_vals: [3.4736250881369837, 2.987270211604235, 2.9705733832577375, 2.965130556385051, 2.9521844897169496]
# Top 5 seeds: [50, 631, 702, 214, 707]
# Plot saved to: data_780/loss_0.02/log_volume.png
# Test loss  [0.0019108597887679934]
# log_exp_r_n  [5413.442371404053]
# Plot saved to: data_780/loss_0.02/gen_log_volume.png
# Plot saved to: data_780/loss_0.02/test_vs_data.png
# Plot saved to: data_780/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_780/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_780/acc_0.85/avg_radius.png
# Plot saved to: data_780/acc_0.85/radius_hist.png
# Plot saved to: data_780/acc_0.85/log_volume.png
# Plot saved to: data_780/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_780/loss_0.02\results.json
# Successfully analyzed data_780 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_80
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from data_80
# The number of model parameters is  4353
# The loss landscape is for data trained with 80
# data_180: 0.0009035354014486074
# data_380: 0.00033903043367899954
# data_780: 0.0007127183489501476
# data_80: 0.00774721335619688
#
# Top perturbations for data_180:
# Top 5 r_vals: [5.338756986691411, 4.5640142678411735, 4.457300247458607, 4.428262440261398, 4.301242421639354]
# Top 5 seeds: [753, 265, 951, 575, 283]
#
# Top perturbations for data_380:
# Top 5 r_vals: [3.24459989571277, 2.9878905325224907, 2.9775829753052547, 2.965130556385051, 2.9636575087590216]
# Top 5 seeds: [595, 545, 188, 214, 527]
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.786904894615994, 4.607274191219727, 4.231840016318638, 4.202282534559313, 4.163668017255544]
# Top 5 seeds: [50, 24, 162, 214, 94]
#
# Top perturbations for data_80:
# Top 5 r_vals: [3.8230076869547753, 3.259430685161073, 2.6982682929356705, 2.6374557677269865, 2.4472945927235688]
# Top 5 seeds: [949, 144, 370, 951, 427]
# Plot saved to: data_80/loss_0.1/log_volume.png
# Test loss  [0.04660448273061775, 0.002548871503677219, 0.0019108597887679934, 1.5104183033108711]
# log_exp_r_n  [7284.336128816228, 5116.538611610418, 6809.385482958565, 5830.628331715984]
# Plot saved to: data_80/loss_0.1/gen_log_volume.png
# Plot saved to: data_80/loss_0.1/test_vs_data.png
# Plot saved to: data_80/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_80/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_80/acc_0.95/avg_radius.png
# Plot saved to: data_80/acc_0.95/radius_hist.png
# Plot saved to: data_80/acc_0.95/log_volume.png
# Plot saved to: data_80/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1, 4]
# test_loss ranks: [2, 3, 4, 1]
# log_exp_r_n ranks: [1, 4, 2, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_80/loss_0.1\results.json
# Successfully analyzed data_80 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from data_80
# The number of model parameters is  4353
# The loss landscape is for data trained with 80
# data_180: 0.0009035354014486074
# data_380: 0.00033903043367899954
# data_780: 0.0007127183489501476
# data_80: 0.00774721335619688
#
# Top perturbations for data_180:
# Top 5 r_vals: [4.256024383523126, 3.8832429407713502, 3.8723151256887056, 3.79793630552686, 3.7731940319387056]
# Top 5 seeds: [753, 771, 221, 951, 575]
#
# Top perturbations for data_380:
# Top 5 r_vals: [2.688269512517856, 2.688124724497979, 2.445869574241767, 2.4411850824074874, 2.437431868673916]
# Top 5 seeds: [972, 527, 545, 130, 188]
#
# Top perturbations for data_780:
# Top 5 r_vals: [4.438885745899056, 3.9000637590392566, 3.837236444702709, 3.6053965194604074, 3.5684598174074242]
# Top 5 seeds: [50, 162, 94, 24, 370]
#
# Top perturbations for data_80:
# Top 5 r_vals: [2.92699026032475, 1.949498841646022, 1.9428333141964056, 1.9055617921827477, 1.7323296092235487]
# Top 5 seeds: [949, 370, 795, 951, 445]
# Plot saved to: data_80/loss_0.05/log_volume.png
# Test loss  [0.04660448273061775, 0.002548871503677219, 0.0019108597887679934, 1.5104183033108711]
# log_exp_r_n  [6297.696594533457, 4298.3466325305835, 6480.818187539899, 4668.104027526891]
# Plot saved to: data_80/loss_0.05/gen_log_volume.png
# Plot saved to: data_80/loss_0.05/test_vs_data.png
# Plot saved to: data_80/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_80/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_80/acc_0.9/avg_radius.png
# Plot saved to: data_80/acc_0.9/radius_hist.png
# Plot saved to: data_80/acc_0.9/log_volume.png
# Plot saved to: data_80/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1, 4]
# test_loss ranks: [2, 3, 4, 1]
# log_exp_r_n ranks: [2, 4, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_80/loss_0.05\results.json
# Successfully analyzed data_80 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from data_80
# The number of model parameters is  4353
# The loss landscape is for data trained with 80
# data_180: 0.0009035354014486074
# data_380: 0.00033903043367899954
# data_780: 0.0007127183489501476
# data_80: 0.00774721335619688
#
# Top perturbations for data_180:
# Top 5 r_vals: [3.5563449678634123, 3.295865282600309, 3.263002748842593, 3.191321478949653, 3.158607011959877]
# Top 5 seeds: [221, 753, 771, 951, 833]
#
# Top perturbations for data_380:
# Top 5 r_vals: [2.426163235047365, 2.426032563859426, 2.195184881036932, 2.1784632659155476, 2.1680613115799328]
# Top 5 seeds: [972, 527, 545, 214, 987]
#
# Top perturbations for data_780:
# Top 5 r_vals: [3.7822458426595507, 3.277136908637153, 3.2649046344521606, 3.224344512562693, 2.9728819932053137]
# Top 5 seeds: [50, 162, 370, 94, 438]
#
# Top perturbations for data_80:
# Top 5 r_vals: [1.9181410096005735, 1.1506304772529492, 1.1400183537653208, 1.1361205193743686, 1.1339840709451585]
# Top 5 seeds: [949, 96, 370, 795, 786]
# Plot saved to: data_80/loss_0.02/log_volume.png
# Test loss  [0.04660448273061775, 0.002548871503677219, 0.0019108597887679934, 1.5104183033108711]
# log_exp_r_n  [5515.888399878479, 3851.787211592568, 5783.9663745340895, 2828.4470580601874]
# Plot saved to: data_80/loss_0.02/gen_log_volume.png
# Plot saved to: data_80/loss_0.02/test_vs_data.png
# Plot saved to: data_80/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_80/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_80/acc_0.85/avg_radius.png
# Plot saved to: data_80/acc_0.85/radius_hist.png
# Plot saved to: data_80/acc_0.85/log_volume.png
# Plot saved to: data_80/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1, 4]
# test_loss ranks: [2, 3, 4, 1]
# log_exp_r_n ranks: [2, 3, 1, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_80/loss_0.02\results.json
# Successfully analyzed data_80 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
