# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 3            
model_seed = 3           

# --- Training configuration ---
epochs = 1000            

# --- Dataset configuration ---
base_data_size = 20      
dataset_type = "data"   
dataset_quantities = [0, 30, 80, 180, 380, 780]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

test_dataset_size = 2000

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    base_data_size=base_data_size,
    dataset_quantities=dataset_quantities,
    test_dataset_size=test_dataset_size,
    noise=0.3, # default swiss params
    extra_pts=1000,
    dataset_type=dataset_type,
    seed=data_seed
)

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
        randperm_indices = False, #Not used for full batch training, which is what we do
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/1000: Train Loss 0.7014 | Test Loss 0.6961 | accs Train 0.4500 Test 0.5000
# Epoch 100/1000: Train Loss 0.1649 | Test Loss 2.8335 | accs Train 0.9500 Test 0.5887
# Epoch 200/1000: Train Loss 0.0754 | Test Loss 5.9117 | accs Train 0.9500 Test 0.5887
# Epoch 300/1000: Train Loss 0.0058 | Test Loss 9.0985 | accs Train 1.0000 Test 0.6038
# Epoch 400/1000: Train Loss 0.0009 | Test Loss 10.7093 | accs Train 1.0000 Test 0.6038
# Epoch 500/1000: Train Loss 0.0004 | Test Loss 11.4893 | accs Train 1.0000 Test 0.6030
# Epoch 600/1000: Train Loss 0.0002 | Test Loss 11.9952 | accs Train 1.0000 Test 0.6022
# Epoch 700/1000: Train Loss 0.0002 | Test Loss 12.3622 | accs Train 1.0000 Test 0.6008
# Epoch 800/1000: Train Loss 0.0001 | Test Loss 12.6624 | accs Train 1.0000 Test 0.6008
# Epoch 900/1000: Train Loss 0.0001 | Test Loss 12.9094 | accs Train 1.0000 Test 0.5980
# Epoch 1000/1000: Train Loss 0.0001 | Test Loss 13.1029 | accs Train 1.0000 Test 0.5980
# Completed training with 0 additional samples of data
# Epoch 1/1000: Train Loss 0.7006 | Test Loss 0.6952 | accs Train 0.4600 Test 0.5000
# Epoch 100/1000: Train Loss 0.4634 | Test Loss 1.0076 | accs Train 0.7800 Test 0.5777
# Epoch 200/1000: Train Loss 0.2730 | Test Loss 2.0632 | accs Train 0.8600 Test 0.6140
# Epoch 300/1000: Train Loss 0.0783 | Test Loss 3.1011 | accs Train 0.9800 Test 0.6713
# Epoch 400/1000: Train Loss 0.0076 | Test Loss 4.0304 | accs Train 1.0000 Test 0.6857
# Epoch 500/1000: Train Loss 0.0025 | Test Loss 4.5289 | accs Train 1.0000 Test 0.6875
# Epoch 600/1000: Train Loss 0.0013 | Test Loss 4.8618 | accs Train 1.0000 Test 0.6835
# Epoch 700/1000: Train Loss 0.0008 | Test Loss 5.1013 | accs Train 1.0000 Test 0.6843
# Epoch 800/1000: Train Loss 0.0005 | Test Loss 5.2925 | accs Train 1.0000 Test 0.6850
# Epoch 900/1000: Train Loss 0.0004 | Test Loss 5.4532 | accs Train 1.0000 Test 0.6863
# Epoch 1000/1000: Train Loss 0.0003 | Test Loss 5.5878 | accs Train 1.0000 Test 0.6867
# Completed training with 30 additional samples of data
# Epoch 1/1000: Train Loss 0.7024 | Test Loss 0.6949 | accs Train 0.4500 Test 0.5000
# Epoch 100/1000: Train Loss 0.4434 | Test Loss 0.7115 | accs Train 0.8100 Test 0.6987
# Epoch 200/1000: Train Loss 0.2478 | Test Loss 0.6138 | accs Train 0.9100 Test 0.7840
# Epoch 300/1000: Train Loss 0.0149 | Test Loss 0.6101 | accs Train 0.9900 Test 0.8822
# Epoch 400/1000: Train Loss 0.0009 | Test Loss 0.9466 | accs Train 1.0000 Test 0.8892
# Epoch 500/1000: Train Loss 0.0002 | Test Loss 1.0539 | accs Train 1.0000 Test 0.8920
# Epoch 600/1000: Train Loss 0.0001 | Test Loss 1.1258 | accs Train 1.0000 Test 0.8928
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 1.1749 | accs Train 1.0000 Test 0.8938
# Epoch 800/1000: Train Loss 0.0000 | Test Loss 1.2125 | accs Train 1.0000 Test 0.8935
# Epoch 900/1000: Train Loss 0.0000 | Test Loss 1.2413 | accs Train 1.0000 Test 0.8935
# Epoch 1000/1000: Train Loss 0.0000 | Test Loss 1.2657 | accs Train 1.0000 Test 0.8940
# Completed training with 80 additional samples of data
# Epoch 1/1000: Train Loss 0.7034 | Test Loss 0.6946 | accs Train 0.4600 Test 0.5000
# Epoch 100/1000: Train Loss 0.5047 | Test Loss 0.5612 | accs Train 0.7450 Test 0.7027
# Epoch 200/1000: Train Loss 0.0840 | Test Loss 0.1809 | accs Train 0.9700 Test 0.9515
# Epoch 300/1000: Train Loss 0.0027 | Test Loss 0.0965 | accs Train 1.0000 Test 0.9762
# Epoch 400/1000: Train Loss 0.0007 | Test Loss 0.0934 | accs Train 1.0000 Test 0.9788
# Epoch 500/1000: Train Loss 0.0004 | Test Loss 0.0926 | accs Train 1.0000 Test 0.9800
# Epoch 600/1000: Train Loss 0.0002 | Test Loss 0.0936 | accs Train 1.0000 Test 0.9802
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 0.0942 | accs Train 1.0000 Test 0.9808
# Epoch 800/1000: Train Loss 0.0001 | Test Loss 0.0947 | accs Train 1.0000 Test 0.9808
# Epoch 900/1000: Train Loss 0.0001 | Test Loss 0.0952 | accs Train 1.0000 Test 0.9810
# Epoch 1000/1000: Train Loss 0.0001 | Test Loss 0.0956 | accs Train 1.0000 Test 0.9812
# Completed training with 180 additional samples of data
# Epoch 1/1000: Train Loss 0.6977 | Test Loss 0.6939 | accs Train 0.4925 Test 0.5000
# Epoch 100/1000: Train Loss 0.5320 | Test Loss 0.5275 | accs Train 0.6750 Test 0.6673
# Epoch 200/1000: Train Loss 0.0876 | Test Loss 0.0942 | accs Train 0.9800 Test 0.9798
# Epoch 300/1000: Train Loss 0.0019 | Test Loss 0.0080 | accs Train 1.0000 Test 0.9975
# Epoch 400/1000: Train Loss 0.0005 | Test Loss 0.0054 | accs Train 1.0000 Test 0.9982
# Epoch 500/1000: Train Loss 0.0002 | Test Loss 0.0048 | accs Train 1.0000 Test 0.9985
# Epoch 600/1000: Train Loss 0.0001 | Test Loss 0.0045 | accs Train 1.0000 Test 0.9988
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 0.0043 | accs Train 1.0000 Test 0.9988
# Epoch 800/1000: Train Loss 0.0001 | Test Loss 0.0042 | accs Train 1.0000 Test 0.9988
# Epoch 900/1000: Train Loss 0.0001 | Test Loss 0.0042 | accs Train 1.0000 Test 0.9988
# Epoch 1000/1000: Train Loss 0.0000 | Test Loss 0.0041 | accs Train 1.0000 Test 0.9988
# Completed training with 380 additional samples of data
# Epoch 1/1000: Train Loss 0.6958 | Test Loss 0.6938 | accs Train 0.5038 Test 0.5000
# Epoch 100/1000: Train Loss 0.5067 | Test Loss 0.5213 | accs Train 0.6813 Test 0.6820
# Epoch 200/1000: Train Loss 0.0570 | Test Loss 0.0588 | accs Train 0.9862 Test 0.9882
# Epoch 300/1000: Train Loss 0.0022 | Test Loss 0.0055 | accs Train 1.0000 Test 0.9982
# Epoch 400/1000: Train Loss 0.0006 | Test Loss 0.0038 | accs Train 1.0000 Test 0.9990
# Epoch 500/1000: Train Loss 0.0003 | Test Loss 0.0035 | accs Train 1.0000 Test 0.9992
# Epoch 600/1000: Train Loss 0.0002 | Test Loss 0.0034 | accs Train 1.0000 Test 0.9992
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 0.0034 | accs Train 1.0000 Test 0.9992
# Epoch 800/1000: Train Loss 0.0001 | Test Loss 0.0034 | accs Train 1.0000 Test 0.9992
# Epoch 900/1000: Train Loss 0.0001 | Test Loss 0.0034 | accs Train 1.0000 Test 0.9992
# Epoch 1000/1000: Train Loss 0.0001 | Test Loss 0.0034 | accs Train 1.0000 Test 0.9992
# Completed training with 780 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 13.1029 | accs: 0.5980
#   30 samples | Test Loss: 5.5878 | accs: 0.6867
#   80 samples | Test Loss: 1.2657 | accs: 0.8940
#  180 samples | Test Loss: 0.0956 | accs: 0.9812
#  380 samples | Test Loss: 0.0041 | accs: 0.9988
#  780 samples | Test Loss: 0.0034 | accs: 0.9992
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0001 | accs: 1.0000
#  Model   30 | Train Loss: 0.0003 | accs: 1.0000
#  Model   80 | Train Loss: 0.0000 | accs: 1.0000
#  Model  180 | Train Loss: 0.0001 | accs: 1.0000
#  Model  380 | Train Loss: 0.0001 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 30
#  Model    0 | Train Loss: 8.3445 | accs: 0.6400
#  Model   30 | Train Loss: 0.0003 | accs: 1.0000
#  Model   80 | Train Loss: 0.0000 | accs: 1.0000
#  Model  180 | Train Loss: 0.0001 | accs: 1.0000
#  Model  380 | Train Loss: 0.0001 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 80
#  Model    0 | Train Loss: 10.3206 | accs: 0.6300
#  Model   30 | Train Loss: 1.6865 | accs: 0.9200
#  Model   80 | Train Loss: 0.0000 | accs: 1.0000
#  Model  180 | Train Loss: 0.0001 | accs: 1.0000
#  Model  380 | Train Loss: 0.0001 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 180
#  Model    0 | Train Loss: 12.0433 | accs: 0.6300
#  Model   30 | Train Loss: 3.3804 | accs: 0.8150
#  Model   80 | Train Loss: 0.6624 | accs: 0.9600
#  Model  180 | Train Loss: 0.0001 | accs: 1.0000
#  Model  380 | Train Loss: 0.0000 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 380
#  Model    0 | Train Loss: 13.3895 | accs: 0.5975
#  Model   30 | Train Loss: 4.7675 | accs: 0.7375
#  Model   80 | Train Loss: 0.9071 | accs: 0.9250
#  Model  180 | Train Loss: 0.0632 | accs: 0.9850
#  Model  380 | Train Loss: 0.0000 | accs: 1.0000
#  Model  780 | Train Loss: 0.0001 | accs: 1.0000
#
# Dataset type: data, additional samples: 780
#  Model    0 | Train Loss: 14.0399 | accs: 0.5962
#  Model   30 | Train Loss: 4.8525 | accs: 0.7137
#  Model   80 | Train Loss: 1.1807 | accs: 0.9025
#  Model  180 | Train Loss: 0.0606 | accs: 0.9838
#  Model  380 | Train Loss: 0.0001 | accs: 1.0000
#  Model  780 | Train Loss: 0.0001 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_30.pt
# Saved model: models_and_data/model_additional_30.pt
# ✅ Model saved to models_and_data\model_additional_80.pt
# Saved model: models_and_data/model_additional_80.pt
# ✅ Model saved to models_and_data\model_additional_180.pt
# Saved model: models_and_data/model_additional_180.pt
# ✅ Model saved to models_and_data\model_additional_380.pt
# Saved model: models_and_data/model_additional_380.pt
# ✅ Model saved to models_and_data\model_additional_780.pt
# Saved model: models_and_data/model_additional_780.pt
