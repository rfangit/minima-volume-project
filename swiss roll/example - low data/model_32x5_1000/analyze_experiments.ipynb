# %% [markdown]
# # Comparisons In A Given Loss Landscape

# %%
import os
import json
from pathlib import Path
import matplotlib.pyplot as plt

from minima_volume.analysis_funcs import (  grab_folder_names,
                                            load_base_train_size,
                                            list_additional_data,
                                            multiple_minima_fixed_landscape,
                                            fixed_landscape_minima_labels,
                                            plot_fixed_landscape_minima_pair,
                                            model_volume_across_targets,
                                            append_cutoff_points,
                                            varying_landscape_minima_labels,
                                            plot_minima_volume_vs_data_level,
)

loss_value = 0.1  # Loss value to analyze
data_level_log = False #Is the data log distributed?
base_output_dir = "analysis"  # Root folder to save all plots
os.makedirs(base_output_dir, exist_ok=True)

# Data for the loss landscape levels
experiment_folders, data_modifications = grab_folder_names()

base_train_size = load_base_train_size(experiment_folders[0])
model_data_sizes = list_additional_data(experiment_folders[0])

if data_modifications[0].startswith("data_"):
    base_shift = base_train_size  # Shift to reflect true dataset size
    
print("Experiment folders: ", experiment_folders)
print("Different data levels where loss landscapes were computed:", data_modifications)
print("The base train size is: ", base_train_size)
print("Data levels where models were trained: ", model_data_sizes)
# Out:
# First entry: Model_0, base_train_size = 20
# Experiment folders:  ['model_0_data_0', 'model_1_data_1', 'model_2_data_2', 'model_3_data_3', 'model_4_data_4', 'model_5_data_5', 'model_6_data_6', 'model_7_data_7', 'model_8_data_8', 'model_9_data_9']
# Different data levels where loss landscapes were computed: ['data_0', 'data_180', 'data_30', 'data_80']
# The base train size is:  20
# Data levels where models were trained:  [0, 180, 30, 380, 780, 80]

# %% [markdown]
# ## Plotting Different Model Volumes In A Landscape

# %%
for data_modification in data_modifications:
    print(f"\nProcessing data modification folder: {data_modification}")

    # Create output folder for this data_modification
    save_dir = os.path.join(base_output_dir, data_modification)
    os.makedirs(save_dir, exist_ok=True)

    # Get axis labels and titles
    labels = fixed_landscape_minima_labels(data_modification, base_train_size)

    # Extract minima landscapes
    all_mdl, all_log_rn, all_test_loss = multiple_minima_fixed_landscape(
        experiment_folders, data_modification, loss_value
    )

    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=data_level_log,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_log_volume",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="log_volume_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )

    ## Rank variant
    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_log_volume",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="log_volume_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )
# Out:
# Processing data modification folder: data_0
# Processing data modification folder: data_180
# Processing data modification folder: data_30
# Processing data modification folder: data_80

# %% [markdown]
# # Comparisons Across Loss Landscapes

# %% [markdown]
# Here, we track the performance of all models across all loss landscapes.

# %%
# For the poisoning experiments, this plot has no meaning

labels = varying_landscape_minima_labels(
    data_modification_folder=data_modifications[0], # Random choice to grab datatype from
    base_train_size=base_train_size,
)

results_dict = model_volume_across_targets(
    target_model_data_levels=model_data_sizes,
    loss_value=loss_value,
    experiment_folders=experiment_folders
)
results_with_cutoff = append_cutoff_points(results_dict, threshold=loss_value, base_dir=".")

plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          # NEW: needed for correct legend labels
    base_train_size=base_train_size,  # NEW: used for dataset size shifts
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = data_level_log,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels",
    xlabel_size=15, ylabel_size=15, title_size=15
)
# Out:
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Model_0: first exceedance at index 21 (value=0.2653621733188629, threshold=0.1)
# Appended cutoff for model_0_data_0 | target=0, cutoff_idx=21
# Model_0: first exceedance at index 20 (value=0.7891814708709717, threshold=0.1)
# Appended cutoff for model_1_data_1 | target=0, cutoff_idx=20
# Model_0: first exceedance at index 21 (value=0.6183644533157349, threshold=0.1)
# Appended cutoff for model_2_data_2 | target=0, cutoff_idx=21
# Model_0: first exceedance at index 20 (value=3.1435608863830566, threshold=0.1)
# Appended cutoff for model_3_data_3 | target=0, cutoff_idx=20
# Model_0: first exceedance at index 21 (value=0.6632968187332153, threshold=0.1)
# Appended cutoff for model_4_data_4 | target=0, cutoff_idx=21
# Model_0: first exceedance at index 24 (value=0.6274206638336182, threshold=0.1)
# Appended cutoff for model_5_data_5 | target=0, cutoff_idx=24
# Model_0: first exceedance at index 21 (value=0.4530050456523895, threshold=0.1)
# Appended cutoff for model_6_data_6 | target=0, cutoff_idx=21
# Model_0: first exceedance at index 21 (value=1.4790669679641724, threshold=0.1)
# Appended cutoff for model_7_data_7 | target=0, cutoff_idx=21
# Model_0: first exceedance at index 23 (value=0.7718717455863953, threshold=0.1)
# Appended cutoff for model_8_data_8 | target=0, cutoff_idx=23
# Model_0: first exceedance at index 20 (value=1.3454060554504395, threshold=0.1)
# Appended cutoff for model_9_data_9 | target=0, cutoff_idx=20
# Model_30: first exceedance at index 56 (value=0.24549119174480438, threshold=0.1)
# Appended cutoff for model_0_data_0 | target=30, cutoff_idx=56
# Model_30: first exceedance at index 50 (value=0.9531528353691101, threshold=0.1)
# Appended cutoff for model_1_data_1 | target=30, cutoff_idx=50
# Model_30: first exceedance at index 59 (value=0.5793095231056213, threshold=0.1)
# Appended cutoff for model_2_data_2 | target=30, cutoff_idx=59
# Model_30: first exceedance at index 53 (value=0.32796135544776917, threshold=0.1)
# Appended cutoff for model_3_data_3 | target=30, cutoff_idx=53
# Model_30: first exceedance at index 50 (value=0.1748388260602951, threshold=0.1)
# Appended cutoff for model_4_data_4 | target=30, cutoff_idx=50
# Model_30: first exceedance at index 50 (value=0.14853589236736298, threshold=0.1)
# Appended cutoff for model_5_data_5 | target=30, cutoff_idx=50
# Model_30: first exceedance at index 51 (value=0.2624453902244568, threshold=0.1)
# Appended cutoff for model_6_data_6 | target=30, cutoff_idx=51
# Model_30: first exceedance at index 63 (value=0.21706640720367432, threshold=0.1)
# Appended cutoff for model_7_data_7 | target=30, cutoff_idx=63
# Model_30: first exceedance at index 55 (value=0.10825787484645844, threshold=0.1)
# Appended cutoff for model_8_data_8 | target=30, cutoff_idx=55
# Model_30: first exceedance at index 55 (value=0.39113083481788635, threshold=0.1)
# Appended cutoff for model_9_data_9 | target=30, cutoff_idx=55
# Model_80: first exceedance at index 118 (value=0.12156709283590317, threshold=0.1)
# Appended cutoff for model_0_data_0 | target=80, cutoff_idx=118
# Model_80: first exceedance at index 221 (value=0.12869243323802948, threshold=0.1)
# Appended cutoff for model_1_data_1 | target=80, cutoff_idx=221
# Model_80: first exceedance at index 112 (value=0.34584951400756836, threshold=0.1)
# Appended cutoff for model_2_data_2 | target=80, cutoff_idx=112
# Model_80: first exceedance at index 118 (value=0.13238151371479034, threshold=0.1)
# Appended cutoff for model_3_data_3 | target=80, cutoff_idx=118
# Model_80: first exceedance at index 110 (value=0.27969416975975037, threshold=0.1)
# Appended cutoff for model_4_data_4 | target=80, cutoff_idx=110
# Model_80: first exceedance at index 103 (value=0.17961424589157104, threshold=0.1)
# Appended cutoff for model_5_data_5 | target=80, cutoff_idx=103
# Model_80: first exceedance at index 125 (value=0.11276035010814667, threshold=0.1)
# Appended cutoff for model_6_data_6 | target=80, cutoff_idx=125
# Model_80: first exceedance at index 121 (value=0.1309087574481964, threshold=0.1)
# Appended cutoff for model_7_data_7 | target=80, cutoff_idx=121
# Model_80: first exceedance at index 124 (value=0.11156431585550308, threshold=0.1)
# Appended cutoff for model_8_data_8 | target=80, cutoff_idx=124
# Model_80: first exceedance at index 113 (value=0.36812764406204224, threshold=0.1)
# Appended cutoff for model_9_data_9 | target=80, cutoff_idx=113
# ⚠️ Skipped model_0_data_0 (target=180): Model_180: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_1_data_1 (target=180): Model_180: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_2_data_2 (target=180): Model_180: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_3_data_3 (target=180): Model_180: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_4_data_4 (target=180): Model_180: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_5_data_5 (target=180): Model_180: loss curve never exceeds threshold=0.1
# Model_180: first exceedance at index 217 (value=0.1235809475183487, threshold=0.1)
# Appended cutoff for model_6_data_6 | target=180, cutoff_idx=217
# ⚠️ Skipped model_7_data_7 (target=180): Model_180: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_8_data_8 (target=180): Model_180: loss curve never exceeds threshold=0.1
# Model_180: first exceedance at index 252 (value=0.10005293041467667, threshold=0.1)
# Appended cutoff for model_9_data_9 | target=180, cutoff_idx=252
# ⚠️ Skipped model_0_data_0 (target=380): Model_380: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_1_data_1 (target=380): Model_380: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_2_data_2 (target=380): Model_380: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_3_data_3 (target=380): Model_380: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_4_data_4 (target=380): Model_380: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_5_data_5 (target=380): Model_380: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_6_data_6 (target=380): Model_380: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_7_data_7 (target=380): Model_380: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_8_data_8 (target=380): Model_380: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_9_data_9 (target=380): Model_380: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_0_data_0 (target=780): Model_780: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_1_data_1 (target=780): Model_780: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_2_data_2 (target=780): Model_780: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_3_data_3 (target=780): Model_780: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_4_data_4 (target=780): Model_780: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_5_data_5 (target=780): Model_780: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_6_data_6 (target=780): Model_780: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_7_data_7 (target=780): Model_780: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_8_data_8 (target=780): Model_780: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_9_data_9 (target=780): Model_780: loss curve never exceeds threshold=0.1
