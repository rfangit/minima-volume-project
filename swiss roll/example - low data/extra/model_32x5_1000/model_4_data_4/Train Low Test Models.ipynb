# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 4            
model_seed = 4           

# --- Training configuration ---
epochs = 1000            

# --- Dataset configuration ---
base_data_size = 20      
dataset_type = "data"   
dataset_quantities = [0, 30, 80, 180, 380, 780]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

test_dataset_size = 2000

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    base_data_size=base_data_size,
    dataset_quantities=dataset_quantities,
    test_dataset_size=test_dataset_size,
    noise=0.3, # default swiss params
    extra_pts=1000,
    dataset_type=dataset_type,
    seed=data_seed
)

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
        randperm_indices = False, #Not used for full batch training, which is what we do
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/1000: Train Loss 0.7098 | Test Loss 0.6975 | accs Train 0.5000 Test 0.5000
# Epoch 100/1000: Train Loss 0.0596 | Test Loss 3.2104 | accs Train 1.0000 Test 0.5907
# Epoch 200/1000: Train Loss 0.0018 | Test Loss 6.6225 | accs Train 1.0000 Test 0.5800
# Epoch 300/1000: Train Loss 0.0005 | Test Loss 7.8192 | accs Train 1.0000 Test 0.5777
# Epoch 400/1000: Train Loss 0.0002 | Test Loss 8.3531 | accs Train 1.0000 Test 0.5747
# Epoch 500/1000: Train Loss 0.0001 | Test Loss 8.7334 | accs Train 1.0000 Test 0.5713
# Epoch 600/1000: Train Loss 0.0001 | Test Loss 9.0031 | accs Train 1.0000 Test 0.5683
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 9.2194 | accs Train 1.0000 Test 0.5660
# Epoch 800/1000: Train Loss 0.0000 | Test Loss 9.4047 | accs Train 1.0000 Test 0.5643
# Epoch 900/1000: Train Loss 0.0000 | Test Loss 9.5652 | accs Train 1.0000 Test 0.5630
# Epoch 1000/1000: Train Loss 0.0000 | Test Loss 9.7069 | accs Train 1.0000 Test 0.5617
# Completed training with 0 additional samples of data
# Epoch 1/1000: Train Loss 0.6991 | Test Loss 0.6972 | accs Train 0.5400 Test 0.5000
# Epoch 100/1000: Train Loss 0.4260 | Test Loss 0.7340 | accs Train 0.8200 Test 0.5962
# Epoch 200/1000: Train Loss 0.0598 | Test Loss 1.9675 | accs Train 0.9800 Test 0.6435
# Epoch 300/1000: Train Loss 0.0035 | Test Loss 3.4585 | accs Train 1.0000 Test 0.6585
# Epoch 400/1000: Train Loss 0.0007 | Test Loss 4.1770 | accs Train 1.0000 Test 0.6630
# Epoch 500/1000: Train Loss 0.0003 | Test Loss 4.5954 | accs Train 1.0000 Test 0.6657
# Epoch 600/1000: Train Loss 0.0002 | Test Loss 4.8555 | accs Train 1.0000 Test 0.6655
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 5.0386 | accs Train 1.0000 Test 0.6653
# Epoch 800/1000: Train Loss 0.0001 | Test Loss 5.1961 | accs Train 1.0000 Test 0.6655
# Epoch 900/1000: Train Loss 0.0001 | Test Loss 5.3378 | accs Train 1.0000 Test 0.6653
# Epoch 1000/1000: Train Loss 0.0000 | Test Loss 5.4456 | accs Train 1.0000 Test 0.6663
# Completed training with 30 additional samples of data
# Epoch 1/1000: Train Loss 0.6861 | Test Loss 0.6974 | accs Train 0.5900 Test 0.5000
# Epoch 100/1000: Train Loss 0.4338 | Test Loss 0.6856 | accs Train 0.7600 Test 0.6012
# Epoch 200/1000: Train Loss 0.1396 | Test Loss 0.7776 | accs Train 0.9500 Test 0.7420
# Epoch 300/1000: Train Loss 0.0491 | Test Loss 1.2624 | accs Train 0.9700 Test 0.7788
# Epoch 400/1000: Train Loss 0.0119 | Test Loss 1.6640 | accs Train 1.0000 Test 0.8133
# Epoch 500/1000: Train Loss 0.0029 | Test Loss 1.8513 | accs Train 1.0000 Test 0.8227
# Epoch 600/1000: Train Loss 0.0011 | Test Loss 1.9646 | accs Train 1.0000 Test 0.8277
# Epoch 700/1000: Train Loss 0.0006 | Test Loss 2.0300 | accs Train 1.0000 Test 0.8330
# Epoch 800/1000: Train Loss 0.0004 | Test Loss 2.0761 | accs Train 1.0000 Test 0.8355
# Epoch 900/1000: Train Loss 0.0003 | Test Loss 2.1069 | accs Train 1.0000 Test 0.8387
# Epoch 1000/1000: Train Loss 0.0002 | Test Loss 2.1361 | accs Train 1.0000 Test 0.8405
# Completed training with 80 additional samples of data
# Epoch 1/1000: Train Loss 0.6948 | Test Loss 0.6969 | accs Train 0.5400 Test 0.5000
# Epoch 100/1000: Train Loss 0.5195 | Test Loss 0.6296 | accs Train 0.7250 Test 0.6272
# Epoch 200/1000: Train Loss 0.0941 | Test Loss 0.1623 | accs Train 0.9950 Test 0.9505
# Epoch 300/1000: Train Loss 0.0025 | Test Loss 0.0367 | accs Train 1.0000 Test 0.9880
# Epoch 400/1000: Train Loss 0.0008 | Test Loss 0.0341 | accs Train 1.0000 Test 0.9885
# Epoch 500/1000: Train Loss 0.0004 | Test Loss 0.0338 | accs Train 1.0000 Test 0.9898
# Epoch 600/1000: Train Loss 0.0002 | Test Loss 0.0334 | accs Train 1.0000 Test 0.9902
# Epoch 700/1000: Train Loss 0.0002 | Test Loss 0.0335 | accs Train 1.0000 Test 0.9905
# Epoch 800/1000: Train Loss 0.0001 | Test Loss 0.0337 | accs Train 1.0000 Test 0.9905
# Epoch 900/1000: Train Loss 0.0001 | Test Loss 0.0340 | accs Train 1.0000 Test 0.9908
# Epoch 1000/1000: Train Loss 0.0001 | Test Loss 0.0345 | accs Train 1.0000 Test 0.9905
# Completed training with 180 additional samples of data
# Epoch 1/1000: Train Loss 0.7028 | Test Loss 0.6969 | accs Train 0.5000 Test 0.5000
# Epoch 100/1000: Train Loss 0.5692 | Test Loss 0.6105 | accs Train 0.6200 Test 0.6020
# Epoch 200/1000: Train Loss 0.0208 | Test Loss 0.0431 | accs Train 1.0000 Test 0.9922
# Epoch 300/1000: Train Loss 0.0013 | Test Loss 0.0286 | accs Train 1.0000 Test 0.9925
# Epoch 400/1000: Train Loss 0.0005 | Test Loss 0.0297 | accs Train 1.0000 Test 0.9928
# Epoch 500/1000: Train Loss 0.0003 | Test Loss 0.0307 | accs Train 1.0000 Test 0.9930
# Epoch 600/1000: Train Loss 0.0002 | Test Loss 0.0314 | accs Train 1.0000 Test 0.9932
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 0.0320 | accs Train 1.0000 Test 0.9932
# Epoch 800/1000: Train Loss 0.0001 | Test Loss 0.0326 | accs Train 1.0000 Test 0.9935
# Epoch 900/1000: Train Loss 0.0001 | Test Loss 0.0331 | accs Train 1.0000 Test 0.9938
# Epoch 1000/1000: Train Loss 0.0001 | Test Loss 0.0335 | accs Train 1.0000 Test 0.9940
# Completed training with 380 additional samples of data
# Epoch 1/1000: Train Loss 0.7018 | Test Loss 0.6969 | accs Train 0.5062 Test 0.5000
# Epoch 100/1000: Train Loss 0.5442 | Test Loss 0.5923 | accs Train 0.6338 Test 0.5860
# Epoch 200/1000: Train Loss 0.0235 | Test Loss 0.0383 | accs Train 0.9975 Test 0.9908
# Epoch 300/1000: Train Loss 0.0015 | Test Loss 0.0130 | accs Train 1.0000 Test 0.9955
# Epoch 400/1000: Train Loss 0.0005 | Test Loss 0.0120 | accs Train 1.0000 Test 0.9955
# Epoch 500/1000: Train Loss 0.0003 | Test Loss 0.0119 | accs Train 1.0000 Test 0.9958
# Epoch 600/1000: Train Loss 0.0002 | Test Loss 0.0120 | accs Train 1.0000 Test 0.9958
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 0.0122 | accs Train 1.0000 Test 0.9958
# Epoch 800/1000: Train Loss 0.0001 | Test Loss 0.0124 | accs Train 1.0000 Test 0.9958
# Epoch 900/1000: Train Loss 0.0001 | Test Loss 0.0126 | accs Train 1.0000 Test 0.9958
# Epoch 1000/1000: Train Loss 0.0000 | Test Loss 0.0128 | accs Train 1.0000 Test 0.9958
# Completed training with 780 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 9.7069 | accs: 0.5617
#   30 samples | Test Loss: 5.4456 | accs: 0.6663
#   80 samples | Test Loss: 2.1361 | accs: 0.8405
#  180 samples | Test Loss: 0.0345 | accs: 0.9905
#  380 samples | Test Loss: 0.0335 | accs: 0.9940
#  780 samples | Test Loss: 0.0128 | accs: 0.9958
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model   30 | Train Loss: 0.0000 | accs: 1.0000
#  Model   80 | Train Loss: 0.0004 | accs: 1.0000
#  Model  180 | Train Loss: 0.0001 | accs: 1.0000
#  Model  380 | Train Loss: 0.0000 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 30
#  Model    0 | Train Loss: 4.5473 | accs: 0.7400
#  Model   30 | Train Loss: 0.0000 | accs: 1.0000
#  Model   80 | Train Loss: 0.0003 | accs: 1.0000
#  Model  180 | Train Loss: 0.0001 | accs: 1.0000
#  Model  380 | Train Loss: 0.0000 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 80
#  Model    0 | Train Loss: 8.1418 | accs: 0.6600
#  Model   30 | Train Loss: 3.4139 | accs: 0.7800
#  Model   80 | Train Loss: 0.0002 | accs: 1.0000
#  Model  180 | Train Loss: 0.0001 | accs: 1.0000
#  Model  380 | Train Loss: 0.0000 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 180
#  Model    0 | Train Loss: 8.4997 | accs: 0.6100
#  Model   30 | Train Loss: 4.3906 | accs: 0.7150
#  Model   80 | Train Loss: 1.0502 | accs: 0.9050
#  Model  180 | Train Loss: 0.0001 | accs: 1.0000
#  Model  380 | Train Loss: 0.0001 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 380
#  Model    0 | Train Loss: 9.0030 | accs: 0.5900
#  Model   30 | Train Loss: 4.7444 | accs: 0.6925
#  Model   80 | Train Loss: 1.8273 | accs: 0.8550
#  Model  180 | Train Loss: 0.0024 | accs: 1.0000
#  Model  380 | Train Loss: 0.0001 | accs: 1.0000
#  Model  780 | Train Loss: 0.0001 | accs: 1.0000
#
# Dataset type: data, additional samples: 780
#  Model    0 | Train Loss: 9.3572 | accs: 0.5887
#  Model   30 | Train Loss: 5.2427 | accs: 0.6775
#  Model   80 | Train Loss: 1.8855 | accs: 0.8538
#  Model  180 | Train Loss: 0.0040 | accs: 1.0000
#  Model  380 | Train Loss: 0.0001 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_30.pt
# Saved model: models_and_data/model_additional_30.pt
# ✅ Model saved to models_and_data\model_additional_80.pt
# Saved model: models_and_data/model_additional_80.pt
# ✅ Model saved to models_and_data\model_additional_180.pt
# Saved model: models_and_data/model_additional_180.pt
# ✅ Model saved to models_and_data\model_additional_380.pt
# Saved model: models_and_data/model_additional_380.pt
# ✅ Model saved to models_and_data\model_additional_780.pt
# Saved model: models_and_data/model_additional_780.pt
