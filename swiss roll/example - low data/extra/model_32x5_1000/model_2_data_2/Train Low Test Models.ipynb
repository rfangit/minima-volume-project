# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 2            
model_seed = 2           

# --- Training configuration ---
epochs = 1000            

# --- Dataset configuration ---
base_data_size = 20      
dataset_type = "data"   
dataset_quantities = [0, 30, 80, 180, 380, 780]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

test_dataset_size = 2000

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    base_data_size=base_data_size,
    dataset_quantities=dataset_quantities,
    test_dataset_size=test_dataset_size,
    noise=0.3, # default swiss params
    extra_pts=1000,
    dataset_type=dataset_type,
    seed=data_seed
)

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
        randperm_indices = False, #Not used for full batch training, which is what we do
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/1000: Train Loss 0.6944 | Test Loss 0.6932 | accs Train 0.5000 Test 0.5000
# Epoch 100/1000: Train Loss 0.1425 | Test Loss 2.2972 | accs Train 0.9500 Test 0.4963
# Epoch 200/1000: Train Loss 0.0013 | Test Loss 6.0021 | accs Train 1.0000 Test 0.5035
# Epoch 300/1000: Train Loss 0.0004 | Test Loss 6.8270 | accs Train 1.0000 Test 0.5070
# Epoch 400/1000: Train Loss 0.0002 | Test Loss 7.2880 | accs Train 1.0000 Test 0.5085
# Epoch 500/1000: Train Loss 0.0001 | Test Loss 7.6119 | accs Train 1.0000 Test 0.5082
# Epoch 600/1000: Train Loss 0.0001 | Test Loss 7.8630 | accs Train 1.0000 Test 0.5085
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 8.0666 | accs Train 1.0000 Test 0.5092
# Epoch 800/1000: Train Loss 0.0000 | Test Loss 8.2355 | accs Train 1.0000 Test 0.5105
# Epoch 900/1000: Train Loss 0.0000 | Test Loss 8.3802 | accs Train 1.0000 Test 0.5112
# Epoch 1000/1000: Train Loss 0.0000 | Test Loss 8.5067 | accs Train 1.0000 Test 0.5112
# Completed training with 0 additional samples of data
# Epoch 1/1000: Train Loss 0.6847 | Test Loss 0.6932 | accs Train 0.6000 Test 0.5000
# Epoch 100/1000: Train Loss 0.4204 | Test Loss 1.1124 | accs Train 0.7600 Test 0.5490
# Epoch 200/1000: Train Loss 0.0054 | Test Loss 4.5629 | accs Train 1.0000 Test 0.6705
# Epoch 300/1000: Train Loss 0.0008 | Test Loss 5.6280 | accs Train 1.0000 Test 0.6765
# Epoch 400/1000: Train Loss 0.0003 | Test Loss 6.1311 | accs Train 1.0000 Test 0.6767
# Epoch 500/1000: Train Loss 0.0002 | Test Loss 6.4532 | accs Train 1.0000 Test 0.6785
# Epoch 600/1000: Train Loss 0.0001 | Test Loss 6.6902 | accs Train 1.0000 Test 0.6787
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 6.8712 | accs Train 1.0000 Test 0.6777
# Epoch 800/1000: Train Loss 0.0000 | Test Loss 7.0445 | accs Train 1.0000 Test 0.6783
# Epoch 900/1000: Train Loss 0.0000 | Test Loss 7.1768 | accs Train 1.0000 Test 0.6793
# Epoch 1000/1000: Train Loss 0.0000 | Test Loss 7.2862 | accs Train 1.0000 Test 0.6797
# Completed training with 30 additional samples of data
# Epoch 1/1000: Train Loss 0.6882 | Test Loss 0.6928 | accs Train 0.5600 Test 0.5000
# Epoch 100/1000: Train Loss 0.5237 | Test Loss 0.6226 | accs Train 0.7200 Test 0.6300
# Epoch 200/1000: Train Loss 0.0538 | Test Loss 0.8531 | accs Train 0.9800 Test 0.8137
# Epoch 300/1000: Train Loss 0.0052 | Test Loss 1.0071 | accs Train 1.0000 Test 0.8548
# Epoch 400/1000: Train Loss 0.0013 | Test Loss 1.1301 | accs Train 1.0000 Test 0.8615
# Epoch 500/1000: Train Loss 0.0006 | Test Loss 1.1887 | accs Train 1.0000 Test 0.8655
# Epoch 600/1000: Train Loss 0.0003 | Test Loss 1.2310 | accs Train 1.0000 Test 0.8678
# Epoch 700/1000: Train Loss 0.0002 | Test Loss 1.2566 | accs Train 1.0000 Test 0.8702
# Epoch 800/1000: Train Loss 0.0002 | Test Loss 1.2769 | accs Train 1.0000 Test 0.8718
# Epoch 900/1000: Train Loss 0.0001 | Test Loss 1.2979 | accs Train 1.0000 Test 0.8725
# Epoch 1000/1000: Train Loss 0.0001 | Test Loss 1.3185 | accs Train 1.0000 Test 0.8740
# Completed training with 80 additional samples of data
# Epoch 1/1000: Train Loss 0.6941 | Test Loss 0.6927 | accs Train 0.4950 Test 0.5000
# Epoch 100/1000: Train Loss 0.5534 | Test Loss 0.5983 | accs Train 0.6550 Test 0.6475
# Epoch 200/1000: Train Loss 0.0623 | Test Loss 0.1042 | accs Train 0.9950 Test 0.9782
# Epoch 300/1000: Train Loss 0.0018 | Test Loss 0.0226 | accs Train 1.0000 Test 0.9950
# Epoch 400/1000: Train Loss 0.0006 | Test Loss 0.0219 | accs Train 1.0000 Test 0.9942
# Epoch 500/1000: Train Loss 0.0003 | Test Loss 0.0221 | accs Train 1.0000 Test 0.9942
# Epoch 600/1000: Train Loss 0.0002 | Test Loss 0.0225 | accs Train 1.0000 Test 0.9940
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 0.0231 | accs Train 1.0000 Test 0.9940
# Epoch 800/1000: Train Loss 0.0001 | Test Loss 0.0237 | accs Train 1.0000 Test 0.9940
# Epoch 900/1000: Train Loss 0.0001 | Test Loss 0.0242 | accs Train 1.0000 Test 0.9940
# Epoch 1000/1000: Train Loss 0.0001 | Test Loss 0.0246 | accs Train 1.0000 Test 0.9940
# Completed training with 180 additional samples of data
# Epoch 1/1000: Train Loss 0.6933 | Test Loss 0.6926 | accs Train 0.5050 Test 0.5000
# Epoch 100/1000: Train Loss 0.5787 | Test Loss 0.5770 | accs Train 0.6550 Test 0.6615
# Epoch 200/1000: Train Loss 0.0173 | Test Loss 0.0222 | accs Train 1.0000 Test 0.9970
# Epoch 300/1000: Train Loss 0.0006 | Test Loss 0.0053 | accs Train 1.0000 Test 0.9985
# Epoch 400/1000: Train Loss 0.0003 | Test Loss 0.0047 | accs Train 1.0000 Test 0.9985
# Epoch 500/1000: Train Loss 0.0001 | Test Loss 0.0046 | accs Train 1.0000 Test 0.9985
# Epoch 600/1000: Train Loss 0.0001 | Test Loss 0.0045 | accs Train 1.0000 Test 0.9985
# Epoch 700/1000: Train Loss 0.0001 | Test Loss 0.0045 | accs Train 1.0000 Test 0.9985
# Epoch 800/1000: Train Loss 0.0001 | Test Loss 0.0044 | accs Train 1.0000 Test 0.9985
# Epoch 900/1000: Train Loss 0.0000 | Test Loss 0.0044 | accs Train 1.0000 Test 0.9988
# Epoch 1000/1000: Train Loss 0.0000 | Test Loss 0.0044 | accs Train 1.0000 Test 0.9988
# Completed training with 380 additional samples of data
# Epoch 1/1000: Train Loss 0.6964 | Test Loss 0.6927 | accs Train 0.4725 Test 0.5000
# Epoch 100/1000: Train Loss 0.5783 | Test Loss 0.5741 | accs Train 0.6737 Test 0.6835
# Epoch 200/1000: Train Loss 0.0544 | Test Loss 0.0568 | accs Train 1.0000 Test 0.9968
# Epoch 300/1000: Train Loss 0.0007 | Test Loss 0.0052 | accs Train 1.0000 Test 0.9985
# Epoch 400/1000: Train Loss 0.0002 | Test Loss 0.0046 | accs Train 1.0000 Test 0.9985
# Epoch 500/1000: Train Loss 0.0001 | Test Loss 0.0045 | accs Train 1.0000 Test 0.9985
# Epoch 600/1000: Train Loss 0.0001 | Test Loss 0.0045 | accs Train 1.0000 Test 0.9985
# Epoch 700/1000: Train Loss 0.0000 | Test Loss 0.0045 | accs Train 1.0000 Test 0.9985
# Epoch 800/1000: Train Loss 0.0000 | Test Loss 0.0045 | accs Train 1.0000 Test 0.9985
# Epoch 900/1000: Train Loss 0.0000 | Test Loss 0.0045 | accs Train 1.0000 Test 0.9985
# Epoch 1000/1000: Train Loss 0.0000 | Test Loss 0.0049 | accs Train 1.0000 Test 0.9985
# Completed training with 780 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 8.5067 | accs: 0.5112
#   30 samples | Test Loss: 7.2862 | accs: 0.6797
#   80 samples | Test Loss: 1.3185 | accs: 0.8740
#  180 samples | Test Loss: 0.0246 | accs: 0.9940
#  380 samples | Test Loss: 0.0044 | accs: 0.9988
#  780 samples | Test Loss: 0.0049 | accs: 0.9985
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model   30 | Train Loss: 0.0000 | accs: 1.0000
#  Model   80 | Train Loss: 0.0002 | accs: 1.0000
#  Model  180 | Train Loss: 0.0001 | accs: 1.0000
#  Model  380 | Train Loss: 0.0001 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 30
#  Model    0 | Train Loss: 4.5454 | accs: 0.6400
#  Model   30 | Train Loss: 0.0000 | accs: 1.0000
#  Model   80 | Train Loss: 0.0001 | accs: 1.0000
#  Model  180 | Train Loss: 0.0001 | accs: 1.0000
#  Model  380 | Train Loss: 0.0000 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 80
#  Model    0 | Train Loss: 8.1761 | accs: 0.5800
#  Model   30 | Train Loss: 3.9612 | accs: 0.8500
#  Model   80 | Train Loss: 0.0001 | accs: 1.0000
#  Model  180 | Train Loss: 0.0000 | accs: 1.0000
#  Model  380 | Train Loss: 0.0000 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 180
#  Model    0 | Train Loss: 8.6892 | accs: 0.5350
#  Model   30 | Train Loss: 5.9807 | accs: 0.7400
#  Model   80 | Train Loss: 0.7274 | accs: 0.9350
#  Model  180 | Train Loss: 0.0001 | accs: 1.0000
#  Model  380 | Train Loss: 0.0000 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 380
#  Model    0 | Train Loss: 8.1113 | accs: 0.5325
#  Model   30 | Train Loss: 6.2877 | accs: 0.7250
#  Model   80 | Train Loss: 1.1193 | accs: 0.8975
#  Model  180 | Train Loss: 0.0025 | accs: 1.0000
#  Model  380 | Train Loss: 0.0000 | accs: 1.0000
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 780
#  Model    0 | Train Loss: 8.3285 | accs: 0.5200
#  Model   30 | Train Loss: 6.7373 | accs: 0.7050
#  Model   80 | Train Loss: 1.1864 | accs: 0.8962
#  Model  180 | Train Loss: 0.0093 | accs: 0.9962
#  Model  380 | Train Loss: 0.0020 | accs: 0.9988
#  Model  780 | Train Loss: 0.0000 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_30.pt
# Saved model: models_and_data/model_additional_30.pt
# ✅ Model saved to models_and_data\model_additional_80.pt
# Saved model: models_and_data/model_additional_80.pt
# ✅ Model saved to models_and_data\model_additional_180.pt
# Saved model: models_and_data/model_additional_180.pt
# ✅ Model saved to models_and_data\model_additional_380.pt
# Saved model: models_and_data/model_additional_380.pt
# ✅ Model saved to models_and_data\model_additional_780.pt
# Saved model: models_and_data/model_additional_780.pt
