# %%
import os
import subprocess
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock

# ---------- Configuration ----------
MAX_WORKERS = 1
EXCLUDE_PREFIXES = [
    '__pycache__', 
    '.ipynb_checkpoints', 
    'base', 
    'completed runs', 
    'to do', 
    'analysis'
]

# Lock for thread-safe printing
print_lock = Lock()

# ---------- Core Helpers ----------
def run_notebook(folder: str, notebook_name: str) -> str:
    """
    Execute a Jupyter notebook in place using nbconvert.
    Returns a status string with execution time.
    All printing inside this function is thread-safe.
    """
    notebook_path = os.path.join(folder, notebook_name)
    if not os.path.exists(notebook_path):
        with print_lock:
            print(f"SKIP: {notebook_name} not found in {folder}", flush=True)
        return f"SKIP: {notebook_name} not found in {folder}"

    with print_lock:
        print(f"🔹 Running {notebook_path}...", flush=True)

    start_time = time.time()
    try:
        subprocess.run(
            [
                'jupyter', 'nbconvert', '--to', 'notebook',
                '--execute', notebook_path, '--inplace',
                '--ExecutePreprocessor.timeout=-1'
            ],
            check=True,
            capture_output=True,
            text=True
        )
        elapsed = time.time() - start_time
        return f"✅ SUCCESS: {folder}/{notebook_name} (took {elapsed:.2f}s)"
    except subprocess.CalledProcessError as e:
        elapsed = time.time() - start_time
        stderr_clean = e.stderr.strip()
        return f"❌ ERROR: {folder}/{notebook_name} - {stderr_clean} (took {elapsed:.2f}s)"

def find_folders(base_dir: str = '.') -> list[str]:
    """Return a list of folders to process, excluding certain prefixes."""
    return [
        d for d in os.listdir(base_dir)
        if os.path.isdir(d) and not any(d.startswith(prefix) for prefix in EXCLUDE_PREFIXES)
    ]

def run_in_parallel(folders: list[str], notebook_names: list[str]):
    """Run one or more notebooks across all folders in parallel, with thread-safe printing."""
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [
            executor.submit(run_notebook, folder, nb)
            for folder in folders
            for nb in notebook_names
        ]

        for future in as_completed(futures):
            msg = future.result().strip()
            with print_lock:
                print(msg)
    with print_lock:
        print("✅ All done!")

# ---------- Specialized Variants ----------
def run_random_perturbs_parallel():
    """Run Random Perturbs.ipynb across all model_* folders."""
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders for Random Perturbs.")
    run_in_parallel(folders, ["Random Perturbs.ipynb"])

def run_volume_parallel():
    """Run all notebooks containing 'Volume Cutoff' or 'Volume Estimation' across folders."""
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders for Volume notebooks.")

    notebook_names = []
    if folders:
        for nb in os.listdir(folders[0]):
            if nb.endswith(".ipynb") and ("Volume Cutoff" in nb or "Volume Estimation" in nb):
                notebook_names.append(nb)

    if not notebook_names:
        with print_lock:
            print("⚠️ No Volume notebooks found in reference folder.")
        return

    with print_lock:
        print(f"Will run these notebooks: {notebook_names}")
    run_in_parallel(folders, notebook_names)

def run_nb_parallel():
    """Generic function for ad-hoc notebook runs (prompt user)."""
    notebook_name = input("Enter notebook name (without .ipynb): ").strip() + ".ipynb"
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders to process.")
    run_in_parallel(folders, [notebook_name])

run_random_perturbs_parallel()
# Out:
# Found 50 folders for Random Perturbs.
# 🔹 Running model_40_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_40_data_10/Random Perturbs.ipynb (took 145.16s)
# 🔹 Running model_0_data_10/Random Perturbs.ipynb...
# 🔹 Running model_22_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_0_data_10/Random Perturbs.ipynb (took 133.78s)
# 🔹 Running model_32_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_22_data_10/Random Perturbs.ipynb (took 186.48s)
# ✅ SUCCESS: model_32_data_10/Random Perturbs.ipynb (took 133.70s)
# 🔹 Running model_14_data_10/Random Perturbs.ipynb...
# 🔹 Running model_49_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_14_data_10/Random Perturbs.ipynb (took 170.39s)
# 🔹 Running model_9_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_49_data_10/Random Perturbs.ipynb (took 134.36s)
# ✅ SUCCESS: model_9_data_10/Random Perturbs.ipynb (took 135.91s)
# 🔹 Running model_15_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_15_data_10/Random Perturbs.ipynb (took 133.24s)
# 🔹 Running model_8_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_8_data_10/Random Perturbs.ipynb (took 147.60s)
# 🔹 Running model_48_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_48_data_10/Random Perturbs.ipynb (took 134.17s)
# 🔹 Running model_1_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_1_data_10/Random Perturbs.ipynb (took 132.96s)
# 🔹 Running model_41_data_10/Random Perturbs.ipynb...
# 🔹 Running model_33_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_41_data_10/Random Perturbs.ipynb (took 132.44s)
# 🔹 Running model_23_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_33_data_10/Random Perturbs.ipynb (took 155.57s)
# ✅ SUCCESS: model_23_data_10/Random Perturbs.ipynb (took 132.82s)
# 🔹 Running model_17_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_17_data_10/Random Perturbs.ipynb (took 131.94s)
# 🔹 Running model_38_data_10/Random Perturbs.ipynb...
# 🔹 Running model_28_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_38_data_10/Random Perturbs.ipynb (took 144.98s)
# 🔹 Running model_21_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_28_data_10/Random Perturbs.ipynb (took 144.95s)
# 🔹 Running model_31_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_21_data_10/Random Perturbs.ipynb (took 144.80s)
# 🔹 Running model_3_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_31_data_10/Random Perturbs.ipynb (took 149.49s)
# 🔹 Running model_43_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_3_data_10/Random Perturbs.ipynb (took 145.29s)
# 🔹 Running model_30_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_43_data_10/Random Perturbs.ipynb (took 187.95s)
# 🔹 Running model_20_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_30_data_10/Random Perturbs.ipynb (took 155.50s)
# 🔹 Running model_42_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_20_data_10/Random Perturbs.ipynb (took 149.25s)
# 🔹 Running model_2_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_42_data_10/Random Perturbs.ipynb (took 175.42s)
# 🔹 Running model_16_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_2_data_10/Random Perturbs.ipynb (took 165.87s)
# 🔹 Running model_29_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_16_data_10/Random Perturbs.ipynb (took 133.19s)
# 🔹 Running model_39_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_29_data_10/Random Perturbs.ipynb (took 145.17s)
# 🔹 Running model_13_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_39_data_10/Random Perturbs.ipynb (took 132.87s)
# 🔹 Running model_25_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_13_data_10/Random Perturbs.ipynb (took 145.37s)
# ✅ SUCCESS: model_25_data_10/Random Perturbs.ipynb (took 177.78s)
# 🔹 Running model_35_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_35_data_10/Random Perturbs.ipynb (took 132.88s)
# 🔹 Running model_47_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_47_data_10/Random Perturbs.ipynb (took 144.12s)
# 🔹 Running model_7_data_10/Random Perturbs.ipynb...
# 🔹 Running model_34_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_7_data_10/Random Perturbs.ipynb (took 169.21s)
# 🔹 Running model_24_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_34_data_10/Random Perturbs.ipynb (took 189.34s)
# 🔹 Running model_6_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_24_data_10/Random Perturbs.ipynb (took 165.69s)
# 🔹 Running model_46_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_6_data_10/Random Perturbs.ipynb (took 132.72s)
# 🔹 Running model_12_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_46_data_10/Random Perturbs.ipynb (took 132.76s)
# 🔹 Running model_4_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_12_data_10/Random Perturbs.ipynb (took 144.59s)
# 🔹 Running model_44_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_4_data_10/Random Perturbs.ipynb (took 169.74s)
# ✅ SUCCESS: model_44_data_10/Random Perturbs.ipynb (took 132.89s)
# 🔹 Running model_26_data_10/Random Perturbs.ipynb...
# 🔹 Running model_36_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_26_data_10/Random Perturbs.ipynb (took 133.90s)
# 🔹 Running model_19_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_36_data_10/Random Perturbs.ipynb (took 144.99s)
# 🔹 Running model_10_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_19_data_10/Random Perturbs.ipynb (took 146.15s)
# ✅ SUCCESS: model_10_data_10/Random Perturbs.ipynb (took 150.04s)
# 🔹 Running model_11_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_11_data_10/Random Perturbs.ipynb (took 149.45s)
# 🔹 Running model_45_data_10/Random Perturbs.ipynb...
# 🔹 Running model_5_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_45_data_10/Random Perturbs.ipynb (took 181.52s)
# ✅ SUCCESS: model_5_data_10/Random Perturbs.ipynb (took 147.18s)
# 🔹 Running model_37_data_10/Random Perturbs.ipynb...
# 🔹 Running model_27_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_37_data_10/Random Perturbs.ipynb (took 183.07s)
# 🔹 Running model_18_data_10/Random Perturbs.ipynb...
# ✅ SUCCESS: model_27_data_10/Random Perturbs.ipynb (took 147.16s)
# ✅ SUCCESS: model_18_data_10/Random Perturbs.ipynb (took 144.14s)
# ✅ All done!
