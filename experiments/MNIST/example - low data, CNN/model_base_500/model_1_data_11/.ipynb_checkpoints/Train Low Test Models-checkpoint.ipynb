# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 11            
model_seed = 1           

# --- Training configuration ---
epochs = 200            

# --- Dataset configuration ---
base_data_size = 60      
dataset_type = "data"   
dataset_quantities = [0, 600-60, 2000 - 60, 6000 - 60, 20000 - 60, 60000 - 60]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import MNIST_CNN_model_data as model_module

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device=device
)

# CNN-specific initialization parameters
conv_channels = [32, 64]  # number of filters per conv layer
fc_dims = [128]           # fully connected layer sizes

# Grab model
model_template = model_module.get_model(
    conv_channels=conv_channels,
    fc_dims=fc_dims,
    device=device,
    seed=model_seed
)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = min(len(x_train), 1024)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=20,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/200: Train Loss 2.3165 | Test Loss 2.2796 | accs Train 0.1000 Test 0.1188
# Epoch 20/200: Train Loss 0.0064 | Test Loss 1.7166 | accs Train 1.0000 Test 0.6791
# Epoch 40/200: Train Loss 0.0001 | Test Loss 2.5307 | accs Train 1.0000 Test 0.6853
# Epoch 60/200: Train Loss 0.0000 | Test Loss 2.6625 | accs Train 1.0000 Test 0.6880
# Epoch 80/200: Train Loss 0.0000 | Test Loss 2.6833 | accs Train 1.0000 Test 0.6881
# Epoch 100/200: Train Loss 0.0000 | Test Loss 2.6852 | accs Train 1.0000 Test 0.6876
# Epoch 120/200: Train Loss 0.0000 | Test Loss 2.6796 | accs Train 1.0000 Test 0.6882
# Epoch 140/200: Train Loss 0.0000 | Test Loss 2.6728 | accs Train 1.0000 Test 0.6889
# Epoch 160/200: Train Loss 0.0000 | Test Loss 2.6668 | accs Train 1.0000 Test 0.6891
# Epoch 180/200: Train Loss 0.0000 | Test Loss 2.6616 | accs Train 1.0000 Test 0.6889
# Epoch 200/200: Train Loss 0.0000 | Test Loss 2.6573 | accs Train 1.0000 Test 0.6892
# Completed training with 0 additional samples of data
# Epoch 1/200: Train Loss 2.3107 | Test Loss 2.1879 | accs Train 0.0617 Test 0.1880
# Epoch 20/200: Train Loss 0.1822 | Test Loss 0.4230 | accs Train 0.9467 Test 0.8855
# Epoch 40/200: Train Loss 0.0167 | Test Loss 0.4738 | accs Train 1.0000 Test 0.8935
# Epoch 60/200: Train Loss 0.0031 | Test Loss 0.4934 | accs Train 1.0000 Test 0.9042
# Epoch 80/200: Train Loss 0.0014 | Test Loss 0.5013 | accs Train 1.0000 Test 0.9057
# Epoch 100/200: Train Loss 0.0009 | Test Loss 0.5096 | accs Train 1.0000 Test 0.9062
# Epoch 120/200: Train Loss 0.0007 | Test Loss 0.5158 | accs Train 1.0000 Test 0.9070
# Epoch 140/200: Train Loss 0.0005 | Test Loss 0.5214 | accs Train 1.0000 Test 0.9074
# Epoch 160/200: Train Loss 0.0004 | Test Loss 0.5291 | accs Train 1.0000 Test 0.9076
# Epoch 180/200: Train Loss 0.0003 | Test Loss 0.5338 | accs Train 1.0000 Test 0.9079
# Epoch 200/200: Train Loss 0.0003 | Test Loss 0.5384 | accs Train 1.0000 Test 0.9081
# Completed training with 540 additional samples of data
# Epoch 1/200: Train Loss 2.2384 | Test Loss 1.9815 | accs Train 0.2815 Test 0.5290
# Epoch 20/200: Train Loss 0.1312 | Test Loss 0.2334 | accs Train 0.9665 Test 0.9313
# Epoch 40/200: Train Loss 0.0249 | Test Loss 0.1782 | accs Train 0.9980 Test 0.9476
# Epoch 60/200: Train Loss 0.0062 | Test Loss 0.1799 | accs Train 1.0000 Test 0.9523
# Epoch 80/200: Train Loss 0.0028 | Test Loss 0.1867 | accs Train 1.0000 Test 0.9543
# Epoch 100/200: Train Loss 0.0016 | Test Loss 0.1938 | accs Train 1.0000 Test 0.9550
# Epoch 120/200: Train Loss 0.0011 | Test Loss 0.1995 | accs Train 1.0000 Test 0.9554
# Epoch 140/200: Train Loss 0.0008 | Test Loss 0.2043 | accs Train 1.0000 Test 0.9558
# Epoch 160/200: Train Loss 0.0006 | Test Loss 0.2084 | accs Train 1.0000 Test 0.9558
# Epoch 180/200: Train Loss 0.0005 | Test Loss 0.2122 | accs Train 1.0000 Test 0.9562
# Epoch 200/200: Train Loss 0.0004 | Test Loss 0.2158 | accs Train 1.0000 Test 0.9567
# Completed training with 1940 additional samples of data
# Epoch 1/200: Train Loss 1.8561 | Test Loss 1.0672 | accs Train 0.5288 Test 0.7780
# Epoch 20/200: Train Loss 0.0370 | Test Loss 0.0897 | accs Train 0.9920 Test 0.9720
# Epoch 40/200: Train Loss 0.0051 | Test Loss 0.0880 | accs Train 0.9997 Test 0.9753
# Epoch 60/200: Train Loss 0.0014 | Test Loss 0.0949 | accs Train 1.0000 Test 0.9755
# Epoch 80/200: Train Loss 0.0007 | Test Loss 0.0993 | accs Train 1.0000 Test 0.9762
# Epoch 100/200: Train Loss 0.0004 | Test Loss 0.1040 | accs Train 1.0000 Test 0.9767
# Epoch 120/200: Train Loss 0.0003 | Test Loss 0.1076 | accs Train 1.0000 Test 0.9766
# Epoch 140/200: Train Loss 0.0002 | Test Loss 0.1106 | accs Train 1.0000 Test 0.9765
# Epoch 160/200: Train Loss 0.0001 | Test Loss 0.1133 | accs Train 1.0000 Test 0.9763
# Epoch 180/200: Train Loss 0.0001 | Test Loss 0.1155 | accs Train 1.0000 Test 0.9763
# Epoch 200/200: Train Loss 0.0001 | Test Loss 0.1175 | accs Train 1.0000 Test 0.9765
# Completed training with 5940 additional samples of data
# Epoch 1/200: Train Loss 0.9857 | Test Loss 0.3433 | accs Train 0.7255 Test 0.9040
# Epoch 20/200: Train Loss 0.0113 | Test Loss 0.0397 | accs Train 0.9977 Test 0.9870
# Epoch 40/200: Train Loss 0.0008 | Test Loss 0.0483 | accs Train 1.0000 Test 0.9871
# Epoch 60/200: Train Loss 0.0003 | Test Loss 0.0524 | accs Train 1.0000 Test 0.9874
# Epoch 80/200: Train Loss 0.0001 | Test Loss 0.0560 | accs Train 1.0000 Test 0.9870
# Epoch 100/200: Train Loss 0.0001 | Test Loss 0.0588 | accs Train 1.0000 Test 0.9875
# Epoch 120/200: Train Loss 0.0001 | Test Loss 0.0610 | accs Train 1.0000 Test 0.9872
# Epoch 140/200: Train Loss 0.0000 | Test Loss 0.0628 | accs Train 1.0000 Test 0.9869
# Epoch 160/200: Train Loss 0.0000 | Test Loss 0.0648 | accs Train 1.0000 Test 0.9871
# Epoch 180/200: Train Loss 0.0000 | Test Loss 0.0664 | accs Train 1.0000 Test 0.9869
# Epoch 200/200: Train Loss 0.0000 | Test Loss 0.0680 | accs Train 1.0000 Test 0.9870
# Completed training with 19940 additional samples of data
# Epoch 1/200: Train Loss 0.4806 | Test Loss 0.1311 | accs Train 0.8643 Test 0.9616
# Epoch 20/200: Train Loss 0.0052 | Test Loss 0.0272 | accs Train 0.9987 Test 0.9913
# Epoch 40/200: Train Loss 0.0005 | Test Loss 0.0351 | accs Train 1.0000 Test 0.9913
# Epoch 60/200: Train Loss 0.0000 | Test Loss 0.0383 | accs Train 1.0000 Test 0.9911
# Epoch 80/200: Train Loss 0.0000 | Test Loss 0.0415 | accs Train 1.0000 Test 0.9912
# Epoch 100/200: Train Loss 0.0000 | Test Loss 0.0446 | accs Train 1.0000 Test 0.9912
# Epoch 120/200: Train Loss 0.0000 | Test Loss 0.0475 | accs Train 1.0000 Test 0.9910
# Epoch 140/200: Train Loss 0.0000 | Test Loss 0.0498 | accs Train 1.0000 Test 0.9909
# Epoch 160/200: Train Loss 0.0000 | Test Loss 0.0523 | accs Train 1.0000 Test 0.9906
# Epoch 180/200: Train Loss 0.0000 | Test Loss 0.0554 | accs Train 1.0000 Test 0.9906
# Epoch 200/200: Train Loss 0.0000 | Test Loss 0.0577 | accs Train 1.0000 Test 0.9906
# Completed training with 59940 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 2.6573 | accs: 0.6892
#  540 samples | Test Loss: 0.5384 | accs: 0.9081
# 1940 samples | Test Loss: 0.2158 | accs: 0.9567
# 5940 samples | Test Loss: 0.1175 | accs: 0.9765
# 19940 samples | Test Loss: 0.0680 | accs: 0.9870
# 59940 samples | Test Loss: 0.0577 | accs: 0.9906
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  540 | Train Loss: 0.0004 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0004 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 540
#  Model    0 | Train Loss: 2.2414 | accs: 0.7583
#  Model  540 | Train Loss: 0.0003 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0004 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 1940
#  Model    0 | Train Loss: 2.5062 | accs: 0.7130
#  Model  540 | Train Loss: 0.3631 | accs: 0.9355
#  Model 1940 | Train Loss: 0.0004 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 5940
#  Model    0 | Train Loss: 2.6607 | accs: 0.6967
#  Model  540 | Train Loss: 0.5295 | accs: 0.9145
#  Model 1940 | Train Loss: 0.1686 | accs: 0.9667
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 19940
#  Model    0 | Train Loss: 2.6565 | accs: 0.6926
#  Model  540 | Train Loss: 0.5683 | accs: 0.9073
#  Model 1940 | Train Loss: 0.2266 | accs: 0.9561
#  Model 5940 | Train Loss: 0.1018 | accs: 0.9823
#  Model 19940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 59940
#  Model    0 | Train Loss: 2.6823 | accs: 0.6923
#  Model  540 | Train Loss: 0.5755 | accs: 0.9033
#  Model 1940 | Train Loss: 0.2394 | accs: 0.9531
#  Model 5940 | Train Loss: 0.1254 | accs: 0.9773
#  Model 19940 | Train Loss: 0.0575 | accs: 0.9910
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_540.pt
# Saved model: models_and_data/model_additional_540.pt
# ✅ Model saved to models_and_data\model_additional_1940.pt
# Saved model: models_and_data/model_additional_1940.pt
# ✅ Model saved to models_and_data\model_additional_5940.pt
# Saved model: models_and_data/model_additional_5940.pt
# ✅ Model saved to models_and_data\model_additional_19940.pt
# Saved model: models_and_data/model_additional_19940.pt
# ✅ Model saved to models_and_data\model_additional_59940.pt
# Saved model: models_and_data/model_additional_59940.pt
