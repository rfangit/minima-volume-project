# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 17            
model_seed = 7           

# --- Training configuration ---
epochs = 700            

# --- Dataset configuration ---
base_data_size = 60      
dataset_type = "data"   
dataset_quantities = [0, 600-60, 2000 - 60, 6000 - 60, 20000 - 60, 60000 - 60]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
from minima_volume.models import MNIST_model_data as model_module

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device = device
)

# MNIST specific initialization parameters
hidden_dims = [256, 256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/700: Train Loss 2.2774 | Test Loss 2.2678 | accs Train 0.1667 Test 0.0980
# Epoch 100/700: Train Loss 0.0000 | Test Loss 2.2473 | accs Train 1.0000 Test 0.6605
# Epoch 200/700: Train Loss 0.0000 | Test Loss 2.2192 | accs Train 1.0000 Test 0.6620
# Epoch 300/700: Train Loss 0.0000 | Test Loss 2.2028 | accs Train 1.0000 Test 0.6643
# Epoch 400/700: Train Loss 0.0000 | Test Loss 2.1926 | accs Train 1.0000 Test 0.6653
# Epoch 500/700: Train Loss 0.0000 | Test Loss 2.1852 | accs Train 1.0000 Test 0.6662
# Epoch 600/700: Train Loss 0.0000 | Test Loss 2.1799 | accs Train 1.0000 Test 0.6668
# Epoch 700/700: Train Loss 0.0000 | Test Loss 2.1747 | accs Train 1.0000 Test 0.6677
# Completed training with 0 additional samples of data
# Epoch 1/700: Train Loss 2.2952 | Test Loss 2.2458 | accs Train 0.1200 Test 0.0981
# Epoch 100/700: Train Loss 0.0008 | Test Loss 0.7472 | accs Train 1.0000 Test 0.8711
# Epoch 200/700: Train Loss 0.0003 | Test Loss 0.8005 | accs Train 1.0000 Test 0.8708
# Epoch 300/700: Train Loss 0.0002 | Test Loss 0.8359 | accs Train 1.0000 Test 0.8706
# Epoch 400/700: Train Loss 0.0001 | Test Loss 0.8617 | accs Train 1.0000 Test 0.8700
# Epoch 500/700: Train Loss 0.0001 | Test Loss 0.8818 | accs Train 1.0000 Test 0.8702
# Epoch 600/700: Train Loss 0.0001 | Test Loss 0.8981 | accs Train 1.0000 Test 0.8703
# Epoch 700/700: Train Loss 0.0000 | Test Loss 0.9117 | accs Train 1.0000 Test 0.8702
# Completed training with 540 additional samples of data
# Epoch 1/700: Train Loss 2.3009 | Test Loss 2.2407 | accs Train 0.0995 Test 0.2152
# Epoch 100/700: Train Loss 0.0031 | Test Loss 0.5251 | accs Train 1.0000 Test 0.9007
# Epoch 200/700: Train Loss 0.0006 | Test Loss 0.6048 | accs Train 1.0000 Test 0.9020
# Epoch 300/700: Train Loss 0.0002 | Test Loss 0.6433 | accs Train 1.0000 Test 0.9028
# Epoch 400/700: Train Loss 0.0001 | Test Loss 0.6693 | accs Train 1.0000 Test 0.9036
# Epoch 500/700: Train Loss 0.0001 | Test Loss 0.6894 | accs Train 1.0000 Test 0.9032
# Epoch 600/700: Train Loss 0.0001 | Test Loss 0.7058 | accs Train 1.0000 Test 0.9032
# Epoch 700/700: Train Loss 0.0000 | Test Loss 0.7194 | accs Train 1.0000 Test 0.9035
# Completed training with 1940 additional samples of data
# Epoch 1/700: Train Loss 2.3018 | Test Loss 2.2385 | accs Train 0.0958 Test 0.2342
# Epoch 100/700: Train Loss 0.0212 | Test Loss 0.2265 | accs Train 0.9985 Test 0.9389
# Epoch 200/700: Train Loss 0.0014 | Test Loss 0.2763 | accs Train 1.0000 Test 0.9427
# Epoch 300/700: Train Loss 0.0005 | Test Loss 0.2998 | accs Train 1.0000 Test 0.9435
# Epoch 400/700: Train Loss 0.0003 | Test Loss 0.3154 | accs Train 1.0000 Test 0.9444
# Epoch 500/700: Train Loss 0.0002 | Test Loss 0.3271 | accs Train 1.0000 Test 0.9445
# Epoch 600/700: Train Loss 0.0001 | Test Loss 0.3364 | accs Train 1.0000 Test 0.9448
# Epoch 700/700: Train Loss 0.0001 | Test Loss 0.3439 | accs Train 1.0000 Test 0.9451
# Completed training with 5940 additional samples of data
# Epoch 1/700: Train Loss 2.3014 | Test Loss 2.2370 | accs Train 0.0975 Test 0.2540
# Epoch 100/700: Train Loss 0.0830 | Test Loss 0.1426 | accs Train 0.9776 Test 0.9568
# Epoch 200/700: Train Loss 0.0082 | Test Loss 0.1484 | accs Train 0.9995 Test 0.9616
# Epoch 300/700: Train Loss 0.0015 | Test Loss 0.1795 | accs Train 1.0000 Test 0.9626
# Epoch 400/700: Train Loss 0.0006 | Test Loss 0.1981 | accs Train 1.0000 Test 0.9635
# Epoch 500/700: Train Loss 0.0003 | Test Loss 0.2110 | accs Train 1.0000 Test 0.9639
# Epoch 600/700: Train Loss 0.0002 | Test Loss 0.2208 | accs Train 1.0000 Test 0.9639
# Epoch 700/700: Train Loss 0.0002 | Test Loss 0.2288 | accs Train 1.0000 Test 0.9640
# Completed training with 19940 additional samples of data
# Epoch 1/700: Train Loss 2.3016 | Test Loss 2.2371 | accs Train 0.0996 Test 0.2485
# Epoch 100/700: Train Loss 0.1087 | Test Loss 0.1241 | accs Train 0.9694 Test 0.9623
# Epoch 200/700: Train Loss 0.0303 | Test Loss 0.0841 | accs Train 0.9930 Test 0.9754
# Epoch 300/700: Train Loss 0.0083 | Test Loss 0.0922 | accs Train 0.9992 Test 0.9760
# Epoch 400/700: Train Loss 0.0028 | Test Loss 0.1058 | accs Train 0.9999 Test 0.9764
# Epoch 500/700: Train Loss 0.0013 | Test Loss 0.1164 | accs Train 1.0000 Test 0.9766
# Epoch 600/700: Train Loss 0.0007 | Test Loss 0.1244 | accs Train 1.0000 Test 0.9767
# Epoch 700/700: Train Loss 0.0005 | Test Loss 0.1307 | accs Train 1.0000 Test 0.9770
# Completed training with 59940 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 2.1747 | accs: 0.6677
#  540 samples | Test Loss: 0.9117 | accs: 0.8702
# 1940 samples | Test Loss: 0.7194 | accs: 0.9035
# 5940 samples | Test Loss: 0.3439 | accs: 0.9451
# 19940 samples | Test Loss: 0.2288 | accs: 0.9640
# 59940 samples | Test Loss: 0.1307 | accs: 0.9770
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  540 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0004 | accs: 1.0000
#
# Dataset type: data, additional samples: 540
#  Model    0 | Train Loss: 2.2020 | accs: 0.6717
#  Model  540 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0004 | accs: 1.0000
#
# Dataset type: data, additional samples: 1940
#  Model    0 | Train Loss: 2.1252 | accs: 0.6635
#  Model  540 | Train Loss: 0.6011 | accs: 0.9090
#  Model 1940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0002 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0005 | accs: 1.0000
#
# Dataset type: data, additional samples: 5940
#  Model    0 | Train Loss: 2.1912 | accs: 0.6642
#  Model  540 | Train Loss: 0.8299 | accs: 0.8792
#  Model 1940 | Train Loss: 0.5213 | accs: 0.9333
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0005 | accs: 1.0000
#
# Dataset type: data, additional samples: 19940
#  Model    0 | Train Loss: 2.2287 | accs: 0.6611
#  Model  540 | Train Loss: 0.8943 | accs: 0.8716
#  Model 1940 | Train Loss: 0.7099 | accs: 0.9069
#  Model 5940 | Train Loss: 0.3144 | accs: 0.9561
#  Model 19940 | Train Loss: 0.0002 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0005 | accs: 1.0000
#
# Dataset type: data, additional samples: 59940
#  Model    0 | Train Loss: 2.2260 | accs: 0.6608
#  Model  540 | Train Loss: 0.9276 | accs: 0.8687
#  Model 1940 | Train Loss: 0.7597 | accs: 0.9005
#  Model 5940 | Train Loss: 0.3918 | accs: 0.9435
#  Model 19940 | Train Loss: 0.1699 | accs: 0.9738
#  Model 59940 | Train Loss: 0.0005 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_540.pt
# Saved model: models_and_data/model_additional_540.pt
# ✅ Model saved to models_and_data\model_additional_1940.pt
# Saved model: models_and_data/model_additional_1940.pt
# ✅ Model saved to models_and_data\model_additional_5940.pt
# Saved model: models_and_data/model_additional_5940.pt
# ✅ Model saved to models_and_data\model_additional_19940.pt
# Saved model: models_and_data/model_additional_19940.pt
# ✅ Model saved to models_and_data\model_additional_59940.pt
# Saved model: models_and_data/model_additional_59940.pt
