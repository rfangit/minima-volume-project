# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 12            
model_seed = 2           

# --- Training configuration ---
epochs = 3000            

# --- Dataset configuration ---
base_data_size = 60      
dataset_type = "data"   
dataset_quantities = [0, 600-60, 2000 - 60, 6000 - 60, 20000 - 60, 60000 - 60]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
from minima_volume.models import MNIST_model_data as model_module

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device = device
)

# MNIST specific initialization parameters
hidden_dims = [256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.SGD(
        model.parameters(),
        lr=1e-2,         # usually requires higher LR than AdamW
        momentum=0.9,    # typical value, helps convergence
        weight_decay=1e-4  # optional, acts like L2 regularization
    )
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/3000: Train Loss 2.3134 | Test Loss 2.2997 | accs Train 0.1667 Test 0.1437
# Epoch 100/3000: Train Loss 0.0075 | Test Loss 1.0181 | accs Train 1.0000 Test 0.6823
# Epoch 200/3000: Train Loss 0.0030 | Test Loss 1.0616 | accs Train 1.0000 Test 0.6845
# Epoch 300/3000: Train Loss 0.0019 | Test Loss 1.0890 | accs Train 1.0000 Test 0.6858
# Epoch 400/3000: Train Loss 0.0013 | Test Loss 1.1090 | accs Train 1.0000 Test 0.6869
# Epoch 500/3000: Train Loss 0.0010 | Test Loss 1.1247 | accs Train 1.0000 Test 0.6879
# Epoch 600/3000: Train Loss 0.0008 | Test Loss 1.1377 | accs Train 1.0000 Test 0.6881
# Epoch 700/3000: Train Loss 0.0007 | Test Loss 1.1487 | accs Train 1.0000 Test 0.6881
# Epoch 800/3000: Train Loss 0.0006 | Test Loss 1.1584 | accs Train 1.0000 Test 0.6887
# Epoch 900/3000: Train Loss 0.0006 | Test Loss 1.1668 | accs Train 1.0000 Test 0.6890
# Epoch 1000/3000: Train Loss 0.0005 | Test Loss 1.1743 | accs Train 1.0000 Test 0.6896
# Epoch 1100/3000: Train Loss 0.0004 | Test Loss 1.1810 | accs Train 1.0000 Test 0.6897
# Epoch 1200/3000: Train Loss 0.0004 | Test Loss 1.1870 | accs Train 1.0000 Test 0.6898
# Epoch 1300/3000: Train Loss 0.0004 | Test Loss 1.1925 | accs Train 1.0000 Test 0.6898
# Epoch 1400/3000: Train Loss 0.0004 | Test Loss 1.1976 | accs Train 1.0000 Test 0.6896
# Epoch 1500/3000: Train Loss 0.0003 | Test Loss 1.2022 | accs Train 1.0000 Test 0.6899
# Epoch 1600/3000: Train Loss 0.0003 | Test Loss 1.2064 | accs Train 1.0000 Test 0.6900
# Epoch 1700/3000: Train Loss 0.0003 | Test Loss 1.2104 | accs Train 1.0000 Test 0.6900
# Epoch 1800/3000: Train Loss 0.0003 | Test Loss 1.2140 | accs Train 1.0000 Test 0.6901
# Epoch 1900/3000: Train Loss 0.0003 | Test Loss 1.2174 | accs Train 1.0000 Test 0.6899
# Epoch 2000/3000: Train Loss 0.0003 | Test Loss 1.2205 | accs Train 1.0000 Test 0.6901
# Epoch 2100/3000: Train Loss 0.0002 | Test Loss 1.2235 | accs Train 1.0000 Test 0.6903
# Epoch 2200/3000: Train Loss 0.0002 | Test Loss 1.2262 | accs Train 1.0000 Test 0.6901
# Epoch 2300/3000: Train Loss 0.0002 | Test Loss 1.2288 | accs Train 1.0000 Test 0.6900
# Epoch 2400/3000: Train Loss 0.0002 | Test Loss 1.2312 | accs Train 1.0000 Test 0.6898
# Epoch 2500/3000: Train Loss 0.0002 | Test Loss 1.2335 | accs Train 1.0000 Test 0.6901
# Epoch 2600/3000: Train Loss 0.0002 | Test Loss 1.2356 | accs Train 1.0000 Test 0.6900
# Epoch 2700/3000: Train Loss 0.0002 | Test Loss 1.2376 | accs Train 1.0000 Test 0.6901
# Epoch 2800/3000: Train Loss 0.0002 | Test Loss 1.2395 | accs Train 1.0000 Test 0.6902
# Epoch 2900/3000: Train Loss 0.0002 | Test Loss 1.2414 | accs Train 1.0000 Test 0.6902
# Epoch 3000/3000: Train Loss 0.0002 | Test Loss 1.2431 | accs Train 1.0000 Test 0.6902
# Completed training with 0 additional samples of data
# Epoch 1/3000: Train Loss 2.3098 | Test Loss 2.2995 | accs Train 0.1383 Test 0.1449
# Epoch 100/3000: Train Loss 0.1177 | Test Loss 0.4675 | accs Train 0.9833 Test 0.8601
# Epoch 200/3000: Train Loss 0.0245 | Test Loss 0.5017 | accs Train 1.0000 Test 0.8655
# Epoch 300/3000: Train Loss 0.0114 | Test Loss 0.5382 | accs Train 1.0000 Test 0.8654
# Epoch 400/3000: Train Loss 0.0071 | Test Loss 0.5643 | accs Train 1.0000 Test 0.8655
# Epoch 500/3000: Train Loss 0.0050 | Test Loss 0.5842 | accs Train 1.0000 Test 0.8656
# Epoch 600/3000: Train Loss 0.0038 | Test Loss 0.6000 | accs Train 1.0000 Test 0.8660
# Epoch 700/3000: Train Loss 0.0031 | Test Loss 0.6131 | accs Train 1.0000 Test 0.8657
# Epoch 800/3000: Train Loss 0.0025 | Test Loss 0.6242 | accs Train 1.0000 Test 0.8656
# Epoch 900/3000: Train Loss 0.0022 | Test Loss 0.6338 | accs Train 1.0000 Test 0.8656
# Epoch 1000/3000: Train Loss 0.0019 | Test Loss 0.6422 | accs Train 1.0000 Test 0.8650
# Epoch 1100/3000: Train Loss 0.0017 | Test Loss 0.6496 | accs Train 1.0000 Test 0.8650
# Epoch 1200/3000: Train Loss 0.0015 | Test Loss 0.6563 | accs Train 1.0000 Test 0.8649
# Epoch 1300/3000: Train Loss 0.0014 | Test Loss 0.6623 | accs Train 1.0000 Test 0.8648
# Epoch 1400/3000: Train Loss 0.0012 | Test Loss 0.6678 | accs Train 1.0000 Test 0.8648
# Epoch 1500/3000: Train Loss 0.0011 | Test Loss 0.6728 | accs Train 1.0000 Test 0.8650
# Epoch 1600/3000: Train Loss 0.0011 | Test Loss 0.6773 | accs Train 1.0000 Test 0.8652
# Epoch 1700/3000: Train Loss 0.0010 | Test Loss 0.6815 | accs Train 1.0000 Test 0.8654
# Epoch 1800/3000: Train Loss 0.0009 | Test Loss 0.6854 | accs Train 1.0000 Test 0.8654
# Epoch 1900/3000: Train Loss 0.0009 | Test Loss 0.6890 | accs Train 1.0000 Test 0.8653
# Epoch 2000/3000: Train Loss 0.0008 | Test Loss 0.6923 | accs Train 1.0000 Test 0.8648
# Epoch 2100/3000: Train Loss 0.0008 | Test Loss 0.6954 | accs Train 1.0000 Test 0.8647
# Epoch 2200/3000: Train Loss 0.0007 | Test Loss 0.6984 | accs Train 1.0000 Test 0.8647
# Epoch 2300/3000: Train Loss 0.0007 | Test Loss 0.7011 | accs Train 1.0000 Test 0.8646
# Epoch 2400/3000: Train Loss 0.0007 | Test Loss 0.7036 | accs Train 1.0000 Test 0.8647
# Epoch 2500/3000: Train Loss 0.0006 | Test Loss 0.7060 | accs Train 1.0000 Test 0.8649
# Epoch 2600/3000: Train Loss 0.0006 | Test Loss 0.7083 | accs Train 1.0000 Test 0.8649
# Epoch 2700/3000: Train Loss 0.0006 | Test Loss 0.7104 | accs Train 1.0000 Test 0.8649
# Epoch 2800/3000: Train Loss 0.0006 | Test Loss 0.7124 | accs Train 1.0000 Test 0.8649
# Epoch 2900/3000: Train Loss 0.0006 | Test Loss 0.7143 | accs Train 1.0000 Test 0.8649
# Epoch 3000/3000: Train Loss 0.0005 | Test Loss 0.7161 | accs Train 1.0000 Test 0.8649
# Completed training with 540 additional samples of data
# Epoch 1/3000: Train Loss 2.3059 | Test Loss 2.2995 | accs Train 0.1375 Test 0.1472
# Epoch 100/3000: Train Loss 0.2859 | Test Loss 0.3835 | accs Train 0.9180 Test 0.8886
# Epoch 200/3000: Train Loss 0.1335 | Test Loss 0.3347 | accs Train 0.9660 Test 0.9016
# Epoch 300/3000: Train Loss 0.0645 | Test Loss 0.3359 | accs Train 0.9925 Test 0.9051
# Epoch 400/3000: Train Loss 0.0334 | Test Loss 0.3478 | accs Train 0.9995 Test 0.9055
# Epoch 500/3000: Train Loss 0.0198 | Test Loss 0.3610 | accs Train 0.9995 Test 0.9069
# Epoch 600/3000: Train Loss 0.0132 | Test Loss 0.3730 | accs Train 1.0000 Test 0.9076
# Epoch 700/3000: Train Loss 0.0096 | Test Loss 0.3833 | accs Train 1.0000 Test 0.9085
# Epoch 800/3000: Train Loss 0.0074 | Test Loss 0.3920 | accs Train 1.0000 Test 0.9092
# Epoch 900/3000: Train Loss 0.0060 | Test Loss 0.3996 | accs Train 1.0000 Test 0.9095
# Epoch 1000/3000: Train Loss 0.0050 | Test Loss 0.4061 | accs Train 1.0000 Test 0.9094
# Epoch 1100/3000: Train Loss 0.0042 | Test Loss 0.4119 | accs Train 1.0000 Test 0.9092
# Epoch 1200/3000: Train Loss 0.0037 | Test Loss 0.4170 | accs Train 1.0000 Test 0.9092
# Epoch 1300/3000: Train Loss 0.0032 | Test Loss 0.4216 | accs Train 1.0000 Test 0.9090
# Epoch 1400/3000: Train Loss 0.0029 | Test Loss 0.4258 | accs Train 1.0000 Test 0.9091
# Epoch 1500/3000: Train Loss 0.0026 | Test Loss 0.4295 | accs Train 1.0000 Test 0.9093
# Epoch 1600/3000: Train Loss 0.0024 | Test Loss 0.4329 | accs Train 1.0000 Test 0.9094
# Epoch 1700/3000: Train Loss 0.0022 | Test Loss 0.4361 | accs Train 1.0000 Test 0.9095
# Epoch 1800/3000: Train Loss 0.0020 | Test Loss 0.4390 | accs Train 1.0000 Test 0.9096
# Epoch 1900/3000: Train Loss 0.0019 | Test Loss 0.4416 | accs Train 1.0000 Test 0.9096
# Epoch 2000/3000: Train Loss 0.0017 | Test Loss 0.4441 | accs Train 1.0000 Test 0.9097
# Epoch 2100/3000: Train Loss 0.0016 | Test Loss 0.4464 | accs Train 1.0000 Test 0.9099
# Epoch 2200/3000: Train Loss 0.0015 | Test Loss 0.4485 | accs Train 1.0000 Test 0.9101
# Epoch 2300/3000: Train Loss 0.0015 | Test Loss 0.4505 | accs Train 1.0000 Test 0.9103
# Epoch 2400/3000: Train Loss 0.0014 | Test Loss 0.4524 | accs Train 1.0000 Test 0.9106
# Epoch 2500/3000: Train Loss 0.0013 | Test Loss 0.4541 | accs Train 1.0000 Test 0.9106
# Epoch 2600/3000: Train Loss 0.0012 | Test Loss 0.4557 | accs Train 1.0000 Test 0.9109
# Epoch 2700/3000: Train Loss 0.0012 | Test Loss 0.4572 | accs Train 1.0000 Test 0.9111
# Epoch 2800/3000: Train Loss 0.0011 | Test Loss 0.4587 | accs Train 1.0000 Test 0.9113
# Epoch 2900/3000: Train Loss 0.0011 | Test Loss 0.4600 | accs Train 1.0000 Test 0.9114
# Epoch 3000/3000: Train Loss 0.0011 | Test Loss 0.4613 | accs Train 1.0000 Test 0.9115
# Completed training with 1940 additional samples of data
# Epoch 1/3000: Train Loss 2.3052 | Test Loss 2.2996 | accs Train 0.1435 Test 0.1463
# Epoch 100/3000: Train Loss 0.3285 | Test Loss 0.3570 | accs Train 0.9037 Test 0.8971
# Epoch 200/3000: Train Loss 0.2180 | Test Loss 0.2832 | accs Train 0.9392 Test 0.9139
# Epoch 300/3000: Train Loss 0.1583 | Test Loss 0.2526 | accs Train 0.9573 Test 0.9241
# Epoch 400/3000: Train Loss 0.1158 | Test Loss 0.2343 | accs Train 0.9698 Test 0.9308
# Epoch 500/3000: Train Loss 0.0844 | Test Loss 0.2229 | accs Train 0.9798 Test 0.9344
# Epoch 600/3000: Train Loss 0.0612 | Test Loss 0.2165 | accs Train 0.9883 Test 0.9368
# Epoch 700/3000: Train Loss 0.0446 | Test Loss 0.2138 | accs Train 0.9940 Test 0.9389
# Epoch 800/3000: Train Loss 0.0329 | Test Loss 0.2138 | accs Train 0.9967 Test 0.9405
# Epoch 900/3000: Train Loss 0.0249 | Test Loss 0.2151 | accs Train 0.9983 Test 0.9411
# Epoch 1000/3000: Train Loss 0.0193 | Test Loss 0.2172 | accs Train 0.9993 Test 0.9416
# Epoch 1100/3000: Train Loss 0.0153 | Test Loss 0.2197 | accs Train 0.9995 Test 0.9422
# Epoch 1200/3000: Train Loss 0.0125 | Test Loss 0.2225 | accs Train 0.9998 Test 0.9423
# Epoch 1300/3000: Train Loss 0.0104 | Test Loss 0.2251 | accs Train 0.9998 Test 0.9426
# Epoch 1400/3000: Train Loss 0.0088 | Test Loss 0.2276 | accs Train 0.9998 Test 0.9429
# Epoch 1500/3000: Train Loss 0.0076 | Test Loss 0.2300 | accs Train 1.0000 Test 0.9430
# Epoch 1600/3000: Train Loss 0.0067 | Test Loss 0.2323 | accs Train 1.0000 Test 0.9433
# Epoch 1700/3000: Train Loss 0.0059 | Test Loss 0.2344 | accs Train 1.0000 Test 0.9434
# Epoch 1800/3000: Train Loss 0.0053 | Test Loss 0.2363 | accs Train 1.0000 Test 0.9438
# Epoch 1900/3000: Train Loss 0.0048 | Test Loss 0.2382 | accs Train 1.0000 Test 0.9440
# Epoch 2000/3000: Train Loss 0.0044 | Test Loss 0.2399 | accs Train 1.0000 Test 0.9442
# Epoch 2100/3000: Train Loss 0.0040 | Test Loss 0.2415 | accs Train 1.0000 Test 0.9444
# Epoch 2200/3000: Train Loss 0.0037 | Test Loss 0.2430 | accs Train 1.0000 Test 0.9446
# Epoch 2300/3000: Train Loss 0.0034 | Test Loss 0.2444 | accs Train 1.0000 Test 0.9446
# Epoch 2400/3000: Train Loss 0.0032 | Test Loss 0.2458 | accs Train 1.0000 Test 0.9448
# Epoch 2500/3000: Train Loss 0.0030 | Test Loss 0.2470 | accs Train 1.0000 Test 0.9449
# Epoch 2600/3000: Train Loss 0.0028 | Test Loss 0.2482 | accs Train 1.0000 Test 0.9448
# Epoch 2700/3000: Train Loss 0.0026 | Test Loss 0.2493 | accs Train 1.0000 Test 0.9448
# Epoch 2800/3000: Train Loss 0.0025 | Test Loss 0.2504 | accs Train 1.0000 Test 0.9449
# Epoch 2900/3000: Train Loss 0.0024 | Test Loss 0.2514 | accs Train 1.0000 Test 0.9449
# Epoch 3000/3000: Train Loss 0.0022 | Test Loss 0.2523 | accs Train 1.0000 Test 0.9450
# Completed training with 5940 additional samples of data
# Epoch 1/3000: Train Loss 2.3048 | Test Loss 2.2996 | accs Train 0.1362 Test 0.1466
# Epoch 100/3000: Train Loss 0.3518 | Test Loss 0.3496 | accs Train 0.8992 Test 0.8987
# Epoch 200/3000: Train Loss 0.2613 | Test Loss 0.2706 | accs Train 0.9245 Test 0.9216
# Epoch 300/3000: Train Loss 0.2143 | Test Loss 0.2321 | accs Train 0.9385 Test 0.9324
# Epoch 400/3000: Train Loss 0.1789 | Test Loss 0.2033 | accs Train 0.9487 Test 0.9401
# Epoch 500/3000: Train Loss 0.1505 | Test Loss 0.1808 | accs Train 0.9584 Test 0.9452
# Epoch 600/3000: Train Loss 0.1276 | Test Loss 0.1635 | accs Train 0.9653 Test 0.9513
# Epoch 700/3000: Train Loss 0.1089 | Test Loss 0.1501 | accs Train 0.9706 Test 0.9546
# Epoch 800/3000: Train Loss 0.0934 | Test Loss 0.1395 | accs Train 0.9752 Test 0.9575
# Epoch 900/3000: Train Loss 0.0805 | Test Loss 0.1313 | accs Train 0.9796 Test 0.9594
# Epoch 1000/3000: Train Loss 0.0696 | Test Loss 0.1249 | accs Train 0.9827 Test 0.9617
# Epoch 1100/3000: Train Loss 0.0604 | Test Loss 0.1199 | accs Train 0.9858 Test 0.9640
# Epoch 1200/3000: Train Loss 0.0524 | Test Loss 0.1159 | accs Train 0.9885 Test 0.9648
# Epoch 1300/3000: Train Loss 0.0456 | Test Loss 0.1129 | accs Train 0.9905 Test 0.9654
# Epoch 1400/3000: Train Loss 0.0398 | Test Loss 0.1105 | accs Train 0.9924 Test 0.9668
# Epoch 1500/3000: Train Loss 0.0348 | Test Loss 0.1086 | accs Train 0.9936 Test 0.9666
# Epoch 1600/3000: Train Loss 0.0304 | Test Loss 0.1071 | accs Train 0.9951 Test 0.9671
# Epoch 1700/3000: Train Loss 0.0267 | Test Loss 0.1059 | accs Train 0.9957 Test 0.9677
# Epoch 1800/3000: Train Loss 0.0235 | Test Loss 0.1051 | accs Train 0.9964 Test 0.9676
# Epoch 1900/3000: Train Loss 0.0208 | Test Loss 0.1045 | accs Train 0.9971 Test 0.9678
# Epoch 2000/3000: Train Loss 0.0184 | Test Loss 0.1042 | accs Train 0.9977 Test 0.9679
# Epoch 2100/3000: Train Loss 0.0164 | Test Loss 0.1040 | accs Train 0.9982 Test 0.9685
# Epoch 2200/3000: Train Loss 0.0146 | Test Loss 0.1040 | accs Train 0.9987 Test 0.9685
# Epoch 2300/3000: Train Loss 0.0131 | Test Loss 0.1040 | accs Train 0.9991 Test 0.9687
# Epoch 2400/3000: Train Loss 0.0118 | Test Loss 0.1041 | accs Train 0.9994 Test 0.9689
# Epoch 2500/3000: Train Loss 0.0107 | Test Loss 0.1043 | accs Train 0.9994 Test 0.9690
# Epoch 2600/3000: Train Loss 0.0097 | Test Loss 0.1045 | accs Train 0.9997 Test 0.9693
# Epoch 2700/3000: Train Loss 0.0089 | Test Loss 0.1048 | accs Train 0.9997 Test 0.9695
# Epoch 2800/3000: Train Loss 0.0081 | Test Loss 0.1050 | accs Train 0.9998 Test 0.9696
# Epoch 2900/3000: Train Loss 0.0075 | Test Loss 0.1053 | accs Train 0.9999 Test 0.9698
# Epoch 3000/3000: Train Loss 0.0069 | Test Loss 0.1055 | accs Train 0.9999 Test 0.9696
# Completed training with 19940 additional samples of data
# Epoch 1/3000: Train Loss 2.3039 | Test Loss 2.2996 | accs Train 0.1393 Test 0.1469
# Epoch 100/3000: Train Loss 0.3613 | Test Loss 0.3454 | accs Train 0.8955 Test 0.9005
# Epoch 200/3000: Train Loss 0.2742 | Test Loss 0.2641 | accs Train 0.9212 Test 0.9246
# Epoch 300/3000: Train Loss 0.2305 | Test Loss 0.2245 | accs Train 0.9339 Test 0.9375
# Epoch 400/3000: Train Loss 0.1977 | Test Loss 0.1944 | accs Train 0.9439 Test 0.9444
# Epoch 500/3000: Train Loss 0.1715 | Test Loss 0.1707 | accs Train 0.9511 Test 0.9501
# Epoch 600/3000: Train Loss 0.1504 | Test Loss 0.1520 | accs Train 0.9574 Test 0.9545
# Epoch 700/3000: Train Loss 0.1333 | Test Loss 0.1373 | accs Train 0.9625 Test 0.9597
# Epoch 800/3000: Train Loss 0.1190 | Test Loss 0.1256 | accs Train 0.9670 Test 0.9640
# Epoch 900/3000: Train Loss 0.1071 | Test Loss 0.1160 | accs Train 0.9709 Test 0.9661
# Epoch 1000/3000: Train Loss 0.0968 | Test Loss 0.1081 | accs Train 0.9738 Test 0.9680
# Epoch 1100/3000: Train Loss 0.0880 | Test Loss 0.1015 | accs Train 0.9764 Test 0.9691
# Epoch 1200/3000: Train Loss 0.0802 | Test Loss 0.0959 | accs Train 0.9783 Test 0.9708
# Epoch 1300/3000: Train Loss 0.0734 | Test Loss 0.0912 | accs Train 0.9802 Test 0.9717
# Epoch 1400/3000: Train Loss 0.0674 | Test Loss 0.0871 | accs Train 0.9819 Test 0.9728
# Epoch 1500/3000: Train Loss 0.0621 | Test Loss 0.0836 | accs Train 0.9834 Test 0.9737
# Epoch 1600/3000: Train Loss 0.0573 | Test Loss 0.0806 | accs Train 0.9847 Test 0.9745
# Epoch 1700/3000: Train Loss 0.0530 | Test Loss 0.0780 | accs Train 0.9860 Test 0.9753
# Epoch 1800/3000: Train Loss 0.0491 | Test Loss 0.0758 | accs Train 0.9873 Test 0.9761
# Epoch 1900/3000: Train Loss 0.0455 | Test Loss 0.0738 | accs Train 0.9884 Test 0.9764
# Epoch 2000/3000: Train Loss 0.0423 | Test Loss 0.0722 | accs Train 0.9895 Test 0.9772
# Epoch 2100/3000: Train Loss 0.0394 | Test Loss 0.0707 | accs Train 0.9904 Test 0.9781
# Epoch 2200/3000: Train Loss 0.0367 | Test Loss 0.0694 | accs Train 0.9913 Test 0.9786
# Epoch 2300/3000: Train Loss 0.0343 | Test Loss 0.0683 | accs Train 0.9921 Test 0.9790
# Epoch 2400/3000: Train Loss 0.0320 | Test Loss 0.0673 | accs Train 0.9928 Test 0.9794
# Epoch 2500/3000: Train Loss 0.0300 | Test Loss 0.0664 | accs Train 0.9935 Test 0.9794
# Epoch 2600/3000: Train Loss 0.0280 | Test Loss 0.0656 | accs Train 0.9940 Test 0.9800
# Epoch 2700/3000: Train Loss 0.0263 | Test Loss 0.0650 | accs Train 0.9945 Test 0.9798
# Epoch 2800/3000: Train Loss 0.0247 | Test Loss 0.0645 | accs Train 0.9950 Test 0.9797
# Epoch 2900/3000: Train Loss 0.0232 | Test Loss 0.0640 | accs Train 0.9956 Test 0.9799
# Epoch 3000/3000: Train Loss 0.0218 | Test Loss 0.0636 | accs Train 0.9962 Test 0.9799
# Completed training with 59940 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 1.2431 | accs: 0.6902
#  540 samples | Test Loss: 0.7161 | accs: 0.8649
# 1940 samples | Test Loss: 0.4613 | accs: 0.9115
# 5940 samples | Test Loss: 0.2523 | accs: 0.9450
# 19940 samples | Test Loss: 0.1055 | accs: 0.9696
# 59940 samples | Test Loss: 0.0636 | accs: 0.9799
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0002 | accs: 1.0000
#  Model  540 | Train Loss: 0.0007 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0013 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0029 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0027 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0049 | accs: 1.0000
#
# Dataset type: data, additional samples: 540
#  Model    0 | Train Loss: 1.2317 | accs: 0.6900
#  Model  540 | Train Loss: 0.0005 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0010 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0021 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0047 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0090 | accs: 1.0000
#
# Dataset type: data, additional samples: 1940
#  Model    0 | Train Loss: 1.3208 | accs: 0.6745
#  Model  540 | Train Loss: 0.5704 | accs: 0.9055
#  Model 1940 | Train Loss: 0.0011 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0022 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0065 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0162 | accs: 0.9980
#
# Dataset type: data, additional samples: 5940
#  Model    0 | Train Loss: 1.2801 | accs: 0.6830
#  Model  540 | Train Loss: 0.7036 | accs: 0.8777
#  Model 1940 | Train Loss: 0.3234 | accs: 0.9363
#  Model 5940 | Train Loss: 0.0022 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0063 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0185 | accs: 0.9970
#
# Dataset type: data, additional samples: 19940
#  Model    0 | Train Loss: 1.2861 | accs: 0.6822
#  Model  540 | Train Loss: 0.7449 | accs: 0.8684
#  Model 1940 | Train Loss: 0.4554 | accs: 0.9168
#  Model 5940 | Train Loss: 0.2059 | accs: 0.9596
#  Model 19940 | Train Loss: 0.0069 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0221 | accs: 0.9959
#
# Dataset type: data, additional samples: 59940
#  Model    0 | Train Loss: 1.3245 | accs: 0.6752
#  Model  540 | Train Loss: 0.7683 | accs: 0.8623
#  Model 1940 | Train Loss: 0.4808 | accs: 0.9103
#  Model 5940 | Train Loss: 0.2626 | accs: 0.9474
#  Model 19940 | Train Loss: 0.0875 | accs: 0.9773
#  Model 59940 | Train Loss: 0.0218 | accs: 0.9962

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_540.pt
# Saved model: models_and_data/model_additional_540.pt
# ✅ Model saved to models_and_data\model_additional_1940.pt
# Saved model: models_and_data/model_additional_1940.pt
# ✅ Model saved to models_and_data\model_additional_5940.pt
# Saved model: models_and_data/model_additional_5940.pt
# ✅ Model saved to models_and_data\model_additional_19940.pt
# Saved model: models_and_data/model_additional_19940.pt
# ✅ Model saved to models_and_data\model_additional_59940.pt
# Saved model: models_and_data/model_additional_59940.pt
