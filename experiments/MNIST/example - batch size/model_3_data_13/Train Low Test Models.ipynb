# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 13            
model_seed = 3           

# --- Training configuration ---
epochs = 500
batch_sizes = [100, 200, 500, 1000, 6000]

# --- Dataset configuration ---
base_data_size = 6000
dataset_type = "data"   
dataset_quantities = [0]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
from minima_volume.models import MNIST_model_data as model_module

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device = device
)

# MNIST specific initialization parameters
hidden_dims = [256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for batch_size in batch_sizes:
    print (f"Training batch_size {batch_size}")
    # Assemble training dataset
    x_train = x_base_train#, x_additional[:additional_data]], dim=0)
    y_train = y_base_train#, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    #batch_size = len(x_train) # We are varying batch size now!!!

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": 0,
        "dataset_type": dataset_type,
        "batch_size": batch_size,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Training batch_size 100
# Epoch 1/500: Train Loss 0.7452 | Test Loss 0.3570 | accs Train 0.7885 Test 0.8967
# Epoch 100/500: Train Loss 0.0000 | Test Loss 0.2980 | accs Train 1.0000 Test 0.9553
# Epoch 200/500: Train Loss 0.0000 | Test Loss 0.3729 | accs Train 1.0000 Test 0.9561
# Epoch 300/500: Train Loss 0.0000 | Test Loss 0.4397 | accs Train 1.0000 Test 0.9565
# Epoch 400/500: Train Loss 0.0000 | Test Loss 0.3030 | accs Train 1.0000 Test 0.9553
# Epoch 500/500: Train Loss 0.0000 | Test Loss 0.3454 | accs Train 1.0000 Test 0.9563
# Training batch_size 200
# Epoch 1/500: Train Loss 0.9839 | Test Loss 0.4109 | accs Train 0.7382 Test 0.8789
# Epoch 100/500: Train Loss 0.0001 | Test Loss 0.2907 | accs Train 1.0000 Test 0.9523
# Epoch 200/500: Train Loss 0.0000 | Test Loss 0.3351 | accs Train 1.0000 Test 0.9522
# Epoch 300/500: Train Loss 0.0000 | Test Loss 0.3738 | accs Train 1.0000 Test 0.9526
# Epoch 400/500: Train Loss 0.0000 | Test Loss 0.4092 | accs Train 1.0000 Test 0.9528
# Epoch 500/500: Train Loss 0.0000 | Test Loss 0.4434 | accs Train 1.0000 Test 0.9529
# Training batch_size 500
# Epoch 1/500: Train Loss 1.5343 | Test Loss 0.6891 | accs Train 0.6387 Test 0.8323
# Epoch 100/500: Train Loss 0.0004 | Test Loss 0.2801 | accs Train 1.0000 Test 0.9489
# Epoch 200/500: Train Loss 0.0001 | Test Loss 0.3149 | accs Train 1.0000 Test 0.9493
# Epoch 300/500: Train Loss 0.0000 | Test Loss 0.3368 | accs Train 1.0000 Test 0.9505
# Epoch 400/500: Train Loss 0.0000 | Test Loss 0.3549 | accs Train 1.0000 Test 0.9502
# Epoch 500/500: Train Loss 0.0000 | Test Loss 0.3714 | accs Train 1.0000 Test 0.9508
# Training batch_size 1000
# Epoch 1/500: Train Loss 1.9665 | Test Loss 1.3637 | accs Train 0.5157 Test 0.7566
# Epoch 100/500: Train Loss 0.0012 | Test Loss 0.2641 | accs Train 1.0000 Test 0.9473
# Epoch 200/500: Train Loss 0.0003 | Test Loss 0.2994 | accs Train 1.0000 Test 0.9476
# Epoch 300/500: Train Loss 0.0001 | Test Loss 0.3202 | accs Train 1.0000 Test 0.9474
# Epoch 400/500: Train Loss 0.0001 | Test Loss 0.3364 | accs Train 1.0000 Test 0.9481
# Epoch 500/500: Train Loss 0.0000 | Test Loss 0.3491 | accs Train 1.0000 Test 0.9485
# Training batch_size 6000
# Epoch 1/500: Train Loss 2.3115 | Test Loss 2.1834 | accs Train 0.0790 Test 0.4072
# Epoch 100/500: Train Loss 0.0357 | Test Loss 0.2324 | accs Train 0.9968 Test 0.9376
# Epoch 200/500: Train Loss 0.0026 | Test Loss 0.2719 | accs Train 1.0000 Test 0.9431
# Epoch 300/500: Train Loss 0.0009 | Test Loss 0.2957 | accs Train 1.0000 Test 0.9433
# Epoch 400/500: Train Loss 0.0005 | Test Loss 0.3112 | accs Train 1.0000 Test 0.9435
# Epoch 500/500: Train Loss 0.0003 | Test Loss 0.3231 | accs Train 1.0000 Test 0.9435

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["batch_size"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["batch_size"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#  100 samples | Test Loss: 0.3454 | accs: 0.9563
#  200 samples | Test Loss: 0.4434 | accs: 0.9529
#  500 samples | Test Loss: 0.3714 | accs: 0.9508
# 1000 samples | Test Loss: 0.3491 | accs: 0.9485
# 6000 samples | Test Loss: 0.3231 | accs: 0.9435
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model  100 | Train Loss: 0.0000 | accs: 1.0000
#  Model  200 | Train Loss: 0.0000 | accs: 1.0000
#  Model  500 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0000 | accs: 1.0000
#  Model 6000 | Train Loss: 0.0003 | accs: 1.0000

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_batch_{model_data['batch_size']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
            batch_size=model_data["batch_size"]
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_batch_100.pt
# Saved model: models_and_data/model_batch_100.pt
# ✅ Model saved to models_and_data\model_batch_200.pt
# Saved model: models_and_data/model_batch_200.pt
# ✅ Model saved to models_and_data\model_batch_500.pt
# Saved model: models_and_data/model_batch_500.pt
# ✅ Model saved to models_and_data\model_batch_1000.pt
# Saved model: models_and_data/model_batch_1000.pt
# ✅ Model saved to models_and_data\model_batch_6000.pt
# Saved model: models_and_data/model_batch_6000.pt
