
#
# Top perturbations for poison_100:
# Top 5 r_vals: [17.87094573927904, 16.07244419066374, 16.061102748902375, 16.058352635911675, 16.056346042097108]
# Top 5 seeds: [813, 472, 424, 691, 708]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [9.723174709432556, 9.71597573699033, 9.709499957354483, 9.708947645548768, 9.694425811938837]
# Top 5 seeds: [704, 424, 517, 448, 606]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [12.688081095041325, 12.663143429241916, 12.65845481328436, 11.161807702154716, 11.16141957684982]
# Top 5 seeds: [691, 542, 271, 704, 472]
# Plot saved to: poison_10/loss_0.1/log_volume.png
# Test loss  [0.2568010985851288, 0.2684527039527893, 0.45825767517089844, 0.33320149779319763]
# log_exp_r_n  [702362.4743272916, 677960.4549778402, 534835.5336384856, 597419.8472926293]
# Plot saved to: poison_10/loss_0.1/gen_log_volume.png
# Plot saved to: poison_10/loss_0.1/test_vs_data.png
# Plot saved to: poison_10/loss_0.1/other_plots/avg_radius.png
# Plot saved to: poison_10/loss_0.1/other_plots/radius_hist.png
# Plot saved to: poison_10/acc_0.95/avg_radius.png
# Plot saved to: poison_10/acc_0.95/radius_hist.png
# Plot saved to: poison_10/acc_0.95/log_volume.png
# Plot saved to: poison_10/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 1, 2]
# test_loss ranks: [4, 3, 1, 2]
# log_exp_r_n ranks: [1, 2, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to poison_10/loss_0.1\results.json
# Successfully analyzed poison_10 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from poison_10
# The number of model parameters is  235146
# The loss landscape is for poison trained with 10
# poison_10: 0.0005103661678731441
# poison_100: 0.0006193991866894066
# poison_1000: 0.0036946742329746485
# poison_500: 0.0012970700627192855
#
# Top perturbations for poison_10:
# Top 5 r_vals: [16.08261839811467, 16.061102748902375, 16.058352635911675, 16.056346042097108, 16.05513340973657]
# Top 5 seeds: [589, 424, 691, 708, 373]
#
# Top perturbations for poison_100:
# Top 5 r_vals: [14.323654048698996, 14.307375484918436, 14.306657392386823, 14.27781400903368, 12.710603509845935]
# Top 5 seeds: [691, 18, 813, 859, 419]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [8.383757785173987, 8.37755050791513, 8.351094330273021, 7.150076313561755, 7.143672161960515]
# Top 5 seeds: [704, 424, 893, 594, 182]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [9.722836609166958, 9.721866859488195, 9.717803553408139, 9.71597573699033, 9.715387418116618]
# Top 5 seeds: [472, 139, 995, 424, 329]
# Plot saved to: poison_10/loss_0.05/log_volume.png
# Test loss  [0.2568010985851288, 0.2684527039527893, 0.45825767517089844, 0.33320149779319763]
# log_exp_r_n  [653167.3274078771, 625931.121935924, 499983.14719836734, 534827.3568536675]
# Plot saved to: poison_10/loss_0.05/gen_log_volume.png
# Plot saved to: poison_10/loss_0.05/test_vs_data.png
# Plot saved to: poison_10/loss_0.05/other_plots/avg_radius.png
# Plot saved to: poison_10/loss_0.05/other_plots/radius_hist.png
# Plot saved to: poison_10/acc_0.9/avg_radius.png
# Plot saved to: poison_10/acc_0.9/radius_hist.png
# Plot saved to: poison_10/acc_0.9/log_volume.png
# Plot saved to: poison_10/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 1, 2]
# test_loss ranks: [4, 3, 1, 2]
# log_exp_r_n ranks: [1, 2, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to poison_10/loss_0.05\results.json
# Successfully analyzed poison_10 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from poison_10
# The number of model parameters is  235146
# The loss landscape is for poison trained with 10
# poison_10: 0.0005103661678731441
# poison_100: 0.0006193991866894066
# poison_1000: 0.0036946742329746485
# poison_500: 0.0012970700627192855
#
# Top perturbations for poison_10:
# Top 5 r_vals: [12.709206968676668, 12.707254042954801, 12.699215162993573, 12.698288918222632, 12.690254023824101]
# Top 5 seeds: [384, 589, 472, 140, 424]
#
# Top perturbations for poison_100:
# Top 5 r_vals: [11.16141957684982, 11.153543575626651, 11.151633774938663, 11.147642529700414, 11.147636224415677]
# Top 5 seeds: [472, 424, 691, 994, 540]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [6.002572142047647, 6.002363416883681, 6.001925621503665, 5.99812787844811, 5.9977646815924]
# Top 5 seeds: [704, 472, 140, 424, 329]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [8.376116035398375, 8.359653279460485, 8.359559612509647, 8.357419480548662, 8.356558060332254]
# Top 5 seeds: [691, 542, 922, 437, 271]
# Plot saved to: poison_10/loss_0.02/log_volume.png
# Test loss  [0.2568010985851288, 0.2684527039527893, 0.45825767517089844, 0.33320149779319763]
# log_exp_r_n  [597811.0438499256, 567274.1523710086, 421418.9478950224, 499768.7151523392]
# Plot saved to: poison_10/loss_0.02/gen_log_volume.png
# Plot saved to: poison_10/loss_0.02/test_vs_data.png
# Plot saved to: poison_10/loss_0.02/other_plots/avg_radius.png
# Plot saved to: poison_10/loss_0.02/other_plots/radius_hist.png
# Plot saved to: poison_10/acc_0.85/avg_radius.png
# Plot saved to: poison_10/acc_0.85/radius_hist.png
# Plot saved to: poison_10/acc_0.85/log_volume.png
# Plot saved to: poison_10/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 1, 2]
# test_loss ranks: [4, 3, 1, 2]
# log_exp_r_n ranks: [1, 2, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to poison_10/loss_0.02\results.json
# Successfully analyzed poison_10 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
