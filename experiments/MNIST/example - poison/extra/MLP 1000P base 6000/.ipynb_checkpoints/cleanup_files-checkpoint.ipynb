# %%
import os
import shutil

# names you want to delete
TARGETS = {"poison_10"}
#{"loss", "accuracy", "log_volume.png", "log_volume_generalization.png", "model_modification_vs_test_loss.png", "results.json"}  

# get current folder (where this script is located)
base_dir = "."

for root, dirs, files in os.walk(base_dir, topdown=False):
    # check files
    for name in files:
        if name in TARGETS:
            path = os.path.join(root, name)
            os.remove(path)
            print(f"Deleted file: {path}")

    # check directories
    for name in dirs:
        if name in TARGETS:
            path = os.path.join(root, name)
            shutil.rmtree(path, ignore_errors=True)
            print(f"Deleted folder: {path}")
# Out:
# Deleted folder: .\analysis\poison_10
# Deleted folder: .\model_0_data_10\poison_10
# Deleted folder: .\model_1_data_11\poison_10
# Deleted folder: .\model_2_data_12\poison_10
# Deleted folder: .\model_3_data_13\poison_10
# Deleted folder: .\model_4_data_14\poison_10
# Deleted folder: .\model_5_data_15\poison_10
# Deleted folder: .\model_6_data_16\poison_10
# Deleted folder: .\model_7_data_17\poison_10
# Deleted folder: .\model_8_data_18\poison_10
# Deleted folder: .\model_9_data_19\poison_10
