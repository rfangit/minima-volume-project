# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train_sam

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 14            
model_seed = 4           

# --- Training configuration ---
epochs = 1000            

# --- Dataset configuration ---
base_data_size = 20      
dataset_type = "data"   
dataset_quantities = [0, 30, 100, 300, 700]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

test_dataset_size = 2000

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    base_data_size=base_data_size,
    dataset_quantities=dataset_quantities,
    test_dataset_size=test_dataset_size,
    noise=0.3, # default swiss params
    extra_pts=1000,
    dataset_type=dataset_type,
    seed=data_seed
)

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train_sam(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# [SAM] Epoch 1/1000: Train Loss 0.6707 | Test Loss 0.7015 | accs Train 0.6500 Test 0.5000
# [SAM] Epoch 100/1000: Train Loss 0.2781 | Test Loss 2.7046 | accs Train 0.8500 Test 0.5205
# [SAM] Epoch 200/1000: Train Loss 0.1353 | Test Loss 5.2128 | accs Train 0.9500 Test 0.4765
# [SAM] Epoch 300/1000: Train Loss 0.0953 | Test Loss 6.4580 | accs Train 0.9500 Test 0.5085
# [SAM] Epoch 400/1000: Train Loss 0.0173 | Test Loss 8.1890 | accs Train 1.0000 Test 0.5028
# [SAM] Epoch 500/1000: Train Loss 0.0072 | Test Loss 8.9045 | accs Train 1.0000 Test 0.4995
# [SAM] Epoch 600/1000: Train Loss 0.0035 | Test Loss 9.8072 | accs Train 1.0000 Test 0.4988
# [SAM] Epoch 700/1000: Train Loss 0.0021 | Test Loss 10.3838 | accs Train 1.0000 Test 0.4978
# [SAM] Epoch 800/1000: Train Loss 0.0008 | Test Loss 11.1887 | accs Train 1.0000 Test 0.4968
# [SAM] Epoch 900/1000: Train Loss 0.0004 | Test Loss 11.7099 | accs Train 1.0000 Test 0.4948
# [SAM] Epoch 1000/1000: Train Loss 0.0002 | Test Loss 12.1579 | accs Train 1.0000 Test 0.4958
# Completed training with 0 additional samples of data
# [SAM] Epoch 1/1000: Train Loss 0.6798 | Test Loss 0.7020 | accs Train 0.6200 Test 0.5000
# [SAM] Epoch 100/1000: Train Loss 0.5139 | Test Loss 0.7081 | accs Train 0.7200 Test 0.5770
# [SAM] Epoch 200/1000: Train Loss 0.3492 | Test Loss 0.9461 | accs Train 0.8400 Test 0.5970
# [SAM] Epoch 300/1000: Train Loss 0.2083 | Test Loss 1.1338 | accs Train 0.9400 Test 0.6045
# [SAM] Epoch 400/1000: Train Loss 0.1281 | Test Loss 1.1271 | accs Train 0.9600 Test 0.6468
# [SAM] Epoch 500/1000: Train Loss 0.0810 | Test Loss 1.1360 | accs Train 0.9800 Test 0.6835
# [SAM] Epoch 600/1000: Train Loss 0.0522 | Test Loss 1.1594 | accs Train 1.0000 Test 0.7077
# [SAM] Epoch 700/1000: Train Loss 0.0327 | Test Loss 1.1092 | accs Train 1.0000 Test 0.7262
# [SAM] Epoch 800/1000: Train Loss 0.0212 | Test Loss 0.9539 | accs Train 1.0000 Test 0.7548
# [SAM] Epoch 900/1000: Train Loss 0.0147 | Test Loss 0.9114 | accs Train 1.0000 Test 0.7802
# [SAM] Epoch 1000/1000: Train Loss 0.0093 | Test Loss 0.8970 | accs Train 1.0000 Test 0.7947
# Completed training with 30 additional samples of data
# [SAM] Epoch 1/1000: Train Loss 0.6925 | Test Loss 0.6988 | accs Train 0.5583 Test 0.5000
# [SAM] Epoch 100/1000: Train Loss 0.5460 | Test Loss 0.5930 | accs Train 0.6667 Test 0.6425
# [SAM] Epoch 200/1000: Train Loss 0.3976 | Test Loss 0.5138 | accs Train 0.7917 Test 0.6787
# [SAM] Epoch 300/1000: Train Loss 0.1898 | Test Loss 0.3438 | accs Train 0.9500 Test 0.8738
# [SAM] Epoch 400/1000: Train Loss 0.0749 | Test Loss 0.2099 | accs Train 1.0000 Test 0.9393
# [SAM] Epoch 500/1000: Train Loss 0.0342 | Test Loss 0.1396 | accs Train 1.0000 Test 0.9633
# [SAM] Epoch 600/1000: Train Loss 0.0138 | Test Loss 0.0988 | accs Train 1.0000 Test 0.9758
# [SAM] Epoch 700/1000: Train Loss 0.0072 | Test Loss 0.1070 | accs Train 1.0000 Test 0.9825
# [SAM] Epoch 800/1000: Train Loss 0.0112 | Test Loss 0.1063 | accs Train 1.0000 Test 0.9838
# [SAM] Epoch 900/1000: Train Loss 0.0056 | Test Loss 0.1135 | accs Train 1.0000 Test 0.9835
# [SAM] Epoch 1000/1000: Train Loss 0.0042 | Test Loss 0.1172 | accs Train 1.0000 Test 0.9838
# Completed training with 100 additional samples of data
# [SAM] Epoch 1/1000: Train Loss 0.6956 | Test Loss 0.6987 | accs Train 0.5437 Test 0.5000
# [SAM] Epoch 100/1000: Train Loss 0.5745 | Test Loss 0.6033 | accs Train 0.6438 Test 0.6418
# [SAM] Epoch 200/1000: Train Loss 0.4983 | Test Loss 0.5495 | accs Train 0.6969 Test 0.6617
# [SAM] Epoch 300/1000: Train Loss 0.2472 | Test Loss 0.2892 | accs Train 0.9219 Test 0.9060
# [SAM] Epoch 400/1000: Train Loss 0.0756 | Test Loss 0.0991 | accs Train 0.9969 Test 0.9942
# [SAM] Epoch 500/1000: Train Loss 0.0223 | Test Loss 0.0477 | accs Train 1.0000 Test 0.9952
# [SAM] Epoch 600/1000: Train Loss 0.0095 | Test Loss 0.0375 | accs Train 1.0000 Test 0.9952
# [SAM] Epoch 700/1000: Train Loss 0.0054 | Test Loss 0.0330 | accs Train 1.0000 Test 0.9955
# [SAM] Epoch 800/1000: Train Loss 0.0033 | Test Loss 0.0307 | accs Train 1.0000 Test 0.9955
# [SAM] Epoch 900/1000: Train Loss 0.0062 | Test Loss 0.0245 | accs Train 1.0000 Test 0.9962
# [SAM] Epoch 1000/1000: Train Loss 0.0035 | Test Loss 0.0264 | accs Train 1.0000 Test 0.9955
# Completed training with 300 additional samples of data
# [SAM] Epoch 1/1000: Train Loss 0.7000 | Test Loss 0.6980 | accs Train 0.5139 Test 0.5000
# [SAM] Epoch 100/1000: Train Loss 0.5845 | Test Loss 0.5843 | accs Train 0.6611 Test 0.6630
# [SAM] Epoch 200/1000: Train Loss 0.4140 | Test Loss 0.4222 | accs Train 0.7917 Test 0.7772
# [SAM] Epoch 300/1000: Train Loss 0.1651 | Test Loss 0.1789 | accs Train 0.9889 Test 0.9772
# [SAM] Epoch 400/1000: Train Loss 0.0512 | Test Loss 0.0612 | accs Train 0.9958 Test 0.9922
# [SAM] Epoch 500/1000: Train Loss 0.0225 | Test Loss 0.0273 | accs Train 0.9972 Test 0.9958
# [SAM] Epoch 600/1000: Train Loss 0.0168 | Test Loss 0.0225 | accs Train 0.9972 Test 0.9955
# [SAM] Epoch 700/1000: Train Loss 0.0100 | Test Loss 0.0153 | accs Train 0.9972 Test 0.9962
# [SAM] Epoch 800/1000: Train Loss 0.0070 | Test Loss 0.0110 | accs Train 0.9972 Test 0.9970
# [SAM] Epoch 900/1000: Train Loss 0.0092 | Test Loss 0.0141 | accs Train 0.9972 Test 0.9970
# [SAM] Epoch 1000/1000: Train Loss 0.0051 | Test Loss 0.0096 | accs Train 0.9986 Test 0.9970
# Completed training with 700 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 12.1579 | accs: 0.4958
#   30 samples | Test Loss: 0.8970 | accs: 0.7947
#  100 samples | Test Loss: 0.1172 | accs: 0.9838
#  300 samples | Test Loss: 0.0264 | accs: 0.9955
#  700 samples | Test Loss: 0.0096 | accs: 0.9970
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0002 | accs: 1.0000
#  Model   30 | Train Loss: 0.0075 | accs: 1.0000
#  Model  100 | Train Loss: 0.0037 | accs: 1.0000
#  Model  300 | Train Loss: 0.0037 | accs: 1.0000
#  Model  700 | Train Loss: 0.0031 | accs: 1.0000
#
# Dataset type: data, additional samples: 30
#  Model    0 | Train Loss: 7.0147 | accs: 0.7400
#  Model   30 | Train Loss: 0.0092 | accs: 1.0000
#  Model  100 | Train Loss: 0.0047 | accs: 1.0000
#  Model  300 | Train Loss: 0.0039 | accs: 1.0000
#  Model  700 | Train Loss: 0.0071 | accs: 1.0000
#
# Dataset type: data, additional samples: 100
#  Model    0 | Train Loss: 9.6360 | accs: 0.6083
#  Model   30 | Train Loss: 0.7242 | accs: 0.8500
#  Model  100 | Train Loss: 0.0042 | accs: 1.0000
#  Model  300 | Train Loss: 0.0038 | accs: 1.0000
#  Model  700 | Train Loss: 0.0097 | accs: 1.0000
#
# Dataset type: data, additional samples: 300
#  Model    0 | Train Loss: 9.1577 | accs: 0.5687
#  Model   30 | Train Loss: 0.7252 | accs: 0.8219
#  Model  100 | Train Loss: 0.0955 | accs: 0.9906
#  Model  300 | Train Loss: 0.0035 | accs: 1.0000
#  Model  700 | Train Loss: 0.0056 | accs: 1.0000
#
# Dataset type: data, additional samples: 700
#  Model    0 | Train Loss: 9.8910 | accs: 0.5208
#  Model   30 | Train Loss: 0.8251 | accs: 0.8014
#  Model  100 | Train Loss: 0.0896 | accs: 0.9917
#  Model  300 | Train Loss: 0.0171 | accs: 0.9986
#  Model  700 | Train Loss: 0.0051 | accs: 0.9986

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_30.pt
# Saved model: models_and_data/model_additional_30.pt
# ✅ Model saved to models_and_data\model_additional_100.pt
# Saved model: models_and_data/model_additional_100.pt
# ✅ Model saved to models_and_data\model_additional_300.pt
# Saved model: models_and_data/model_additional_300.pt
# ✅ Model saved to models_and_data\model_additional_700.pt
# Saved model: models_and_data/model_additional_700.pt
