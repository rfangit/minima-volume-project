# %%
import os
import subprocess
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock

# ---------- Configuration ----------
MAX_WORKERS = 1
EXCLUDE_PREFIXES = [
    '__pycache__', 
    '.ipynb_checkpoints', 
    'base', 
    'completed runs', 
    'to do', 
    'analysis'
]

# Lock for thread-safe printing
print_lock = Lock()

# ---------- Core Helpers ----------
def run_notebook(folder: str, notebook_name: str) -> str:
    """
    Execute a Jupyter notebook in place using nbconvert.
    Returns a status string with execution time.
    All printing inside this function is thread-safe.
    """
    notebook_path = os.path.join(folder, notebook_name)
    if not os.path.exists(notebook_path):
        with print_lock:
            print(f"SKIP: {notebook_name} not found in {folder}", flush=True)
        return f"SKIP: {notebook_name} not found in {folder}"

    with print_lock:
        print(f"🔹 Running {notebook_path}...", flush=True)

    start_time = time.time()
    try:
        subprocess.run(
            [
                'jupyter', 'nbconvert', '--to', 'notebook',
                '--execute', notebook_path, '--inplace',
                '--ExecutePreprocessor.timeout=-1'
            ],
            check=True,
            capture_output=True,
            text=True
        )
        elapsed = time.time() - start_time
        return f"✅ SUCCESS: {folder}/{notebook_name} (took {elapsed:.2f}s)"
    except subprocess.CalledProcessError as e:
        elapsed = time.time() - start_time
        stderr_clean = e.stderr.strip()
        return f"❌ ERROR: {folder}/{notebook_name} - {stderr_clean} (took {elapsed:.2f}s)"

def find_folders(base_dir: str = '.') -> list[str]:
    """Return a list of folders to process, excluding certain prefixes."""
    return [
        d for d in os.listdir(base_dir)
        if os.path.isdir(d) and not any(d.startswith(prefix) for prefix in EXCLUDE_PREFIXES)
    ]

def run_in_parallel(folders: list[str], notebook_names: list[str]):
    """Run one or more notebooks across all folders in parallel, with thread-safe printing."""
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [
            executor.submit(run_notebook, folder, nb)
            for folder in folders
            for nb in notebook_names
        ]

        for future in as_completed(futures):
            msg = future.result().strip()
            with print_lock:
                print(msg)
    with print_lock:
        print("✅ All done!")

# ---------- Specialized Variants ----------
def run_random_perturbs_parallel():
    """Run Random Perturbs.ipynb across all model_* folders."""
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders for Random Perturbs.")
    run_in_parallel(folders, ["Random Perturbs.ipynb"])

def run_volume_parallel():
    """Run all notebooks containing 'Volume Cutoff' or 'Volume Estimation' across folders."""
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders for Volume notebooks.")

    notebook_names = []
    if folders:
        for nb in os.listdir(folders[0]):
            if nb.endswith(".ipynb") and ("Volume Cutoff" in nb or "Volume Estimation" in nb):
                notebook_names.append(nb)

    if not notebook_names:
        with print_lock:
            print("⚠️ No Volume notebooks found in reference folder.")
        return

    with print_lock:
        print(f"Will run these notebooks: {notebook_names}")
    run_in_parallel(folders, notebook_names)

def run_nb_parallel():
    """Generic function for ad-hoc notebook runs (prompt user)."""
    notebook_name = input("Enter notebook name (without .ipynb): ").strip() + ".ipynb"
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders to process.")
    run_in_parallel(folders, [notebook_name])

run_volume_parallel()
# Out:
# Found 10 folders for Volume notebooks.
# Will run these notebooks: ['Volume Cutoff.ipynb', 'Volume Estimation Pipeline.ipynb']
# 🔹 Running model_0_data_10\Volume Cutoff.ipynb...
# ✅ SUCCESS: model_0_data_10/Volume Cutoff.ipynb (took 41.09s)
# 🔹 Running model_0_data_10\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_0_data_10/Volume Estimation Pipeline.ipynb (took 67.17s)
# 🔹 Running model_1_data_11\Volume Cutoff.ipynb...
# ✅ SUCCESS: model_1_data_11/Volume Cutoff.ipynb (took 39.07s)
# 🔹 Running model_1_data_11\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_1_data_11/Volume Estimation Pipeline.ipynb (took 67.29s)
# 🔹 Running model_2_data_12\Volume Cutoff.ipynb...
# ✅ SUCCESS: model_2_data_12/Volume Cutoff.ipynb (took 39.07s)
# 🔹 Running model_2_data_12\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_2_data_12/Volume Estimation Pipeline.ipynb (took 67.84s)
# 🔹 Running model_3_data_13\Volume Cutoff.ipynb...
# ✅ SUCCESS: model_3_data_13/Volume Cutoff.ipynb (took 39.47s)
# 🔹 Running model_3_data_13\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_3_data_13/Volume Estimation Pipeline.ipynb (took 68.17s)
# 🔹 Running model_4_data_14\Volume Cutoff.ipynb...
# ✅ SUCCESS: model_4_data_14/Volume Cutoff.ipynb (took 40.43s)
# 🔹 Running model_4_data_14\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_4_data_14/Volume Estimation Pipeline.ipynb (took 72.84s)
# 🔹 Running model_5_data_15\Volume Cutoff.ipynb...
# ✅ SUCCESS: model_5_data_15/Volume Cutoff.ipynb (took 40.39s)
# 🔹 Running model_5_data_15\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_5_data_15/Volume Estimation Pipeline.ipynb (took 70.32s)
# 🔹 Running model_6_data_16\Volume Cutoff.ipynb...
# ✅ SUCCESS: model_6_data_16/Volume Cutoff.ipynb (took 40.72s)
# 🔹 Running model_6_data_16\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_6_data_16/Volume Estimation Pipeline.ipynb (took 67.73s)
# 🔹 Running model_7_data_17\Volume Cutoff.ipynb...
# 🔹 Running model_7_data_17\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_7_data_17/Volume Cutoff.ipynb (took 39.39s)
# ✅ SUCCESS: model_7_data_17/Volume Estimation Pipeline.ipynb (took 67.44s)
# 🔹 Running model_8_data_18\Volume Cutoff.ipynb...
# ✅ SUCCESS: model_8_data_18/Volume Cutoff.ipynb (took 39.66s)
# 🔹 Running model_8_data_18\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_8_data_18/Volume Estimation Pipeline.ipynb (took 64.41s)
# 🔹 Running model_9_data_19\Volume Cutoff.ipynb...
# ✅ SUCCESS: model_9_data_19/Volume Cutoff.ipynb (took 40.42s)
# 🔹 Running model_9_data_19\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_9_data_19/Volume Estimation Pipeline.ipynb (took 67.96s)
# ✅ All done!
# ❌ ERROR: model_0_data_10/Volume Cutoff.ipynb - [NbConvertApp] Converting notebook model_0_data_10\Volume Cutoff.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # ====================================
# # Load Trained Models and Dataset
# # ====================================
# target_dir = "models_and_data"  # relative path
# loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#     model_template=model_template,
#     target_dir=target_dir,
#     device=device,
# )
#
# # Dataset Info
# dataset_type = loaded_dataset['dataset_type']
# dataset_quantities = loaded_dataset['dataset_quantities']
# print(f"Dataset type: {dataset_type}")
# print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")
#
# print("\nTensor shapes:")
# for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
#     shape = getattr(loaded_dataset[key], "shape", None)
#     print(f"  {key}: {shape if shape is not None else 'None'}")
#
# # Reconstruct trained_model dicts safely.
# # If the loss or accuracy or additional metrics happen to be
# # tensors, they get safely converted to lists.
# all_models = [
#     {
#         "model": model,
#         **{
#             k: tensor_to_list(model_data[k], key_path=k)
#             for k in ["train_loss", "train_accs", "test_loss", "test_accs", "additional_data", "dataset_type"]
#         },
#     }
#     for model, model_data in zip(loaded_models, loaded_model_data)
# ]
# print(f"Reconstructed {len(all_models)} trained models")
# ------------------
#
# ----- stdout -----
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_additional_0.pt
#   - model_additional_1940.pt
#   - model_additional_19940.pt
#   - model_additional_540.pt
#   - model_additional_5940.pt
#   - model_additional_59940.pt
# ------------------
#
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 5
#       1 # ====================================
#       2 # Load Trained Models and Dataset
#       3 # ====================================
#       4 target_dir = "models_and_data"  # relative path
# ----> 5 loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#       6     model_template=model_template,
#       7     target_dir=target_dir,
#       8     device=device,
#       9 )
#      11 # Dataset Info
#      12 dataset_type = loaded_dataset['dataset_type']
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:382, in load_models_and_data(model_template, target_dir, device)
#     379     model = copy.deepcopy(model_template)
#     381 # Load the model - now returns model_data instead of just additional_data
# --> 382 model_loaded, model_data = load_model(
#     383     model,
#     384     folder=str(target_dir),
#     385     filename=os.path.basename(model_file),
#     386     device=device
#     387 )
#     389 # Store the results
#     390 loaded_models.append(model_loaded)
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:319, in load_model(model, folder, filename, device)
#     316 load_path = os.path.join(folder, filename)
#     317 model_dict = torch.load(load_path, map_location=device)
# --> 319 model.load_state_dict(model_dict["state_dict"])
#     320 model.to(device)
#     322 # Return all metadata in a dictionary
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:2581, in Module.load_state_dict(self, state_dict, strict, assign)
#    2573         error_msgs.insert(
#    2574             0,
#    2575             "Missing key(s) in state_dict: {}. ".format(
#    2576                 ", ".join(f'"{k}"' for k in missing_keys)
#    2577             ),
#    2578         )
#    2580 if len(error_msgs) > 0:
# -> 2581     raise RuntimeError(
#    2582         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2583             self.__class__.__name__, "\n\t".join(error_msgs)
#    2584         )
#    2585     )
#    2586 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for MNIST_MLP:
# 	Unexpected key(s) in state_dict: "model.6.weight", "model.6.bias".
# 	size mismatch for model.2.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([128, 256]).
# 	size mismatch for model.2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for model.4.weight: copying a param with shape torch.Size([128, 256]) from checkpoint, the shape in current model is torch.Size([10, 128]).
# 	size mismatch for model.4.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([10]). (took 6.70s)
# 🔹 Running model_0_data_10\Volume Estimation Pipeline.ipynb...
# 🔹 Running model_1_data_11\Volume Cutoff.ipynb...
# ✅ SUCCESS: model_0_data_10/Volume Estimation Pipeline.ipynb (took 57.15s)
# ❌ ERROR: model_1_data_11/Volume Cutoff.ipynb - [NbConvertApp] Converting notebook model_1_data_11\Volume Cutoff.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # ====================================
# # Load Trained Models and Dataset
# # ====================================
# target_dir = "models_and_data"  # relative path
# loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#     model_template=model_template,
#     target_dir=target_dir,
#     device=device,
# )
#
# # Dataset Info
# dataset_type = loaded_dataset['dataset_type']
# dataset_quantities = loaded_dataset['dataset_quantities']
# print(f"Dataset type: {dataset_type}")
# print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")
#
# print("\nTensor shapes:")
# for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
#     shape = getattr(loaded_dataset[key], "shape", None)
#     print(f"  {key}: {shape if shape is not None else 'None'}")
#
# # Reconstruct trained_model dicts safely.
# # If the loss or accuracy or additional metrics happen to be
# # tensors, they get safely converted to lists.
# all_models = [
#     {
#         "model": model,
#         **{
#             k: tensor_to_list(model_data[k], key_path=k)
#             for k in ["train_loss", "train_accs", "test_loss", "test_accs", "additional_data", "dataset_type"]
#         },
#     }
#     for model, model_data in zip(loaded_models, loaded_model_data)
# ]
# print(f"Reconstructed {len(all_models)} trained models")
# ------------------
#
# ----- stdout -----
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_additional_0.pt
#   - model_additional_1940.pt
#   - model_additional_19940.pt
#   - model_additional_540.pt
#   - model_additional_5940.pt
#   - model_additional_59940.pt
# ------------------
#
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 5
#       1 # ====================================
#       2 # Load Trained Models and Dataset
#       3 # ====================================
#       4 target_dir = "models_and_data"  # relative path
# ----> 5 loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#       6     model_template=model_template,
#       7     target_dir=target_dir,
#       8     device=device,
#       9 )
#      11 # Dataset Info
#      12 dataset_type = loaded_dataset['dataset_type']
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:382, in load_models_and_data(model_template, target_dir, device)
#     379     model = copy.deepcopy(model_template)
#     381 # Load the model - now returns model_data instead of just additional_data
# --> 382 model_loaded, model_data = load_model(
#     383     model,
#     384     folder=str(target_dir),
#     385     filename=os.path.basename(model_file),
#     386     device=device
#     387 )
#     389 # Store the results
#     390 loaded_models.append(model_loaded)
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:319, in load_model(model, folder, filename, device)
#     316 load_path = os.path.join(folder, filename)
#     317 model_dict = torch.load(load_path, map_location=device)
# --> 319 model.load_state_dict(model_dict["state_dict"])
#     320 model.to(device)
#     322 # Return all metadata in a dictionary
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:2581, in Module.load_state_dict(self, state_dict, strict, assign)
#    2573         error_msgs.insert(
#    2574             0,
#    2575             "Missing key(s) in state_dict: {}. ".format(
#    2576                 ", ".join(f'"{k}"' for k in missing_keys)
#    2577             ),
#    2578         )
#    2580 if len(error_msgs) > 0:
# -> 2581     raise RuntimeError(
#    2582         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2583             self.__class__.__name__, "\n\t".join(error_msgs)
#    2584         )
#    2585     )
#    2586 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for MNIST_MLP:
# 	Unexpected key(s) in state_dict: "model.6.weight", "model.6.bias".
# 	size mismatch for model.2.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([128, 256]).
# 	size mismatch for model.2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for model.4.weight: copying a param with shape torch.Size([128, 256]) from checkpoint, the shape in current model is torch.Size([10, 128]).
# 	size mismatch for model.4.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([10]). (took 6.54s)
# 🔹 Running model_1_data_11\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_1_data_11/Volume Estimation Pipeline.ipynb (took 58.28s)
# 🔹 Running model_2_data_12\Volume Cutoff.ipynb...
# ❌ ERROR: model_2_data_12/Volume Cutoff.ipynb - [NbConvertApp] Converting notebook model_2_data_12\Volume Cutoff.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # ====================================
# # Load Trained Models and Dataset
# # ====================================
# target_dir = "models_and_data"  # relative path
# loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#     model_template=model_template,
#     target_dir=target_dir,
#     device=device,
# )
#
# # Dataset Info
# dataset_type = loaded_dataset['dataset_type']
# dataset_quantities = loaded_dataset['dataset_quantities']
# print(f"Dataset type: {dataset_type}")
# print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")
#
# print("\nTensor shapes:")
# for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
#     shape = getattr(loaded_dataset[key], "shape", None)
#     print(f"  {key}: {shape if shape is not None else 'None'}")
#
# # Reconstruct trained_model dicts safely.
# # If the loss or accuracy or additional metrics happen to be
# # tensors, they get safely converted to lists.
# all_models = [
#     {
#         "model": model,
#         **{
#             k: tensor_to_list(model_data[k], key_path=k)
#             for k in ["train_loss", "train_accs", "test_loss", "test_accs", "additional_data", "dataset_type"]
#         },
#     }
#     for model, model_data in zip(loaded_models, loaded_model_data)
# ]
# print(f"Reconstructed {len(all_models)} trained models")
# ------------------
#
# ----- stdout -----
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_additional_0.pt
#   - model_additional_1940.pt
#   - model_additional_19940.pt
#   - model_additional_540.pt
#   - model_additional_5940.pt
#   - model_additional_59940.pt
# ------------------
#
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 5
#       1 # ====================================
#       2 # Load Trained Models and Dataset
#       3 # ====================================
#       4 target_dir = "models_and_data"  # relative path
# ----> 5 loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#       6     model_template=model_template,
#       7     target_dir=target_dir,
#       8     device=device,
#       9 )
#      11 # Dataset Info
#      12 dataset_type = loaded_dataset['dataset_type']
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:382, in load_models_and_data(model_template, target_dir, device)
#     379     model = copy.deepcopy(model_template)
#     381 # Load the model - now returns model_data instead of just additional_data
# --> 382 model_loaded, model_data = load_model(
#     383     model,
#     384     folder=str(target_dir),
#     385     filename=os.path.basename(model_file),
#     386     device=device
#     387 )
#     389 # Store the results
#     390 loaded_models.append(model_loaded)
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:319, in load_model(model, folder, filename, device)
#     316 load_path = os.path.join(folder, filename)
#     317 model_dict = torch.load(load_path, map_location=device)
# --> 319 model.load_state_dict(model_dict["state_dict"])
#     320 model.to(device)
#     322 # Return all metadata in a dictionary
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:2581, in Module.load_state_dict(self, state_dict, strict, assign)
#    2573         error_msgs.insert(
#    2574             0,
#    2575             "Missing key(s) in state_dict: {}. ".format(
#    2576                 ", ".join(f'"{k}"' for k in missing_keys)
#    2577             ),
#    2578         )
#    2580 if len(error_msgs) > 0:
# -> 2581     raise RuntimeError(
#    2582         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2583             self.__class__.__name__, "\n\t".join(error_msgs)
#    2584         )
#    2585     )
#    2586 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for MNIST_MLP:
# 	Unexpected key(s) in state_dict: "model.6.weight", "model.6.bias".
# 	size mismatch for model.2.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([128, 256]).
# 	size mismatch for model.2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for model.4.weight: copying a param with shape torch.Size([128, 256]) from checkpoint, the shape in current model is torch.Size([10, 128]).
# 	size mismatch for model.4.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([10]). (took 6.56s)
# 🔹 Running model_2_data_12\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_2_data_12/Volume Estimation Pipeline.ipynb (took 57.53s)
# 🔹 Running model_3_data_13\Volume Cutoff.ipynb...
# ❌ ERROR: model_3_data_13/Volume Cutoff.ipynb - [NbConvertApp] Converting notebook model_3_data_13\Volume Cutoff.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # ====================================
# # Load Trained Models and Dataset
# # ====================================
# target_dir = "models_and_data"  # relative path
# loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#     model_template=model_template,
#     target_dir=target_dir,
#     device=device,
# )
#
# # Dataset Info
# dataset_type = loaded_dataset['dataset_type']
# dataset_quantities = loaded_dataset['dataset_quantities']
# print(f"Dataset type: {dataset_type}")
# print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")
#
# print("\nTensor shapes:")
# for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
#     shape = getattr(loaded_dataset[key], "shape", None)
#     print(f"  {key}: {shape if shape is not None else 'None'}")
#
# # Reconstruct trained_model dicts safely.
# # If the loss or accuracy or additional metrics happen to be
# # tensors, they get safely converted to lists.
# all_models = [
#     {
#         "model": model,
#         **{
#             k: tensor_to_list(model_data[k], key_path=k)
#             for k in ["train_loss", "train_accs", "test_loss", "test_accs", "additional_data", "dataset_type"]
#         },
#     }
#     for model, model_data in zip(loaded_models, loaded_model_data)
# ]
# print(f"Reconstructed {len(all_models)} trained models")
# ------------------
#
# ----- stdout -----
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_additional_0.pt
#   - model_additional_1940.pt
#   - model_additional_19940.pt
#   - model_additional_540.pt
#   - model_additional_5940.pt
#   - model_additional_59940.pt
# ------------------
#
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 5
#       1 # ====================================
#       2 # Load Trained Models and Dataset
#       3 # ====================================
#       4 target_dir = "models_and_data"  # relative path
# ----> 5 loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#       6     model_template=model_template,
#       7     target_dir=target_dir,
#       8     device=device,
#       9 )
#      11 # Dataset Info
#      12 dataset_type = loaded_dataset['dataset_type']
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:382, in load_models_and_data(model_template, target_dir, device)
#     379     model = copy.deepcopy(model_template)
#     381 # Load the model - now returns model_data instead of just additional_data
# --> 382 model_loaded, model_data = load_model(
#     383     model,
#     384     folder=str(target_dir),
#     385     filename=os.path.basename(model_file),
#     386     device=device
#     387 )
#     389 # Store the results
#     390 loaded_models.append(model_loaded)
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:319, in load_model(model, folder, filename, device)
#     316 load_path = os.path.join(folder, filename)
#     317 model_dict = torch.load(load_path, map_location=device)
# --> 319 model.load_state_dict(model_dict["state_dict"])
#     320 model.to(device)
#     322 # Return all metadata in a dictionary
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:2581, in Module.load_state_dict(self, state_dict, strict, assign)
#    2573         error_msgs.insert(
#    2574             0,
#    2575             "Missing key(s) in state_dict: {}. ".format(
#    2576                 ", ".join(f'"{k}"' for k in missing_keys)
#    2577             ),
#    2578         )
#    2580 if len(error_msgs) > 0:
# -> 2581     raise RuntimeError(
#    2582         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2583             self.__class__.__name__, "\n\t".join(error_msgs)
#    2584         )
#    2585     )
#    2586 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for MNIST_MLP:
# 	Unexpected key(s) in state_dict: "model.6.weight", "model.6.bias".
# 	size mismatch for model.2.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([128, 256]).
# 	size mismatch for model.2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for model.4.weight: copying a param with shape torch.Size([128, 256]) from checkpoint, the shape in current model is torch.Size([10, 128]).
# 	size mismatch for model.4.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([10]). (took 6.50s)
# 🔹 Running model_3_data_13\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_3_data_13/Volume Estimation Pipeline.ipynb (took 58.11s)
# 🔹 Running model_4_data_14\Volume Cutoff.ipynb...
# ❌ ERROR: model_4_data_14/Volume Cutoff.ipynb - [NbConvertApp] Converting notebook model_4_data_14\Volume Cutoff.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # ====================================
# # Load Trained Models and Dataset
# # ====================================
# target_dir = "models_and_data"  # relative path
# loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#     model_template=model_template,
#     target_dir=target_dir,
#     device=device,
# )
#
# # Dataset Info
# dataset_type = loaded_dataset['dataset_type']
# dataset_quantities = loaded_dataset['dataset_quantities']
# print(f"Dataset type: {dataset_type}")
# print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")
#
# print("\nTensor shapes:")
# for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
#     shape = getattr(loaded_dataset[key], "shape", None)
#     print(f"  {key}: {shape if shape is not None else 'None'}")
#
# # Reconstruct trained_model dicts safely.
# # If the loss or accuracy or additional metrics happen to be
# # tensors, they get safely converted to lists.
# all_models = [
#     {
#         "model": model,
#         **{
#             k: tensor_to_list(model_data[k], key_path=k)
#             for k in ["train_loss", "train_accs", "test_loss", "test_accs", "additional_data", "dataset_type"]
#         },
#     }
#     for model, model_data in zip(loaded_models, loaded_model_data)
# ]
# print(f"Reconstructed {len(all_models)} trained models")
# ------------------
#
# ----- stdout -----
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_additional_0.pt
#   - model_additional_1940.pt
#   - model_additional_19940.pt
#   - model_additional_540.pt
#   - model_additional_5940.pt
#   - model_additional_59940.pt
# ------------------
#
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 5
#       1 # ====================================
#       2 # Load Trained Models and Dataset
#       3 # ====================================
#       4 target_dir = "models_and_data"  # relative path
# ----> 5 loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#       6     model_template=model_template,
#       7     target_dir=target_dir,
#       8     device=device,
#       9 )
#      11 # Dataset Info
#      12 dataset_type = loaded_dataset['dataset_type']
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:382, in load_models_and_data(model_template, target_dir, device)
#     379     model = copy.deepcopy(model_template)
#     381 # Load the model - now returns model_data instead of just additional_data
# --> 382 model_loaded, model_data = load_model(
#     383     model,
#     384     folder=str(target_dir),
#     385     filename=os.path.basename(model_file),
#     386     device=device
#     387 )
#     389 # Store the results
#     390 loaded_models.append(model_loaded)
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:319, in load_model(model, folder, filename, device)
#     316 load_path = os.path.join(folder, filename)
#     317 model_dict = torch.load(load_path, map_location=device)
# --> 319 model.load_state_dict(model_dict["state_dict"])
#     320 model.to(device)
#     322 # Return all metadata in a dictionary
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:2581, in Module.load_state_dict(self, state_dict, strict, assign)
#    2573         error_msgs.insert(
#    2574             0,
#    2575             "Missing key(s) in state_dict: {}. ".format(
#    2576                 ", ".join(f'"{k}"' for k in missing_keys)
#    2577             ),
#    2578         )
#    2580 if len(error_msgs) > 0:
# -> 2581     raise RuntimeError(
#    2582         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2583             self.__class__.__name__, "\n\t".join(error_msgs)
#    2584         )
#    2585     )
#    2586 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for MNIST_MLP:
# 	Unexpected key(s) in state_dict: "model.6.weight", "model.6.bias".
# 	size mismatch for model.2.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([128, 256]).
# 	size mismatch for model.2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for model.4.weight: copying a param with shape torch.Size([128, 256]) from checkpoint, the shape in current model is torch.Size([10, 128]).
# 	size mismatch for model.4.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([10]). (took 7.13s)
# 🔹 Running model_4_data_14\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_4_data_14/Volume Estimation Pipeline.ipynb (took 57.44s)
# 🔹 Running model_5_data_15\Volume Cutoff.ipynb...
# ...
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # ====================================
# # Load Trained Models and Dataset
# # ====================================
# target_dir = "models_and_data"  # relative path
# loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#     model_template=model_template,
#     target_dir=target_dir,
#     device=device,
# )
#
# # Dataset Info
# dataset_type = loaded_dataset['dataset_type']
# dataset_quantities = loaded_dataset['dataset_quantities']
# print(f"Dataset type: {dataset_type}")
# print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")
#
# print("\nTensor shapes:")
# for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
#     shape = getattr(loaded_dataset[key], "shape", None)
#     print(f"  {key}: {shape if shape is not None else 'None'}")
#
# # Reconstruct trained_model dicts safely.
# # If the loss or accuracy or additional metrics happen to be
# # tensors, they get safely converted to lists.
# all_models = [
#     {
#         "model": model,
#         **{
#             k: tensor_to_list(model_data[k], key_path=k)
#             for k in ["train_loss", "train_accs", "test_loss", "test_accs", "additional_data", "dataset_type"]
#         },
#     }
#     for model, model_data in zip(loaded_models, loaded_model_data)
# ]
# print(f"Reconstructed {len(all_models)} trained models")
# ------------------
#
# ----- stdout -----
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_additional_0.pt
#   - model_additional_1940.pt
#   - model_additional_19940.pt
#   - model_additional_540.pt
#   - model_additional_5940.pt
#   - model_additional_59940.pt
# ------------------
#
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 5
#       1 # ====================================
#       2 # Load Trained Models and Dataset
#       3 # ====================================
#       4 target_dir = "models_and_data"  # relative path
# ----> 5 loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#       6     model_template=model_template,
#       7     target_dir=target_dir,
#       8     device=device,
#       9 )
#      11 # Dataset Info
#      12 dataset_type = loaded_dataset['dataset_type']
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:382, in load_models_and_data(model_template, target_dir, device)
#     379     model = copy.deepcopy(model_template)
#     381 # Load the model - now returns model_data instead of just additional_data
# --> 382 model_loaded, model_data = load_model(
#     383     model,
#     384     folder=str(target_dir),
#     385     filename=os.path.basename(model_file),
#     386     device=device
#     387 )
#     389 # Store the results
#     390 loaded_models.append(model_loaded)
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:319, in load_model(model, folder, filename, device)
#     316 load_path = os.path.join(folder, filename)
#     317 model_dict = torch.load(load_path, map_location=device)
# --> 319 model.load_state_dict(model_dict["state_dict"])
#     320 model.to(device)
#     322 # Return all metadata in a dictionary
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:2581, in Module.load_state_dict(self, state_dict, strict, assign)
#    2573         error_msgs.insert(
#    2574             0,
#    2575             "Missing key(s) in state_dict: {}. ".format(
#    2576                 ", ".join(f'"{k}"' for k in missing_keys)
#    2577             ),
#    2578         )
#    2580 if len(error_msgs) > 0:
# -> 2581     raise RuntimeError(
#    2582         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2583             self.__class__.__name__, "\n\t".join(error_msgs)
#    2584         )
#    2585     )
#    2586 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for MNIST_MLP:
# 	Unexpected key(s) in state_dict: "model.6.weight", "model.6.bias".
# 	size mismatch for model.2.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([128, 256]).
# 	size mismatch for model.2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for model.4.weight: copying a param with shape torch.Size([128, 256]) from checkpoint, the shape in current model is torch.Size([10, 128]).
# 	size mismatch for model.4.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([10]). (took 6.83s)
# 🔹 Running model_8_data_18\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_8_data_18/Volume Estimation Pipeline.ipynb (took 57.43s)
# 🔹 Running model_9_data_19\Volume Cutoff.ipynb...
# ❌ ERROR: model_9_data_19/Volume Cutoff.ipynb - [NbConvertApp] Converting notebook model_9_data_19\Volume Cutoff.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # ====================================
# # Load Trained Models and Dataset
# # ====================================
# target_dir = "models_and_data"  # relative path
# loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#     model_template=model_template,
#     target_dir=target_dir,
#     device=device,
# )
#
# # Dataset Info
# dataset_type = loaded_dataset['dataset_type']
# dataset_quantities = loaded_dataset['dataset_quantities']
# print(f"Dataset type: {dataset_type}")
# print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")
#
# print("\nTensor shapes:")
# for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
#     shape = getattr(loaded_dataset[key], "shape", None)
#     print(f"  {key}: {shape if shape is not None else 'None'}")
#
# # Reconstruct trained_model dicts safely.
# # If the loss or accuracy or additional metrics happen to be
# # tensors, they get safely converted to lists.
# all_models = [
#     {
#         "model": model,
#         **{
#             k: tensor_to_list(model_data[k], key_path=k)
#             for k in ["train_loss", "train_accs", "test_loss", "test_accs", "additional_data", "dataset_type"]
#         },
#     }
#     for model, model_data in zip(loaded_models, loaded_model_data)
# ]
# print(f"Reconstructed {len(all_models)} trained models")
# ------------------
#
# ----- stdout -----
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_additional_0.pt
#   - model_additional_1940.pt
#   - model_additional_19940.pt
#   - model_additional_540.pt
#   - model_additional_5940.pt
#   - model_additional_59940.pt
# ------------------
#
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 5
#       1 # ====================================
#       2 # Load Trained Models and Dataset
#       3 # ====================================
#       4 target_dir = "models_and_data"  # relative path
# ----> 5 loaded_models, loaded_model_data, loaded_dataset = load_models_and_data(
#       6     model_template=model_template,
#       7     target_dir=target_dir,
#       8     device=device,
#       9 )
#      11 # Dataset Info
#      12 dataset_type = loaded_dataset['dataset_type']
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:382, in load_models_and_data(model_template, target_dir, device)
#     379     model = copy.deepcopy(model_template)
#     381 # Load the model - now returns model_data instead of just additional_data
# --> 382 model_loaded, model_data = load_model(
#     383     model,
#     384     folder=str(target_dir),
#     385     filename=os.path.basename(model_file),
#     386     device=device
#     387 )
#     389 # Store the results
#     390 loaded_models.append(model_loaded)
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\dataset_funcs.py:319, in load_model(model, folder, filename, device)
#     316 load_path = os.path.join(folder, filename)
#     317 model_dict = torch.load(load_path, map_location=device)
# --> 319 model.load_state_dict(model_dict["state_dict"])
#     320 model.to(device)
#     322 # Return all metadata in a dictionary
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:2581, in Module.load_state_dict(self, state_dict, strict, assign)
#    2573         error_msgs.insert(
#    2574             0,
#    2575             "Missing key(s) in state_dict: {}. ".format(
#    2576                 ", ".join(f'"{k}"' for k in missing_keys)
#    2577             ),
#    2578         )
#    2580 if len(error_msgs) > 0:
# -> 2581     raise RuntimeError(
#    2582         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2583             self.__class__.__name__, "\n\t".join(error_msgs)
#    2584         )
#    2585     )
#    2586 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for MNIST_MLP:
# 	Unexpected key(s) in state_dict: "model.6.weight", "model.6.bias".
# 	size mismatch for model.2.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([128, 256]).
# 	size mismatch for model.2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for model.4.weight: copying a param with shape torch.Size([128, 256]) from checkpoint, the shape in current model is torch.Size([10, 128]).
# 	size mismatch for model.4.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([10]). (took 6.53s)
# 🔹 Running model_9_data_19\Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_9_data_19/Volume Estimation Pipeline.ipynb (took 58.37s)
# ✅ All done!
