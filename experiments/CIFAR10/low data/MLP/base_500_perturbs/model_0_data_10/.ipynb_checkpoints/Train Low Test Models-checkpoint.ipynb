# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 10            
model_seed = 0           

# --- Training configuration ---
epochs = 400               

# --- Dataset configuration ---
base_data_size = 50      
dataset_type = "data"   
dataset_quantities = [0, 500-50, 2000 - 50, 5000 - 50, 20000 - 50, 50000 - 50]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the CIFAR-10 model module name
import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device=device
)

# CIFAR-10 MLP initialization parameters
# Since input dimension is higher, hidden layers can be larger
hidden_dims = [512, 256]  # adjust as desired

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = min(len(x_train), 5000)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=50,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/400: Train Loss 2.3198 | Test Loss 2.2466 | accs Train 0.0800 Test 0.1665
# Epoch 50/400: Train Loss 0.0000 | Test Loss 10.2193 | accs Train 1.0000 Test 0.2030
# Epoch 100/400: Train Loss 0.0000 | Test Loss 10.3733 | accs Train 1.0000 Test 0.2024
# Epoch 150/400: Train Loss 0.0000 | Test Loss 10.3521 | accs Train 1.0000 Test 0.2026
# Epoch 200/400: Train Loss 0.0000 | Test Loss 10.3310 | accs Train 1.0000 Test 0.2024
# Epoch 250/400: Train Loss 0.0000 | Test Loss 10.3112 | accs Train 1.0000 Test 0.2019
# Epoch 300/400: Train Loss 0.0000 | Test Loss 10.2925 | accs Train 1.0000 Test 0.2020
# Epoch 350/400: Train Loss 0.0000 | Test Loss 10.2748 | accs Train 1.0000 Test 0.2021
# Epoch 400/400: Train Loss 0.0000 | Test Loss 10.2581 | accs Train 1.0000 Test 0.2019
# Completed training with 0 additional samples of data
# Epoch 1/400: Train Loss 2.3086 | Test Loss 2.1600 | accs Train 0.0900 Test 0.1993
# Epoch 50/400: Train Loss 0.0002 | Test Loss 5.4656 | accs Train 1.0000 Test 0.3118
# Epoch 100/400: Train Loss 0.0001 | Test Loss 5.7012 | accs Train 1.0000 Test 0.3140
# Epoch 150/400: Train Loss 0.0001 | Test Loss 5.7575 | accs Train 1.0000 Test 0.3149
# Epoch 200/400: Train Loss 0.0001 | Test Loss 5.8095 | accs Train 1.0000 Test 0.3143
# Epoch 250/400: Train Loss 0.0000 | Test Loss 5.8586 | accs Train 1.0000 Test 0.3143
# Epoch 300/400: Train Loss 0.0000 | Test Loss 5.9043 | accs Train 1.0000 Test 0.3147
# Epoch 350/400: Train Loss 0.0000 | Test Loss 5.9471 | accs Train 1.0000 Test 0.3143
# Epoch 400/400: Train Loss 0.0000 | Test Loss 5.9871 | accs Train 1.0000 Test 0.3147
# Completed training with 450 additional samples of data
# Epoch 1/400: Train Loss 2.3107 | Test Loss 2.1111 | accs Train 0.0785 Test 0.2577
# Epoch 50/400: Train Loss 0.0162 | Test Loss 3.3370 | accs Train 1.0000 Test 0.3767
# Epoch 100/400: Train Loss 0.0016 | Test Loss 4.1995 | accs Train 1.0000 Test 0.3786
# Epoch 150/400: Train Loss 0.0009 | Test Loss 4.4126 | accs Train 1.0000 Test 0.3781
# Epoch 200/400: Train Loss 0.0006 | Test Loss 4.5733 | accs Train 1.0000 Test 0.3770
# Epoch 250/400: Train Loss 0.0004 | Test Loss 4.7029 | accs Train 1.0000 Test 0.3777
# Epoch 300/400: Train Loss 0.0003 | Test Loss 4.8139 | accs Train 1.0000 Test 0.3784
# Epoch 350/400: Train Loss 0.0002 | Test Loss 4.9100 | accs Train 1.0000 Test 0.3785
# Epoch 400/400: Train Loss 0.0002 | Test Loss 4.9947 | accs Train 1.0000 Test 0.3783
# Completed training with 1950 additional samples of data
# Epoch 1/400: Train Loss 2.3105 | Test Loss 2.1068 | accs Train 0.0858 Test 0.2546
# Epoch 50/400: Train Loss 0.3737 | Test Loss 1.9760 | accs Train 0.9224 Test 0.4175
# Epoch 100/400: Train Loss 0.0218 | Test Loss 2.9161 | accs Train 1.0000 Test 0.4204
# Epoch 150/400: Train Loss 0.0062 | Test Loss 3.3716 | accs Train 1.0000 Test 0.4190
# Epoch 200/400: Train Loss 0.0032 | Test Loss 3.6209 | accs Train 1.0000 Test 0.4172
# Epoch 250/400: Train Loss 0.0020 | Test Loss 3.8035 | accs Train 1.0000 Test 0.4161
# Epoch 300/400: Train Loss 0.0014 | Test Loss 3.9484 | accs Train 1.0000 Test 0.4151
# Epoch 350/400: Train Loss 0.0010 | Test Loss 4.0679 | accs Train 1.0000 Test 0.4147
# Epoch 400/400: Train Loss 0.0008 | Test Loss 4.1704 | accs Train 1.0000 Test 0.4137
# Completed training with 4950 additional samples of data
# Epoch 1/400: Train Loss 2.1225 | Test Loss 1.9238 | accs Train 0.2260 Test 0.3141
# Epoch 50/400: Train Loss 0.2364 | Test Loss 1.9057 | accs Train 0.9572 Test 0.4915
# Epoch 100/400: Train Loss 0.0194 | Test Loss 2.7922 | accs Train 0.9999 Test 0.4864
# Epoch 150/400: Train Loss 0.0059 | Test Loss 3.2455 | accs Train 1.0000 Test 0.4860
# Epoch 200/400: Train Loss 0.0029 | Test Loss 3.5315 | accs Train 1.0000 Test 0.4832
# Epoch 250/400: Train Loss 0.0017 | Test Loss 3.7409 | accs Train 1.0000 Test 0.4839
# Epoch 300/400: Train Loss 0.0011 | Test Loss 3.9075 | accs Train 1.0000 Test 0.4836
# Epoch 350/400: Train Loss 0.0008 | Test Loss 4.0484 | accs Train 1.0000 Test 0.4840
# Epoch 400/400: Train Loss 0.0006 | Test Loss 4.1716 | accs Train 1.0000 Test 0.4834
# Completed training with 19950 additional samples of data
# Epoch 1/400: Train Loss 1.9328 | Test Loss 1.7116 | accs Train 0.3084 Test 0.4032
# Epoch 50/400: Train Loss 0.1753 | Test Loss 1.9393 | accs Train 0.9632 Test 0.5332
# Epoch 100/400: Train Loss 0.0156 | Test Loss 2.8284 | accs Train 0.9999 Test 0.5327
# Epoch 150/400: Train Loss 0.0044 | Test Loss 3.3172 | accs Train 1.0000 Test 0.5356
# Epoch 200/400: Train Loss 0.0021 | Test Loss 3.6364 | accs Train 1.0000 Test 0.5348
# Epoch 250/400: Train Loss 0.0012 | Test Loss 3.8822 | accs Train 1.0000 Test 0.5342
# Epoch 300/400: Train Loss 0.0007 | Test Loss 4.0810 | accs Train 1.0000 Test 0.5337
# Epoch 350/400: Train Loss 0.0005 | Test Loss 4.2584 | accs Train 1.0000 Test 0.5331
# Epoch 400/400: Train Loss 0.0003 | Test Loss 4.4189 | accs Train 1.0000 Test 0.5331
# Completed training with 49950 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 10.2580 | accs: 0.2019
#  450 samples | Test Loss: 5.9871 | accs: 0.3147
# 1950 samples | Test Loss: 4.9947 | accs: 0.3783
# 4950 samples | Test Loss: 4.1704 | accs: 0.4137
# 19950 samples | Test Loss: 4.1716 | accs: 0.4834
# 49950 samples | Test Loss: 4.4189 | accs: 0.5331
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  450 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1950 | Train Loss: 0.0002 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0009 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0002 | accs: 1.0000
#
# Dataset type: data, additional samples: 450
#  Model    0 | Train Loss: 9.4782 | accs: 0.2920
#  Model  450 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1950 | Train Loss: 0.0002 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0008 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0003 | accs: 1.0000
#
# Dataset type: data, additional samples: 1950
#  Model    0 | Train Loss: 10.1967 | accs: 0.2250
#  Model  450 | Train Loss: 4.6214 | accs: 0.4850
#  Model 1950 | Train Loss: 0.0002 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0008 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0003 | accs: 1.0000
#
# Dataset type: data, additional samples: 4950
#  Model    0 | Train Loss: 10.4450 | accs: 0.2180
#  Model  450 | Train Loss: 5.4794 | accs: 0.3780
#  Model 1950 | Train Loss: 3.0275 | accs: 0.6268
#  Model 4950 | Train Loss: 0.0008 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0003 | accs: 1.0000
#
# Dataset type: data, additional samples: 19950
#  Model    0 | Train Loss: 10.4989 | accs: 0.2045
#  Model  450 | Train Loss: 5.8879 | accs: 0.3286
#  Model 1950 | Train Loss: 4.5556 | accs: 0.4362
#  Model 4950 | Train Loss: 3.1623 | accs: 0.5610
#  Model 19950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0003 | accs: 1.0000
#
# Dataset type: data, additional samples: 49950
#  Model    0 | Train Loss: 10.3806 | accs: 0.2069
#  Model  450 | Train Loss: 5.9538 | accs: 0.3180
#  Model 1950 | Train Loss: 4.8284 | accs: 0.3992
#  Model 4950 | Train Loss: 3.7858 | accs: 0.4737
#  Model 19950 | Train Loss: 2.5195 | accs: 0.6894
#  Model 49950 | Train Loss: 0.0003 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_450.pt
# Saved model: models_and_data/model_additional_450.pt
# ✅ Model saved to models_and_data\model_additional_1950.pt
# Saved model: models_and_data/model_additional_1950.pt
# ✅ Model saved to models_and_data\model_additional_4950.pt
# Saved model: models_and_data/model_additional_4950.pt
# ✅ Model saved to models_and_data\model_additional_19950.pt
# Saved model: models_and_data/model_additional_19950.pt
# ✅ Model saved to models_and_data\model_additional_49950.pt
# Saved model: models_and_data/model_additional_49950.pt
