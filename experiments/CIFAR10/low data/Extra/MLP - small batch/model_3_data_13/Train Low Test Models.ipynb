# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 13            
model_seed = 3           

# --- Training configuration ---
epochs = 200            

# --- Dataset configuration ---
base_data_size = 50      
dataset_type = "data"   
dataset_quantities = [0, 500-50, 2000 - 50, 5000 - 50, 20000 - 50, 50000 - 50]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the CIFAR-10 model module name
from minima_volume.models import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device=device
)

# CIFAR-10 MLP initialization parameters
# Since input dimension is higher, hidden layers can be larger
hidden_dims = [512, 256]  # adjust as desired

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = min(len(x_train), 1024)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=50,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/200: Train Loss 2.3202 | Test Loss 2.2441 | accs Train 0.0400 Test 0.1806
# Epoch 50/200: Train Loss 0.0000 | Test Loss 9.4616 | accs Train 1.0000 Test 0.2217
# Epoch 100/200: Train Loss 0.0000 | Test Loss 9.5928 | accs Train 1.0000 Test 0.2225
# Epoch 150/200: Train Loss 0.0000 | Test Loss 9.5845 | accs Train 1.0000 Test 0.2222
# Epoch 200/200: Train Loss 0.0000 | Test Loss 9.5746 | accs Train 1.0000 Test 0.2223
# Completed training with 0 additional samples of data
# Epoch 1/200: Train Loss 2.3162 | Test Loss 2.1571 | accs Train 0.0880 Test 0.2160
# Epoch 50/200: Train Loss 0.0007 | Test Loss 5.0144 | accs Train 1.0000 Test 0.3076
# Epoch 100/200: Train Loss 0.0002 | Test Loss 5.3083 | accs Train 1.0000 Test 0.3102
# Epoch 150/200: Train Loss 0.0002 | Test Loss 5.3877 | accs Train 1.0000 Test 0.3109
# Epoch 200/200: Train Loss 0.0001 | Test Loss 5.4598 | accs Train 1.0000 Test 0.3122
# Completed training with 450 additional samples of data
# Epoch 1/200: Train Loss 2.2572 | Test Loss 2.1054 | accs Train 0.1515 Test 0.2414
# Epoch 50/200: Train Loss 0.0095 | Test Loss 3.4462 | accs Train 1.0000 Test 0.3755
# Epoch 100/200: Train Loss 0.0021 | Test Loss 4.0004 | accs Train 1.0000 Test 0.3750
# Epoch 150/200: Train Loss 0.0009 | Test Loss 4.3152 | accs Train 1.0000 Test 0.3739
# Epoch 200/200: Train Loss 0.0005 | Test Loss 4.5504 | accs Train 1.0000 Test 0.3731
# Completed training with 1950 additional samples of data
# Epoch 1/200: Train Loss 2.1270 | Test Loss 1.9516 | accs Train 0.2224 Test 0.2994
# Epoch 50/200: Train Loss 0.0081 | Test Loss 3.2399 | accs Train 1.0000 Test 0.4263
# Epoch 100/200: Train Loss 0.0017 | Test Loss 3.8358 | accs Train 1.0000 Test 0.4230
# Epoch 150/200: Train Loss 0.0007 | Test Loss 4.1590 | accs Train 1.0000 Test 0.4217
# Epoch 200/200: Train Loss 0.0004 | Test Loss 4.3822 | accs Train 1.0000 Test 0.4205
# Completed training with 4950 additional samples of data
# Epoch 1/200: Train Loss 1.8666 | Test Loss 1.6803 | accs Train 0.3361 Test 0.4098
# Epoch 50/200: Train Loss 0.0048 | Test Loss 3.2658 | accs Train 0.9999 Test 0.4973
# Epoch 100/200: Train Loss 0.0009 | Test Loss 3.8504 | accs Train 1.0000 Test 0.4961
# Epoch 150/200: Train Loss 0.0003 | Test Loss 4.2084 | accs Train 1.0000 Test 0.4955
# Epoch 200/200: Train Loss 0.0002 | Test Loss 4.4922 | accs Train 1.0000 Test 0.4949
# Completed training with 19950 additional samples of data
# Epoch 1/200: Train Loss 1.7117 | Test Loss 1.5358 | accs Train 0.3928 Test 0.4588
# Epoch 50/200: Train Loss 0.0241 | Test Loss 3.4491 | accs Train 0.9941 Test 0.5419
# Epoch 100/200: Train Loss 0.0004 | Test Loss 3.9288 | accs Train 1.0000 Test 0.5455
# Epoch 150/200: Train Loss 0.0001 | Test Loss 4.3119 | accs Train 1.0000 Test 0.5445
# Epoch 200/200: Train Loss 0.1005 | Test Loss 3.2063 | accs Train 0.9717 Test 0.5124
# Completed training with 49950 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 9.5746 | accs: 0.2223
#  450 samples | Test Loss: 5.4598 | accs: 0.3122
# 1950 samples | Test Loss: 4.5504 | accs: 0.3731
# 4950 samples | Test Loss: 4.3822 | accs: 0.4205
# 19950 samples | Test Loss: 4.4922 | accs: 0.4949
# 49950 samples | Test Loss: 3.2063 | accs: 0.5124
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  450 | Train Loss: 0.0001 | accs: 1.0000
#  Model 1950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0004 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0002 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0586 | accs: 1.0000
#
# Dataset type: data, additional samples: 450
#  Model    0 | Train Loss: 9.2501 | accs: 0.3000
#  Model  450 | Train Loss: 0.0001 | accs: 1.0000
#  Model 1950 | Train Loss: 0.0005 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0004 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0002 | accs: 1.0000
#  Model 49950 | Train Loss: 0.1076 | accs: 0.9780
#
# Dataset type: data, additional samples: 1950
#  Model    0 | Train Loss: 9.9070 | accs: 0.2310
#  Model  450 | Train Loss: 4.3423 | accs: 0.4645
#  Model 1950 | Train Loss: 0.0005 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0004 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0002 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0919 | accs: 0.9750
#
# Dataset type: data, additional samples: 4950
#  Model    0 | Train Loss: 9.6924 | accs: 0.2234
#  Model  450 | Train Loss: 4.9863 | accs: 0.3718
#  Model 1950 | Train Loss: 2.6922 | accs: 0.6270
#  Model 4950 | Train Loss: 0.0004 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0002 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0968 | accs: 0.9730
#
# Dataset type: data, additional samples: 19950
#  Model    0 | Train Loss: 9.6579 | accs: 0.2242
#  Model  450 | Train Loss: 5.3542 | accs: 0.3220
#  Model 1950 | Train Loss: 4.0467 | accs: 0.4346
#  Model 4950 | Train Loss: 3.2991 | accs: 0.5657
#  Model 19950 | Train Loss: 0.0002 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0950 | accs: 0.9738
#
# Dataset type: data, additional samples: 49950
#  Model    0 | Train Loss: 9.7099 | accs: 0.2225
#  Model  450 | Train Loss: 5.4659 | accs: 0.3109
#  Model 1950 | Train Loss: 4.3191 | accs: 0.3998
#  Model 4950 | Train Loss: 3.9825 | accs: 0.4797
#  Model 19950 | Train Loss: 2.7079 | accs: 0.6976
#  Model 49950 | Train Loss: 0.0956 | accs: 0.9736

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_450.pt
# Saved model: models_and_data/model_additional_450.pt
# ✅ Model saved to models_and_data\model_additional_1950.pt
# Saved model: models_and_data/model_additional_1950.pt
# ✅ Model saved to models_and_data\model_additional_4950.pt
# Saved model: models_and_data/model_additional_4950.pt
# ✅ Model saved to models_and_data\model_additional_19950.pt
# Saved model: models_and_data/model_additional_19950.pt
# ✅ Model saved to models_and_data\model_additional_49950.pt
# Saved model: models_and_data/model_additional_49950.pt
