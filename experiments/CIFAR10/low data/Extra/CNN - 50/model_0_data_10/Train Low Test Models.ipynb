# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 10            
model_seed = 0           

# --- Training configuration ---
epochs = 200            

# --- Dataset configuration ---
base_data_size = 50      
dataset_type = "data"   
dataset_quantities = [0, 500-50, 2000 - 50, 5000 - 50, 20000 - 50, 50000 - 50]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the CIFAR-10 model module name
from minima_volume.models import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device=device
)

# CIFAR-10 CNN initialization parameters
conv_channels = [32, 64, 128]  # adjust as desired
fc_dims = [512, 256]  # adjust as desired

# Grab model - use CNN parameters instead of MLP hidden_dims
model_template = model_module.get_model(
    conv_channels=conv_channels,  # CNN-specific parameter
    fc_dims=fc_dims,              # CNN-specific parameter
    device=device, 
    seed=model_seed
)

# Grab loss and metrics (these should remain the same)
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = min(len(x_train), 1024)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=50,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/200: Train Loss 2.3084 | Test Loss 2.3032 | accs Train 0.1200 Test 0.1000
# Epoch 50/200: Train Loss 0.0013 | Test Loss 14.3215 | accs Train 1.0000 Test 0.2197
# Epoch 100/200: Train Loss 0.0001 | Test Loss 16.3359 | accs Train 1.0000 Test 0.2288
# Epoch 150/200: Train Loss 0.0001 | Test Loss 16.7184 | accs Train 1.0000 Test 0.2300
# Epoch 200/200: Train Loss 0.0000 | Test Loss 16.9823 | accs Train 1.0000 Test 0.2301
# Completed training with 0 additional samples of data
# Epoch 1/200: Train Loss 2.3006 | Test Loss 2.2955 | accs Train 0.1120 Test 0.1253
# Epoch 50/200: Train Loss 0.7777 | Test Loss 1.9840 | accs Train 0.7600 Test 0.3798
# Epoch 100/200: Train Loss 0.0190 | Test Loss 4.0831 | accs Train 1.0000 Test 0.3927
# Epoch 150/200: Train Loss 0.0023 | Test Loss 5.3204 | accs Train 1.0000 Test 0.3875
# Epoch 200/200: Train Loss 0.0011 | Test Loss 5.7403 | accs Train 1.0000 Test 0.3871
# Completed training with 450 additional samples of data
# Epoch 1/200: Train Loss 2.2988 | Test Loss 2.2686 | accs Train 0.1240 Test 0.1157
# Epoch 50/200: Train Loss 0.9255 | Test Loss 1.5655 | accs Train 0.6825 Test 0.4750
# Epoch 100/200: Train Loss 0.0811 | Test Loss 2.3611 | accs Train 0.9905 Test 0.5141
# Epoch 150/200: Train Loss 0.0049 | Test Loss 3.3449 | accs Train 1.0000 Test 0.5187
# Epoch 200/200: Train Loss 0.0019 | Test Loss 3.7228 | accs Train 1.0000 Test 0.5179
# Completed training with 1950 additional samples of data
# Epoch 1/200: Train Loss 2.2643 | Test Loss 2.1125 | accs Train 0.1482 Test 0.2122
# Epoch 50/200: Train Loss 0.4808 | Test Loss 1.3979 | accs Train 0.8464 Test 0.5813
# Epoch 100/200: Train Loss 0.0048 | Test Loss 2.7604 | accs Train 1.0000 Test 0.5881
# Epoch 150/200: Train Loss 0.0012 | Test Loss 3.2469 | accs Train 1.0000 Test 0.5857
# Epoch 200/200: Train Loss 0.0006 | Test Loss 3.5259 | accs Train 1.0000 Test 0.5841
# Completed training with 4950 additional samples of data
# Epoch 1/200: Train Loss 2.0675 | Test Loss 1.8894 | accs Train 0.2354 Test 0.3062
# Epoch 50/200: Train Loss 0.0049 | Test Loss 2.0754 | accs Train 1.0000 Test 0.6857
# Epoch 100/200: Train Loss 0.0004 | Test Loss 2.8677 | accs Train 1.0000 Test 0.6800
# Epoch 150/200: Train Loss 0.0001 | Test Loss 3.2650 | accs Train 1.0000 Test 0.6776
# Epoch 200/200: Train Loss 0.0001 | Test Loss 3.5493 | accs Train 1.0000 Test 0.6750
# Completed training with 19950 additional samples of data
# Epoch 1/200: Train Loss 1.8177 | Test Loss 1.5217 | accs Train 0.3330 Test 0.4420
# Epoch 50/200: Train Loss 0.0007 | Test Loss 2.0029 | accs Train 1.0000 Test 0.7516
# Epoch 100/200: Train Loss 0.0001 | Test Loss 2.5823 | accs Train 1.0000 Test 0.7518
# Epoch 150/200: Train Loss 0.0000 | Test Loss 3.0341 | accs Train 1.0000 Test 0.7482
# Epoch 200/200: Train Loss 0.0000 | Test Loss 3.4331 | accs Train 1.0000 Test 0.7461
# Completed training with 49950 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 16.9823 | accs: 0.2301
#  450 samples | Test Loss: 5.7403 | accs: 0.3871
# 1950 samples | Test Loss: 3.7228 | accs: 0.5179
# 4950 samples | Test Loss: 3.5259 | accs: 0.5841
# 19950 samples | Test Loss: 3.5493 | accs: 0.6750
# 49950 samples | Test Loss: 3.4331 | accs: 0.7461
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  450 | Train Loss: 0.0013 | accs: 1.0000
#  Model 1950 | Train Loss: 0.0017 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0004 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0001 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 450
#  Model    0 | Train Loss: 15.8840 | accs: 0.2820
#  Model  450 | Train Loss: 0.0011 | accs: 1.0000
#  Model 1950 | Train Loss: 0.0018 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0001 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 1950
#  Model    0 | Train Loss: 16.9481 | accs: 0.2370
#  Model  450 | Train Loss: 4.3082 | accs: 0.5310
#  Model 1950 | Train Loss: 0.0019 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0000 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 4950
#  Model    0 | Train Loss: 17.6130 | accs: 0.2220
#  Model  450 | Train Loss: 5.1501 | accs: 0.4424
#  Model 1950 | Train Loss: 2.2320 | accs: 0.7124
#  Model 4950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0000 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 19950
#  Model    0 | Train Loss: 17.4499 | accs: 0.2190
#  Model  450 | Train Loss: 5.5234 | accs: 0.3978
#  Model 1950 | Train Loss: 3.3569 | accs: 0.5636
#  Model 4950 | Train Loss: 2.6602 | accs: 0.6877
#  Model 19950 | Train Loss: 0.0000 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 49950
#  Model    0 | Train Loss: 17.2216 | accs: 0.2217
#  Model  450 | Train Loss: 5.6418 | accs: 0.3917
#  Model 1950 | Train Loss: 3.5824 | accs: 0.5356
#  Model 4950 | Train Loss: 3.1916 | accs: 0.6259
#  Model 19950 | Train Loss: 2.0240 | accs: 0.8110
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_450.pt
# Saved model: models_and_data/model_additional_450.pt
# ✅ Model saved to models_and_data\model_additional_1950.pt
# Saved model: models_and_data/model_additional_1950.pt
# ✅ Model saved to models_and_data\model_additional_4950.pt
# Saved model: models_and_data/model_additional_4950.pt
# ✅ Model saved to models_and_data\model_additional_19950.pt
# Saved model: models_and_data/model_additional_19950.pt
# ✅ Model saved to models_and_data\model_additional_49950.pt
# Saved model: models_and_data/model_additional_49950.pt
