# %%
import os
import subprocess
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock

# ---------- Configuration ----------
MAX_WORKERS = 1
EXCLUDE_PREFIXES = [
    '__pycache__', 
    '.ipynb_checkpoints', 
    'base', 
    'completed runs', 
    'to do', 
    'analysis'
]

# Lock for thread-safe printing
print_lock = Lock()

# ---------- Core Helpers ----------
def run_notebook(folder: str, notebook_name: str) -> str:
    """
    Execute a Jupyter notebook in place using nbconvert.
    Returns a status string with execution time.
    All printing inside this function is thread-safe.
    """
    notebook_path = os.path.join(folder, notebook_name)
    if not os.path.exists(notebook_path):
        with print_lock:
            print(f"SKIP: {notebook_name} not found in {folder}", flush=True)
        return f"SKIP: {notebook_name} not found in {folder}"

    with print_lock:
        print(f"🔹 Running {notebook_path}...", flush=True)

    start_time = time.time()
    try:
        subprocess.run(
            [
                'jupyter', 'nbconvert', '--to', 'notebook',
                '--execute', notebook_path, '--inplace',
                '--ExecutePreprocessor.timeout=-1'
            ],
            check=True,
            capture_output=True,
            text=True
        )
        elapsed = time.time() - start_time
        return f"✅ SUCCESS: {folder}/{notebook_name} (took {elapsed:.2f}s)"
    except subprocess.CalledProcessError as e:
        elapsed = time.time() - start_time
        stderr_clean = e.stderr.strip()
        return f"❌ ERROR: {folder}/{notebook_name} - {stderr_clean} (took {elapsed:.2f}s)"

def find_folders(base_dir: str = '.') -> list[str]:
    """Return a list of folders to process, excluding certain prefixes."""
    return [
        d for d in os.listdir(base_dir)
        if os.path.isdir(d) and not any(d.startswith(prefix) for prefix in EXCLUDE_PREFIXES)
    ]

def run_in_parallel(folders: list[str], notebook_names: list[str]):
    """Run one or more notebooks across all folders in parallel, with thread-safe printing."""
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [
            executor.submit(run_notebook, folder, nb)
            for folder in folders
            for nb in notebook_names
        ]

        for future in as_completed(futures):
            msg = future.result().strip()
            with print_lock:
                print(msg)
    with print_lock:
        print("✅ All done!")

# ---------- Specialized Variants ----------
def run_random_perturbs_parallel():
    """Run Random Perturbs.ipynb across all model_* folders."""
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders for Random Perturbs.")
    run_in_parallel(folders, ["Random Perturbs.ipynb"])

def run_volume_parallel():
    """Run all notebooks containing 'Volume Cutoff' or 'Volume Estimation' across folders."""
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders for Volume notebooks.")

    notebook_names = []
    if folders:
        for nb in os.listdir(folders[0]):
            if nb.endswith(".ipynb") and ("Volume Cutoff" in nb or "Volume Estimation" in nb):
                notebook_names.append(nb)

    if not notebook_names:
        with print_lock:
            print("⚠️ No Volume notebooks found in reference folder.")
        return

    with print_lock:
        print(f"Will run these notebooks: {notebook_names}")
    run_in_parallel(folders, notebook_names)

def run_nb_parallel():
    """Generic function for ad-hoc notebook runs (prompt user)."""
    notebook_name = input("Enter notebook name (without .ipynb): ").strip() + ".ipynb"
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders to process.")
    run_in_parallel(folders, [notebook_name])

run_random_perturbs_parallel()
# Out:
# Found 10 folders for Random Perturbs.
# 🔹 Running model_0_data_10\Random Perturbs.ipynb...
# ❌ ERROR: model_0_data_10/Random Perturbs.ipynb - [NbConvertApp] Converting notebook model_0_data_10\Random Perturbs.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # User specifies the CIFAR-10 model module name
# import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10
#
# # Generate dataset
# #x_base, y_base, x_test, y_test = model_module.get_dataset(
# #    device=device
# #)
#
# # CIFAR-10 MLP initialization parameters
# # Since input dimension is higher, hidden layers can be larger
# hidden_dims = [512, 256]  # adjust as desired
#
# # Grab model
# model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#
# # Grab loss and metrics
# loss_fn = model_module.get_loss_fn()
# other_metrics = model_module.get_additional_metrics()
# ------------------
#
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 hidden_dims = [512, 256]  # adjust as desired
#      13 # Grab model
# ---> 14 model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#      16 # Grab loss and metrics
#      17 loss_fn = model_module.get_loss_fn()
#
# NameError: name 'model_seed' is not defined (took 8.48s)
# 🔹 Running model_1_data_11\Random Perturbs.ipynb...
# ❌ ERROR: model_1_data_11/Random Perturbs.ipynb - [NbConvertApp] Converting notebook model_1_data_11\Random Perturbs.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # User specifies the CIFAR-10 model module name
# import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10
#
# # Generate dataset
# #x_base, y_base, x_test, y_test = model_module.get_dataset(
# #    device=device
# #)
#
# # CIFAR-10 MLP initialization parameters
# # Since input dimension is higher, hidden layers can be larger
# hidden_dims = [512, 256]  # adjust as desired
#
# # Grab model
# model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#
# # Grab loss and metrics
# loss_fn = model_module.get_loss_fn()
# other_metrics = model_module.get_additional_metrics()
# ------------------
#
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 hidden_dims = [512, 256]  # adjust as desired
#      13 # Grab model
# ---> 14 model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#      16 # Grab loss and metrics
#      17 loss_fn = model_module.get_loss_fn()
#
# NameError: name 'model_seed' is not defined (took 7.29s)
# 🔹 Running model_2_data_12\Random Perturbs.ipynb...
# ❌ ERROR: model_2_data_12/Random Perturbs.ipynb - [NbConvertApp] Converting notebook model_2_data_12\Random Perturbs.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # User specifies the CIFAR-10 model module name
# import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10
#
# # Generate dataset
# #x_base, y_base, x_test, y_test = model_module.get_dataset(
# #    device=device
# #)
#
# # CIFAR-10 MLP initialization parameters
# # Since input dimension is higher, hidden layers can be larger
# hidden_dims = [512, 256]  # adjust as desired
#
# # Grab model
# model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#
# # Grab loss and metrics
# loss_fn = model_module.get_loss_fn()
# other_metrics = model_module.get_additional_metrics()
# ------------------
#
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 hidden_dims = [512, 256]  # adjust as desired
#      13 # Grab model
# ---> 14 model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#      16 # Grab loss and metrics
#      17 loss_fn = model_module.get_loss_fn()
#
# NameError: name 'model_seed' is not defined (took 7.42s)
# 🔹 Running model_3_data_13\Random Perturbs.ipynb...
# ❌ ERROR: model_3_data_13/Random Perturbs.ipynb - [NbConvertApp] Converting notebook model_3_data_13\Random Perturbs.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # User specifies the CIFAR-10 model module name
# import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10
#
# # Generate dataset
# #x_base, y_base, x_test, y_test = model_module.get_dataset(
# #    device=device
# #)
#
# # CIFAR-10 MLP initialization parameters
# # Since input dimension is higher, hidden layers can be larger
# hidden_dims = [512, 256]  # adjust as desired
#
# # Grab model
# model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#
# # Grab loss and metrics
# loss_fn = model_module.get_loss_fn()
# other_metrics = model_module.get_additional_metrics()
# ------------------
#
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 hidden_dims = [512, 256]  # adjust as desired
#      13 # Grab model
# ---> 14 model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#      16 # Grab loss and metrics
#      17 loss_fn = model_module.get_loss_fn()
#
# NameError: name 'model_seed' is not defined (took 7.30s)
# 🔹 Running model_4_data_14\Random Perturbs.ipynb...
# 🔹 Running model_5_data_15\Random Perturbs.ipynb...
# ❌ ERROR: model_4_data_14/Random Perturbs.ipynb - [NbConvertApp] Converting notebook model_4_data_14\Random Perturbs.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # User specifies the CIFAR-10 model module name
# import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10
#
# # Generate dataset
# #x_base, y_base, x_test, y_test = model_module.get_dataset(
# #    device=device
# #)
#
# # CIFAR-10 MLP initialization parameters
# # Since input dimension is higher, hidden layers can be larger
# hidden_dims = [512, 256]  # adjust as desired
#
# # Grab model
# model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#
# # Grab loss and metrics
# loss_fn = model_module.get_loss_fn()
# other_metrics = model_module.get_additional_metrics()
# ------------------
#
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 hidden_dims = [512, 256]  # adjust as desired
#      13 # Grab model
# ---> 14 model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#      16 # Grab loss and metrics
#      17 loss_fn = model_module.get_loss_fn()
#
# NameError: name 'model_seed' is not defined (took 7.56s)
# ❌ ERROR: model_5_data_15/Random Perturbs.ipynb - [NbConvertApp] Converting notebook model_5_data_15\Random Perturbs.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # User specifies the CIFAR-10 model module name
# import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10
#
# # Generate dataset
# #x_base, y_base, x_test, y_test = model_module.get_dataset(
# #    device=device
# #)
#
# # CIFAR-10 MLP initialization parameters
# # Since input dimension is higher, hidden layers can be larger
# hidden_dims = [512, 256]  # adjust as desired
#
# # Grab model
# model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#
# # Grab loss and metrics
# loss_fn = model_module.get_loss_fn()
# other_metrics = model_module.get_additional_metrics()
# ------------------
#
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 hidden_dims = [512, 256]  # adjust as desired
#      13 # Grab model
# ---> 14 model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#      16 # Grab loss and metrics
#      17 loss_fn = model_module.get_loss_fn()
#
# NameError: name 'model_seed' is not defined (took 7.33s)
# 🔹 Running model_6_data_16\Random Perturbs.ipynb...
# ❌ ERROR: model_6_data_16/Random Perturbs.ipynb - [NbConvertApp] Converting notebook model_6_data_16\Random Perturbs.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # User specifies the CIFAR-10 model module name
# import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10
#
# # Generate dataset
# #x_base, y_base, x_test, y_test = model_module.get_dataset(
# #    device=device
# #)
#
# # CIFAR-10 MLP initialization parameters
# # Since input dimension is higher, hidden layers can be larger
# hidden_dims = [512, 256]  # adjust as desired
#
# # Grab model
# model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#
# # Grab loss and metrics
# loss_fn = model_module.get_loss_fn()
# other_metrics = model_module.get_additional_metrics()
# ------------------
#
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 hidden_dims = [512, 256]  # adjust as desired
#      13 # Grab model
# ---> 14 model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#      16 # Grab loss and metrics
#      17 loss_fn = model_module.get_loss_fn()
#
# NameError: name 'model_seed' is not defined (took 7.36s)
# 🔹 Running model_7_data_17\Random Perturbs.ipynb...
# ❌ ERROR: model_7_data_17/Random Perturbs.ipynb - [NbConvertApp] Converting notebook model_7_data_17\Random Perturbs.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # User specifies the CIFAR-10 model module name
# import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10
#
# # Generate dataset
# #x_base, y_base, x_test, y_test = model_module.get_dataset(
# #    device=device
# #)
#
# # CIFAR-10 MLP initialization parameters
# # Since input dimension is higher, hidden layers can be larger
# hidden_dims = [512, 256]  # adjust as desired
#
# # Grab model
# model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#
# # Grab loss and metrics
# loss_fn = model_module.get_loss_fn()
# other_metrics = model_module.get_additional_metrics()
# ------------------
#
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 hidden_dims = [512, 256]  # adjust as desired
#      13 # Grab model
# ---> 14 model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#      16 # Grab loss and metrics
#      17 loss_fn = model_module.get_loss_fn()
#
# NameError: name 'model_seed' is not defined (took 7.06s)
# 🔹 Running model_8_data_18\Random Perturbs.ipynb...
# ❌ ERROR: model_8_data_18/Random Perturbs.ipynb - [NbConvertApp] Converting notebook model_8_data_18\Random Perturbs.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # User specifies the CIFAR-10 model module name
# import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10
#
# # Generate dataset
# #x_base, y_base, x_test, y_test = model_module.get_dataset(
# #    device=device
# #)
#
# # CIFAR-10 MLP initialization parameters
# # Since input dimension is higher, hidden layers can be larger
# hidden_dims = [512, 256]  # adjust as desired
#
# # Grab model
# model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#
# # Grab loss and metrics
# loss_fn = model_module.get_loss_fn()
# other_metrics = model_module.get_additional_metrics()
# ------------------
#
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 hidden_dims = [512, 256]  # adjust as desired
#      13 # Grab model
# ---> 14 model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#      16 # Grab loss and metrics
#      17 loss_fn = model_module.get_loss_fn()
#
# NameError: name 'model_seed' is not defined (took 6.89s)
# 🔹 Running model_9_data_19\Random Perturbs.ipynb...
# ❌ ERROR: model_9_data_19/Random Perturbs.ipynb - [NbConvertApp] Converting notebook model_9_data_19\Random Perturbs.ipynb to notebook
# L:\Programming\diffusion-env\Lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "L:\Programming\diffusion-env\Scripts\jupyter-nbconvert.EXE\__main__.py", line 7, in <module>
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "L:\Programming\diffusion-env\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\exporters\exporter.py", line 353, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\base.py", line 48, in __call__
#     return self.preprocess(nb, resources)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 103, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbconvert\preprocessors\execute.py", line 124, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\jupyter_core\utils\__init__.py", line 165, in wrapped
#     return loop.run_until_complete(inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 1062, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "L:\Programming\diffusion-env\Lib\site-packages\nbclient\client.py", line 918, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# # User specifies the CIFAR-10 model module name
# import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10
#
# # Generate dataset
# #x_base, y_base, x_test, y_test = model_module.get_dataset(
# #    device=device
# #)
#
# # CIFAR-10 MLP initialization parameters
# # Since input dimension is higher, hidden layers can be larger
# hidden_dims = [512, 256]  # adjust as desired
#
# # Grab model
# model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#
# # Grab loss and metrics
# loss_fn = model_module.get_loss_fn()
# other_metrics = model_module.get_additional_metrics()
# ------------------
#
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 hidden_dims = [512, 256]  # adjust as desired
#      13 # Grab model
# ---> 14 model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)
#      16 # Grab loss and metrics
#      17 loss_fn = model_module.get_loss_fn()
#
# NameError: name 'model_seed' is not defined (took 7.19s)
# ✅ All done!
