# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 14            
model_seed = 4           

# --- Training configuration ---
epochs = 2000            

# --- Dataset configuration ---
base_data_size = 5000
dataset_type = "poison"   
dataset_quantities = [0, 100, 500, 1000, 2000]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the CIFAR-10 model module name
from minima_volume.models import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device=device
)

# CIFAR-10 MLP initialization parameters
# Since input dimension is higher, hidden layers can be larger
hidden_dims = [512, 256]  # adjust as desired

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/2000: Train Loss 2.3002 | Test Loss 2.1349 | accs Train 0.1192 Test 0.2506
# Epoch 100/2000: Train Loss 0.0189 | Test Loss 3.1100 | accs Train 1.0000 Test 0.4126
# Epoch 200/2000: Train Loss 0.0029 | Test Loss 3.8146 | accs Train 1.0000 Test 0.4116
# Epoch 300/2000: Train Loss 0.0012 | Test Loss 4.1522 | accs Train 1.0000 Test 0.4103
# Epoch 400/2000: Train Loss 0.0007 | Test Loss 4.3816 | accs Train 1.0000 Test 0.4099
# Epoch 500/2000: Train Loss 0.0004 | Test Loss 4.5598 | accs Train 1.0000 Test 0.4094
# Epoch 600/2000: Train Loss 0.0003 | Test Loss 4.7046 | accs Train 1.0000 Test 0.4088
# Epoch 700/2000: Train Loss 0.0002 | Test Loss 4.8272 | accs Train 1.0000 Test 0.4098
# Epoch 800/2000: Train Loss 0.0002 | Test Loss 4.9329 | accs Train 1.0000 Test 0.4095
# Epoch 900/2000: Train Loss 0.0001 | Test Loss 5.0262 | accs Train 1.0000 Test 0.4100
# Epoch 1000/2000: Train Loss 0.0001 | Test Loss 5.1096 | accs Train 1.0000 Test 0.4096
# Epoch 1100/2000: Train Loss 0.0001 | Test Loss 5.1854 | accs Train 1.0000 Test 0.4100
# Epoch 1200/2000: Train Loss 0.0001 | Test Loss 5.2547 | accs Train 1.0000 Test 0.4104
# Epoch 1300/2000: Train Loss 0.0001 | Test Loss 5.3194 | accs Train 1.0000 Test 0.4107
# Epoch 1400/2000: Train Loss 0.0001 | Test Loss 5.3794 | accs Train 1.0000 Test 0.4107
# Epoch 1500/2000: Train Loss 0.0001 | Test Loss 5.4360 | accs Train 1.0000 Test 0.4109
# Epoch 1600/2000: Train Loss 0.0000 | Test Loss 5.4882 | accs Train 1.0000 Test 0.4109
# Epoch 1700/2000: Train Loss 0.0000 | Test Loss 5.5376 | accs Train 1.0000 Test 0.4111
# Epoch 1800/2000: Train Loss 0.0000 | Test Loss 5.5844 | accs Train 1.0000 Test 0.4106
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 5.6293 | accs Train 1.0000 Test 0.4106
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 5.6723 | accs Train 1.0000 Test 0.4110
# Completed training with 0 additional samples of poison
# Epoch 1/2000: Train Loss 2.3004 | Test Loss 2.1340 | accs Train 0.1194 Test 0.2522
# Epoch 100/2000: Train Loss 0.0275 | Test Loss 2.9378 | accs Train 1.0000 Test 0.4144
# Epoch 200/2000: Train Loss 0.0039 | Test Loss 3.6573 | accs Train 1.0000 Test 0.4073
# Epoch 300/2000: Train Loss 0.0016 | Test Loss 3.9897 | accs Train 1.0000 Test 0.4076
# Epoch 400/2000: Train Loss 0.0009 | Test Loss 4.2353 | accs Train 1.0000 Test 0.4069
# Epoch 500/2000: Train Loss 0.0006 | Test Loss 4.4290 | accs Train 1.0000 Test 0.4070
# Epoch 600/2000: Train Loss 0.0004 | Test Loss 4.5923 | accs Train 1.0000 Test 0.4072
# Epoch 700/2000: Train Loss 0.0003 | Test Loss 4.7323 | accs Train 1.0000 Test 0.4070
# Epoch 800/2000: Train Loss 0.0002 | Test Loss 4.8525 | accs Train 1.0000 Test 0.4068
# Epoch 900/2000: Train Loss 0.0002 | Test Loss 4.9586 | accs Train 1.0000 Test 0.4070
# Epoch 1000/2000: Train Loss 0.0001 | Test Loss 5.0550 | accs Train 1.0000 Test 0.4057
# Epoch 1100/2000: Train Loss 0.0001 | Test Loss 5.1423 | accs Train 1.0000 Test 0.4054
# Epoch 1200/2000: Train Loss 0.0001 | Test Loss 5.2227 | accs Train 1.0000 Test 0.4041
# Epoch 1300/2000: Train Loss 0.0001 | Test Loss 5.2960 | accs Train 1.0000 Test 0.4042
# Epoch 1400/2000: Train Loss 0.0001 | Test Loss 5.3642 | accs Train 1.0000 Test 0.4042
# Epoch 1500/2000: Train Loss 0.0001 | Test Loss 5.4280 | accs Train 1.0000 Test 0.4043
# Epoch 1600/2000: Train Loss 0.0000 | Test Loss 5.4881 | accs Train 1.0000 Test 0.4045
# Epoch 1700/2000: Train Loss 0.0000 | Test Loss 5.5446 | accs Train 1.0000 Test 0.4048
# Epoch 1800/2000: Train Loss 0.0000 | Test Loss 5.5990 | accs Train 1.0000 Test 0.4042
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 5.6508 | accs Train 1.0000 Test 0.4041
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 5.7002 | accs Train 1.0000 Test 0.4036
# Completed training with 100 additional samples of poison
# Epoch 1/2000: Train Loss 2.3005 | Test Loss 2.1356 | accs Train 0.1198 Test 0.2509
# Epoch 100/2000: Train Loss 0.0457 | Test Loss 2.8198 | accs Train 0.9989 Test 0.3888
# Epoch 200/2000: Train Loss 0.0048 | Test Loss 3.6601 | accs Train 1.0000 Test 0.3894
# Epoch 300/2000: Train Loss 0.0019 | Test Loss 4.0240 | accs Train 1.0000 Test 0.3886
# Epoch 400/2000: Train Loss 0.0010 | Test Loss 4.2651 | accs Train 1.0000 Test 0.3889
# Epoch 500/2000: Train Loss 0.0007 | Test Loss 4.4486 | accs Train 1.0000 Test 0.3889
# Epoch 600/2000: Train Loss 0.0005 | Test Loss 4.5969 | accs Train 1.0000 Test 0.3878
# Epoch 700/2000: Train Loss 0.0003 | Test Loss 4.7212 | accs Train 1.0000 Test 0.3876
# Epoch 800/2000: Train Loss 0.0003 | Test Loss 4.8299 | accs Train 1.0000 Test 0.3874
# Epoch 900/2000: Train Loss 0.0002 | Test Loss 4.9266 | accs Train 1.0000 Test 0.3880
# Epoch 1000/2000: Train Loss 0.0002 | Test Loss 5.0128 | accs Train 1.0000 Test 0.3875
# Epoch 1100/2000: Train Loss 0.0001 | Test Loss 5.0923 | accs Train 1.0000 Test 0.3878
# Epoch 1200/2000: Train Loss 0.0001 | Test Loss 5.1663 | accs Train 1.0000 Test 0.3877
# Epoch 1300/2000: Train Loss 0.0001 | Test Loss 5.2332 | accs Train 1.0000 Test 0.3872
# Epoch 1400/2000: Train Loss 0.0001 | Test Loss 5.2950 | accs Train 1.0000 Test 0.3870
# Epoch 1500/2000: Train Loss 0.0001 | Test Loss 5.3536 | accs Train 1.0000 Test 0.3872
# Epoch 1600/2000: Train Loss 0.0001 | Test Loss 5.4086 | accs Train 1.0000 Test 0.3876
# Epoch 1700/2000: Train Loss 0.0001 | Test Loss 5.4601 | accs Train 1.0000 Test 0.3876
# Epoch 1800/2000: Train Loss 0.0001 | Test Loss 5.5089 | accs Train 1.0000 Test 0.3873
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 5.5554 | accs Train 1.0000 Test 0.3874
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 5.5998 | accs Train 1.0000 Test 0.3874
# Completed training with 500 additional samples of poison
# Epoch 1/2000: Train Loss 2.3010 | Test Loss 2.1314 | accs Train 0.1200 Test 0.2535
# Epoch 100/2000: Train Loss 0.1039 | Test Loss 2.6461 | accs Train 0.9938 Test 0.3709
# Epoch 200/2000: Train Loss 0.0095 | Test Loss 3.5657 | accs Train 1.0000 Test 0.3673
# Epoch 300/2000: Train Loss 0.0035 | Test Loss 3.9764 | accs Train 1.0000 Test 0.3667
# Epoch 400/2000: Train Loss 0.0019 | Test Loss 4.2433 | accs Train 1.0000 Test 0.3660
# Epoch 500/2000: Train Loss 0.0012 | Test Loss 4.4452 | accs Train 1.0000 Test 0.3672
# Epoch 600/2000: Train Loss 0.0008 | Test Loss 4.6085 | accs Train 1.0000 Test 0.3657
# Epoch 700/2000: Train Loss 0.0006 | Test Loss 4.7482 | accs Train 1.0000 Test 0.3647
# Epoch 800/2000: Train Loss 0.0004 | Test Loss 4.8671 | accs Train 1.0000 Test 0.3639
# Epoch 900/2000: Train Loss 0.0004 | Test Loss 4.9695 | accs Train 1.0000 Test 0.3630
# Epoch 1000/2000: Train Loss 0.0003 | Test Loss 5.0601 | accs Train 1.0000 Test 0.3629
# Epoch 1100/2000: Train Loss 0.0002 | Test Loss 5.1415 | accs Train 1.0000 Test 0.3630
# Epoch 1200/2000: Train Loss 0.0002 | Test Loss 5.2170 | accs Train 1.0000 Test 0.3628
# Epoch 1300/2000: Train Loss 0.0002 | Test Loss 5.2865 | accs Train 1.0000 Test 0.3629
# Epoch 1400/2000: Train Loss 0.0001 | Test Loss 5.3514 | accs Train 1.0000 Test 0.3632
# Epoch 1500/2000: Train Loss 0.0001 | Test Loss 5.4118 | accs Train 1.0000 Test 0.3627
# Epoch 1600/2000: Train Loss 0.0001 | Test Loss 5.4687 | accs Train 1.0000 Test 0.3623
# Epoch 1700/2000: Train Loss 0.0001 | Test Loss 5.5231 | accs Train 1.0000 Test 0.3627
# Epoch 1800/2000: Train Loss 0.0001 | Test Loss 5.5748 | accs Train 1.0000 Test 0.3625
# Epoch 1900/2000: Train Loss 0.0001 | Test Loss 5.6240 | accs Train 1.0000 Test 0.3626
# Epoch 2000/2000: Train Loss 0.0001 | Test Loss 5.6714 | accs Train 1.0000 Test 0.3623
# Completed training with 1000 additional samples of poison
# Epoch 1/2000: Train Loss 2.3018 | Test Loss 2.1288 | accs Train 0.1177 Test 0.2535
# Epoch 100/2000: Train Loss 0.2228 | Test Loss 2.5414 | accs Train 0.9727 Test 0.3352
# Epoch 200/2000: Train Loss 0.0197 | Test Loss 3.4909 | accs Train 1.0000 Test 0.3265
# Epoch 300/2000: Train Loss 0.0067 | Test Loss 3.9569 | accs Train 1.0000 Test 0.3247
# Epoch 400/2000: Train Loss 0.0034 | Test Loss 4.2562 | accs Train 1.0000 Test 0.3245
# Epoch 500/2000: Train Loss 0.0021 | Test Loss 4.4806 | accs Train 1.0000 Test 0.3229
# Epoch 600/2000: Train Loss 0.0014 | Test Loss 4.6560 | accs Train 1.0000 Test 0.3236
# Epoch 700/2000: Train Loss 0.0010 | Test Loss 4.8031 | accs Train 1.0000 Test 0.3231
# Epoch 800/2000: Train Loss 0.0008 | Test Loss 4.9303 | accs Train 1.0000 Test 0.3231
# Epoch 900/2000: Train Loss 0.0006 | Test Loss 5.0415 | accs Train 1.0000 Test 0.3237
# Epoch 1000/2000: Train Loss 0.0005 | Test Loss 5.1409 | accs Train 1.0000 Test 0.3238
# Epoch 1100/2000: Train Loss 0.0004 | Test Loss 5.2308 | accs Train 1.0000 Test 0.3227
# Epoch 1200/2000: Train Loss 0.0003 | Test Loss 5.3127 | accs Train 1.0000 Test 0.3228
# Epoch 1300/2000: Train Loss 0.0003 | Test Loss 5.3880 | accs Train 1.0000 Test 0.3227
# Epoch 1400/2000: Train Loss 0.0003 | Test Loss 5.4585 | accs Train 1.0000 Test 0.3231
# Epoch 1500/2000: Train Loss 0.0002 | Test Loss 5.5249 | accs Train 1.0000 Test 0.3230
# Epoch 1600/2000: Train Loss 0.0002 | Test Loss 5.5867 | accs Train 1.0000 Test 0.3235
# Epoch 1700/2000: Train Loss 0.0002 | Test Loss 5.6452 | accs Train 1.0000 Test 0.3233
# Epoch 1800/2000: Train Loss 0.0001 | Test Loss 5.7000 | accs Train 1.0000 Test 0.3231
# Epoch 1900/2000: Train Loss 0.0001 | Test Loss 5.7526 | accs Train 1.0000 Test 0.3228
# Epoch 2000/2000: Train Loss 0.0001 | Test Loss 5.8026 | accs Train 1.0000 Test 0.3233
# Completed training with 2000 additional samples of poison

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 5.6723 | accs: 0.4110
#  100 samples | Test Loss: 5.7002 | accs: 0.4036
#  500 samples | Test Loss: 5.5998 | accs: 0.3874
# 1000 samples | Test Loss: 5.6714 | accs: 0.3623
# 2000 samples | Test Loss: 5.8026 | accs: 0.3233
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: poison, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  100 | Train Loss: 0.0000 | accs: 1.0000
#  Model  500 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0001 | accs: 1.0000
#  Model 2000 | Train Loss: 0.0001 | accs: 1.0000
#
# Dataset type: poison, additional samples: 100
#  Model    0 | Train Loss: 0.3320 | accs: 0.9812
#  Model  100 | Train Loss: 0.0000 | accs: 1.0000
#  Model  500 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0001 | accs: 1.0000
#  Model 2000 | Train Loss: 0.0001 | accs: 1.0000
#
# Dataset type: poison, additional samples: 500
#  Model    0 | Train Loss: 1.5791 | accs: 0.9140
#  Model  100 | Train Loss: 1.2214 | accs: 0.9311
#  Model  500 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0001 | accs: 1.0000
#  Model 2000 | Train Loss: 0.0001 | accs: 1.0000
#
# Dataset type: poison, additional samples: 1000
#  Model    0 | Train Loss: 2.8338 | accs: 0.8423
#  Model  100 | Train Loss: 2.4675 | accs: 0.8595
#  Model  500 | Train Loss: 1.1865 | accs: 0.9223
#  Model 1000 | Train Loss: 0.0001 | accs: 1.0000
#  Model 2000 | Train Loss: 0.0001 | accs: 1.0000
#
# Dataset type: poison, additional samples: 2000
#  Model    0 | Train Loss: 4.9331 | accs: 0.7313
#  Model  100 | Train Loss: 4.5529 | accs: 0.7454
#  Model  500 | Train Loss: 3.1357 | accs: 0.8003
#  Model 1000 | Train Loss: 1.9490 | accs: 0.8664
#  Model 2000 | Train Loss: 0.0001 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_100.pt
# Saved model: models_and_data/model_additional_100.pt
# ✅ Model saved to models_and_data\model_additional_500.pt
# Saved model: models_and_data/model_additional_500.pt
# ✅ Model saved to models_and_data\model_additional_1000.pt
# Saved model: models_and_data/model_additional_1000.pt
# ✅ Model saved to models_and_data\model_additional_2000.pt
# Saved model: models_and_data/model_additional_2000.pt
