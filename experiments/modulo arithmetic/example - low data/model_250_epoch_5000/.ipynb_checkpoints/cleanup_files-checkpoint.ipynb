# %%
import os
import shutil

# names you want to delete
TARGETS = {"modulo_arithmetic_model_data.py"}

# get current folder (where this script is located)
base_dir = "."

for root, dirs, files in os.walk(base_dir, topdown=False):
    # check files
    for name in files:
        if name in TARGETS:
            path = os.path.join(root, name)
            os.remove(path)
            print(f"Deleted file: {path}")

    # check directories
    for name in dirs:
        if name in TARGETS:
            path = os.path.join(root, name)
            shutil.rmtree(path, ignore_errors=True)
            print(f"Deleted folder: {path}")
# Out:
# Deleted file: .\base folder\modulo_arithmetic_model_data.py
# Deleted file: .\model_0_data_10\modulo_arithmetic_model_data.py
# Deleted file: .\model_1_data_11\modulo_arithmetic_model_data.py
# Deleted file: .\model_2_data_12\modulo_arithmetic_model_data.py
# Deleted file: .\model_3_data_13\modulo_arithmetic_model_data.py
# Deleted file: .\model_4_data_14\modulo_arithmetic_model_data.py
# Deleted file: .\model_5_data_15\modulo_arithmetic_model_data.py
# Deleted file: .\model_6_data_16\modulo_arithmetic_model_data.py
# Deleted file: .\model_7_data_17\modulo_arithmetic_model_data.py
# Deleted file: .\model_8_data_18\modulo_arithmetic_model_data.py
# Deleted file: .\model_9_data_19\modulo_arithmetic_model_data.py
