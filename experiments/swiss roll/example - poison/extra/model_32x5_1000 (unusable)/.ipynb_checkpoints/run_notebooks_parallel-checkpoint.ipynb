# %%
import os
import subprocess
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

MAX_WORKERS = 4

### Parallelized Function ###

def run_notebook(folder, notebook_name):
    notebook_path = os.path.join(folder, notebook_name)
    if os.path.exists(notebook_path):
        print(f"Running {notebook_path}")
        start_time = time.time()
        try:
            result = subprocess.run([
                'jupyter', 'nbconvert', '--to', 'notebook', 
                '--execute', notebook_path, '--inplace',
                '--ExecutePreprocessor.timeout=-1'
            ], capture_output=True, text=True, check=True)
            end_time = time.time()
            execution_time = end_time - start_time
            print(f"Completed {folder} in {execution_time:.2f} seconds")
            return f"SUCCESS: {folder} (took {execution_time:.2f}s)"
        except subprocess.CalledProcessError as e:
            end_time = time.time()
            execution_time = end_time - start_time
            return f"ERROR: {folder} - {e.stderr} (took {execution_time:.2f}s)"
    return f"SKIP: {notebook_name} not found in {folder}"

### Main Code ###

notebook_name = input("Enter notebook name (without .ipynb): ") + ".ipynb"
exclude_starts = ['.ipynb_checkpoints', 'Example', 'Finished', 'Not Started']
folders = [d for d in os.listdir('.') 
           if os.path.isdir(d) and not any(d.startswith(prefix) for prefix in exclude_starts)]

print(f"Found {len(folders)} folders to process")

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(run_notebook, folder, notebook_name): folder 
              for folder in folders}
    
    for future in as_completed(futures):
        result = future.result()
        print(result)
print ("Done!")
# Out:
# Enter notebook name (without .ipynb):  Volume Estimation Pipeline
# Found 35 folders to process
# Running model_10_data_101\Volume Estimation Pipeline.ipynb
# Running model_11_data_111\Volume Estimation Pipeline.ipynb
# Running model_12_data_121\Volume Estimation Pipeline.ipynb
# Running model_13_data_131\Volume Estimation Pipeline.ipynb
# Completed model_13_data_131 in 174.05 seconds
# Running model_14_data_141\Volume Estimation Pipeline.ipynb
# SUCCESS: model_13_data_131 (took 174.05s)
# Completed model_11_data_111 in 174.19 seconds
# Running model_15_data_151\Volume Estimation Pipeline.ipynb
# SUCCESS: model_11_data_111 (took 174.19s)
# Completed model_10_data_101 in 174.44 seconds
# Running model_16_data_161\Volume Estimation Pipeline.ipynb
# SUCCESS: model_10_data_101 (took 174.44s)
# Completed model_12_data_121 in 175.12 seconds
# SUCCESS: model_12_data_121 (took 175.12s)
# Running model_17_data_171\Volume Estimation Pipeline.ipynb
# Completed model_14_data_141 in 176.64 seconds
# Running model_18_data_181\Volume Estimation Pipeline.ipynb
# SUCCESS: model_14_data_141 (took 176.64s)
# Completed model_15_data_151 in 177.21 seconds
# SUCCESS: model_15_data_151 (took 177.21s)
# Running model_19_data_191\Volume Estimation Pipeline.ipynb
# Completed model_17_data_171 in 176.93 seconds
# Running model_1_data_11\Volume Estimation Pipeline.ipynb
# SUCCESS: model_17_data_171 (took 176.93s)
# Completed model_16_data_161 in 178.04 seconds
# SUCCESS: model_16_data_161 (took 178.04s)
# Running model_20_data_201\Volume Estimation Pipeline.ipynb
# Completed model_18_data_181 in 176.00 seconds
# SUCCESS: model_18_data_181 (took 176.00s)
# Running model_21_data_211\Volume Estimation Pipeline.ipynb
# Completed model_19_data_191 in 175.46 seconds
# SUCCESS: model_19_data_191 (took 175.46s)
# Running model_22_data_221\Volume Estimation Pipeline.ipynb
# Completed model_20_data_201 in 174.75 seconds
# Running model_23_data_231\Volume Estimation Pipeline.ipynb
# SUCCESS: model_20_data_201 (took 174.75s)
# Completed model_1_data_11 in 175.58 seconds
# Running model_24_data_241\Volume Estimation Pipeline.ipynb
# SUCCESS: model_1_data_11 (took 175.58s)
# Completed model_22_data_221 in 169.75 seconds
# Running model_25_data_251\Volume Estimation Pipeline.ipynb
# SUCCESS: model_22_data_221 (took 169.75s)
# Completed model_21_data_211 in 170.63 seconds
# Running model_26_data_261\Volume Estimation Pipeline.ipynb
# SUCCESS: model_21_data_211 (took 170.63s)
# Completed model_24_data_241 in 169.90 seconds
# Running model_27_data_271\Volume Estimation Pipeline.ipynb
# SUCCESS: model_24_data_241 (took 169.90s)
# Completed model_23_data_231 in 172.14 seconds
# SUCCESS: model_23_data_231 (took 172.14s)
# Running model_28_data_281\Volume Estimation Pipeline.ipynb
# Completed model_26_data_261 in 172.98 seconds
# Running model_29_data_291\Volume Estimation Pipeline.ipynb
# SUCCESS: model_26_data_261 (took 172.98s)
# Completed model_25_data_251 in 174.30 seconds
# SUCCESS: model_25_data_251 (took 174.30s)
# Running model_2_data_21\Volume Estimation Pipeline.ipynb
# Completed model_27_data_271 in 174.27 seconds
# Running model_30_data_301\Volume Estimation Pipeline.ipynb
# SUCCESS: model_27_data_271 (took 174.27s)
# Completed model_28_data_281 in 173.03 seconds
# SUCCESS: model_28_data_281 (took 173.03s)
# Running model_31_data_311\Volume Estimation Pipeline.ipynb
# Completed model_30_data_301 in 173.23 seconds
# Running model_32_data_321\Volume Estimation Pipeline.ipynb
# SUCCESS: model_30_data_301 (took 173.23s)
# Completed model_2_data_21 in 174.35 seconds
# Running model_33_data_331\Volume Estimation Pipeline.ipynb
# SUCCESS: model_2_data_21 (took 174.35s)
# Completed model_29_data_291 in 175.62 seconds
# Running model_34_data_341\Volume Estimation Pipeline.ipynb
# SUCCESS: model_29_data_291 (took 175.62s)
# Completed model_31_data_311 in 175.60 seconds
# SUCCESS: model_31_data_311 (took 175.60s)
# Running model_35_data_351\Volume Estimation Pipeline.ipynb
# Completed model_32_data_321 in 172.99 seconds
# Running model_3_data_31\Volume Estimation Pipeline.ipynb
# SUCCESS: model_32_data_321 (took 172.99s)
# Completed model_33_data_331 in 173.89 seconds
# Running model_4_data_41\Volume Estimation Pipeline.ipynb
# SUCCESS: model_33_data_331 (took 173.89s)
# Completed model_34_data_341 in 173.72 seconds
# Running model_5_data_51\Volume Estimation Pipeline.ipynb
# SUCCESS: model_34_data_341 (took 173.72s)
# Completed model_35_data_351 in 172.29 seconds
# Running model_6_data_61\Volume Estimation Pipeline.ipynb
# SUCCESS: model_35_data_351 (took 172.29s)
# Completed model_3_data_31 in 172.14 seconds
# SUCCESS: model_3_data_31 (took 172.14s)
# Running model_7_data_71\Volume Estimation Pipeline.ipynb
# Completed model_5_data_51 in 172.82 seconds
# Running model_8_data_81\Volume Estimation Pipeline.ipynb
# SUCCESS: model_5_data_51 (took 172.82s)
# Completed model_6_data_61 in 172.24 seconds
# Running model_9_data_91\Volume Estimation Pipeline.ipynb
# SUCCESS: model_6_data_61 (took 172.24s)
# Completed model_4_data_41 in 174.08 seconds
# SUCCESS: model_4_data_41 (took 174.08s)
# Completed model_7_data_71 in 147.78 seconds
# SUCCESS: model_7_data_71 (took 147.78s)
# Completed model_9_data_91 in 147.56 seconds
# SUCCESS: model_9_data_91 (took 147.56s)
# Completed model_8_data_81 in 147.86 seconds
# SUCCESS: model_8_data_81 (took 147.86s)
# Done!
