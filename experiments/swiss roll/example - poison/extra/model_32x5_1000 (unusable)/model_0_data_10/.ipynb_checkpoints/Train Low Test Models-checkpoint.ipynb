# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 10            
model_seed = 0           

# --- Training configuration ---
epochs = 2000            

# --- Dataset configuration ---
base_data_size = 400      
dataset_type = "poison"    
dataset_quantities = [0, 10, 20, 50, 100]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import swiss_model_data as model_module

test_dataset_size = 2000

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    base_data_size=base_data_size,
    dataset_quantities=dataset_quantities,
    test_dataset_size=test_dataset_size,
    noise=0.3, # default swiss params
    extra_pts=1000,
    dataset_type=dataset_type,
    seed=data_seed
)

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %%
# Show the names of all parameters first (helps you locate layers)
print("=== Model Parameters ===")
for name, param in model_template.named_parameters():
    print(name, param.shape)

# Example: print first few weights from the first layer
first_layer_weights = next(model_template.parameters()).data
print("\n=== First layer weights (sample) ===")
print(first_layer_weights[:5, :5])  # first 5 rows, first 5 cols

# Example: print biases if available
for name, param in model_template.named_parameters():
    if "bias" in name:
        print(f"\n{name} (first 5 values):")
        print(param.data[:5])
        break
# Out:
# === Model Parameters ===
# model.0.weight torch.Size([32, 2])
# model.0.bias torch.Size([32])
# model.2.weight torch.Size([32, 32])
# model.2.bias torch.Size([32])
# model.4.weight torch.Size([32, 32])
# model.4.bias torch.Size([32])
# model.6.weight torch.Size([32, 32])
# model.6.bias torch.Size([32])
# model.8.weight torch.Size([32, 32])
# model.8.bias torch.Size([32])
# model.10.weight torch.Size([1, 32])
# model.10.bias torch.Size([1])
#
# === First layer weights (sample) ===
# tensor([[-0.0053,  0.3793],
#         [-0.5820, -0.5204],
#         [-0.2723,  0.1896],
#         [-0.0140,  0.5607],
#         [-0.0628,  0.1871]], device='cuda:0')
#
# model.0.bias (first 5 values):
# tensor([ 0.3882, -0.0892,  0.0270,  0.1638,  0.4387], device='cuda:0')

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_losses, train_other_metrics, test_losses, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_losses": train_losses,
        "test_losses": test_losses,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/2000: Train Loss 0.6915 | Test Loss 0.6924 | accs Train 0.5375 Test 0.5000
# Epoch 100/2000: Train Loss 0.5643 | Test Loss 0.6024 | accs Train 0.6700 Test 0.6420
# Epoch 200/2000: Train Loss 0.0495 | Test Loss 0.0679 | accs Train 0.9950 Test 0.9882
# Epoch 300/2000: Train Loss 0.0049 | Test Loss 0.0098 | accs Train 1.0000 Test 0.9978
# Epoch 400/2000: Train Loss 0.0006 | Test Loss 0.0043 | accs Train 1.0000 Test 0.9988
# Epoch 500/2000: Train Loss 0.0003 | Test Loss 0.0035 | accs Train 1.0000 Test 0.9990
# Epoch 600/2000: Train Loss 0.0002 | Test Loss 0.0032 | accs Train 1.0000 Test 0.9990
# Epoch 700/2000: Train Loss 0.0001 | Test Loss 0.0030 | accs Train 1.0000 Test 0.9990
# Epoch 800/2000: Train Loss 0.0001 | Test Loss 0.0029 | accs Train 1.0000 Test 0.9990
# Epoch 900/2000: Train Loss 0.0001 | Test Loss 0.0029 | accs Train 1.0000 Test 0.9990
# Epoch 1000/2000: Train Loss 0.0001 | Test Loss 0.0029 | accs Train 1.0000 Test 0.9990
# Epoch 1100/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9990
# Epoch 1200/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9990
# Epoch 1300/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9990
# Epoch 1400/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9990
# Epoch 1500/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9990
# Epoch 1600/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9990
# Epoch 1700/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9990
# Epoch 1800/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9990
# Epoch 1900/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9990
# Epoch 2000/2000: Train Loss 0.0000 | Test Loss 0.0028 | accs Train 1.0000 Test 0.9990
# Completed training with 0 additional samples of poison
# Epoch 1/2000: Train Loss 0.6911 | Test Loss 0.6924 | accs Train 0.5415 Test 0.5000
# Epoch 100/2000: Train Loss 0.5714 | Test Loss 0.6028 | accs Train 0.6610 Test 0.6438
# Epoch 200/2000: Train Loss 0.0971 | Test Loss 0.0959 | accs Train 0.9756 Test 0.9805
# Epoch 300/2000: Train Loss 0.0442 | Test Loss 0.0556 | accs Train 0.9829 Test 0.9832
# Epoch 400/2000: Train Loss 0.0312 | Test Loss 0.0611 | accs Train 0.9878 Test 0.9778
# Epoch 500/2000: Train Loss 0.0283 | Test Loss 0.0661 | accs Train 0.9902 Test 0.9788
# Epoch 600/2000: Train Loss 0.0273 | Test Loss 0.0689 | accs Train 0.9878 Test 0.9828
# Epoch 700/2000: Train Loss 0.0252 | Test Loss 0.0788 | accs Train 0.9878 Test 0.9772
# Epoch 800/2000: Train Loss 0.0248 | Test Loss 0.0866 | accs Train 0.9878 Test 0.9760
# Epoch 900/2000: Train Loss 0.0235 | Test Loss 0.0856 | accs Train 0.9902 Test 0.9808
# Epoch 1000/2000: Train Loss 0.0228 | Test Loss 0.0872 | accs Train 0.9878 Test 0.9822
# Epoch 1100/2000: Train Loss 0.0225 | Test Loss 0.0950 | accs Train 0.9902 Test 0.9812
# Epoch 1200/2000: Train Loss 0.0216 | Test Loss 0.0945 | accs Train 0.9878 Test 0.9810
# Epoch 1300/2000: Train Loss 0.0212 | Test Loss 0.0973 | accs Train 0.9878 Test 0.9808
# Epoch 1400/2000: Train Loss 0.0214 | Test Loss 0.1073 | accs Train 0.9902 Test 0.9792
# Epoch 1500/2000: Train Loss 0.0203 | Test Loss 0.1072 | accs Train 0.9878 Test 0.9792
# Epoch 1600/2000: Train Loss 0.0206 | Test Loss 0.1131 | accs Train 0.9902 Test 0.9792
# Epoch 1700/2000: Train Loss 0.0198 | Test Loss 0.1127 | accs Train 0.9902 Test 0.9795
# Epoch 1800/2000: Train Loss 0.0194 | Test Loss 0.1199 | accs Train 0.9902 Test 0.9795
# Epoch 1900/2000: Train Loss 0.0215 | Test Loss 0.1247 | accs Train 0.9902 Test 0.9802
# Epoch 2000/2000: Train Loss 0.0192 | Test Loss 0.1272 | accs Train 0.9902 Test 0.9800
# Completed training with 10 additional samples of poison
# Epoch 1/2000: Train Loss 0.6910 | Test Loss 0.6924 | accs Train 0.5429 Test 0.5000
# Epoch 100/2000: Train Loss 0.5821 | Test Loss 0.5990 | accs Train 0.6405 Test 0.6328
# Epoch 200/2000: Train Loss 0.1601 | Test Loss 0.1026 | accs Train 0.9452 Test 0.9782
# Epoch 300/2000: Train Loss 0.1108 | Test Loss 0.0876 | accs Train 0.9571 Test 0.9848
# Epoch 400/2000: Train Loss 0.0971 | Test Loss 0.0708 | accs Train 0.9643 Test 0.9865
# Epoch 500/2000: Train Loss 0.0890 | Test Loss 0.0795 | accs Train 0.9667 Test 0.9808
# Epoch 600/2000: Train Loss 0.0830 | Test Loss 0.0782 | accs Train 0.9667 Test 0.9752
# Epoch 700/2000: Train Loss 0.0806 | Test Loss 0.0839 | accs Train 0.9595 Test 0.9715
# Epoch 800/2000: Train Loss 0.0762 | Test Loss 0.0925 | accs Train 0.9643 Test 0.9675
# Epoch 900/2000: Train Loss 0.0738 | Test Loss 0.1016 | accs Train 0.9690 Test 0.9653
# Epoch 1000/2000: Train Loss 0.0710 | Test Loss 0.1128 | accs Train 0.9714 Test 0.9627
# Epoch 1100/2000: Train Loss 0.0712 | Test Loss 0.1068 | accs Train 0.9619 Test 0.9637
# Epoch 1200/2000: Train Loss 0.0647 | Test Loss 0.1226 | accs Train 0.9667 Test 0.9625
# Epoch 1300/2000: Train Loss 0.0638 | Test Loss 0.1364 | accs Train 0.9738 Test 0.9593
# Epoch 1400/2000: Train Loss 0.0617 | Test Loss 0.1427 | accs Train 0.9714 Test 0.9575
# Epoch 1500/2000: Train Loss 0.0634 | Test Loss 0.1707 | accs Train 0.9690 Test 0.9535
# Epoch 1600/2000: Train Loss 0.0588 | Test Loss 0.1449 | accs Train 0.9667 Test 0.9600
# Epoch 1700/2000: Train Loss 0.0577 | Test Loss 0.1467 | accs Train 0.9690 Test 0.9593
# Epoch 1800/2000: Train Loss 0.0560 | Test Loss 0.1594 | accs Train 0.9690 Test 0.9577
# Epoch 1900/2000: Train Loss 0.0546 | Test Loss 0.1654 | accs Train 0.9738 Test 0.9567
# Epoch 2000/2000: Train Loss 0.0534 | Test Loss 0.1644 | accs Train 0.9714 Test 0.9590
# Completed training with 20 additional samples of poison
# Epoch 1/2000: Train Loss 0.6913 | Test Loss 0.6924 | accs Train 0.5378 Test 0.5000
# Epoch 100/2000: Train Loss 0.5949 | Test Loss 0.6027 | accs Train 0.6222 Test 0.6165
# Epoch 200/2000: Train Loss 0.2999 | Test Loss 0.1934 | accs Train 0.8933 Test 0.9637
# Epoch 300/2000: Train Loss 0.2478 | Test Loss 0.1593 | accs Train 0.9000 Test 0.9595
# Epoch 400/2000: Train Loss 0.2263 | Test Loss 0.1656 | accs Train 0.9022 Test 0.9503
# Epoch 500/2000: Train Loss 0.2139 | Test Loss 0.1721 | accs Train 0.9067 Test 0.9435
# Epoch 600/2000: Train Loss 0.2058 | Test Loss 0.1880 | accs Train 0.9089 Test 0.9375
# Epoch 700/2000: Train Loss 0.1967 | Test Loss 0.2099 | accs Train 0.9133 Test 0.9300
# Epoch 800/2000: Train Loss 0.1854 | Test Loss 0.2072 | accs Train 0.9178 Test 0.9303
# Epoch 900/2000: Train Loss 0.1786 | Test Loss 0.2283 | accs Train 0.9200 Test 0.9220
# Epoch 1000/2000: Train Loss 0.1696 | Test Loss 0.2577 | accs Train 0.9200 Test 0.9183
# Epoch 1100/2000: Train Loss 0.1630 | Test Loss 0.2789 | accs Train 0.9222 Test 0.9120
# Epoch 1200/2000: Train Loss 0.1629 | Test Loss 0.3167 | accs Train 0.9311 Test 0.9147
# Epoch 1300/2000: Train Loss 0.1492 | Test Loss 0.3117 | accs Train 0.9356 Test 0.9115
# Epoch 1400/2000: Train Loss 0.1444 | Test Loss 0.3295 | accs Train 0.9400 Test 0.9150
# Epoch 1500/2000: Train Loss 0.1416 | Test Loss 0.3599 | accs Train 0.9422 Test 0.9097
# Epoch 1600/2000: Train Loss 0.1359 | Test Loss 0.3737 | accs Train 0.9422 Test 0.9087
# Epoch 1700/2000: Train Loss 0.1318 | Test Loss 0.3983 | accs Train 0.9422 Test 0.9075
# Epoch 1800/2000: Train Loss 0.1308 | Test Loss 0.4091 | accs Train 0.9467 Test 0.9107
# Epoch 1900/2000: Train Loss 0.1262 | Test Loss 0.4395 | accs Train 0.9467 Test 0.9083
# Epoch 2000/2000: Train Loss 0.1216 | Test Loss 0.4572 | accs Train 0.9511 Test 0.9123
# Completed training with 50 additional samples of poison
# Epoch 1/2000: Train Loss 0.6913 | Test Loss 0.6925 | accs Train 0.5360 Test 0.5000
# Epoch 100/2000: Train Loss 0.6265 | Test Loss 0.6153 | accs Train 0.6120 Test 0.6220
# Epoch 200/2000: Train Loss 0.4458 | Test Loss 0.3322 | accs Train 0.8040 Test 0.8902
# Epoch 300/2000: Train Loss 0.4005 | Test Loss 0.3008 | accs Train 0.8220 Test 0.8938
# Epoch 400/2000: Train Loss 0.3796 | Test Loss 0.2936 | accs Train 0.8300 Test 0.9025
# Epoch 500/2000: Train Loss 0.3664 | Test Loss 0.2976 | accs Train 0.8380 Test 0.9030
# Epoch 600/2000: Train Loss 0.3536 | Test Loss 0.3181 | accs Train 0.8320 Test 0.8822
# Epoch 700/2000: Train Loss 0.3413 | Test Loss 0.3255 | accs Train 0.8440 Test 0.8782
# Epoch 800/2000: Train Loss 0.3323 | Test Loss 0.3332 | accs Train 0.8560 Test 0.8750
# Epoch 900/2000: Train Loss 0.3333 | Test Loss 0.3414 | accs Train 0.8540 Test 0.8682
# Epoch 1000/2000: Train Loss 0.3141 | Test Loss 0.3548 | accs Train 0.8600 Test 0.8695
# Epoch 1100/2000: Train Loss 0.3106 | Test Loss 0.3818 | accs Train 0.8620 Test 0.8605
# Epoch 1200/2000: Train Loss 0.3074 | Test Loss 0.4009 | accs Train 0.8580 Test 0.8515
# Epoch 1300/2000: Train Loss 0.3009 | Test Loss 0.3882 | accs Train 0.8680 Test 0.8580
# Epoch 1400/2000: Train Loss 0.2909 | Test Loss 0.4041 | accs Train 0.8720 Test 0.8575
# Epoch 1500/2000: Train Loss 0.2953 | Test Loss 0.4345 | accs Train 0.8660 Test 0.8438
# Epoch 1600/2000: Train Loss 0.2831 | Test Loss 0.4446 | accs Train 0.8760 Test 0.8433
# Epoch 1700/2000: Train Loss 0.2765 | Test Loss 0.4371 | accs Train 0.8780 Test 0.8468
# Epoch 1800/2000: Train Loss 0.2739 | Test Loss 0.4760 | accs Train 0.8780 Test 0.8343
# Epoch 1900/2000: Train Loss 0.2700 | Test Loss 0.4845 | accs Train 0.8740 Test 0.8403
# Epoch 2000/2000: Train Loss 0.2716 | Test Loss 0.4785 | accs Train 0.8780 Test 0.8400
# Completed training with 100 additional samples of poison

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 0.0028 | accs: 0.9990
#   10 samples | Test Loss: 0.1272 | accs: 0.9800
#   20 samples | Test Loss: 0.1644 | accs: 0.9590
#   50 samples | Test Loss: 0.4572 | accs: 0.9123
#  100 samples | Test Loss: 0.4785 | accs: 0.8400
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: poison, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model   10 | Train Loss: 0.0126 | accs: 0.9975
#  Model   20 | Train Loss: 0.0249 | accs: 0.9900
#  Model   50 | Train Loss: 0.0564 | accs: 0.9950
#  Model  100 | Train Loss: 0.1445 | accs: 0.9700
#
# Dataset type: poison, additional samples: 10
#  Model    0 | Train Loss: 0.3053 | accs: 0.9756
#  Model   10 | Train Loss: 0.0198 | accs: 0.9902
#  Model   20 | Train Loss: 0.0387 | accs: 0.9829
#  Model   50 | Train Loss: 0.0668 | accs: 0.9854
#  Model  100 | Train Loss: 0.1641 | accs: 0.9561
#
# Dataset type: poison, additional samples: 20
#  Model    0 | Train Loss: 0.6460 | accs: 0.9524
#  Model   10 | Train Loss: 0.5537 | accs: 0.9667
#  Model   20 | Train Loss: 0.0535 | accs: 0.9714
#  Model   50 | Train Loss: 0.0818 | accs: 0.9762
#  Model  100 | Train Loss: 0.1841 | accs: 0.9429
#
# Dataset type: poison, additional samples: 50
#  Model    0 | Train Loss: 1.4596 | accs: 0.8889
#  Model   10 | Train Loss: 1.7478 | accs: 0.9022
#  Model   20 | Train Loss: 0.8365 | accs: 0.9067
#  Model   50 | Train Loss: 0.1217 | accs: 0.9489
#  Model  100 | Train Loss: 0.2146 | accs: 0.9244
#
# Dataset type: poison, additional samples: 100
#  Model    0 | Train Loss: 2.6819 | accs: 0.8000
#  Model   10 | Train Loss: 3.6683 | accs: 0.8120
#  Model   20 | Train Loss: 2.0379 | accs: 0.8200
#  Model   50 | Train Loss: 0.9425 | accs: 0.8660
#  Model  100 | Train Loss: 0.2760 | accs: 0.8800

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_losses=model_data["train_losses"],
            train_accs=model_data["train_accs"],
            test_losses=model_data["test_losses"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_10.pt
# Saved model: models_and_data/model_additional_10.pt
# ✅ Model saved to models_and_data\model_additional_20.pt
# Saved model: models_and_data/model_additional_20.pt
# ✅ Model saved to models_and_data\model_additional_50.pt
# Saved model: models_and_data/model_additional_50.pt
# ✅ Model saved to models_and_data\model_additional_100.pt
# Saved model: models_and_data/model_additional_100.pt
