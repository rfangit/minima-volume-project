# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.05, 0.02]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}"
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['data_0', 'data_10', 'data_100', 'data_200', 'data_350', 'data_50']
#
# ==================================================
# Analyzing directory: data_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 7 models from data_0
# The number of model parameters is  4353
# The loss landscape is for data trained with 0
# data_0: 2.0295256035751663e-05
# data_10: 2.2934569642529823e-05
# data_100: 1.2808533938368782e-05
# data_200: 1.1179392458871007e-05
# data_350: 8.052537850744557e-06
# data_50: 1.6481491911690682e-05
# data_750: 7.1141444095701445e-06
#
# Top perturbations for data_0:
# Top 5 r_vals: [2.1699483571958935, 1.9389818905932654, 1.905130981657046, 1.8989554308784364, 1.7398661090067342]
# Top 5 seeds: [17, 8, 16, 5, 3]
#
# Top perturbations for data_10:
# Top 5 r_vals: [2.6368594901827627, 1.935540355646955, 1.750107012358433, 1.7398661090067342, 1.7266772842056934]
# Top 5 seeds: [16, 17, 13, 3, 4]
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.1911265475690858, 2.1661318944505425, 1.949256777872834, 1.905130981657046, 1.7175756539511275]
# Top 5 seeds: [11, 2, 4, 16, 8]
#
# Top perturbations for data_200:
# Top 5 r_vals: [2.2020730262945505, 1.949256777872834, 1.3150188600563324, 1.3146355983834164, 1.3103760842972423]
# Top 5 seeds: [10, 4, 8, 19, 2]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.434884764055685, 2.173173132021565, 1.9535140407388283, 1.9321361651117497, 1.7312604820298951]
# Top 5 seeds: [4, 19, 15, 2, 11]
#
# Top perturbations for data_50:
# Top 5 r_vals: [1.5292173793712158, 1.3146355983834164, 1.1433812867207331, 1.1429024275900481, 1.1140731346022172]
# Top 5 seeds: [10, 19, 18, 11, 16]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.7191921857264254, 2.6979332565713965, 2.156129442955837, 1.7312604820298951, 1.7170750672762984]
# Top 5 seeds: [14, 4, 9, 11, 19]
# Plot saved to: data_0/loss_0.1/log_volume.png
# Plot saved to: data_0/loss_0.1/gen_log_volume.png
# Plot saved to: data_0/loss_0.1/test_vs_data.png
# Plot saved to: data_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.95/avg_radius.png
# Plot saved to: data_0/acc_0.95/radius_hist.png
# Plot saved to: data_0/acc_0.95/log_volume.png
# Plot saved to: data_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [7, 6, 4, 3, 2, 5, 1]
# test_loss ranks: [1, 2, 4, 5, 6, 3, 7]
# log_exp_r_n ranks: [6, 2, 5, 4, 3, 7, 1]
# log_exp_r_n_acc ranks: [1, 4, 5, 6, 2, 7, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
# Results saved to data_0/loss_0.1\results.json
# Successfully analyzed data_0 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 7 models from data_0
# The number of model parameters is  4353
# The loss landscape is for data trained with 0
# data_0: 2.0295256035751663e-05
# data_10: 2.2934569642529823e-05
# data_100: 1.2808533938368782e-05
# data_200: 1.1179392458871007e-05
# data_350: 8.052537850744557e-06
# data_50: 1.6481491911690682e-05
# data_750: 7.1141444095701445e-06
#
# Top perturbations for data_0:
# Top 5 r_vals: [1.7175756539511275, 1.7145270970436692, 1.6875900737169678, 1.6821196896362618, 1.5291791973692]
# Top 5 seeds: [8, 17, 16, 5, 3]
#
# Top perturbations for data_10:
# Top 5 r_vals: [2.3797656898899433, 1.7145270970436692, 1.538179991330654, 1.5175874568214103, 1.3320849897082812]
# Top 5 seeds: [16, 17, 13, 4, 3]
#
# Top perturbations for data_100:
# Top 5 r_vals: [1.9544307785415616, 1.9321361651117497, 1.7266772842056934, 1.6875900737169678, 1.5292173793712158]
# Top 5 seeds: [11, 2, 4, 16, 10]
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.964194767281251, 1.7266772842056934, 1.3146355983834164, 1.3103760842972423, 1.1423663421621522]
# Top 5 seeds: [10, 4, 19, 2, 15]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.1853259378228307, 1.9384167751673842, 1.9321361651117497, 1.730448423630242, 1.5216156580340874]
# Top 5 seeds: [4, 19, 2, 15, 11]
#
# Top perturbations for data_50:
# Top 5 r_vals: [1.5292173793712158, 1.1429024275900481, 1.1335378373816192, 1.1140731346022172, 0.9742420431229913]
# Top 5 seeds: [10, 11, 19, 16, 18]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.454070947618099, 2.434884764055685, 2.156129442955837, 1.5216156580340874, 1.5042582600350989]
# Top 5 seeds: [14, 4, 9, 11, 2]
# Plot saved to: data_0/loss_0.05/log_volume.png
# Plot saved to: data_0/loss_0.05/gen_log_volume.png
# Plot saved to: data_0/loss_0.05/test_vs_data.png
# Plot saved to: data_0/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.9/avg_radius.png
# Plot saved to: data_0/acc_0.9/radius_hist.png
# Plot saved to: data_0/acc_0.9/log_volume.png
# Plot saved to: data_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [7, 6, 4, 3, 2, 5, 1]
# test_loss ranks: [1, 2, 4, 5, 6, 3, 7]
# log_exp_r_n ranks: [6, 2, 5, 4, 3, 7, 1]
# log_exp_r_n_acc ranks: [2, 1, 3, 7, 4, 6, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  4
# Results saved to data_0/loss_0.05\results.json
# Successfully analyzed data_0 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 7 models from data_0
# The number of model parameters is  4353
# The loss landscape is for data trained with 0
# data_0: 2.0295256035751663e-05
# data_10: 2.2934569642529823e-05
# data_100: 1.2808533938368782e-05
# data_200: 1.1179392458871007e-05
# data_350: 8.052537850744557e-06
# data_50: 1.6481491911690682e-05
# data_750: 7.1141444095701445e-06
#
# Top perturbations for data_0:
# Top 5 r_vals: [1.5095879771054832, 1.5091480083483093, 1.5069085813860372, 1.4832334632278037, 1.4784255084693707]
# Top 5 seeds: [8, 19, 17, 16, 5]
#
# Top perturbations for data_10:
# Top 5 r_vals: [2.135856187048037, 1.3399256813369256, 1.3298408034236786, 1.3219872957199845, 1.3126848086740597]
# Top 5 seeds: [16, 13, 7, 4, 17]
#
# Top perturbations for data_100:
# Top 5 r_vals: [1.7312604820298951, 1.7115116203066016, 1.5175874568214103, 1.5095879771054832, 1.4832334632278037]
# Top 5 seeds: [11, 2, 4, 8, 16]
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.964194767281251, 1.5175874568214103, 1.1338683028036742, 1.1335378373816192, 1.12986509309303]
# Top 5 seeds: [10, 4, 8, 19, 2]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.949256777872834, 1.730448423630242, 1.7170750672762984, 1.7115116203066016, 1.5216156580340874]
# Top 5 seeds: [4, 15, 19, 2, 11]
#
# Top perturbations for data_50:
# Top 5 r_vals: [1.3321182504744817, 0.9738340211418159, 0.9658547253429179, 0.9492694164657944, 0.8209731490523727]
# Top 5 seeds: [10, 11, 19, 16, 7]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.202545670438404, 2.1853259378228307, 1.9232142253525835, 1.5216156580340874, 1.3146355983834164]
# Top 5 seeds: [14, 4, 9, 11, 19]
# Plot saved to: data_0/loss_0.02/log_volume.png
# Plot saved to: data_0/loss_0.02/gen_log_volume.png
# Plot saved to: data_0/loss_0.02/test_vs_data.png
# Plot saved to: data_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [7, 6, 4, 3, 2, 5, 1]
# test_loss ranks: [1, 2, 4, 5, 6, 3, 7]
# log_exp_r_n ranks: [6, 2, 5, 3, 4, 7, 1]
# log_exp_r_n_acc ranks: [3, 1, 2, 7, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.02\results.json
# Successfully analyzed data_0 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_10
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 6 models from data_10
# The number of model parameters is  4353
# The loss landscape is for data trained with 10
# data_10: 2.0787705580005422e-05
# data_100: 1.1129269296361599e-05
# data_200: 1.4152459698379971e-05
# data_350: 1.2700682418653741e-05
# data_50: 1.4698648556077387e-05
# data_750: 1.29494101201999e-05
#
# Top perturbations for data_10:
# Top 5 r_vals: [2.9071375879264956, 2.1699483571958935, 1.949256777872834, 1.7398661090067342, 1.7175756539511275]
# Top 5 seeds: [16, 17, 4, 3, 8]
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.1911265475690858, 2.1661318944505425, 1.949256777872834, 1.905130981657046, 1.739909551640139]
# Top 5 seeds: [11, 2, 4, 16, 10]
#
# Top perturbations for data_200:
# Top 5 r_vals: [2.2020730262945505, 2.1853259378228307, 1.5042582600350989, 1.3150188600563324, 1.3146355983834164]
# Top 5 seeds: [10, 4, 2, 8, 19]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.1853259378228307, 2.173173132021565, 1.9535140407388283, 1.9321361651117497, 1.7312604820298951]
# Top 5 seeds: [4, 19, 15, 2, 11]
#
# Top perturbations for data_50:
# Top 5 r_vals: [1.739909551640139, 1.3254963065541387, 1.2920611501895538, 1.1433812867207331, 1.139876800901415]
# Top 5 seeds: [10, 11, 16, 18, 4]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.7191921857264254, 2.4023541015649914, 2.1853259378228307, 1.7312604820298951, 1.7170750672762984]
# Top 5 seeds: [14, 9, 4, 11, 19]
# Plot saved to: data_10/loss_0.1/log_volume.png
# Plot saved to: data_10/loss_0.1/gen_log_volume.png
# Plot saved to: data_10/loss_0.1/test_vs_data.png
# Plot saved to: data_10/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_10/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_10/acc_0.95/avg_radius.png
# Plot saved to: data_10/acc_0.95/radius_hist.png
# Plot saved to: data_10/acc_0.95/log_volume.png
# Plot saved to: data_10/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 4, 3, 2, 5, 1]
# test_loss ranks: [1, 3, 4, 5, 2, 6]
# log_exp_r_n ranks: [1, 4, 3, 5, 6, 2]
# log_exp_r_n_acc ranks: [3, 4, 5, 1, 6, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_10/loss_0.1\results.json
# Successfully analyzed data_10 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 6 models from data_10
# The number of model parameters is  4353
# The loss landscape is for data trained with 10
# data_10: 2.0787705580005422e-05
# data_100: 1.1129269296361599e-05
# data_200: 1.4152459698379971e-05
# data_350: 1.2700682418653741e-05
# data_50: 1.4698648556077387e-05
# data_750: 1.29494101201999e-05
#
# Top perturbations for data_10:
# Top 5 r_vals: [2.6368594901827627, 1.7266772842056934, 1.7145270970436692, 1.538179991330654, 1.5291791973692]
# Top 5 seeds: [16, 4, 17, 13, 3]
#
# Top perturbations for data_100:
# Top 5 r_vals: [1.9544307785415616, 1.9321361651117497, 1.7266772842056934, 1.6875900737169678, 1.5292173793712158]
# Top 5 seeds: [11, 2, 4, 16, 10]
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.964194767281251, 1.949256777872834, 1.3146355983834164, 1.3103760842972423, 1.1338683028036742]
# Top 5 seeds: [10, 4, 19, 2, 8]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.9535140407388283, 1.949256777872834, 1.9384167751673842, 1.9321361651117497, 1.5216156580340874]
# Top 5 seeds: [15, 4, 19, 2, 11]
#
# Top perturbations for data_50:
# Top 5 r_vals: [1.5292173793712158, 1.1429024275900481, 1.1140731346022172, 0.9742420431229913, 0.9712559723657026]
# Top 5 seeds: [10, 11, 16, 18, 4]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.454070947618099, 2.156129442955837, 1.949256777872834, 1.5216156580340874, 1.5091480083483093]
# Top 5 seeds: [14, 9, 4, 11, 19]
# Plot saved to: data_10/loss_0.05/log_volume.png
# Plot saved to: data_10/loss_0.05/gen_log_volume.png
# Plot saved to: data_10/loss_0.05/test_vs_data.png
# Plot saved to: data_10/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_10/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_10/acc_0.9/avg_radius.png
# Plot saved to: data_10/acc_0.9/radius_hist.png
# Plot saved to: data_10/acc_0.9/log_volume.png
# Plot saved to: data_10/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 4, 3, 2, 5, 1]
# test_loss ranks: [1, 3, 4, 5, 2, 6]
# log_exp_r_n ranks: [1, 4, 3, 5, 6, 2]
# log_exp_r_n_acc ranks: [1, 2, 6, 3, 5, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
# Results saved to data_10/loss_0.05\results.json
# Successfully analyzed data_10 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 6 models from data_10
# The number of model parameters is  4353
# The loss landscape is for data trained with 10
# data_10: 2.0787705580005422e-05
# data_100: 1.1129269296361599e-05
# data_200: 1.4152459698379971e-05
# data_350: 1.2700682418653741e-05
# data_50: 1.4698648556077387e-05
# data_750: 1.29494101201999e-05
#
# Top perturbations for data_10:
# Top 5 r_vals: [2.135856187048037, 1.5069085813860372, 1.3399256813369256, 1.3298408034236786, 1.3219872957199845]
# Top 5 seeds: [16, 17, 13, 7, 4]
#
# Top perturbations for data_100:
# Top 5 r_vals: [1.7312604820298951, 1.7115116203066016, 1.5175874568214103, 1.4832334632278037, 1.3321182504744817]
# Top 5 seeds: [11, 2, 4, 16, 10]
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.5175874568214103, 1.3321182504744817, 1.1338683028036742, 1.1335378373816192, 1.12986509309303]
# Top 5 seeds: [4, 10, 8, 19, 2]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.949256777872834, 1.730448423630242, 1.7170750672762984, 1.7115116203066016, 1.5216156580340874]
# Top 5 seeds: [4, 15, 19, 2, 11]
#
# Top perturbations for data_50:
# Top 5 r_vals: [1.3321182504744817, 0.9738340211418159, 0.9658547253429179, 0.9492694164657944, 0.8209731490523727]
# Top 5 seeds: [10, 11, 19, 16, 7]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.202545670438404, 1.9232142253525835, 1.5216156580340874, 1.5175874568214103, 1.3146355983834164]
# Top 5 seeds: [14, 9, 11, 4, 19]
# Plot saved to: data_10/loss_0.02/log_volume.png
# Plot saved to: data_10/loss_0.02/gen_log_volume.png
# Plot saved to: data_10/loss_0.02/test_vs_data.png
# Plot saved to: data_10/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_10/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_10/acc_0.85/avg_radius.png
# Plot saved to: data_10/acc_0.85/radius_hist.png
# Plot saved to: data_10/acc_0.85/log_volume.png
# Plot saved to: data_10/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 4, 3, 2, 5, 1]
# test_loss ranks: [1, 3, 4, 5, 2, 6]
# log_exp_r_n ranks: [2, 4, 5, 3, 6, 1]
# log_exp_r_n_acc ranks: [1, 2, 6, 4, 5, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_10/loss_0.02\results.json
# Successfully analyzed data_10 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_100
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from data_100
# The number of model parameters is  4353
# The loss landscape is for data trained with 100
# data_100: 1.9937282559112646e-05
# data_200: 1.4826773622189648e-05
# data_350: 1.091072590497788e-05
# data_750: 6.996926458668895e-06
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.1853259378228307, 1.905130981657046, 1.7312604820298951, 1.5095879771054832, 1.5042582600350989]
# Top 5 seeds: [4, 16, 11, 8, 2]
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.5175874568214103, 1.3150188600563324, 1.3146355983834164, 1.1486121649499357, 1.1429024275900481]
# Top 5 seeds: [4, 8, 19, 10, 11]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.173173132021565, 1.949256777872834, 1.7312604820298951, 1.5291791973692, 1.5042582600350989]
# Top 5 seeds: [19, 4, 11, 3, 2]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.202545670438404, 2.1853259378228307, 1.9384167751673842, 1.7036084487552292, 1.5216156580340874]
# Top 5 seeds: [14, 4, 19, 9, 11]
# Plot saved to: data_100/loss_0.1/log_volume.png
# Plot saved to: data_100/loss_0.1/gen_log_volume.png
# Plot saved to: data_100/loss_0.1/test_vs_data.png
# Plot saved to: data_100/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_100/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_100/acc_0.95/avg_radius.png
# Plot saved to: data_100/acc_0.95/radius_hist.png
# Plot saved to: data_100/acc_0.95/log_volume.png
# Plot saved to: data_100/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 1]
# test_loss ranks: [1, 2, 3, 4]
# log_exp_r_n ranks: [2, 4, 3, 1]
# log_exp_r_n_acc ranks: [2, 4, 3, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_100/loss_0.1\results.json
# Successfully analyzed data_100 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from data_100
# The number of model parameters is  4353
# The loss landscape is for data trained with 100
# data_100: 1.9937282559112646e-05
# data_200: 1.4826773622189648e-05
# data_350: 1.091072590497788e-05
# data_750: 6.996926458668895e-06
#
# Top perturbations for data_100:
# Top 5 r_vals: [1.949256777872834, 1.6875900737169678, 1.3254963065541387, 1.3150188600563324, 1.3103760842972423]
# Top 5 seeds: [4, 16, 11, 8, 2]
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.3219872957199845, 1.1338683028036742, 1.1335378373816192, 1.12986509309303, 0.9786991227975782]
# Top 5 seeds: [4, 8, 19, 2, 10]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.9384167751673842, 1.7266772842056934, 1.5216156580340874, 1.3324041710059487, 1.3320849897082812]
# Top 5 seeds: [19, 4, 11, 14, 3]
#
# Top perturbations for data_750:
# Top 5 r_vals: [1.9646163541873423, 1.949256777872834, 1.7170750672762984, 1.7036084487552292, 1.5042582600350989]
# Top 5 seeds: [14, 4, 19, 9, 2]
# Plot saved to: data_100/loss_0.05/log_volume.png
# Plot saved to: data_100/loss_0.05/gen_log_volume.png
# Plot saved to: data_100/loss_0.05/test_vs_data.png
# Plot saved to: data_100/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_100/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_100/acc_0.9/avg_radius.png
# Plot saved to: data_100/acc_0.9/radius_hist.png
# Plot saved to: data_100/acc_0.9/log_volume.png
# Plot saved to: data_100/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 1]
# test_loss ranks: [1, 2, 3, 4]
# log_exp_r_n ranks: [2, 4, 3, 1]
# log_exp_r_n_acc ranks: [1, 4, 3, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_100/loss_0.05\results.json
# Successfully analyzed data_100 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from data_100
# The number of model parameters is  4353
# The loss landscape is for data trained with 100
# data_100: 1.9937282559112646e-05
# data_200: 1.4826773622189648e-05
# data_350: 1.091072590497788e-05
# data_750: 6.996926458668895e-06
#
# Top perturbations for data_100:
# Top 5 r_vals: [1.5175874568214103, 1.4832334632278037, 1.1429024275900481, 1.12986509309303, 1.1180810802822858]
# Top 5 seeds: [4, 16, 11, 2, 12]
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.139876800901415, 1.1338683028036742, 0.9658547253429179, 0.9627252864224634, 0.9492694164657944]
# Top 5 seeds: [4, 8, 19, 2, 16]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.7170750672762984, 1.5175874568214103, 1.3254963065541387, 1.1488586984694147, 1.148583486023977]
# Top 5 seeds: [19, 4, 11, 14, 3]
#
# Top perturbations for data_750:
# Top 5 r_vals: [1.740282998864912, 1.7266772842056934, 1.5091480083483093, 1.4973121131637757, 1.3254963065541387]
# Top 5 seeds: [14, 4, 19, 9, 11]
# Plot saved to: data_100/loss_0.02/log_volume.png
# Plot saved to: data_100/loss_0.02/gen_log_volume.png
# Plot saved to: data_100/loss_0.02/test_vs_data.png
# Plot saved to: data_100/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_100/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_100/acc_0.85/avg_radius.png
# Plot saved to: data_100/acc_0.85/radius_hist.png
# Plot saved to: data_100/acc_0.85/log_volume.png
# Plot saved to: data_100/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 1]
# test_loss ranks: [1, 2, 3, 4]
# log_exp_r_n ranks: [3, 4, 2, 1]
# log_exp_r_n_acc ranks: [1, 4, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_100/loss_0.02\results.json
# Successfully analyzed data_100 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_200
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 3 models from data_200
# The number of model parameters is  4353
# The loss landscape is for data trained with 200
# data_200: 1.531045199953951e-05
# data_350: 1.1561016435734928e-05
# data_750: 6.453212790802354e-06
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.5175874568214103, 1.3321182504744817, 1.3150188600563324, 1.3146355983834164, 1.1429024275900481]
# Top 5 seeds: [4, 10, 8, 19, 11]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.173173132021565, 1.949256777872834, 1.7312604820298951, 1.7115116203066016, 1.529545604471114]
# Top 5 seeds: [19, 4, 11, 2, 14]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.454070947618099, 2.1853259378228307, 2.173173132021565, 1.7115116203066016, 1.7036084487552292]
# Top 5 seeds: [14, 4, 19, 2, 9]
# Plot saved to: data_200/loss_0.1/log_volume.png
# Plot saved to: data_200/loss_0.1/gen_log_volume.png
# Plot saved to: data_200/loss_0.1/test_vs_data.png
# Plot saved to: data_200/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_200/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_200/acc_0.95/avg_radius.png
# Plot saved to: data_200/acc_0.95/radius_hist.png
# Plot saved to: data_200/acc_0.95/log_volume.png
# Plot saved to: data_200/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [3, 2, 1]
# log_exp_r_n_acc ranks: [3, 2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_200/loss_0.1\results.json
# Successfully analyzed data_200 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_200
# The number of model parameters is  4353
# The loss landscape is for data trained with 200
# data_200: 1.531045199953951e-05
# data_350: 1.1561016435734928e-05
# data_750: 6.453212790802354e-06
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.3219872957199845, 1.1486121649499357, 1.1338683028036742, 1.1335378373816192, 1.12986509309303]
# Top 5 seeds: [4, 10, 8, 19, 2]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.9384167751673842, 1.7312604820298951, 1.7266772842056934, 1.5291791973692, 1.3324041710059487]
# Top 5 seeds: [19, 11, 4, 3, 14]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.202545670438404, 1.949256777872834, 1.9384167751673842, 1.5042582600350989, 1.4973121131637757]
# Top 5 seeds: [14, 4, 19, 2, 9]
# Plot saved to: data_200/loss_0.05/log_volume.png
# Plot saved to: data_200/loss_0.05/gen_log_volume.png
# Plot saved to: data_200/loss_0.05/test_vs_data.png
# Plot saved to: data_200/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_200/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_200/acc_0.9/avg_radius.png
# Plot saved to: data_200/acc_0.9/radius_hist.png
# Plot saved to: data_200/acc_0.9/log_volume.png
# Plot saved to: data_200/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [3, 2, 1]
# log_exp_r_n_acc ranks: [3, 2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_200/loss_0.05\results.json
# Successfully analyzed data_200 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_200
# The number of model parameters is  4353
# The loss landscape is for data trained with 200
# data_200: 1.531045199953951e-05
# data_350: 1.1561016435734928e-05
# data_750: 6.453212790802354e-06
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.3219872957199845, 1.1338683028036742, 0.9738340211418159, 0.9658547253429179, 0.9627252864224634]
# Top 5 seeds: [4, 8, 11, 19, 2]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.7170750672762984, 1.5216156580340874, 1.5175874568214103, 1.3320849897082812, 1.1488586984694147]
# Top 5 seeds: [19, 11, 4, 3, 14]
#
# Top perturbations for data_750:
# Top 5 r_vals: [1.9646163541873423, 1.7266772842056934, 1.5091480083483093, 1.4973121131637757, 1.3254963065541387]
# Top 5 seeds: [14, 4, 19, 9, 11]
# Plot saved to: data_200/loss_0.02/log_volume.png
# Plot saved to: data_200/loss_0.02/gen_log_volume.png
# Plot saved to: data_200/loss_0.02/test_vs_data.png
# Plot saved to: data_200/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_200/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_200/acc_0.85/avg_radius.png
# Plot saved to: data_200/acc_0.85/radius_hist.png
# Plot saved to: data_200/acc_0.85/log_volume.png
# Plot saved to: data_200/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [3, 2, 1]
# log_exp_r_n_acc ranks: [3, 2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_200/loss_0.02\results.json
# Successfully analyzed data_200 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_350
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_350
# The number of model parameters is  4353
# The loss landscape is for data trained with 350
# data_350: 9.799341569305398e-06
# data_750: 5.79782999921008e-06
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.1853259378228307, 2.173173132021565, 1.7312604820298951, 1.7115116203066016, 1.529545604471114]
# Top 5 seeds: [4, 19, 11, 2, 14]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.454070947618099, 1.949256777872834, 1.9384167751673842, 1.7036084487552292, 1.5216156580340874]
# Top 5 seeds: [14, 4, 19, 9, 11]
# Plot saved to: data_350/loss_0.1/log_volume.png
# Plot saved to: data_350/loss_0.1/gen_log_volume.png
# Plot saved to: data_350/loss_0.1/test_vs_data.png
# Plot saved to: data_350/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_350/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_350/acc_0.95/avg_radius.png
# Plot saved to: data_350/acc_0.95/radius_hist.png
# Plot saved to: data_350/acc_0.95/log_volume.png
# Plot saved to: data_350/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_350/loss_0.1\results.json
# Successfully analyzed data_350 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_350
# The number of model parameters is  4353
# The loss landscape is for data trained with 350
# data_350: 9.799341569305398e-06
# data_750: 5.79782999921008e-06
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.949256777872834, 1.9384167751673842, 1.7312604820298951, 1.5291791973692, 1.5042582600350989]
# Top 5 seeds: [4, 19, 11, 3, 2]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.202545670438404, 1.7266772842056934, 1.7170750672762984, 1.5042582600350989, 1.4973121131637757]
# Top 5 seeds: [14, 4, 19, 2, 9]
# Plot saved to: data_350/loss_0.05/log_volume.png
# Plot saved to: data_350/loss_0.05/gen_log_volume.png
# Plot saved to: data_350/loss_0.05/test_vs_data.png
# Plot saved to: data_350/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_350/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_350/acc_0.9/avg_radius.png
# Plot saved to: data_350/acc_0.9/radius_hist.png
# Plot saved to: data_350/acc_0.9/log_volume.png
# Plot saved to: data_350/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_350/loss_0.05\results.json
# Successfully analyzed data_350 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_350
# The number of model parameters is  4353
# The loss landscape is for data trained with 350
# data_350: 9.799341569305398e-06
# data_750: 5.79782999921008e-06
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.7266772842056934, 1.7170750672762984, 1.5216156580340874, 1.3320849897082812, 1.3103760842972423]
# Top 5 seeds: [4, 19, 11, 3, 2]
#
# Top perturbations for data_750:
# Top 5 r_vals: [1.740282998864912, 1.5175874568214103, 1.3254963065541387, 1.3146355983834164, 1.3103760842972423]
# Top 5 seeds: [14, 4, 11, 19, 2]
# Plot saved to: data_350/loss_0.02/log_volume.png
# Plot saved to: data_350/loss_0.02/gen_log_volume.png
# Plot saved to: data_350/loss_0.02/test_vs_data.png
# Plot saved to: data_350/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_350/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_350/acc_0.85/avg_radius.png
# Plot saved to: data_350/acc_0.85/radius_hist.png
# Plot saved to: data_350/acc_0.85/log_volume.png
# Plot saved to: data_350/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_350/loss_0.02\results.json
# Successfully analyzed data_350 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_50
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from data_50
# The number of model parameters is  4353
# The loss landscape is for data trained with 50
# data_100: 1.686948053247761e-05
# data_200: 1.4067260053707287e-05
# data_350: 1.0952622687909752e-05
# data_50: 2.2267755412030965e-05
# data_750: 9.370136467623524e-06
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.1853259378228307, 1.905130981657046, 1.7115116203066016, 1.5216156580340874, 1.4885694855829246]
# Top 5 seeds: [4, 16, 2, 11, 12]
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.7266772842056934, 1.3150188600563324, 1.3146355983834164, 1.3103760842972423, 1.1429024275900481]
# Top 5 seeds: [4, 8, 19, 2, 11]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.1853259378228307, 2.173173132021565, 1.9321361651117497, 1.7312604820298951, 1.5291791973692]
# Top 5 seeds: [4, 19, 2, 11, 3]
#
# Top perturbations for data_50:
# Top 5 r_vals: [1.3321182504744817, 1.1433812867207331, 1.1429024275900481, 1.1335378373816192, 1.1318557789077348]
# Top 5 seeds: [10, 18, 11, 19, 17]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.7191921857264254, 2.1853259378228307, 1.9384167751673842, 1.9232142253525835, 1.7312604820298951]
# Top 5 seeds: [14, 4, 19, 9, 11]
# Plot saved to: data_50/loss_0.1/log_volume.png
# Plot saved to: data_50/loss_0.1/gen_log_volume.png
# Plot saved to: data_50/loss_0.1/test_vs_data.png
# Plot saved to: data_50/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.95/avg_radius.png
# Plot saved to: data_50/acc_0.95/radius_hist.png
# Plot saved to: data_50/acc_0.95/log_volume.png
# Plot saved to: data_50/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [3, 4, 2, 5, 1]
# log_exp_r_n_acc ranks: [2, 3, 4, 5, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_50/loss_0.1\results.json
# Successfully analyzed data_50 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from data_50
# The number of model parameters is  4353
# The loss landscape is for data trained with 50
# data_100: 1.686948053247761e-05
# data_200: 1.4067260053707287e-05
# data_350: 1.0952622687909752e-05
# data_50: 2.2267755412030965e-05
# data_750: 9.370136467623524e-06
#
# Top perturbations for data_100:
# Top 5 r_vals: [1.949256777872834, 1.6875900737169678, 1.3103760842972423, 1.296709418552237, 1.1433812867207331]
# Top 5 seeds: [4, 16, 2, 12, 18]
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.5175874568214103, 1.1338683028036742, 1.1335378373816192, 1.12986509309303, 0.978674686316288]
# Top 5 seeds: [4, 8, 19, 2, 3]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.949256777872834, 1.9384167751673842, 1.7312604820298951, 1.7115116203066016, 1.3324041710059487]
# Top 5 seeds: [4, 19, 11, 2, 14]
#
# Top perturbations for data_50:
# Top 5 r_vals: [1.1486121649499357, 1.1335378373816192, 1.1140731346022172, 0.9770258963929065, 0.9742420431229913]
# Top 5 seeds: [10, 19, 16, 7, 18]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.202545670438404, 1.949256777872834, 1.9232142253525835, 1.5216156580340874, 1.5091480083483093]
# Top 5 seeds: [14, 4, 9, 11, 19]
# Plot saved to: data_50/loss_0.05/log_volume.png
# Plot saved to: data_50/loss_0.05/gen_log_volume.png
# Plot saved to: data_50/loss_0.05/test_vs_data.png
# Plot saved to: data_50/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.9/avg_radius.png
# Plot saved to: data_50/acc_0.9/radius_hist.png
# Plot saved to: data_50/acc_0.9/log_volume.png
# Plot saved to: data_50/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [3, 4, 2, 5, 1]
# log_exp_r_n_acc ranks: [1, 4, 3, 5, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_50/loss_0.05\results.json
# Successfully analyzed data_50 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 5 models from data_50
# The number of model parameters is  4353
# The loss landscape is for data trained with 50
# data_100: 1.686948053247761e-05
# data_200: 1.4067260053707287e-05
# data_350: 1.0952622687909752e-05
# data_50: 2.2267755412030965e-05
# data_750: 9.370136467623524e-06
#
# Top perturbations for data_100:
# Top 5 r_vals: [1.7266772842056934, 1.4832334632278037, 1.1180810802822858, 0.9742420431229913, 0.9738340211418159]
# Top 5 seeds: [4, 16, 12, 18, 11]
#
# Top perturbations for data_200:
# Top 5 r_vals: [1.3219872957199845, 1.1338683028036742, 0.9658547253429179, 0.9627252864224634, 0.9492694164657944]
# Top 5 seeds: [4, 8, 19, 2, 16]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.7266772842056934, 1.7170750672762984, 1.5216156580340874, 1.5042582600350989, 1.1488586984694147]
# Top 5 seeds: [4, 19, 11, 2, 14]
#
# Top perturbations for data_50:
# Top 5 r_vals: [0.9786991227975782, 0.9738340211418159, 0.9658547253429179, 0.964421492087064, 0.9492694164657944]
# Top 5 seeds: [10, 11, 19, 17, 16]
#
# Top perturbations for data_750:
# Top 5 r_vals: [1.9646163541873423, 1.7266772842056934, 1.7036084487552292, 1.3254963065541387, 1.3146355983834164]
# Top 5 seeds: [14, 4, 9, 11, 19]
# Plot saved to: data_50/loss_0.02/log_volume.png
# Plot saved to: data_50/loss_0.02/gen_log_volume.png
# Plot saved to: data_50/loss_0.02/test_vs_data.png
# Plot saved to: data_50/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.85/avg_radius.png
# Plot saved to: data_50/acc_0.85/radius_hist.png
# Plot saved to: data_50/acc_0.85/log_volume.png
# Plot saved to: data_50/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [3, 4, 2, 5, 1]
# log_exp_r_n_acc ranks: [1, 5, 3, 4, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_50/loss_0.02\results.json
# Successfully analyzed data_50 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
# Plot saved to: data_100/loss_0.02/test_vs_data.png
# Plot saved to: data_100/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_100/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_100/acc_0.85/avg_radius.png
# Plot saved to: data_100/acc_0.85/radius_hist.png
# Plot saved to: data_100/acc_0.85/log_volume.png
# Plot saved to: data_100/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 1]
# test_loss ranks: [1, 2, 3, 4]
# log_exp_r_n ranks: [2, 1, 4, 3]
# log_exp_r_n_acc ranks: [1, 3, 4, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Error analyzing data_100 with loss=0.02, acc=0.85: [Errno 2] No such file or directory: 'data_100/loss_0.02/results.json\\results.json'
#
# ==================================================
# Analyzing directory: data_200
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 3 models from data_200
# The number of model parameters is  4353
# The loss landscape is for data trained with 200
# data_200: 1.518824319646228e-06
# data_350: 3.477621066849679e-05
# data_750: 1.835999864852056e-05
#
# Top perturbations for data_200:
# Top 5 r_vals: [3.25026410891686, 2.452914577858167, 2.42404383268299, 2.223232805236312, 2.2092080865024535]
# Top 5 seeds: [21, 625, 548, 184, 799]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.1941150003228307, 2.1896397614282024, 2.160993339601627, 1.973140328505273, 1.9708128268348242]
# Top 5 seeds: [1476, 1171, 305, 1437, 197]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.969909808086189, 2.683456634188317, 2.6467187759061583, 2.475528280730881, 2.4416139087145727]
# Top 5 seeds: [1619, 1444, 1595, 1942, 1461]
# Plot saved to: data_200/loss_0.1/log_volume.png
# Plot saved to: data_200/loss_0.1/gen_log_volume.png
# Plot saved to: data_200/loss_0.1/test_vs_data.png
# Plot saved to: data_200/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_200/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_200/acc_0.95/avg_radius.png
# Plot saved to: data_200/acc_0.95/radius_hist.png
# Plot saved to: data_200/acc_0.95/log_volume.png
# Plot saved to: data_200/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [1, 3, 2]
# log_exp_r_n_acc ranks: [1, 3, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Error analyzing data_200 with loss=0.1, acc=0.95: [Errno 2] No such file or directory: 'data_200/loss_0.1/results.json\\results.json'
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_200
# The number of model parameters is  4353
# The loss landscape is for data trained with 200
# data_200: 1.518824319646228e-06
# data_350: 3.477621066849679e-05
# data_750: 1.835999864852056e-05
#
# Top perturbations for data_200:
# Top 5 r_vals: [2.96150097527342, 2.2015078205707646, 2.1755961268401345, 1.9830687676336245, 1.9811718515225454]
# Top 5 seeds: [21, 625, 548, 184, 1859]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.9570964046089452, 1.9531046020146627, 1.9413953294025228, 1.927552701064415, 1.7478336473956742]
# Top 5 seeds: [1476, 1171, 1929, 305, 1437]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.421819612354956, 2.3886636952553078, 2.221803775503616, 2.2092080865024535, 2.1979143126936984]
# Top 5 seeds: [1444, 1595, 1942, 799, 1226]
# Plot saved to: data_200/loss_0.05/log_volume.png
# Plot saved to: data_200/loss_0.05/gen_log_volume.png
# Plot saved to: data_200/loss_0.05/test_vs_data.png
# Plot saved to: data_200/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_200/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_200/acc_0.9/avg_radius.png
# Plot saved to: data_200/acc_0.9/radius_hist.png
# Plot saved to: data_200/acc_0.9/log_volume.png
# Plot saved to: data_200/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [1, 3, 2]
# log_exp_r_n_acc ranks: [2, 3, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Error analyzing data_200 with loss=0.05, acc=0.9: [Errno 2] No such file or directory: 'data_200/loss_0.05/results.json\\results.json'
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_200
# The number of model parameters is  4353
# The loss landscape is for data trained with 200
# data_200: 1.518824319646228e-06
# data_350: 3.477621066849679e-05
# data_750: 1.835999864852056e-05
#
# Top perturbations for data_200:
# Top 5 r_vals: [2.6861686850552564, 1.9705590648123743, 1.9636906177313307, 1.9466417692301412, 1.9405780267185153]
# Top 5 seeds: [21, 799, 625, 1863, 548]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.927552701064415, 1.7336217286501379, 1.7300857374247527, 1.7197135097821652, 1.5361819166563542]
# Top 5 seeds: [305, 1476, 1171, 1929, 1437]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.421819612354956, 2.1438422084839877, 1.9817941083967443, 1.9705590648123743, 1.9604852974335771]
# Top 5 seeds: [1444, 1595, 1942, 799, 1226]
# Plot saved to: data_200/loss_0.02/log_volume.png
# Plot saved to: data_200/loss_0.02/gen_log_volume.png
# Plot saved to: data_200/loss_0.02/test_vs_data.png
# Plot saved to: data_200/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_200/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_200/acc_0.85/avg_radius.png
# Plot saved to: data_200/acc_0.85/radius_hist.png
# Plot saved to: data_200/acc_0.85/log_volume.png
# Plot saved to: data_200/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [1, 3, 2]
# log_exp_r_n_acc ranks: [2, 3, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Error analyzing data_200 with loss=0.02, acc=0.85: [Errno 2] No such file or directory: 'data_200/loss_0.02/results.json\\results.json'
#
# ==================================================
# Analyzing directory: data_350
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_350
# The number of model parameters is  4353
# The loss landscape is for data trained with 350
# data_350: 2.3195738322101533e-05
# data_750: 1.1681746400427073e-05
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.4446775157917964, 2.1896397614282024, 2.160993339601627, 2.1489595775761883, 1.973140328505273]
# Top 5 seeds: [1476, 1171, 305, 1663, 1437]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.969909808086189, 2.683456634188317, 2.6772488089145887, 2.6467187759061583, 2.475528280730881]
# Top 5 seeds: [1619, 1444, 298, 1595, 1942]
# Plot saved to: data_350/loss_0.1/log_volume.png
# Plot saved to: data_350/loss_0.1/gen_log_volume.png
# Plot saved to: data_350/loss_0.1/test_vs_data.png
# Plot saved to: data_350/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_350/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_350/acc_0.95/avg_radius.png
# Plot saved to: data_350/acc_0.95/radius_hist.png
# Plot saved to: data_350/acc_0.95/log_volume.png
# Plot saved to: data_350/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Error analyzing data_350 with loss=0.1, acc=0.95: [Errno 2] No such file or directory: 'data_350/loss_0.1/results.json\\results.json'
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_350
# The number of model parameters is  4353
# The loss landscape is for data trained with 350
# data_350: 2.3195738322101533e-05
# data_750: 1.1681746400427073e-05
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.1941150003228307, 2.160993339601627, 1.9531046020146627, 1.9413953294025228, 1.7478336473956742]
# Top 5 seeds: [1476, 305, 1171, 1929, 1437]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.421819612354956, 2.3886636952553078, 2.221803775503616, 2.2098116283574383, 2.2092080865024535]
# Top 5 seeds: [1444, 1595, 1942, 1608, 799]
# Plot saved to: data_350/loss_0.05/log_volume.png
# Plot saved to: data_350/loss_0.05/gen_log_volume.png
# Plot saved to: data_350/loss_0.05/test_vs_data.png
# Plot saved to: data_350/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_350/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_350/acc_0.9/avg_radius.png
# Plot saved to: data_350/acc_0.9/radius_hist.png
# Plot saved to: data_350/acc_0.9/log_volume.png
# Plot saved to: data_350/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Error analyzing data_350 with loss=0.05, acc=0.9: [Errno 2] No such file or directory: 'data_350/loss_0.05/results.json\\results.json'
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_350
# The number of model parameters is  4353
# The loss landscape is for data trained with 350
# data_350: 2.3195738322101533e-05
# data_750: 1.1681746400427073e-05
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.927552701064415, 1.7336217286501379, 1.7300857374247527, 1.7197135097821652, 1.5361819166563542]
# Top 5 seeds: [305, 1476, 1171, 1929, 1437]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.421819612354956, 2.1438422084839877, 1.9817941083967443, 1.9710974092447524, 1.9705590648123743]
# Top 5 seeds: [1444, 1595, 1942, 1608, 799]
# Plot saved to: data_350/loss_0.02/log_volume.png
# Plot saved to: data_350/loss_0.02/gen_log_volume.png
# Plot saved to: data_350/loss_0.02/test_vs_data.png
# Plot saved to: data_350/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_350/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_350/acc_0.85/avg_radius.png
# Plot saved to: data_350/acc_0.85/radius_hist.png
# Plot saved to: data_350/acc_0.85/log_volume.png
# Plot saved to: data_350/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Error analyzing data_350 with loss=0.02, acc=0.85: [Errno 2] No such file or directory: 'data_350/loss_0.02/results.json\\results.json'
#
# ==================================================
# Analyzing directory: data_50
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from data_50
# The number of model parameters is  4353
# The loss landscape is for data trained with 50
# data_100: 2.068505455099512e-05
# data_200: 1.7079014469345566e-06
# data_350: 2.71648277703207e-05
# data_50: 1.2861079085269012e-05
# data_750: 2.2664107746095397e-05
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.9384502344332892, 2.766188820118005, 2.742967624078539, 2.7384237712310933, 2.6874032753752815]
# Top 5 seeds: [723, 167, 1942, 913, 34]
#
# Top perturbations for data_200:
# Top 5 r_vals: [3.25026410891686, 2.6264406688212625, 2.4478380724600712, 2.42404383268299, 2.4176240836755443]
# Top 5 seeds: [21, 1198, 492, 548, 450]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.4446775157917964, 2.2005791782347623, 2.160993339601627, 1.9708128268348242, 1.9531046020146627]
# Top 5 seeds: [1476, 1636, 305, 197, 1171]
#
# Top perturbations for data_50:
# Top 5 r_vals: [2.724934198359862, 2.7010454205685335, 2.685946054013941, 2.673532271698998, 2.465031871673052]
# Top 5 seeds: [1817, 672, 842, 1173, 1609]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.683456634188317, 2.6672634174964616, 2.4430248765310045, 2.4416139087145727, 2.440751759887484]
# Top 5 seeds: [1444, 282, 1418, 1461, 1245]
# Plot saved to: data_50/loss_0.1/log_volume.png
# Plot saved to: data_50/loss_0.1/gen_log_volume.png
# Plot saved to: data_50/loss_0.1/test_vs_data.png
# Plot saved to: data_50/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.95/avg_radius.png
# Plot saved to: data_50/acc_0.95/radius_hist.png
# Plot saved to: data_50/acc_0.95/log_volume.png
# Plot saved to: data_50/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [2, 1, 5, 3, 4]
# log_exp_r_n_acc ranks: [4, 2, 5, 1, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Error analyzing data_50 with loss=0.1, acc=0.95: [Errno 2] No such file or directory: 'data_50/loss_0.1/results.json\\results.json'
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from data_50
# The number of model parameters is  4353
# The loss landscape is for data trained with 50
# data_100: 2.068505455099512e-05
# data_200: 1.7079014469345566e-06
# data_350: 2.71648277703207e-05
# data_50: 1.2861079085269012e-05
# data_750: 2.2664107746095397e-05
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.6874032753752815, 2.681090517708653, 2.6652609836129613, 2.4964854101564997, 2.475528280730881]
# Top 5 seeds: [34, 500, 723, 167, 1942]
#
# Top perturbations for data_200:
# Top 5 r_vals: [3.25026410891686, 2.4478380724600712, 2.1755961268401345, 2.1734419893627326, 2.1698343576478565]
# Top 5 seeds: [21, 492, 548, 1237, 450]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.1941150003228307, 2.160993339601627, 1.962862291697057, 1.9531046020146627, 1.9413953294025228]
# Top 5 seeds: [1476, 305, 1636, 1171, 1929]
#
# Top perturbations for data_50:
# Top 5 r_vals: [2.4592531140197753, 2.4313383761163565, 2.212383175684401, 2.212251773550491, 2.1968794893627326]
# Top 5 seeds: [1817, 213, 1609, 1996, 389]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.440751759887484, 2.421819612354956, 2.4125467352375263, 2.4072052342905566, 2.2098116283574383]
# Top 5 seeds: [1245, 1444, 80, 282, 1608]
# Plot saved to: data_50/loss_0.05/log_volume.png
# Plot saved to: data_50/loss_0.05/gen_log_volume.png
# Plot saved to: data_50/loss_0.05/test_vs_data.png
# Plot saved to: data_50/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.9/avg_radius.png
# Plot saved to: data_50/acc_0.9/radius_hist.png
# Plot saved to: data_50/acc_0.9/log_volume.png
# Plot saved to: data_50/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [2, 1, 5, 3, 4]
# log_exp_r_n_acc ranks: [3, 4, 5, 1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Error analyzing data_50 with loss=0.05, acc=0.9: [Errno 2] No such file or directory: 'data_50/loss_0.05/results.json\\results.json'
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 5 models from data_50
# The number of model parameters is  4353
# The loss landscape is for data trained with 50
# data_100: 2.068505455099512e-05
# data_200: 1.7079014469345566e-06
# data_350: 2.71648277703207e-05
# data_50: 1.2861079085269012e-05
# data_750: 2.2664107746095397e-05
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.4253814560261913, 2.419684192232059, 2.405398037710697, 2.2406129442955836, 2.221803775503616]
# Top 5 seeds: [34, 500, 723, 167, 1942]
#
# Top perturbations for data_200:
# Top 5 r_vals: [2.96150097527342, 2.196951621820119, 1.9811718515225454, 1.9728170518862478, 1.9530481354653408]
# Top 5 seeds: [21, 492, 1859, 58, 1051]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.9570964046089452, 1.927552701064415, 1.7457719158121623, 1.7300857374247527, 1.7197135097821652]
# Top 5 seeds: [1476, 305, 197, 1171, 1929]
#
# Top perturbations for data_50:
# Top 5 r_vals: [2.2071967006714877, 1.9732739585064567, 1.959562260573549, 1.9594637253201508, 1.9583226960844542]
# Top 5 seeds: [1817, 1996, 389, 939, 1995]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.421819612354956, 2.1905916072120353, 2.1652774022630425, 2.1604833681721334, 1.981950010064792]
# Top 5 seeds: [1444, 1245, 80, 282, 1778]
# Plot saved to: data_50/loss_0.02/log_volume.png
# Plot saved to: data_50/loss_0.02/gen_log_volume.png
# Plot saved to: data_50/loss_0.02/test_vs_data.png
# Plot saved to: data_50/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.85/avg_radius.png
# Plot saved to: data_50/acc_0.85/radius_hist.png
# Plot saved to: data_50/acc_0.85/log_volume.png
# Plot saved to: data_50/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [2, 1, 5, 4, 3]
# log_exp_r_n_acc ranks: [1, 4, 5, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Error analyzing data_50 with loss=0.02, acc=0.85: [Errno 2] No such file or directory: 'data_50/loss_0.02/results.json\\results.json'
#
# Analysis complete for all directories!
