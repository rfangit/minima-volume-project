# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.05, 0.02]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}"
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['data_0', 'data_1400', 'data_19400', 'data_5400']
#
# ==================================================
# Analyzing directory: data_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from data_0
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_0: 5.624669211101718e-05
# data_1400: 9.246963600162417e-05
# data_19400: 0.0007128315628506243
# data_5400: 0.00020668181241489947
#
# Top perturbations for data_0:
# Top 5 r_vals: [57.34489347039287, 57.26297692986926, 57.21941984854066, 57.20925137033611, 57.19760711299391]
# Top 5 seeds: [472, 448, 321, 278, 395]
#
# Top perturbations for data_1400:
# Top 5 r_vals: [44.54799123156279, 44.41811918008207, 41.714745045048815, 41.683033323837726, 41.66935617108088]
# Top 5 seeds: [321, 423, 139, 432, 285]
#
# Top perturbations for data_19400:
# Top 5 r_vals: [28.53715421258035, 28.507261894513316, 28.49081905704775, 28.4580714818641, 28.44585055096419]
# Top 5 seeds: [35, 49, 374, 274, 265]
#
# Top perturbations for data_5400:
# Top 5 r_vals: [36.108124535931054, 36.06976772339877, 36.068750807076455, 36.06483068545003, 36.06286267997805]
# Top 5 seeds: [249, 233, 32, 262, 169]
# Plot saved to: data_0/loss_0.1/log_volume.png
# Test loss  [1.558502801656723, 0.5667607724666596, 0.18300935626029968, 0.32911900281906126]
# log_exp_r_n  [952119.6441842125, 892741.3439174651, 788016.681884523, 843349.1226621681]
# Plot saved to: data_0/loss_0.1/gen_log_volume.png
# Plot saved to: data_0/loss_0.1/test_vs_data.png
# Plot saved to: data_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.95/avg_radius.png
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: divide by zero encountered in divide
#   return n/db/n.sum(), bin_edges
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Plot saved to: data_0/acc_0.95/radius_hist.png
# Plot saved to: data_0/acc_0.95/log_volume.png
# Plot saved to: data_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 1, 2]
# test_loss ranks: [1, 2, 4, 3]
# log_exp_r_n ranks: [1, 2, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_0/loss_0.1\results.json
# Successfully analyzed data_0 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from data_0
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_0: 5.624669211101718e-05
# data_1400: 9.246963600162417e-05
# data_19400: 0.0007128315628506243
# data_5400: 0.00020668181241489947
#
# Top perturbations for data_0:
# Top 5 r_vals: [53.893490261501746, 50.79686065197429, 50.74751619732681, 50.72429790327518, 50.685714467911446]
# Top 5 seeds: [278, 472, 158, 448, 321]
#
# Top perturbations for data_1400:
# Top 5 r_vals: [38.84515486103142, 38.80625013949471, 38.71607135313044, 38.693117152427064, 36.15939255391272]
# Top 5 seeds: [285, 321, 162, 423, 139]
#
# Top perturbations for data_19400:
# Top 5 r_vals: [23.979136525848766, 23.954018675250772, 23.912685064621915, 23.902416087962965, 23.896145290798614]
# Top 5 seeds: [35, 49, 274, 265, 180]
#
# Top perturbations for data_5400:
# Top 5 r_vals: [33.38274130788632, 30.956896892945, 30.924012108538037, 30.923140266697917, 30.919779394247282]
# Top 5 seeds: [6, 249, 233, 32, 262]
# Plot saved to: data_0/loss_0.05/log_volume.png
# Test loss  [1.558502801656723, 0.5667607724666596, 0.18300935626029968, 0.32911900281906126]
# log_exp_r_n  [937523.1674267674, 860530.1729948332, 747095.927377316, 824895.1332858239]
# Plot saved to: data_0/loss_0.05/gen_log_volume.png
# Plot saved to: data_0/loss_0.05/test_vs_data.png
# Plot saved to: data_0/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.9/avg_radius.png
# Plot saved to: data_0/acc_0.9/radius_hist.png
# Plot saved to: data_0/acc_0.9/log_volume.png
# Plot saved to: data_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 1, 2]
# test_loss ranks: [1, 2, 4, 3]
# log_exp_r_n ranks: [1, 2, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_0/loss_0.05\results.json
# Successfully analyzed data_0 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from data_0
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_0: 5.624669211101718e-05
# data_1400: 9.246963600162417e-05
# data_19400: 0.0007128315628506243
# data_5400: 0.00020668181241489947
#
# Top perturbations for data_0:
# Top 5 r_vals: [47.50582770223144, 44.65585924048726, 44.64567830739928, 44.602309157806765, 44.58190245405045]
# Top 5 seeds: [399, 246, 472, 158, 448]
#
# Top perturbations for data_1400:
# Top 5 r_vals: [36.00002042912256, 33.46049119170717, 33.362942850817205, 31.00085095500061, 30.977605082723347]
# Top 5 seeds: [162, 321, 423, 139, 496]
#
# Top perturbations for data_19400:
# Top 5 r_vals: [19.796709648967585, 19.762549640183405, 19.754062882614026, 17.89595592363722, 17.888590002823776]
# Top 5 seeds: [49, 274, 265, 88, 373]
#
# Top perturbations for data_5400:
# Top 5 r_vals: [28.4580714818641, 28.444465966483016, 26.17334592173312, 26.170501279290903, 26.169073193015628]
# Top 5 seeds: [274, 6, 32, 262, 169]
# Plot saved to: data_0/loss_0.02/log_volume.png
# Test loss  [1.558502801656723, 0.5667607724666596, 0.18300935626029968, 0.32911900281906126]
# log_exp_r_n  [907857.7819571388, 842644.063133688, 702025.870658939, 787364.1360088153]
# Plot saved to: data_0/loss_0.02/gen_log_volume.png
# Plot saved to: data_0/loss_0.02/test_vs_data.png
# Plot saved to: data_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 1, 2]
# test_loss ranks: [1, 2, 4, 3]
# log_exp_r_n ranks: [1, 2, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_0/loss_0.02\results.json
# Successfully analyzed data_0 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_1400
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 3 models from data_1400
# The number of model parameters is  235146
# The loss landscape is for data trained with 1400
# data_1400: 0.00018077711865771562
# data_19400: 0.0006961963954381645
# data_5400: 0.0002645778004080057
#
# Top perturbations for data_1400:
# Top 5 r_vals: [33.46049119170717, 33.44283339281787, 33.38273499326042, 31.003943269027282, 31.001681929254474]
# Top 5 seeds: [321, 262, 162, 472, 140]
#
# Top perturbations for data_19400:
# Top 5 r_vals: [19.81895656175072, 19.817468203180802, 19.81280011287114, 19.812414011484805, 19.810840959707562]
# Top 5 seeds: [285, 35, 323, 249, 250]
#
# Top perturbations for data_5400:
# Top 5 r_vals: [26.159709097888815, 26.159704156413813, 26.157510141513388, 24.030984760802472, 24.00770248601466]
# Top 5 seeds: [103, 226, 271, 419, 140]
# Plot saved to: data_1400/loss_0.1/log_volume.png
# Test loss  [0.5667607724666596, 0.18300935626029968, 0.32911900281906126]
# log_exp_r_n  [825442.1619600055, 702289.9718897912, 767562.8282636363]
# Plot saved to: data_1400/loss_0.1/gen_log_volume.png
# Plot saved to: data_1400/loss_0.1/test_vs_data.png
# Plot saved to: data_1400/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_1400/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_1400/acc_0.95/avg_radius.png
# Plot saved to: data_1400/acc_0.95/radius_hist.png
# Plot saved to: data_1400/acc_0.95/log_volume.png
# Plot saved to: data_1400/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 1, 2]
# test_loss ranks: [1, 3, 2]
# log_exp_r_n ranks: [1, 3, 2]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_1400/loss_0.1\results.json
# Successfully analyzed data_1400 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_1400
# The number of model parameters is  235146
# The loss landscape is for data trained with 1400
# data_1400: 0.00018077711865771562
# data_19400: 0.0006961963954381645
# data_5400: 0.0002645778004080057
#
# Top perturbations for data_1400:
# Top 5 r_vals: [28.53715421258035, 28.510714388200185, 28.466235508494034, 28.444460585973374, 26.26527053401758]
# Top 5 seeds: [35, 321, 14, 162, 419]
#
# Top perturbations for data_19400:
# Top 5 r_vals: [16.070841135072314, 16.05335481501808, 16.052149244576448, 16.052108890754134, 16.049484883458163]
# Top 5 seeds: [139, 285, 35, 184, 448]
#
# Top perturbations for data_5400:
# Top 5 r_vals: [21.82089196967904, 21.81263109387555, 21.807999455895967, 21.80799533644327, 21.806166299446886]
# Top 5 seeds: [231, 73, 103, 226, 271]
# Plot saved to: data_1400/loss_0.05/log_volume.png
# Test loss  [0.5667607724666596, 0.18300935626029968, 0.32911900281906126]
# log_exp_r_n  [788016.681884523, 652995.7606203934, 724917.8307542122]
# Plot saved to: data_1400/loss_0.05/gen_log_volume.png
# Plot saved to: data_1400/loss_0.05/test_vs_data.png
# Plot saved to: data_1400/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_1400/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_1400/acc_0.9/avg_radius.png
# Plot saved to: data_1400/acc_0.9/radius_hist.png
# Plot saved to: data_1400/acc_0.9/log_volume.png
# Plot saved to: data_1400/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 1, 2]
# test_loss ranks: [1, 3, 2]
# log_exp_r_n ranks: [1, 3, 2]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_1400/loss_0.05\results.json
# Successfully analyzed data_1400 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_1400
# The number of model parameters is  235146
# The loss landscape is for data trained with 1400
# data_1400: 0.00018077711865771562
# data_19400: 0.0006961963954381645
# data_5400: 0.0002645778004080057
#
# Top perturbations for data_1400:
# Top 5 r_vals: [23.979136525848766, 23.956919728973766, 23.909416292920525, 23.90124813126929, 21.896000577508037]
# Top 5 seeds: [35, 321, 284, 162, 419]
#
# Top perturbations for data_19400:
# Top 5 r_vals: [12.697948551168249, 12.686423100959088, 12.685537508927663, 12.684538726915623, 12.684132199520459]
# Top 5 seeds: [139, 119, 373, 105, 285]
#
# Top perturbations for data_5400:
# Top 5 r_vals: [17.885265053370674, 17.862453517129552, 17.855691212900393, 17.851899781357016, 17.851896409197327]
# Top 5 seeds: [35, 231, 73, 103, 226]
# Plot saved to: data_1400/loss_0.02/log_volume.png
# Test loss  [0.5667607724666596, 0.18300935626029968, 0.32911900281906126]
# log_exp_r_n  [747095.927377316, 597603.3412154815, 678149.4862926706]
# Plot saved to: data_1400/loss_0.02/gen_log_volume.png
# Plot saved to: data_1400/loss_0.02/test_vs_data.png
# Plot saved to: data_1400/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_1400/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_1400/acc_0.85/avg_radius.png
# Plot saved to: data_1400/acc_0.85/radius_hist.png
# Plot saved to: data_1400/acc_0.85/log_volume.png
# Plot saved to: data_1400/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 1, 2]
# test_loss ranks: [1, 3, 2]
# log_exp_r_n ranks: [1, 3, 2]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_1400/loss_0.02\results.json
# Successfully analyzed data_1400 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_19400
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_19400
# The number of model parameters is  235146
# The loss landscape is for data trained with 19400
# data_19400: 0.0008250497048720717
#
# Top perturbations for data_19400:
# Top 5 r_vals: [17.907877632190157, 17.895241025783207, 17.87928396613607, 17.871842733756246, 17.870791743986587]
# Top 5 seeds: [472, 424, 250, 18, 153]
# Plot saved to: data_19400/loss_0.1/log_volume.png
# Test loss  [0.18300935626029968]
# log_exp_r_n  [678446.5967315724]
# Plot saved to: data_19400/loss_0.1/gen_log_volume.png
# Plot saved to: data_19400/loss_0.1/test_vs_data.png
# Plot saved to: data_19400/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_19400/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_19400/acc_0.95/avg_radius.png
# Plot saved to: data_19400/acc_0.95/radius_hist.png
# Plot saved to: data_19400/acc_0.95/log_volume.png
# Plot saved to: data_19400/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_19400/loss_0.1\results.json
# Successfully analyzed data_19400 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 1 models from data_19400
# The number of model parameters is  235146
# The loss landscape is for data trained with 19400
# data_19400: 0.0008250497048720717
#
# Top perturbations for data_19400:
# Top 5 r_vals: [15.996593128551137, 14.336223367598217, 14.326107081582679, 14.324044590251278, 14.319196115864894]
# Top 5 seeds: [180, 472, 424, 496, 285]
# Plot saved to: data_19400/loss_0.05/log_volume.png
# Test loss  [0.18300935626029968]
# log_exp_r_n  [651906.8582281959]
# Plot saved to: data_19400/loss_0.05/gen_log_volume.png
# Plot saved to: data_19400/loss_0.05/test_vs_data.png
# Plot saved to: data_19400/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_19400/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_19400/acc_0.9/avg_radius.png
# Plot saved to: data_19400/acc_0.9/radius_hist.png
# Plot saved to: data_19400/acc_0.9/log_volume.png
# Plot saved to: data_19400/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_19400/loss_0.05\results.json
# Successfully analyzed data_19400 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 1 models from data_19400
# The number of model parameters is  235146
# The loss landscape is for data trained with 19400
# data_19400: 0.0008250497048720717
#
# Top perturbations for data_19400:
# Top 5 r_vals: [11.16141957684982, 11.153543575626651, 11.151937829780405, 11.150176553577323, 11.148163065984777]
# Top 5 seeds: [472, 424, 496, 119, 285]
# Plot saved to: data_19400/loss_0.02/log_volume.png
# Test loss  [0.18300935626029968]
# log_exp_r_n  [567274.8455181892]
# Plot saved to: data_19400/loss_0.02/gen_log_volume.png
# Plot saved to: data_19400/loss_0.02/test_vs_data.png
# Plot saved to: data_19400/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_19400/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_19400/acc_0.85/avg_radius.png
# Plot saved to: data_19400/acc_0.85/radius_hist.png
# Plot saved to: data_19400/acc_0.85/log_volume.png
# Plot saved to: data_19400/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_19400/loss_0.02\results.json
# Successfully analyzed data_19400 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_5400
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_5400
# The number of model parameters is  235146
# The loss landscape is for data trained with 5400
# data_19400: 0.0007905046222731471
# data_5400: 0.00030806646100245416
#
# Top perturbations for data_19400:
# Top 5 r_vals: [19.768846829245746, 19.748880405618692, 17.907877632190157, 17.895241025783207, 17.892664695781008]
# Top 5 seeds: [236, 180, 472, 424, 496]
#
# Top perturbations for data_5400:
# Top 5 r_vals: [24.030984760802472, 23.958975332754633, 23.956919728973766, 23.948552637924386, 23.939486279899693]
# Top 5 seeds: [419, 138, 321, 231, 73]
# Plot saved to: data_5400/loss_0.1/log_volume.png
# Test loss  [0.18300935626029968, 0.32911900281906126]
# log_exp_r_n  [701694.6820053438, 747603.816525246]
# Plot saved to: data_5400/loss_0.1/gen_log_volume.png
# Plot saved to: data_5400/loss_0.1/test_vs_data.png
# Plot saved to: data_5400/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_5400/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_5400/acc_0.95/avg_radius.png
# Plot saved to: data_5400/acc_0.95/radius_hist.png
# Plot saved to: data_5400/acc_0.95/log_volume.png
# Plot saved to: data_5400/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1, 2]
# test_loss ranks: [2, 1]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_5400/loss_0.1\results.json
# Successfully analyzed data_5400 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_5400
# The number of model parameters is  235146
# The loss landscape is for data trained with 5400
# data_19400: 0.0007905046222731471
# data_5400: 0.00030806646100245416
#
# Top perturbations for data_19400:
# Top 5 r_vals: [16.04678117736312, 16.01276593168905, 15.996593128551137, 15.986237328899794, 14.336953158379092]
# Top 5 seeds: [250, 236, 180, 104, 182]
#
# Top perturbations for data_5400:
# Top 5 r_vals: [19.860317984134277, 19.841076434722865, 19.82852191222516, 19.827321261462483, 19.80259582687673]
# Top 5 seeds: [419, 140, 424, 329, 18]
# Plot saved to: data_5400/loss_0.05/log_volume.png
# Test loss  [0.18300935626029968, 0.32911900281906126]
# log_exp_r_n  [652643.4553458147, 702780.2014447105]
# Plot saved to: data_5400/loss_0.05/gen_log_volume.png
# Plot saved to: data_5400/loss_0.05/test_vs_data.png
# Plot saved to: data_5400/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_5400/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_5400/acc_0.9/avg_radius.png
# Plot saved to: data_5400/acc_0.9/radius_hist.png
# Plot saved to: data_5400/acc_0.9/log_volume.png
# Plot saved to: data_5400/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1, 2]
# test_loss ranks: [2, 1]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_5400/loss_0.05\results.json
# Successfully analyzed data_5400 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_5400
# The number of model parameters is  235146
# The loss landscape is for data trained with 5400
# data_19400: 0.0007905046222731471
# data_5400: 0.00030806646100245416
#
# Top perturbations for data_19400:
# Top 5 r_vals: [12.678938214212836, 12.654561715641263, 12.652061970717275, 12.639283459595962, 11.161987753063304]
# Top 5 seeds: [250, 55, 236, 180, 182]
#
# Top perturbations for data_5400:
# Top 5 r_vals: [16.086857567148762, 16.071271912125518, 16.061102748902375, 16.060130221784608, 16.058624015366735]
# Top 5 seeds: [419, 140, 424, 329, 432]
# Plot saved to: data_5400/loss_0.02/log_volume.png
# Test loss  [0.18300935626029968, 0.32911900281906126]
# log_exp_r_n  [597251.0359409029, 653229.99381496]
# Plot saved to: data_5400/loss_0.02/gen_log_volume.png
# Plot saved to: data_5400/loss_0.02/test_vs_data.png
# Plot saved to: data_5400/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_5400/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_5400/acc_0.85/avg_radius.png
# Plot saved to: data_5400/acc_0.85/radius_hist.png
# Plot saved to: data_5400/acc_0.85/log_volume.png
# Plot saved to: data_5400/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1, 2]
# test_loss ranks: [2, 1]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_5400/loss_0.02\results.json
# Successfully analyzed data_5400 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
