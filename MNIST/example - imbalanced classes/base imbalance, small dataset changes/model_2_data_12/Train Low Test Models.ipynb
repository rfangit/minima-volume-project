# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
    prepare_class_imbalanced_dataset,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 12            
model_seed = 2           

# --- Training configuration ---
epochs = 500            

# --- Dataset configuration ---
base_data_size = 1500      
dataset_type = "data"   
dataset_quantities = [0, 2000 - 1500, 3000 - 1500, 6000 - 1500, 10000 - 1500]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import MNIST_model_data as model_module

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device = device
)

# MNIST specific initialization parameters
hidden_dims = [256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_class_imbalanced_dataset(
    x_base=x_base,
    y_base=y_base,
    target_labels = [0, 1],
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    target_ratio=0.9,
    data_seed=data_seed,
    seed_1=None,
    additional_imbalanced = False,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/500: Train Loss 2.2473 | Test Loss 2.2643 | accs Train 0.2840 Test 0.2104
# Epoch 100/500: Train Loss 0.0033 | Test Loss 1.0933 | accs Train 1.0000 Test 0.7377
# Epoch 200/500: Train Loss 0.0004 | Test Loss 1.2688 | accs Train 1.0000 Test 0.7380
# Epoch 300/500: Train Loss 0.0002 | Test Loss 1.3514 | accs Train 1.0000 Test 0.7387
# Epoch 400/500: Train Loss 0.0001 | Test Loss 1.4083 | accs Train 1.0000 Test 0.7397
# Epoch 500/500: Train Loss 0.0001 | Test Loss 1.4530 | accs Train 1.0000 Test 0.7394
# Completed training with 0 additional samples of data
# Epoch 1/500: Train Loss 2.2612 | Test Loss 2.2451 | accs Train 0.2550 Test 0.2102
# Epoch 100/500: Train Loss 0.0067 | Test Loss 0.5310 | accs Train 1.0000 Test 0.8624
# Epoch 200/500: Train Loss 0.0009 | Test Loss 0.6160 | accs Train 1.0000 Test 0.8673
# Epoch 300/500: Train Loss 0.0004 | Test Loss 0.6562 | accs Train 1.0000 Test 0.8683
# Epoch 400/500: Train Loss 0.0002 | Test Loss 0.6837 | accs Train 1.0000 Test 0.8691
# Epoch 500/500: Train Loss 0.0001 | Test Loss 0.7063 | accs Train 1.0000 Test 0.8698
# Completed training with 500 additional samples of data
# Epoch 1/500: Train Loss 2.2759 | Test Loss 2.2187 | accs Train 0.2160 Test 0.2101
# Epoch 100/500: Train Loss 0.0134 | Test Loss 0.3662 | accs Train 0.9990 Test 0.9031
# Epoch 200/500: Train Loss 0.0015 | Test Loss 0.4203 | accs Train 1.0000 Test 0.9078
# Epoch 300/500: Train Loss 0.0006 | Test Loss 0.4480 | accs Train 1.0000 Test 0.9092
# Epoch 400/500: Train Loss 0.0003 | Test Loss 0.4666 | accs Train 1.0000 Test 0.9105
# Epoch 500/500: Train Loss 0.0002 | Test Loss 0.4810 | accs Train 1.0000 Test 0.9109
# Completed training with 1500 additional samples of data
# Epoch 1/500: Train Loss 2.2891 | Test Loss 2.1853 | accs Train 0.1803 Test 0.2242
# Epoch 100/500: Train Loss 0.0312 | Test Loss 0.2416 | accs Train 0.9962 Test 0.9352
# Epoch 200/500: Train Loss 0.0022 | Test Loss 0.2841 | accs Train 1.0000 Test 0.9386
# Epoch 300/500: Train Loss 0.0007 | Test Loss 0.3134 | accs Train 1.0000 Test 0.9394
# Epoch 400/500: Train Loss 0.0004 | Test Loss 0.3328 | accs Train 1.0000 Test 0.9403
# Epoch 500/500: Train Loss 0.0002 | Test Loss 0.3474 | accs Train 1.0000 Test 0.9395
# Completed training with 4500 additional samples of data
# Epoch 1/500: Train Loss 2.2955 | Test Loss 2.1674 | accs Train 0.1664 Test 0.3035
# Epoch 100/500: Train Loss 0.0572 | Test Loss 0.1782 | accs Train 0.9888 Test 0.9463
# Epoch 200/500: Train Loss 0.0043 | Test Loss 0.1990 | accs Train 0.9999 Test 0.9528
# Epoch 300/500: Train Loss 0.0013 | Test Loss 0.2208 | accs Train 1.0000 Test 0.9535
# Epoch 400/500: Train Loss 0.0006 | Test Loss 0.2350 | accs Train 1.0000 Test 0.9544
# Epoch 500/500: Train Loss 0.0004 | Test Loss 0.2459 | accs Train 1.0000 Test 0.9545
# Completed training with 8500 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 1.4530 | accs: 0.7394
#  500 samples | Test Loss: 0.7063 | accs: 0.8698
# 1500 samples | Test Loss: 0.4810 | accs: 0.9109
# 4500 samples | Test Loss: 0.3474 | accs: 0.9395
# 8500 samples | Test Loss: 0.2459 | accs: 0.9545
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0001 | accs: 1.0000
#  Model  500 | Train Loss: 0.0001 | accs: 1.0000
#  Model 1500 | Train Loss: 0.0001 | accs: 1.0000
#  Model 4500 | Train Loss: 0.0001 | accs: 1.0000
#  Model 8500 | Train Loss: 0.0002 | accs: 1.0000
#
# Dataset type: data, additional samples: 500
#  Model    0 | Train Loss: 0.4133 | accs: 0.9325
#  Model  500 | Train Loss: 0.0001 | accs: 1.0000
#  Model 1500 | Train Loss: 0.0002 | accs: 1.0000
#  Model 4500 | Train Loss: 0.0002 | accs: 1.0000
#  Model 8500 | Train Loss: 0.0003 | accs: 1.0000
#
# Dataset type: data, additional samples: 1500
#  Model    0 | Train Loss: 0.8078 | accs: 0.8643
#  Model  500 | Train Loss: 0.2415 | accs: 0.9570
#  Model 1500 | Train Loss: 0.0002 | accs: 1.0000
#  Model 4500 | Train Loss: 0.0002 | accs: 1.0000
#  Model 8500 | Train Loss: 0.0003 | accs: 1.0000
#
# Dataset type: data, additional samples: 4500
#  Model    0 | Train Loss: 1.1702 | accs: 0.8012
#  Model  500 | Train Loss: 0.4666 | accs: 0.9115
#  Model 1500 | Train Loss: 0.2350 | accs: 0.9582
#  Model 4500 | Train Loss: 0.0002 | accs: 1.0000
#  Model 8500 | Train Loss: 0.0004 | accs: 1.0000
#
# Dataset type: data, additional samples: 8500
#  Model    0 | Train Loss: 1.3365 | accs: 0.7698
#  Model  500 | Train Loss: 0.5880 | accs: 0.8920
#  Model 1500 | Train Loss: 0.3612 | accs: 0.9373
#  Model 4500 | Train Loss: 0.1670 | accs: 0.9749
#  Model 8500 | Train Loss: 0.0004 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_500.pt
# Saved model: models_and_data/model_additional_500.pt
# ✅ Model saved to models_and_data\model_additional_1500.pt
# Saved model: models_and_data/model_additional_1500.pt
# ✅ Model saved to models_and_data\model_additional_4500.pt
# Saved model: models_and_data/model_additional_4500.pt
# ✅ Model saved to models_and_data\model_additional_8500.pt
# Saved model: models_and_data/model_additional_8500.pt
