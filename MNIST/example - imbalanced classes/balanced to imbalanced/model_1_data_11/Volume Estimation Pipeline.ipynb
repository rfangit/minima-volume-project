# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.05, 0.02]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}"
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['data_0', 'data_1500', 'data_4500', 'data_500', 'data_8500']
#
# ==================================================
# Analyzing directory: data_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from data_0
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_0: 0.00019018595048692077
# data_1500: 0.0003655378823168576
# data_4500: 0.000512081547640264
# data_500: 0.00023654683900531381
# data_8500: 0.0007404134958051145
#
# Top perturbations for data_0:
# Top 5 r_vals: [30.941555979494883, 30.88784234862634, 28.598857897153355, 28.55053374655648, 28.54866491620753]
# Top 5 seeds: [18, 14, 419, 478, 432]
#
# Top perturbations for data_1500:
# Top 5 r_vals: [28.50473305498164, 28.495668689738295, 28.489958175505052, 28.43776185146924, 26.26527053401758]
# Top 5 seeds: [356, 262, 8, 56, 419]
#
# Top perturbations for data_4500:
# Top 5 r_vals: [24.030984760802472, 24.009453667534725, 23.98359435281636, 23.956246081693674, 23.946412639853396]
# Top 5 seeds: [419, 472, 373, 223, 135]
#
# Top perturbations for data_500:
# Top 5 r_vals: [30.88784234862634, 28.598857897153355, 28.55053374655648, 28.53857108011938, 28.53512217343894]
# Top 5 seeds: [14, 419, 478, 391, 221]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [21.860945408228236, 21.847202914039187, 21.84182565512189, 21.841364276420098, 21.837663634749486]
# Top 5 seeds: [424, 221, 66, 330, 48]
# Plot saved to: data_0/loss_0.1/log_volume.png
# Test loss  [0.6335680991411209, 0.4904277384281158, 0.4019420802593231, 0.5360201001167297, 0.3323042392730713]
# log_exp_r_n  [807038.4035257458, 787749.3798469908, 747603.816525246, 806629.842259966, 725349.0584253005]
# Plot saved to: data_0/loss_0.1/gen_log_volume.png
# Plot saved to: data_0/loss_0.1/test_vs_data.png
# Plot saved to: data_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.95/avg_radius.png
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: divide by zero encountered in divide
#   return n/db/n.sum(), bin_edges
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Plot saved to: data_0/acc_0.95/radius_hist.png
# Plot saved to: data_0/acc_0.95/log_volume.png
# Plot saved to: data_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 3, 2, 4, 1]
# test_loss ranks: [1, 3, 4, 2, 5]
# log_exp_r_n ranks: [1, 3, 4, 2, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.1\results.json
# Successfully analyzed data_0 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from data_0
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_0: 0.00019018595048692077
# data_1500: 0.0003655378823168576
# data_4500: 0.000512081547640264
# data_500: 0.00023654683900531381
# data_8500: 0.0007404134958051145
#
# Top perturbations for data_0:
# Top 5 r_vals: [26.2099029537902, 26.18893298104447, 26.144299931677498, 26.143469763877338, 26.096654229718276]
# Top 5 seeds: [391, 18, 236, 14, 294]
#
# Top perturbations for data_1500:
# Top 5 r_vals: [26.17882601750918, 24.009453667534725, 23.990379050925927, 23.970079210069446, 23.956919728973766]
# Top 5 seeds: [356, 472, 478, 328, 321]
#
# Top perturbations for data_4500:
# Top 5 r_vals: [21.896000577508037, 21.806166299446886, 21.777790136135863, 19.842523692177462, 19.832166211116856]
# Top 5 seeds: [419, 271, 162, 472, 31]
#
# Top perturbations for data_500:
# Top 5 r_vals: [26.187392888002506, 26.143469763877338, 26.123471614548468, 26.11766373426401, 24.030984760802472]
# Top 5 seeds: [153, 14, 162, 481, 419]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [19.789728686804924, 19.754116438612776, 17.913450688102422, 17.90147952120738, 17.895241025783207]
# Top 5 seeds: [127, 244, 173, 7, 424]
# Plot saved to: data_0/loss_0.05/log_volume.png
# Test loss  [0.6335680991411209, 0.4904277384281158, 0.4019420802593231, 0.5360201001167297, 0.3323042392730713]
# log_exp_r_n  [768012.9103914961, 767733.9336627465, 725725.8253322811, 767810.8712530136, 701942.9359259987]
# Plot saved to: data_0/loss_0.05/gen_log_volume.png
# Plot saved to: data_0/loss_0.05/test_vs_data.png
# Plot saved to: data_0/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.9/avg_radius.png
# Plot saved to: data_0/acc_0.9/radius_hist.png
# Plot saved to: data_0/acc_0.9/log_volume.png
# Plot saved to: data_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 3, 2, 4, 1]
# test_loss ranks: [1, 3, 4, 2, 5]
# log_exp_r_n ranks: [1, 3, 4, 2, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.05\results.json
# Successfully analyzed data_0 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 5 models from data_0
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_0: 0.00019018595048692077
# data_1500: 0.0003655378823168576
# data_4500: 0.000512081547640264
# data_500: 0.00023654683900531381
# data_8500: 0.0007404134958051145
#
# Top perturbations for data_0:
# Top 5 r_vals: [21.891642196557193, 21.8498434832164, 21.832361899131588, 21.81263109387555, 21.79515362924343]
# Top 5 seeds: [333, 391, 18, 73, 236]
#
# Top perturbations for data_1500:
# Top 5 r_vals: [21.823936245220317, 19.842523692177462, 19.82675954621978, 19.81076124845361, 19.80259582687673]
# Top 5 seeds: [356, 472, 478, 330, 18]
#
# Top perturbations for data_4500:
# Top 5 r_vals: [17.923936980681184, 17.850399170295525, 17.82717061030623, 16.07244419066374, 16.064054631004648]
# Top 5 seeds: [419, 271, 162, 472, 31]
#
# Top perturbations for data_500:
# Top 5 r_vals: [21.859002399707304, 21.832361899131588, 21.831078003041785, 21.794461561190744, 21.777790136135863]
# Top 5 seeds: [478, 18, 153, 14, 162]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [16.029680236311982, 16.000834315276343, 14.34068489989363, 14.331101334152171, 14.326107081582679]
# Top 5 seeds: [127, 244, 173, 7, 424]
# Plot saved to: data_0/loss_0.02/log_volume.png
# Test loss  [0.6335680991411209, 0.4904277384281158, 0.4019420802593231, 0.5360201001167297, 0.3323042392730713]
# log_exp_r_n  [725679.0150549733, 724950.6341468188, 678657.3754406006, 725328.1576372222, 652392.7282962481]
# Plot saved to: data_0/loss_0.02/gen_log_volume.png
# Plot saved to: data_0/loss_0.02/test_vs_data.png
# Plot saved to: data_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 3, 2, 4, 1]
# test_loss ranks: [1, 3, 4, 2, 5]
# log_exp_r_n ranks: [1, 3, 4, 2, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.02\results.json
# Successfully analyzed data_0 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_1500
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 3 models from data_1500
# The number of model parameters is  235146
# The loss landscape is for data trained with 1500
# data_1500: 0.0002651736722327769
# data_4500: 0.00035954127088189125
# data_8500: 0.0005024871206842363
#
# Top perturbations for data_1500:
# Top 5 r_vals: [30.92961486000612, 28.598857897153355, 28.55053374655648, 28.53857108011938, 28.526375258264466]
# Top 5 seeds: [356, 419, 478, 391, 328]
#
# Top perturbations for data_4500:
# Top 5 r_vals: [26.26527053401758, 26.241737582904694, 26.213473993057555, 26.164960238656498, 26.157510141513388]
# Top 5 seeds: [419, 472, 373, 10, 271]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [23.97742904851466, 23.9715274763696, 23.966959635416668, 23.946524160879633, 23.945571711033953]
# Top 5 seeds: [221, 66, 48, 403, 127]
# Plot saved to: data_1500/loss_0.1/log_volume.png
# Test loss  [0.4904277384281158, 0.4019420802593231, 0.3323042392730713]
# log_exp_r_n  [806947.6372939106, 768509.1248482087, 747079.1827893513]
# Plot saved to: data_1500/loss_0.1/gen_log_volume.png
# Plot saved to: data_1500/loss_0.1/test_vs_data.png
# Plot saved to: data_1500/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_1500/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_1500/acc_0.95/avg_radius.png
# Plot saved to: data_1500/acc_0.95/radius_hist.png
# Plot saved to: data_1500/acc_0.95/log_volume.png
# Plot saved to: data_1500/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [1, 2, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_1500/loss_0.1\results.json
# Successfully analyzed data_1500 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_1500
# The number of model parameters is  235146
# The loss landscape is for data trained with 1500
# data_1500: 0.0002651736722327769
# data_4500: 0.00035954127088189125
# data_8500: 0.0005024871206842363
#
# Top perturbations for data_1500:
# Top 5 r_vals: [26.18431929055191, 26.17882601750918, 24.030984760802472, 23.995121708622687, 23.990379050925927]
# Top 5 seeds: [321, 356, 419, 383, 478]
#
# Top perturbations for data_4500:
# Top 5 r_vals: [21.896000577508037, 21.87638237062565, 21.852820474363668, 21.835575072233343, 21.806166299446886]
# Top 5 seeds: [419, 472, 373, 476, 271]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [19.82852191222516, 19.816057064888156, 19.811179732536864, 19.80740465736915, 19.790975420636293]
# Top 5 seeds: [424, 221, 66, 48, 282]
# Plot saved to: data_1500/loss_0.05/log_volume.png
# Test loss  [0.4904277384281158, 0.4019420802593231, 0.3323042392730713]
# log_exp_r_n  [767783.2706985584, 725725.8253322811, 702403.43453773]
# Plot saved to: data_1500/loss_0.05/gen_log_volume.png
# Plot saved to: data_1500/loss_0.05/test_vs_data.png
# Plot saved to: data_1500/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_1500/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_1500/acc_0.9/avg_radius.png
# Plot saved to: data_1500/acc_0.9/radius_hist.png
# Plot saved to: data_1500/acc_0.9/log_volume.png
# Plot saved to: data_1500/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [1, 2, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_1500/loss_0.05\results.json
# Successfully analyzed data_1500 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_1500
# The number of model parameters is  235146
# The loss landscape is for data trained with 1500
# data_1500: 0.0002651736722327769
# data_4500: 0.00035954127088189125
# data_8500: 0.0005024871206842363
#
# Top perturbations for data_1500:
# Top 5 r_vals: [23.951893747588738, 21.82851570346577, 19.860317984134277, 19.830679098035283, 19.82675954621978]
# Top 5 seeds: [356, 321, 419, 383, 478]
#
# Top perturbations for data_4500:
# Top 5 r_vals: [17.923936980681184, 17.888590002823776, 17.874473018313466, 17.850399170295525, 17.8434862429336]
# Top 5 seeds: [419, 373, 476, 271, 227]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [16.061102748902375, 16.047055583354854, 16.04399777246901, 16.030690090715392, 16.030317826704547]
# Top 5 seeds: [424, 66, 48, 282, 403]
# Plot saved to: data_1500/loss_0.02/log_volume.png
# Test loss  [0.4904277384281158, 0.4019420802593231, 0.3323042392730713]
# log_exp_r_n  [746828.6253397838, 678657.3754406006, 652853.2269079795]
# Plot saved to: data_1500/loss_0.02/gen_log_volume.png
# Plot saved to: data_1500/loss_0.02/test_vs_data.png
# Plot saved to: data_1500/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_1500/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_1500/acc_0.85/avg_radius.png
# Plot saved to: data_1500/acc_0.85/radius_hist.png
# Plot saved to: data_1500/acc_0.85/log_volume.png
# Plot saved to: data_1500/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [1, 2, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_1500/loss_0.02\results.json
# Successfully analyzed data_1500 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_4500
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_4500
# The number of model parameters is  235146
# The loss landscape is for data trained with 4500
# data_4500: 0.0002821396046783775
# data_8500: 0.0003981101035606116
#
# Top perturbations for data_4500:
# Top 5 r_vals: [28.598857897153355, 28.48963534492654, 28.48152332988981, 28.438136693640956, 26.241737582904694]
# Top 5 seeds: [419, 10, 271, 481, 472]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [26.1952926593707, 26.17295719236638, 26.168101369598773, 24.009453667534725, 23.99251151379244]
# Top 5 seeds: [48, 403, 485, 472, 424]
# Plot saved to: data_4500/loss_0.1/log_volume.png
# Test loss  [0.4019420802593231, 0.3323042392730713]
# log_exp_r_n  [788524.5710324531, 767881.7954384697]
# Plot saved to: data_4500/loss_0.1/gen_log_volume.png
# Plot saved to: data_4500/loss_0.1/test_vs_data.png
# Plot saved to: data_4500/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_4500/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_4500/acc_0.95/avg_radius.png
# Plot saved to: data_4500/acc_0.95/radius_hist.png
# Plot saved to: data_4500/acc_0.95/log_volume.png
# Plot saved to: data_4500/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_4500/loss_0.1\results.json
# Successfully analyzed data_4500 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_4500
# The number of model parameters is  235146
# The loss landscape is for data trained with 4500
# data_4500: 0.0002821396046783775
# data_8500: 0.0003981101035606116
#
# Top perturbations for data_4500:
# Top 5 r_vals: [24.030984760802472, 23.939207477334108, 23.932391131365744, 23.895934305073304, 21.87638237062565]
# Top 5 seeds: [419, 10, 271, 481, 472]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [21.84182565512189, 21.837663634749486, 21.819043708570078, 21.818175877202425, 21.814995659722225]
# Top 5 seeds: [66, 48, 403, 127, 485]
# Plot saved to: data_4500/loss_0.05/log_volume.png
# Test loss  [0.4019420802593231, 0.3323042392730713]
# log_exp_r_n  [747603.816525246, 725143.3079137701]
# Plot saved to: data_4500/loss_0.05/gen_log_volume.png
# Plot saved to: data_4500/loss_0.05/test_vs_data.png
# Plot saved to: data_4500/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_4500/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_4500/acc_0.9/avg_radius.png
# Plot saved to: data_4500/acc_0.9/radius_hist.png
# Plot saved to: data_4500/acc_0.9/log_volume.png
# Plot saved to: data_4500/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_4500/loss_0.05\results.json
# Successfully analyzed data_4500 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_4500
# The number of model parameters is  235146
# The loss landscape is for data trained with 4500
# data_4500: 0.0002821396046783775
# data_8500: 0.0003981101035606116
#
# Top perturbations for data_4500:
# Top 5 r_vals: [19.778835645756818, 17.923936980681184, 17.907877632190157, 17.89853000553296, 17.89415743846989]
# Top 5 seeds: [271, 419, 472, 31, 329]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [17.876182703275656, 17.860940541482538, 17.86023013984144, 17.85762683256173, 16.069752590715392]
# Top 5 seeds: [48, 403, 127, 485, 242]
# Plot saved to: data_4500/loss_0.02/log_volume.png
# Test loss  [0.4019420802593231, 0.3323042392730713]
# log_exp_r_n  [701813.4667305294, 678030.0460308617]
# Plot saved to: data_4500/loss_0.02/gen_log_volume.png
# Plot saved to: data_4500/loss_0.02/test_vs_data.png
# Plot saved to: data_4500/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_4500/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_4500/acc_0.85/avg_radius.png
# Plot saved to: data_4500/acc_0.85/radius_hist.png
# Plot saved to: data_4500/acc_0.85/log_volume.png
# Plot saved to: data_4500/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_4500/loss_0.02\results.json
# Successfully analyzed data_4500 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_500
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from data_500
# The number of model parameters is  235146
# The loss landscape is for data trained with 500
# data_1500: 0.0003255559131503105
# data_4500: 0.00044745783088728786
# data_500: 0.00021442142315208912
# data_8500: 0.0006348109454847872
#
# Top perturbations for data_1500:
# Top 5 r_vals: [28.55053374655648, 28.510714388200185, 28.50473305498164, 28.498342803030305, 28.495668689738295]
# Top 5 seeds: [478, 321, 356, 403, 262]
#
# Top perturbations for data_4500:
# Top 5 r_vals: [26.26527053401758, 26.157510141513388, 24.009453667534725, 23.99692111545139, 23.98359435281636]
# Top 5 seeds: [419, 271, 472, 31, 373]
#
# Top perturbations for data_500:
# Top 5 r_vals: [30.864215045544025, 28.598857897153355, 28.55053374655648, 28.54866491620753, 28.53857108011938]
# Top 5 seeds: [162, 419, 478, 432, 391]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [23.94208140432099, 21.883190452778855, 21.87638237062565, 21.860945408228236, 21.852820474363668]
# Top 5 seeds: [485, 173, 472, 424, 373]
# Plot saved to: data_500/loss_0.1/log_volume.png
# Test loss  [0.4904277384281158, 0.4019420802593231, 0.5360201001167297, 0.3323042392730713]
# log_exp_r_n  [788126.9033373941, 768509.1248482087, 806449.9011756958, 746732.2736256068]
# Plot saved to: data_500/loss_0.1/gen_log_volume.png
# Plot saved to: data_500/loss_0.1/test_vs_data.png
# Plot saved to: data_500/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_500/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_500/acc_0.95/avg_radius.png
# Plot saved to: data_500/acc_0.95/radius_hist.png
# Plot saved to: data_500/acc_0.95/log_volume.png
# Plot saved to: data_500/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 4, 1]
# test_loss ranks: [2, 3, 1, 4]
# log_exp_r_n ranks: [2, 3, 1, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_500/loss_0.1\results.json
# Successfully analyzed data_500 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from data_500
# The number of model parameters is  235146
# The loss landscape is for data trained with 500
# data_1500: 0.0003255559131503105
# data_4500: 0.00044745783088728786
# data_500: 0.00021442142315208912
# data_8500: 0.0006348109454847872
#
# Top perturbations for data_1500:
# Top 5 r_vals: [26.17882601750918, 24.030984760802472, 24.009453667534725, 23.995121708622687, 23.990379050925927]
# Top 5 seeds: [356, 419, 472, 383, 478]
#
# Top perturbations for data_4500:
# Top 5 r_vals: [21.896000577508037, 21.852820474363668, 21.806166299446886, 21.777790136135863, 19.842523692177462]
# Top 5 seeds: [419, 373, 271, 162, 472]
#
# Top perturbations for data_500:
# Top 5 r_vals: [26.2099029537902, 26.187392888002506, 26.15733060125502, 26.123471614548468, 26.11766373426401]
# Top 5 seeds: [391, 153, 462, 162, 481]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [19.82852191222516, 19.80740465736915, 19.789728686804924, 19.786844135802475, 17.913450688102422]
# Top 5 seeds: [424, 48, 127, 485, 173]
# Plot saved to: data_500/loss_0.05/log_volume.png
# Test loss  [0.4904277384281158, 0.4019420802593231, 0.5360201001167297, 0.3323042392730713]
# log_exp_r_n  [767733.9336627465, 725725.8253322811, 768012.9103914961, 702403.43453773]
# Plot saved to: data_500/loss_0.05/gen_log_volume.png
# Plot saved to: data_500/loss_0.05/test_vs_data.png
# Plot saved to: data_500/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_500/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_500/acc_0.9/avg_radius.png
# Plot saved to: data_500/acc_0.9/radius_hist.png
# Plot saved to: data_500/acc_0.9/log_volume.png
# Plot saved to: data_500/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 4, 1]
# test_loss ranks: [2, 3, 1, 4]
# log_exp_r_n ranks: [2, 3, 1, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_500/loss_0.05\results.json
# Successfully analyzed data_500 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from data_500
# The number of model parameters is  235146
# The loss landscape is for data trained with 500
# data_1500: 0.0003255559131503105
# data_4500: 0.00044745783088728786
# data_500: 0.00021442142315208912
# data_8500: 0.0006348109454847872
#
# Top perturbations for data_1500:
# Top 5 r_vals: [21.823936245220317, 19.860317984134277, 19.842523692177462, 19.830679098035283, 19.82675954621978]
# Top 5 seeds: [356, 419, 472, 383, 478]
#
# Top perturbations for data_4500:
# Top 5 r_vals: [17.923936980681184, 17.850399170295525, 16.07244419066374, 16.064054631004648, 16.061174376936982]
# Top 5 seeds: [419, 271, 472, 31, 435]
#
# Top perturbations for data_500:
# Top 5 r_vals: [21.8498434832164, 21.832361899131588, 21.831078003041785, 21.806016625998986, 21.777790136135863]
# Top 5 seeds: [391, 18, 153, 462, 162]
#
# Top perturbations for data_8500:
# Top 5 r_vals: [16.061102748902375, 16.04399777246901, 16.030690090715392, 16.029680236311982, 14.34068489989363]
# Top 5 seeds: [424, 48, 282, 127, 173]
# Plot saved to: data_500/loss_0.02/log_volume.png
# Test loss  [0.4904277384281158, 0.4019420802593231, 0.5360201001167297, 0.3323042392730713]
# log_exp_r_n  [724950.6341468188, 678657.3754406006, 725229.6108755685, 652853.2269079795]
# Plot saved to: data_500/loss_0.02/gen_log_volume.png
# Plot saved to: data_500/loss_0.02/test_vs_data.png
# Plot saved to: data_500/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_500/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_500/acc_0.85/avg_radius.png
# Plot saved to: data_500/acc_0.85/radius_hist.png
# Plot saved to: data_500/acc_0.85/log_volume.png
# Plot saved to: data_500/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 4, 1]
# test_loss ranks: [2, 3, 1, 4]
# log_exp_r_n ranks: [2, 3, 1, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_500/loss_0.02\results.json
# Successfully analyzed data_500 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_8500
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_8500
# The number of model parameters is  235146
# The loss landscape is for data trained with 8500
# data_8500: 0.00033969461219385266
#
# Top perturbations for data_8500:
# Top 5 r_vals: [28.498342803030305, 26.223220228917775, 26.206735468314584, 26.200285196280003, 26.1978622263712]
# Top 5 seeds: [403, 424, 221, 66, 205]
# Plot saved to: data_8500/loss_0.1/log_volume.png
# Test loss  [0.3323042392730713]
# log_exp_r_n  [787696.6584045414]
# Plot saved to: data_8500/loss_0.1/gen_log_volume.png
# Plot saved to: data_8500/loss_0.1/test_vs_data.png
# Plot saved to: data_8500/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_8500/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_8500/acc_0.95/avg_radius.png
# Plot saved to: data_8500/acc_0.95/radius_hist.png
# Plot saved to: data_8500/acc_0.95/log_volume.png
# Plot saved to: data_8500/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_8500/loss_0.1\results.json
# Successfully analyzed data_8500 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 1 models from data_8500
# The number of model parameters is  235146
# The loss landscape is for data trained with 8500
# data_8500: 0.00033969461219385266
#
# Top perturbations for data_8500:
# Top 5 r_vals: [23.946524160879633, 21.860945408228236, 21.847202914039187, 21.84182565512189, 21.839805750150656]
# Top 5 seeds: [403, 424, 221, 66, 205]
# Plot saved to: data_8500/loss_0.05/log_volume.png
# Test loss  [0.3323042392730713]
# log_exp_r_n  [746775.9038973345]
# Plot saved to: data_8500/loss_0.05/gen_log_volume.png
# Plot saved to: data_8500/loss_0.05/test_vs_data.png
# Plot saved to: data_8500/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_8500/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_8500/acc_0.9/avg_radius.png
# Plot saved to: data_8500/acc_0.9/radius_hist.png
# Plot saved to: data_8500/acc_0.9/log_volume.png
# Plot saved to: data_8500/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_8500/loss_0.05\results.json
# Successfully analyzed data_8500 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 1 models from data_8500
# The number of model parameters is  235146
# The loss landscape is for data trained with 8500
# data_8500: 0.00033969461219385266
#
# Top perturbations for data_8500:
# Top 5 r_vals: [17.879589708614517, 17.876182703275656, 17.860940541482538, 17.86023013984144, 17.85762683256173]
# Top 5 seeds: [66, 48, 403, 127, 485]
# Plot saved to: data_8500/loss_0.02/log_volume.png
# Test loss  [0.3323042392730713]
# log_exp_r_n  [678074.8580220897]
# Plot saved to: data_8500/loss_0.02/gen_log_volume.png
# Plot saved to: data_8500/loss_0.02/test_vs_data.png
# Plot saved to: data_8500/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_8500/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_8500/acc_0.85/avg_radius.png
# Plot saved to: data_8500/acc_0.85/radius_hist.png
# Plot saved to: data_8500/acc_0.85/log_volume.png
# Plot saved to: data_8500/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_8500/loss_0.02\results.json
# Successfully analyzed data_8500 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
