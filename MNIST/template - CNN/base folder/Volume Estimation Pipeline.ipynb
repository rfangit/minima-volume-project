# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.05, 0.02]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}"
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['data_0', 'data_540', 'data_5940']
#
# ==================================================
# Analyzing directory: data_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from data_0
# The number of model parameters is  1625866
# The loss landscape is for data trained with 0
# data_0: 1.117947067541536e-05
# data_540: 0.0004967606510035694
# data_5940: 0.00013833357661496848
# data_59940: 1.1563212183318683e-06
#
# Top perturbations for data_0:
# Top 5 r_vals: [94.78460945570767, 87.97278323999147, 81.28998827148538, 81.2472524527153, 74.95359131083563]
# Top 5 seeds: [4, 41, 29, 26, 31]
#
# Top perturbations for data_540:
# Top 5 r_vals: [62.929699556327165, 52.07665751581473, 47.00015009380023, 46.97004794831204, 46.951874255696175]
# Top 5 seeds: [4, 11, 21, 32, 8]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [62.93666811342593, 62.929699556327165, 57.41147750139894, 57.38082877335142, 52.01197183323132]
# Top 5 seeds: [44, 4, 45, 5, 36]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [52.04892298139222, 52.02129306799053, 52.01377530035202, 52.01197183323132, 52.010751254655155]
# Top 5 seeds: [22, 43, 44, 36, 49]
# Plot saved to: data_0/loss_0.1/log_volume.png
# Test loss  [2.44683859449625, 0.5908902212977409, 0.13253154902458192, 0.06324651592969895]
# log_exp_r_n  [7400299.233603339, 6734362.688581093, 6734542.719836102, 6425717.846536023]
# Plot saved to: data_0/loss_0.1/gen_log_volume.png
# Plot saved to: data_0/loss_0.1/test_vs_data.png
# Plot saved to: data_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.95/avg_radius.png
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: divide by zero encountered in divide
#   return n/db/n.sum(), bin_edges
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Plot saved to: data_0/acc_0.95/radius_hist.png
# Plot saved to: data_0/acc_0.95/log_volume.png
# Plot saved to: data_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 1]
# test_loss ranks: [1, 2, 3, 4]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.1\results.json
# Successfully analyzed data_0 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from data_0
# The number of model parameters is  1625866
# The loss landscape is for data trained with 0
# data_0: 1.117947067541536e-05
# data_540: 0.0004967606510035694
# data_5940: 0.00013833357661496848
# data_59940: 1.1563212183318683e-06
#
# Top perturbations for data_0:
# Top 5 r_vals: [87.89354731420903, 81.33578332099803, 81.28998827148538, 74.95359131083563, 74.91955061983472]
# Top 5 seeds: [4, 41, 29, 31, 2]
#
# Top perturbations for data_540:
# Top 5 r_vals: [52.00801616225387, 46.99918340802279, 42.18296019498967, 42.15594331095041, 42.139632295971076]
# Top 5 seeds: [4, 11, 21, 32, 8]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [57.34518726863809, 57.338837818884876, 52.07390249559995, 52.04610319578361, 42.18209258780992]
# Top 5 seeds: [44, 4, 45, 5, 11]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [52.04892298139222, 46.94921699386145, 46.942432208567695, 46.940804579491264, 46.93970300732627]
# Top 5 seeds: [22, 43, 44, 36, 49]
# Plot saved to: data_0/loss_0.05/log_volume.png
# Test loss  [2.44683859449625, 0.5908902212977409, 0.13253154902458192, 0.06324651592969895]
# log_exp_r_n  [7277577.80141102, 6424439.526985616, 6583272.096355621, 6425717.846536023]
# Plot saved to: data_0/loss_0.05/gen_log_volume.png
# Plot saved to: data_0/loss_0.05/test_vs_data.png
# Plot saved to: data_0/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.9/avg_radius.png
# Plot saved to: data_0/acc_0.9/radius_hist.png
# Plot saved to: data_0/acc_0.9/log_volume.png
# Plot saved to: data_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 1]
# test_loss ranks: [1, 2, 3, 4]
# log_exp_r_n ranks: [1, 4, 2, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.05\results.json
# Successfully analyzed data_0 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from data_0
# The number of model parameters is  1625866
# The loss landscape is for data trained with 0
# data_0: 1.117947067541536e-05
# data_540: 0.0004967606510035694
# data_5940: 0.00013833357661496848
# data_59940: 1.1563212183318683e-06
#
# Top perturbations for data_0:
# Top 5 r_vals: [81.26252525352166, 74.95905790863178, 74.91685319100092, 68.83758646429176, 68.80632339911905]
# Top 5 seeds: [4, 41, 29, 31, 2]
#
# Top perturbations for data_540:
# Top 5 r_vals: [42.18209258780992, 42.12649309142562, 37.60206054587862, 37.58751152325816, 37.58132764872527]
# Top 5 seeds: [11, 4, 32, 8, 46]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [52.01377530035202, 52.00801616225387, 46.99669700227896, 46.9716081341947, 37.58302299500291]
# Top 5 seeds: [44, 4, 45, 5, 40]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [46.94921699386145, 46.942432208567695, 42.18046632877066, 42.159627614927686, 42.129697184917354]
# Top 5 seeds: [43, 44, 10, 22, 36]
# Plot saved to: data_0/loss_0.02/log_volume.png
# Test loss  [2.44683859449625, 0.5908902212977409, 0.13253154902458192, 0.06324651592969895]
# log_exp_r_n  [7150042.5533876745, 6083979.806498488, 6424619.558240626, 6258062.487701064]
# Plot saved to: data_0/loss_0.02/gen_log_volume.png
# Plot saved to: data_0/loss_0.02/test_vs_data.png
# Plot saved to: data_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 1]
# test_loss ranks: [1, 2, 3, 4]
# log_exp_r_n ranks: [1, 4, 2, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.02\results.json
# Successfully analyzed data_0 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_540
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 3 models from data_540
# The number of model parameters is  1625866
# The loss landscape is for data trained with 540
# data_540: 0.0003585658851079643
# data_5940: 9.710447193356231e-05
# data_59940: 3.643031277533737e-06
#
# Top perturbations for data_540:
# Top 5 r_vals: [52.04892298139222, 52.044374457963485, 52.01567840654016, 52.00801616225387, 47.00015009380023]
# Top 5 seeds: [22, 32, 46, 4, 21]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [52.07390249559995, 52.04610319578361, 52.01377530035202, 52.01197183323132, 52.00928157841038]
# Top 5 seeds: [45, 5, 44, 36, 3]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [46.97415299070647, 46.942432208567695, 46.93970300732627, 42.18209258780992, 42.179861021435954]
# Top 5 seeds: [22, 44, 49, 11, 45]
# Plot saved to: data_540/loss_0.1/log_volume.png
# Test loss  [0.5908902212977409, 0.13253154902458192, 0.06324651592969895]
# log_exp_r_n  [6425717.846536023, 6426497.951060463, 6258925.799790604]
# Plot saved to: data_540/loss_0.1/gen_log_volume.png
# Plot saved to: data_540/loss_0.1/test_vs_data.png
# Plot saved to: data_540/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_540/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_540/acc_0.95/avg_radius.png
# Plot saved to: data_540/acc_0.95/radius_hist.png
# Plot saved to: data_540/acc_0.95/log_volume.png
# Plot saved to: data_540/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_540/loss_0.1\results.json
# Successfully analyzed data_540 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_540
# The number of model parameters is  1625866
# The loss landscape is for data trained with 540
# data_540: 0.0003585658851079643
# data_5940: 9.710447193356231e-05
# data_59940: 3.643031277533737e-06
#
# Top perturbations for data_540:
# Top 5 r_vals: [46.97415299070647, 46.944149761902494, 46.93723458643411, 42.176083903667354, 42.15594331095041]
# Top 5 seeds: [22, 46, 4, 15, 32]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [46.99669700227896, 46.9716081341947, 46.938376624515364, 46.93723458643411, 42.15594331095041]
# Top 5 seeds: [45, 5, 3, 4, 32]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [42.1318359375, 42.13115799328512, 37.62538505517614, 37.623394553070966, 37.60534685405588]
# Top 5 seeds: [27, 44, 11, 45, 22]
# Plot saved to: data_540/loss_0.05/log_volume.png
# Test loss  [0.5908902212977409, 0.13253154902458192, 0.06324651592969895]
# log_exp_r_n  [6258925.799790604, 6259705.904315043, 6082041.559992388]
# Plot saved to: data_540/loss_0.05/gen_log_volume.png
# Plot saved to: data_540/loss_0.05/test_vs_data.png
# Plot saved to: data_540/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_540/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_540/acc_0.9/avg_radius.png
# Plot saved to: data_540/acc_0.9/radius_hist.png
# Plot saved to: data_540/acc_0.9/log_volume.png
# Plot saved to: data_540/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_540/loss_0.05\results.json
# Successfully analyzed data_540 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_540
# The number of model parameters is  1625866
# The loss landscape is for data trained with 540
# data_540: 0.0003585658851079643
# data_5940: 9.710447193356231e-05
# data_59940: 3.643031277533737e-06
#
# Top perturbations for data_540:
# Top 5 r_vals: [37.60534685405588, 37.58132764872527, 37.575791677228416, 33.341715768799105, 33.32974632690542]
# Top 5 seeds: [22, 46, 4, 19, 21]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [42.127518078512395, 37.623394553070966, 37.603309558953654, 37.60206054587862, 37.57864964950963]
# Top 5 seeds: [3, 45, 5, 32, 36]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [33.32906081012142, 33.327297597183964, 33.311310708091014, 33.29551193755739, 33.289351851851855]
# Top 5 seeds: [11, 45, 22, 8, 27]
# Plot saved to: data_540/loss_0.02/log_volume.png
# Test loss  [0.5908902212977409, 0.13253154902458192, 0.06324651592969895]
# log_exp_r_n  [5897249.842882364, 6081874.925433914, 5700980.940397485]
# Plot saved to: data_540/loss_0.02/gen_log_volume.png
# Plot saved to: data_540/loss_0.02/test_vs_data.png
# Plot saved to: data_540/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_540/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_540/acc_0.85/avg_radius.png
# Plot saved to: data_540/acc_0.85/radius_hist.png
# Plot saved to: data_540/acc_0.85/log_volume.png
# Plot saved to: data_540/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [3, 2, 1]
# test_loss ranks: [1, 2, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_540/loss_0.02\results.json
# Successfully analyzed data_540 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_5940
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_5940
# The number of model parameters is  1625866
# The loss landscape is for data trained with 5940
# data_5940: 0.00010590138117549941
# data_59940: 4.001681190857198e-06
#
# Top perturbations for data_5940:
# Top 5 r_vals: [52.07390249559995, 52.00928157841038, 52.00801616225387, 46.99918340802279, 46.99893611631228]
# Top 5 seeds: [45, 3, 4, 11, 25]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [42.18296019498967, 42.179861021435954, 42.165200477789256, 42.159627614927686, 42.150455191115704]
# Top 5 seeds: [21, 45, 16, 22, 33]
# Plot saved to: data_5940/loss_0.1/log_volume.png
# Test loss  [0.13253154902458192, 0.06324651592969895]
# log_exp_r_n  [6426497.951060463, 6084013.247193858]
# Plot saved to: data_5940/loss_0.1/gen_log_volume.png
# Plot saved to: data_5940/loss_0.1/test_vs_data.png
# Plot saved to: data_5940/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.95/avg_radius.png
# Plot saved to: data_5940/acc_0.95/radius_hist.png
# Plot saved to: data_5940/acc_0.95/log_volume.png
# Plot saved to: data_5940/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_5940/loss_0.1\results.json
# Successfully analyzed data_5940 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_5940
# The number of model parameters is  1625866
# The loss landscape is for data trained with 5940
# data_5940: 0.00010590138117549941
# data_59940: 4.001681190857198e-06
#
# Top perturbations for data_5940:
# Top 5 r_vals: [46.99669700227896, 46.938376624515364, 46.93723458643411, 42.18187064178719, 42.15734358858471]
# Top 5 seeds: [45, 3, 4, 25, 5]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [37.58538424162315, 37.57776778148835, 37.5767059404015, 33.33607540046934, 33.32974632690542]
# Top 5 seeds: [43, 49, 3, 30, 21]
# Plot saved to: data_5940/loss_0.05/log_volume.png
# Test loss  [0.13253154902458192, 0.06324651592969895]
# log_exp_r_n  [6259705.904315043, 5896386.530792824]
# Plot saved to: data_5940/loss_0.05/gen_log_volume.png
# Plot saved to: data_5940/loss_0.05/test_vs_data.png
# Plot saved to: data_5940/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.9/avg_radius.png
# Plot saved to: data_5940/acc_0.9/radius_hist.png
# Plot saved to: data_5940/acc_0.9/log_volume.png
# Plot saved to: data_5940/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_5940/loss_0.05\results.json
# Successfully analyzed data_5940 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_5940
# The number of model parameters is  1625866
# The loss landscape is for data trained with 5940
# data_5940: 0.00010590138117549941
# data_59940: 4.001681190857198e-06
#
# Top perturbations for data_5940:
# Top 5 r_vals: [37.623394553070966, 37.5767059404015, 37.575791677228416, 33.32906081012142, 33.32888544536272]
# Top 5 seeds: [45, 3, 4, 11, 25]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [29.29372235763172, 29.293119852645777, 29.291570153774966, 29.281389220686986, 29.277891889419767]
# Top 5 seeds: [21, 11, 45, 16, 1]
# Plot saved to: data_5940/loss_0.02/log_volume.png
# Test loss  [0.13253154902458192, 0.06324651592969895]
# log_exp_r_n  [5898029.947406803, 5491152.406677138]
# Plot saved to: data_5940/loss_0.02/gen_log_volume.png
# Plot saved to: data_5940/loss_0.02/test_vs_data.png
# Plot saved to: data_5940/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.85/avg_radius.png
# Plot saved to: data_5940/acc_0.85/radius_hist.png
# Plot saved to: data_5940/acc_0.85/log_volume.png
# Plot saved to: data_5940/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_5940/loss_0.02\results.json
# Successfully analyzed data_5940 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
# Plot saved to: data_50/loss_0.1/gen_log_volume.png
# Plot saved to: data_50/loss_0.1/test_vs_data.png
# Plot saved to: data_50/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.95/avg_radius.png
# Plot saved to: data_50/acc_0.95/radius_hist.png
# Plot saved to: data_50/acc_0.95/log_volume.png
# Plot saved to: data_50/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [2, 1, 5, 3, 4]
# log_exp_r_n_acc ranks: [4, 2, 5, 1, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Error analyzing data_50 with loss=0.1, acc=0.95: [Errno 2] No such file or directory: 'data_50/loss_0.1/results.json\\results.json'
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from data_50
# The number of model parameters is  4353
# The loss landscape is for data trained with 50
# data_100: 2.068505455099512e-05
# data_200: 1.7079014469345566e-06
# data_350: 2.71648277703207e-05
# data_50: 1.2861079085269012e-05
# data_750: 2.2664107746095397e-05
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.6874032753752815, 2.681090517708653, 2.6652609836129613, 2.4964854101564997, 2.475528280730881]
# Top 5 seeds: [34, 500, 723, 167, 1942]
#
# Top perturbations for data_200:
# Top 5 r_vals: [3.25026410891686, 2.4478380724600712, 2.1755961268401345, 2.1734419893627326, 2.1698343576478565]
# Top 5 seeds: [21, 492, 548, 1237, 450]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.1941150003228307, 2.160993339601627, 1.962862291697057, 1.9531046020146627, 1.9413953294025228]
# Top 5 seeds: [1476, 305, 1636, 1171, 1929]
#
# Top perturbations for data_50:
# Top 5 r_vals: [2.4592531140197753, 2.4313383761163565, 2.212383175684401, 2.212251773550491, 2.1968794893627326]
# Top 5 seeds: [1817, 213, 1609, 1996, 389]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.440751759887484, 2.421819612354956, 2.4125467352375263, 2.4072052342905566, 2.2098116283574383]
# Top 5 seeds: [1245, 1444, 80, 282, 1608]
# Plot saved to: data_50/loss_0.05/log_volume.png
# Plot saved to: data_50/loss_0.05/gen_log_volume.png
# Plot saved to: data_50/loss_0.05/test_vs_data.png
# Plot saved to: data_50/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.9/avg_radius.png
# Plot saved to: data_50/acc_0.9/radius_hist.png
# Plot saved to: data_50/acc_0.9/log_volume.png
# Plot saved to: data_50/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [2, 1, 5, 3, 4]
# log_exp_r_n_acc ranks: [3, 4, 5, 1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Error analyzing data_50 with loss=0.05, acc=0.9: [Errno 2] No such file or directory: 'data_50/loss_0.05/results.json\\results.json'
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 5 models from data_50
# The number of model parameters is  4353
# The loss landscape is for data trained with 50
# data_100: 2.068505455099512e-05
# data_200: 1.7079014469345566e-06
# data_350: 2.71648277703207e-05
# data_50: 1.2861079085269012e-05
# data_750: 2.2664107746095397e-05
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.4253814560261913, 2.419684192232059, 2.405398037710697, 2.2406129442955836, 2.221803775503616]
# Top 5 seeds: [34, 500, 723, 167, 1942]
#
# Top perturbations for data_200:
# Top 5 r_vals: [2.96150097527342, 2.196951621820119, 1.9811718515225454, 1.9728170518862478, 1.9530481354653408]
# Top 5 seeds: [21, 492, 1859, 58, 1051]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.9570964046089452, 1.927552701064415, 1.7457719158121623, 1.7300857374247527, 1.7197135097821652]
# Top 5 seeds: [1476, 305, 197, 1171, 1929]
#
# Top perturbations for data_50:
# Top 5 r_vals: [2.2071967006714877, 1.9732739585064567, 1.959562260573549, 1.9594637253201508, 1.9583226960844542]
# Top 5 seeds: [1817, 1996, 389, 939, 1995]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.421819612354956, 2.1905916072120353, 2.1652774022630425, 2.1604833681721334, 1.981950010064792]
# Top 5 seeds: [1444, 1245, 80, 282, 1778]
# Plot saved to: data_50/loss_0.02/log_volume.png
# Plot saved to: data_50/loss_0.02/gen_log_volume.png
# Plot saved to: data_50/loss_0.02/test_vs_data.png
# Plot saved to: data_50/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.85/avg_radius.png
# Plot saved to: data_50/acc_0.85/radius_hist.png
# Plot saved to: data_50/acc_0.85/log_volume.png
# Plot saved to: data_50/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [2, 1, 5, 4, 3]
# log_exp_r_n_acc ranks: [1, 4, 5, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Error analyzing data_50 with loss=0.02, acc=0.85: [Errno 2] No such file or directory: 'data_50/loss_0.02/results.json\\results.json'
#
# Analysis complete for all directories!
