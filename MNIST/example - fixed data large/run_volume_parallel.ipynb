# %%
import os
import subprocess
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock

# ---------- Configuration ----------
MAX_WORKERS = 1
EXCLUDE_PREFIXES = [
    '__pycache__', 
    '.ipynb_checkpoints', 
    'base', 
    'completed runs', 
    'to do', 
    'analysis'
]

# Lock for thread-safe printing
print_lock = Lock()

# ---------- Core Helpers ----------
def run_notebook(folder: str, notebook_name: str) -> str:
    """
    Execute a Jupyter notebook in place using nbconvert.
    Returns a status string with execution time.
    All printing inside this function is thread-safe.
    """
    notebook_path = os.path.join(folder, notebook_name)
    if not os.path.exists(notebook_path):
        with print_lock:
            print(f"SKIP: {notebook_name} not found in {folder}", flush=True)
        return f"SKIP: {notebook_name} not found in {folder}"

    with print_lock:
        print(f"🔹 Running {notebook_path}...", flush=True)

    start_time = time.time()
    try:
        subprocess.run(
            [
                'jupyter', 'nbconvert', '--to', 'notebook',
                '--execute', notebook_path, '--inplace',
                '--ExecutePreprocessor.timeout=-1'
            ],
            check=True,
            capture_output=True,
            text=True
        )
        elapsed = time.time() - start_time
        return f"✅ SUCCESS: {folder}/{notebook_name} (took {elapsed:.2f}s)"
    except subprocess.CalledProcessError as e:
        elapsed = time.time() - start_time
        stderr_clean = e.stderr.strip()
        return f"❌ ERROR: {folder}/{notebook_name} - {stderr_clean} (took {elapsed:.2f}s)"

def find_folders(base_dir: str = '.') -> list[str]:
    """Return a list of folders to process, excluding certain prefixes."""
    return [
        d for d in os.listdir(base_dir)
        if os.path.isdir(d) and not any(d.startswith(prefix) for prefix in EXCLUDE_PREFIXES)
    ]

def run_in_parallel(folders: list[str], notebook_names: list[str]):
    """Run one or more notebooks across all folders in parallel, with thread-safe printing."""
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [
            executor.submit(run_notebook, folder, nb)
            for folder in folders
            for nb in notebook_names
        ]

        for future in as_completed(futures):
            msg = future.result().strip()
            with print_lock:
                print(msg)
    with print_lock:
        print("✅ All done!")

# ---------- Specialized Variants ----------
def run_random_perturbs_parallel():
    """Run Random Perturbs.ipynb across all model_* folders."""
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders for Random Perturbs.")
    run_in_parallel(folders, ["Random Perturbs.ipynb"])

def run_volume_parallel():
    """Run all notebooks containing 'Volume Cutoff' or 'Volume Estimation' across folders."""
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders for Volume notebooks.")

    notebook_names = []
    if folders:
        for nb in os.listdir(folders[0]):
            if nb.endswith(".ipynb") and ("Volume Cutoff" in nb or "Volume Estimation" in nb):
                notebook_names.append(nb)

    if not notebook_names:
        with print_lock:
            print("⚠️ No Volume notebooks found in reference folder.")
        return

    with print_lock:
        print(f"Will run these notebooks: {notebook_names}")
    run_in_parallel(folders, notebook_names)

def run_nb_parallel():
    """Generic function for ad-hoc notebook runs (prompt user)."""
    notebook_name = input("Enter notebook name (without .ipynb): ").strip() + ".ipynb"
    folders = find_folders()
    with print_lock:
        print(f"Found {len(folders)} folders to process.")
    run_in_parallel(folders, [notebook_name])

run_volume_parallel()
# Out:
# Found 50 folders for Volume notebooks.
# Will run these notebooks: ['Volume Estimation Pipeline.ipynb', 'Volume Cutoff.ipynb']
# 🔹 Running model_40_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_40_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_40_data_10/Volume Estimation Pipeline.ipynb (took 5.67s)
# 🔹 Running model_0_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_40_data_10/Volume Cutoff.ipynb (took 4.75s)
# ✅ SUCCESS: model_0_data_10/Volume Estimation Pipeline.ipynb (took 5.29s)
# 🔹 Running model_0_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_0_data_10/Volume Cutoff.ipynb (took 4.70s)
# 🔹 Running model_22_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_22_data_10/Volume Estimation Pipeline.ipynb (took 5.12s)
# 🔹 Running model_22_data_10/Volume Cutoff.ipynb...
# 🔹 Running model_32_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_22_data_10/Volume Cutoff.ipynb (took 4.28s)
# 🔹 Running model_32_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_32_data_10/Volume Estimation Pipeline.ipynb (took 5.13s)
# 🔹 Running model_14_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_32_data_10/Volume Cutoff.ipynb (took 4.41s)
# 🔹 Running model_14_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_14_data_10/Volume Estimation Pipeline.ipynb (took 5.24s)
# 🔹 Running model_49_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_14_data_10/Volume Cutoff.ipynb (took 4.41s)
# 🔹 Running model_49_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_49_data_10/Volume Estimation Pipeline.ipynb (took 5.09s)
# 🔹 Running model_9_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_49_data_10/Volume Cutoff.ipynb (took 4.27s)
# ✅ SUCCESS: model_9_data_10/Volume Estimation Pipeline.ipynb (took 5.09s)
# 🔹 Running model_9_data_10/Volume Cutoff.ipynb...
# 🔹 Running model_15_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_9_data_10/Volume Cutoff.ipynb (took 4.30s)
# 🔹 Running model_15_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_15_data_10/Volume Estimation Pipeline.ipynb (took 5.08s)
# 🔹 Running model_8_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_15_data_10/Volume Cutoff.ipynb (took 4.43s)
# 🔹 Running model_8_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_8_data_10/Volume Estimation Pipeline.ipynb (took 5.14s)
# 🔹 Running model_48_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_8_data_10/Volume Cutoff.ipynb (took 4.42s)
# ✅ SUCCESS: model_48_data_10/Volume Estimation Pipeline.ipynb (took 5.15s)
# 🔹 Running model_48_data_10/Volume Cutoff.ipynb...
# 🔹 Running model_1_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_48_data_10/Volume Cutoff.ipynb (took 4.29s)
# 🔹 Running model_1_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_1_data_10/Volume Estimation Pipeline.ipynb (took 5.10s)
# 🔹 Running model_41_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_1_data_10/Volume Cutoff.ipynb (took 4.58s)
# 🔹 Running model_41_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_41_data_10/Volume Estimation Pipeline.ipynb (took 7.89s)
# 🔹 Running model_33_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_41_data_10/Volume Cutoff.ipynb (took 4.36s)
# 🔹 Running model_33_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_33_data_10/Volume Estimation Pipeline.ipynb (took 5.11s)
# 🔹 Running model_23_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_33_data_10/Volume Cutoff.ipynb (took 4.27s)
# 🔹 Running model_23_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_23_data_10/Volume Estimation Pipeline.ipynb (took 5.11s)
# 🔹 Running model_17_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_23_data_10/Volume Cutoff.ipynb (took 4.35s)
# 🔹 Running model_17_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_17_data_10/Volume Estimation Pipeline.ipynb (took 5.26s)
# 🔹 Running model_38_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_17_data_10/Volume Cutoff.ipynb (took 4.54s)
# 🔹 Running model_38_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_38_data_10/Volume Estimation Pipeline.ipynb (took 5.20s)
# ✅ SUCCESS: model_38_data_10/Volume Cutoff.ipynb (took 4.19s)
# 🔹 Running model_28_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_28_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_28_data_10/Volume Estimation Pipeline.ipynb (took 5.15s)
# ✅ SUCCESS: model_28_data_10/Volume Cutoff.ipynb (took 4.35s)
# 🔹 Running model_21_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_21_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_21_data_10/Volume Estimation Pipeline.ipynb (took 5.10s)
# 🔹 Running model_31_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_21_data_10/Volume Cutoff.ipynb (took 4.26s)
# 🔹 Running model_31_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_31_data_10/Volume Estimation Pipeline.ipynb (took 5.10s)
# 🔹 Running model_3_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_31_data_10/Volume Cutoff.ipynb (took 4.39s)
# 🔹 Running model_3_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_3_data_10/Volume Estimation Pipeline.ipynb (took 5.12s)
# 🔹 Running model_43_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_3_data_10/Volume Cutoff.ipynb (took 4.29s)
# 🔹 Running model_43_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_43_data_10/Volume Estimation Pipeline.ipynb (took 5.11s)
# ✅ SUCCESS: model_43_data_10/Volume Cutoff.ipynb (took 4.12s)
# 🔹 Running model_30_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_30_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_30_data_10/Volume Estimation Pipeline.ipynb (took 5.13s)
# ✅ SUCCESS: model_30_data_10/Volume Cutoff.ipynb (took 4.19s)
# 🔹 Running model_20_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_20_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_20_data_10/Volume Estimation Pipeline.ipynb (took 5.20s)
# 🔹 Running model_42_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_20_data_10/Volume Cutoff.ipynb (took 4.20s)
# ✅ SUCCESS: model_42_data_10/Volume Estimation Pipeline.ipynb (took 5.39s)
# 🔹 Running model_42_data_10/Volume Cutoff.ipynb...
# 🔹 Running model_2_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_42_data_10/Volume Cutoff.ipynb (took 4.51s)
# 🔹 Running model_2_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_2_data_10/Volume Estimation Pipeline.ipynb (took 7.87s)
# 🔹 Running model_16_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_2_data_10/Volume Cutoff.ipynb (took 4.48s)
# 🔹 Running model_16_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_16_data_10/Volume Estimation Pipeline.ipynb (took 5.20s)
# 🔹 Running model_29_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_16_data_10/Volume Cutoff.ipynb (took 4.29s)
# 🔹 Running model_29_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_29_data_10/Volume Estimation Pipeline.ipynb (took 5.12s)
# 🔹 Running model_39_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_29_data_10/Volume Cutoff.ipynb (took 4.18s)
# 🔹 Running model_39_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_39_data_10/Volume Estimation Pipeline.ipynb (took 5.15s)
# 🔹 Running model_13_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_39_data_10/Volume Cutoff.ipynb (took 4.42s)
# 🔹 Running model_13_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_13_data_10/Volume Estimation Pipeline.ipynb (took 5.17s)
# 🔹 Running model_25_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_13_data_10/Volume Cutoff.ipynb (took 4.48s)
# 🔹 Running model_25_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_25_data_10/Volume Estimation Pipeline.ipynb (took 7.84s)
# 🔹 Running model_35_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_25_data_10/Volume Cutoff.ipynb (took 4.28s)
# ✅ SUCCESS: model_35_data_10/Volume Estimation Pipeline.ipynb (took 5.11s)
# 🔹 Running model_35_data_10/Volume Cutoff.ipynb...
# 🔹 Running model_47_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_35_data_10/Volume Cutoff.ipynb (took 4.21s)
# 🔹 Running model_47_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_47_data_10/Volume Estimation Pipeline.ipynb (took 5.15s)
# 🔹 Running model_7_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_47_data_10/Volume Cutoff.ipynb (took 4.22s)
# 🔹 Running model_7_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_7_data_10/Volume Estimation Pipeline.ipynb (took 5.19s)
# 🔹 Running model_34_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_7_data_10/Volume Cutoff.ipynb (took 4.26s)
# 🔹 Running model_34_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_34_data_10/Volume Estimation Pipeline.ipynb (took 5.10s)
# 🔹 Running model_24_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_34_data_10/Volume Cutoff.ipynb (took 4.25s)
# 🔹 Running model_24_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_24_data_10/Volume Estimation Pipeline.ipynb (took 5.13s)
# 🔹 Running model_6_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_24_data_10/Volume Cutoff.ipynb (took 4.18s)
# ✅ SUCCESS: model_6_data_10/Volume Estimation Pipeline.ipynb (took 5.11s)
# 🔹 Running model_6_data_10/Volume Cutoff.ipynb...
# 🔹 Running model_46_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_6_data_10/Volume Cutoff.ipynb (took 5.21s)
# 🔹 Running model_46_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_46_data_10/Volume Estimation Pipeline.ipynb (took 5.17s)
# ✅ SUCCESS: model_46_data_10/Volume Cutoff.ipynb (took 3.94s)
# 🔹 Running model_12_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_12_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_12_data_10/Volume Estimation Pipeline.ipynb (took 5.13s)
# 🔹 Running model_4_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_12_data_10/Volume Cutoff.ipynb (took 4.30s)
# 🔹 Running model_4_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_4_data_10/Volume Estimation Pipeline.ipynb (took 5.16s)
# ✅ SUCCESS: model_4_data_10/Volume Cutoff.ipynb (took 4.25s)
# 🔹 Running model_44_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_44_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_44_data_10/Volume Estimation Pipeline.ipynb (took 5.22s)
# 🔹 Running model_26_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_44_data_10/Volume Cutoff.ipynb (took 4.08s)
# 🔹 Running model_26_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_26_data_10/Volume Estimation Pipeline.ipynb (took 5.07s)
# 🔹 Running model_36_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_26_data_10/Volume Cutoff.ipynb (took 4.17s)
# ✅ SUCCESS: model_36_data_10/Volume Estimation Pipeline.ipynb (took 5.14s)
# 🔹 Running model_36_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_36_data_10/Volume Cutoff.ipynb (took 4.41s)
# 🔹 Running model_19_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_19_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_19_data_10/Volume Estimation Pipeline.ipynb (took 5.10s)
# 🔹 Running model_10_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_19_data_10/Volume Cutoff.ipynb (took 4.40s)
# 🔹 Running model_10_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_10_data_10/Volume Estimation Pipeline.ipynb (took 5.17s)
# ✅ SUCCESS: model_10_data_10/Volume Cutoff.ipynb (took 4.43s)
# 🔹 Running model_11_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_11_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_11_data_10/Volume Estimation Pipeline.ipynb (took 5.08s)
# 🔹 Running model_45_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_11_data_10/Volume Cutoff.ipynb (took 4.32s)
# 🔹 Running model_45_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_45_data_10/Volume Estimation Pipeline.ipynb (took 5.13s)
# ✅ SUCCESS: model_45_data_10/Volume Cutoff.ipynb (took 4.24s)
# 🔹 Running model_5_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_5_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_5_data_10/Volume Estimation Pipeline.ipynb (took 5.20s)
# 🔹 Running model_37_data_10/Volume Estimation Pipeline.ipynb...
# ✅ SUCCESS: model_5_data_10/Volume Cutoff.ipynb (took 4.35s)
# 🔹 Running model_37_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_37_data_10/Volume Estimation Pipeline.ipynb (took 5.23s)
# ✅ SUCCESS: model_37_data_10/Volume Cutoff.ipynb (took 4.38s)
# 🔹 Running model_27_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_27_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_27_data_10/Volume Estimation Pipeline.ipynb (took 5.13s)
# ✅ SUCCESS: model_27_data_10/Volume Cutoff.ipynb (took 4.27s)
# 🔹 Running model_18_data_10/Volume Estimation Pipeline.ipynb...
# 🔹 Running model_18_data_10/Volume Cutoff.ipynb...
# ✅ SUCCESS: model_18_data_10/Volume Estimation Pipeline.ipynb (took 5.11s)
# ✅ SUCCESS: model_18_data_10/Volume Cutoff.ipynb (took 4.17s)
# ✅ All done!
