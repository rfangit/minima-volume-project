# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 10            
model_seed = 0           

# --- Training configuration ---
epochs = 500            

# --- Dataset configuration ---
base_data_size = 60      
dataset_type = "data"   
dataset_quantities = [0, 600-60, 2000 - 60, 6000 - 60, 20000 - 60, 60000 - 60]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
from minima_volume.models import Fashion_MNIST_model_data as model_module

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device = device
)

# MNIST specific initialization parameters
hidden_dims = [256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/500: Train Loss 2.3240 | Test Loss 2.1812 | accs Train 0.0667 Test 0.2695
# Epoch 100/500: Train Loss 0.0004 | Test Loss 1.7165 | accs Train 1.0000 Test 0.6838
# Epoch 200/500: Train Loss 0.0002 | Test Loss 1.7917 | accs Train 1.0000 Test 0.6832
# Epoch 300/500: Train Loss 0.0001 | Test Loss 1.8476 | accs Train 1.0000 Test 0.6826
# Epoch 400/500: Train Loss 0.0001 | Test Loss 1.8930 | accs Train 1.0000 Test 0.6826
# Epoch 500/500: Train Loss 0.0001 | Test Loss 1.9311 | accs Train 1.0000 Test 0.6830
# Completed training with 0 additional samples of data
# Epoch 1/500: Train Loss 2.3251 | Test Loss 2.1490 | accs Train 0.0567 Test 0.5299
# Epoch 100/500: Train Loss 0.0063 | Test Loss 0.9822 | accs Train 1.0000 Test 0.7873
# Epoch 200/500: Train Loss 0.0013 | Test Loss 1.1756 | accs Train 1.0000 Test 0.7853
# Epoch 300/500: Train Loss 0.0006 | Test Loss 1.2768 | accs Train 1.0000 Test 0.7864
# Epoch 400/500: Train Loss 0.0003 | Test Loss 1.3481 | accs Train 1.0000 Test 0.7867
# Epoch 500/500: Train Loss 0.0002 | Test Loss 1.4027 | accs Train 1.0000 Test 0.7858
# Completed training with 540 additional samples of data
# Epoch 1/500: Train Loss 2.3229 | Test Loss 2.1439 | accs Train 0.0585 Test 0.5190
# Epoch 100/500: Train Loss 0.0683 | Test Loss 0.6210 | accs Train 0.9905 Test 0.8236
# Epoch 200/500: Train Loss 0.0056 | Test Loss 0.8991 | accs Train 1.0000 Test 0.8204
# Epoch 300/500: Train Loss 0.0018 | Test Loss 1.0374 | accs Train 1.0000 Test 0.8206
# Epoch 400/500: Train Loss 0.0009 | Test Loss 1.1247 | accs Train 1.0000 Test 0.8205
# Epoch 500/500: Train Loss 0.0006 | Test Loss 1.1898 | accs Train 1.0000 Test 0.8200
# Completed training with 1940 additional samples of data
# Epoch 1/500: Train Loss 2.3234 | Test Loss 2.1415 | accs Train 0.0587 Test 0.5208
# Epoch 100/500: Train Loss 0.2164 | Test Loss 0.4531 | accs Train 0.9303 Test 0.8483
# Epoch 200/500: Train Loss 0.0684 | Test Loss 0.5558 | accs Train 0.9870 Test 0.8424
# Epoch 300/500: Train Loss 0.0196 | Test Loss 0.7100 | accs Train 0.9997 Test 0.8433
# Epoch 400/500: Train Loss 0.0067 | Test Loss 0.8441 | accs Train 1.0000 Test 0.8421
# Epoch 500/500: Train Loss 0.0032 | Test Loss 0.9403 | accs Train 1.0000 Test 0.8416
# Completed training with 5940 additional samples of data
# Epoch 1/500: Train Loss 2.3232 | Test Loss 2.1405 | accs Train 0.0598 Test 0.4965
# Epoch 100/500: Train Loss 0.3196 | Test Loss 0.4023 | accs Train 0.8890 Test 0.8584
# Epoch 200/500: Train Loss 0.2127 | Test Loss 0.3796 | accs Train 0.9269 Test 0.8727
# Epoch 300/500: Train Loss 0.1366 | Test Loss 0.4064 | accs Train 0.9580 Test 0.8713
# Epoch 400/500: Train Loss 0.0898 | Test Loss 0.4636 | accs Train 0.9742 Test 0.8652
# Epoch 500/500: Train Loss 0.0541 | Test Loss 0.5003 | accs Train 0.9896 Test 0.8683
# Completed training with 19940 additional samples of data
# Epoch 1/500: Train Loss 2.3232 | Test Loss 2.1398 | accs Train 0.0571 Test 0.4897
# Epoch 100/500: Train Loss 0.3415 | Test Loss 0.3913 | accs Train 0.8790 Test 0.8621
# Epoch 200/500: Train Loss 0.2597 | Test Loss 0.3360 | accs Train 0.9067 Test 0.8818
# Epoch 300/500: Train Loss 0.2130 | Test Loss 0.3242 | accs Train 0.9243 Test 0.8874
# Epoch 400/500: Train Loss 0.1748 | Test Loss 0.3270 | accs Train 0.9386 Test 0.8875
# Epoch 500/500: Train Loss 0.1579 | Test Loss 0.3400 | accs Train 0.9441 Test 0.8895
# Completed training with 59940 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 1.9311 | accs: 0.6830
#  540 samples | Test Loss: 1.4027 | accs: 0.7858
# 1940 samples | Test Loss: 1.1898 | accs: 0.8200
# 5940 samples | Test Loss: 0.9403 | accs: 0.8416
# 19940 samples | Test Loss: 0.5003 | accs: 0.8683
# 59940 samples | Test Loss: 0.3400 | accs: 0.8895
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0001 | accs: 1.0000
#  Model  540 | Train Loss: 0.0002 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0006 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0033 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0297 | accs: 1.0000
#  Model 59940 | Train Loss: 0.1219 | accs: 0.9500
#
# Dataset type: data, additional samples: 540
#  Model    0 | Train Loss: 1.8076 | accs: 0.7150
#  Model  540 | Train Loss: 0.0002 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0006 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0034 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0561 | accs: 0.9917
#  Model 59940 | Train Loss: 0.1705 | accs: 0.9417
#
# Dataset type: data, additional samples: 1940
#  Model    0 | Train Loss: 1.8707 | accs: 0.7030
#  Model  540 | Train Loss: 0.8603 | accs: 0.8595
#  Model 1940 | Train Loss: 0.0006 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0033 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0534 | accs: 0.9910
#  Model 59940 | Train Loss: 0.1397 | accs: 0.9520
#
# Dataset type: data, additional samples: 5940
#  Model    0 | Train Loss: 1.9018 | accs: 0.6903
#  Model  540 | Train Loss: 1.0995 | accs: 0.8222
#  Model 1940 | Train Loss: 0.6756 | accs: 0.8930
#  Model 5940 | Train Loss: 0.0031 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0513 | accs: 0.9908
#  Model 59940 | Train Loss: 0.1386 | accs: 0.9533
#
# Dataset type: data, additional samples: 19940
#  Model    0 | Train Loss: 1.8992 | accs: 0.6881
#  Model  540 | Train Loss: 1.2779 | accs: 0.8003
#  Model 1940 | Train Loss: 0.9993 | accs: 0.8451
#  Model 5940 | Train Loss: 0.6179 | accs: 0.8910
#  Model 19940 | Train Loss: 0.0539 | accs: 0.9899
#  Model 59940 | Train Loss: 0.1497 | accs: 0.9495
#
# Dataset type: data, additional samples: 59940
#  Model    0 | Train Loss: 1.9080 | accs: 0.6852
#  Model  540 | Train Loss: 1.2865 | accs: 0.7987
#  Model 1940 | Train Loss: 1.0587 | accs: 0.8366
#  Model 5940 | Train Loss: 0.7622 | accs: 0.8671
#  Model 19940 | Train Loss: 0.3203 | accs: 0.9137
#  Model 59940 | Train Loss: 0.1470 | accs: 0.9504

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_540.pt
# Saved model: models_and_data/model_additional_540.pt
# ✅ Model saved to models_and_data\model_additional_1940.pt
# Saved model: models_and_data/model_additional_1940.pt
# ✅ Model saved to models_and_data\model_additional_5940.pt
# Saved model: models_and_data/model_additional_5940.pt
# ✅ Model saved to models_and_data\model_additional_19940.pt
# Saved model: models_and_data/model_additional_19940.pt
# ✅ Model saved to models_and_data\model_additional_59940.pt
# Saved model: models_and_data/model_additional_59940.pt
