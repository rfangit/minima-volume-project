# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "mps")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 10            
model_seed = 10           

# --- Training configuration ---
epochs = 100       

# --- Dataset configuration ---
base_data_size = 1000
dataset_type = "data"   
dataset_quantities = [0, 100, 200, 500, 1000, 2000, 5000, 10000]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
from minima_volume.models import MNIST_model_data as model_module

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device = device
)

# MNIST specific initialization parameters
hidden_dims = [256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/100: Train Loss 2.3089 | Test Loss 2.1785 | accs Train 0.0880 Test 0.4074
# Epoch 100/100: Train Loss 0.0026 | Test Loss 0.5471 | accs Train 1.0000 Test 0.8872
# Completed training with 0 additional samples of data
# Epoch 1/100: Train Loss 2.3104 | Test Loss 2.1800 | accs Train 0.0891 Test 0.4335
# Epoch 100/100: Train Loss 0.0029 | Test Loss 0.5234 | accs Train 1.0000 Test 0.8895
# Completed training with 100 additional samples of data
# Epoch 1/100: Train Loss 2.3103 | Test Loss 2.1796 | accs Train 0.0892 Test 0.4221
# Epoch 100/100: Train Loss 0.0032 | Test Loss 0.5013 | accs Train 1.0000 Test 0.8934
# Completed training with 200 additional samples of data
# Epoch 1/100: Train Loss 2.3093 | Test Loss 2.1759 | accs Train 0.0887 Test 0.4083
# Epoch 100/100: Train Loss 0.0041 | Test Loss 0.4927 | accs Train 1.0000 Test 0.8976
# Completed training with 500 additional samples of data
# Epoch 1/100: Train Loss 2.3101 | Test Loss 2.1754 | accs Train 0.0825 Test 0.4253
# Epoch 100/100: Train Loss 0.0067 | Test Loss 0.4217 | accs Train 1.0000 Test 0.9031
# Completed training with 1000 additional samples of data
# Epoch 1/100: Train Loss 2.3087 | Test Loss 2.1747 | accs Train 0.0883 Test 0.4163
# Epoch 100/100: Train Loss 0.0150 | Test Loss 0.3442 | accs Train 0.9997 Test 0.9179
# Completed training with 2000 additional samples of data
# Epoch 1/100: Train Loss 2.3097 | Test Loss 2.1748 | accs Train 0.0865 Test 0.4350
# Epoch 100/100: Train Loss 0.0429 | Test Loss 0.2317 | accs Train 0.9940 Test 0.9354
# Completed training with 5000 additional samples of data
# Epoch 1/100: Train Loss 2.3067 | Test Loss 2.1728 | accs Train 0.0892 Test 0.4479
# Epoch 100/100: Train Loss 0.0859 | Test Loss 0.1828 | accs Train 0.9793 Test 0.9467
# Completed training with 10000 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 0.5471 | accs: 0.8872
#  100 samples | Test Loss: 0.5234 | accs: 0.8895
#  200 samples | Test Loss: 0.5013 | accs: 0.8934
#  500 samples | Test Loss: 0.4927 | accs: 0.8976
# 1000 samples | Test Loss: 0.4217 | accs: 0.9031
# 2000 samples | Test Loss: 0.3442 | accs: 0.9179
# 5000 samples | Test Loss: 0.2317 | accs: 0.9354
# 10000 samples | Test Loss: 0.1828 | accs: 0.9467
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0025 | accs: 1.0000
#  Model  100 | Train Loss: 0.0028 | accs: 1.0000
#  Model  200 | Train Loss: 0.0030 | accs: 1.0000
#  Model  500 | Train Loss: 0.0041 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0062 | accs: 1.0000
#  Model 2000 | Train Loss: 0.0135 | accs: 1.0000
#  Model 5000 | Train Loss: 0.0374 | accs: 0.9950
#  Model 10000 | Train Loss: 0.0824 | accs: 0.9810
#
# Dataset type: data, additional samples: 100
#  Model    0 | Train Loss: 0.0779 | accs: 0.9891
#  Model  100 | Train Loss: 0.0028 | accs: 1.0000
#  Model  200 | Train Loss: 0.0031 | accs: 1.0000
#  Model  500 | Train Loss: 0.0042 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0065 | accs: 1.0000
#  Model 2000 | Train Loss: 0.0144 | accs: 0.9991
#  Model 5000 | Train Loss: 0.0422 | accs: 0.9936
#  Model 10000 | Train Loss: 0.0887 | accs: 0.9800
#
# Dataset type: data, additional samples: 200
#  Model    0 | Train Loss: 0.1418 | accs: 0.9767
#  Model  100 | Train Loss: 0.0666 | accs: 0.9850
#  Model  200 | Train Loss: 0.0032 | accs: 1.0000
#  Model  500 | Train Loss: 0.0043 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0067 | accs: 1.0000
#  Model 2000 | Train Loss: 0.0145 | accs: 0.9992
#  Model 5000 | Train Loss: 0.0430 | accs: 0.9933
#  Model 10000 | Train Loss: 0.0891 | accs: 0.9800
#
# Dataset type: data, additional samples: 500
#  Model    0 | Train Loss: 0.1836 | accs: 0.9640
#  Model  100 | Train Loss: 0.1205 | accs: 0.9727
#  Model  200 | Train Loss: 0.0677 | accs: 0.9860
#  Model  500 | Train Loss: 0.0040 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0063 | accs: 1.0000
#  Model 2000 | Train Loss: 0.0136 | accs: 0.9993
#  Model 5000 | Train Loss: 0.0401 | accs: 0.9940
#  Model 10000 | Train Loss: 0.0833 | accs: 0.9813
#
# Dataset type: data, additional samples: 1000
#  Model    0 | Train Loss: 0.2868 | accs: 0.9390
#  Model  100 | Train Loss: 0.2260 | accs: 0.9475
#  Model  200 | Train Loss: 0.1850 | accs: 0.9570
#  Model  500 | Train Loss: 0.1339 | accs: 0.9700
#  Model 1000 | Train Loss: 0.0065 | accs: 1.0000
#  Model 2000 | Train Loss: 0.0138 | accs: 0.9995
#  Model 5000 | Train Loss: 0.0390 | accs: 0.9945
#  Model 10000 | Train Loss: 0.0808 | accs: 0.9830
#
# Dataset type: data, additional samples: 2000
#  Model    0 | Train Loss: 0.4053 | accs: 0.9137
#  Model  100 | Train Loss: 0.3552 | accs: 0.9227
#  Model  200 | Train Loss: 0.3158 | accs: 0.9297
#  Model  500 | Train Loss: 0.2791 | accs: 0.9413
#  Model 1000 | Train Loss: 0.1555 | accs: 0.9643
#  Model 2000 | Train Loss: 0.0145 | accs: 0.9997
#  Model 5000 | Train Loss: 0.0410 | accs: 0.9943
#  Model 10000 | Train Loss: 0.0829 | accs: 0.9817
#
# Dataset type: data, additional samples: 5000
#  Model    0 | Train Loss: 0.4943 | accs: 0.8942
#  Model  100 | Train Loss: 0.4550 | accs: 0.9015
#  Model  200 | Train Loss: 0.4217 | accs: 0.9090
#  Model  500 | Train Loss: 0.3917 | accs: 0.9178
#  Model 1000 | Train Loss: 0.2800 | accs: 0.9350
#  Model 2000 | Train Loss: 0.1665 | accs: 0.9587
#  Model 5000 | Train Loss: 0.0415 | accs: 0.9945
#  Model 10000 | Train Loss: 0.0805 | accs: 0.9822
#
# Dataset type: data, additional samples: 10000
#  Model    0 | Train Loss: 0.5530 | accs: 0.8834
#  Model  100 | Train Loss: 0.5202 | accs: 0.8899
#  Model  200 | Train Loss: 0.4873 | accs: 0.8941
#  Model  500 | Train Loss: 0.4636 | accs: 0.9026
#  Model 1000 | Train Loss: 0.3621 | accs: 0.9180
#  Model 2000 | Train Loss: 0.2693 | accs: 0.9364
#  Model 5000 | Train Loss: 0.1473 | accs: 0.9636
#  Model 10000 | Train Loss: 0.0841 | accs: 0.9797

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data/dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data/model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data/model_additional_100.pt
# Saved model: models_and_data/model_additional_100.pt
# ✅ Model saved to models_and_data/model_additional_200.pt
# Saved model: models_and_data/model_additional_200.pt
# ✅ Model saved to models_and_data/model_additional_500.pt
# Saved model: models_and_data/model_additional_500.pt
# ✅ Model saved to models_and_data/model_additional_1000.pt
# Saved model: models_and_data/model_additional_1000.pt
# ✅ Model saved to models_and_data/model_additional_2000.pt
# Saved model: models_and_data/model_additional_2000.pt
# ✅ Model saved to models_and_data/model_additional_5000.pt
# Saved model: models_and_data/model_additional_5000.pt
# ✅ Model saved to models_and_data/model_additional_10000.pt
# Saved model: models_and_data/model_additional_10000.pt
