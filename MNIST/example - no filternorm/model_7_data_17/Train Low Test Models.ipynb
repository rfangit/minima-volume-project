# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 17            
model_seed = 7           

# --- Training configuration ---
epochs = 500            

# --- Dataset configuration ---
base_data_size = 60      
dataset_type = "data"   
dataset_quantities = [0, 600-60, 2000 - 60, 6000 - 60, 20000 - 60, 60000 - 60]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
from minima_volume.models import MNIST_model_data as model_module

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device = device
)

# MNIST specific initialization parameters
hidden_dims = [256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/500: Train Loss 2.3277 | Test Loss 2.2401 | accs Train 0.0833 Test 0.1215
# Epoch 100/500: Train Loss 0.0001 | Test Loss 1.4661 | accs Train 1.0000 Test 0.6767
# Epoch 200/500: Train Loss 0.0001 | Test Loss 1.4657 | accs Train 1.0000 Test 0.6814
# Epoch 300/500: Train Loss 0.0000 | Test Loss 1.4698 | accs Train 1.0000 Test 0.6852
# Epoch 400/500: Train Loss 0.0000 | Test Loss 1.4768 | accs Train 1.0000 Test 0.6875
# Epoch 500/500: Train Loss 0.0000 | Test Loss 1.4844 | accs Train 1.0000 Test 0.6893
# Completed training with 0 additional samples of data
# Epoch 1/500: Train Loss 2.3220 | Test Loss 2.1858 | accs Train 0.0917 Test 0.3536
# Epoch 100/500: Train Loss 0.0015 | Test Loss 0.6287 | accs Train 1.0000 Test 0.8761
# Epoch 200/500: Train Loss 0.0005 | Test Loss 0.6762 | accs Train 1.0000 Test 0.8764
# Epoch 300/500: Train Loss 0.0003 | Test Loss 0.7066 | accs Train 1.0000 Test 0.8761
# Epoch 400/500: Train Loss 0.0002 | Test Loss 0.7291 | accs Train 1.0000 Test 0.8763
# Epoch 500/500: Train Loss 0.0001 | Test Loss 0.7470 | accs Train 1.0000 Test 0.8767
# Completed training with 540 additional samples of data
# Epoch 1/500: Train Loss 2.3189 | Test Loss 2.1764 | accs Train 0.0975 Test 0.4279
# Epoch 100/500: Train Loss 0.0064 | Test Loss 0.4346 | accs Train 1.0000 Test 0.9071
# Epoch 200/500: Train Loss 0.0011 | Test Loss 0.5020 | accs Train 1.0000 Test 0.9077
# Epoch 300/500: Train Loss 0.0005 | Test Loss 0.5359 | accs Train 1.0000 Test 0.9086
# Epoch 400/500: Train Loss 0.0003 | Test Loss 0.5594 | accs Train 1.0000 Test 0.9085
# Epoch 500/500: Train Loss 0.0002 | Test Loss 0.5771 | accs Train 1.0000 Test 0.9083
# Completed training with 1940 additional samples of data
# Epoch 1/500: Train Loss 2.3158 | Test Loss 2.1717 | accs Train 0.1028 Test 0.3928
# Epoch 100/500: Train Loss 0.0363 | Test Loss 0.2287 | accs Train 0.9950 Test 0.9365
# Epoch 200/500: Train Loss 0.0028 | Test Loss 0.2683 | accs Train 1.0000 Test 0.9409
# Epoch 300/500: Train Loss 0.0010 | Test Loss 0.2914 | accs Train 1.0000 Test 0.9419
# Epoch 400/500: Train Loss 0.0005 | Test Loss 0.3070 | accs Train 1.0000 Test 0.9424
# Epoch 500/500: Train Loss 0.0003 | Test Loss 0.3188 | accs Train 1.0000 Test 0.9422
# Completed training with 5940 additional samples of data
# Epoch 1/500: Train Loss 2.3143 | Test Loss 2.1704 | accs Train 0.1037 Test 0.3745
# Epoch 100/500: Train Loss 0.0990 | Test Loss 0.1539 | accs Train 0.9733 Test 0.9541
# Epoch 200/500: Train Loss 0.0139 | Test Loss 0.1384 | accs Train 0.9987 Test 0.9630
# Epoch 300/500: Train Loss 0.0030 | Test Loss 0.1603 | accs Train 1.0000 Test 0.9634
# Epoch 400/500: Train Loss 0.0013 | Test Loss 0.1761 | accs Train 1.0000 Test 0.9646
# Epoch 500/500: Train Loss 0.0007 | Test Loss 0.1877 | accs Train 1.0000 Test 0.9646
# Completed training with 19940 additional samples of data
# Epoch 1/500: Train Loss 2.3141 | Test Loss 2.1701 | accs Train 0.1041 Test 0.3819
# Epoch 100/500: Train Loss 0.1275 | Test Loss 0.1403 | accs Train 0.9638 Test 0.9581
# Epoch 200/500: Train Loss 0.0433 | Test Loss 0.0857 | accs Train 0.9885 Test 0.9728
# Epoch 300/500: Train Loss 0.0140 | Test Loss 0.0806 | accs Train 0.9981 Test 0.9765
# Epoch 400/500: Train Loss 0.0049 | Test Loss 0.0882 | accs Train 0.9998 Test 0.9770
# Epoch 500/500: Train Loss 0.0022 | Test Loss 0.0967 | accs Train 1.0000 Test 0.9776
# Completed training with 59940 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 1.4844 | accs: 0.6893
#  540 samples | Test Loss: 0.7470 | accs: 0.8767
# 1940 samples | Test Loss: 0.5771 | accs: 0.9083
# 5940 samples | Test Loss: 0.3188 | accs: 0.9422
# 19940 samples | Test Loss: 0.1877 | accs: 0.9646
# 59940 samples | Test Loss: 0.0967 | accs: 0.9776
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  540 | Train Loss: 0.0001 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0002 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0004 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0007 | accs: 1.0000
#
# Dataset type: data, additional samples: 540
#  Model    0 | Train Loss: 1.5040 | accs: 0.6800
#  Model  540 | Train Loss: 0.0001 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0002 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0003 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0007 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0021 | accs: 1.0000
#
# Dataset type: data, additional samples: 1940
#  Model    0 | Train Loss: 1.4713 | accs: 0.6760
#  Model  540 | Train Loss: 0.5149 | accs: 0.9155
#  Model 1940 | Train Loss: 0.0002 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0003 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0007 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0023 | accs: 1.0000
#
# Dataset type: data, additional samples: 5940
#  Model    0 | Train Loss: 1.4956 | accs: 0.6792
#  Model  540 | Train Loss: 0.6938 | accs: 0.8837
#  Model 1940 | Train Loss: 0.3970 | accs: 0.9368
#  Model 5940 | Train Loss: 0.0003 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0007 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0022 | accs: 1.0000
#
# Dataset type: data, additional samples: 19940
#  Model    0 | Train Loss: 1.5182 | accs: 0.6782
#  Model  540 | Train Loss: 0.7438 | accs: 0.8760
#  Model 1940 | Train Loss: 0.5779 | accs: 0.9101
#  Model 5940 | Train Loss: 0.2784 | accs: 0.9551
#  Model 19940 | Train Loss: 0.0007 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0023 | accs: 1.0000
#
# Dataset type: data, additional samples: 59940
#  Model    0 | Train Loss: 1.5229 | accs: 0.6773
#  Model  540 | Train Loss: 0.7711 | accs: 0.8732
#  Model 1940 | Train Loss: 0.6175 | accs: 0.9036
#  Model 5940 | Train Loss: 0.3505 | accs: 0.9422
#  Model 19940 | Train Loss: 0.1391 | accs: 0.9740
#  Model 59940 | Train Loss: 0.0022 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_540.pt
# Saved model: models_and_data/model_additional_540.pt
# ✅ Model saved to models_and_data\model_additional_1940.pt
# Saved model: models_and_data/model_additional_1940.pt
# ✅ Model saved to models_and_data\model_additional_5940.pt
# Saved model: models_and_data/model_additional_5940.pt
# ✅ Model saved to models_and_data\model_additional_19940.pt
# Saved model: models_and_data/model_additional_19940.pt
# ✅ Model saved to models_and_data\model_additional_59940.pt
# Saved model: models_and_data/model_additional_59940.pt
