# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.05, 0.02]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}"
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['poison_0', 'poison_10']
#
# ==================================================
# Analyzing directory: poison_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from poison_0
# The number of model parameters is  235146
# The loss landscape is for poison trained with 0
# poison_0: 0.00038596836384385824
# poison_10: 0.0003730769094545394
# poison_100: 0.0005582653102464974
# poison_1000: 0.006092438008636236
# poison_500: 0.0014497366501018405
#
# Top perturbations for poison_0:
# Top 5 r_vals: [21.858083761756415, 21.83537459220221, 21.827518795913686, 21.818942095403614, 21.806351674818142]
# Top 5 seeds: [13, 27, 786, 135, 291]
#
# Top perturbations for poison_10:
# Top 5 r_vals: [21.844896020530236, 19.860317984134277, 19.859239391229217, 19.83466964268634, 19.825667252942946]
# Top 5 seeds: [715, 419, 675, 727, 496]
#
# Top perturbations for poison_100:
# Top 5 r_vals: [16.086857567148762, 16.07402706934401, 16.058790474883782, 16.056991703254134, 16.056873668323863]
# Top 5 seeds: [419, 788, 496, 926, 969]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [9.689002171035645, 8.390984348296731, 8.390528642794344, 8.389769309029973, 8.385378012935943]
# Top 5 seeds: [573, 419, 675, 980, 246]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [11.171428866075528, 11.170822157566432, 11.159329725253244, 11.158783267242741, 11.154995192290448]
# Top 5 seeds: [419, 675, 676, 985, 749]
# Plot saved to: poison_0/loss_0.1/log_volume.png
# Test loss  [0.2319841980934143, 0.2347954362630844, 0.266191303730011, 0.4701606035232544, 0.381381630897522]
# log_exp_r_n  [725317.5821278533, 725175.667562396, 653229.3006677794, 534007.6466823977, 567484.9310828793]
# Plot saved to: poison_0/loss_0.1/gen_log_volume.png
# Plot saved to: poison_0/loss_0.1/test_vs_data.png
# Plot saved to: poison_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: poison_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: poison_0/acc_0.95/avg_radius.png
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: divide by zero encountered in divide
#   return n/db/n.sum(), bin_edges
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Plot saved to: poison_0/acc_0.95/radius_hist.png
# Plot saved to: poison_0/acc_0.95/log_volume.png
# Plot saved to: poison_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 4, 3, 1, 2]
# test_loss ranks: [5, 4, 3, 1, 2]
# log_exp_r_n ranks: [1, 2, 3, 5, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to poison_0/loss_0.1\results.json
# Successfully analyzed poison_0 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from poison_0
# The number of model parameters is  235146
# The loss landscape is for poison trained with 0
# poison_0: 0.00038596836384385824
# poison_10: 0.0003730769094545394
# poison_100: 0.0005582653102464974
# poison_1000: 0.006092438008636236
# poison_500: 0.0014497366501018405
#
# Top perturbations for poison_0:
# Top 5 r_vals: [17.922963550584367, 17.90078935252442, 17.89289849885276, 17.892664695781008, 17.890660508872664]
# Top 5 seeds: [675, 727, 13, 496, 926]
#
# Top perturbations for poison_10:
# Top 5 r_vals: [17.882103091635862, 17.86787819801551, 17.860857361543548, 17.85548326305292, 17.82924336446158]
# Top 5 seeds: [715, 786, 135, 10, 736]
#
# Top perturbations for poison_100:
# Top 5 r_vals: [14.309349789447708, 14.306497216358467, 14.306037385175943, 14.304201659907157, 14.295501761917635]
# Top 5 seeds: [27, 938, 933, 786, 542]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [7.149714474288339, 7.144937478477962, 7.141971024162076, 7.141621291035355, 7.139196923065887]
# Top 5 seeds: [419, 246, 676, 985, 749]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [9.731027301702317, 9.717240256395238, 9.715766407764518, 9.713488808141392, 9.710066916103113]
# Top 5 seeds: [675, 749, 415, 926, 702]
# Plot saved to: poison_0/loss_0.05/log_volume.png
# Test loss  [0.2319841980934143, 0.2347954362630844, 0.266191303730011, 0.4701606035232544, 0.381381630897522]
# log_exp_r_n  [678643.9114155918, 678107.2176707155, 625696.1770000217, 462542.3040453746, 535025.3646848674]
# Plot saved to: poison_0/loss_0.05/gen_log_volume.png
# Plot saved to: poison_0/loss_0.05/test_vs_data.png
# Plot saved to: poison_0/loss_0.05/other_plots/avg_radius.png
# Plot saved to: poison_0/loss_0.05/other_plots/radius_hist.png
# Plot saved to: poison_0/acc_0.9/avg_radius.png
# Plot saved to: poison_0/acc_0.9/radius_hist.png
# Plot saved to: poison_0/acc_0.9/log_volume.png
# Plot saved to: poison_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 4, 3, 1, 2]
# test_loss ranks: [5, 4, 3, 1, 2]
# log_exp_r_n ranks: [1, 2, 3, 5, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to poison_0/loss_0.05\results.json
# Successfully analyzed poison_0 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 5 models from poison_0
# The number of model parameters is  235146
# The loss landscape is for poison trained with 0
# poison_0: 0.00038596836384385824
# poison_10: 0.0003730769094545394
# poison_100: 0.0005582653102464974
# poison_1000: 0.006092438008636236
# poison_500: 0.0014497366501018405
#
# Top perturbations for poison_0:
# Top 5 r_vals: [14.34830046016311, 14.33054881684088, 14.324231762239467, 14.324044590251278, 14.322440130371746]
# Top 5 seeds: [675, 727, 13, 496, 926]
#
# Top perturbations for poison_10:
# Top 5 r_vals: [14.34830046016311, 14.315589455630926, 14.309349789447708, 14.304201659907157, 14.29858110106949]
# Top 5 seeds: [675, 715, 27, 786, 135]
#
# Top perturbations for poison_100:
# Top 5 r_vals: [11.162518798155562, 11.151937829780405, 11.150688682815371, 11.149138283357367, 11.1483795474274]
# Top 5 seeds: [788, 496, 926, 199, 198]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [5.997998649691358, 5.984801869333527, 4.965079496033569, 4.964809847807304, 4.964360537887558]
# Top 5 seeds: [415, 10, 419, 675, 980]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [7.149714474288339, 7.149326180842517, 7.148679174558081, 7.144115157254363, 7.14401203081956]
# Top 5 seeds: [419, 675, 980, 981, 788]
# Plot saved to: poison_0/loss_0.02/log_volume.png
# Test loss  [0.2319841980934143, 0.2347954362630844, 0.266191303730011, 0.4701606035232544, 0.381381630897522]
# log_exp_r_n  [626335.3850283342, 626335.3850283342, 567297.3093506622, 421239.716391653, 462542.30404821696]
# Plot saved to: poison_0/loss_0.02/gen_log_volume.png
# Plot saved to: poison_0/loss_0.02/test_vs_data.png
# Plot saved to: poison_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: poison_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: poison_0/acc_0.85/avg_radius.png
# Plot saved to: poison_0/acc_0.85/radius_hist.png
# Plot saved to: poison_0/acc_0.85/log_volume.png
# Plot saved to: poison_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 4, 3, 1, 2]
# test_loss ranks: [5, 4, 3, 1, 2]
# log_exp_r_n ranks: [1, 2, 3, 5, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to poison_0/loss_0.02\results.json
# Successfully analyzed poison_0 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: poison_10
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from poison_10
# The number of model parameters is  235146
# The loss landscape is for poison trained with 10
# poison_10: 0.00038612252683378756
# poison_100: 0.000568687217310071
# poison_1000: 0.006111943628638983
# poison_500: 0.001459081075154245
# Top perturbations for poison_10:
# Top 5 r_vals: [19.860317984134277, 19.859239391229217, 19.83466964268634, 19.825667252942946, 19.82453012208576]
# Top 5 seeds: [419, 675, 727, 496, 692]
#
# Top perturbations for poison_100:
# Top 5 r_vals: [16.086857567148762, 16.058790474883782, 16.056991703254134, 16.054759128034608, 16.053666548295453]
# Top 5 seeds: [419, 496, 926, 199, 198]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [9.689002171035645, 8.390984348296731, 8.390528642794344, 8.389769309029973, 8.385378012935943]
# Top 5 seeds: [573, 419, 675, 980, 246]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [11.171428866075528, 11.170822157566432, 11.159329725253244, 11.158783267242741, 11.154995192290448]
# Top 5 seeds: [419, 675, 676, 985, 749]
# Plot saved to: poison_10/loss_0.1/log_volume.png
# Test loss  [0.2347954362630844, 0.266191303730011, 0.4701606035232544, 0.381381630897522]
# log_exp_r_n  [702779.5083003723, 653229.3006677794, 534007.6466823977, 567484.9310828793]
# Plot saved to: poison_10/loss_0.1/gen_log_volume.png
# Plot saved to: poison_10/loss_0.1/test_vs_data.png
# Plot saved to: poison_10/loss_0.1/other_plots/avg_radius.png
# Plot saved to: poison_10/loss_0.1/other_plots/radius_hist.png
# Plot saved to: poison_10/acc_0.95/avg_radius.png
# Plot saved to: poison_10/acc_0.95/radius_hist.png
# Plot saved to: poison_10/acc_0.95/log_volume.png
# Plot saved to: poison_10/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 1, 2]
# test_loss ranks: [4, 3, 1, 2]
# log_exp_r_n ranks: [1, 2, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to poison_10/loss_0.1\results.json
# Successfully analyzed poison_10 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from poison_10
# The number of model parameters is  235146
# The loss landscape is for poison trained with 10
# poison_10: 0.00038612252683378756
# poison_100: 0.000568687217310071
# poison_1000: 0.006111943628638983
# poison_500: 0.001459081075154245
#
# Top perturbations for poison_10:
# Top 5 r_vals: [17.882103091635862, 17.86787819801551, 17.860857361543548, 17.85548326305292, 17.82924336446158]
# Top 5 seeds: [715, 786, 135, 10, 736]
#
# Top perturbations for poison_100:
# Top 5 r_vals: [14.309349789447708, 14.306037385175943, 14.304201659907157, 14.294278844937104, 14.276789962290604]
# Top 5 seeds: [27, 933, 786, 10, 944]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [7.149714474288339, 7.144937478477962, 7.141971024162076, 7.141621291035355, 7.13811409550046]
# Top 5 seeds: [419, 246, 676, 985, 415]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [9.731027301702317, 9.717240256395238, 9.715766407764518, 9.713488808141392, 9.710066916103113]
# Top 5 seeds: [675, 749, 415, 926, 702]
# Plot saved to: poison_10/loss_0.05/log_volume.png
# Test loss  [0.2347954362630844, 0.266191303730011, 0.4701606035232544, 0.381381630897522]
# log_exp_r_n  [678107.2176707155, 625696.1770000217, 462542.3040453746, 535025.3646848674]
# Plot saved to: poison_10/loss_0.05/gen_log_volume.png
# Plot saved to: poison_10/loss_0.05/test_vs_data.png
# Plot saved to: poison_10/loss_0.05/other_plots/avg_radius.png
# Plot saved to: poison_10/loss_0.05/other_plots/radius_hist.png
# Plot saved to: poison_10/acc_0.9/avg_radius.png
# Plot saved to: poison_10/acc_0.9/radius_hist.png
# Plot saved to: poison_10/acc_0.9/log_volume.png
# Plot saved to: poison_10/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 1, 2]
# test_loss ranks: [4, 3, 1, 2]
# log_exp_r_n ranks: [1, 2, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to poison_10/loss_0.05\results.json
# Successfully analyzed poison_10 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from poison_10
# The number of model parameters is  235146
# The loss landscape is for poison trained with 10
# poison_10: 0.00038612252683378756
# poison_100: 0.000568687217310071
# poison_1000: 0.006111943628638983
# poison_500: 0.001459081075154245
#
# Top perturbations for poison_10:
# Top 5 r_vals: [14.34830046016311, 14.315589455630926, 14.304201659907157, 14.29858110106949, 14.294278844937104]
# Top 5 seeds: [675, 715, 786, 135, 10]
#
# Top perturbations for poison_100:
# Top 5 r_vals: [11.162518798155562, 11.150688682815371, 11.149138283357367, 11.1483795474274, 11.145355112515425]
# Top 5 seeds: [788, 926, 199, 198, 715]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [5.997998649691358, 5.984801869333527, 4.965079496033569, 4.964809847807304, 4.964360537887558]
# Top 5 seeds: [415, 10, 419, 675, 980]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [7.149714474288339, 7.149326180842517, 7.148679174558081, 7.144115157254363, 7.14401203081956]
# Top 5 seeds: [419, 675, 980, 981, 788]
# Plot saved to: poison_10/loss_0.02/log_volume.png
# Test loss  [0.2347954362630844, 0.266191303730011, 0.4701606035232544, 0.381381630897522]
# log_exp_r_n  [626335.3850283342, 567297.3093506622, 421239.716391653, 462542.30404821696]
# Plot saved to: poison_10/loss_0.02/gen_log_volume.png
# Plot saved to: poison_10/loss_0.02/test_vs_data.png
# Plot saved to: poison_10/loss_0.02/other_plots/avg_radius.png
# Plot saved to: poison_10/loss_0.02/other_plots/radius_hist.png
# Plot saved to: poison_10/acc_0.85/avg_radius.png
# Plot saved to: poison_10/acc_0.85/radius_hist.png
# Plot saved to: poison_10/acc_0.85/log_volume.png
# Plot saved to: poison_10/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 1, 2]
# test_loss ranks: [4, 3, 1, 2]
# log_exp_r_n ranks: [1, 2, 4, 3]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to poison_10/loss_0.02\results.json
# Successfully analyzed poison_10 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
