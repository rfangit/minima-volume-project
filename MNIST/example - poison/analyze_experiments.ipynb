# %% [markdown]
# # Comparisons In A Given Loss Landscape

# %%
import os
import json
from pathlib import Path
import matplotlib.pyplot as plt

from minima_volume.analysis_funcs import (  grab_folder_names,
                                            load_base_train_size,
                                            list_additional_data,
                                            multiple_minima_fixed_landscape,
                                            fixed_landscape_minima_labels,
                                            plot_fixed_landscape_minima_pair,
                                            model_volume_across_targets,
                                            append_cutoff_points,
                                            varying_landscape_minima_labels,
                                            plot_minima_volume_vs_data_level,
)

loss_value = 0.1  # Loss value to analyze
data_level_log = False #Is the data log distributed?
base_output_dir = "analysis"  # Root folder to save all plots
os.makedirs(base_output_dir, exist_ok=True)

# Data for the loss landscape levels
experiment_folders, data_modifications = grab_folder_names()

base_train_size = load_base_train_size(experiment_folders[0])
model_data_sizes = list_additional_data(experiment_folders[0])

base_shift = 0
if data_modifications[0].startswith("data_"):
    base_shift = base_train_size  # Shift to reflect true dataset size

print("Experiment folders: ", experiment_folders)
print("Different data levels where loss landscapes were computed:", data_modifications)
print("The base train size is: ", base_train_size)
print("Data levels where models were trained: ", model_data_sizes)
# Out:
# First entry: Model_0, base_train_size = 10000
# Experiment folders:  ['model_0_data_10', 'model_1_data_11', 'model_2_data_12', 'model_3_data_13', 'model_4_data_14', 'model_5_data_15', 'model_6_data_16', 'model_7_data_17', 'model_8_data_18', 'model_9_data_19']
# Different data levels where loss landscapes were computed: ['poison_0', 'poison_10']
# The base train size is:  10000
# Data levels where models were trained:  [0, 10, 100, 1000, 500]

# %% [markdown]
# ## Plotting Different Model Volumes In A Landscape

# %%
for data_modification in data_modifications:
    print(f"\nProcessing data modification folder: {data_modification}")

    # Create output folder for this data_modification
    save_dir = os.path.join(base_output_dir, data_modification)
    os.makedirs(save_dir, exist_ok=True)

    # Get axis labels and titles
    labels = fixed_landscape_minima_labels(data_modification, base_train_size)

    # Extract minima landscapes
    all_mdl, all_log_rn, all_test_loss = multiple_minima_fixed_landscape(
        experiment_folders, data_modification, loss_value
    )

    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=data_level_log,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_log_volume",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="log_volume_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )

    ## Rank variant
    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_log_volume",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="log_volume_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )
# Out:
# Processing data modification folder: poison_0
# Processing data modification folder: poison_10

# %% [markdown]
# # Comparisons Across Loss Landscapes

# %% [markdown]
# Here, we track the performance of all models across all loss landscapes.

# %%
# For the poisoning experiments, this plot has no meaning

labels = varying_landscape_minima_labels(
    data_modification_folder=data_modifications[0], # Random choice to grab datatype from
    base_train_size=base_train_size,
)

results_dict = model_volume_across_targets(
    target_model_data_levels=model_data_sizes,
    loss_value=loss_value,
    experiment_folders=experiment_folders
)
results_with_cutoff = append_cutoff_points(results_dict, threshold=loss_value, base_dir=".")

plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          # NEW: needed for correct legend labels
    base_train_size=base_train_size,  # NEW: used for dataset size shifts
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = data_level_log,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels",
    xlabel_size=15, ylabel_size=15, title_size=15
)
# Out:
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Model_0: first exceedance at index 10043 (value=0.10206840187311172, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=0, cutoff_idx=10043
# Model_0: first exceedance at index 10037 (value=0.10018230229616165, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=0, cutoff_idx=10037
# Model_0: first exceedance at index 10040 (value=0.10273855924606323, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=0, cutoff_idx=10040
# Model_0: first exceedance at index 10044 (value=0.10119620710611343, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=0, cutoff_idx=10044
# Model_0: first exceedance at index 10036 (value=0.10040996223688126, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=0, cutoff_idx=10036
# Model_0: first exceedance at index 10037 (value=0.10063284635543823, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=0, cutoff_idx=10037
# Model_0: first exceedance at index 10039 (value=0.10305088013410568, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=0, cutoff_idx=10039
# Model_0: first exceedance at index 10040 (value=0.10179999470710754, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=0, cutoff_idx=10040
# Model_0: first exceedance at index 10046 (value=0.10101586580276489, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=0, cutoff_idx=10046
# Model_0: first exceedance at index 10040 (value=0.10189282894134521, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=0, cutoff_idx=10040
# Model_10: first exceedance at index 10054 (value=0.10388575494289398, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=10, cutoff_idx=10054
# Model_10: first exceedance at index 10047 (value=0.10025659948587418, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=10, cutoff_idx=10047
# Model_10: first exceedance at index 10051 (value=0.10257358849048615, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=10, cutoff_idx=10051
# Model_10: first exceedance at index 10052 (value=0.10539544373750687, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=10, cutoff_idx=10052
# Model_10: first exceedance at index 10050 (value=0.10031433403491974, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=10, cutoff_idx=10050
# Model_10: first exceedance at index 10051 (value=0.10113668441772461, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=10, cutoff_idx=10051
# Model_10: first exceedance at index 10053 (value=0.10013776272535324, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=10, cutoff_idx=10053
# Model_10: first exceedance at index 10050 (value=0.10127957910299301, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=10, cutoff_idx=10050
# Model_10: first exceedance at index 10056 (value=0.10060248523950577, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=10, cutoff_idx=10056
# Model_10: first exceedance at index 10051 (value=0.10227036476135254, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=10, cutoff_idx=10051
# Model_100: first exceedance at index 10147 (value=0.1013111025094986, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=100, cutoff_idx=10147
# Model_100: first exceedance at index 10145 (value=0.1000230684876442, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=100, cutoff_idx=10145
# Model_100: first exceedance at index 10142 (value=0.10260999947786331, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=100, cutoff_idx=10142
# Model_100: first exceedance at index 10149 (value=0.10058556497097015, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=100, cutoff_idx=10149
# Model_100: first exceedance at index 10142 (value=0.10034117847681046, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=100, cutoff_idx=10142
# Model_100: first exceedance at index 10154 (value=0.10032548755407333, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=100, cutoff_idx=10154
# Model_100: first exceedance at index 10145 (value=0.10067538917064667, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=100, cutoff_idx=10145
# Model_100: first exceedance at index 10143 (value=0.10264618694782257, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=100, cutoff_idx=10143
# Model_100: first exceedance at index 10140 (value=0.10178326070308685, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=100, cutoff_idx=10140
# Model_100: first exceedance at index 10151 (value=0.10053561627864838, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=100, cutoff_idx=10151
# Model_500: first exceedance at index 10562 (value=0.10068900883197784, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=500, cutoff_idx=10562
# Model_500: first exceedance at index 10560 (value=0.10051105916500092, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=500, cutoff_idx=10560
# Model_500: first exceedance at index 10555 (value=0.10040062665939331, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=500, cutoff_idx=10555
# Model_500: first exceedance at index 10559 (value=0.10015451908111572, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=500, cutoff_idx=10559
# Model_500: first exceedance at index 10564 (value=0.10176844149827957, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=500, cutoff_idx=10564
# Model_500: first exceedance at index 10558 (value=0.10194876790046692, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=500, cutoff_idx=10558
# Model_500: first exceedance at index 10563 (value=0.10123993456363678, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=500, cutoff_idx=10563
# Model_500: first exceedance at index 10559 (value=0.10123569518327713, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=500, cutoff_idx=10559
# Model_500: first exceedance at index 10558 (value=0.1007300317287445, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=500, cutoff_idx=10558
# Model_500: first exceedance at index 10558 (value=0.10024888068437576, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=500, cutoff_idx=10558
# ⚠️ Skipped model_0_data_10 (target=1000): Model_1000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_1_data_11 (target=1000): Model_1000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_2_data_12 (target=1000): Model_1000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_3_data_13 (target=1000): Model_1000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_4_data_14 (target=1000): Model_1000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_5_data_15 (target=1000): Model_1000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_6_data_16 (target=1000): Model_1000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_7_data_17 (target=1000): Model_1000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_8_data_18 (target=1000): Model_1000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_9_data_19 (target=1000): Model_1000: loss curve never exceeds threshold=0.1
