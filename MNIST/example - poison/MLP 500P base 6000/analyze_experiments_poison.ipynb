# %% [markdown]
# # Comparisons In A Given Loss Landscape

# %%
import os
import json
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

from minima_volume.analysis_funcs import (  grab_folder_names,
                                            load_base_train_size,
                                            list_additional_data,
                                            load_param_num,
                                            multiple_minima_fixed_landscape,
                                            fixed_landscape_minima_labels,
                                            plot_fixed_landscape_minima_pair,
                                            plot_perturb_probs,
                                            model_volume_across_targets,
                                            append_cutoff_points,
                                            varying_landscape_minima_labels,
                                            plot_minima_volume_vs_data_level,                    
)

loss_value = 0.1  # Loss value to analyze
data_level_log = False #Is the data log distributed?
base_output_dir = "analysis"  # Root folder to save all plots
os.makedirs(base_output_dir, exist_ok=True)

# Data for the loss landscape levels
experiment_folders, data_modifications = grab_folder_names()

base_train_size = load_base_train_size(experiment_folders[0])
model_data_sizes = list_additional_data(experiment_folders[0])
num_params = load_param_num(experiment_folders[0], data_modifications[0], loss_value = loss_value)

base_shift = 0
if data_modifications[0].startswith("data_"):
    base_shift = base_train_size  # Shift to reflect true dataset size

print("Experiment folders: ", experiment_folders)
print("Different data levels where loss landscapes were computed:", data_modifications)
print("The base train size is: ", base_train_size)
print("Data levels where models were trained: ", model_data_sizes)
print("The number of model parameters is ", num_params)
# Out:
# First entry: Model_0, base_train_size = 6000
# Experiment folders:  ['model_0_data_10', 'model_1_data_11', 'model_2_data_12', 'model_3_data_13', 'model_4_data_14', 'model_5_data_15', 'model_6_data_16', 'model_7_data_17', 'model_8_data_18', 'model_9_data_19']
# Different data levels where loss landscapes were computed: ['poison_0']
# The base train size is:  6000
# Data levels where models were trained:  [0, 100, 1000, 2000, 500]
# The number of model parameters is  235146

# %% [markdown]
# ## Plotting Different Model Volumes In A Landscape

# %%
# Preparation for the specific plots
import matplotlib as mpl

#cmap = mpl.colormaps.get_cmap("winter")  # blue → green
#background_colors = [cmap(i) for i in np.linspace(0, 1, 10)]

natural_label = "Minima (Base Dataset)"
other_label = "Minima (Poisoned Datasets)"

# %%
for data_modification in data_modifications:
    print(f"\nProcessing data modification folder: {data_modification}")

    # Create output folder for this data_modification
    save_dir = os.path.join(base_output_dir, data_modification)
    os.makedirs(save_dir, exist_ok=True)

    # Get axis labels and titles
    labels = fixed_landscape_minima_labels(data_modification, base_train_size)

    # Extract minima landscapes
    all_mdl, all_log_rn, all_test_loss = multiple_minima_fixed_landscape(
        experiment_folders, data_modification, loss_value #mdl is modification data level
    )
    number_of_minima = len(all_mdl[0]) # Not used currently

    all_mdl = np.array(all_mdl)
    all_log_rn = np.array(all_log_rn)
    all_test_loss = np.array(all_test_loss)
    
    # Print types and shapes
    #for name, var in [("all_mdl", all_mdl), ("all_log_rn", all_log_rn), ("all_test_loss", all_test_loss)]:
    #    print(f"{name}: type={type(var)}, shape={var.shape}")

    # Save the data using np.savez_compressed
    save_dict = {
        'all_mdl': all_mdl,
        'all_log_rn': all_log_rn,
        'all_test_loss': all_test_loss,
        'data_modification': np.array([data_modification], dtype=object),
        'base_train_size': np.array([base_train_size]),
        'base_shift': np.array([base_shift]),
        'labels': labels
    }
    
    output_path = save_dir
    filename = 'minima_data.npz'
    np.savez_compressed(os.path.join(output_path, filename), **save_dict)
    
    print(f"Saved data to {os.path.join(output_path, filename)}")
    
    # Central tendency runs: mean and median
    for ct, suffix in [("mean", "_avg"), ("median", "_median")]:
        for ranking in [False, True]:
            out_dir = save_dir if not ranking else os.path.join(save_dir, "ranks") #handles ranking
            os.makedirs(out_dir, exist_ok=True)

            # --- Data-level plots: loop through shaded + errorbar ---
            #for avg_style in ["shaded", "errorbar"]:
            #    style_suffix = "_shaded" if avg_style == "shaded" else "_errbar"
            style_suffix = "_errbar"
            avg_style = "errorbar"

            # --- Data level vs Log Volume ---
            plot_fixed_landscape_minima_pair(
                all_mdl, all_log_rn,
                xlabel="Additional Poisoned Examples", ylabel="Log Volume",
                title=f"MNIST (Base Dataset: {base_train_size} Examples)",#labels["title_volume"],
                log_scale=data_level_log,
                ranking=ranking,
                alpha=0.7,
                output_dir=out_dir,
                filename="data_level_vs_log_volume" + suffix + style_suffix,
                show_plot=not ranking,
                plot_average=True,
                average_style=avg_style,
                central_tendency=ct,
                plot_x_error=(avg_style == "errorbar"),
                xlabel_size=14, ylabel_size=14, title_size=17,
                base_shift=base_shift,
                background_colors=None,#background_colors,         
                natural_label=natural_label,            
                other_label=other_label,               
                natural_marker="^",            
                other_marker="o",               
            )

            # --- Data level vs Test Loss ---
            plot_fixed_landscape_minima_pair(
                all_mdl, all_test_loss,
                xlabel="Additional Poisoned Examples", ylabel="Test Loss",
                title=f"MNIST Test Loss vs Dataset Size",
                log_scale=False,
                ranking=ranking,
                alpha=0.5,
                output_dir=out_dir,
                filename="data_level_vs_test_loss" + suffix + style_suffix,
                show_plot=not ranking,
                plot_average=True,
                average_style=avg_style,
                central_tendency=ct,
                plot_x_error=(avg_style == "errorbar"),
                xlabel_size=14, ylabel_size=14, title_size=17,
                base_shift=base_shift,
                background_colors=None,#background_colors,         
                natural_label=natural_label,            
                other_label=other_label,               
                natural_marker="^",            
                other_marker="o",               
            )

            # --- Log Volume vs Test Loss ---
            # Only error bar version (no shaded version)
            plot_fixed_landscape_minima_pair(
                all_log_rn, all_test_loss,
                xlabel="Log Volume", ylabel="Test Loss",
                title=f"MNIST (Base Dataset: {base_train_size} Examples)",
                log_scale=False,
                ranking=ranking,
                alpha=0.5,
                output_dir=out_dir,
                filename="log_volume_vs_test_loss" + suffix + "_errbar",
                show_plot=not ranking,
                plot_average=True,
                average_style="errorbar",
                central_tendency=ct,
                plot_x_error=True,  # allow x-error bars
                xlabel_size=14, ylabel_size=14, title_size=17,
                background_colors=None,#background_colors,         
                natural_label=natural_label,            
                other_label=other_label,               
                natural_marker="^",            
                other_marker="o",               
            )
# Out:
# Processing data modification folder: poison_0
# Saved data to analysis\poison_0\minima_data.npz

# %% [markdown]
# # Aggregrate Test Accuracy
#
# Test accuracy vs dataset size across all plots.

# %%
missing_folders = [folder for folder in experiment_folders
                   if not os.path.exists(os.path.join(folder, "test_accuracies.npz"))]

if missing_folders:
    print(f"⚠️ Skipping aggregation — missing test_accuracies.npz in: {missing_folders}")
else:
    # ---------- Step 2: Load all data ----------
    all_dataset_sizes = []
    all_accuracies = []

    for folder in experiment_folders:
        file_path = os.path.join(folder, "test_accuracies.npz")
        data = np.load(file_path)
        all_dataset_sizes.extend(data["dataset_sizes"])
        all_accuracies.extend(data["final_test_accuracies"])

    all_dataset_sizes = np.array(all_dataset_sizes)
    all_accuracies = np.array(all_accuracies)

    # ---------- Step 3: Group by dataset size ----------
    grouped_data = defaultdict(list)
    for size, acc in zip(all_dataset_sizes, all_accuracies):
        grouped_data[size].append(acc)

    sorted_sizes = np.array(sorted(grouped_data.keys()))
    mean_accs = np.array([np.mean(grouped_data[size]) for size in sorted_sizes])
    std_accs = np.array([np.std(grouped_data[size]) for size in sorted_sizes])

    # ---------- Step 4: Plot with error bars ----------
    plt.figure(figsize=(10, 6))
    plt.errorbar(
        sorted_sizes, mean_accs, yerr=std_accs,
        fmt='o-', capsize=4, linewidth=2, markersize=8,
        color='tab:blue', ecolor='black', elinewidth=1, alpha=0.8
    )

    plt.xlabel("Total Dataset Size", fontsize=12)
    plt.ylabel("Final Test Accuracy", fontsize=12)
    plt.title("Test Accuracy vs. Dataset Size (Mean ± Std)", fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.ylim((0.5, 1.0))
    plt.tight_layout()

    os.makedirs(base_output_dir, exist_ok=True)
    plot_path = os.path.join(base_output_dir, "test_acc_plot.png")
    plt.savefig(plot_path, bbox_inches="tight")
    plt.show()
    plt.close()

    print(f"✅ Plot saved to {plot_path}")

    # ---------- Step 5: Save combined data ----------
    save_path = os.path.join(base_output_dir, "test_acc.npz")
    np.savez(
        save_path,
        dataset_sizes=sorted_sizes,
        mean_accuracies=mean_accs,
        std_accuracies=std_accs,
        all_dataset_sizes=all_dataset_sizes,
        all_accuracies=all_accuracies
    )
    print(f"✅ Aggregated data saved to {save_path}")
# Out:
# ✅ Plot saved to analysis\test_acc_plot.png
# ✅ Aggregated data saved to analysis\test_acc.npz

# %% [markdown]
# # Comparisons Across Loss Landscapes

# %% [markdown]
# Here, we track the performance of all models across all loss landscapes.

# %%
# For the poisoning experiments, this plot has no meaning

labels = varying_landscape_minima_labels(
    data_modification_folder=data_modifications[0], # Random choice to grab datatype from
    base_train_size=base_train_size,
)

results_dict = model_volume_across_targets(
    target_model_data_levels=model_data_sizes,
    loss_value=loss_value,
    experiment_folders=experiment_folders
)
results_with_cutoff = append_cutoff_points(results_dict, threshold=loss_value, base_dir=".")

found_minima_vol, found_minima_dataset = plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],        
    base_train_size=base_train_size, 
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = data_level_log,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels",
    xlabel_size=15, ylabel_size=15, title_size=15
)
# Out:
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Model_0: first exceedance at index 6023 (value=0.10418359935283661, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=0, cutoff_idx=6023
# Model_0: first exceedance at index 6027 (value=0.10305581241846085, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=0, cutoff_idx=6027
# Model_0: first exceedance at index 6018 (value=0.10090529918670654, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=0, cutoff_idx=6018
# Model_0: first exceedance at index 6024 (value=0.10092336684465408, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=0, cutoff_idx=6024
# Model_0: first exceedance at index 6026 (value=0.1066279411315918, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=0, cutoff_idx=6026
# Model_0: first exceedance at index 6019 (value=0.10057193785905838, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=0, cutoff_idx=6019
# Model_0: first exceedance at index 6018 (value=0.10034696757793427, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=0, cutoff_idx=6018
# Model_0: first exceedance at index 6026 (value=0.1022011861205101, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=0, cutoff_idx=6026
# Model_0: first exceedance at index 6025 (value=0.10216940939426422, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=0, cutoff_idx=6025
# Model_0: first exceedance at index 6023 (value=0.10063204169273376, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=0, cutoff_idx=6023
# Model_100: first exceedance at index 6132 (value=0.10140572488307953, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=100, cutoff_idx=6132
# Model_100: first exceedance at index 6133 (value=0.10057882964611053, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=100, cutoff_idx=6133
# Model_100: first exceedance at index 6133 (value=0.10098516196012497, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=100, cutoff_idx=6133
# Model_100: first exceedance at index 6133 (value=0.10074654221534729, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=100, cutoff_idx=6133
# Model_100: first exceedance at index 6123 (value=0.10020142793655396, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=100, cutoff_idx=6123
# Model_100: first exceedance at index 6129 (value=0.10482868552207947, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=100, cutoff_idx=6129
# Model_100: first exceedance at index 6133 (value=0.10104766488075256, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=100, cutoff_idx=6133
# Model_100: first exceedance at index 6128 (value=0.10390490293502808, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=100, cutoff_idx=6128
# Model_100: first exceedance at index 6130 (value=0.10280226916074753, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=100, cutoff_idx=6130
# Model_100: first exceedance at index 6131 (value=0.10425329208374023, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=100, cutoff_idx=6131
# Model_500: first exceedance at index 6536 (value=0.10192926228046417, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=500, cutoff_idx=6536
# Model_500: first exceedance at index 6538 (value=0.10162664204835892, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=500, cutoff_idx=6538
# Model_500: first exceedance at index 6538 (value=0.10259213298559189, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=500, cutoff_idx=6538
# Model_500: first exceedance at index 6534 (value=0.10018288344144821, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=500, cutoff_idx=6534
# Model_500: first exceedance at index 6541 (value=0.1007377952337265, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=500, cutoff_idx=6541
# Model_500: first exceedance at index 6538 (value=0.10167130827903748, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=500, cutoff_idx=6538
# Model_500: first exceedance at index 6538 (value=0.10006977617740631, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=500, cutoff_idx=6538
# Model_500: first exceedance at index 6540 (value=0.10003866255283356, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=500, cutoff_idx=6540
# Model_500: first exceedance at index 6537 (value=0.10078899562358856, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=500, cutoff_idx=6537
# Model_500: first exceedance at index 6537 (value=0.10002429783344269, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=500, cutoff_idx=6537
# Model_1000: first exceedance at index 7050 (value=0.10020224750041962, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=1000, cutoff_idx=7050
# Model_1000: first exceedance at index 7043 (value=0.10128073394298553, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=1000, cutoff_idx=7043
# Model_1000: first exceedance at index 7042 (value=0.10224217921495438, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=1000, cutoff_idx=7042
# Model_1000: first exceedance at index 7043 (value=0.10149554908275604, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=1000, cutoff_idx=7043
# Model_1000: first exceedance at index 7045 (value=0.1019246056675911, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=1000, cutoff_idx=7045
# Model_1000: first exceedance at index 7036 (value=0.10083555430173874, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=1000, cutoff_idx=7036
# Model_1000: first exceedance at index 7048 (value=0.10007479041814804, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=1000, cutoff_idx=7048
# Model_1000: first exceedance at index 7046 (value=0.1005161926150322, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=1000, cutoff_idx=7046
# Model_1000: first exceedance at index 7045 (value=0.10134895145893097, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=1000, cutoff_idx=7045
# Model_1000: first exceedance at index 7047 (value=0.1001981571316719, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=1000, cutoff_idx=7047
# ⚠️ Skipped model_0_data_10 (target=2000): Model_2000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_1_data_11 (target=2000): Model_2000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_2_data_12 (target=2000): Model_2000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_3_data_13 (target=2000): Model_2000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_4_data_14 (target=2000): Model_2000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_5_data_15 (target=2000): Model_2000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_6_data_16 (target=2000): Model_2000: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_7_data_17 (target=2000): Model_2000: loss curve never exceeds threshold=0.1
# Model_2000: first exceedance at index 6 (value=0.10962750017642975, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=2000, cutoff_idx=6
# ⚠️ Skipped model_9_data_19 (target=2000): Model_2000: loss curve never exceeds threshold=0.1

# %%
_, _, = plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          
    base_train_size=base_train_size, 
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = True,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels_log",
    xlabel_size=15, ylabel_size=15, title_size=15,
)

# %% [markdown]
# ## Customized Plot

# %%
# We experiment a little with making customized graphs.

_, _, = plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          
    base_train_size=base_train_size, 
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = True,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels_log_custom",
    xlabel_size=15, ylabel_size=15, title_size=15,
    ylim = (500000, 1000000)
)

# %%
# Convert to numpy arrays
x = np.array(found_minima_vol)
y = np.array(found_minima_dataset)

# Fit a linear relationship: y = n * log(x) + log(k)
coefficients = np.polyfit(np.log(x), y, 1)

# Extract the exponent n and constant log(k)
exponent = coefficients[0]  # This is your exponent!
log_k = coefficients[1]  # log of the constant

print(f"Fitting to y = a * log(x) + log(k) ")
print(f"Exponent a = {exponent:.4f}")
print(f"Log k = {log_k:.4f}")
#print(f"Power law relationship: z = {k:.4f} × x^{n:.4f}")
print(f"y = {exponent:.4f} × log(x) + {log_k:.4f}")

print("The exponent divided by the number of parameters is ", exponent/num_params)

# Create the fit line for plotting
x_fit = np.linspace(min(x), max(x), 100)
y_fit = exponent * np.log(x_fit) + log_k

# Plot
plt.figure(figsize=(5, 4))
plt.plot(x, y, 'bo', label="Minima Volume (Found At This Dataset Size)")
plt.plot(x_fit, y_fit, 'k-', label=f'Fit: y = {exponent:.3f}·log(x) + {log_k:.3f}')
#plt.plot(xs, a*xs + b, '--', label=f"Fit: y = {np.exp(b):.2f} * x^{a:.2f}")
#plt.loglog(xs, fit_line, '--', label=f"Fit: y = {np.exp(b):.2f} * x^{a:.2f}")
plt.xscale("log")
plt.xlabel("Dataset Size")
plt.ylabel("Log Volume")
#plt.title("Log-Log Fit Through Large Dots")
plt.legend()
plt.grid(True, which="both")
output_path = os.path.join(base_output_dir, "scaling.png")
plt.savefig(output_path, dpi=300, bbox_inches='tight')
plt.show()
plt.close()  # Close the figure to free memory

print(f"Figure saved to: {output_path}")
# Out:
# C:\Users\raymo\AppData\Local\Temp\ipykernel_25680\4096500207.py:6: RuntimeWarning: divide by zero encountered in log
#   coefficients = np.polyfit(np.log(x), y, 1)
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\polynomial.py:668: RuntimeWarning: invalid value encountered in divide
#   lhs /= scale
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[8], line 6
#       3 y = np.array(found_minima_dataset)
#       5 # Fit a linear relationship: y = n * log(x) + log(k)
# ----> 6 coefficients = np.polyfit(np.log(x), y, 1)
#       8 # Extract the exponent n and constant log(k)
#       9 exponent = coefficients[0]  # This is your exponent!
#
# File L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\polynomial.py:669, in polyfit(x, y, deg, rcond, full, w, cov)
#     667 scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     668 lhs /= scale
# --> 669 c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     670 c = (c.T/scale).T  # broadcast scale coefficients
#     672 # warn on rank reduction, which indicates an ill conditioned matrix
#
# File L:\Programming\diffusion-env\Lib\site-packages\numpy\linalg\linalg.py:2326, in lstsq(a, b, rcond)
#    2323 if n_rhs == 0:
#    2324     # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2325     b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2326 x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2327 if m == 0:
#    2328     x[...] = 0
#
# File L:\Programming\diffusion-env\Lib\site-packages\numpy\linalg\linalg.py:124, in _raise_linalgerror_lstsq(err, flag)
#     123 def _raise_linalgerror_lstsq(err, flag):
# --> 124     raise LinAlgError("SVD did not converge in Linear Least Squares")
#
# LinAlgError: SVD did not converge in Linear Least Squares
