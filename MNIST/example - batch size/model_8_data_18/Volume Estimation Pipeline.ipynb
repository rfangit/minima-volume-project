# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.01, 0.005, 0.002]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}",
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
                max_perturbs = None, # Analyze all our perturbations!
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['data_0']
#
# ==================================================
# Analyzing directory: data_0
# ==================================================
#
# --- Using thresholds: loss=0.01, acc=0.95 ---
# Loaded data dictionary with 6 models from data_0
# The size of the base dataset is  6000
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_100: 2.6973393687512726e-06
# data_1000: 3.5219247365603223e-05
# data_200: 5.541244618711971e-08
# data_3000: 0.0001819022436393425
# data_500: 4.471577540243743e-06
# data_6000: 0.00030957895796746016
#
# Top perturbations for data_100:
# Top 5 r_vals: [17.92196763942296, 17.904878658173637, 17.891442849920452, 17.878100338085325, 17.875010315757205]
# Top 5 seeds: [384, 242, 237, 235, 219]
#
# Top perturbations for data_1000:
# Top 5 r_vals: [17.873317491593454, 16.077446046939567, 16.064054631004648, 16.06012820409349, 16.04836809142562]
# Top 5 seeds: [320, 173, 31, 458, 323]
#
# Top perturbations for data_200:
# Top 5 r_vals: [14.29848571534474, 12.708073474645445, 12.690310618814408, 12.6820302137537, 12.678753284103664]
# Top 5 seeds: [357, 333, 435, 5, 37]
#
# Top perturbations for data_3000:
# Top 5 r_vals: [16.06012820409349, 16.04231602692407, 16.041426225142047, 14.34068489989363, 14.32306643663992]
# Top 5 seeds: [458, 27, 320, 173, 237]
#
# Top perturbations for data_500:
# Top 5 r_vals: [17.873317491593454, 16.077446046939567, 16.076109326575413, 16.057935982696282, 16.053198443956614]
# Top 5 seeds: [320, 173, 246, 378, 342]
#
# Top perturbations for data_6000:
# Top 5 r_vals: [14.32523781167599, 14.309481169785572, 14.308556108228558, 14.27367192892965, 14.257823500775794]
# Top 5 seeds: [458, 476, 320, 77, 255]
# Plot saved to: data_0/loss_0.01/log_volume.png
# Test loss  [0.3610438375768928, 0.3471175320446491, 0.5395807569407225, 0.3339038759469986, 0.3898787278681993, 0.3274603128433228]
# log_exp_r_n  [678631.5380276587, 677992.3535840306, 625518.2726653063, 652838.9584439822, 677992.3535840306, 625957.8136823652]
# Plot saved to: data_0/loss_0.01/gen_log_volume.png
# Plot saved to: data_0/loss_0.01/test_vs_data.png
# Plot saved to: data_0/loss_0.01/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.01/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.95/avg_radius.png
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: divide by zero encountered in divide
#   return n/db/n.sum(), bin_edges
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Plot saved to: data_0/acc_0.95/radius_hist.png
# Plot saved to: data_0/acc_0.95/log_volume.png
# Plot saved to: data_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 3, 5, 2, 4, 1]
# test_loss ranks: [3, 4, 1, 5, 2, 6]
# log_exp_r_n ranks: [1, 2, 6, 4, 3, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.01\results.json
# Successfully analyzed data_0 with loss=0.01, acc=0.95
#
# --- Using thresholds: loss=0.005, acc=0.9 ---
# Loaded data dictionary with 6 models from data_0
# The size of the base dataset is  6000
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_100: 2.6973393687512726e-06
# data_1000: 3.5219247365603223e-05
# data_200: 5.541244618711971e-08
# data_3000: 0.0001819022436393425
# data_500: 4.471577540243743e-06
# data_6000: 0.00030957895796746016
#
# Top perturbations for data_100:
# Top 5 r_vals: [17.850511575618484, 16.085090069731404, 16.069752590715392, 16.0576938597624, 16.05665071345558]
# Top 5 seeds: [385, 384, 242, 237, 449]
#
# Top perturbations for data_1000:
# Top 5 r_vals: [16.041426225142047, 14.34068489989363, 14.32523781167599, 14.318321446766237, 14.3147480815494]
# Top 5 seeds: [320, 173, 458, 74, 323]
#
# Top perturbations for data_200:
# Top 5 r_vals: [12.678753284103664, 12.66578665442302, 12.661043037700237, 12.651395584634223, 12.633631931690646]
# Top 5 seeds: [37, 357, 251, 179, 253]
#
# Top perturbations for data_3000:
# Top 5 r_vals: [14.32523781167599, 14.308556108228558, 12.703167246964597, 12.687560580553006, 12.679944967350272]
# Top 5 seeds: [458, 320, 173, 237, 249]
#
# Top perturbations for data_500:
# Top 5 r_vals: [16.077446046939567, 14.339492578334246, 14.3232824043186, 14.31905663673908, 14.31609967927181]
# Top 5 seeds: [173, 246, 378, 342, 380]
#
# Top perturbations for data_6000:
# Top 5 r_vals: [12.689484013110908, 12.643806276145293, 12.62976753009897, 11.164893088152477, 11.151176291501665]
# Top 5 seeds: [458, 77, 255, 173, 237]
# Plot saved to: data_0/loss_0.005/log_volume.png
# Test loss  [0.3610438375768928, 0.3471175320446491, 0.5395807569407225, 0.3339038759469986, 0.3898787278681993, 0.3274603128433228]
# log_exp_r_n  [677692.1214540268, 652564.9719583901, 597247.6061669067, 625957.8136823652, 653092.3827899664, 597446.5390390704]
# Plot saved to: data_0/loss_0.005/gen_log_volume.png
# Plot saved to: data_0/loss_0.005/test_vs_data.png
# Plot saved to: data_0/loss_0.005/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.005/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.9/avg_radius.png
# Plot saved to: data_0/acc_0.9/radius_hist.png
# Plot saved to: data_0/acc_0.9/log_volume.png
# Plot saved to: data_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 3, 5, 2, 4, 1]
# test_loss ranks: [3, 4, 1, 5, 2, 6]
# log_exp_r_n ranks: [1, 3, 6, 4, 2, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.005\results.json
# Successfully analyzed data_0 with loss=0.005, acc=0.9
#
# --- Using thresholds: loss=0.002, acc=0.85 ---
# Loaded data dictionary with 6 models from data_0
# The size of the base dataset is  6000
# The number of model parameters is  235146
# The loss landscape is for data trained with 0
# data_100: 2.6973393687512726e-06
# data_1000: 3.5219247365603223e-05
# data_200: 5.541244618711971e-08
# data_3000: 0.0001819022436393425
# data_500: 4.471577540243743e-06
# data_6000: 0.00030957895796746016
#
# Top perturbations for data_100:
# Top 5 r_vals: [14.347503179482647, 14.333822526903548, 14.32766654819582, 14.32306643663992, 14.312385035198501]
# Top 5 seeds: [384, 242, 191, 237, 235]
#
# Top perturbations for data_1000:
# Top 5 r_vals: [12.703167246964597, 12.689484013110908, 12.677982476277933, 12.67552657254362, 12.675410194112848]
# Top 5 seeds: [173, 458, 205, 476, 27]
#
# Top perturbations for data_200:
# Top 5 r_vals: [12.66578665442302, 11.15359331731735, 11.146315617556963, 11.143435503606735, 11.127869857353723]
# Top 5 seeds: [357, 435, 5, 37, 251]
#
# Top perturbations for data_3000:
# Top 5 r_vals: [11.15286680839826, 11.140497240919494, 11.139879323015311, 9.725862423457272, 9.721208357346352]
# Top 5 seeds: [458, 27, 320, 173, 242]
#
# Top perturbations for data_500:
# Top 5 r_vals: [12.703167246964597, 12.70211107284971, 12.687751887562495, 12.68400864707683, 12.681389335271913]
# Top 5 seeds: [173, 246, 378, 342, 380]
#
# Top perturbations for data_6000:
# Top 5 r_vals: [9.715386197538042, 9.70470003210371, 9.704072654715562, 9.680414180173743, 9.67690684763513]
# Top 5 seeds: [458, 476, 320, 77, 296]
# Plot saved to: data_0/loss_0.002/log_volume.png
# Test loss  [0.3610438375768928, 0.3471175320446491, 0.5395807569407225, 0.3339038759469986, 0.3898787278681993, 0.3274603128433228]
# log_exp_r_n  [626323.0116404011, 597699.9633850545, 597006.9980220116, 567094.5888562398, 597699.9633850578, 534647.7933388985]
# Plot saved to: data_0/loss_0.002/gen_log_volume.png
# Plot saved to: data_0/loss_0.002/test_vs_data.png
# Plot saved to: data_0/loss_0.002/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.002/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 3, 5, 2, 4, 1]
# test_loss ranks: [3, 4, 1, 5, 2, 6]
# log_exp_r_n ranks: [1, 3, 4, 5, 2, 6]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.002\results.json
# Successfully analyzed data_0 with loss=0.002, acc=0.85
#
# Analysis complete for all directories!
