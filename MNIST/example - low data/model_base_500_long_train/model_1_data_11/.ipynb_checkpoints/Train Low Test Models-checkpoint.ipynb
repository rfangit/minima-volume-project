# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 11            
model_seed = 1           

# --- Training configuration ---
epochs = 4000            

# --- Dataset configuration ---
base_data_size = 60      
dataset_type = "data"   
dataset_quantities = [0, 600-60, 2000 - 60, 6000 - 60, 20000 - 60, 60000 - 60]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
from minima_volume.models import MNIST_model_data as model_module

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device = device
)

# MNIST specific initialization parameters
hidden_dims = [256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/4000: Train Loss 2.3464 | Test Loss 2.2391 | accs Train 0.0333 Test 0.3304
# Epoch 100/4000: Train Loss 0.0001 | Test Loss 1.7672 | accs Train 1.0000 Test 0.6860
# Epoch 200/4000: Train Loss 0.0001 | Test Loss 1.8319 | accs Train 1.0000 Test 0.6867
# Epoch 300/4000: Train Loss 0.0000 | Test Loss 1.8836 | accs Train 1.0000 Test 0.6862
# Epoch 400/4000: Train Loss 0.0000 | Test Loss 1.9309 | accs Train 1.0000 Test 0.6858
# Epoch 500/4000: Train Loss 0.0000 | Test Loss 1.9669 | accs Train 1.0000 Test 0.6860
# Epoch 600/4000: Train Loss 0.0000 | Test Loss 1.9976 | accs Train 1.0000 Test 0.6865
# Epoch 700/4000: Train Loss 0.0000 | Test Loss 2.0214 | accs Train 1.0000 Test 0.6857
# Epoch 800/4000: Train Loss 0.0000 | Test Loss 2.0419 | accs Train 1.0000 Test 0.6844
# Epoch 900/4000: Train Loss 0.0000 | Test Loss 2.0599 | accs Train 1.0000 Test 0.6822
# Epoch 1000/4000: Train Loss 0.0000 | Test Loss 2.0762 | accs Train 1.0000 Test 0.6815
# Epoch 1100/4000: Train Loss 0.0000 | Test Loss 2.0920 | accs Train 1.0000 Test 0.6806
# Epoch 1200/4000: Train Loss 0.0000 | Test Loss 2.1071 | accs Train 1.0000 Test 0.6797
# Epoch 1300/4000: Train Loss 0.0000 | Test Loss 2.1212 | accs Train 1.0000 Test 0.6788
# Epoch 1400/4000: Train Loss 0.0000 | Test Loss 2.1341 | accs Train 1.0000 Test 0.6786
# Epoch 1500/4000: Train Loss 0.0000 | Test Loss 2.1462 | accs Train 1.0000 Test 0.6780
# Epoch 1600/4000: Train Loss 0.0000 | Test Loss 2.1582 | accs Train 1.0000 Test 0.6773
# Epoch 1700/4000: Train Loss 0.0000 | Test Loss 2.1701 | accs Train 1.0000 Test 0.6773
# Epoch 1800/4000: Train Loss 0.0000 | Test Loss 2.1817 | accs Train 1.0000 Test 0.6769
# Epoch 1900/4000: Train Loss 0.0000 | Test Loss 2.1934 | accs Train 1.0000 Test 0.6765
# Epoch 2000/4000: Train Loss 0.0000 | Test Loss 2.2042 | accs Train 1.0000 Test 0.6758
# Epoch 2100/4000: Train Loss 0.0000 | Test Loss 2.2149 | accs Train 1.0000 Test 0.6754
# Epoch 2200/4000: Train Loss 0.0000 | Test Loss 2.2254 | accs Train 1.0000 Test 0.6755
# Epoch 2300/4000: Train Loss 0.0000 | Test Loss 2.2371 | accs Train 1.0000 Test 0.6753
# Epoch 2400/4000: Train Loss 0.0000 | Test Loss 2.2485 | accs Train 1.0000 Test 0.6752
# Epoch 2500/4000: Train Loss 0.0000 | Test Loss 2.2587 | accs Train 1.0000 Test 0.6758
# Epoch 2600/4000: Train Loss 0.0000 | Test Loss 2.2714 | accs Train 1.0000 Test 0.6759
# Epoch 2700/4000: Train Loss 0.0000 | Test Loss 2.2833 | accs Train 1.0000 Test 0.6757
# Epoch 2800/4000: Train Loss 0.0000 | Test Loss 2.2944 | accs Train 1.0000 Test 0.6754
# Epoch 2900/4000: Train Loss 0.0000 | Test Loss 2.3071 | accs Train 1.0000 Test 0.6756
# Epoch 3000/4000: Train Loss 0.0000 | Test Loss 2.3240 | accs Train 1.0000 Test 0.6752
# Epoch 3100/4000: Train Loss 0.0000 | Test Loss 2.3386 | accs Train 1.0000 Test 0.6748
# Epoch 3200/4000: Train Loss 0.0000 | Test Loss 2.3539 | accs Train 1.0000 Test 0.6745
# Epoch 3300/4000: Train Loss 0.0000 | Test Loss 2.3690 | accs Train 1.0000 Test 0.6735
# Epoch 3400/4000: Train Loss 0.0000 | Test Loss 2.3828 | accs Train 1.0000 Test 0.6731
# Epoch 3500/4000: Train Loss 0.0000 | Test Loss 2.3950 | accs Train 1.0000 Test 0.6729
# Epoch 3600/4000: Train Loss 0.0000 | Test Loss 2.4070 | accs Train 1.0000 Test 0.6725
# Epoch 3700/4000: Train Loss 0.0000 | Test Loss 2.4181 | accs Train 1.0000 Test 0.6728
# Epoch 3800/4000: Train Loss 0.0000 | Test Loss 2.4305 | accs Train 1.0000 Test 0.6721
# Epoch 3900/4000: Train Loss 0.0000 | Test Loss 2.4438 | accs Train 1.0000 Test 0.6718
# Epoch 4000/4000: Train Loss 0.0000 | Test Loss 2.4541 | accs Train 1.0000 Test 0.6720
# Completed training with 0 additional samples of data
# Epoch 1/4000: Train Loss 2.3214 | Test Loss 2.2004 | accs Train 0.0500 Test 0.2746
# Epoch 100/4000: Train Loss 0.0013 | Test Loss 0.6735 | accs Train 1.0000 Test 0.8721
# Epoch 200/4000: Train Loss 0.0005 | Test Loss 0.7188 | accs Train 1.0000 Test 0.8730
# Epoch 300/4000: Train Loss 0.0002 | Test Loss 0.7498 | accs Train 1.0000 Test 0.8736
# Epoch 400/4000: Train Loss 0.0002 | Test Loss 0.7727 | accs Train 1.0000 Test 0.8746
# Epoch 500/4000: Train Loss 0.0001 | Test Loss 0.7910 | accs Train 1.0000 Test 0.8752
# Epoch 600/4000: Train Loss 0.0001 | Test Loss 0.8063 | accs Train 1.0000 Test 0.8755
# Epoch 700/4000: Train Loss 0.0001 | Test Loss 0.8193 | accs Train 1.0000 Test 0.8755
# Epoch 800/4000: Train Loss 0.0000 | Test Loss 0.8306 | accs Train 1.0000 Test 0.8757
# Epoch 900/4000: Train Loss 0.0000 | Test Loss 0.8406 | accs Train 1.0000 Test 0.8752
# Epoch 1000/4000: Train Loss 0.0000 | Test Loss 0.8495 | accs Train 1.0000 Test 0.8755
# Epoch 1100/4000: Train Loss 0.0000 | Test Loss 0.8576 | accs Train 1.0000 Test 0.8755
# Epoch 1200/4000: Train Loss 0.0000 | Test Loss 0.8649 | accs Train 1.0000 Test 0.8755
# Epoch 1300/4000: Train Loss 0.0000 | Test Loss 0.8717 | accs Train 1.0000 Test 0.8756
# Epoch 1400/4000: Train Loss 0.0000 | Test Loss 0.8780 | accs Train 1.0000 Test 0.8757
# Epoch 1500/4000: Train Loss 0.0000 | Test Loss 0.8839 | accs Train 1.0000 Test 0.8757
# Epoch 1600/4000: Train Loss 0.0000 | Test Loss 0.8895 | accs Train 1.0000 Test 0.8759
# Epoch 1700/4000: Train Loss 0.0000 | Test Loss 0.8947 | accs Train 1.0000 Test 0.8760
# Epoch 1800/4000: Train Loss 0.0000 | Test Loss 0.8996 | accs Train 1.0000 Test 0.8763
# Epoch 1900/4000: Train Loss 0.0000 | Test Loss 0.9043 | accs Train 1.0000 Test 0.8762
# Epoch 2000/4000: Train Loss 0.0000 | Test Loss 0.9089 | accs Train 1.0000 Test 0.8760
# Epoch 2100/4000: Train Loss 0.0000 | Test Loss 0.9134 | accs Train 1.0000 Test 0.8758
# Epoch 2200/4000: Train Loss 0.0000 | Test Loss 0.9176 | accs Train 1.0000 Test 0.8759
# Epoch 2300/4000: Train Loss 0.0000 | Test Loss 0.9216 | accs Train 1.0000 Test 0.8760
# Epoch 2400/4000: Train Loss 0.0000 | Test Loss 0.9255 | accs Train 1.0000 Test 0.8761
# Epoch 2500/4000: Train Loss 0.0000 | Test Loss 0.9293 | accs Train 1.0000 Test 0.8762
# Epoch 2600/4000: Train Loss 0.0000 | Test Loss 0.9329 | accs Train 1.0000 Test 0.8765
# Epoch 2700/4000: Train Loss 0.0000 | Test Loss 0.9364 | accs Train 1.0000 Test 0.8766
# Epoch 2800/4000: Train Loss 0.0000 | Test Loss 0.9398 | accs Train 1.0000 Test 0.8767
# Epoch 2900/4000: Train Loss 0.0000 | Test Loss 0.9432 | accs Train 1.0000 Test 0.8769
# Epoch 3000/4000: Train Loss 0.0000 | Test Loss 0.9464 | accs Train 1.0000 Test 0.8772
# Epoch 3100/4000: Train Loss 0.0000 | Test Loss 0.9496 | accs Train 1.0000 Test 0.8768
# Epoch 3200/4000: Train Loss 0.0000 | Test Loss 0.9527 | accs Train 1.0000 Test 0.8767
# Epoch 3300/4000: Train Loss 0.0000 | Test Loss 0.9558 | accs Train 1.0000 Test 0.8766
# Epoch 3400/4000: Train Loss 0.0000 | Test Loss 0.9588 | accs Train 1.0000 Test 0.8766
# Epoch 3500/4000: Train Loss 0.0000 | Test Loss 0.9618 | accs Train 1.0000 Test 0.8767
# Epoch 3600/4000: Train Loss 0.0000 | Test Loss 0.9647 | accs Train 1.0000 Test 0.8768
# Epoch 3700/4000: Train Loss 0.0000 | Test Loss 0.9676 | accs Train 1.0000 Test 0.8769
# Epoch 3800/4000: Train Loss 0.0000 | Test Loss 0.9704 | accs Train 1.0000 Test 0.8769
# Epoch 3900/4000: Train Loss 0.0000 | Test Loss 0.9732 | accs Train 1.0000 Test 0.8770
# Epoch 4000/4000: Train Loss 0.0000 | Test Loss 0.9760 | accs Train 1.0000 Test 0.8771
# Completed training with 540 additional samples of data
# Epoch 1/4000: Train Loss 2.3176 | Test Loss 2.1926 | accs Train 0.0570 Test 0.3843
# Epoch 100/4000: Train Loss 0.0061 | Test Loss 0.4398 | accs Train 1.0000 Test 0.9068
# Epoch 200/4000: Train Loss 0.0011 | Test Loss 0.4983 | accs Train 1.0000 Test 0.9100
# Epoch 300/4000: Train Loss 0.0005 | Test Loss 0.5269 | accs Train 1.0000 Test 0.9106
# Epoch 400/4000: Train Loss 0.0003 | Test Loss 0.5471 | accs Train 1.0000 Test 0.9114
# Epoch 500/4000: Train Loss 0.0002 | Test Loss 0.5623 | accs Train 1.0000 Test 0.9116
# Epoch 600/4000: Train Loss 0.0001 | Test Loss 0.5743 | accs Train 1.0000 Test 0.9120
# Epoch 700/4000: Train Loss 0.0001 | Test Loss 0.5842 | accs Train 1.0000 Test 0.9126
# Epoch 800/4000: Train Loss 0.0001 | Test Loss 0.5928 | accs Train 1.0000 Test 0.9124
# Epoch 900/4000: Train Loss 0.0001 | Test Loss 0.6002 | accs Train 1.0000 Test 0.9128
# Epoch 1000/4000: Train Loss 0.0000 | Test Loss 0.6069 | accs Train 1.0000 Test 0.9124
# Epoch 1100/4000: Train Loss 0.0000 | Test Loss 0.6129 | accs Train 1.0000 Test 0.9129
# Epoch 1200/4000: Train Loss 0.0000 | Test Loss 0.6185 | accs Train 1.0000 Test 0.9130
# Epoch 1300/4000: Train Loss 0.0000 | Test Loss 0.6237 | accs Train 1.0000 Test 0.9128
# Epoch 1400/4000: Train Loss 0.0000 | Test Loss 0.6287 | accs Train 1.0000 Test 0.9129
# Epoch 1500/4000: Train Loss 0.0000 | Test Loss 0.6334 | accs Train 1.0000 Test 0.9135
# Epoch 1600/4000: Train Loss 0.0000 | Test Loss 0.6375 | accs Train 1.0000 Test 0.9136
# Epoch 1700/4000: Train Loss 0.0000 | Test Loss 0.6414 | accs Train 1.0000 Test 0.9139
# Epoch 1800/4000: Train Loss 0.0000 | Test Loss 0.6450 | accs Train 1.0000 Test 0.9138
# Epoch 1900/4000: Train Loss 0.0000 | Test Loss 0.6486 | accs Train 1.0000 Test 0.9137
# Epoch 2000/4000: Train Loss 0.0000 | Test Loss 0.6519 | accs Train 1.0000 Test 0.9138
# Epoch 2100/4000: Train Loss 0.0000 | Test Loss 0.6550 | accs Train 1.0000 Test 0.9136
# Epoch 2200/4000: Train Loss 0.0000 | Test Loss 0.6580 | accs Train 1.0000 Test 0.9137
# Epoch 2300/4000: Train Loss 0.0000 | Test Loss 0.6609 | accs Train 1.0000 Test 0.9138
# Epoch 2400/4000: Train Loss 0.0000 | Test Loss 0.6637 | accs Train 1.0000 Test 0.9139
# Epoch 2500/4000: Train Loss 0.0000 | Test Loss 0.6665 | accs Train 1.0000 Test 0.9140
# Epoch 2600/4000: Train Loss 0.0000 | Test Loss 0.6691 | accs Train 1.0000 Test 0.9144
# Epoch 2700/4000: Train Loss 0.0000 | Test Loss 0.6716 | accs Train 1.0000 Test 0.9144
# Epoch 2800/4000: Train Loss 0.0000 | Test Loss 0.6741 | accs Train 1.0000 Test 0.9144
# Epoch 2900/4000: Train Loss 0.0000 | Test Loss 0.6765 | accs Train 1.0000 Test 0.9144
# Epoch 3000/4000: Train Loss 0.0000 | Test Loss 0.6789 | accs Train 1.0000 Test 0.9145
# Epoch 3100/4000: Train Loss 0.0000 | Test Loss 0.6812 | accs Train 1.0000 Test 0.9142
# Epoch 3200/4000: Train Loss 0.0000 | Test Loss 0.6834 | accs Train 1.0000 Test 0.9144
# Epoch 3300/4000: Train Loss 0.0000 | Test Loss 0.6856 | accs Train 1.0000 Test 0.9147
# Epoch 3400/4000: Train Loss 0.0000 | Test Loss 0.6878 | accs Train 1.0000 Test 0.9147
# Epoch 3500/4000: Train Loss 0.0000 | Test Loss 0.6900 | accs Train 1.0000 Test 0.9146
# Epoch 3600/4000: Train Loss 0.0000 | Test Loss 0.6921 | accs Train 1.0000 Test 0.9144
# Epoch 3700/4000: Train Loss 0.0000 | Test Loss 0.6942 | accs Train 1.0000 Test 0.9144
# Epoch 3800/4000: Train Loss 0.0000 | Test Loss 0.6963 | accs Train 1.0000 Test 0.9142
# Epoch 3900/4000: Train Loss 0.0000 | Test Loss 0.6983 | accs Train 1.0000 Test 0.9143
# Epoch 4000/4000: Train Loss 0.0000 | Test Loss 0.7003 | accs Train 1.0000 Test 0.9142
# Completed training with 1940 additional samples of data
# Epoch 1/4000: Train Loss 2.3195 | Test Loss 2.1916 | accs Train 0.0628 Test 0.3848
# Epoch 100/4000: Train Loss 0.0296 | Test Loss 0.2433 | accs Train 0.9973 Test 0.9357
# Epoch 200/4000: Train Loss 0.0024 | Test Loss 0.2876 | accs Train 1.0000 Test 0.9418
# Epoch 300/4000: Train Loss 0.0009 | Test Loss 0.3122 | accs Train 1.0000 Test 0.9427
# Epoch 400/4000: Train Loss 0.0005 | Test Loss 0.3290 | accs Train 1.0000 Test 0.9431
# Epoch 500/4000: Train Loss 0.0003 | Test Loss 0.3419 | accs Train 1.0000 Test 0.9435
# Epoch 600/4000: Train Loss 0.0002 | Test Loss 0.3523 | accs Train 1.0000 Test 0.9434
# Epoch 700/4000: Train Loss 0.0002 | Test Loss 0.3611 | accs Train 1.0000 Test 0.9427
# Epoch 800/4000: Train Loss 0.0001 | Test Loss 0.3687 | accs Train 1.0000 Test 0.9426
# Epoch 900/4000: Train Loss 0.0001 | Test Loss 0.3754 | accs Train 1.0000 Test 0.9428
# Epoch 1000/4000: Train Loss 0.0001 | Test Loss 0.3813 | accs Train 1.0000 Test 0.9425
# Epoch 1100/4000: Train Loss 0.0001 | Test Loss 0.3867 | accs Train 1.0000 Test 0.9428
# Epoch 1200/4000: Train Loss 0.0001 | Test Loss 0.3916 | accs Train 1.0000 Test 0.9428
# Epoch 1300/4000: Train Loss 0.0000 | Test Loss 0.3961 | accs Train 1.0000 Test 0.9428
# Epoch 1400/4000: Train Loss 0.0000 | Test Loss 0.4003 | accs Train 1.0000 Test 0.9427
# Epoch 1500/4000: Train Loss 0.0000 | Test Loss 0.4043 | accs Train 1.0000 Test 0.9429
# Epoch 1600/4000: Train Loss 0.0000 | Test Loss 0.4080 | accs Train 1.0000 Test 0.9428
# Epoch 1700/4000: Train Loss 0.0000 | Test Loss 0.4115 | accs Train 1.0000 Test 0.9426
# Epoch 1800/4000: Train Loss 0.0000 | Test Loss 0.4149 | accs Train 1.0000 Test 0.9426
# Epoch 1900/4000: Train Loss 0.0000 | Test Loss 0.4180 | accs Train 1.0000 Test 0.9428
# Epoch 2000/4000: Train Loss 0.0000 | Test Loss 0.4210 | accs Train 1.0000 Test 0.9429
# Epoch 2100/4000: Train Loss 0.0000 | Test Loss 0.4238 | accs Train 1.0000 Test 0.9427
# Epoch 2200/4000: Train Loss 0.0000 | Test Loss 0.4266 | accs Train 1.0000 Test 0.9427
# Epoch 2300/4000: Train Loss 0.0000 | Test Loss 0.4292 | accs Train 1.0000 Test 0.9427
# Epoch 2400/4000: Train Loss 0.0000 | Test Loss 0.4318 | accs Train 1.0000 Test 0.9429
# Epoch 2500/4000: Train Loss 0.0000 | Test Loss 0.4342 | accs Train 1.0000 Test 0.9430
# Epoch 2600/4000: Train Loss 0.0000 | Test Loss 0.4366 | accs Train 1.0000 Test 0.9430
# Epoch 2700/4000: Train Loss 0.0000 | Test Loss 0.4389 | accs Train 1.0000 Test 0.9430
# Epoch 2800/4000: Train Loss 0.0000 | Test Loss 0.4411 | accs Train 1.0000 Test 0.9430
# Epoch 2900/4000: Train Loss 0.0000 | Test Loss 0.4433 | accs Train 1.0000 Test 0.9431
# Epoch 3000/4000: Train Loss 0.0000 | Test Loss 0.4454 | accs Train 1.0000 Test 0.9432
# Epoch 3100/4000: Train Loss 0.0000 | Test Loss 0.4474 | accs Train 1.0000 Test 0.9430
# Epoch 3200/4000: Train Loss 0.0000 | Test Loss 0.4495 | accs Train 1.0000 Test 0.9433
# Epoch 3300/4000: Train Loss 0.0000 | Test Loss 0.4515 | accs Train 1.0000 Test 0.9434
# Epoch 3400/4000: Train Loss 0.0000 | Test Loss 0.4534 | accs Train 1.0000 Test 0.9436
# Epoch 3500/4000: Train Loss 0.0000 | Test Loss 0.4553 | accs Train 1.0000 Test 0.9436
# Epoch 3600/4000: Train Loss 0.0000 | Test Loss 0.4572 | accs Train 1.0000 Test 0.9438
# Epoch 3700/4000: Train Loss 0.0000 | Test Loss 0.4591 | accs Train 1.0000 Test 0.9439
# Epoch 3800/4000: Train Loss 0.0000 | Test Loss 0.4609 | accs Train 1.0000 Test 0.9440
# Epoch 3900/4000: Train Loss 0.0000 | Test Loss 0.4627 | accs Train 1.0000 Test 0.9440
# Epoch 4000/4000: Train Loss 0.0000 | Test Loss 0.4644 | accs Train 1.0000 Test 0.9440
# Completed training with 5940 additional samples of data
# Epoch 1/4000: Train Loss 2.3221 | Test Loss 2.1926 | accs Train 0.0605 Test 0.4079
# Epoch 100/4000: Train Loss 0.0966 | Test Loss 0.1514 | accs Train 0.9748 Test 0.9550
# Epoch 200/4000: Train Loss 0.0138 | Test Loss 0.1360 | accs Train 0.9988 Test 0.9610
# Epoch 300/4000: Train Loss 0.0031 | Test Loss 0.1559 | accs Train 1.0000 Test 0.9622
# Epoch 400/4000: Train Loss 0.0013 | Test Loss 0.1698 | accs Train 1.0000 Test 0.9630
# Epoch 500/4000: Train Loss 0.0007 | Test Loss 0.1801 | accs Train 1.0000 Test 0.9633
# Epoch 600/4000: Train Loss 0.0005 | Test Loss 0.1881 | accs Train 1.0000 Test 0.9638
# Epoch 700/4000: Train Loss 0.0003 | Test Loss 0.1946 | accs Train 1.0000 Test 0.9640
# Epoch 800/4000: Train Loss 0.0003 | Test Loss 0.2001 | accs Train 1.0000 Test 0.9641
# Epoch 900/4000: Train Loss 0.0002 | Test Loss 0.2049 | accs Train 1.0000 Test 0.9640
# Epoch 1000/4000: Train Loss 0.0002 | Test Loss 0.2092 | accs Train 1.0000 Test 0.9640
# Epoch 1100/4000: Train Loss 0.0001 | Test Loss 0.2131 | accs Train 1.0000 Test 0.9643
# Epoch 1200/4000: Train Loss 0.0001 | Test Loss 0.2167 | accs Train 1.0000 Test 0.9644
# Epoch 1300/4000: Train Loss 0.0001 | Test Loss 0.2199 | accs Train 1.0000 Test 0.9644
# Epoch 1400/4000: Train Loss 0.0001 | Test Loss 0.2229 | accs Train 1.0000 Test 0.9644
# Epoch 1500/4000: Train Loss 0.0001 | Test Loss 0.2257 | accs Train 1.0000 Test 0.9646
# Epoch 1600/4000: Train Loss 0.0001 | Test Loss 0.2284 | accs Train 1.0000 Test 0.9648
# Epoch 1700/4000: Train Loss 0.0001 | Test Loss 0.2309 | accs Train 1.0000 Test 0.9647
# Epoch 1800/4000: Train Loss 0.0000 | Test Loss 0.2333 | accs Train 1.0000 Test 0.9645
# Epoch 1900/4000: Train Loss 0.0000 | Test Loss 0.2355 | accs Train 1.0000 Test 0.9646
# Epoch 2000/4000: Train Loss 0.0000 | Test Loss 0.2377 | accs Train 1.0000 Test 0.9646
# Epoch 2100/4000: Train Loss 0.0000 | Test Loss 0.2397 | accs Train 1.0000 Test 0.9648
# Epoch 2200/4000: Train Loss 0.0000 | Test Loss 0.2417 | accs Train 1.0000 Test 0.9650
# Epoch 2300/4000: Train Loss 0.0000 | Test Loss 0.2436 | accs Train 1.0000 Test 0.9648
# Epoch 2400/4000: Train Loss 0.0000 | Test Loss 0.2454 | accs Train 1.0000 Test 0.9646
# Epoch 2500/4000: Train Loss 0.0000 | Test Loss 0.2472 | accs Train 1.0000 Test 0.9646
# Epoch 2600/4000: Train Loss 0.0000 | Test Loss 0.2489 | accs Train 1.0000 Test 0.9645
# Epoch 2700/4000: Train Loss 0.0000 | Test Loss 0.2505 | accs Train 1.0000 Test 0.9646
# Epoch 2800/4000: Train Loss 0.0000 | Test Loss 0.2521 | accs Train 1.0000 Test 0.9646
# Epoch 2900/4000: Train Loss 0.0000 | Test Loss 0.2536 | accs Train 1.0000 Test 0.9645
# Epoch 3000/4000: Train Loss 0.0000 | Test Loss 0.2552 | accs Train 1.0000 Test 0.9646
# Epoch 3100/4000: Train Loss 0.0000 | Test Loss 0.2566 | accs Train 1.0000 Test 0.9646
# Epoch 3200/4000: Train Loss 0.0000 | Test Loss 0.2581 | accs Train 1.0000 Test 0.9646
# Epoch 3300/4000: Train Loss 0.0000 | Test Loss 0.2595 | accs Train 1.0000 Test 0.9646
# Epoch 3400/4000: Train Loss 0.0000 | Test Loss 0.2609 | accs Train 1.0000 Test 0.9646
# Epoch 3500/4000: Train Loss 0.0000 | Test Loss 0.2623 | accs Train 1.0000 Test 0.9646
# Epoch 3600/4000: Train Loss 0.0000 | Test Loss 0.2636 | accs Train 1.0000 Test 0.9645
# Epoch 3700/4000: Train Loss 0.0000 | Test Loss 0.2649 | accs Train 1.0000 Test 0.9646
# Epoch 3800/4000: Train Loss 0.0000 | Test Loss 0.2663 | accs Train 1.0000 Test 0.9646
# Epoch 3900/4000: Train Loss 0.0000 | Test Loss 0.2675 | accs Train 1.0000 Test 0.9646
# Epoch 4000/4000: Train Loss 0.0000 | Test Loss 0.2688 | accs Train 1.0000 Test 0.9648
# Completed training with 19940 additional samples of data
# Epoch 1/4000: Train Loss 2.3228 | Test Loss 2.1924 | accs Train 0.0581 Test 0.4226
# Epoch 100/4000: Train Loss 0.1249 | Test Loss 0.1349 | accs Train 0.9648 Test 0.9597
# Epoch 200/4000: Train Loss 0.0431 | Test Loss 0.0830 | accs Train 0.9889 Test 0.9742
# Epoch 300/4000: Train Loss 0.0147 | Test Loss 0.0801 | accs Train 0.9981 Test 0.9769
# Epoch 400/4000: Train Loss 0.0052 | Test Loss 0.0890 | accs Train 0.9998 Test 0.9760
# Epoch 500/4000: Train Loss 0.0024 | Test Loss 0.0989 | accs Train 1.0000 Test 0.9761
# Epoch 600/4000: Train Loss 0.0013 | Test Loss 0.1068 | accs Train 1.0000 Test 0.9762
# Epoch 700/4000: Train Loss 0.0008 | Test Loss 0.1132 | accs Train 1.0000 Test 0.9760
# Epoch 800/4000: Train Loss 0.0006 | Test Loss 0.1184 | accs Train 1.0000 Test 0.9759
# Epoch 900/4000: Train Loss 0.0004 | Test Loss 0.1228 | accs Train 1.0000 Test 0.9762
# Epoch 1000/4000: Train Loss 0.0003 | Test Loss 0.1268 | accs Train 1.0000 Test 0.9761
# Epoch 1100/4000: Train Loss 0.0003 | Test Loss 0.1303 | accs Train 1.0000 Test 0.9760
# Epoch 1200/4000: Train Loss 0.0002 | Test Loss 0.1334 | accs Train 1.0000 Test 0.9760
# Epoch 1300/4000: Train Loss 0.0002 | Test Loss 0.1363 | accs Train 1.0000 Test 0.9760
# Epoch 1400/4000: Train Loss 0.0001 | Test Loss 0.1389 | accs Train 1.0000 Test 0.9760
# Epoch 1500/4000: Train Loss 0.0001 | Test Loss 0.1414 | accs Train 1.0000 Test 0.9761
# Epoch 1600/4000: Train Loss 0.0001 | Test Loss 0.1437 | accs Train 1.0000 Test 0.9761
# Epoch 1700/4000: Train Loss 0.0001 | Test Loss 0.1459 | accs Train 1.0000 Test 0.9762
# Epoch 1800/4000: Train Loss 0.0001 | Test Loss 0.1479 | accs Train 1.0000 Test 0.9761
# Epoch 1900/4000: Train Loss 0.0001 | Test Loss 0.1499 | accs Train 1.0000 Test 0.9761
# Epoch 2000/4000: Train Loss 0.0001 | Test Loss 0.1518 | accs Train 1.0000 Test 0.9760
# Epoch 2100/4000: Train Loss 0.0001 | Test Loss 0.1535 | accs Train 1.0000 Test 0.9760
# Epoch 2200/4000: Train Loss 0.0000 | Test Loss 0.1552 | accs Train 1.0000 Test 0.9760
# Epoch 2300/4000: Train Loss 0.0000 | Test Loss 0.1568 | accs Train 1.0000 Test 0.9761
# Epoch 2400/4000: Train Loss 0.0000 | Test Loss 0.1584 | accs Train 1.0000 Test 0.9761
# Epoch 2500/4000: Train Loss 0.0000 | Test Loss 0.1599 | accs Train 1.0000 Test 0.9761
# Epoch 2600/4000: Train Loss 0.0000 | Test Loss 0.1614 | accs Train 1.0000 Test 0.9761
# Epoch 2700/4000: Train Loss 0.0000 | Test Loss 0.1629 | accs Train 1.0000 Test 0.9761
# Epoch 2800/4000: Train Loss 0.0000 | Test Loss 0.1643 | accs Train 1.0000 Test 0.9761
# Epoch 2900/4000: Train Loss 0.0000 | Test Loss 0.1656 | accs Train 1.0000 Test 0.9762
# Epoch 3000/4000: Train Loss 0.0000 | Test Loss 0.1669 | accs Train 1.0000 Test 0.9760
# Epoch 3100/4000: Train Loss 0.0000 | Test Loss 0.1682 | accs Train 1.0000 Test 0.9759
# Epoch 3200/4000: Train Loss 0.0000 | Test Loss 0.1695 | accs Train 1.0000 Test 0.9759
# Epoch 3300/4000: Train Loss 0.0000 | Test Loss 0.1707 | accs Train 1.0000 Test 0.9759
# Epoch 3400/4000: Train Loss 0.0000 | Test Loss 0.1719 | accs Train 1.0000 Test 0.9761
# Epoch 3500/4000: Train Loss 0.0000 | Test Loss 0.1730 | accs Train 1.0000 Test 0.9761
# Epoch 3600/4000: Train Loss 0.0000 | Test Loss 0.1742 | accs Train 1.0000 Test 0.9761
# Epoch 3700/4000: Train Loss 0.0000 | Test Loss 0.1753 | accs Train 1.0000 Test 0.9760
# Epoch 3800/4000: Train Loss 0.0000 | Test Loss 0.1764 | accs Train 1.0000 Test 0.9760
# Epoch 3900/4000: Train Loss 0.0000 | Test Loss 0.1775 | accs Train 1.0000 Test 0.9760
# Epoch 4000/4000: Train Loss 0.0000 | Test Loss 0.1786 | accs Train 1.0000 Test 0.9761
# Completed training with 59940 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 2.4541 | accs: 0.6720
#  540 samples | Test Loss: 0.9760 | accs: 0.8771
# 1940 samples | Test Loss: 0.7003 | accs: 0.9142
# 5940 samples | Test Loss: 0.4644 | accs: 0.9440
# 19940 samples | Test Loss: 0.2688 | accs: 0.9648
# 59940 samples | Test Loss: 0.1786 | accs: 0.9761
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  540 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 540
#  Model    0 | Train Loss: 2.1752 | accs: 0.7133
#  Model  540 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 1940
#  Model    0 | Train Loss: 2.3772 | accs: 0.6855
#  Model  540 | Train Loss: 0.6761 | accs: 0.9085
#  Model 1940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 5940
#  Model    0 | Train Loss: 2.4304 | accs: 0.6742
#  Model  540 | Train Loss: 0.9303 | accs: 0.8822
#  Model 1940 | Train Loss: 0.5005 | accs: 0.9387
#  Model 5940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 19940
#  Model    0 | Train Loss: 2.4256 | accs: 0.6708
#  Model  540 | Train Loss: 1.0256 | accs: 0.8708
#  Model 1940 | Train Loss: 0.6952 | accs: 0.9176
#  Model 5940 | Train Loss: 0.3449 | accs: 0.9570
#  Model 19940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 59940
#  Model    0 | Train Loss: 2.4557 | accs: 0.6698
#  Model  540 | Train Loss: 1.0391 | accs: 0.8678
#  Model 1940 | Train Loss: 0.7561 | accs: 0.9098
#  Model 5940 | Train Loss: 0.4443 | accs: 0.9450
#  Model 19940 | Train Loss: 0.1775 | accs: 0.9759
#  Model 59940 | Train Loss: 0.0000 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_540.pt
# Saved model: models_and_data/model_additional_540.pt
# ✅ Model saved to models_and_data\model_additional_1940.pt
# Saved model: models_and_data/model_additional_1940.pt
# ✅ Model saved to models_and_data\model_additional_5940.pt
# Saved model: models_and_data/model_additional_5940.pt
# ✅ Model saved to models_and_data\model_additional_19940.pt
# Saved model: models_and_data/model_additional_19940.pt
# ✅ Model saved to models_and_data\model_additional_59940.pt
# Saved model: models_and_data/model_additional_59940.pt
