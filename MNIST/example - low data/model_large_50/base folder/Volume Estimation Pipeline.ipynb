
#
# Top perturbations for data_29940:
# Top 5 r_vals: [14.311151319834037, 12.69467799841853, 12.683179650035711, 12.675007652280382, 12.66471932073258]
# Top 5 seeds: [4, 7, 35, 11, 33]
#
# Top perturbations for data_540:
# Top 5 r_vals: [28.4708824753214, 26.1952926593707, 26.18893298104447, 26.17045515885756, 26.1431008004106]
# Top 5 seeds: [25, 48, 18, 33, 44]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [19.784693177434068, 17.876182703275656, 17.840817740566575, 16.041806559917354, 16.03533481566374]
# Top 5 seeds: [8, 48, 14, 11, 49]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.692586375114786, 11.152922855373696, 11.131100965487619, 11.122122940609936, 11.12143846692242]
# Top 5 seeds: [31, 29, 33, 36, 25]
# Plot saved to: data_0/loss_0.02/log_volume.png
# Test loss  [1.5887256466746331, 0.46807741224765775, 0.13011255860328674, 0.7671977418661118, 0.3333293259143829, 0.09866916388273239]
# log_exp_r_n  [860122.9344054488, 746921.694156712, 625728.7754749702, 787472.2706427679, 701885.3978444625, 597506.3237765833]
# Plot saved to: data_0/loss_0.02/gen_log_volume.png
# Plot saved to: data_0/loss_0.02/test_vs_data.png
# Plot saved to: data_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 4, 2, 5, 3, 1]
# test_loss ranks: [1, 3, 5, 2, 4, 6]
# log_exp_r_n ranks: [1, 3, 5, 2, 4, 6]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  5
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
# Results saved to data_0/loss_0.02\results.json
# Successfully analyzed data_0 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_2940
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from data_2940
# The number of model parameters is  235146
# The loss landscape is for data trained with 2940
# data_2940: 0.00022717672982253134
# data_29940: 0.0010422273771837354
# data_5940: 0.0003428877971600741
# data_59940: 0.0023517075460404158
#
# Top perturbations for data_2940:
# Top 5 r_vals: [26.18893298104447, 26.143469763877338, 23.963686342592595, 21.848758694006833, 21.838123640300378]
# Top 5 seeds: [18, 14, 11, 35, 4]
#
# Top perturbations for data_29940:
# Top 5 r_vals: [16.052149244576448, 16.040102619770146, 16.02878539030217, 14.313123824632655, 14.308895357457152]
# Top 5 seeds: [35, 18, 33, 37, 11]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [23.919545114776238, 21.834681150998627, 21.832361899131588, 19.817468203180802, 19.810552006411978]
# Top 5 seeds: [14, 11, 18, 35, 37]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [16.02878539030217, 14.31812077679813, 14.307375484918436, 12.678753284103664, 12.675007652280382]
# Top 5 seeds: [33, 35, 18, 37, 11]
# Plot saved to: data_2940/loss_0.1/log_volume.png
# Test loss  [0.46807741224765775, 0.13011255860328674, 0.3333293259143829, 0.09866916388273239]
# log_exp_r_n  [767827.0024796746, 652724.4072521231, 746513.1328909321, 652381.9036492191]
# Plot saved to: data_2940/loss_0.1/gen_log_volume.png
# Plot saved to: data_2940/loss_0.1/test_vs_data.png
# Plot saved to: data_2940/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_2940/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_2940/acc_0.95/avg_radius.png
# Plot saved to: data_2940/acc_0.95/radius_hist.png
# Plot saved to: data_2940/acc_0.95/log_volume.png
# Plot saved to: data_2940/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 3, 2, 4]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_2940/loss_0.1\results.json
# Successfully analyzed data_2940 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from data_2940
# The number of model parameters is  235146
# The loss landscape is for data trained with 2940
# data_2940: 0.00022717672982253134
# data_29940: 0.0010422273771837354
# data_5940: 0.0003428877971600741
# data_59940: 0.0023517075460404158
#
# Top perturbations for data_2940:
# Top 5 r_vals: [23.961140950520836, 23.919545114776238, 19.807821895964064, 19.80740465736915, 19.8046994566881]
# Top 5 seeds: [18, 14, 4, 48, 11]
#
# Top perturbations for data_29940:
# Top 5 r_vals: [14.297280795670767, 12.683179650035711, 12.675007652280382, 12.673661329201103, 12.655214550811143]
# Top 5 seeds: [33, 35, 11, 18, 28]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [19.76821910312086, 17.873741259661006, 17.871842733756246, 17.859233104626803, 16.06670184174845]
# Top 5 seeds: [14, 11, 18, 33, 7]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.66471932073258, 11.147325864289199, 11.138960152618157, 11.122239938671159, 11.103455094266529]
# Top 5 seeds: [33, 35, 18, 17, 2]
# Plot saved to: data_2940/loss_0.05/log_volume.png
# Test loss  [0.46807741224765775, 0.13011255860328674, 0.3333293259143829, 0.09866916388273239]
# log_exp_r_n  [746921.694156712, 625500.7588876021, 701689.5178103966, 596989.4842443073]
# Plot saved to: data_2940/loss_0.05/gen_log_volume.png
# Plot saved to: data_2940/loss_0.05/test_vs_data.png
# Plot saved to: data_2940/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_2940/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_2940/acc_0.9/avg_radius.png
# Plot saved to: data_2940/acc_0.9/radius_hist.png
# Plot saved to: data_2940/acc_0.9/log_volume.png
# Plot saved to: data_2940/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 3, 2, 4]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_2940/loss_0.05\results.json
# Successfully analyzed data_2940 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from data_2940
# The number of model parameters is  235146
# The loss landscape is for data trained with 2940
# data_2940: 0.00022717672982253134
# data_29940: 0.0010422273771837354
# data_5940: 0.0003428877971600741
# data_59940: 0.0023517075460404158
#
# Top perturbations for data_2940:
# Top 5 r_vals: [19.80259582687673, 19.76821910312086, 16.052149244576448, 16.04433573573089, 16.04399777246901]
# Top 5 seeds: [18, 14, 35, 4, 48]
#
# Top perturbations for data_29940:
# Top 5 r_vals: [9.710559419558594, 9.703271955169598, 9.696425729935884, 9.688706791020213, 9.688236868268389]
# Top 5 seeds: [35, 18, 33, 17, 20]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [16.012257473527892, 14.31812077679813, 14.308895357457152, 14.307375484918436, 14.304322241861087]
# Top 5 seeds: [14, 35, 11, 18, 30]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [8.37288031584389, 8.366596736855417, 8.360693614077368, 8.359032867465894, 8.339928493026862]
# Top 5 seeds: [35, 18, 33, 8, 2]
# Plot saved to: data_2940/loss_0.02/log_volume.png
# Test loss  [0.46807741224765775, 0.13011255860328674, 0.3333293259143829, 0.09866916388273239]
# log_exp_r_n  [702098.0790761765, 534533.2421470392, 652139.3101806461, 499680.855706921]
# Plot saved to: data_2940/loss_0.02/gen_log_volume.png
# Plot saved to: data_2940/loss_0.02/test_vs_data.png
# Plot saved to: data_2940/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_2940/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_2940/acc_0.85/avg_radius.png
# Plot saved to: data_2940/acc_0.85/radius_hist.png
# Plot saved to: data_2940/acc_0.85/log_volume.png
# Plot saved to: data_2940/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 3, 2, 4]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_2940/loss_0.02\results.json
# Successfully analyzed data_2940 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_29940
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_29940
# The number of model parameters is  235146
# The loss landscape is for data trained with 29940
# data_29940: 0.0010279032867401838
# data_59940: 0.0024260934442281723
#
# Top perturbations for data_29940:
# Top 5 r_vals: [16.052149244576448, 16.041806559917354, 16.040102619770146, 16.02878539030217, 14.313123824632655]
# Top 5 seeds: [35, 11, 18, 33, 37]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [14.31812077679813, 14.307375484918436, 14.297280795670767, 14.261771209969012, 12.678753284103664]
# Top 5 seeds: [35, 18, 33, 2, 37]
# Plot saved to: data_29940/loss_0.1/log_volume.png
# Test loss  [0.13011255860328674, 0.09866916388273239]
# log_exp_r_n  [652724.4072521231, 625843.2624905059]
# Plot saved to: data_29940/loss_0.1/gen_log_volume.png
# Plot saved to: data_29940/loss_0.1/test_vs_data.png
# Plot saved to: data_29940/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_29940/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_29940/acc_0.95/avg_radius.png
# Plot saved to: data_29940/acc_0.95/radius_hist.png
# Plot saved to: data_29940/acc_0.95/log_volume.png
# Plot saved to: data_29940/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_29940/loss_0.1\results.json
# Successfully analyzed data_29940 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_29940
# The number of model parameters is  235146
# The loss landscape is for data trained with 29940
# data_29940: 0.0010279032867401838
# data_59940: 0.0024260934442281723
#
# Top perturbations for data_29940:
# Top 5 r_vals: [14.297280795670767, 12.683179650035711, 12.675007652280382, 12.673661329201103, 12.655214550811143]
# Top 5 seeds: [33, 35, 11, 18, 28]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [11.147325864289199, 11.138960152618157, 11.131100965487619, 11.103455094266529, 9.71936284253919]
# Top 5 seeds: [35, 18, 33, 2, 7]
# Plot saved to: data_29940/loss_0.05/log_volume.png
# Test loss  [0.13011255860328674, 0.09866916388273239]
# log_exp_r_n  [625500.7588876021, 566980.0376643805]
# Plot saved to: data_29940/loss_0.05/gen_log_volume.png
# Plot saved to: data_29940/loss_0.05/test_vs_data.png
# Plot saved to: data_29940/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_29940/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_29940/acc_0.9/avg_radius.png
# Plot saved to: data_29940/acc_0.9/radius_hist.png
# Plot saved to: data_29940/acc_0.9/log_volume.png
# Plot saved to: data_29940/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_29940/loss_0.05\results.json
# Successfully analyzed data_29940 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_29940
# The number of model parameters is  235146
# The loss landscape is for data trained with 29940
# data_29940: 0.0010279032867401838
# data_59940: 0.0024260934442281723
#
# Top perturbations for data_29940:
# Top 5 r_vals: [9.710559419558594, 9.703271955169598, 9.696425729935884, 9.689148640464785, 9.688008620074646]
# Top 5 seeds: [35, 18, 33, 28, 25]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [8.37288031584389, 8.360693614077368, 8.339928493026862, 7.140756374110423, 7.137870627439165]
# Top 5 seeds: [35, 33, 2, 7, 29]
# Plot saved to: data_29940/loss_0.02/log_volume.png
# Test loss  [0.13011255860328674, 0.09866916388273239]
# log_exp_r_n  [534533.2421470392, 499680.855706921]
# Plot saved to: data_29940/loss_0.02/gen_log_volume.png
# Plot saved to: data_29940/loss_0.02/test_vs_data.png
# Plot saved to: data_29940/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_29940/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_29940/acc_0.85/avg_radius.png
# Plot saved to: data_29940/acc_0.85/radius_hist.png
# Plot saved to: data_29940/acc_0.85/log_volume.png
# Plot saved to: data_29940/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_29940/loss_0.02\results.json
# Successfully analyzed data_29940 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_540
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from data_540
# The number of model parameters is  235146
# The loss landscape is for data trained with 540
# data_2940: 0.00023233838146552444
# data_29940: 0.0007380543975159526
# data_540: 0.00010721592843765393
# data_5940: 0.0003324685094412416
# data_59940: 0.0017658494180068374
#
# Top perturbations for data_2940:
# Top 5 r_vals: [26.19171503147001, 26.18893298104447, 26.143469763877338, 21.848758694006833, 21.841133587069205]
# Top 5 seeds: [11, 18, 14, 35, 37]
#
# Top perturbations for data_29940:
# Top 5 r_vals: [17.873741259661006, 16.052149244576448, 16.040102619770146, 16.02878539030217, 16.01602551168647]
# Top 5 seeds: [11, 35, 18, 33, 17]
#
# Top perturbations for data_540:
# Top 5 r_vals: [36.090230894482836, 33.469942081802884, 33.44277445630947, 33.40781879220712, 30.933160609632672]
# Top 5 seeds: [18, 11, 33, 44, 41]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [23.919545114776238, 21.834681150998627, 21.77779425558856, 19.817468203180802, 19.810552006411978]
# Top 5 seeds: [14, 11, 6, 35, 37]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [16.
 30]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [14.31812077679813, 14.307375484918436, 14.297280795670767, 14.261771209969012, 12.678753284103664]
# Top 5 seeds: [35, 18, 33, 2, 37]
# Plot saved to: data_5940/loss_0.1/log_volume.png
# Test loss  [0.13011255860328674, 0.3333293259143829, 0.09866916388273239]
# log_exp_r_n  [677809.2852748598, 746513.1328909321, 625843.2624905059]
# Plot saved to: data_5940/loss_0.1/gen_log_volume.png
# Plot saved to: data_5940/loss_0.1/test_vs_data.png
# Plot saved to: data_5940/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.95/avg_radius.png
# Plot saved to: data_5940/acc_0.95/radius_hist.png
# Plot saved to: data_5940/acc_0.95/log_volume.png
# Plot saved to: data_5940/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [2, 1, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_5940/loss_0.1\results.json
# Successfully analyzed data_5940 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_5940
# The number of model parameters is  235146
# The loss landscape is for data trained with 5940
# data_29940: 0.0010109617142006755
# data_5940: 0.00035205911262892187
# data_59940: 0.0023646061308681965
#
# Top perturbations for data_29940:
# Top 5 r_vals: [14.297280795670767, 12.683179650035711, 12.673661329201103, 12.655214550811143, 12.653725544587289]
# Top 5 seeds: [33, 35, 18, 28, 25]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [19.76821910312086, 17.873741259661006, 17.871842733756246, 17.859233104626803, 17.855685592634245]
# Top 5 seeds: [14, 11, 18, 33, 8]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.66471932073258, 11.147325864289199, 11.138960152618157, 11.103455094266529, 9.715435020681088]
# Top 5 seeds: [33, 35, 18, 2, 29]
# Plot saved to: data_5940/loss_0.05/log_volume.png
# Test loss  [0.13011255860328674, 0.3333293259143829, 0.09866916388273239]
# log_exp_r_n  [625500.7588876021, 701689.5178103966, 596989.4842443073]
# Plot saved to: data_5940/loss_0.05/gen_log_volume.png
# Plot saved to: data_5940/loss_0.05/test_vs_data.png
# Plot saved to: data_5940/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.9/avg_radius.png
# Plot saved to: data_5940/acc_0.9/radius_hist.png
# Plot saved to: data_5940/acc_0.9/log_volume.png
# Plot saved to: data_5940/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [2, 1, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_5940/loss_0.05\results.json
# Successfully analyzed data_5940 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_5940
# The number of model parameters is  235146
# The loss landscape is for data trained with 5940
# data_29940: 0.0010109617142006755
# data_5940: 0.00035205911262892187
# data_59940: 0.0023646061308681965
#
# Top perturbations for data_29940:
# Top 5 r_vals: [11.131100965487619, 9.710559419558594, 9.703271955169598, 9.689148640464785, 9.688008620074646]
# Top 5 seeds: [33, 35, 18, 28, 25]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [16.012257473527892, 14.308895357457152, 14.307375484918436, 14.29886005932112, 14.297280795670767]
# Top 5 seeds: [14, 11, 18, 32, 33]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [8.37288031584389, 8.366596736855417, 8.360693614077368, 8.339928493026862, 7.140756374110423]
# Top 5 seeds: [35, 18, 33, 2, 7]
# Plot saved to: data_5940/loss_0.02/log_volume.png
# Test loss  [0.13011255860328674, 0.3333293259143829, 0.09866916388273239]
# log_exp_r_n  [566637.5340614767, 652139.3101806461, 499680.855706921]
# Plot saved to: data_5940/loss_0.02/gen_log_volume.png
# Plot saved to: data_5940/loss_0.02/test_vs_data.png
# Plot saved to: data_5940/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.85/avg_radius.png
# Plot saved to: data_5940/acc_0.85/radius_hist.png
# Plot saved to: data_5940/acc_0.85/log_volume.png
# Plot saved to: data_5940/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [2, 1, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_5940/loss_0.02\results.json
# Successfully analyzed data_5940 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_59940
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.002317112172022462
#
# Top perturbations for data_59940:
# Top 5 r_vals: [14.31812077679813, 14.307375484918436, 14.297280795670767, 14.261771209969012, 12.688592841291706]
# Top 5 seeds: [35, 18, 33, 2, 13]
# Plot saved to: data_59940/loss_0.1/log_volume.png
# Test loss  [0.09866916388273239]
# log_exp_r_n  [625843.2624905059]
# Plot saved to: data_59940/loss_0.1/gen_log_volume.png
# Plot saved to: data_59940/loss_0.1/test_vs_data.png
# Plot saved to: data_59940/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_59940/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_59940/acc_0.95/avg_radius.png
# Plot saved to: data_59940/acc_0.95/radius_hist.png
# Plot saved to: data_59940/acc_0.95/log_volume.png
# Plot saved to: data_59940/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_59940/loss_0.1\results.json
# Successfully analyzed data_59940 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.002317112172022462
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.66471932073258, 11.147325864289199, 11.140143444387054, 11.138960152618157, 11.103455094266529]
# Top 5 seeds: [33, 35, 11, 18, 2]
# Plot saved to: data_59940/loss_0.05/log_volume.png
# Test loss  [0.09866916388273239]
# log_exp_r_n  [596989.4842443073]
# Plot saved to: data_59940/loss_0.05/gen_log_volume.png
# Plot saved to: data_59940/loss_0.05/test_vs_data.png
# Plot saved to: data_59940/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_59940/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_59940/acc_0.9/avg_radius.png
# Plot saved to: data_59940/acc_0.9/radius_hist.png
# Plot saved to: data_59940/acc_0.9/log_volume.png
# Plot saved to: data_59940/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_59940/loss_0.05\results.json
# Successfully analyzed data_59940 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.002317112172022462
#
# Top perturbations for data_59940:
# Top 5 r_vals: [8.37288031584389, 8.360693614077368, 8.339928493026862, 7.140756374110423, 7.137870627439165]
# Top 5 seeds: [35, 33, 2, 7, 29]
# Plot saved to: data_59940/loss_0.02/log_volume.png
# Test loss  [0.09866916388273239]
# log_exp_r_n  [499680.855706921]
# Plot saved to: data_59940/loss_0.02/gen_log_volume.png
# Plot saved to: data_59940/loss_0.02/test_vs_data.png
# Plot saved to: data_59940/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_59940/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_59940/acc_0.85/avg_radius.png
# Plot saved to: data_59940/acc_0.85/radius_hist.png
# Plot saved to: data_59940/acc_0.85/log_volume.png
# Plot saved to: data_59940/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_59940/loss_0.02\results.json
# Successfully analyzed data_59940 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
# Plot saved to: data_350/acc_0.95/radius_hist.png
# Plot saved to: data_350/acc_0.95/log_volume.png
# Plot saved to: data_350/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Error analyzing data_350 with loss=0.1, acc=0.95: [Errno 2] No such file or directory: 'data_350/loss_0.1/results.json\\results.json'
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_350
# The number of model parameters is  4353
# The loss landscape is for data trained with 350
# data_350: 2.3195738322101533e-05
# data_750: 1.1681746400427073e-05
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.1941150003228307, 2.160993339601627, 1.9531046020146627, 1.9413953294025228, 1.7478336473956742]
# Top 5 seeds: [1476, 305, 1171, 1929, 1437]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.421819612354956, 2.3886636952553078, 2.221803775503616, 2.2098116283574383, 2.2092080865024535]
# Top 5 seeds: [1444, 1595, 1942, 1608, 799]
# Plot saved to: data_350/loss_0.05/log_volume.png
# Plot saved to: data_350/loss_0.05/gen_log_volume.png
# Plot saved to: data_350/loss_0.05/test_vs_data.png
# Plot saved to: data_350/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_350/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_350/acc_0.9/avg_radius.png
# Plot saved to: data_350/acc_0.9/radius_hist.png
# Plot saved to: data_350/acc_0.9/log_volume.png
# Plot saved to: data_350/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Error analyzing data_350 with loss=0.05, acc=0.9: [Errno 2] No such file or directory: 'data_350/loss_0.05/results.json\\results.json'
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_350
# The number of model parameters is  4353
# The loss landscape is for data trained with 350
# data_350: 2.3195738322101533e-05
# data_750: 1.1681746400427073e-05
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.927552701064415, 1.7336217286501379, 1.7300857374247527, 1.7197135097821652, 1.5361819166563542]
# Top 5 seeds: [305, 1476, 1171, 1929, 1437]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.421819612354956, 2.1438422084839877, 1.9817941083967443, 1.9710974092447524, 1.9705590648123743]
# Top 5 seeds: [1444, 1595, 1942, 1608, 799]
# Plot saved to: data_350/loss_0.02/log_volume.png
# Plot saved to: data_350/loss_0.02/gen_log_volume.png
# Plot saved to: data_350/loss_0.02/test_vs_data.png
# Plot saved to: data_350/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_350/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_350/acc_0.85/avg_radius.png
# Plot saved to: data_350/acc_0.85/radius_hist.png
# Plot saved to: data_350/acc_0.85/log_volume.png
# Plot saved to: data_350/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [2, 1]
# log_exp_r_n_acc ranks: [2, 1]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Error analyzing data_350 with loss=0.02, acc=0.85: [Errno 2] No such file or directory: 'data_350/loss_0.02/results.json\\results.json'
#
# ==================================================
# Analyzing directory: data_50
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from data_50
# The number of model parameters is  4353
# The loss landscape is for data trained with 50
# data_100: 2.068505455099512e-05
# data_200: 1.7079014469345566e-06
# data_350: 2.71648277703207e-05
# data_50: 1.2861079085269012e-05
# data_750: 2.2664107746095397e-05
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.9384502344332892, 2.766188820118005, 2.742967624078539, 2.7384237712310933, 2.6874032753752815]
# Top 5 seeds: [723, 167, 1942, 913, 34]
#
# Top perturbations for data_200:
# Top 5 r_vals: [3.25026410891686, 2.6264406688212625, 2.4478380724600712, 2.42404383268299, 2.4176240836755443]
# Top 5 seeds: [21, 1198, 492, 548, 450]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.4446775157917964, 2.2005791782347623, 2.160993339601627, 1.9708128268348242, 1.9531046020146627]
# Top 5 seeds: [1476, 1636, 305, 197, 1171]
#
# Top perturbations for data_50:
# Top 5 r_vals: [2.724934198359862, 2.7010454205685335, 2.685946054013941, 2.673532271698998, 2.465031871673052]
# Top 5 seeds: [1817, 672, 842, 1173, 1609]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.683456634188317, 2.6672634174964616, 2.4430248765310045, 2.4416139087145727, 2.440751759887484]
# Top 5 seeds: [1444, 282, 1418, 1461, 1245]
# Plot saved to: data_50/loss_0.1/log_volume.png
# Plot saved to: data_50/loss_0.1/gen_log_volume.png
# Plot saved to: data_50/loss_0.1/test_vs_data.png
# Plot saved to: data_50/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.95/avg_radius.png
# Plot saved to: data_50/acc_0.95/radius_hist.png
# Plot saved to: data_50/acc_0.95/log_volume.png
# Plot saved to: data_50/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [2, 1, 5, 3, 4]
# log_exp_r_n_acc ranks: [4, 2, 5, 1, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Error analyzing data_50 with loss=0.1, acc=0.95: [Errno 2] No such file or directory: 'data_50/loss_0.1/results.json\\results.json'
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from data_50
# The number of model parameters is  4353
# The loss landscape is for data trained with 50
# data_100: 2.068505455099512e-05
# data_200: 1.7079014469345566e-06
# data_350: 2.71648277703207e-05
# data_50: 1.2861079085269012e-05
# data_750: 2.2664107746095397e-05
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.6874032753752815, 2.681090517708653, 2.6652609836129613, 2.4964854101564997, 2.475528280730881]
# Top 5 seeds: [34, 500, 723, 167, 1942]
#
# Top perturbations for data_200:
# Top 5 r_vals: [3.25026410891686, 2.4478380724600712, 2.1755961268401345, 2.1734419893627326, 2.1698343576478565]
# Top 5 seeds: [21, 492, 548, 1237, 450]
#
# Top perturbations for data_350:
# Top 5 r_vals: [2.1941150003228307, 2.160993339601627, 1.962862291697057, 1.9531046020146627, 1.9413953294025228]
# Top 5 seeds: [1476, 305, 1636, 1171, 1929]
#
# Top perturbations for data_50:
# Top 5 r_vals: [2.4592531140197753, 2.4313383761163565, 2.212383175684401, 2.212251773550491, 2.1968794893627326]
# Top 5 seeds: [1817, 213, 1609, 1996, 389]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.440751759887484, 2.421819612354956, 2.4125467352375263, 2.4072052342905566, 2.2098116283574383]
# Top 5 seeds: [1245, 1444, 80, 282, 1608]
# Plot saved to: data_50/loss_0.05/log_volume.png
# Plot saved to: data_50/loss_0.05/gen_log_volume.png
# Plot saved to: data_50/loss_0.05/test_vs_data.png
# Plot saved to: data_50/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.9/avg_radius.png
# Plot saved to: data_50/acc_0.9/radius_hist.png
# Plot saved to: data_50/acc_0.9/log_volume.png
# Plot saved to: data_50/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [2, 1, 5, 3, 4]
# log_exp_r_n_acc ranks: [3, 4, 5, 1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Error analyzing data_50 with loss=0.05, acc=0.9: [Errno 2] No such file or directory: 'data_50/loss_0.05/results.json\\results.json'
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 5 models from data_50
# The number of model parameters is  4353
# The loss landscape is for data trained with 50
# data_100: 2.068505455099512e-05
# data_200: 1.7079014469345566e-06
# data_350: 2.71648277703207e-05
# data_50: 1.2861079085269012e-05
# data_750: 2.2664107746095397e-05
#
# Top perturbations for data_100:
# Top 5 r_vals: [2.4253814560261913, 2.419684192232059, 2.405398037710697, 2.2406129442955836, 2.221803775503616]
# Top 5 seeds: [34, 500, 723, 167, 1942]
#
# Top perturbations for data_200:
# Top 5 r_vals: [2.96150097527342, 2.196951621820119, 1.9811718515225454, 1.9728170518862478, 1.9530481354653408]
# Top 5 seeds: [21, 492, 1859, 58, 1051]
#
# Top perturbations for data_350:
# Top 5 r_vals: [1.9570964046089452, 1.927552701064415, 1.7457719158121623, 1.7300857374247527, 1.7197135097821652]
# Top 5 seeds: [1476, 305, 197, 1171, 1929]
#
# Top perturbations for data_50:
# Top 5 r_vals: [2.2071967006714877, 1.9732739585064567, 1.959562260573549, 1.9594637253201508, 1.9583226960844542]
# Top 5 seeds: [1817, 1996, 389, 939, 1995]
#
# Top perturbations for data_750:
# Top 5 r_vals: [2.421819612354956, 2.1905916072120353, 2.1652774022630425, 2.1604833681721334, 1.981950010064792]
# Top 5 seeds: [1444, 1245, 80, 282, 1778]
# Plot saved to: data_50/loss_0.02/log_volume.png
# Plot saved to: data_50/loss_0.02/gen_log_volume.png
# Plot saved to: data_50/loss_0.02/test_vs_data.png
# Plot saved to: data_50/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_50/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_50/acc_0.85/avg_radius.png
# Plot saved to: data_50/acc_0.85/radius_hist.png
# Plot saved to: data_50/acc_0.85/log_volume.png
# Plot saved to: data_50/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 3, 2, 5, 1]
# test_loss ranks: [2, 3, 4, 1, 5]
# log_exp_r_n ranks: [2, 1, 5, 4, 3]
# log_exp_r_n_acc ranks: [1, 4, 5, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Error analyzing data_50 with loss=0.02, acc=0.85: [Errno 2] No such file or directory: 'data_50/loss_0.02/results.json\\results.json'
#
# Analysis complete for all directories!
