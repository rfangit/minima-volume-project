
# Plot saved to: data_0/loss_0.02/gen_log_volume.png
# Plot saved to: data_0/loss_0.02/test_vs_data.png
# Plot saved to: data_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 4, 2, 5, 3, 1]
# test_loss ranks: [1, 3, 5, 2, 4, 6]
# log_exp_r_n ranks: [1, 3, 5, 2, 4, 6]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  5
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
# Error analyzing data_0 with loss=0.02, acc=0.85: name 'subset_sizes' is not defined
#
# ==================================================
# Analyzing directory: data_1940
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from data_1940
# The number of model parameters is  235146
# The loss landscape is for data trained with 1940
# data_1940: 0.0002089978806907311
# data_19940: 0.0008176960982382298
# data_5940: 0.00039263616781681776
# data_59940: 0.0026135225780308247
#
# Top perturbations for data_1940:
# Top 5 r_vals: [28.550478147956845, 28.529347093089992, 28.525446223599637, 28.523611469811758, 28.519672936753906]
# Top 5 seeds: [46, 218, 422, 392, 27]
#
# Top perturbations for data_19940:
# Top 5 r_vals: [19.835434372528958, 19.761660361506486, 19.748445730186976, 17.891442849920452, 17.88427588652864]
# Top 5 seeds: [7, 207, 56, 237, 334]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [23.99033233265818, 23.987419222608025, 23.969257872781636, 23.963686342592595, 23.959410867573304]
# Top 5 seeds: [46, 237, 326, 11, 412]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [16.051261460485538, 16.045718862990704, 16.028215392561982, 16.006944892820247, 15.996241041451446]
# Top 5 seeds: [334, 235, 130, 207, 56]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 4
# 500
# Plot saved to: data_1940/loss_0.1/log_volume.png
# Test loss  [0.5736378490924835, 0.16879180073738098, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [724295.288556126, 652294.175411323, 701349.6646685556, 596901.756006411]
# Plot saved to: data_1940/loss_0.1/gen_log_volume.png
# Plot saved to: data_1940/loss_0.1/test_vs_data.png
# Plot saved to: data_1940/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_1940/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_1940/acc_0.95/avg_radius.png
# Plot saved to: data_1940/acc_0.95/radius_hist.png
# Plot saved to: data_1940/acc_0.95/log_volume.png
# Plot saved to: data_1940/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 3, 2, 4]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Error analyzing data_1940 with loss=0.1, acc=0.95: name 'subset_sizes' is not defined
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from data_1940
# The number of model parameters is  235146
# The loss landscape is for data trained with 1940
# data_1940: 0.0002089978806907311
# data_19940: 0.0008176960982382298
# data_5940: 0.00039263616781681776
# data_59940: 0.0026135225780308247
#
# Top perturbations for data_1940:
# Top 5 r_vals: [23.99033233265818, 23.98359435281636, 23.98236762152778, 23.974648558063272, 23.972576376832563]
# Top 5 seeds: [46, 373, 202, 361, 218]
#
# Top perturbations for data_19940:
# Top 5 r_vals: [16.06670184174845, 16.045718862990704, 16.041806559917354, 16.039553807786675, 16.030074694925105]
# Top 5 seeds: [7, 235, 11, 308, 465]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [21.816957892355735, 19.826720936081145, 19.824313407114076, 19.809529460482356, 19.809304027092267]
# Top 5 seeds: [33, 46, 237, 235, 326]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.68247819100092, 12.678753284103664, 12.678098854708704, 12.665738030558108, 12.664268952147742]
# Top 5 seeds: [334, 322, 235, 465, 130]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 4
# 500
# Plot saved to: data_1940/loss_0.05/log_volume.png
# Test loss  [0.5736378490924835, 0.16879180073738098, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [677226.8386644456, 596901.756006411, 651799.457038805, 534103.0103062391]
# Plot saved to: data_1940/loss_0.05/gen_log_volume.png
# Plot saved to: data_1940/loss_0.05/test_vs_data.png
# Plot saved to: data_1940/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_1940/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_1940/acc_0.9/avg_radius.png
# Plot saved to: data_1940/acc_0.9/radius_hist.png
# Plot saved to: data_1940/acc_0.9/log_volume.png
# Plot saved to: data_1940/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 3, 2, 4]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Error analyzing data_1940 with loss=0.05, acc=0.9: name 'subset_sizes' is not defined
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from data_1940
# The number of model parameters is  235146
# The loss landscape is for data trained with 1940
# data_1940: 0.0002089978806907311
# data_19940: 0.0008176960982382298
# data_5940: 0.00039263616781681776
# data_59940: 0.0026135225780308247
#
# Top perturbations for data_1940:
# Top 5 r_vals: [19.826720936081145, 19.821152357699475, 19.820138530188252, 19.81375913889527, 19.81204659242361]
# Top 5 seeds: [46, 373, 202, 361, 218]
#
# Top perturbations for data_19940:
# Top 5 r_vals: [12.69467799841853, 12.678098854708704, 12.673227699979595, 12.665738030558108, 12.655836298591982]
# Top 5 seeds: [7, 235, 308, 465, 163]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [17.859233104626803, 16.0576938597624, 16.045718862990704, 16.045536261944733, 16.041806559917354]
# Top 5 seeds: [33, 237, 235, 326, 11]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [9.706669435636355, 9.697205679646054, 9.67673840779162, 8.390984348296731, 8.382854793670411]
# Top 5 seeds: [235, 465, 56, 419, 140]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 4
# 500
# Plot saved to: data_1940/loss_0.02/log_volume.png
# Test loss  [0.5736378490924835, 0.16879180073738098, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [651799.457038805, 534103.0103062391, 624918.3122771881, 461607.1787889182]
# Plot saved to: data_1940/loss_0.02/gen_log_volume.png
# Plot saved to: data_1940/loss_0.02/test_vs_data.png
# Plot saved to: data_1940/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_1940/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_1940/acc_0.85/avg_radius.png
# Plot saved to: data_1940/acc_0.85/radius_hist.png
# Plot saved to: data_1940/acc_0.85/log_volume.png
# Plot saved to: data_1940/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 3, 2, 4]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Error analyzing data_1940 with loss=0.02, acc=0.85: name 'subset_sizes' is not defined
#
# ==================================================
# Analyzing directory: data_19940
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_19940
# The number of model parameters is  235146
# The loss landscape is for data trained with 19940
# data_19940: 0.0007218651007860899
# data_59940: 0.0020485962741076946
#
# Top perturbations for data_19940:
# Top 5 r_vals: [19.748445730186976, 17.90147952120738, 17.891442849920452, 17.88205700545345, 17.87902318578681]
# Top 5 seeds: [56, 7, 237, 371, 322]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [16.051261460485538, 16.045718862990704, 16.028215392561982, 16.006944892820247, 15.997676628680269]
# Top 5 seeds: [334, 235, 130, 207, 370]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 2
# 500
# Plot saved to: data_19940/loss_0.1/log_volume.png
# Test loss  [0.16879180073738098, 0.09716315567493439]
# log_exp_r_n  [625413.0306497059, 596901.756006411]
# Plot saved to: data_19940/loss_0.1/gen_log_volume.png
# Plot saved to: data_19940/loss_0.1/test_vs_data.png
# Plot saved to: data_19940/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_19940/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_19940/acc_0.95/avg_radius.png
# Plot saved to: data_19940/acc_0.95/radius_hist.png
# Plot saved to: data_19940/acc_0.95/log_volume.png
# Plot saved to: data_19940/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Error analyzing data_19940 with loss=0.1, acc=0.95: name 'subset_sizes' is not defined
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_19940
# The number of model parameters is  235146
# The loss landscape is for data trained with 19940
# data_19940: 0.0007218651007860899
# data_59940: 0.0020485962741076946
#
# Top perturbations for data_19940:
# Top 5 r_vals: [16.06670184174845, 16.039553807786675, 16.006944892820247, 15.996241041451446, 15.99164776762655]
# Top 5 seeds: [7, 308, 207, 56, 42]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.68247819100092, 12.678753284103664, 12.678098854708704, 12.677081739108257, 12.673227699979595]
# Top 5 seeds: [334, 322, 235, 71, 308]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 2
# 500
# Plot saved to: data_19940/loss_0.05/log_volume.png
# Test loss  [0.16879180073738098, 0.09716315567493439]
# log_exp_r_n  [596901.756006411, 534103.0103062391]
# Plot saved to: data_19940/loss_0.05/gen_log_volume.png
# Plot saved to: data_19940/loss_0.05/test_vs_data.png
# Plot saved to: data_19940/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_19940/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_19940/acc_0.9/avg_radius.png
# Plot saved to: data_19940/acc_0.9/radius_hist.png
# Plot saved to: data_19940/acc_0.9/log_volume.png
# Plot saved to: data_19940/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Error analyzing data_19940 with loss=0.05, acc=0.9: name 'subset_sizes' is not defined
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_19940
# The number of model parameters is  235146
# The loss landscape is for data trained with 19940
# data_19940: 0.0007218651007860899
# data_59940: 0.0020485962741076946
#
# Top perturbations for data_19940:
# Top 5 r_vals: [12.69467799841853, 12.673227699979595, 12.64938686103459, 12.647462631364148, 12.639005267319662]
# Top 5 seeds: [7, 308, 93, 207, 56]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [9.673959760662978, 8.390984348296731, 8.380471022393484, 8.380209491637494, 8.378047784704687]
# Top 5 seeds: [42, 419, 7, 376, 394]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 2
# 500
# Plot saved to: data_19940/loss_0.02/log_volume.png
# Test loss  [0.16879180073738098, 0.09716315567493439]
# log_exp_r_n  [534103.0103062391, 462080.5129948641]
# Plot saved to: data_19940/loss_0.02/gen_log_volume.png
# Plot saved to: data_19940/loss_0.02/test_vs_data.png
# Plot saved to: data_19940/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_19940/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_19940/acc_0.85/avg_radius.png
# Plot saved to: data_19940/acc_0.85/radius_hist.png
# Plot saved to: data_19940/acc_0.85/log_volume.png
# Plot saved to: data_19940/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [1, 2]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Error analyzing data_19940 with loss=0.02, acc=0.85: name 'subset_sizes' is not defined
#
# ==================================================
# Analyzing directory: data_540
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from data_540
# The number of model parameters is  235146
# The loss landscape is for data trained with 540
# data_1940: 0.00023191994114313275
# data_19940: 0.0006831872742623091
# data_540: 0.00011267192894592881
# data_5940: 0.0004145340935792774
# data_59940: 0.0021421322599053383
#
# Top perturbations for data_1940:
# Top 5 r_vals: [30.979251462626785, 28.519672936753906, 28.495618471648303, 26.236308549036973, 26.22607310715166]
# Top 5 seeds: [46, 27, 33, 128, 383]
#
# Top perturbations for data_19940:
# Top 5 r_vals: [19.835434372528958, 19.826720936081145, 19.809529460482356, 19.8046994566881, 19.791367749464346]
# Top 5 seeds: [7, 46, 235, 11, 233]
#
# Top perturbations for data_540:
# Top 5 r_vals: [36.10745491469203, 36.10286744172909, 36.09406475981406, 36.090101510040036, 36.07767379382426]
# Top 5 seeds: [218, 235, 11, 40, 59]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [26.220838437967313, 26.174083848666598, 26.17045515885756, 23.969530647183642, 23.969257872781636]
# Top 5 seeds: [46, 233, 33, 235, 326]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [17.878100338085325, 17.85859801455209, 17.81785445713946, 16.059643958225724, 16.051261460485538]
# Top 5 seeds: [235, 130, 42, 46, 334]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 5
# 500
# Plot saved to: data_540/loss_0.1/log_volume.png
# Test loss  [0.5736378490924835, 0.16879180073738098, 0.7863510105013848, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [724295.288556126, 625413.0306497059, 746986.0455319663, 677226.8386644456, 596901.756006411]
# Plot saved to: data_540/loss_0.1/gen_log_volume.png
# Plot saved to: data_540/loss_0.1/test_vs_data.png
# Plot saved to: data_540/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_540/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_540/acc_0.95/avg_radius.png
# Plot saved to: data_540/acc_0.95/radius_hist.png
# Plot saved to: data_540/acc_0.95/log_volume.png
# Plot saved to: data_540/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 5, 3, 1]
# test_loss ranks: [2, 4, 1, 3, 5]
# log_exp_r_n ranks: [2, 4, 1, 3, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  3
# Error analyzing data_540 with loss=0.1, acc=0.95: name 'subset_sizes' is not defined
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from data_540
# The number of model parameters is  235146
# The loss landscape is for data trained with 540
# data_1940: 0.00023191994114313275
# data_19940: 0.0006831872742623091
# data_540: 0.00011267192894592881
# data_5940: 0.0004145340935792774
# data_59940: 0.0021421322599053383
#
# Top perturbations for data_1940:
# Top 5 r_vals: [26.220838437967313, 23.98359435281636, 23.98236762152778, 23.972576376832563, 23.969298562885804]
# Top 5 seeds: [46, 373, 202, 218, 422]
#
# Top perturbations for data_19940:
# Top 5 r_vals: [17.90147952120738, 17.84340868326076, 16.059643958225724, 16.045718862990704, 16.041806559917354]
# Top 5 seeds: [7, 34, 46, 235, 11]
#
# Top perturbations for data_540:
# Top 5 r_vals: [33.44277445630947, 31.01359191153466, 30.979251462626785, 30.958998654523857, 30.956322800661887]
# Top 5 seeds: [33, 173, 46, 361, 218]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [21.85895983202946, 21.81998294378444, 21.817843574685064, 21.816957892355735, 19.809529460482356]
# Top 5 seeds: [46, 233, 186, 33, 235]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [16.045718862990704, 14.324805876318628, 14.29926319898799, 14.29759124920887, 14.29677237176054]
# Top 5 seeds: [235, 46, 233, 360, 130]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 5
# 500
# Plot saved to: data_540/loss_0.05/log_volume.png
# Test loss  [0.5736378490924835, 0.16879180073738098, 0.7863510105013848, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [677226.8386644456, 567023.1400295264, 725108.0543390012, 651799.457038805, 566549.8058235804]
# Plot saved to: data_540/loss_0.05/gen_log_volume.png
# Plot saved to: data_540/loss_0.05/test_vs_data.png
# Plot saved to: data_540/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_540/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_540/acc_0.9/avg_radius.png
# Plot saved to: data_540/acc_0.9/radius_hist.png
# Plot saved to: data_540/acc_0.9/log_volume.png
# Plot saved to: data_540/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 5, 3, 1]
# test_loss ranks: [2, 4, 1, 3, 5]
# log_exp_r_n ranks: [2, 4, 1, 3, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  3
# Error analyzing data_540 with loss=0.05, acc=0.9: name 'subset_sizes' is not defined
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 5 models from data_540
# The number of model parameters is  235146
# The loss landscape is for data trained with 540
# data_1940: 0.00023191994114313275
# data_19940: 0.0006831872742623091
# data_540: 0.00011267192894592881
# data_5940: 0.0004145340935792774
# data_59940: 0.0021421322599053383
#
# Top perturbations for data_1940:
# Top 5 r_vals: [21.85895983202946, 21.83078552190047, 19.830679098035283, 19.821152357699475, 19.820138530188252]
# Top 5 seeds: [46, 412, 383, 373, 202]
#
# Top perturbations for data_19940:
# Top 5 r_vals: [14.331101334152171, 14.312385035198501, 14.29926319898799, 14.284612491585484, 14.264154953222452]
# Top 5 seeds: [7, 235, 233, 34, 42]
#
# Top perturbations for data_540:
# Top 5 r_vals: [28.525722423094585, 28.518767217630856, 28.513679049012858, 28.50581633092287, 28.495618471648303]
# Top 5 seeds: [235, 11, 412, 59, 33]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [17.86170939389157, 17.859958118959884, 17.859233104626803, 17.854292890682796, 16.059643958225724]
# Top 5 seeds: [233, 186, 33, 318, 46]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [11.142860321521322, 11.132644359073693, 11.131342668069188, 11.121238098985236, 9.71936284253919]
# Top 5 seeds: [235, 233, 360, 34, 7]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 5
# 500
# Plot saved to: data_540/loss_0.02/log_volume.png
# Test loss  [0.5736378490924835, 0.16879180073738098, 0.7863510105013848, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [624918.3122771881, 499723.95807206695, 701349.6646685556, 596407.0376338932, 462080.5129948641]
# Plot saved to: data_540/loss_0.02/gen_log_volume.png
# Plot saved to: data_540/loss_0.02/test_vs_data.png
# Plot saved to: data_540/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_540/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_540/acc_0.85/avg_radius.png
# Plot saved to: data_540/acc_0.85/radius_hist.png
# Plot saved to: data_540/acc_0.85/log_volume.png
# Plot saved to: data_540/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 5, 3, 1]
# test_loss ranks: [2, 4, 1, 3, 5]
# log_exp_r_n ranks: [2, 4, 1, 3, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  3
# Error analyzing data_540 with loss=0.02, acc=0.85: name 'subset_sizes' is not defined
#
# ==================================================
# Analyzing directory: data_5940
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 3 models from data_5940
# The number of model parameters is  235146
# The loss landscape is for data trained with 5940
# data_19940: 0.0007089984137564898
# data_5940: 0.00035999639658257365
# data_59940: 0.0022575354669243097
#
# Top perturbations for data_19940:
# Top 5 r_vals: [19.761660361506486, 19.748445730186976, 19.74277502176118, 17.90147952120738, 17.891442849920452]
# Top 5 seeds: [207, 56, 42, 7, 237]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [23.969530647183642, 23.969257872781636, 23.963686342592595, 23.959410867573304, 23.947298779899693]
# Top 5 seeds: [235, 326, 11, 412, 111]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [16.051261460485538, 16.046547125193698, 16.045718862990704, 16.030074694925105, 16.028215392561982]
# Top 5 seeds: [334, 322, 235, 465, 130]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 3
# 500
# Plot saved to: data_5940/loss_0.1/log_volume.png
# Test loss  [0.16879180073738098, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [652294.175411323, 701349.6646685556, 596901.756006411]
# Plot saved to: data_5940/loss_0.1/gen_log_volume.png
# Plot saved to: data_5940/loss_0.1/test_vs_data.png
# Plot saved to: data_5940/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.95/avg_radius.png
# Plot saved to: data_5940/acc_0.95/radius_hist.png
# Plot saved to: data_5940/acc_0.95/log_volume.png
# Plot saved to: data_5940/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [2, 1, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Error analyzing data_5940 with loss=0.1, acc=0.95: name 'subset_sizes' is not defined
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_5940
# The number of model parameters is  235146
# The loss landscape is for data trained with 5940
# data_19940: 0.0007089984137564898
# data_5940: 0.00035999639658257365
# data_59940: 0.0022575354669243097
#
# Top perturbations for data_19940:
# Top 5 r_vals: [16.06670184174845, 16.041806559917354, 16.039553807786675, 16.030074694925105, 16.02878539030217]
# Top 5 seeds: [7, 11, 308, 465, 33]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [21.816957892355735, 19.824313407114076, 19.809529460482356, 19.809304027092267, 19.8046994566881]
# Top 5 seeds: [33, 237, 235, 326, 11]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.683231462350783, 12.68247819100092, 12.678753284103664, 12.678098854708704, 12.67795457733905]
# Top 5 seeds: [417, 334, 322, 235, 326]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 3
# 500
# Plot saved to: data_5940/loss_0.05/log_volume.png
# Test loss  [0.16879180073738098, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [596901.756006411, 651799.457038805, 534103.0103062391]
# Plot saved to: data_5940/loss_0.05/gen_log_volume.png
# Plot saved to: data_5940/loss_0.05/test_vs_data.png
# Plot saved to: data_5940/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.9/avg_radius.png
# Plot saved to: data_5940/acc_0.9/radius_hist.png
# Plot saved to: data_5940/acc_0.9/log_volume.png
# Plot saved to: data_5940/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [2, 1, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Error analyzing data_5940 with loss=0.05, acc=0.9: name 'subset_sizes' is not defined
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_5940
# The number of model parameters is  235146
# The loss landscape is for data trained with 5940
# data_19940: 0.0007089984137564898
# data_5940: 0.00035999639658257365
# data_59940: 0.0022575354669243097
#
# Top perturbations for data_19940:
# Top 5 r_vals: [12.69467799841853, 12.673227699979595, 12.665738030558108, 12.66471932073258, 12.647462631364148]
# Top 5 seeds: [7, 308, 465, 33, 207]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [17.859233104626803, 16.0576938597624, 16.045718862990704, 16.045536261944733, 16.041806559917354]
# Top 5 seeds: [33, 237, 235, 326, 11]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [9.710022364985083, 9.706669435636355, 9.70293995779688, 9.697205679646054, 9.68321357713818]
# Top 5 seeds: [334, 235, 308, 465, 207]
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# Considering truncated radii!
# 5
# The shape of radii are:
# 3
# 500
# Plot saved to: data_5940/loss_0.02/log_volume.png
# Test loss  [0.16879180073738098, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [534103.0103062391, 596901.756006411, 462080.5129948641]
# Plot saved to: data_5940/loss_0.02/gen_log_volume.png
# Plot saved to: data_5940/loss_0.02/test_vs_data.png
# Plot saved to: data_5940/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_5940/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_5940/acc_0.85/avg_radius.png
# Plot saved to: data_5940/acc_0.85/radius_hist.png
# Plot saved to: data_5940/acc_0.85/log_volume.png
# Plot saved to: data_5940/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [2, 1, 3]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Error analyzing data_5940 with loss=0.02, acc=0.85: name 'subset_sizes' is not defined
#
# ==================================================
# Analyzing directory: data_59940
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.0021192370913922787
#
# Top perturbations for data_59940:
# Top 5 r_vals: [16.051261460485538, 16.045718862990704, 16.02878539030217, 16.028215392561982, 16.006944892820247]
# Top 5 seeds: [334, 235, 33, 130, 207]
# Considering truncated radii!
# 5
# The shape of radii are:
# 1
# 500
# Plot saved to: data_59940/loss_0.1/log_volume.png
# Test loss  [0.09716315567493439]
# log_exp_r_n  [596901.756006411]
# Plot saved to: data_59940/loss_0.1/gen_log_volume.png
# Plot saved to: data_59940/loss_0.1/test_vs_data.png
# Plot saved to: data_59940/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_59940/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_59940/acc_0.95/avg_radius.png
# Plot saved to: data_59940/acc_0.95/radius_hist.png
# Plot saved to: data_59940/acc_0.95/log_volume.png
# Plot saved to: data_59940/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Error analyzing data_59940 with loss=0.1, acc=0.95: name 'subset_sizes' is not defined
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.0021192370913922787
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.68247819100092, 12.678753284103664, 12.678098854708704, 12.665738030558108, 12.66471932073258]
# Top 5 seeds: [334, 322, 235, 465, 33]
# Considering truncated radii!
# 5
# The shape of radii are:
# 1
# 500
# Plot saved to: data_59940/loss_0.05/log_volume.png
# Test loss  [0.09716315567493439]
# log_exp_r_n  [534103.0103062391]
# Plot saved to: data_59940/loss_0.05/gen_log_volume.png
# Plot saved to: data_59940/loss_0.05/test_vs_data.png
# Plot saved to: data_59940/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_59940/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_59940/acc_0.9/avg_radius.png
# Plot saved to: data_59940/acc_0.9/radius_hist.png
# Plot saved to: data_59940/acc_0.9/log_volume.png
# Plot saved to: data_59940/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Error analyzing data_59940 with loss=0.05, acc=0.9: name 'subset_sizes' is not defined
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.0021192370913922787
#
# Top perturbations for data_59940:
# Top 5 r_vals: [9.696425729935884, 9.673959760662978, 8.390984348296731, 8.380471022393484, 8.378047784704687]
# Top 5 seeds: [33, 42, 419, 7, 394]
# Considering truncated radii!
# 5
# The shape of radii are:
# 1
# 500
# Plot saved to: data_59940/loss_0.02/log_volume.png
# Test loss  [0.09716315567493439]
# log_exp_r_n  [462080.5129948641]
# Plot saved to: data_59940/loss_0.02/gen_log_volume.png
# Plot saved to: data_59940/loss_0.02/test_vs_data.png
# Plot saved to: data_59940/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_59940/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_59940/acc_0.85/avg_radius.png
# Plot saved to: data_59940/acc_0.85/radius_hist.png
# Plot saved to: data_59940/acc_0.85/log_volume.png
# Plot saved to: data_59940/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Error analyzing data_59940 with loss=0.02, acc=0.85: name 'subset_sizes' is not defined
#
# Analysis complete for all directories!
# Loaded data dictionary with 3 models from data_5940
# The number of model parameters is  235146
# The loss landscape is for data trained with 5940
# data_19940: 0.0007089984137564898
# data_5940: 0.00035999639658257365
# data_59940: 0.0022575354669243097
#
# Top perturbations for data_19940:
# Top 5 r_vals: [19.761660361506486, 19.748445730186976, 19.74277502176118, 17.90147952120738, 17.891442849920452]
# Top 5 seeds: [207, 56, 42, 7, 237]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [23.969530647183642, 23.969257872781636, 23.963686342592595, 23.959410867573304, 23.947298779899693]
# Top 5 seeds: [235, 326, 11, 412, 111]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [16.051261460485538, 16.046547125193698, 16.045718862990704, 16.030074694925105, 16.028215392561982]
# Top 5 seeds: [334, 322, 235, 465, 130]
# Plot saved to: data_5940/loss_0.1/log_volume.png
# Test loss  [0.16879180073738098, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [701386.6616097371, 746946.6723902697, 651836.4539799865]
# Plot saved to: data_5940/loss_0.1/gen_log_volume.png
# Plot saved to: data_5940/loss_0.1/test_vs_data.png
# Error analyzing data_5940 with loss=0.1, acc=0.95: name 'power_mean_1' is not defined
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_5940
# The number of model parameters is  235146
# The loss landscape is for data trained with 5940
# data_19940: 0.0007089984137564898
# data_5940: 0.00035999639658257365
# data_59940: 0.0022575354669243097
#
# Top perturbations for data_19940:
# Top 5 r_vals: [16.06670184174845, 16.041806559917354, 16.039553807786675, 16.030074694925105, 16.02878539030217]
# Top 5 seeds: [7, 11, 308, 465, 33]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [21.816957892355735, 19.824313407114076, 19.809529460482356, 19.809304027092267, 19.8046994566881]
# Top 5 seeds: [33, 237, 235, 326, 11]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.683231462350783, 12.68247819100092, 12.678753284103664, 12.678098854708704, 12.67795457733905]
# Top 5 seeds: [417, 334, 322, 235, 326]
# Plot saved to: data_5940/loss_0.05/log_volume.png
# Test loss  [0.16879180073738098, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [652937.4899205893, 724877.7351665401, 596989.4842443073]
# Plot saved to: data_5940/loss_0.05/gen_log_volume.png
# Plot saved to: data_5940/loss_0.05/test_vs_data.png
# Error analyzing data_5940 with loss=0.05, acc=0.9: name 'power_mean_1' is not defined
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_5940
# The number of model parameters is  235146
# The loss landscape is for data trained with 5940
# data_19940: 0.0007089984137564898
# data_5940: 0.00035999639658257365
# data_59940: 0.0022575354669243097
#
# Top perturbations for data_19940:
# Top 5 r_vals: [12.69467799841853, 12.673227699979595, 12.665738030558108, 12.66471932073258, 12.647462631364148]
# Top 5 seeds: [7, 308, 465, 33, 207]
#
# Top perturbations for data_5940:
# Top 5 r_vals: [17.859233104626803, 16.0576938597624, 16.045718862990704, 16.045536261944733, 16.041806559917354]
# Top 5 seeds: [33, 237, 235, 326, 11]
#
# Top perturbations for data_59940:
# Top 5 r_vals: [9.710022364985083, 9.706669435636355, 9.70293995779688, 9.697205679646054, 9.68321357713818]
# Top 5 seeds: [334, 235, 308, 465, 207]
# Plot saved to: data_5940/loss_0.02/log_volume.png
# Test loss  [0.16879180073738098, 0.3294579029083252, 0.09716315567493439]
# log_exp_r_n  [597545.0705156773, 677809.2852748598, 499893.93837538717]
# Plot saved to: data_5940/loss_0.02/gen_log_volume.png
# Plot saved to: data_5940/loss_0.02/test_vs_data.png
# Error analyzing data_5940 with loss=0.02, acc=0.85: name 'power_mean_1' is not defined
#
# ==================================================
# Analyzing directory: data_59940
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.0021192370913922787
#
# Top perturbations for data_59940:
# Top 5 r_vals: [16.051261460485538, 16.045718862990704, 16.02878539030217, 16.028215392561982, 16.006944892820247]
# Top 5 seeds: [334, 235, 33, 130, 207]
# Plot saved to: data_59940/loss_0.1/log_volume.png
# Test loss  [0.09716315567493439]
# log_exp_r_n  [652381.9036492191]
# Plot saved to: data_59940/loss_0.1/gen_log_volume.png
# Plot saved to: data_59940/loss_0.1/test_vs_data.png
# Error analyzing data_59940 with loss=0.1, acc=0.95: name 'power_mean_1' is not defined
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.0021192370913922787
#
# Top perturbations for data_59940:
# Top 5 r_vals: [12.68247819100092, 12.678753284103664, 12.678098854708704, 12.665738030558108, 12.66471932073258]
# Top 5 seeds: [334, 322, 235, 465, 33]
# Plot saved to: data_59940/loss_0.05/log_volume.png
# Test loss  [0.09716315567493439]
# log_exp_r_n  [596989.4842443073]
# Plot saved to: data_59940/loss_0.05/gen_log_volume.png
# Plot saved to: data_59940/loss_0.05/test_vs_data.png
# Error analyzing data_59940 with loss=0.05, acc=0.9: name 'power_mean_1' is not defined
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 1 models from data_59940
# The number of model parameters is  235146
# The loss landscape is for data trained with 59940
# data_59940: 0.0021192370913922787
#
# Top perturbations for data_59940:
# Top 5 r_vals: [9.696425729935884, 9.673959760662978, 8.390984348296731, 8.380471022393484, 8.378047784704687]
# Top 5 seeds: [33, 42, 419, 7, 394]
# Plot saved to: data_59940/loss_0.02/log_volume.png
# Test loss  [0.09716315567493439]
# log_exp_r_n  [534190.7385441354]
# Plot saved to: data_59940/loss_0.02/gen_log_volume.png
# Plot saved to: data_59940/loss_0.02/test_vs_data.png
# Error analyzing data_59940 with loss=0.02, acc=0.85: name 'power_mean_1' is not defined
#
# Analysis complete for all directories!
