# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 18            
model_seed = 8           

# --- Training configuration ---
epochs = 700            

# --- Dataset configuration ---
base_data_size = 60      
dataset_type = "data"   
dataset_quantities = [0, 600-60, 2000 - 60, 6000 - 60, 20000 - 60, 60000 - 60]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
import MNIST_model_data as model_module

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device = device
)

# MNIST specific initialization parameters
hidden_dims = [256, 256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/700: Train Loss 2.3014 | Test Loss 2.2676 | accs Train 0.1000 Test 0.1931
# Epoch 100/700: Train Loss 0.0000 | Test Loss 2.0656 | accs Train 1.0000 Test 0.6982
# Epoch 200/700: Train Loss 0.0000 | Test Loss 2.0485 | accs Train 1.0000 Test 0.7007
# Epoch 300/700: Train Loss 0.0000 | Test Loss 2.0375 | accs Train 1.0000 Test 0.7012
# Epoch 400/700: Train Loss 0.0000 | Test Loss 2.0275 | accs Train 1.0000 Test 0.7015
# Epoch 500/700: Train Loss 0.0000 | Test Loss 2.0203 | accs Train 1.0000 Test 0.7034
# Epoch 600/700: Train Loss 0.0000 | Test Loss 2.0128 | accs Train 1.0000 Test 0.7051
# Epoch 700/700: Train Loss 0.0000 | Test Loss 2.0089 | accs Train 1.0000 Test 0.7065
# Completed training with 0 additional samples of data
# Epoch 1/700: Train Loss 2.2972 | Test Loss 2.2495 | accs Train 0.1133 Test 0.2277
# Epoch 100/700: Train Loss 0.0004 | Test Loss 0.9401 | accs Train 1.0000 Test 0.8578
# Epoch 200/700: Train Loss 0.0002 | Test Loss 0.9999 | accs Train 1.0000 Test 0.8586
# Epoch 300/700: Train Loss 0.0001 | Test Loss 1.0444 | accs Train 1.0000 Test 0.8579
# Epoch 400/700: Train Loss 0.0001 | Test Loss 1.0801 | accs Train 1.0000 Test 0.8578
# Epoch 500/700: Train Loss 0.0000 | Test Loss 1.1090 | accs Train 1.0000 Test 0.8583
# Epoch 600/700: Train Loss 0.0000 | Test Loss 1.1330 | accs Train 1.0000 Test 0.8575
# Epoch 700/700: Train Loss 0.0000 | Test Loss 1.1536 | accs Train 1.0000 Test 0.8588
# Completed training with 540 additional samples of data
# Epoch 1/700: Train Loss 2.3002 | Test Loss 2.2452 | accs Train 0.1000 Test 0.2921
# Epoch 100/700: Train Loss 0.0033 | Test Loss 0.5543 | accs Train 1.0000 Test 0.9015
# Epoch 200/700: Train Loss 0.0006 | Test Loss 0.6390 | accs Train 1.0000 Test 0.9018
# Epoch 300/700: Train Loss 0.0003 | Test Loss 0.6803 | accs Train 1.0000 Test 0.9027
# Epoch 400/700: Train Loss 0.0002 | Test Loss 0.7087 | accs Train 1.0000 Test 0.9033
# Epoch 500/700: Train Loss 0.0001 | Test Loss 0.7304 | accs Train 1.0000 Test 0.9036
# Epoch 600/700: Train Loss 0.0001 | Test Loss 0.7478 | accs Train 1.0000 Test 0.9034
# Epoch 700/700: Train Loss 0.0001 | Test Loss 0.7625 | accs Train 1.0000 Test 0.9039
# Completed training with 1940 additional samples of data
# Epoch 1/700: Train Loss 2.3015 | Test Loss 2.2452 | accs Train 0.0923 Test 0.3466
# Epoch 100/700: Train Loss 0.0238 | Test Loss 0.2469 | accs Train 0.9975 Test 0.9364
# Epoch 200/700: Train Loss 0.0014 | Test Loss 0.3186 | accs Train 1.0000 Test 0.9384
# Epoch 300/700: Train Loss 0.0005 | Test Loss 0.3490 | accs Train 1.0000 Test 0.9394
# Epoch 400/700: Train Loss 0.0003 | Test Loss 0.3688 | accs Train 1.0000 Test 0.9397
# Epoch 500/700: Train Loss 0.0002 | Test Loss 0.3835 | accs Train 1.0000 Test 0.9401
# Epoch 600/700: Train Loss 0.0001 | Test Loss 0.3951 | accs Train 1.0000 Test 0.9407
# Epoch 700/700: Train Loss 0.0001 | Test Loss 0.4048 | accs Train 1.0000 Test 0.9405
# Completed training with 5940 additional samples of data
# Epoch 1/700: Train Loss 2.3017 | Test Loss 2.2451 | accs Train 0.0978 Test 0.3230
# Epoch 100/700: Train Loss 0.0857 | Test Loss 0.1465 | accs Train 0.9760 Test 0.9557
# Epoch 200/700: Train Loss 0.0072 | Test Loss 0.1528 | accs Train 0.9998 Test 0.9623
# Epoch 300/700: Train Loss 0.0014 | Test Loss 0.1811 | accs Train 1.0000 Test 0.9626
# Epoch 400/700: Train Loss 0.0006 | Test Loss 0.1978 | accs Train 1.0000 Test 0.9625
# Epoch 500/700: Train Loss 0.0003 | Test Loss 0.2095 | accs Train 1.0000 Test 0.9627
# Epoch 600/700: Train Loss 0.0002 | Test Loss 0.2183 | accs Train 1.0000 Test 0.9624
# Epoch 700/700: Train Loss 0.0002 | Test Loss 0.2253 | accs Train 1.0000 Test 0.9629
# Completed training with 19940 additional samples of data
# Epoch 1/700: Train Loss 2.3013 | Test Loss 2.2446 | accs Train 0.0986 Test 0.3148
# Epoch 100/700: Train Loss 0.1183 | Test Loss 0.1302 | accs Train 0.9661 Test 0.9614
# Epoch 200/700: Train Loss 0.0352 | Test Loss 0.0849 | accs Train 0.9908 Test 0.9738
# Epoch 300/700: Train Loss 0.0098 | Test Loss 0.0916 | accs Train 0.9989 Test 0.9746
# Epoch 400/700: Train Loss 0.0032 | Test Loss 0.1042 | accs Train 0.9999 Test 0.9759
# Epoch 500/700: Train Loss 0.0014 | Test Loss 0.1148 | accs Train 1.0000 Test 0.9767
# Epoch 600/700: Train Loss 0.0008 | Test Loss 0.1228 | accs Train 1.0000 Test 0.9765
# Epoch 700/700: Train Loss 0.0005 | Test Loss 0.1291 | accs Train 1.0000 Test 0.9764
# Completed training with 59940 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 2.0089 | accs: 0.7065
#  540 samples | Test Loss: 1.1536 | accs: 0.8588
# 1940 samples | Test Loss: 0.7625 | accs: 0.9039
# 5940 samples | Test Loss: 0.4048 | accs: 0.9405
# 19940 samples | Test Loss: 0.2253 | accs: 0.9629
# 59940 samples | Test Loss: 0.1291 | accs: 0.9764
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  540 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0002 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0011 | accs: 1.0000
#
# Dataset type: data, additional samples: 540
#  Model    0 | Train Loss: 1.6951 | accs: 0.7467
#  Model  540 | Train Loss: 0.0000 | accs: 1.0000
#  Model 1940 | Train Loss: 0.0000 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0002 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0007 | accs: 1.0000
#
# Dataset type: data, additional samples: 1940
#  Model    0 | Train Loss: 1.8655 | accs: 0.7155
#  Model  540 | Train Loss: 0.7632 | accs: 0.8950
#  Model 1940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0002 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0005 | accs: 1.0000
#
# Dataset type: data, additional samples: 5940
#  Model    0 | Train Loss: 2.1379 | accs: 0.6907
#  Model  540 | Train Loss: 1.1554 | accs: 0.8540
#  Model 1940 | Train Loss: 0.5414 | accs: 0.9328
#  Model 5940 | Train Loss: 0.0001 | accs: 1.0000
#  Model 19940 | Train Loss: 0.0002 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0005 | accs: 1.0000
#
# Dataset type: data, additional samples: 19940
#  Model    0 | Train Loss: 2.1297 | accs: 0.6918
#  Model  540 | Train Loss: 1.1601 | accs: 0.8535
#  Model 1940 | Train Loss: 0.6752 | accs: 0.9128
#  Model 5940 | Train Loss: 0.2760 | accs: 0.9585
#  Model 19940 | Train Loss: 0.0002 | accs: 1.0000
#  Model 59940 | Train Loss: 0.0005 | accs: 1.0000
#
# Dataset type: data, additional samples: 59940
#  Model    0 | Train Loss: 2.1279 | accs: 0.6912
#  Model  540 | Train Loss: 1.1856 | accs: 0.8506
#  Model 1940 | Train Loss: 0.7389 | accs: 0.9054
#  Model 5940 | Train Loss: 0.3735 | accs: 0.9450
#  Model 19940 | Train Loss: 0.1637 | accs: 0.9740
#  Model 59940 | Train Loss: 0.0005 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_540.pt
# Saved model: models_and_data/model_additional_540.pt
# ✅ Model saved to models_and_data\model_additional_1940.pt
# Saved model: models_and_data/model_additional_1940.pt
# ✅ Model saved to models_and_data\model_additional_5940.pt
# Saved model: models_and_data/model_additional_5940.pt
# ✅ Model saved to models_and_data\model_additional_19940.pt
# Saved model: models_and_data/model_additional_19940.pt
# ✅ Model saved to models_and_data\model_additional_59940.pt
# Saved model: models_and_data/model_additional_59940.pt
