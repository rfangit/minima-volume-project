# %% [markdown]
# # Comparisons In A Given Loss Landscape

# %%
import os
import json
from pathlib import Path
import matplotlib.pyplot as plt

from minima_volume.analysis_funcs import (  grab_folder_names,
                                            load_base_train_size,
                                            list_additional_data,
                                            multiple_minima_fixed_landscape,
                                            fixed_landscape_minima_labels,
                                            plot_fixed_landscape_minima_pair,
                                            model_volume_across_targets,
                                            append_cutoff_points,
                                            varying_landscape_minima_labels,
                                            plot_minima_volume_vs_data_level,
)

loss_value = 0.1  # Loss value to analyze
data_level_log = False #Is the data log distributed?
base_output_dir = "analysis"  # Root folder to save all plots
os.makedirs(base_output_dir, exist_ok=True)

# Data for the loss landscape levels
experiment_folders, data_modifications = grab_folder_names()

base_train_size = load_base_train_size(experiment_folders[0])
model_data_sizes = list_additional_data(experiment_folders[0])

base_shift = 0
if data_modifications[0].startswith("data_"):
    base_shift = base_train_size  # Shift to reflect true dataset size

print("Experiment folders: ", experiment_folders)
print("Different data levels where loss landscapes were computed:", data_modifications)
print("The base train size is: ", base_train_size)
print("Data levels where models were trained: ", model_data_sizes)
# Out:
# First entry: Model_0, base_train_size = 60
# Experiment folders:  ['model_0_data_10', 'model_1_data_11', 'model_2_data_12', 'model_3_data_13', 'model_4_data_14', 'model_5_data_15', 'model_6_data_16', 'model_7_data_17', 'model_8_data_18', 'model_9_data_19']
# Different data levels where loss landscapes were computed: ['data_0', 'data_1940', 'data_19940', 'data_540', 'data_5940', 'data_59940']
# The base train size is:  60
# Data levels where models were trained:  [0, 1940, 19940, 540, 5940, 59940]

# %% [markdown]
# ## Plotting Different Model Volumes In A Landscape

# %%
for data_modification in data_modifications:
    print(f"\nProcessing data modification folder: {data_modification}")

    # Create output folder for this data_modification
    save_dir = os.path.join(base_output_dir, data_modification)
    os.makedirs(save_dir, exist_ok=True)

    # Get axis labels and titles
    labels = fixed_landscape_minima_labels(data_modification, base_train_size)

    # Extract minima landscapes
    all_mdl, all_log_rn, all_test_loss = multiple_minima_fixed_landscape(
        experiment_folders, data_modification, loss_value
    )

    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=data_level_log,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_log_volume",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="log_volume_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )

    ## Rank variant
    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_log_volume",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="log_volume_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )
# Out:
# Processing data modification folder: data_0
# Processing data modification folder: data_1940
# Processing data modification folder: data_19940
# Processing data modification folder: data_540
# Processing data modification folder: data_5940
# Processing data modification folder: data_59940

# %% [markdown]
# # Comparisons Across Loss Landscapes

# %% [markdown]
# Here, we track the performance of all models across all loss landscapes.

# %%
# For the poisoning experiments, this plot has no meaning

labels = varying_landscape_minima_labels(
    data_modification_folder=data_modifications[0], # Random choice to grab datatype from
    base_train_size=base_train_size,
)

results_dict = model_volume_across_targets(
    target_model_data_levels=model_data_sizes,
    loss_value=loss_value,
    experiment_folders=experiment_folders
)
results_with_cutoff = append_cutoff_points(results_dict, threshold=loss_value, base_dir=".")

plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          # NEW: needed for correct legend labels
    base_train_size=base_train_size,  # NEW: used for dataset size shifts
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = data_level_log,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels",
    xlabel_size=15, ylabel_size=15, title_size=15
)
# Out:
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Model_0: first exceedance at index 62 (value=0.12093748152256012, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=0, cutoff_idx=62
# Model_0: first exceedance at index 62 (value=0.29523277282714844, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=0, cutoff_idx=62
# Model_0: first exceedance at index 64 (value=0.12533143162727356, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=0, cutoff_idx=64
# Model_0: first exceedance at index 68 (value=0.2424452155828476, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=0, cutoff_idx=68
# Model_0: first exceedance at index 64 (value=0.19633957743644714, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=0, cutoff_idx=64
# Model_0: first exceedance at index 62 (value=0.12318136543035507, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=0, cutoff_idx=62
# Model_0: first exceedance at index 65 (value=0.10618417710065842, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=0, cutoff_idx=65
# Model_0: first exceedance at index 66 (value=0.16039633750915527, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=0, cutoff_idx=66
# Model_0: first exceedance at index 63 (value=0.19169756770133972, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=0, cutoff_idx=63
# Model_0: first exceedance at index 64 (value=0.14580567181110382, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=0, cutoff_idx=64
# Model_540: first exceedance at index 646 (value=0.11209677159786224, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=540, cutoff_idx=646
# Model_540: first exceedance at index 672 (value=0.10356535762548447, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=540, cutoff_idx=672
# Model_540: first exceedance at index 676 (value=0.10492362827062607, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=540, cutoff_idx=676
# Model_540: first exceedance at index 716 (value=0.11155926436185837, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=540, cutoff_idx=716
# Model_540: first exceedance at index 608 (value=0.1041242703795433, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=540, cutoff_idx=608
# Model_540: first exceedance at index 650 (value=0.10050570219755173, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=540, cutoff_idx=650
# Model_540: first exceedance at index 745 (value=0.10104416310787201, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=540, cutoff_idx=745
# Model_540: first exceedance at index 728 (value=0.11192760616540909, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=540, cutoff_idx=728
# Model_540: first exceedance at index 695 (value=0.1031346395611763, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=540, cutoff_idx=695
# Model_540: first exceedance at index 682 (value=0.12505362927913666, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=540, cutoff_idx=682
# Model_1940: first exceedance at index 2540 (value=0.101479172706604, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=1940, cutoff_idx=2540
# Model_1940: first exceedance at index 2516 (value=0.10408293455839157, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=1940, cutoff_idx=2516
# Model_1940: first exceedance at index 2617 (value=0.10298050940036774, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=1940, cutoff_idx=2617
# Model_1940: first exceedance at index 2580 (value=0.10261549055576324, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=1940, cutoff_idx=2580
# Model_1940: first exceedance at index 2555 (value=0.1002776101231575, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=1940, cutoff_idx=2555
# Model_1940: first exceedance at index 2536 (value=0.10773120075464249, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=1940, cutoff_idx=2536
# Model_1940: first exceedance at index 2361 (value=0.10150810331106186, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=1940, cutoff_idx=2361
# Model_1940: first exceedance at index 2337 (value=0.10244946926832199, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=1940, cutoff_idx=2337
# Model_1940: first exceedance at index 2394 (value=0.10580386966466904, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=1940, cutoff_idx=2394
# Model_1940: first exceedance at index 2464 (value=0.10148118436336517, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=1940, cutoff_idx=2464
# Model_5940: first exceedance at index 7646 (value=0.1012784019112587, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=5940, cutoff_idx=7646
# Model_5940: first exceedance at index 8432 (value=0.10030543804168701, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=5940, cutoff_idx=8432
# Model_5940: first exceedance at index 8461 (value=0.10024004429578781, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=5940, cutoff_idx=8461
# Model_5940: first exceedance at index 8658 (value=0.10075538605451584, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=5940, cutoff_idx=8658
# Model_5940: first exceedance at index 7729 (value=0.10121748596429825, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=5940, cutoff_idx=7729
# Model_5940: first exceedance at index 8313 (value=0.10003970563411713, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=5940, cutoff_idx=8313
# Model_5940: first exceedance at index 8717 (value=0.10096423327922821, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=5940, cutoff_idx=8717
# Model_5940: first exceedance at index 8075 (value=0.10048612952232361, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=5940, cutoff_idx=8075
# Model_5940: first exceedance at index 8992 (value=0.10085034370422363, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=5940, cutoff_idx=8992
# Model_5940: first exceedance at index 8675 (value=0.1011190116405487, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=5940, cutoff_idx=8675
# Model_19940: first exceedance at index 40250 (value=0.10004494339227676, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=19940, cutoff_idx=40250
# Model_19940: first exceedance at index 45042 (value=0.10000593960285187, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=19940, cutoff_idx=45042
# Model_19940: first exceedance at index 44049 (value=0.10001275688409805, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=19940, cutoff_idx=44049
# Model_19940: first exceedance at index 42797 (value=0.10013420134782791, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=19940, cutoff_idx=42797
# Model_19940: first exceedance at index 45497 (value=0.10012078285217285, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=19940, cutoff_idx=45497
# Model_19940: first exceedance at index 39875 (value=0.10003545880317688, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=19940, cutoff_idx=39875
# Model_19940: first exceedance at index 45149 (value=0.10005779564380646, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=19940, cutoff_idx=45149
# Model_19940: first exceedance at index 36454 (value=0.10021167248487473, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=19940, cutoff_idx=36454
# Model_19940: first exceedance at index 40132 (value=0.10002994537353516, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=19940, cutoff_idx=40132
# Model_19940: first exceedance at index 38496 (value=0.10000917315483093, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=19940, cutoff_idx=38496
# ⚠️ Skipped model_0_data_10 (target=59940): Model_59940: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_1_data_11 (target=59940): Model_59940: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_2_data_12 (target=59940): Model_59940: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_3_data_13 (target=59940): Model_59940: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_4_data_14 (target=59940): Model_59940: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_5_data_15 (target=59940): Model_59940: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_6_data_16 (target=59940): Model_59940: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_7_data_17 (target=59940): Model_59940: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_8_data_18 (target=59940): Model_59940: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_9_data_19 (target=59940): Model_59940: loss curve never exceeds threshold=0.1

# %%
plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          # NEW: needed for correct legend labels
    base_train_size=base_train_size,  # NEW: used for dataset size shifts
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = True,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels_log",
    xlabel_size=15, ylabel_size=15, title_size=15
)
