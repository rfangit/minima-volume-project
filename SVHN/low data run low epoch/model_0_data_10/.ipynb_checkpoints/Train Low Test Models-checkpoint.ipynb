# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 10            
model_seed = 0           

# --- Training configuration ---
epochs = 500            

# --- Dataset configuration ---
base_data_size = 60      
dataset_type = "data"   
dataset_quantities = [0, 600-60, 3000 - 60, 6000 - 60, 30000 - 60, 60000 - 60]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the model module name
from minima_volume.models import SVHN_model_data as model_module

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device = device
)

# Optional: you can keep hidden_dims or increase due to higher input size
hidden_dims = [512, 256]  # Suggested for SVHN, but your choice

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics (unchanged)
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/500: Train Loss 2.3011 | Test Loss 2.3403 | accs Train 0.0667 Test 0.1422
# Epoch 100/500: Train Loss 0.0000 | Test Loss 12.0049 | accs Train 1.0000 Test 0.1687
# Epoch 200/500: Train Loss 0.0000 | Test Loss 12.1110 | accs Train 1.0000 Test 0.1676
# Epoch 300/500: Train Loss 0.0000 | Test Loss 12.1709 | accs Train 1.0000 Test 0.1672
# Epoch 400/500: Train Loss 0.0000 | Test Loss 12.2176 | accs Train 1.0000 Test 0.1668
# Epoch 500/500: Train Loss 0.0000 | Test Loss 12.2590 | accs Train 1.0000 Test 0.1663
# Completed training with 0 additional samples of data
# Epoch 1/500: Train Loss 2.3105 | Test Loss 2.4162 | accs Train 0.0667 Test 0.2062
# Epoch 100/500: Train Loss 0.0032 | Test Loss 4.2233 | accs Train 1.0000 Test 0.4239
# Epoch 200/500: Train Loss 0.0010 | Test Loss 4.6598 | accs Train 1.0000 Test 0.4266
# Epoch 300/500: Train Loss 0.0005 | Test Loss 4.9253 | accs Train 1.0000 Test 0.4277
# Epoch 400/500: Train Loss 0.0003 | Test Loss 5.1157 | accs Train 1.0000 Test 0.4286
# Epoch 500/500: Train Loss 0.0002 | Test Loss 5.2668 | accs Train 1.0000 Test 0.4286
# Completed training with 540 additional samples of data
# Epoch 1/500: Train Loss 2.3145 | Test Loss 2.4239 | accs Train 0.0713 Test 0.1993
# Epoch 100/500: Train Loss 0.5081 | Test Loss 2.0781 | accs Train 0.9087 Test 0.5838
# Epoch 200/500: Train Loss 0.0192 | Test Loss 2.1024 | accs Train 1.0000 Test 0.6373
# Epoch 300/500: Train Loss 0.0063 | Test Loss 2.4009 | accs Train 1.0000 Test 0.6373
# Epoch 400/500: Train Loss 0.0031 | Test Loss 2.5954 | accs Train 1.0000 Test 0.6367
# Epoch 500/500: Train Loss 0.0019 | Test Loss 2.7365 | accs Train 1.0000 Test 0.6371
# Completed training with 2940 additional samples of data
# Epoch 1/500: Train Loss 2.3150 | Test Loss 2.4606 | accs Train 0.0773 Test 0.2000
# Epoch 100/500: Train Loss 0.4336 | Test Loss 1.4035 | accs Train 0.8762 Test 0.6438
# Epoch 200/500: Train Loss 0.0641 | Test Loss 1.5473 | accs Train 0.9975 Test 0.6965
# Epoch 300/500: Train Loss 0.0144 | Test Loss 1.9158 | accs Train 1.0000 Test 0.6966
# Epoch 400/500: Train Loss 0.0061 | Test Loss 2.1328 | accs Train 1.0000 Test 0.6977
# Epoch 500/500: Train Loss 0.0034 | Test Loss 2.2824 | accs Train 1.0000 Test 0.6981
# Completed training with 5940 additional samples of data
# Epoch 1/500: Train Loss 2.3159 | Test Loss 2.4875 | accs Train 0.0832 Test 0.1980
# Epoch 100/500: Train Loss 0.7010 | Test Loss 0.9805 | accs Train 0.7869 Test 0.7127
# Epoch 200/500: Train Loss 0.3798 | Test Loss 0.7958 | accs Train 0.8919 Test 0.7861
# Epoch 300/500: Train Loss 0.2374 | Test Loss 0.7975 | accs Train 0.9407 Test 0.8031
# Epoch 400/500: Train Loss 0.3436 | Test Loss 0.7958 | accs Train 0.9031 Test 0.7952
# Epoch 500/500: Train Loss 0.1939 | Test Loss 0.8423 | accs Train 0.9543 Test 0.8034
# Completed training with 29940 additional samples of data
# Epoch 1/500: Train Loss 2.3159 | Test Loss 2.4775 | accs Train 0.0836 Test 0.1979
# Epoch 100/500: Train Loss 0.7506 | Test Loss 0.9282 | accs Train 0.7719 Test 0.7285
# Epoch 200/500: Train Loss 0.4532 | Test Loss 0.7062 | accs Train 0.8709 Test 0.8060
# Epoch 300/500: Train Loss 0.6410 | Test Loss 0.8270 | accs Train 0.8062 Test 0.7639
# Epoch 400/500: Train Loss 0.3333 | Test Loss 0.6652 | accs Train 0.9082 Test 0.8263
# Epoch 500/500: Train Loss 0.3211 | Test Loss 0.6867 | accs Train 0.9085 Test 0.8258
# Completed training with 59940 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 12.2590 | accs: 0.1663
#  540 samples | Test Loss: 5.2668 | accs: 0.4286
# 2940 samples | Test Loss: 2.7365 | accs: 0.6371
# 5940 samples | Test Loss: 2.2824 | accs: 0.6981
# 29940 samples | Test Loss: 0.8423 | accs: 0.8034
# 59940 samples | Test Loss: 0.6867 | accs: 0.8258
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  540 | Train Loss: 0.0002 | accs: 1.0000
#  Model 2940 | Train Loss: 0.0018 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0031 | accs: 1.0000
#  Model 29940 | Train Loss: 0.1485 | accs: 0.9667
#  Model 59940 | Train Loss: 0.2730 | accs: 0.9167
#
# Dataset type: data, additional samples: 540
#  Model    0 | Train Loss: 9.9942 | accs: 0.2567
#  Model  540 | Train Loss: 0.0002 | accs: 1.0000
#  Model 2940 | Train Loss: 0.0017 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0032 | accs: 1.0000
#  Model 29940 | Train Loss: 0.2039 | accs: 0.9517
#  Model 59940 | Train Loss: 0.3544 | accs: 0.8917
#
# Dataset type: data, additional samples: 2940
#  Model    0 | Train Loss: 11.2111 | accs: 0.1700
#  Model  540 | Train Loss: 3.8437 | accs: 0.5280
#  Model 2940 | Train Loss: 0.0019 | accs: 1.0000
#  Model 5940 | Train Loss: 0.0033 | accs: 1.0000
#  Model 29940 | Train Loss: 0.1911 | accs: 0.9550
#  Model 59940 | Train Loss: 0.3274 | accs: 0.9030
#
# Dataset type: data, additional samples: 5940
#  Model    0 | Train Loss: 11.3608 | accs: 0.1673
#  Model  540 | Train Loss: 4.2028 | accs: 0.4787
#  Model 2940 | Train Loss: 1.0613 | accs: 0.8333
#  Model 5940 | Train Loss: 0.0034 | accs: 1.0000
#  Model 29940 | Train Loss: 0.2034 | accs: 0.9528
#  Model 59940 | Train Loss: 0.3314 | accs: 0.9065
#
# Dataset type: data, additional samples: 29940
#  Model    0 | Train Loss: 11.4854 | accs: 0.1600
#  Model  540 | Train Loss: 4.6368 | accs: 0.4331
#  Model 2940 | Train Loss: 1.9887 | accs: 0.6927
#  Model 5940 | Train Loss: 1.4790 | accs: 0.7773
#  Model 29940 | Train Loss: 0.1931 | accs: 0.9543
#  Model 59940 | Train Loss: 0.3192 | accs: 0.9079
#
# Dataset type: data, additional samples: 59940
#  Model    0 | Train Loss: 11.4701 | accs: 0.1598
#  Model  540 | Train Loss: 4.7264 | accs: 0.4261
#  Model 2940 | Train Loss: 2.1300 | accs: 0.6760
#  Model 5940 | Train Loss: 1.6795 | accs: 0.7488
#  Model 29940 | Train Loss: 0.4348 | accs: 0.8899
#  Model 59940 | Train Loss: 0.3188 | accs: 0.9088

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_540.pt
# Saved model: models_and_data/model_additional_540.pt
# ✅ Model saved to models_and_data\model_additional_2940.pt
# Saved model: models_and_data/model_additional_2940.pt
# ✅ Model saved to models_and_data\model_additional_5940.pt
# Saved model: models_and_data/model_additional_5940.pt
# ✅ Model saved to models_and_data\model_additional_29940.pt
# Saved model: models_and_data/model_additional_29940.pt
# ✅ Model saved to models_and_data\model_additional_59940.pt
# Saved model: models_and_data/model_additional_59940.pt
