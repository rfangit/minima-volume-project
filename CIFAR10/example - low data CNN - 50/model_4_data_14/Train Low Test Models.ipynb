# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 14            
model_seed = 4           

# --- Training configuration ---
epochs = 200            

# --- Dataset configuration ---
base_data_size = 50      
dataset_type = "data"   
dataset_quantities = [0, 500-50, 2000 - 50, 5000 - 50, 20000 - 50, 50000 - 50]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the CIFAR-10 model module name
import CIFAR10_CNN_model_data as model_module  # <- your new module for CIFAR-10

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device=device
)

# CIFAR-10 CNN initialization parameters
conv_channels = [32, 64, 128]  # adjust as desired
fc_dims = [512, 256]  # adjust as desired

# Grab model - use CNN parameters instead of MLP hidden_dims
model_template = model_module.get_model(
    conv_channels=conv_channels,  # CNN-specific parameter
    fc_dims=fc_dims,              # CNN-specific parameter
    device=device, 
    seed=model_seed
)

# Grab loss and metrics (these should remain the same)
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = min(len(x_train), 1024)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=50,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/200: Train Loss 2.3018 | Test Loss 2.3018 | accs Train 0.1000 Test 0.0988
# Epoch 50/200: Train Loss 0.0003 | Test Loss 19.1219 | accs Train 1.0000 Test 0.1861
# Epoch 100/200: Train Loss 0.0000 | Test Loss 21.4349 | accs Train 1.0000 Test 0.1876
# Epoch 150/200: Train Loss 0.0000 | Test Loss 21.5315 | accs Train 1.0000 Test 0.1888
# Epoch 200/200: Train Loss 0.0000 | Test Loss 21.5900 | accs Train 1.0000 Test 0.1893
# Completed training with 0 additional samples of data
# Epoch 1/200: Train Loss 2.3025 | Test Loss 2.2957 | accs Train 0.1080 Test 0.1000
# Epoch 50/200: Train Loss 0.8235 | Test Loss 2.0282 | accs Train 0.7040 Test 0.3766
# Epoch 100/200: Train Loss 0.0610 | Test Loss 3.7540 | accs Train 0.9940 Test 0.3694
# Epoch 150/200: Train Loss 0.0058 | Test Loss 5.2638 | accs Train 1.0000 Test 0.3671
# Epoch 200/200: Train Loss 0.0023 | Test Loss 5.8600 | accs Train 1.0000 Test 0.3662
# Completed training with 450 additional samples of data
# Epoch 1/200: Train Loss 2.2977 | Test Loss 2.2856 | accs Train 0.1230 Test 0.1000
# Epoch 50/200: Train Loss 0.9344 | Test Loss 1.4584 | accs Train 0.6685 Test 0.4829
# Epoch 100/200: Train Loss 0.1566 | Test Loss 2.2804 | accs Train 0.9650 Test 0.4976
# Epoch 150/200: Train Loss 0.0079 | Test Loss 3.1650 | accs Train 1.0000 Test 0.4965
# Epoch 200/200: Train Loss 0.0024 | Test Loss 3.6448 | accs Train 1.0000 Test 0.4966
# Completed training with 1950 additional samples of data
# Epoch 1/200: Train Loss 2.2706 | Test Loss 2.1604 | accs Train 0.1408 Test 0.2108
# Epoch 50/200: Train Loss 0.4859 | Test Loss 1.3705 | accs Train 0.8370 Test 0.5799
# Epoch 100/200: Train Loss 0.0053 | Test Loss 2.8981 | accs Train 1.0000 Test 0.5697
# Epoch 150/200: Train Loss 0.0013 | Test Loss 3.4261 | accs Train 1.0000 Test 0.5662
# Epoch 200/200: Train Loss 0.0006 | Test Loss 3.7050 | accs Train 1.0000 Test 0.5650
# Completed training with 4950 additional samples of data
# Epoch 1/200: Train Loss 2.0788 | Test Loss 1.8705 | accs Train 0.2348 Test 0.3152
# Epoch 50/200: Train Loss 0.0043 | Test Loss 2.0792 | accs Train 1.0000 Test 0.6873
# Epoch 100/200: Train Loss 0.0003 | Test Loss 2.7835 | accs Train 1.0000 Test 0.6818
# Epoch 150/200: Train Loss 0.0001 | Test Loss 3.1031 | accs Train 1.0000 Test 0.6804
# Epoch 200/200: Train Loss 0.0001 | Test Loss 3.3358 | accs Train 1.0000 Test 0.6795
# Completed training with 19950 additional samples of data
# Epoch 1/200: Train Loss 1.8480 | Test Loss 1.5249 | accs Train 0.3210 Test 0.4439
# Epoch 50/200: Train Loss 0.0006 | Test Loss 1.8870 | accs Train 1.0000 Test 0.7565
# Epoch 100/200: Train Loss 0.0001 | Test Loss 2.3546 | accs Train 1.0000 Test 0.7571
# Epoch 150/200: Train Loss 0.0000 | Test Loss 2.7189 | accs Train 1.0000 Test 0.7549
# Epoch 200/200: Train Loss 0.0000 | Test Loss 3.0681 | accs Train 1.0000 Test 0.7538
# Completed training with 49950 additional samples of data

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 21.5900 | accs: 0.1893
#  450 samples | Test Loss: 5.8600 | accs: 0.3662
# 1950 samples | Test Loss: 3.6448 | accs: 0.4966
# 4950 samples | Test Loss: 3.7050 | accs: 0.5650
# 19950 samples | Test Loss: 3.3358 | accs: 0.6795
# 49950 samples | Test Loss: 3.0681 | accs: 0.7538
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: data, additional samples: 0
#  Model    0 | Train Loss: 0.0000 | accs: 1.0000
#  Model  450 | Train Loss: 0.0031 | accs: 1.0000
#  Model 1950 | Train Loss: 0.0045 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0010 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0001 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 450
#  Model    0 | Train Loss: 18.4382 | accs: 0.2600
#  Model  450 | Train Loss: 0.0023 | accs: 1.0000
#  Model 1950 | Train Loss: 0.0028 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0008 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0001 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 1950
#  Model    0 | Train Loss: 20.6902 | accs: 0.1995
#  Model  450 | Train Loss: 4.6888 | accs: 0.5155
#  Model 1950 | Train Loss: 0.0023 | accs: 1.0000
#  Model 4950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0001 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 4950
#  Model    0 | Train Loss: 21.1392 | accs: 0.1840
#  Model  450 | Train Loss: 5.4445 | accs: 0.4358
#  Model 1950 | Train Loss: 2.2717 | accs: 0.6864
#  Model 4950 | Train Loss: 0.0006 | accs: 1.0000
#  Model 19950 | Train Loss: 0.0001 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 19950
#  Model    0 | Train Loss: 21.2466 | accs: 0.1814
#  Model  450 | Train Loss: 5.6858 | accs: 0.3827
#  Model 1950 | Train Loss: 3.3636 | accs: 0.5395
#  Model 4950 | Train Loss: 2.7951 | accs: 0.6768
#  Model 19950 | Train Loss: 0.0001 | accs: 1.0000
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000
#
# Dataset type: data, additional samples: 49950
#  Model    0 | Train Loss: 21.3947 | accs: 0.1837
#  Model  450 | Train Loss: 5.8489 | accs: 0.3723
#  Model 1950 | Train Loss: 3.5853 | accs: 0.5054
#  Model 4950 | Train Loss: 3.3600 | accs: 0.6101
#  Model 19950 | Train Loss: 1.9847 | accs: 0.8109
#  Model 49950 | Train Loss: 0.0000 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_450.pt
# Saved model: models_and_data/model_additional_450.pt
# ✅ Model saved to models_and_data\model_additional_1950.pt
# Saved model: models_and_data/model_additional_1950.pt
# ✅ Model saved to models_and_data\model_additional_4950.pt
# Saved model: models_and_data/model_additional_4950.pt
# ✅ Model saved to models_and_data\model_additional_19950.pt
# Saved model: models_and_data/model_additional_19950.pt
# ✅ Model saved to models_and_data\model_additional_49950.pt
# Saved model: models_and_data/model_additional_49950.pt
