# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.05, 0.01]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}",
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
                max_perturbs = None, # Analyze all our perturbations!
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['data_0', 'data_1950', 'data_19950', 'data_450', 'data_4950', 'data_49950']
#
# ==================================================
# Analyzing directory: data_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 6 models from data_0
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 0
# data_0: 5.38825361218187e-07
# data_1950: 0.00026081354008056223
# data_19950: 0.0007500956417061388
# data_450: 6.83252583257854e-05
# data_4950: 0.0012844795128330588
# data_49950: 0.0008582618902437389
#
# Top perturbations for data_0:
# Top 5 r_vals: [112.08735421808042, 112.08492412086457, 104.59285265055865, 104.52524236206769, 104.51106412132695]
# Top 5 seeds: [418, 474, 158, 212, 152]
#
# Top perturbations for data_1950:
# Top 5 r_vals: [53.35728357597441, 53.354603285060215, 48.15715157164688, 48.149885691570866, 48.138937413114746]
# Top 5 seeds: [428, 487, 362, 138, 469]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [22.543452310849187, 22.54231988793794, 22.5382069616023, 22.538162759221002, 22.536537795489625]
# Top 5 seeds: [428, 487, 180, 363, 261]
#
# Top perturbations for data_450:
# Top 5 r_vals: [70.56146284449213, 70.53829062105432, 70.50690896048157, 70.50441186844775, 70.50221785354732]
# Top 5 seeds: [487, 435, 402, 418, 121]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [34.16959047546169, 34.15538911845731, 34.14103152739517, 34.13947875216815, 34.13479491888583]
# Top 5 seeds: [482, 438, 355, 204, 232]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [16.12196632667824, 13.34332887548146, 13.34092508297942, 13.339939901700085, 13.339922464863283]
# Top 5 seeds: [436, 351, 158, 32, 97]
# Plot saved to: data_0/loss_0.1/log_volume.png
# Test loss  [11.799238953590393, 5.0275774002075195, 4.182729244232178, 5.7362594366073605, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [8057095.293952415, 6789840.397501807, 5318911.452924149, 7266978.494842443, 6028952.061985126, 4746527.441770378]
# Plot saved to: data_0/loss_0.1/gen_log_volume.png
# Plot saved to: data_0/loss_0.1/test_vs_data.png
# Plot saved to: data_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.95/avg_radius.png
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: divide by zero encountered in divide
#   return n/db/n.sum(), bin_edges
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Plot saved to: data_0/acc_0.95/radius_hist.png
# Plot saved to: data_0/acc_0.95/log_volume.png
# Plot saved to: data_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 4, 2, 5, 3, 1]
# test_loss ranks: [1, 3, 5, 2, 6, 4]
# log_exp_r_n ranks: [1, 3, 5, 2, 4, 6]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.1\results.json
# Successfully analyzed data_0 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 6 models from data_0
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 0
# data_0: 5.38825361218187e-07
# data_1950: 0.00026081354008056223
# data_19950: 0.0007500956417061388
# data_450: 6.83252583257854e-05
# data_4950: 0.0012844795128330588
# data_49950: 0.0008582618902437389
#
# Top perturbations for data_0:
# Top 5 r_vals: [112.08735421808042, 104.51106412132695, 104.48820512575251, 104.48810747946642, 104.48245375950162]
# Top 5 seeds: [418, 152, 474, 304, 67]
#
# Top perturbations for data_1950:
# Top 5 r_vals: [48.154948427316896, 48.152529464766836, 48.099141432574655, 43.221377033832646, 43.21972252711777]
# Top 5 seeds: [428, 487, 403, 362, 165]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [19.21443483126722, 19.208622087350783, 19.207657182621674, 19.206602602731866, 19.20518573519284]
# Top 5 seeds: [384, 428, 487, 138, 220]
#
# Top perturbations for data_450:
# Top 5 r_vals: [64.55906997492285, 64.53786892361111, 64.53287760416667, 64.5091567804784, 64.50687210648148]
# Top 5 seeds: [487, 435, 290, 402, 418]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [30.03186662882375, 30.019384967394114, 30.005401247022785, 30.001284596677, 29.98769880983127]
# Top 5 seeds: [482, 438, 204, 232, 418]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [13.34092508297942, 13.333682568264722, 13.332003649978322, 13.329593630034566, 13.329408052271456]
# Top 5 seeds: [158, 186, 77, 473, 286]
# Plot saved to: data_0/loss_0.05/log_volume.png
# Test loss  [11.799238953590393, 5.0275774002075195, 4.182729244232178, 5.7362594366073605, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [8057095.293952415, 6614696.981737385, 5046118.347578529, 7115195.817859728, 5808582.183711874, 4423261.383130331]
# Plot saved to: data_0/loss_0.05/gen_log_volume.png
# Plot saved to: data_0/loss_0.05/test_vs_data.png
# Plot saved to: data_0/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.9/avg_radius.png
# Plot saved to: data_0/acc_0.9/radius_hist.png
# Plot saved to: data_0/acc_0.9/log_volume.png
# Plot saved to: data_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 4, 2, 5, 3, 1]
# test_loss ranks: [1, 3, 5, 2, 6, 4]
# log_exp_r_n ranks: [1, 3, 5, 2, 4, 6]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.05\results.json
# Successfully analyzed data_0 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.01, acc=0.85 ---
# Loaded data dictionary with 6 models from data_0
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 0
# data_0: 5.38825361218187e-07
# data_1950: 0.00026081354008056223
# data_19950: 0.0007500956417061388
# data_450: 6.83252583257854e-05
# data_4950: 0.0012844795128330588
# data_49950: 0.0008582618902437389
#
# Top perturbations for data_0:
# Top 5 r_vals: [104.49047051958988, 97.15803767432854, 97.15794687822833, 97.15268978402636, 90.19025252923811]
# Top 5 seeds: [418, 474, 304, 67, 380]
#
# Top perturbations for data_1950:
# Top 5 r_vals: [38.55063738364151, 38.50596086984508, 34.1502238292011, 34.14891656463627, 34.146946102438534]
# Top 5 seeds: [428, 403, 362, 165, 487]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.13682273582176, 16.135627652391978, 13.343357521713349, 13.341875390585148, 13.341220263716716]
# Top 5 seeds: [180, 261, 384, 483, 249]
#
# Top perturbations for data_450:
# Top 5 r_vals: [58.77797136403094, 53.370530589990835, 53.354603285060215, 53.33954284001634, 53.33708175505052]
# Top 5 seeds: [402, 444, 487, 469, 435]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [22.547893597731584, 22.53429820817073, 22.524093772717713, 22.522104665559482, 19.2203946424472]
# Top 5 seeds: [438, 232, 418, 391, 482]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.806149317213327, 10.800282880294422, 10.792390681495352, 10.791712737280475, 10.78932076446281]
# Top 5 seeds: [158, 186, 436, 410, 420]
# Plot saved to: data_0/loss_0.01/log_volume.png
# Test loss  [11.799238953590393, 5.0275774002075195, 4.182729244232178, 5.7362594366073605, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [7937274.298073483, 6234911.711823039, 4748099.972147022, 6955030.519302585, 5319247.76994874, 4063502.845111931]
# Plot saved to: data_0/loss_0.01/gen_log_volume.png
# Plot saved to: data_0/loss_0.01/test_vs_data.png
# Plot saved to: data_0/loss_0.01/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.01/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 4, 2, 5, 3, 1]
# test_loss ranks: [1, 3, 5, 2, 6, 4]
# log_exp_r_n ranks: [1, 3, 5, 2, 4, 6]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.01\results.json
# Successfully analyzed data_0 with loss=0.01, acc=0.85
#
# ==================================================
# Analyzing directory: data_1950
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from data_1950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 1950
# data_1950: 0.0001989046431845054
# data_19950: 0.0005859752418473363
# data_4950: 0.0009680937509983778
# data_49950: 0.0006963012856431305
#
# Top perturbations for data_1950:
# Top 5 r_vals: [43.219399696539256, 43.19969492510331, 43.197011395919425, 38.56680976331339, 38.56225284529322]
# Top 5 seeds: [428, 290, 202, 78, 71]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.154432508680557, 16.15047049816744, 16.147977852527006, 16.147349416473766, 16.146769205729168]
# Top 5 seeds: [440, 482, 246, 78, 64]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [30.016736747804753, 30.007584276716027, 29.982281869655363, 29.97998394366248, 26.161092707775364]
# Top 5 seeds: [316, 247, 52, 496, 482]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.808652263042356, 10.808432334710744, 10.808299167097108, 10.80809638913998, 10.807906726175103]
# Top 5 seeds: [431, 338, 136, 351, 30]
# Plot saved to: data_1950/loss_0.1/log_volume.png
# Test loss  [5.0275774002075195, 4.182729244232178, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [6430081.859483407, 4749962.068253258, 5807721.852194373, 4063898.242158769]
# Plot saved to: data_1950/loss_0.1/gen_log_volume.png
# Plot saved to: data_1950/loss_0.1/test_vs_data.png
# Plot saved to: data_1950/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_1950/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_1950/acc_0.95/avg_radius.png
# Plot saved to: data_1950/acc_0.95/radius_hist.png
# Plot saved to: data_1950/acc_0.95/log_volume.png
# Plot saved to: data_1950/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 3, 4, 2]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_1950/loss_0.1\results.json
# Successfully analyzed data_1950 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from data_1950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 1950
# data_1950: 0.0001989046431845054
# data_19950: 0.0005859752418473363
# data_4950: 0.0009680937509983778
# data_49950: 0.0006963012856431305
#
# Top perturbations for data_1950:
# Top 5 r_vals: [38.55063738364151, 38.53306121405821, 34.17051831445771, 34.16298719518417, 34.158950617283956]
# Top 5 seeds: [428, 290, 377, 78, 71]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.14514461564429, 16.11923556857639, 13.350770668331041, 13.348591063730746, 13.347496279477225]
# Top 5 seeds: [30, 348, 440, 58, 482]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [26.14791290030993, 26.117898873122012, 26.115897124257103, 22.55726871231651, 22.552909515570803]
# Top 5 seeds: [316, 52, 496, 482, 78]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.804606792355372, 8.544493227731865, 8.542629578614427, 8.541620434139375, 8.541305574686257]
# Top 5 seeds: [41, 440, 377, 242, 217]
# Plot saved to: data_1950/loss_0.05/log_volume.png
# Test loss  [5.0275774002075195, 4.182729244232178, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [6234911.711823039, 4748980.199130228, 5572142.380844346, 4063259.122719669]
# Plot saved to: data_1950/loss_0.05/gen_log_volume.png
# Plot saved to: data_1950/loss_0.05/test_vs_data.png
# Plot saved to: data_1950/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_1950/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_1950/acc_0.9/avg_radius.png
# Plot saved to: data_1950/acc_0.9/radius_hist.png
# Plot saved to: data_1950/acc_0.9/log_volume.png
# Plot saved to: data_1950/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 3, 4, 2]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_1950/loss_0.05\results.json
# Successfully analyzed data_1950 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.01, acc=0.85 ---
# Loaded data dictionary with 4 models from data_1950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 1950
# data_1950: 0.0001989046431845054
# data_19950: 0.0005859752418473363
# data_4950: 0.0009680937509983778
# data_49950: 0.0006963012856431305
#
# Top perturbations for data_1950:
# Top 5 r_vals: [30.013472011485597, 29.999788142432852, 29.9979245804996, 29.99415542140152, 26.161803084506694]
# Top 5 seeds: [428, 290, 202, 497, 377]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [10.814124241348141, 10.81147198637655, 10.809803355823863, 10.80938266722624, 10.808856049845042]
# Top 5 seeds: [440, 482, 246, 78, 257]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [16.154432508680557, 16.15047049816744, 16.147349416473766, 16.14625831886574, 16.145441502700617]
# Top 5 seeds: [440, 482, 78, 431, 71]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [6.5418776274822115, 6.539001334067477, 6.53877430645231, 6.53856741838365, 6.538434375318848]
# Top 5 seeds: [440, 160, 64, 431, 338]
# Plot saved to: data_1950/loss_0.01/log_volume.png
# Test loss  [5.0275774002075195, 4.182729244232178, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [5807536.152375723, 4064762.3464043606, 4749962.068253258, 3206637.16794665]
# Plot saved to: data_1950/loss_0.01/gen_log_volume.png
# Plot saved to: data_1950/loss_0.01/test_vs_data.png
# Plot saved to: data_1950/loss_0.01/other_plots/avg_radius.png
# Plot saved to: data_1950/loss_0.01/other_plots/radius_hist.png
# Plot saved to: data_1950/acc_0.85/avg_radius.png
# Plot saved to: data_1950/acc_0.85/radius_hist.png
# Plot saved to: data_1950/acc_0.85/log_volume.png
# Plot saved to: data_1950/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 3, 4, 2]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_1950/loss_0.01\results.json
# Successfully analyzed data_1950 with loss=0.01, acc=0.85
#
# ==================================================
# Analyzing directory: data_19950
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_19950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 19950
# data_19950: 0.0005483293207362294
# data_49950: 0.0006473008543252945
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.154432508680557, 16.15047049816744, 16.149001133294753, 16.147977852527006, 16.147349416473766]
# Top 5 seeds: [440, 482, 242, 246, 78]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.808432334710744, 10.808299167097108, 10.80809638913998, 10.807906726175103, 10.807193472365702]
# Top 5 seeds: [338, 136, 351, 30, 33]
# Plot saved to: data_19950/loss_0.1/log_volume.png
# Test loss  [4.182729244232178, 4.401926279067993]
# log_exp_r_n  [4749962.068253258, 4063863.503161405]
# Plot saved to: data_19950/loss_0.1/gen_log_volume.png
# Plot saved to: data_19950/loss_0.1/test_vs_data.png
# Plot saved to: data_19950/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_19950/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_19950/acc_0.95/avg_radius.png
# Plot saved to: data_19950/acc_0.95/radius_hist.png
# Plot saved to: data_19950/acc_0.95/log_volume.png
# Plot saved to: data_19950/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [2, 1]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_19950/loss_0.1\results.json
# Successfully analyzed data_19950 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_19950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 19950
# data_19950: 0.0005483293207362294
# data_49950: 0.0006473008543252945
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.12918505256559, 13.350770668331041, 13.348591063730746, 13.347858716585046, 13.347496279477225]
# Top 5 seeds: [283, 440, 58, 377, 482]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [8.544493227731865, 8.542743565707582, 8.542629578614427, 8.541620434139375, 8.541079194725029]
# Top 5 seeds: [440, 361, 377, 242, 246]
# Plot saved to: data_19950/loss_0.05/log_volume.png
# Test loss  [4.182729244232178, 4.401926279067993]
# log_exp_r_n  [4747291.714839669, 3662586.517569928]
# Plot saved to: data_19950/loss_0.05/gen_log_volume.png
# Plot saved to: data_19950/loss_0.05/test_vs_data.png
# Plot saved to: data_19950/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_19950/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_19950/acc_0.9/avg_radius.png
# Plot saved to: data_19950/acc_0.9/radius_hist.png
# Plot saved to: data_19950/acc_0.9/log_volume.png
# Plot saved to: data_19950/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [2, 1]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_19950/loss_0.05\results.json
# Successfully analyzed data_19950 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.01, acc=0.85 ---
# Loaded data dictionary with 2 models from data_19950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 19950
# data_19950: 0.0005483293207362294
# data_49950: 0.0006473008543252945
#
# Top perturbations for data_19950:
# Top 5 r_vals: [10.814124241348141, 10.81147198637655, 10.80938266722624, 10.808856049845042, 10.808652263042356]
# Top 5 seeds: [440, 482, 78, 257, 431]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [6.5418776274822115, 6.539263758461352, 6.539001334067477, 6.53856741838365, 6.538434375318848]
# Top 5 seeds: [440, 246, 160, 431, 338]
# Plot saved to: data_19950/loss_0.01/log_volume.png
# Test loss  [4.182729244232178, 4.401926279067993]
# log_exp_r_n  [4064762.3464043606, 3206637.16794665]
# Plot saved to: data_19950/loss_0.01/gen_log_volume.png
# Plot saved to: data_19950/loss_0.01/test_vs_data.png
# Plot saved to: data_19950/loss_0.01/other_plots/avg_radius.png
# Plot saved to: data_19950/loss_0.01/other_plots/radius_hist.png
# Plot saved to: data_19950/acc_0.85/avg_radius.png
# Plot saved to: data_19950/acc_0.85/radius_hist.png
# Plot saved to: data_19950/acc_0.85/log_volume.png
# Plot saved to: data_19950/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [2, 1]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_19950/loss_0.01\results.json
# Successfully analyzed data_19950 with loss=0.01, acc=0.85
#
# ==================================================
# Analyzing directory: data_450
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from data_450
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 450
# data_1950: 0.0002212497784057632
# data_19950: 0.0006639914936386049
# data_450: 4.765190169564448e-05
# data_4950: 0.0010791986715048552
# data_49950: 0.0008221925818361342
#
# Top perturbations for data_1950:
# Top 5 r_vals: [43.23753066890496, 43.219399696539256, 43.21592926782025, 43.20248740960744, 43.19969492510331]
# Top 5 seeds: [78, 428, 82, 309, 290]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [19.195063203053262, 16.154432508680557, 16.15047049816744, 16.149001133294753, 16.147977852527006]
# Top 5 seeds: [283, 440, 482, 242, 246]
#
# Top perturbations for data_450:
# Top 5 r_vals: [64.53786892361111, 58.85108341045398, 58.841009975464885, 58.83799453609247, 58.83170550497877]
# Top 5 seeds: [435, 78, 444, 438, 325]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [30.026062964517333, 30.019384967394114, 30.014845162383782, 30.001284596677, 29.9979245804996]
# Top 5 seeds: [78, 438, 362, 232, 202]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.814124241348141, 10.809369552233989, 10.808432334710744, 10.80809638913998, 10.808035858406509]
# Top 5 seeds: [440, 160, 338, 351, 422]
# Plot saved to: data_450/loss_0.1/log_volume.png
# Test loss  [5.0275774002075195, 4.182729244232178, 5.7362594366073605, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [6430797.9278896665, 5044396.238116856, 7114635.060891957, 5808252.220781983, 4064762.3464043606]
# Plot saved to: data_450/loss_0.1/gen_log_volume.png
# Plot saved to: data_450/loss_0.1/test_vs_data.png
# Plot saved to: data_450/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_450/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_450/acc_0.95/avg_radius.png
# Plot saved to: data_450/acc_0.95/radius_hist.png
# Plot saved to: data_450/acc_0.95/log_volume.png
# Plot saved to: data_450/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 5, 3, 1]
# test_loss ranks: [2, 4, 1, 5, 3]
# log_exp_r_n ranks: [2, 4, 1, 3, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_450/loss_0.1\results.json
# Successfully analyzed data_450 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from data_450
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 450
# data_1950: 0.0002212497784057632
# data_19950: 0.0006639914936386049
# data_450: 4.765190169564448e-05
# data_4950: 0.0010791986715048552
# data_49950: 0.0008221925818361342
#
# Top perturbations for data_1950:
# Top 5 r_vals: [38.56680976331339, 38.55063738364151, 38.54754184691375, 38.535552041285655, 38.53306121405821]
# Top 5 seeds: [78, 428, 82, 309, 290]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.142903645833336, 16.141316731770836, 16.13402416087963, 16.133219401041668, 16.12918505256559]
# Top 5 seeds: [366, 362, 232, 290, 283]
#
# Top perturbations for data_450:
# Top 5 r_vals: [58.80413263494319, 53.37966749247527, 53.370530589990835, 53.36779549758955, 53.36209116097849]
# Top 5 seeds: [435, 78, 444, 438, 325]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [26.156037071312888, 26.15021979381888, 26.146265119232105, 26.134452359771974, 26.131525412346328]
# Top 5 seeds: [78, 438, 362, 232, 202]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.804606792355372, 10.795852030604339, 8.544493227731865, 8.542629578614427, 8.542397618865422]
# Top 5 seeds: [41, 75, 440, 377, 482]
# Plot saved to: data_450/loss_0.05/log_volume.png
# Test loss  [5.0275774002075195, 4.182729244232178, 5.7362594366073605, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [6235627.780229299, 4748743.210541249, 6955790.234545866, 5572672.749431957, 4063259.122719669]
# Plot saved to: data_450/loss_0.05/gen_log_volume.png
# Plot saved to: data_450/loss_0.05/test_vs_data.png
# Plot saved to: data_450/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_450/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_450/acc_0.9/avg_radius.png
# Plot saved to: data_450/acc_0.9/radius_hist.png
# Plot saved to: data_450/acc_0.9/log_volume.png
# Plot saved to: data_450/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 5, 3, 1]
# test_loss ranks: [2, 4, 1, 5, 3]
# log_exp_r_n ranks: [2, 4, 1, 3, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_450/loss_0.05\results.json
# Successfully analyzed data_450 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.01, acc=0.85 ---
# Loaded data dictionary with 5 models from data_450
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 450
# data_1950: 0.0002212497784057632
# data_19950: 0.0006639914936386049
# data_450: 4.765190169564448e-05
# data_4950: 0.0010791986715048552
# data_49950: 0.0008221925818361342
#
# Top perturbations for data_1950:
# Top 5 r_vals: [30.013472011485597, 30.01106199154184, 30.001727367782944, 29.999788142432852, 29.97744501567522]
# Top 5 seeds: [428, 82, 309, 290, 429]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [10.81147198637655, 10.810488361957646, 10.80938266722624, 10.808856049845042, 10.808652263042356]
# Top 5 seeds: [482, 242, 78, 257, 431]
#
# Top perturbations for data_450:
# Top 5 r_vals: [48.13671628393309, 43.23753066890496, 43.23162690470041, 43.230129777892564, 43.227914353047524]
# Top 5 seeds: [435, 78, 30, 444, 438]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [19.212406379132233, 19.198671731519745, 19.183661903122132, 16.15047049816744, 16.147349416473766]
# Top 5 seeds: [438, 202, 140, 482, 78]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [6.5418776274822115, 6.5404507711266735, 6.539678144887961, 6.539009267828222, 6.539001334067477]
# Top 5 seeds: [440, 377, 242, 78, 160]
# Plot saved to: data_450/loss_0.01/log_volume.png
# Test loss  [5.0275774002075195, 4.182729244232178, 5.7362594366073605, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [5807536.152375723, 4064343.5717329583, 6614050.461297038, 5045938.102547481, 3206637.16794665]
# Plot saved to: data_450/loss_0.01/gen_log_volume.png
# Plot saved to: data_450/loss_0.01/test_vs_data.png
# Plot saved to: data_450/loss_0.01/other_plots/avg_radius.png
# Plot saved to: data_450/loss_0.01/other_plots/radius_hist.png
# Plot saved to: data_450/acc_0.85/avg_radius.png
# Plot saved to: data_450/acc_0.85/radius_hist.png
# Plot saved to: data_450/acc_0.85/log_volume.png
# Plot saved to: data_450/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 5, 3, 1]
# test_loss ranks: [2, 4, 1, 5, 3]
# log_exp_r_n ranks: [2, 4, 1, 3, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_450/loss_0.01\results.json
# Successfully analyzed data_450 with loss=0.01, acc=0.85
#
# ==================================================
# Analyzing directory: data_4950
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 3 models from data_4950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 4950
# data_19950: 0.0005627591744996607
# data_4950: 0.0009429430938325822
# data_49950: 0.0006621037609875202
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.154432508680557, 16.15047049816744, 16.147977852527006, 16.147349416473766, 16.146769205729168]
# Top 5 seeds: [440, 482, 246, 78, 64]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [30.026062964517333, 30.012796645431592, 30.001284596677, 29.97998394366248, 29.97447172362833]
# Top 5 seeds: [78, 41, 232, 496, 140]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.808652263042356, 10.808432334710744, 10.808299167097108, 10.80809638913998, 10.807906726175103]
# Top 5 seeds: [431, 338, 136, 351, 30]
# Plot saved to: data_4950/loss_0.1/log_volume.png
# Test loss  [4.182729244232178, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [4749962.068253258, 5808252.220781983, 4063898.242158769]
# Plot saved to: data_4950/loss_0.1/gen_log_volume.png
# Plot saved to: data_4950/loss_0.1/test_vs_data.png
# Plot saved to: data_4950/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_4950/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_4950/acc_0.95/avg_radius.png
# Plot saved to: data_4950/acc_0.95/radius_hist.png
# Plot saved to: data_4950/acc_0.95/log_volume.png
# Plot saved to: data_4950/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [2, 3, 1]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_4950/loss_0.1\results.json
# Successfully analyzed data_4950 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_4950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 4950
# data_19950: 0.0005627591744996607
# data_4950: 0.0009429430938325822
# data_49950: 0.0006621037609875202
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.12165889033565, 16.11923556857639, 13.350770668331041, 13.348591063730746, 13.347858716585046]
# Top 5 seeds: [72, 348, 440, 58, 377]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [26.15021979381888, 26.14448063335375, 26.115897124257103, 22.55726871231651, 22.55378724857078]
# Top 5 seeds: [438, 41, 496, 482, 246]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [8.544493227731865, 8.542743565707582, 8.542629578614427, 8.541620434139375, 8.541079194725029]
# Top 5 seeds: [440, 361, 377, 242, 246]
# Plot saved to: data_4950/loss_0.05/log_volume.png
# Test loss  [4.182729244232178, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [4746494.884756652, 5572292.998050286, 3662586.517569928]
# Plot saved to: data_4950/loss_0.05/gen_log_volume.png
# Plot saved to: data_4950/loss_0.05/test_vs_data.png
# Plot saved to: data_4950/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_4950/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_4950/acc_0.9/avg_radius.png
# Plot saved to: data_4950/acc_0.9/radius_hist.png
# Plot saved to: data_4950/acc_0.9/log_volume.png
# Plot saved to: data_4950/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [2, 3, 1]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_4950/loss_0.05\results.json
# Successfully analyzed data_4950 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.01, acc=0.85 ---
# Loaded data dictionary with 3 models from data_4950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 4950
# data_19950: 0.0005627591744996607
# data_4950: 0.0009429430938325822
# data_49950: 0.0006621037609875202
#
# Top perturbations for data_19950:
# Top 5 r_vals: [10.814124241348141, 10.81147198637655, 10.809803355823863, 10.80938266722624, 10.808994261686466]
# Top 5 seeds: [440, 482, 246, 78, 64]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [16.15047049816744, 16.147349416473766, 16.14625831886574, 16.145929783950617, 16.145441502700617]
# Top 5 seeds: [482, 78, 431, 338, 71]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [6.539263758461352, 6.539001334067477, 6.53877430645231, 6.538434375318848, 6.538353817132821]
# Top 5 seeds: [246, 160, 64, 338, 136]
# Plot saved to: data_4950/loss_0.01/log_volume.png
# Test loss  [4.182729244232178, 4.121039390563965, 4.401926279067993]
# log_exp_r_n  [4064762.3464043606, 4749543.293581856, 3205954.8741702205]
# Plot saved to: data_4950/loss_0.01/gen_log_volume.png
# Plot saved to: data_4950/loss_0.01/test_vs_data.png
# Plot saved to: data_4950/loss_0.01/other_plots/avg_radius.png
# Plot saved to: data_4950/loss_0.01/other_plots/radius_hist.png
# Plot saved to: data_4950/acc_0.85/avg_radius.png
# Plot saved to: data_4950/acc_0.85/radius_hist.png
# Plot saved to: data_4950/acc_0.85/log_volume.png
# Plot saved to: data_4950/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [2, 3, 1]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_4950/loss_0.01\results.json
# Successfully analyzed data_4950 with loss=0.01, acc=0.85
#
# ==================================================
# Analyzing directory: data_49950
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_49950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 49950
# data_49950: 0.0006502136820927262
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.808432334710744, 10.808299167097108, 10.80809638913998, 10.807906726175103, 10.807193472365702]
# Top 5 seeds: [338, 136, 351, 30, 33]
# Plot saved to: data_49950/loss_0.1/log_volume.png
# Test loss  [4.401926279067993]
# log_exp_r_n  [4063863.503161405]
# Plot saved to: data_49950/loss_0.1/gen_log_volume.png
# Plot saved to: data_49950/loss_0.1/test_vs_data.png
# Plot saved to: data_49950/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_49950/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_49950/acc_0.95/avg_radius.png
# Plot saved to: data_49950/acc_0.95/radius_hist.png
# Plot saved to: data_49950/acc_0.95/log_volume.png
# Plot saved to: data_49950/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_49950/loss_0.1\results.json
# Successfully analyzed data_49950 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 1 models from data_49950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 49950
# data_49950: 0.0006502136820927262
#
# Top perturbations for data_49950:
# Top 5 r_vals: [8.544493227731865, 8.542743565707582, 8.542629578614427, 8.541620434139375, 8.541079194725029]
# Top 5 seeds: [440, 361, 377, 242, 246]
# Plot saved to: data_49950/loss_0.05/log_volume.png
# Test loss  [4.401926279067993]
# log_exp_r_n  [3662586.517569928]
# Plot saved to: data_49950/loss_0.05/gen_log_volume.png
# Plot saved to: data_49950/loss_0.05/test_vs_data.png
# Plot saved to: data_49950/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_49950/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_49950/acc_0.9/avg_radius.png
# Plot saved to: data_49950/acc_0.9/radius_hist.png
# Plot saved to: data_49950/acc_0.9/log_volume.png
# Plot saved to: data_49950/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_49950/loss_0.05\results.json
# Successfully analyzed data_49950 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.01, acc=0.85 ---
# Loaded data dictionary with 1 models from data_49950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 49950
# data_49950: 0.0006502136820927262
#
# Top perturbations for data_49950:
# Top 5 r_vals: [6.5418776274822115, 6.539263758461352, 6.53856741838365, 6.538434375318848, 6.538353817132821]
# Top 5 seeds: [440, 246, 431, 338, 136]
# Plot saved to: data_49950/loss_0.01/log_volume.png
# Test loss  [4.401926279067993]
# log_exp_r_n  [3206637.16794665]
# Plot saved to: data_49950/loss_0.01/gen_log_volume.png
# Plot saved to: data_49950/loss_0.01/test_vs_data.png
# Plot saved to: data_49950/loss_0.01/other_plots/avg_radius.png
# Plot saved to: data_49950/loss_0.01/other_plots/radius_hist.png
# Plot saved to: data_49950/acc_0.85/avg_radius.png
# Plot saved to: data_49950/acc_0.85/radius_hist.png
# Plot saved to: data_49950/acc_0.85/log_volume.png
# Plot saved to: data_49950/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_49950/loss_0.01\results.json
# Successfully analyzed data_49950 with loss=0.01, acc=0.85
#
# Analysis complete for all directories!
