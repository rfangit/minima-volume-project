# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.05, 0.02]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}",
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
                max_perturbs = 50, # Analyze all our perturbations!
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['data_0', 'data_1950', 'data_19950', 'data_450', 'data_4950', 'data_49950']
#
# ==================================================
# Analyzing directory: data_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 6 models from data_0
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 0
# data_0: 5.006782544114685e-07
# data_1950: 0.0002084530860884115
# data_19950: 0.0006549078389070928
# data_450: 3.514102354529314e-05
# data_4950: 0.0007156606880016625
# data_49950: 0.0002451969776302576
#
# Top perturbations for data_0:
# Top 5 r_vals: [120.07453575169308, 112.21739584279904, 112.15139565936352, 112.02807870021633, 104.59449310816503]
# Top 5 seeds: [206, 351, 200, 256, 163]
#
# Top perturbations for data_1950:
# Top 5 r_vals: [53.32058650743548, 48.164889554079316, 48.160186515366746, 48.154948427316896, 48.144503724707626]
# Top 5 seeds: [229, 199, 316, 428, 463]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [22.55181077066435, 22.546700133436644, 22.54475733353501, 22.543620700873163, 22.543384954839595]
# Top 5 seeds: [257, 366, 259, 165, 85]
#
# Top perturbations for data_450:
# Top 5 r_vals: [76.80097853535355, 76.76252582644629, 64.59362340856482, 64.57368827160495, 64.57005931712963]
# Top 5 seeds: [394, 177, 217, 114, 148]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [38.54005856684746, 34.16959047546169, 34.16132282420162, 34.15445809101112, 34.15358126721763]
# Top 5 seeds: [295, 482, 257, 412, 366]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [19.178306502525256, 16.143907335069446, 16.142772533275465, 16.14069884500386, 16.14053005642361]
# Top 5 seeds: [413, 260, 163, 165, 85]
# Plot saved to: data_0/loss_0.1/log_volume.png
# Test loss  [10.143835594654083, 4.913583374023437, 3.9533917903900146, 5.709335207939148, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [7937871.758035048, 6613827.739660137, 5317658.118007865, 7114840.194764706, 6027776.179173268, 4745071.890440284]
# Plot saved to: data_0/loss_0.1/gen_log_volume.png
# Plot saved to: data_0/loss_0.1/test_vs_data.png
# Plot saved to: data_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.95/avg_radius.png
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: divide by zero encountered in divide
#   return n/db/n.sum(), bin_edges
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Plot saved to: data_0/acc_0.95/radius_hist.png
# Plot saved to: data_0/acc_0.95/log_volume.png
# Plot saved to: data_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 4, 2, 5, 3, 1]
# test_loss ranks: [1, 3, 6, 2, 5, 4]
# log_exp_r_n ranks: [1, 3, 5, 2, 4, 6]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.1\results.json
# Successfully analyzed data_0 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 6 models from data_0
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 0
# data_0: 5.006782544114685e-07
# data_1950: 0.0002084530860884115
# data_19950: 0.0006549078389070928
# data_450: 3.514102354529314e-05
# data_4950: 0.0007156606880016625
# data_49950: 0.0002451969776302576
#
# Top perturbations for data_0:
# Top 5 r_vals: [120.07453575169308, 112.02807870021633, 104.61169838377465, 104.5501714589073, 104.52690234893127]
# Top 5 seeds: [206, 256, 351, 200, 21]
#
# Top perturbations for data_1950:
# Top 5 r_vals: [48.13037212750533, 48.121829322960515, 48.111807264365574, 43.237478208935954, 43.228321926652896]
# Top 5 seeds: [21, 229, 17, 160, 199]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [22.546700133436644, 19.21574408861341, 19.21555935778237, 19.211882676193756, 19.209734059343436]
# Top 5 seeds: [366, 257, 373, 412, 259]
#
# Top perturbations for data_450:
# Top 5 r_vals: [70.5342320229202, 70.49891694824669, 64.57368827160495, 64.5218520929784, 64.51789158950618]
# Top 5 seeds: [394, 177, 114, 464, 484]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [34.146946102438534, 34.13929063360882, 30.03186662882375, 30.02460013845845, 30.023423151974292]
# Top 5 seeds: [487, 295, 482, 257, 338]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [16.12580023871528, 16.119008005401238, 16.115104769483025, 13.344916873118818, 13.342072177743347]
# Top 5 seeds: [274, 287, 413, 78, 260]
# Plot saved to: data_0/loss_0.05/log_volume.png
# Test loss  [10.143835594654083, 4.913583374023437, 3.9533917903900146, 5.709335207939148, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [7937871.758035048, 6613827.739660137, 5045614.130760724, 6955995.368418615, 5807406.300900018, 4422970.226291103]
# Plot saved to: data_0/loss_0.05/gen_log_volume.png
# Plot saved to: data_0/loss_0.05/test_vs_data.png
# Plot saved to: data_0/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.9/avg_radius.png
# Plot saved to: data_0/acc_0.9/radius_hist.png
# Plot saved to: data_0/acc_0.9/log_volume.png
# Plot saved to: data_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 4, 2, 5, 3, 1]
# test_loss ranks: [1, 3, 6, 2, 5, 4]
# log_exp_r_n ranks: [1, 3, 5, 2, 4, 6]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.05\results.json
# Successfully analyzed data_0 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 6 models from data_0
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 0
# data_0: 5.006782544114685e-07
# data_1950: 0.0002084530860884115
# data_19950: 0.0006549078389070928
# data_450: 3.514102354529314e-05
# data_4950: 0.0007156606880016625
# data_49950: 0.0002451969776302576
#
# Top perturbations for data_0:
# Top 5 r_vals: [112.2029828524154, 104.5501714589073, 104.4352124862897, 97.27286750225983, 97.25686922940343]
# Top 5 seeds: [206, 200, 256, 351, 163]
#
# Top perturbations for data_1950:
# Top 5 r_vals: [43.197342297262395, 43.18967507102273, 43.180680204028924, 38.56676297031634, 38.5585957926009]
# Top 5 seeds: [21, 229, 17, 160, 199]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [19.21138946280992, 19.19200707357668, 19.191524621212125, 16.148405852141206, 16.146562741126544]
# Top 5 seeds: [366, 457, 255, 217, 257]
#
# Top perturbations for data_450:
# Top 5 r_vals: [64.53415557484568, 64.50184461805556, 58.836769685491284, 58.831189200241056, 58.79519616889779]
# Top 5 seeds: [394, 177, 114, 456, 227]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [30.00523590844525, 26.161092707775364, 26.15476278727937, 26.15021979381888, 26.1495069759304]
# Top 5 seeds: [295, 482, 257, 438, 412]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [16.115104769483025, 13.339420533061043, 13.336666758334612, 13.327623267475898, 13.327107635301886]
# Top 5 seeds: [413, 165, 267, 176, 274]
# Plot saved to: data_0/loss_0.02/log_volume.png
# Test loss  [10.143835594654083, 4.913583374023437, 3.9533917903900146, 5.709335207939148, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [7813692.691366676, 6429212.617406159, 4748509.607483537, 6789399.0109342085, 5570926.506910476, 4063211.688272702]
# Plot saved to: data_0/loss_0.02/gen_log_volume.png
# Plot saved to: data_0/loss_0.02/test_vs_data.png
# Plot saved to: data_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_0/acc_0.85/avg_radius.png
# Plot saved to: data_0/acc_0.85/radius_hist.png
# Plot saved to: data_0/acc_0.85/log_volume.png
# Plot saved to: data_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [6, 4, 2, 5, 3, 1]
# test_loss ranks: [1, 3, 6, 2, 5, 4]
# log_exp_r_n ranks: [1, 3, 5, 2, 4, 6]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5, 6]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  4
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
# Results saved to data_0/loss_0.02\results.json
# Successfully analyzed data_0 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_1950
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 4 models from data_1950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 1950
# data_1950: 0.00021696524345315993
# data_19950: 0.0008593588136136532
# data_4950: 0.0007887035608291626
# data_49950: 0.0002942541323136538
#
# Top perturbations for data_1950:
# Top 5 r_vals: [43.21272517432851, 43.19665628228306, 43.19102288868802, 43.18967507102273, 43.188064953512395]
# Top 5 seeds: [498, 212, 68, 229, 27]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [19.186106448002757, 16.154432508680557, 16.149001133294753, 16.148405852141206, 16.147977852527006]
# Top 5 seeds: [72, 440, 242, 217, 246]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [30.02460013845845, 30.011078805634472, 30.010109192959426, 30.006962155288683, 30.002884737825703]
# Top 5 seeds: [257, 320, 139, 463, 225]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [13.331719678636112, 13.317727862590555, 10.814124241348141, 10.812358761621901, 10.811909825348657]
# Top 5 seeds: [459, 423, 440, 58, 361]
# Plot saved to: data_1950/loss_0.1/log_volume.png
# Test loss  [4.913583374023437, 3.9533917903900146, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [6428845.912696686, 4748509.607483537, 5572038.2073772475, 4063782.779866423]
# Plot saved to: data_1950/loss_0.1/gen_log_volume.png
# Plot saved to: data_1950/loss_0.1/test_vs_data.png
# Plot saved to: data_1950/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_1950/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_1950/acc_0.95/avg_radius.png
# Plot saved to: data_1950/acc_0.95/radius_hist.png
# Plot saved to: data_1950/acc_0.95/log_volume.png
# Plot saved to: data_1950/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 4, 3, 2]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_1950/loss_0.1\results.json
# Successfully analyzed data_1950 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 4 models from data_1950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 1950
# data_1950: 0.00021696524345315993
# data_19950: 0.0008593588136136532
# data_4950: 0.0007887035608291626
# data_49950: 0.0002942541323136538
#
# Top perturbations for data_1950:
# Top 5 r_vals: [38.54468387463254, 38.53035081969076, 38.52532597170013, 38.524123751622135, 38.521834494228116]
# Top 5 seeds: [498, 212, 68, 229, 195]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.146562741126544, 16.12998077015818, 16.12947741849923, 16.12349597318673, 16.12165889033565]
# Top 5 seeds: [257, 68, 229, 306, 72]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [26.15476278727937, 26.14298420401937, 26.142139563644665, 26.139398144162595, 26.135846260505954]
# Top 5 seeds: [257, 320, 139, 463, 225]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.808856049845042, 10.806318803267045, 10.805823460098141, 10.805735690534608, 10.805344258458161]
# Top 5 seeds: [257, 163, 325, 349, 362]
# Plot saved to: data_1950/loss_0.05/log_volume.png
# Test loss  [4.913583374023437, 3.9533917903900146, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [6027987.557000525, 4423541.317884824, 5319396.692393766, 4062536.9069091897]
# Plot saved to: data_1950/loss_0.05/gen_log_volume.png
# Plot saved to: data_1950/loss_0.05/test_vs_data.png
# Plot saved to: data_1950/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_1950/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_1950/acc_0.9/avg_radius.png
# Plot saved to: data_1950/acc_0.9/radius_hist.png
# Plot saved to: data_1950/acc_0.9/log_volume.png
# Plot saved to: data_1950/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 4, 3, 2]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_1950/loss_0.05\results.json
# Successfully analyzed data_1950 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 4 models from data_1950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 1950
# data_1950: 0.00021696524345315993
# data_19950: 0.0008593588136136532
# data_4950: 0.0007887035608291626
# data_49950: 0.0002942541323136538
#
# Top perturbations for data_1950:
# Top 5 r_vals: [34.12314751045812, 34.1177781603918, 34.10863368533823, 30.02723154395518, 30.02460013845845]
# Top 5 seeds: [195, 278, 72, 246, 257]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [13.344266728203758, 13.343254146180879, 13.331412043015385, 13.33014662685887, 13.325203283625399]
# Top 5 seeds: [257, 422, 416, 229, 306]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [22.55181077066435, 22.54165474734323, 22.54092646048953, 22.53856268552795, 22.535500091966863]
# Top 5 seeds: [257, 320, 139, 463, 225]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [8.542397618865422, 8.541305574686257, 8.541079194725029, 8.54073643633303, 8.540330706050405]
# Top 5 seeds: [482, 217, 246, 160, 257]
# Plot saved to: data_1950/loss_0.02/log_volume.png
# Test loss  [4.913583374023437, 3.9533917903900146, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [5806666.910298475, 4063782.779866423, 5045683.311874442, 3661203.2379139243]
# Plot saved to: data_1950/loss_0.02/gen_log_volume.png
# Plot saved to: data_1950/loss_0.02/test_vs_data.png
# Plot saved to: data_1950/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_1950/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_1950/acc_0.85/avg_radius.png
# Plot saved to: data_1950/acc_0.85/radius_hist.png
# Plot saved to: data_1950/acc_0.85/log_volume.png
# Plot saved to: data_1950/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 3, 1]
# test_loss ranks: [1, 4, 3, 2]
# log_exp_r_n ranks: [1, 3, 2, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
# Results saved to data_1950/loss_0.02\results.json
# Successfully analyzed data_1950 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_19950
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 2 models from data_19950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 19950
# data_19950: 0.0008460453245788813
# data_49950: 0.0002888833696488291
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.150909047067902, 16.15047049816744, 16.149001133294753, 16.148405852141206, 16.147977852527006]
# Top 5 seeds: [377, 482, 242, 217, 246]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.814124241348141, 10.812358761621901, 10.811909825348657, 10.811765560433885, 10.81147198637655]
# Top 5 seeds: [440, 58, 361, 377, 482]
# Plot saved to: data_19950/loss_0.1/log_volume.png
# Test loss  [3.9533917903900146, 4.488439083099365]
# log_exp_r_n  [4748509.607483537, 4063782.779866423]
# Plot saved to: data_19950/loss_0.1/gen_log_volume.png
# Plot saved to: data_19950/loss_0.1/test_vs_data.png
# Plot saved to: data_19950/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_19950/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_19950/acc_0.95/avg_radius.png
# Plot saved to: data_19950/acc_0.95/radius_hist.png
# Plot saved to: data_19950/acc_0.95/log_volume.png
# Plot saved to: data_19950/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [2, 1]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_19950/loss_0.1\results.json
# Successfully analyzed data_19950 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 2 models from data_19950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 19950
# data_19950: 0.0008460453245788813
# data_49950: 0.0002888833696488291
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.12998077015818, 16.12349597318673, 16.12165889033565, 16.116256148726855, 13.350770668331041]
# Top 5 seeds: [68, 306, 72, 480, 440]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.808856049845042, 10.80772513397469, 10.806318803267045, 10.805823460098141, 10.805735690534608]
# Top 5 seeds: [257, 458, 163, 325, 349]
# Plot saved to: data_19950/loss_0.05/log_volume.png
# Test loss  [3.9533917903900146, 4.488439083099365]
# log_exp_r_n  [4423541.317884824, 4062536.9069091897]
# Plot saved to: data_19950/loss_0.05/gen_log_volume.png
# Plot saved to: data_19950/loss_0.05/test_vs_data.png
# Plot saved to: data_19950/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_19950/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_19950/acc_0.9/avg_radius.png
# Plot saved to: data_19950/acc_0.9/radius_hist.png
# Plot saved to: data_19950/acc_0.9/log_volume.png
# Plot saved to: data_19950/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [2, 1]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_19950/loss_0.05\results.json
# Successfully analyzed data_19950 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 2 models from data_19950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 19950
# data_19950: 0.0008460453245788813
# data_49950: 0.0002888833696488291
#
# Top perturbations for data_19950:
# Top 5 r_vals: [13.325203283625399, 13.32368503333525, 13.319219957625501, 10.814124241348141, 10.812358761621901]
# Top 5 seeds: [306, 72, 480, 440, 58]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [8.542397618865422, 8.541305574686257, 8.541079194725029, 8.54073643633303, 8.54043991046832]
# Top 5 seeds: [482, 217, 246, 160, 64]
# Plot saved to: data_19950/loss_0.02/log_volume.png
# Test loss  [3.9533917903900146, 4.488439083099365]
# log_exp_r_n  [4063782.779866423, 3661203.2379139243]
# Plot saved to: data_19950/loss_0.02/gen_log_volume.png
# Plot saved to: data_19950/loss_0.02/test_vs_data.png
# Plot saved to: data_19950/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_19950/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_19950/acc_0.85/avg_radius.png
# Plot saved to: data_19950/acc_0.85/radius_hist.png
# Plot saved to: data_19950/acc_0.85/log_volume.png
# Plot saved to: data_19950/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 1]
# test_loss ranks: [2, 1]
# log_exp_r_n ranks: [1, 2]
# log_exp_r_n_acc ranks: [1, 2]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_19950/loss_0.02\results.json
# Successfully analyzed data_19950 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_450
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from data_450
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 450
# data_1950: 0.00019593475735746324
# data_19950: 0.0007057898910716176
# data_450: 3.2834053854458034e-05
# data_4950: 0.0006956186261959374
# data_49950: 0.0002621198073029518
#
# Top perturbations for data_1950:
# Top 5 r_vals: [48.09850297034025, 43.23542419938017, 43.22527521306818, 43.21722866089876, 43.216005940082646]
# Top 5 seeds: [72, 257, 163, 487, 216]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [19.21574408861341, 19.20445577938476, 19.20184623220845, 19.19881879878329, 19.19734095213499]
# Top 5 seeds: [257, 463, 225, 21, 491]
#
# Top perturbations for data_450:
# Top 5 r_vals: [70.5342320229202, 64.5177951388889, 64.50981385030865, 64.50730010609568, 64.49893904320989]
# Top 5 seeds: [394, 490, 494, 210, 433]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [30.02460013845845, 30.016736747804753, 30.01617627805039, 30.014845162383782, 30.01336832458104]
# Top 5 seeds: [257, 316, 325, 362, 443]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [13.342870535771226, 13.340771887913228, 13.340414432758779, 13.338273438297117, 13.336427624572751]
# Top 5 seeds: [458, 316, 349, 216, 463]
# Plot saved to: data_450/loss_0.1/log_volume.png
# Test loss  [4.913583374023437, 3.9533917903900146, 5.709335207939148, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [6429212.617406159, 5044732.543445642, 6956155.447797639, 5807406.300900018, 4422376.298818447]
# Plot saved to: data_450/loss_0.1/gen_log_volume.png
# Plot saved to: data_450/loss_0.1/test_vs_data.png
# Plot saved to: data_450/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_450/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_450/acc_0.95/avg_radius.png
# Plot saved to: data_450/acc_0.95/radius_hist.png
# Plot saved to: data_450/acc_0.95/log_volume.png
# Plot saved to: data_450/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 5, 3, 1]
# test_loss ranks: [2, 5, 1, 4, 3]
# log_exp_r_n ranks: [2, 4, 1, 3, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_450/loss_0.1\results.json
# Successfully analyzed data_450 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from data_450
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 450
# data_1950: 0.00019593475735746324
# data_19950: 0.0007057898910716176
# data_450: 3.2834053854458034e-05
# data_4950: 0.0006956186261959374
# data_49950: 0.0002621198073029518
#
# Top perturbations for data_1950:
# Top 5 r_vals: [43.1687395080062, 38.564930844508865, 38.555878199310825, 38.548700873456006, 38.547610236678665]
# Top 5 seeds: [72, 257, 163, 487, 216]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.148405852141206, 16.14732982494213, 16.146562741126544, 16.14533751687886, 16.142903645833336]
# Top 5 seeds: [217, 160, 257, 422, 366]
#
# Top perturbations for data_450:
# Top 5 r_vals: [64.53415557484568, 58.785842264979344, 58.77857005782255, 58.77627964212438, 58.76866140094124]
# Top 5 seeds: [394, 490, 494, 210, 433]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [26.15476278727937, 26.14791290030993, 26.147424668879463, 26.146265119232105, 26.144978629412826]
# Top 5 seeds: [257, 316, 325, 362, 443]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.809369552233989, 10.808856049845042, 10.808752138752583, 10.807808868155991, 10.80772513397469]
# Top 5 seeds: [160, 257, 373, 228, 458]
# Plot saved to: data_450/loss_0.05/log_volume.png
# Test loss  [4.913583374023437, 3.9533917903900146, 5.709335207939148, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [6234042.4697457915, 4748055.875678107, 6789559.090313233, 5571826.829549991, 4063379.066748358]
# Plot saved to: data_450/loss_0.05/gen_log_volume.png
# Plot saved to: data_450/loss_0.05/test_vs_data.png
# Plot saved to: data_450/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_450/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_450/acc_0.9/avg_radius.png
# Plot saved to: data_450/acc_0.9/radius_hist.png
# Plot saved to: data_450/acc_0.9/log_volume.png
# Plot saved to: data_450/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 5, 3, 1]
# test_loss ranks: [2, 5, 1, 4, 3]
# log_exp_r_n ranks: [2, 4, 1, 3, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_450/loss_0.05\results.json
# Successfully analyzed data_450 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 5 models from data_450
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 450
# data_1950: 0.00019593475735746324
# data_19950: 0.0007057898910716176
# data_450: 3.2834053854458034e-05
# data_4950: 0.0006956186261959374
# data_49950: 0.0002621198073029518
#
# Top perturbations for data_1950:
# Top 5 r_vals: [34.153303872053876, 34.145938552188554, 34.14207415059688, 34.14125471890624, 34.13123342005918]
# Top 5 seeds: [163, 320, 105, 463, 21]
#
# Top perturbations for data_19950:
# Top 5 r_vals: [13.344900681770358, 13.344266728203758, 13.343254146180879, 13.342870535771226, 13.341585191801222]
# Top 5 seeds: [160, 257, 422, 458, 412]
#
# Top perturbations for data_450:
# Top 5 r_vals: [58.80074919113006, 53.32049185032141, 53.31181826950058, 53.304908300173466, 53.30443003264975]
# Top 5 seeds: [394, 490, 210, 433, 386]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [22.55181077066435, 22.54548351551341, 22.544483699746046, 22.543374430463096, 22.54231988793794]
# Top 5 seeds: [257, 325, 362, 443, 487]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [8.543098280787676, 8.542397618865422, 8.541620434139375, 8.541079194725029, 8.541064846699317]
# Top 5 seeds: [58, 482, 242, 246, 328]
# Plot saved to: data_450/loss_0.02/log_volume.png
# Test loss  [4.913583374023437, 3.9533917903900146, 5.709335207939148, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [6027036.7885717265, 4422614.691847609, 6614017.202140625, 5318391.1372336885, 3661203.2379139243]
# Plot saved to: data_450/loss_0.02/gen_log_volume.png
# Plot saved to: data_450/loss_0.02/test_vs_data.png
# Plot saved to: data_450/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_450/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_450/acc_0.85/avg_radius.png
# Plot saved to: data_450/acc_0.85/radius_hist.png
# Plot saved to: data_450/acc_0.85/log_volume.png
# Plot saved to: data_450/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [4, 2, 5, 3, 1]
# test_loss ranks: [2, 5, 1, 4, 3]
# log_exp_r_n ranks: [2, 4, 1, 3, 5]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  2
# Results saved to data_450/loss_0.02\results.json
# Successfully analyzed data_450 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_4950
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 3 models from data_4950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 4950
# data_19950: 0.0008322859648615122
# data_4950: 0.0007788533112034202
# data_49950: 0.0002858700754586607
#
# Top perturbations for data_19950:
# Top 5 r_vals: [19.186106448002757, 16.154432508680557, 16.1517951871142, 16.150909047067902, 16.15047049816744]
# Top 5 seeds: [72, 440, 58, 377, 482]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [30.011078805634472, 30.010109192959426, 30.006962155288683, 30.002884737825703, 30.0019011134068]
# Top 5 seeds: [320, 139, 463, 225, 381]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.814124241348141, 10.812358761621901, 10.811909825348657, 10.811765560433885, 10.81147198637655]
# Top 5 seeds: [440, 58, 361, 377, 482]
# Plot saved to: data_4950/loss_0.1/log_volume.png
# Test loss  [3.9533917903900146, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [4748509.607483537, 5572441.920495314, 4063782.779866423]
# Plot saved to: data_4950/loss_0.1/gen_log_volume.png
# Plot saved to: data_4950/loss_0.1/test_vs_data.png
# Plot saved to: data_4950/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_4950/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_4950/acc_0.95/avg_radius.png
# Plot saved to: data_4950/acc_0.95/radius_hist.png
# Plot saved to: data_4950/acc_0.95/log_volume.png
# Plot saved to: data_4950/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [3, 2, 1]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_4950/loss_0.1\results.json
# Successfully analyzed data_4950 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 3 models from data_4950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 4950
# data_19950: 0.0008322859648615122
# data_4950: 0.0007788533112034202
# data_49950: 0.0002858700754586607
#
# Top perturbations for data_19950:
# Top 5 r_vals: [16.12998077015818, 16.12947741849923, 16.12349597318673, 16.12165889033565, 16.116256148726855]
# Top 5 seeds: [68, 229, 306, 72, 480]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [26.14298420401937, 26.142139563644665, 26.139398144162595, 26.135846260505954, 26.134989414345487]
# Top 5 seeds: [320, 139, 463, 225, 381]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.808856049845042, 10.806820199509298, 10.806318803267045, 10.80602522920971, 10.805823460098141]
# Top 5 seeds: [257, 380, 163, 316, 325]
# Plot saved to: data_4950/loss_0.05/log_volume.png
# Test loss  [3.9533917903900146, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [4423541.317884824, 5319396.692393766, 4062536.9069091897]
# Plot saved to: data_4950/loss_0.05/gen_log_volume.png
# Plot saved to: data_4950/loss_0.05/test_vs_data.png
# Plot saved to: data_4950/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_4950/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_4950/acc_0.9/avg_radius.png
# Plot saved to: data_4950/acc_0.9/radius_hist.png
# Plot saved to: data_4950/acc_0.9/log_volume.png
# Plot saved to: data_4950/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [3, 2, 1]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_4950/loss_0.05\results.json
# Successfully analyzed data_4950 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 3 models from data_4950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 4950
# data_19950: 0.0008322859648615122
# data_4950: 0.0007788533112034202
# data_49950: 0.0002858700754586607
#
# Top perturbations for data_19950:
# Top 5 r_vals: [13.344266728203758, 13.330562619965441, 13.33014662685887, 13.325203283625399, 13.32368503333525]
# Top 5 seeds: [257, 68, 229, 306, 72]
#
# Top perturbations for data_4950:
# Top 5 r_vals: [22.54165474734323, 22.54092646048953, 22.53856268552795, 22.535500091966863, 22.527535243832745]
# Top 5 seeds: [320, 139, 463, 225, 244]
#
# Top perturbations for data_49950:
# Top 5 r_vals: [8.542397618865422, 8.541305574686257, 8.541079194725029, 8.54073643633303, 8.54043991046832]
# Top 5 seeds: [482, 217, 246, 160, 64]
# Plot saved to: data_4950/loss_0.02/log_volume.png
# Test loss  [3.9533917903900146, 4.286296606063843, 4.488439083099365]
# log_exp_r_n  [4063782.779866423, 5045683.311874442, 3661203.2379139243]
# Plot saved to: data_4950/loss_0.02/gen_log_volume.png
# Plot saved to: data_4950/loss_0.02/test_vs_data.png
# Plot saved to: data_4950/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_4950/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_4950/acc_0.85/avg_radius.png
# Plot saved to: data_4950/acc_0.85/radius_hist.png
# Plot saved to: data_4950/acc_0.85/log_volume.png
# Plot saved to: data_4950/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [2, 3, 1]
# test_loss ranks: [3, 2, 1]
# log_exp_r_n ranks: [2, 1, 3]
# log_exp_r_n_acc ranks: [1, 2, 3]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  1
#
# Accuracy:
# Does it predict the minimas which are actually trained?  False
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_4950/loss_0.02\results.json
# Successfully analyzed data_4950 with loss=0.02, acc=0.85
#
# ==================================================
# Analyzing directory: data_49950
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 1 models from data_49950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 49950
# data_49950: 0.000289236253593117
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.814124241348141, 10.812358761621901, 10.811909825348657, 10.811765560433885, 10.81147198637655]
# Top 5 seeds: [440, 58, 361, 377, 482]
# Plot saved to: data_49950/loss_0.1/log_volume.png
# Test loss  [4.488439083099365]
# log_exp_r_n  [4063782.779866423]
# Plot saved to: data_49950/loss_0.1/gen_log_volume.png
# Plot saved to: data_49950/loss_0.1/test_vs_data.png
# Plot saved to: data_49950/loss_0.1/other_plots/avg_radius.png
# Plot saved to: data_49950/loss_0.1/other_plots/radius_hist.png
# Plot saved to: data_49950/acc_0.95/avg_radius.png
# Plot saved to: data_49950/acc_0.95/radius_hist.png
# Plot saved to: data_49950/acc_0.95/log_volume.png
# Plot saved to: data_49950/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_49950/loss_0.1\results.json
# Successfully analyzed data_49950 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 1 models from data_49950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 49950
# data_49950: 0.000289236253593117
#
# Top perturbations for data_49950:
# Top 5 r_vals: [10.809803355823863, 10.808856049845042, 10.80772513397469, 10.807080481663224, 10.806684005358989]
# Top 5 seeds: [246, 257, 458, 199, 412]
# Plot saved to: data_49950/loss_0.05/log_volume.png
# Test loss  [4.488439083099365]
# log_exp_r_n  [4062536.9069091897]
# Plot saved to: data_49950/loss_0.05/gen_log_volume.png
# Plot saved to: data_49950/loss_0.05/test_vs_data.png
# Plot saved to: data_49950/loss_0.05/other_plots/avg_radius.png
# Plot saved to: data_49950/loss_0.05/other_plots/radius_hist.png
# Plot saved to: data_49950/acc_0.9/avg_radius.png
# Plot saved to: data_49950/acc_0.9/radius_hist.png
# Plot saved to: data_49950/acc_0.9/log_volume.png
# Plot saved to: data_49950/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_49950/loss_0.05\results.json
# Successfully analyzed data_49950 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 1 models from data_49950
# The size of the base dataset is  50
# The number of model parameters is  1707274
# The loss landscape is for data trained with 49950
# data_49950: 0.000289236253593117
#
# Top perturbations for data_49950:
# Top 5 r_vals: [8.542397618865422, 8.541305574686257, 8.541079194725029, 8.54073643633303, 8.54043991046832]
# Top 5 seeds: [482, 217, 246, 160, 64]
# Plot saved to: data_49950/loss_0.02/log_volume.png
# Test loss  [4.488439083099365]
# log_exp_r_n  [3661606.9510319903]
# Plot saved to: data_49950/loss_0.02/gen_log_volume.png
# Plot saved to: data_49950/loss_0.02/test_vs_data.png
# Plot saved to: data_49950/loss_0.02/other_plots/avg_radius.png
# Plot saved to: data_49950/loss_0.02/other_plots/radius_hist.png
# Plot saved to: data_49950/acc_0.85/avg_radius.png
# Plot saved to: data_49950/acc_0.85/radius_hist.png
# Plot saved to: data_49950/acc_0.85/log_volume.png
# Plot saved to: data_49950/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [1]
# test_loss ranks: [1]
# log_exp_r_n ranks: [1]
# log_exp_r_n_acc ranks: [1]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  0
# Results saved to data_49950/loss_0.02\results.json
# Successfully analyzed data_49950 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
