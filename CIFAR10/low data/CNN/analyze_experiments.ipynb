# %% [markdown]
# # Comparisons In A Given Loss Landscape

# %%
import os
import json
from pathlib import Path
import matplotlib.pyplot as plt

from minima_volume.analysis_funcs import (  grab_folder_names,
                                            load_base_train_size,
                                            list_additional_data,
                                            multiple_minima_fixed_landscape,
                                            fixed_landscape_minima_labels,
                                            plot_fixed_landscape_minima_pair,
                                            model_volume_across_targets,
                                            append_cutoff_points,
                                            varying_landscape_minima_labels,
                                            plot_minima_volume_vs_data_level,
)

loss_value = 0.1  # Loss value to analyze
data_level_log = False #Is the data log distributed?
base_output_dir = "analysis"  # Root folder to save all plots
os.makedirs(base_output_dir, exist_ok=True)

# Data for the loss landscape levels
experiment_folders, data_modifications = grab_folder_names()

base_train_size = load_base_train_size(experiment_folders[0])
model_data_sizes = list_additional_data(experiment_folders[0])

base_shift = 0
if data_modifications[0].startswith("data_"):
    base_shift = base_train_size  # Shift to reflect true dataset size

print("Experiment folders: ", experiment_folders)
print("Different data levels where loss landscapes were computed:", data_modifications)
print("The base train size is: ", base_train_size)
print("Data levels where models were trained: ", model_data_sizes)
# Out:
# First entry: Model_0, base_train_size = 50
# Experiment folders:  ['model_0_data_10', 'model_1_data_11', 'model_2_data_12', 'model_3_data_13', 'model_4_data_14', 'model_5_data_15', 'model_6_data_16', 'model_7_data_17', 'model_8_data_18', 'model_9_data_19']
# Different data levels where loss landscapes were computed: ['data_0', 'data_1950', 'data_19950', 'data_450', 'data_4950', 'data_49950']
# The base train size is:  50
# Data levels where models were trained:  [0, 1950, 19950, 450, 4950, 49950]

# %% [markdown]
# ## Plotting Different Model Volumes In A Landscape

# %%
for data_modification in data_modifications:
    print(f"\nProcessing data modification folder: {data_modification}")

    # Create output folder for this data_modification
    save_dir = os.path.join(base_output_dir, data_modification)
    os.makedirs(save_dir, exist_ok=True)

    # Get axis labels and titles
    labels = fixed_landscape_minima_labels(data_modification, base_train_size)

    # Extract minima landscapes
    all_mdl, all_log_rn, all_test_loss = multiple_minima_fixed_landscape(
        experiment_folders, data_modification, loss_value
    )

    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=data_level_log,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_log_volume",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="data_level_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=False,
        alpha=0.5,
        output_dir=save_dir, filename="log_volume_vs_test_loss",
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )

    ## Rank variant
    # Plot: Data level vs Log Volume
    plot_fixed_landscape_minima_pair(
        all_mdl, all_log_rn,
        xlabel=labels["xlabel"], ylabel="Log Volume",
        title=labels["title_volume"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_log_volume",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Data level vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_mdl, all_test_loss,
        xlabel=labels["xlabel"], ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="data_level_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16,
        base_shift=base_shift,
    )

    # Plot: Log Volume vs Test Loss
    plot_fixed_landscape_minima_pair(
        all_log_rn, all_test_loss,
        xlabel="Log Volume", ylabel="Test Loss",
        title=labels["title_loss"],
        log_scale=False,
        ranking=True,
        alpha=0.5,
        output_dir=os.path.join(save_dir, "ranks"), filename="log_volume_vs_test_loss",
        show_plot = False,
        plot_average=True,
        xlabel_size=14, ylabel_size=14, title_size=16
    )
# Out:
# Processing data modification folder: data_0
# ⚠️ Inf detected in y_vals: [8058746.73946771 7549992.45380919 6790176.7145264  6429413.65125296
#  5806028.92551243             -inf]
# ⚠️ Inf detected in y_vals: [8174614.07511588 7411641.34903529 6790072.47927277 6235739.47448344
#  5572055.51091134             -inf]
# L:\Programming\diffusion-env\Lib\site-packages\numpy\core\_methods.py:173: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# ⚠️ Inf detected in x_vals: [8058746.73946771 7549992.45380919 6790176.7145264  6429413.65125296
#  5806028.92551243             -inf]
# ⚠️ Inf detected in x_vals: [8174614.07511588 7411641.34903529 6790072.47927277 6235739.47448344
#  5572055.51091134             -inf]
# Processing data modification folder: data_1950
# ⚠️ Inf detected in y_vals: [6429590.33493428 6026728.3990596  5046647.81685904             -inf]
# ⚠️ Inf detected in y_vals: [6430313.94125437 6027714.73074559 5046647.81685904             -inf]
# ⚠️ Inf detected in x_vals: [6429590.33493428 6026728.3990596  5046647.81685904             -inf]
# ⚠️ Inf detected in x_vals: [6430313.94125437 6027714.73074559 5046647.81685904             -inf]
# Processing data modification folder: data_19950
# ⚠️ Inf detected in y_vals: [5046647.81685904             -inf]
# ⚠️ Inf detected in y_vals: [5046647.81685904             -inf]
# ⚠️ Inf detected in x_vals: [5046647.81685904             -inf]
# ⚠️ Inf detected in x_vals: [5046647.81685904             -inf]
# Processing data modification folder: data_450
# ⚠️ Inf detected in y_vals: [7113976.33085472 6430433.95468462 6028258.12585004 5319051.40710885
#              -inf]
# ⚠️ Inf detected in y_vals: [7265348.80803167 6430433.95468448 5808582.18371187 5046694.17544472
#              -inf]
# ⚠️ Inf detected in y_vals: [7266319.50274082 6430433.95910736 6027714.73074559 5318510.81448234
#              -inf]
# ⚠️ Inf detected in x_vals: [7113976.33085472 6430433.95468462 6028258.12585004 5319051.40710885
#              -inf]
# ⚠️ Inf detected in x_vals: [7265348.80803167 6430433.95468448 5808582.18371187 5046694.17544472
#              -inf]
# ⚠️ Inf detected in x_vals: [7266319.50274082 6430433.95910736 6027714.73074559 5318510.81448234
#              -inf]
# Processing data modification folder: data_4950
# ⚠️ Inf detected in y_vals: [6024826.52783232 5046647.81685904             -inf]
# ⚠️ Inf detected in y_vals: [6027338.28559903 5046647.81685904             -inf]
# ⚠️ Inf detected in x_vals: [6024826.52783232 5046647.81685904             -inf]
# ⚠️ Inf detected in x_vals: [6027338.28559903 5046647.81685904             -inf]
# Processing data modification folder: data_49950
# Warning: model_8_data_18\data_49950\loss_0.1\results.json does not exist!
# ⚠️ Inf detected in y_vals: [-inf]
# ⚠️ Inf detected in x_vals: [-inf]

# %% [markdown]
# # Comparisons Across Loss Landscapes

# %% [markdown]
# Here, we track the performance of all models across all loss landscapes.

# %%
# For the poisoning experiments, this plot has no meaning

labels = varying_landscape_minima_labels(
    data_modification_folder=data_modifications[0], # Random choice to grab datatype from
    base_train_size=base_train_size,
)

results_dict = model_volume_across_targets(
    target_model_data_levels=model_data_sizes,
    loss_value=loss_value,
    experiment_folders=experiment_folders
)
results_with_cutoff = append_cutoff_points(results_dict, threshold=loss_value, base_dir=".")

plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          # NEW: needed for correct legend labels
    base_train_size=base_train_size,  # NEW: used for dataset size shifts
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = data_level_log,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels",
    xlabel_size=15, ylabel_size=15, title_size=15
)
# Out:
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Collected results for 10 experiments
# Model_0: first exceedance at index 50 (value=0.4215545654296875, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=0, cutoff_idx=50
# Model_0: first exceedance at index 50 (value=0.12610574066638947, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=0, cutoff_idx=50
# Model_0: first exceedance at index 53 (value=0.39620983600616455, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=0, cutoff_idx=53
# Model_0: first exceedance at index 50 (value=0.19754287600517273, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=0, cutoff_idx=50
# Model_0: first exceedance at index 50 (value=0.25769108533859253, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=0, cutoff_idx=50
# Model_0: first exceedance at index 50 (value=0.39399510622024536, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=0, cutoff_idx=50
# Model_0: first exceedance at index 50 (value=0.3290348947048187, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=0, cutoff_idx=50
# Model_0: first exceedance at index 52 (value=0.18806275725364685, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=0, cutoff_idx=52
# Model_0: first exceedance at index 50 (value=0.123710997402668, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=0, cutoff_idx=50
# Model_0: first exceedance at index 50 (value=0.15556688606739044, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=0, cutoff_idx=50
# Model_450: first exceedance at index 505 (value=0.1071752980351448, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=450, cutoff_idx=505
# Model_450: first exceedance at index 507 (value=0.10911598056554794, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=450, cutoff_idx=507
# Model_450: first exceedance at index 505 (value=0.10385783016681671, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=450, cutoff_idx=505
# Model_450: first exceedance at index 507 (value=0.11739947646856308, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=450, cutoff_idx=507
# Model_450: first exceedance at index 511 (value=0.10370450466871262, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=450, cutoff_idx=511
# Model_450: first exceedance at index 505 (value=0.10873372852802277, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=450, cutoff_idx=505
# Model_450: first exceedance at index 504 (value=0.15141186118125916, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=450, cutoff_idx=504
# Model_450: first exceedance at index 509 (value=0.11100495606660843, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=450, cutoff_idx=509
# Model_450: first exceedance at index 503 (value=0.10051138699054718, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=450, cutoff_idx=503
# Model_450: first exceedance at index 512 (value=0.10011133551597595, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=450, cutoff_idx=512
# Model_1950: first exceedance at index 2041 (value=0.10421331226825714, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=1950, cutoff_idx=2041
# Model_1950: first exceedance at index 2047 (value=0.10006112605333328, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=1950, cutoff_idx=2047
# Model_1950: first exceedance at index 2047 (value=0.1002373993396759, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=1950, cutoff_idx=2047
# Model_1950: first exceedance at index 2039 (value=0.1005997285246849, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=1950, cutoff_idx=2039
# Model_1950: first exceedance at index 2042 (value=0.10449816286563873, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=1950, cutoff_idx=2042
# Model_1950: first exceedance at index 2041 (value=0.10138575732707977, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=1950, cutoff_idx=2041
# Model_1950: first exceedance at index 2055 (value=0.1014629676938057, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=1950, cutoff_idx=2055
# Model_1950: first exceedance at index 2043 (value=0.10191652923822403, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=1950, cutoff_idx=2043
# Model_1950: first exceedance at index 2046 (value=0.10019123554229736, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=1950, cutoff_idx=2046
# Model_1950: first exceedance at index 2035 (value=0.10400756448507309, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=1950, cutoff_idx=2035
# Model_4950: first exceedance at index 5113 (value=0.10018383711576462, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=4950, cutoff_idx=5113
# Model_4950: first exceedance at index 5114 (value=0.10136395692825317, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=4950, cutoff_idx=5114
# Model_4950: first exceedance at index 5132 (value=0.10249807685613632, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=4950, cutoff_idx=5132
# Model_4950: first exceedance at index 5117 (value=0.10026194155216217, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=4950, cutoff_idx=5117
# Model_4950: first exceedance at index 5117 (value=0.10153035074472427, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=4950, cutoff_idx=5117
# Model_4950: first exceedance at index 5088 (value=0.10121259093284607, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=4950, cutoff_idx=5088
# Model_4950: first exceedance at index 5088 (value=0.10023678094148636, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=4950, cutoff_idx=5088
# Model_4950: first exceedance at index 5109 (value=0.10041788220405579, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=4950, cutoff_idx=5109
# Model_4950: first exceedance at index 5122 (value=0.10125633329153061, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=4950, cutoff_idx=5122
# Model_4950: first exceedance at index 5105 (value=0.10202483087778091, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=4950, cutoff_idx=5105
# Model_19950: first exceedance at index 20479 (value=0.10010244697332382, threshold=0.1)
# Appended cutoff for model_0_data_10 | target=19950, cutoff_idx=20479
# Model_19950: first exceedance at index 20442 (value=0.10026545077562332, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=19950, cutoff_idx=20442
# Model_19950: first exceedance at index 20397 (value=0.1000506579875946, threshold=0.1)
# Appended cutoff for model_2_data_12 | target=19950, cutoff_idx=20397
# Model_19950: first exceedance at index 20511 (value=0.10019757598638535, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=19950, cutoff_idx=20511
# Model_19950: first exceedance at index 20440 (value=0.10023237764835358, threshold=0.1)
# Appended cutoff for model_4_data_14 | target=19950, cutoff_idx=20440
# Model_19950: first exceedance at index 20503 (value=0.10002613067626953, threshold=0.1)
# Appended cutoff for model_5_data_15 | target=19950, cutoff_idx=20503
# Model_19950: first exceedance at index 20413 (value=0.10072130709886551, threshold=0.1)
# Appended cutoff for model_6_data_16 | target=19950, cutoff_idx=20413
# Model_19950: first exceedance at index 20479 (value=0.10010458528995514, threshold=0.1)
# Appended cutoff for model_7_data_17 | target=19950, cutoff_idx=20479
# Model_19950: first exceedance at index 20402 (value=0.10004974156618118, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=19950, cutoff_idx=20402
# Model_19950: first exceedance at index 20462 (value=0.10003408044576645, threshold=0.1)
# Appended cutoff for model_9_data_19 | target=19950, cutoff_idx=20462
# ⚠️ Skipped model_0_data_10 (target=49950): Model_49950: loss curve never exceeds threshold=0.1
# Model_49950: first exceedance at index 1 (value=0.17149780690670013, threshold=0.1)
# Appended cutoff for model_1_data_11 | target=49950, cutoff_idx=1
# ⚠️ Skipped model_2_data_12 (target=49950): Model_49950: loss curve never exceeds threshold=0.1
# Model_49950: first exceedance at index 1 (value=0.1626814752817154, threshold=0.1)
# Appended cutoff for model_3_data_13 | target=49950, cutoff_idx=1
# ⚠️ Skipped model_4_data_14 (target=49950): Model_49950: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_5_data_15 (target=49950): Model_49950: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_6_data_16 (target=49950): Model_49950: loss curve never exceeds threshold=0.1
# ⚠️ Skipped model_7_data_17 (target=49950): Model_49950: loss curve never exceeds threshold=0.1
# Model_49950: first exceedance at index 0 (value=0.12967200577259064, threshold=0.1)
# Appended cutoff for model_8_data_18 | target=49950, cutoff_idx=0
# ⚠️ Skipped model_9_data_19 (target=49950): Model_49950: loss curve never exceeds threshold=0.1

# %%
plot_minima_volume_vs_data_level(
    results_dict = results_with_cutoff,
    data_type=labels["data_type"],          # NEW: needed for correct legend labels
    base_train_size=base_train_size,  # NEW: used for dataset size shifts
    xlabel=labels["xlabel"],
    ylabel="Log Volume",
    title=labels["title_volume"],
    log_scale = True,
    alpha=0.1,
    plot_average=True,
    output_dir=base_output_dir, filename="log_volumes_vs_data_levels_log",
    xlabel_size=15, ylabel_size=15, title_size=15
)
