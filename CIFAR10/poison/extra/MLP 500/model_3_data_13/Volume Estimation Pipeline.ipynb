# %% [markdown]
# # Volume Estimation
#
# This notebook estimates volume for all model radii stored in a given folder as npz files.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

import json

from minima_volume.volume_funcs import ( analyze_and_plot_model_landscape )

# %% [markdown]
# ## Input Parameters
#
# The input parameters are the folder to analyze, the files in the folder, and the loss and accuracy thresholds to use. Note that to check our thresholds are reasonable, we also print the base loss + accuracy thresholds.

# %%
# Define thresholds as pairs
loss_thresholds = [0.1, 0.05, 0.02]
accuracy_thresholds = [0.95, 0.9, 0.85]

if len(loss_thresholds) != len(accuracy_thresholds):
    raise ValueError("loss_thresholds and accuracy_thresholds must have the same length!")

display_options = {
    'loss_plots': False,
    'accuracy_plots': False
}

valid_starts = ['poison', 'noise', 'data']
directories_to_analyze = [d for d in os.listdir('.') 
                           if os.path.isdir(d) and any(d.startswith(prefix) for prefix in valid_starts)]

print("Directories to analyze:", directories_to_analyze)

# Loop through each directory
for directory in directories_to_analyze:
    print(f"\n{'='*50}")
    print(f"Analyzing directory: {directory}")
    print(f"{'='*50}")

    # Loop through each (loss, acc) pair
    for loss_threshold, accuracy_threshold in zip(loss_thresholds, accuracy_thresholds):
        print(f"\n--- Using thresholds: loss={loss_threshold}, acc={accuracy_threshold} ---")

        save_paths_dict = {
            "log_volume": f"{directory}/loss_{loss_threshold}/log_volume.png",
            "log_volume_generalization": f"{directory}/loss_{loss_threshold}/gen_log_volume.png",
            "model_modification_vs_test_loss": f"{directory}/loss_{loss_threshold}/test_vs_data.png",
            "average_radius_loss": f"{directory}/loss_{loss_threshold}/other_plots/avg_radius.png",
            "radius_histogram_loss": f"{directory}/loss_{loss_threshold}/other_plots/radius_hist.png",
            "average_radius_acc": f"{directory}/acc_{accuracy_threshold}/avg_radius.png",
            "radius_histogram_acc": f"{directory}/acc_{accuracy_threshold}/radius_hist.png",
            "log_volume_acc": f"{directory}/acc_{accuracy_threshold}/log_volume.png",
            "log_volume_generalization_acc": f"{directory}/acc_{accuracy_threshold}/gen_log_volume.png",
            "results.json": f"{directory}/loss_{loss_threshold}",
        }

        try:
            results = analyze_and_plot_model_landscape(
                directory=directory, 
                loss_threshold=loss_threshold, 
                acc_threshold=accuracy_threshold, 
                verbose=True,
                display_options=display_options,
                save_paths_dict=save_paths_dict,
                max_perturbs = None, # Analyze all our perturbations!
            )
            print(f"Successfully analyzed {directory} with loss={loss_threshold}, acc={accuracy_threshold}")
        
        except Exception as e:
            print(f"Error analyzing {directory} with loss={loss_threshold}, acc={accuracy_threshold}: {e}")
            continue

print("\nAnalysis complete for all directories!")
# Out:
# Directories to analyze: ['poison_0']
#
# ==================================================
# Analyzing directory: poison_0
# ==================================================
#
# --- Using thresholds: loss=0.1, acc=0.95 ---
# Loaded data dictionary with 5 models from poison_0
# The number of model parameters is  1707274
# The loss landscape is for poison trained with 0
# poison_0: 0.0013778844149783254
# poison_10: 0.002115530427545309
# poison_100: 0.0010492587462067604
# poison_1000: 0.002706350991502404
# poison_500: 0.0017391216242685914
#
# Top perturbations for poison_0:
# Top 5 r_vals: [22.559453572877615, 22.55726871231651, 22.54962591010325, 22.549049174271126, 22.5484998018179]
# Top 5 seeds: [862, 482, 228, 444, 839]
#
# Top perturbations for poison_10:
# Top 5 r_vals: [22.55726871231651, 22.54962591010325, 22.5484998018179, 22.547502090925835, 22.546199173115312]
# Top 5 seeds: [482, 228, 839, 588, 633]
#
# Top perturbations for poison_100:
# Top 5 r_vals: [22.54962591010325, 19.225109762396695, 19.22225629878329, 19.22117302284206, 19.2203946424472]
# Top 5 seeds: [228, 440, 862, 361, 482]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [19.22348484848485, 19.22225629878329, 19.21388243227732, 19.21346633953168, 19.213391012396695]
# Top 5 seeds: [906, 862, 228, 820, 444]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [19.225109762396695, 19.22348484848485, 19.22225629878329, 19.2203946424472, 19.217632647497705]
# Top 5 seeds: [440, 906, 862, 482, 945]
# Plot saved to: poison_0/loss_0.1/log_volume.png
# Test loss  [3.9137613773345947, 3.772554397583008, 4.19923734664917, 3.8180019855499268, 3.895505428314209]
# log_exp_r_n  [5320122.146903328, 5319956.7911131205, 5319378.238422232, 5046921.592808318, 5047065.898383264]
# Plot saved to: poison_0/loss_0.1/gen_log_volume.png
# Plot saved to: poison_0/loss_0.1/test_vs_data.png
# Plot saved to: poison_0/loss_0.1/other_plots/avg_radius.png
# Plot saved to: poison_0/loss_0.1/other_plots/radius_hist.png
# Plot saved to: poison_0/acc_0.95/avg_radius.png
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: divide by zero encountered in divide
#   return n/db/n.sum(), bin_edges
# L:\Programming\diffusion-env\Lib\site-packages\numpy\lib\histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Plot saved to: poison_0/acc_0.95/radius_hist.png
# Plot saved to: poison_0/acc_0.95/log_volume.png
# Plot saved to: poison_0/acc_0.95/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 4, 3, 1, 2]
# test_loss ranks: [2, 5, 1, 4, 3]
# log_exp_r_n ranks: [1, 2, 3, 5, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to poison_0/loss_0.1\results.json
# Successfully analyzed poison_0 with loss=0.1, acc=0.95
#
# --- Using thresholds: loss=0.05, acc=0.9 ---
# Loaded data dictionary with 5 models from poison_0
# The number of model parameters is  1707274
# The loss landscape is for poison trained with 0
# poison_0: 0.0013778844149783254
# poison_10: 0.002115530427545309
# poison_100: 0.0010492587462067604
# poison_1000: 0.002706350991502404
# poison_500: 0.0017391216242685914
#
# Top perturbations for poison_0:
# Top 5 r_vals: [19.22225629878329, 19.2203946424472, 19.21388243227732, 19.213391012396695, 19.212922908057852]
# Top 5 seeds: [862, 482, 228, 444, 839]
#
# Top perturbations for poison_10:
# Top 5 r_vals: [19.2203946424472, 19.21388243227732, 19.212922908057852, 19.21207278753444, 19.210962609044998]
# Top 5 seeds: [482, 228, 839, 588, 633]
#
# Top perturbations for poison_100:
# Top 5 r_vals: [19.21388243227732, 19.212922908057852, 19.190622489095503, 19.19033194157484, 16.154432508680557]
# Top 5 seeds: [228, 839, 700, 53, 440]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [16.15306712962963, 16.152034806616513, 16.15047049816744, 16.146769205729168, 16.144998432677472]
# Top 5 seeds: [906, 862, 482, 64, 228]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [16.154432508680557, 16.15306712962963, 16.152034806616513, 16.151124553915896, 16.15047049816744]
# Top 5 seeds: [440, 906, 862, 361, 482]
# Plot saved to: poison_0/loss_0.05/log_volume.png
# Test loss  [3.9137613773345947, 3.772554397583008, 4.19923734664917, 3.8180019855499268, 3.895505428314209]
# log_exp_r_n  [5046812.479502069, 5046647.123711862, 5046068.571020973, 4749817.069531132, 4749961.375106078]
# Plot saved to: poison_0/loss_0.05/gen_log_volume.png
# Plot saved to: poison_0/loss_0.05/test_vs_data.png
# Plot saved to: poison_0/loss_0.05/other_plots/avg_radius.png
# Plot saved to: poison_0/loss_0.05/other_plots/radius_hist.png
# Plot saved to: poison_0/acc_0.9/avg_radius.png
# Plot saved to: poison_0/acc_0.9/radius_hist.png
# Plot saved to: poison_0/acc_0.9/log_volume.png
# Plot saved to: poison_0/acc_0.9/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 4, 3, 1, 2]
# test_loss ranks: [2, 5, 1, 4, 3]
# log_exp_r_n ranks: [1, 2, 3, 5, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  3
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to poison_0/loss_0.05\results.json
# Successfully analyzed poison_0 with loss=0.05, acc=0.9
#
# --- Using thresholds: loss=0.02, acc=0.85 ---
# Loaded data dictionary with 5 models from poison_0
# The number of model parameters is  1707274
# The loss landscape is for poison trained with 0
# poison_0: 0.0013778844149783254
# poison_10: 0.002115530427545309
# poison_100: 0.0010492587462067604
# poison_1000: 0.002706350991502404
# poison_500: 0.0017391216242685914
#
# Top perturbations for poison_0:
# Top 5 r_vals: [16.144998432677472, 16.144585503472225, 16.143907335069446, 16.14046374662423, 16.138905466338738]
# Top 5 seeds: [228, 444, 260, 755, 640]
#
# Top perturbations for poison_10:
# Top 5 r_vals: [16.13336859809028, 13.358946053814666, 13.350770668331041, 13.34964225589226, 13.348789096377287]
# Top 5 seeds: [946, 995, 440, 906, 862]
#
# Top perturbations for poison_100:
# Top 5 r_vals: [16.144998432677472, 13.350770668331041, 13.348789096377287, 13.348036821418098, 13.347858716585046]
# Top 5 seeds: [228, 440, 862, 361, 377]
#
# Top perturbations for poison_1000:
# Top 5 r_vals: [13.348789096377287, 13.342973911303698, 13.342307575040179, 13.341717213565584, 13.341064577673839]
# Top 5 seeds: [862, 228, 839, 588, 543]
#
# Top perturbations for poison_500:
# Top 5 r_vals: [13.350770668331041, 13.34964225589226, 13.348789096377287, 13.347496279477225, 13.345578227428964]
# Top 5 seeds: [440, 906, 862, 482, 945]
# Plot saved to: poison_0/loss_0.02/log_volume.png
# Test loss  [3.9137613773345947, 3.772554397583008, 4.19923734664917, 3.8180019855499268, 3.895505428314209]
# log_exp_r_n  [4748964.047743787, 4747733.792504712, 4748964.047743787, 4424266.772394385, 4424520.19127558]
# Plot saved to: poison_0/loss_0.02/gen_log_volume.png
# Plot saved to: poison_0/loss_0.02/test_vs_data.png
# Plot saved to: poison_0/loss_0.02/other_plots/avg_radius.png
# Plot saved to: poison_0/loss_0.02/other_plots/radius_hist.png
# Plot saved to: poison_0/acc_0.85/avg_radius.png
# Plot saved to: poison_0/acc_0.85/radius_hist.png
# Plot saved to: poison_0/acc_0.85/log_volume.png
# Plot saved to: poison_0/acc_0.85/gen_log_volume.png
# Ranks for quick verification:
# data_level ranks: [5, 4, 3, 1, 2]
# test_loss ranks: [2, 5, 1, 4, 3]
# log_exp_r_n ranks: [1, 3, 2, 5, 4]
# log_exp_r_n_acc ranks: [1, 2, 3, 4, 5]
#
# Loss:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
#
# Accuracy:
# Does it predict the minimas which are actually trained?  True
# How many violations does it have, when ordering the log volumes?  2
# Results saved to poison_0/loss_0.02\results.json
# Successfully analyzed poison_0 with loss=0.02, acc=0.85
#
# Analysis complete for all directories!
