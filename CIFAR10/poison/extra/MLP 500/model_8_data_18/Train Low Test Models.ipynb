# %% [markdown]
# # Train Low Test Models
#
# This notebook is a streamlined notebook for generating minima of low test accuracy through three different means:
# - Dataset Poisoning
# - Adding Noise to Data
# - Decreasing Dataset Sizes

# %% [markdown]
# ## Imports

# %%
# Standard library
import copy
import os
import sys
import time

# Third-party
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Local package imports
from minima_volume.dataset_funcs import (
    prepare_datasets,
    save_dataset,
    save_model,
)
from minima_volume.train_funcs import evaluate, train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Input Parameters

# %%
# ==============================
# Base Input Parameters
# ==============================
# --- SEEDS ---
data_seed = 18            
model_seed = 8           

# --- Training configuration ---
epochs = 500            

# --- Dataset configuration ---
base_data_size = 10000
dataset_type = "poison"   
dataset_quantities = [0, 10, 100, 500, 1000]

# --- Output configuration ---
base_output_dir = ""     
save_generated_dataset = True   
save_generated_models = True

# %% [markdown]
# ## Model + Dataset Specific Code
#
# This is for specific code.

# %%
# User specifies the CIFAR-10 model module name
from minima_volume.models import CIFAR10_model_data as model_module  # <- your new module for CIFAR-10

# Generate dataset
x_base, y_base, x_test, y_test = model_module.get_dataset(
    device=device
)

# CIFAR-10 MLP initialization parameters
# Since input dimension is higher, hidden layers can be larger
hidden_dims = [512, 256]  # adjust as desired

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Training
#
# We generate the various datasets used to train our models here, before training them. We record the losses, and what each model was trained on.

# %%
# ==============================
# Prepare datasets
# ==============================
x_base_train, y_base_train, x_additional, y_additional = prepare_datasets(
    x_base=x_base,
    y_base=y_base,
    dataset_type=dataset_type,
    dataset_quantities=dataset_quantities,
    base_data_size=base_data_size,
    data_seed=data_seed,
    seed_1=None,
    seed_2=None,
)

x_base_train = x_base_train.to(device)
y_base_train = y_base_train.to(device)
x_additional = x_additional.to(device)
y_additional = y_additional.to(device)
x_test = x_test.to(device)
y_test = y_test.to(device)

# ==============================
# Training loop
# ==============================
all_models = []

for additional_data in dataset_quantities:
    # Assemble training dataset
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    # Initialize model (defined in the model-specific file)
    torch.manual_seed(model_seed)
    model = copy.deepcopy(model_template)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    batch_size = len(x_train)

    # Train model
    train_loss, train_other_metrics, test_loss, test_other_metrics = train(
        model = model,
        x_train = x_train, y_train = y_train,
        x_test = x_test, y_test = y_test,
        loss_fn = loss_fn,
        metrics = other_metrics,
        optimizer = optimizer,
        epochs=epochs,
        batch_size=batch_size,
        verbose_every=100,
    )
    
    # Build dictionary dynamically for additional metrics
    train_metrics_dict = {}
    test_metrics_dict = {}
    if train_other_metrics is not None:
        # train_other_metrics is a list of dicts per epoch
        for metric_name in train_other_metrics[0].keys():  # keys from first epoch
            train_metrics_dict[f"train_{metric_name}"] = [m[metric_name] for m in train_other_metrics]
            test_metrics_dict[f"test_{metric_name}"] = [m[metric_name] for m in test_other_metrics]
    
    # Store results
    trained_model = {
        "model": model,
        "train_loss": train_loss,
        "test_loss": test_loss,
        "additional_data": additional_data,
        "dataset_type": dataset_type,
        **train_metrics_dict,  # dynamically include additional metrics
        **test_metrics_dict,
    }
    
    all_models.append(trained_model)

    print(f"Completed training with {additional_data} additional samples of {dataset_type}")

    # Free memory (important for large GPU datasets)
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# Epoch 1/500: Train Loss 2.3044 | Test Loss 2.1571 | accs Train 0.1084 Test 0.2336
# Epoch 100/500: Train Loss 0.2216 | Test Loss 2.0180 | accs Train 0.9667 Test 0.4498
# Epoch 200/500: Train Loss 0.0147 | Test Loss 3.0098 | accs Train 1.0000 Test 0.4484
# Epoch 300/500: Train Loss 0.0044 | Test Loss 3.4972 | accs Train 1.0000 Test 0.4485
# Epoch 400/500: Train Loss 0.0021 | Test Loss 3.8089 | accs Train 1.0000 Test 0.4480
# Epoch 500/500: Train Loss 0.0013 | Test Loss 4.0369 | accs Train 1.0000 Test 0.4475
# Completed training with 0 additional samples of poison
# Epoch 1/500: Train Loss 2.3043 | Test Loss 2.1576 | accs Train 0.1087 Test 0.2336
# Epoch 100/500: Train Loss 0.2521 | Test Loss 2.1242 | accs Train 0.9470 Test 0.4451
# Epoch 200/500: Train Loss 0.0195 | Test Loss 2.8986 | accs Train 1.0000 Test 0.4487
# Epoch 300/500: Train Loss 0.0063 | Test Loss 3.3357 | accs Train 1.0000 Test 0.4478
# Epoch 400/500: Train Loss 0.0031 | Test Loss 3.6144 | accs Train 1.0000 Test 0.4489
# Epoch 500/500: Train Loss 0.0019 | Test Loss 3.8219 | accs Train 1.0000 Test 0.4474
# Completed training with 10 additional samples of poison
# Epoch 1/500: Train Loss 2.3043 | Test Loss 2.1568 | accs Train 0.1084 Test 0.2339
# Epoch 100/500: Train Loss 0.3600 | Test Loss 2.1359 | accs Train 0.9018 Test 0.4380
# Epoch 200/500: Train Loss 0.0254 | Test Loss 2.7973 | accs Train 0.9999 Test 0.4457
# Epoch 300/500: Train Loss 0.0081 | Test Loss 3.2310 | accs Train 1.0000 Test 0.4436
# Epoch 400/500: Train Loss 0.0040 | Test Loss 3.5069 | accs Train 1.0000 Test 0.4428
# Epoch 500/500: Train Loss 0.0024 | Test Loss 3.7078 | accs Train 1.0000 Test 0.4425
# Completed training with 100 additional samples of poison
# Epoch 1/500: Train Loss 2.3044 | Test Loss 2.1551 | accs Train 0.1079 Test 0.2344
# Epoch 100/500: Train Loss 0.3842 | Test Loss 2.0392 | accs Train 0.9042 Test 0.4208
# Epoch 200/500: Train Loss 0.0282 | Test Loss 2.8280 | accs Train 0.9999 Test 0.4259
# Epoch 300/500: Train Loss 0.0080 | Test Loss 3.3300 | accs Train 1.0000 Test 0.4264
# Epoch 400/500: Train Loss 0.0035 | Test Loss 3.7080 | accs Train 1.0000 Test 0.4261
# Epoch 500/500: Train Loss 0.0020 | Test Loss 3.9789 | accs Train 1.0000 Test 0.4244
# Completed training with 500 additional samples of poison
# Epoch 1/500: Train Loss 2.3045 | Test Loss 2.1533 | accs Train 0.1081 Test 0.2352
# Epoch 100/500: Train Loss 0.4179 | Test Loss 1.9441 | accs Train 0.9066 Test 0.4277
# Epoch 200/500: Train Loss 0.0357 | Test Loss 2.8151 | accs Train 0.9997 Test 0.4181
# Epoch 300/500: Train Loss 0.0097 | Test Loss 3.3362 | accs Train 1.0000 Test 0.4165
# Epoch 400/500: Train Loss 0.0045 | Test Loss 3.6485 | accs Train 1.0000 Test 0.4143
# Epoch 500/500: Train Loss 0.0027 | Test Loss 3.8782 | accs Train 1.0000 Test 0.4139
# Completed training with 1000 additional samples of poison

# %% [markdown]
# ## Training Summary

# %%
# ====================================
# Summary of Training Results
# ====================================
print("=== True Generalization ===")
for model_data in all_models:
    model = model_data["model"]
    additional_data = model_data["additional_data"]

    test_loss, test_metrics = evaluate(
        model=model,
        x_test=x_test,
        y_test=y_test,
        loss_fn=loss_fn,
        metrics=other_metrics
    )

    metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in test_metrics.items()])
    print(
        f"{additional_data:>4} samples | "
        f"Test Loss: {test_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
    )

print("\n=== Model Diagnostics by Training Data ===")
for additional_data in dataset_quantities:
    # Build dataset with this many additional samples
    x_train = torch.cat([x_base_train, x_additional[:additional_data]], dim=0)
    y_train = torch.cat([y_base_train, y_additional[:additional_data]], dim=0)

    print(f"\nDataset type: {dataset_type}, additional samples: {additional_data}")

    for model_data in all_models:
        model = model_data["model"]
        model_additional_data = model_data["additional_data"]

        train_loss, train_metrics = evaluate(
            model=model,
            x_test=x_train,
            y_test=y_train,
            loss_fn=loss_fn,
            metrics=other_metrics
        )

        metrics_str = " | ".join([f"{name}: {val:.4f}" for name, val in train_metrics.items()])
        print(
            f" Model {model_additional_data:>4} | "
            f"Train Loss: {train_loss:.4f}" + (f" | {metrics_str}" if metrics_str else "")
        )

    # Free memory if large
    del x_train, y_train
    torch.cuda.empty_cache()
# Out:
# === True Generalization ===
#    0 samples | Test Loss: 4.0369 | accs: 0.4475
#   10 samples | Test Loss: 3.8219 | accs: 0.4474
#  100 samples | Test Loss: 3.7078 | accs: 0.4425
#  500 samples | Test Loss: 3.9789 | accs: 0.4244
# 1000 samples | Test Loss: 3.8782 | accs: 0.4139
#
# === Model Diagnostics by Training Data ===
#
# Dataset type: poison, additional samples: 0
#  Model    0 | Train Loss: 0.0012 | accs: 1.0000
#  Model   10 | Train Loss: 0.0019 | accs: 1.0000
#  Model  100 | Train Loss: 0.0024 | accs: 1.0000
#  Model  500 | Train Loss: 0.0019 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0025 | accs: 1.0000
#
# Dataset type: poison, additional samples: 10
#  Model    0 | Train Loss: 0.0194 | accs: 0.9990
#  Model   10 | Train Loss: 0.0019 | accs: 1.0000
#  Model  100 | Train Loss: 0.0024 | accs: 1.0000
#  Model  500 | Train Loss: 0.0019 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0025 | accs: 1.0000
#
# Dataset type: poison, additional samples: 100
#  Model    0 | Train Loss: 0.1398 | accs: 0.9904
#  Model   10 | Train Loss: 0.1212 | accs: 0.9913
#  Model  100 | Train Loss: 0.0024 | accs: 1.0000
#  Model  500 | Train Loss: 0.0019 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0025 | accs: 1.0000
#
# Dataset type: poison, additional samples: 500
#  Model    0 | Train Loss: 0.6858 | accs: 0.9552
#  Model   10 | Train Loss: 0.6417 | accs: 0.9560
#  Model  100 | Train Loss: 0.4988 | accs: 0.9645
#  Model  500 | Train Loss: 0.0020 | accs: 1.0000
#  Model 1000 | Train Loss: 0.0026 | accs: 1.0000
#
# Dataset type: poison, additional samples: 1000
#  Model    0 | Train Loss: 1.2821 | accs: 0.9137
#  Model   10 | Train Loss: 1.2106 | accs: 0.9145
#  Model  100 | Train Loss: 1.0469 | accs: 0.9228
#  Model  500 | Train Loss: 0.5408 | accs: 0.9570
#  Model 1000 | Train Loss: 0.0026 | accs: 1.0000

# %% [markdown]
# ### Model + Data Specific Verification

# %%
model_module.verify_model_results(
    all_models=all_models,
    x_base_train=x_base_train,
    y_base_train=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    x_test=x_test,
    y_test=y_test,
    dataset_quantities=dataset_quantities,
    dataset_type=dataset_type,
)

# %% [markdown]
# ## Model Saving

# %%
# ====================================
# Save Datasets and Models
# ====================================
output_folder = "models_and_data"
# Save dataset (Possible to skip)
if save_generated_dataset:
    save_dataset(
        folder=output_folder,
        filename="dataset.pt",
        x_base_train=x_base_train,
        y_base_train=y_base_train,
        x_additional=x_additional,
        y_additional=y_additional,
        x_test=x_test,
        y_test=y_test,
        dataset_quantities=dataset_quantities,
        dataset_type=dataset_type,
    )
    print(f"Saved dataset to {output_folder}/dataset.pt")

# Save trained models
if save_generated_models:
    for model_data in all_models:
        filename = f"model_additional_{model_data['additional_data']}.pt"
        save_model(
            folder=output_folder,
            filename=filename,
            model=model_data["model"],
            train_loss=model_data["train_loss"],
            train_accs=model_data["train_accs"],
            test_loss=model_data["test_loss"],
            test_accs=model_data["test_accs"],
            additional_data=model_data["additional_data"],
            dataset_type=model_data["dataset_type"],
        )
        print(f"Saved model: {output_folder}/{filename}")
# Out:
# ✅ Dataset saved to models_and_data\dataset.pt
# Saved dataset to models_and_data/dataset.pt
# ✅ Model saved to models_and_data\model_additional_0.pt
# Saved model: models_and_data/model_additional_0.pt
# ✅ Model saved to models_and_data\model_additional_10.pt
# Saved model: models_and_data/model_additional_10.pt
# ✅ Model saved to models_and_data\model_additional_100.pt
# Saved model: models_and_data/model_additional_100.pt
# ✅ Model saved to models_and_data\model_additional_500.pt
# Saved model: models_and_data/model_additional_500.pt
# ✅ Model saved to models_and_data\model_additional_1000.pt
# Saved model: models_and_data/model_additional_1000.pt
