# %% [markdown]
# # Model Analysis
#
# This program takes in a folder name with datasets and models, and in that folder generates a series of images and videos describing how the loss landscape changes over time.

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

import time
import glob

# Importing our existing funcs
import os
import sys
from pathlib import Path

from minima_volume.dataset_funcs import ( load_models_and_data )

from minima_volume.landscape_videos import (
    plot_2d_loss_landscape_3model,
    plot_3d_loss_landscape,
    load_computed_loss_landscapes,
)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Model

# %%
# User specifies the model module name
import MNIST_model_data as model_module

# Generate dataset
#x_base, y_base, x_test, y_test = model_module.get_dataset(
#    device = device
#)

# MNIST specific initialization parameters
hidden_dims = [256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=0)

# Grab loss and metrics
loss_fn_per_sample = model_module.get_loss_fn_per_sample()

# %% [markdown]
# ## Loading Model and Datasets

# %%
# Get the relative path
target_dir = Path("models_and_data") #current directory

# Lists to store loaded models and additional data
loaded_models, loaded_additional_data, loaded_dataset = load_models_and_data(model_template=model_template, target_dir=target_dir, device="cpu")

# Print dataset information
print(f"Dataset type: {loaded_dataset['dataset_type']}")
print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")

# Print tensor shapes
print("\nTensor shapes:")
for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
    if loaded_dataset[key] is not None:
        print(f"  {key}: {loaded_dataset[key].shape}")
    else:
        print(f"  {key}: None")
# Out:
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_additional_0.pt
#   - model_additional_1940.pt
#   - model_additional_19940.pt
#   - model_additional_540.pt
#   - model_additional_5940.pt
#   - model_additional_59940.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_0.pt
# Successfully loaded: model_additional_0.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_1940.pt
# Successfully loaded: model_additional_1940.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_19940.pt
# Successfully loaded: model_additional_19940.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_540.pt
# Successfully loaded: model_additional_540.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_5940.pt
# Successfully loaded: model_additional_5940.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_59940.pt
# Successfully loaded: model_additional_59940.pt
#
# Model data loaded from all models:
# Model 0 (model_additional_0.pt):
#   - Additional data: 0
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 1 (model_additional_1940.pt):
#   - Additional data: 1940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 2 (model_additional_19940.pt):
#   - Additional data: 19940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 3 (model_additional_540.pt):
#   - Additional data: 540
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 4 (model_additional_5940.pt):
#   - Additional data: 5940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 5 (model_additional_59940.pt):
#   - Additional data: 59940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
#
# Loading dataset...
# Using dataset file: dataset.pt
# ✅ Dataset loaded from models_and_data\dataset.pt
# Dataset type: data
# Dataset quantities: [0, 540, 1940, 5940, 19940, 59940]
#
# Tensor shapes:
#   x_base_train: torch.Size([60, 1, 28, 28])
#   y_base_train: torch.Size([60])
#   x_additional: torch.Size([59940, 1, 28, 28])
#   y_additional: torch.Size([59940])
#   x_test: torch.Size([10000, 1, 28, 28])
#   y_test: torch.Size([10000])

# %% [markdown]
# ## Plotting Parameters
#
# Determines what models to use.

# %%
index1 = 3
index2 = 4
index3 = 5
index_list = [index1, index2, index3]

print(
    f"Loading models trained with: "
    f"{loaded_additional_data[index1]['additional_data']}, "
    f"{loaded_additional_data[index2]['additional_data']}, "
    f"{loaded_additional_data[index3]['additional_data']}"
)

model_0 = loaded_models[index1]
model_1 = loaded_models[index2]
model_2 = loaded_models[index3]

print("=== Selected Models ===")
dataset_type = loaded_dataset['dataset_type']
model_labels = [
    f"Model Trained with {loaded_additional_data[index1]['additional_data']} {dataset_type}",
    f"Model Trained with {loaded_additional_data[index2]['additional_data']} {dataset_type}",
    f"Model Trained with {loaded_additional_data[index3]['additional_data']} {dataset_type}"
]

# Prepare dataset with additional_data = 0 (base dataset only)
x_base_train = loaded_dataset['x_base_train']
y_base_train = loaded_dataset['y_base_train']
x_additional = loaded_dataset['x_additional']
y_additional = loaded_dataset['y_additional']
# Out:
# Loading models trained with: 540, 5940, 59940
# === Selected Models ===

# %% [markdown]
# ## Loss Landscape Parameters
#
# Loss landscapes have been computed, here's parameters to help plot.

# %%
# Create storage directory
varying_dataset_dir = Path("varying_dataset")
varying_dataset_dir.mkdir(exist_ok=True)

# Define the additional data amounts to test
# This can be varied depending on the use case!!
anchor_points = [600-60, 6000-60, 60000-60]   # specify 2, 3, or more points
steps_per_segment = 200               # how many intervals between each pair

additional_data_amounts = []

for i in range(len(anchor_points) - 1):
    start, end = anchor_points[i], anchor_points[i+1]
    # linspace includes both start and end, so skip first element except first segment
    segment = np.linspace(start, end, steps_per_segment + 1, dtype=int)
    if i > 0:
        segment = segment[1:]  # avoid repeating the start of each segment
    additional_data_amounts.extend(segment.tolist())
# Create grid
N = 80
span_low, span_high = -0.5, 1.5
x = np.linspace(span_low, span_high, N)
y = np.linspace(span_low, span_high, N)
C1_grid, C2_grid = np.meshgrid(x, y)
grid_coefficients = (C1_grid, C2_grid)

print(f"Grid size: {N}x{N}, Range: [{span_low}, {span_high}]")
# Out:
# Grid size: 80x80, Range: [-0.5, 1.5]

# %% [markdown]
# ## Visualization
#
# Load from folder and then visualize.

# %%
# Load specific indexes
loss_grids_list, C1_grid, C2_grid = load_computed_loss_landscapes(
    output_dir=varying_dataset_dir,
    indexes_to_load=range(len(additional_data_amounts))
)
# Out:
# ✓ Loaded index 0: landscape_index_0_amount_540.npz
# ✓ Loaded index 1: landscape_index_1_amount_567.npz
# ✓ Loaded index 2: landscape_index_2_amount_594.npz
# ✓ Loaded index 3: landscape_index_3_amount_621.npz
# ✓ Loaded index 4: landscape_index_4_amount_648.npz
# ✓ Loaded index 5: landscape_index_5_amount_675.npz
# ✓ Loaded index 6: landscape_index_6_amount_702.npz
# ✓ Loaded index 7: landscape_index_7_amount_729.npz
# ✓ Loaded index 8: landscape_index_8_amount_756.npz
# ✓ Loaded index 9: landscape_index_9_amount_783.npz
# ✓ Loaded index 10: landscape_index_10_amount_810.npz
# ✓ Loaded index 11: landscape_index_11_amount_837.npz
# ✓ Loaded index 12: landscape_index_12_amount_864.npz
# ✓ Loaded index 13: landscape_index_13_amount_891.npz
# ✓ Loaded index 14: landscape_index_14_amount_918.npz
# ✓ Loaded index 15: landscape_index_15_amount_945.npz
# ✓ Loaded index 16: landscape_index_16_amount_972.npz
# ✓ Loaded index 17: landscape_index_17_amount_999.npz
# ✓ Loaded index 18: landscape_index_18_amount_1026.npz
# ✓ Loaded index 19: landscape_index_19_amount_1053.npz
# ✓ Loaded index 20: landscape_index_20_amount_1080.npz
# ✓ Loaded index 21: landscape_index_21_amount_1107.npz
# ✓ Loaded index 22: landscape_index_22_amount_1134.npz
# ✓ Loaded index 23: landscape_index_23_amount_1161.npz
# ✓ Loaded index 24: landscape_index_24_amount_1188.npz
# ✓ Loaded index 25: landscape_index_25_amount_1215.npz
# ✓ Loaded index 26: landscape_index_26_amount_1242.npz
# ✓ Loaded index 27: landscape_index_27_amount_1269.npz
# ✓ Loaded index 28: landscape_index_28_amount_1296.npz
# ✓ Loaded index 29: landscape_index_29_amount_1323.npz
# ✓ Loaded index 30: landscape_index_30_amount_1350.npz
# ✓ Loaded index 31: landscape_index_31_amount_1377.npz
# ✓ Loaded index 32: landscape_index_32_amount_1404.npz
# ✓ Loaded index 33: landscape_index_33_amount_1431.npz
# ✓ Loaded index 34: landscape_index_34_amount_1458.npz
# ✓ Loaded index 35: landscape_index_35_amount_1485.npz
# ✓ Loaded index 36: landscape_index_36_amount_1512.npz
# ✓ Loaded index 37: landscape_index_37_amount_1539.npz
# ✓ Loaded index 38: landscape_index_38_amount_1566.npz
# ✓ Loaded index 39: landscape_index_39_amount_1593.npz
# ✓ Loaded index 40: landscape_index_40_amount_1620.npz
# ✓ Loaded index 41: landscape_index_41_amount_1647.npz
# ✓ Loaded index 42: landscape_index_42_amount_1674.npz
# ✓ Loaded index 43: landscape_index_43_amount_1701.npz
# ✓ Loaded index 44: landscape_index_44_amount_1728.npz
# ✓ Loaded index 45: landscape_index_45_amount_1755.npz
# ✓ Loaded index 46: landscape_index_46_amount_1782.npz
# ✓ Loaded index 47: landscape_index_47_amount_1809.npz
# ✓ Loaded index 48: landscape_index_48_amount_1836.npz
# ✓ Loaded index 49: landscape_index_49_amount_1863.npz
# ✓ Loaded index 50: landscape_index_50_amount_1890.npz
# ✓ Loaded index 51: landscape_index_51_amount_1917.npz
# ✓ Loaded index 52: landscape_index_52_amount_1944.npz
# ✓ Loaded index 53: landscape_index_53_amount_1971.npz
# ✓ Loaded index 54: landscape_index_54_amount_1998.npz
# ✓ Loaded index 55: landscape_index_55_amount_2025.npz
# ✓ Loaded index 56: landscape_index_56_amount_2052.npz
# ✓ Loaded index 57: landscape_index_57_amount_2079.npz
# ✓ Loaded index 58: landscape_index_58_amount_2106.npz
# ✓ Loaded index 59: landscape_index_59_amount_2133.npz
# ✓ Loaded index 60: landscape_index_60_amount_2160.npz
# ✓ Loaded index 61: landscape_index_61_amount_2187.npz
# ✓ Loaded index 62: landscape_index_62_amount_2214.npz
# ✓ Loaded index 63: landscape_index_63_amount_2241.npz
# ✓ Loaded index 64: landscape_index_64_amount_2268.npz
# ✓ Loaded index 65: landscape_index_65_amount_2295.npz
# ✓ Loaded index 66: landscape_index_66_amount_2322.npz
# ✓ Loaded index 67: landscape_index_67_amount_2349.npz
# ✓ Loaded index 68: landscape_index_68_amount_2376.npz
# ✓ Loaded index 69: landscape_index_69_amount_2403.npz
# ✓ Loaded index 70: landscape_index_70_amount_2430.npz
# ✓ Loaded index 71: landscape_index_71_amount_2457.npz
# ✓ Loaded index 72: landscape_index_72_amount_2484.npz
# ✓ Loaded index 73: landscape_index_73_amount_2511.npz
# ✓ Loaded index 74: landscape_index_74_amount_2538.npz
# ✓ Loaded index 75: landscape_index_75_amount_2565.npz
# ✓ Loaded index 76: landscape_index_76_amount_2592.npz
# ✓ Loaded index 77: landscape_index_77_amount_2619.npz
# ✓ Loaded index 78: landscape_index_78_amount_2646.npz
# ✓ Loaded index 79: landscape_index_79_amount_2673.npz
# ✓ Loaded index 80: landscape_index_80_amount_2700.npz
# ✓ Loaded index 81: landscape_index_81_amount_2727.npz
# ✓ Loaded index 82: landscape_index_82_amount_2754.npz
# ✓ Loaded index 83: landscape_index_83_amount_2781.npz
# ✓ Loaded index 84: landscape_index_84_amount_2808.npz
# ✓ Loaded index 85: landscape_index_85_amount_2835.npz
# ✓ Loaded index 86: landscape_index_86_amount_2862.npz
# ✓ Loaded index 87: landscape_index_87_amount_2889.npz
# ✓ Loaded index 88: landscape_index_88_amount_2916.npz
# ✓ Loaded index 89: landscape_index_89_amount_2943.npz
# ✓ Loaded index 90: landscape_index_90_amount_2970.npz
# ✓ Loaded index 91: landscape_index_91_amount_2997.npz
# ✓ Loaded index 92: landscape_index_92_amount_3024.npz
# ✓ Loaded index 93: landscape_index_93_amount_3051.npz
# ✓ Loaded index 94: landscape_index_94_amount_3078.npz
# ✓ Loaded index 95: landscape_index_95_amount_3105.npz
# ✓ Loaded index 96: landscape_index_96_amount_3132.npz
# ✓ Loaded index 97: landscape_index_97_amount_3159.npz
# ✓ Loaded index 98: landscape_index_98_amount_3186.npz
# ✓ Loaded index 99: landscape_index_99_amount_3213.npz
# ✓ Loaded index 100: landscape_index_100_amount_3240.npz
# ✓ Loaded index 101: landscape_index_101_amount_3267.npz
# ✓ Loaded index 102: landscape_index_102_amount_3294.npz
# ✓ Loaded index 103: landscape_index_103_amount_3321.npz
# ✓ Loaded index 104: landscape_index_104_amount_3348.npz
# ✓ Loaded index 105: landscape_index_105_amount_3375.npz
# ✓ Loaded index 106: landscape_index_106_amount_3402.npz
# ✓ Loaded index 107: landscape_index_107_amount_3429.npz
# ✓ Loaded index 108: landscape_index_108_amount_3456.npz
# ✓ Loaded index 109: landscape_index_109_amount_3483.npz
# ✓ Loaded index 110: landscape_index_110_amount_3510.npz
# ✓ Loaded index 111: landscape_index_111_amount_3537.npz
# ✓ Loaded index 112: landscape_index_112_amount_3564.npz
# ✓ Loaded index 113: landscape_index_113_amount_3591.npz
# ✓ Loaded index 114: landscape_index_114_amount_3618.npz
# ✓ Loaded index 115: landscape_index_115_amount_3645.npz
# ✓ Loaded index 116: landscape_index_116_amount_3672.npz
# ✓ Loaded index 117: landscape_index_117_amount_3699.npz
# ✓ Loaded index 118: landscape_index_118_amount_3726.npz
# ✓ Loaded index 119: landscape_index_119_amount_3753.npz
# ✓ Loaded index 120: landscape_index_120_amount_3780.npz
# ✓ Loaded index 121: landscape_index_121_amount_3807.npz
# ✓ Loaded index 122: landscape_index_122_amount_3834.npz
# ✓ Loaded index 123: landscape_index_123_amount_3861.npz
# ✓ Loaded index 124: landscape_index_124_amount_3888.npz
# ✓ Loaded index 125: landscape_index_125_amount_3915.npz
# ✓ Loaded index 126: landscape_index_126_amount_3942.npz
# ✓ Loaded index 127: landscape_index_127_amount_3969.npz
# ✓ Loaded index 128: landscape_index_128_amount_3996.npz
# ✓ Loaded index 129: landscape_index_129_amount_4023.npz
# ✓ Loaded index 130: landscape_index_130_amount_4050.npz
# ✓ Loaded index 131: landscape_index_131_amount_4077.npz
# ✓ Loaded index 132: landscape_index_132_amount_4104.npz
# ✓ Loaded index 133: landscape_index_133_amount_4131.npz
# ✓ Loaded index 134: landscape_index_134_amount_4158.npz
# ✓ Loaded index 135: landscape_index_135_amount_4185.npz
# ✓ Loaded index 136: landscape_index_136_amount_4212.npz
# ✓ Loaded index 137: landscape_index_137_amount_4239.npz
# ✓ Loaded index 138: landscape_index_138_amount_4266.npz
# ✓ Loaded index 139: landscape_index_139_amount_4293.npz
# ✓ Loaded index 140: landscape_index_140_amount_4320.npz
# ✓ Loaded index 141: landscape_index_141_amount_4347.npz
# ✓ Loaded index 142: landscape_index_142_amount_4374.npz
# ✓ Loaded index 143: landscape_index_143_amount_4401.npz
# ✓ Loaded index 144: landscape_index_144_amount_4428.npz
# ✓ Loaded index 145: landscape_index_145_amount_4455.npz
# ✓ Loaded index 146: landscape_index_146_amount_4482.npz
# ✓ Loaded index 147: landscape_index_147_amount_4509.npz
# ✓ Loaded index 148: landscape_index_148_amount_4536.npz
# ✓ Loaded index 149: landscape_index_149_amount_4563.npz
# ✓ Loaded index 150: landscape_index_150_amount_4590.npz
# ✓ Loaded index 151: landscape_index_151_amount_4617.npz
# ✓ Loaded index 152: landscape_index_152_amount_4644.npz
# ✓ Loaded index 153: landscape_index_153_amount_4671.npz
# ✓ Loaded index 154: landscape_index_154_amount_4698.npz
# ✓ Loaded index 155: landscape_index_155_amount_4725.npz
# ✓ Loaded index 156: landscape_index_156_amount_4752.npz
# ✓ Loaded index 157: landscape_index_157_amount_4779.npz
# ✓ Loaded index 158: landscape_index_158_amount_4806.npz
# ✓ Loaded index 159: landscape_index_159_amount_4833.npz
# ✓ Loaded index 160: landscape_index_160_amount_4860.npz
# ✓ Loaded index 161: landscape_index_161_amount_4887.npz
# ✓ Loaded index 162: landscape_index_162_amount_4914.npz
# ✓ Loaded index 163: landscape_index_163_amount_4941.npz
# ✓ Loaded index 164: landscape_index_164_amount_4968.npz
# ✓ Loaded index 165: landscape_index_165_amount_4995.npz
# ✓ Loaded index 166: landscape_index_166_amount_5022.npz
# ✓ Loaded index 167: landscape_index_167_amount_5049.npz
# ✓ Loaded index 168: landscape_index_168_amount_5076.npz
# ✓ Loaded index 169: landscape_index_169_amount_5103.npz
# ✓ Loaded index 170: landscape_index_170_amount_5130.npz
# ✓ Loaded index 171: landscape_index_171_amount_5157.npz
# ✓ Loaded index 172: landscape_index_172_amount_5184.npz
# ✓ Loaded index 173: landscape_index_173_amount_5211.npz
# ✓ Loaded index 174: landscape_index_174_amount_5238.npz
# ✓ Loaded index 175: landscape_index_175_amount_5265.npz
# ✓ Loaded index 176: landscape_index_176_amount_5292.npz
# ✓ Loaded index 177: landscape_index_177_amount_5319.npz
# ✓ Loaded index 178: landscape_index_178_amount_5346.npz
# ✓ Loaded index 179: landscape_index_179_amount_5373.npz
# ✓ Loaded index 180: landscape_index_180_amount_5400.npz
# ✓ Loaded index 181: landscape_index_181_amount_5427.npz
# ✓ Loaded index 182: landscape_index_182_amount_5454.npz
# ✓ Loaded index 183: landscape_index_183_amount_5481.npz
# ✓ Loaded index 184: landscape_index_184_amount_5508.npz
# ✓ Loaded index 185: landscape_index_185_amount_5535.npz
# ✓ Loaded index 186: landscape_index_186_amount_5562.npz
# ✓ Loaded index 187: landscape_index_187_amount_5589.npz
# ✓ Loaded index 188: landscape_index_188_amount_5616.npz
# ✓ Loaded index 189: landscape_index_189_amount_5643.npz
# ✓ Loaded index 190: landscape_index_190_amount_5670.npz
# ✓ Loaded index 191: landscape_index_191_amount_5697.npz
# ✓ Loaded index 192: landscape_index_192_amount_5724.npz
# ✓ Loaded index 193: landscape_index_193_amount_5751.npz
# ✓ Loaded index 194: landscape_index_194_amount_5778.npz
# ✓ Loaded index 195: landscape_index_195_amount_5805.npz
# ✓ Loaded index 196: landscape_index_196_amount_5832.npz
# ✓ Loaded index 197: landscape_index_197_amount_5859.npz
# ✓ Loaded index 198: landscape_index_198_amount_5886.npz
# ✓ Loaded index 199: landscape_index_199_amount_5913.npz
# ✓ Loaded index 200: landscape_index_200_amount_5940.npz
# ✓ Loaded index 201: landscape_index_201_amount_6210.npz
# ✓ Loaded index 202: landscape_index_202_amount_6480.npz
# ✓ Loaded index 203: landscape_index_203_amount_6750.npz
# ✓ Loaded index 204: landscape_index_204_amount_7020.npz
# ✓ Loaded index 205: landscape_index_205_amount_7290.npz
# ✓ Loaded index 206: landscape_index_206_amount_7560.npz
# ✓ Loaded index 207: landscape_index_207_amount_7830.npz
# ✓ Loaded index 208: landscape_index_208_amount_8100.npz
# ✓ Loaded index 209: landscape_index_209_amount_8370.npz
# ✓ Loaded index 210: landscape_index_210_amount_8640.npz
# ✓ Loaded index 211: landscape_index_211_amount_8910.npz
# ✓ Loaded index 212: landscape_index_212_amount_9180.npz
# ✓ Loaded index 213: landscape_index_213_amount_9450.npz
# ✓ Loaded index 214: landscape_index_214_amount_9720.npz
# ✓ Loaded index 215: landscape_index_215_amount_9990.npz
# ✓ Loaded index 216: landscape_index_216_amount_10260.npz
# ✓ Loaded index 217: landscape_index_217_amount_10530.npz
# ✓ Loaded index 218: landscape_index_218_amount_10800.npz
# ✓ Loaded index 219: landscape_index_219_amount_11070.npz
# ✓ Loaded index 220: landscape_index_220_amount_11340.npz
# ✓ Loaded index 221: landscape_index_221_amount_11610.npz
# ✓ Loaded index 222: landscape_index_222_amount_11880.npz
# ✓ Loaded index 223: landscape_index_223_amount_12150.npz
# ✓ Loaded index 224: landscape_index_224_amount_12420.npz
# ✓ Loaded index 225: landscape_index_225_amount_12690.npz
# ✓ Loaded index 226: landscape_index_226_amount_12960.npz
# ✓ Loaded index 227: landscape_index_227_amount_13230.npz
# ✓ Loaded index 228: landscape_index_228_amount_13500.npz
# ✓ Loaded index 229: landscape_index_229_amount_13770.npz
# ✓ Loaded index 230: landscape_index_230_amount_14040.npz
# ✓ Loaded index 231: landscape_index_231_amount_14310.npz
# ✓ Loaded index 232: landscape_index_232_amount_14580.npz
# ✓ Loaded index 233: landscape_index_233_amount_14850.npz
# ✓ Loaded index 234: landscape_index_234_amount_15120.npz
# ✓ Loaded index 235: landscape_index_235_amount_15390.npz
# ✓ Loaded index 236: landscape_index_236_amount_15660.npz
# ✓ Loaded index 237: landscape_index_237_amount_15930.npz
# ✓ Loaded index 238: landscape_index_238_amount_16200.npz
# ✓ Loaded index 239: landscape_index_239_amount_16470.npz
# ✓ Loaded index 240: landscape_index_240_amount_16740.npz
# ✓ Loaded index 241: landscape_index_241_amount_17010.npz
# ✓ Loaded index 242: landscape_index_242_amount_17280.npz
# ✓ Loaded index 243: landscape_index_243_amount_17550.npz
# ✓ Loaded index 244: landscape_index_244_amount_17820.npz
# ✓ Loaded index 245: landscape_index_245_amount_18090.npz
# ✓ Loaded index 246: landscape_index_246_amount_18360.npz
# ✓ Loaded index 247: landscape_index_247_amount_18630.npz
# ✓ Loaded index 248: landscape_index_248_amount_18900.npz
# ✓ Loaded index 249: landscape_index_249_amount_19170.npz
# ✓ Loaded index 250: landscape_index_250_amount_19440.npz
# ✓ Loaded index 251: landscape_index_251_amount_19710.npz
# ✓ Loaded index 252: landscape_index_252_amount_19980.npz
# ✓ Loaded index 253: landscape_index_253_amount_20250.npz
# ✓ Loaded index 254: landscape_index_254_amount_20520.npz
# ✓ Loaded index 255: landscape_index_255_amount_20790.npz
# ✓ Loaded index 256: landscape_index_256_amount_21060.npz
# ✓ Loaded index 257: landscape_index_257_amount_21330.npz
# ✓ Loaded index 258: landscape_index_258_amount_21600.npz
# ✓ Loaded index 259: landscape_index_259_amount_21870.npz
# ✓ Loaded index 260: landscape_index_260_amount_22140.npz
# ✓ Loaded index 261: landscape_index_261_amount_22410.npz
# ✓ Loaded index 262: landscape_index_262_amount_22680.npz
# ✓ Loaded index 263: landscape_index_263_amount_22950.npz
# ✓ Loaded index 264: landscape_index_264_amount_23220.npz
# ✓ Loaded index 265: landscape_index_265_amount_23490.npz
# ✓ Loaded index 266: landscape_index_266_amount_23760.npz
# ✓ Loaded index 267: landscape_index_267_amount_24030.npz
# ✓ Loaded index 268: landscape_index_268_amount_24300.npz
# ✓ Loaded index 269: landscape_index_269_amount_24570.npz
# ✓ Loaded index 270: landscape_index_270_amount_24840.npz
# ✓ Loaded index 271: landscape_index_271_amount_25110.npz
# ✓ Loaded index 272: landscape_index_272_amount_25380.npz
# ✓ Loaded index 273: landscape_index_273_amount_25650.npz
# ✓ Loaded index 274: landscape_index_274_amount_25920.npz
# ✓ Loaded index 275: landscape_index_275_amount_26190.npz
# ✓ Loaded index 276: landscape_index_276_amount_26460.npz
# ✓ Loaded index 277: landscape_index_277_amount_26730.npz
# ✓ Loaded index 278: landscape_index_278_amount_27000.npz
# ✓ Loaded index 279: landscape_index_279_amount_27270.npz
# ✓ Loaded index 280: landscape_index_280_amount_27540.npz
# ✓ Loaded index 281: landscape_index_281_amount_27810.npz
# ✓ Loaded index 282: landscape_index_282_amount_28080.npz
# ✓ Loaded index 283: landscape_index_283_amount_28350.npz
# ✓ Loaded index 284: landscape_index_284_amount_28620.npz
# ✓ Loaded index 285: landscape_index_285_amount_28890.npz
# ✓ Loaded index 286: landscape_index_286_amount_29160.npz
# ✓ Loaded index 287: landscape_index_287_amount_29430.npz
# ✓ Loaded index 288: landscape_index_288_amount_29700.npz
# ✓ Loaded index 289: landscape_index_289_amount_29970.npz
# ✓ Loaded index 290: landscape_index_290_amount_30240.npz
# ✓ Loaded index 291: landscape_index_291_amount_30510.npz
# ✓ Loaded index 292: landscape_index_292_amount_30780.npz
# ✓ Loaded index 293: landscape_index_293_amount_31050.npz
# ✓ Loaded index 294: landscape_index_294_amount_31320.npz
# ✓ Loaded index 295: landscape_index_295_amount_31590.npz
# ✓ Loaded index 296: landscape_index_296_amount_31860.npz
# ✓ Loaded index 297: landscape_index_297_amount_32130.npz
# ✓ Loaded index 298: landscape_index_298_amount_32400.npz
# ✓ Loaded index 299: landscape_index_299_amount_32670.npz
# ✓ Loaded index 300: landscape_index_300_amount_32940.npz
# ✓ Loaded index 301: landscape_index_301_amount_33210.npz
# ✓ Loaded index 302: landscape_index_302_amount_33480.npz
# ✓ Loaded index 303: landscape_index_303_amount_33750.npz
# ✓ Loaded index 304: landscape_index_304_amount_34020.npz
# ✓ Loaded index 305: landscape_index_305_amount_34290.npz
# ✓ Loaded index 306: landscape_index_306_amount_34560.npz
# ✓ Loaded index 307: landscape_index_307_amount_34830.npz
# ✓ Loaded index 308: landscape_index_308_amount_35100.npz
# ✓ Loaded index 309: landscape_index_309_amount_35370.npz
# ✓ Loaded index 310: landscape_index_310_amount_35640.npz
# ✓ Loaded index 311: landscape_index_311_amount_35910.npz
# ✓ Loaded index 312: landscape_index_312_amount_36180.npz
# ✓ Loaded index 313: landscape_index_313_amount_36450.npz
# ✓ Loaded index 314: landscape_index_314_amount_36720.npz
# ✓ Loaded index 315: landscape_index_315_amount_36990.npz
# ✓ Loaded index 316: landscape_index_316_amount_37260.npz
# ✓ Loaded index 317: landscape_index_317_amount_37530.npz
# ✓ Loaded index 318: landscape_index_318_amount_37800.npz
# ✓ Loaded index 319: landscape_index_319_amount_38070.npz
# ✓ Loaded index 320: landscape_index_320_amount_38340.npz
# ✓ Loaded index 321: landscape_index_321_amount_38610.npz
# ✓ Loaded index 322: landscape_index_322_amount_38880.npz
# ✓ Loaded index 323: landscape_index_323_amount_39150.npz
# ✓ Loaded index 324: landscape_index_324_amount_39420.npz
# ✓ Loaded index 325: landscape_index_325_amount_39690.npz
# ✓ Loaded index 326: landscape_index_326_amount_39960.npz
# ✓ Loaded index 327: landscape_index_327_amount_40230.npz
# ✓ Loaded index 328: landscape_index_328_amount_40500.npz
# ✓ Loaded index 329: landscape_index_329_amount_40770.npz
# ✓ Loaded index 330: landscape_index_330_amount_41040.npz
# ✓ Loaded index 331: landscape_index_331_amount_41310.npz
# ✓ Loaded index 332: landscape_index_332_amount_41580.npz
# ✓ Loaded index 333: landscape_index_333_amount_41850.npz
# ✓ Loaded index 334: landscape_index_334_amount_42120.npz
# ✓ Loaded index 335: landscape_index_335_amount_42390.npz
# ✓ Loaded index 336: landscape_index_336_amount_42660.npz
# ✓ Loaded index 337: landscape_index_337_amount_42930.npz
# ✓ Loaded index 338: landscape_index_338_amount_43200.npz
# ✓ Loaded index 339: landscape_index_339_amount_43470.npz
# ✓ Loaded index 340: landscape_index_340_amount_43740.npz
# ✓ Loaded index 341: landscape_index_341_amount_44010.npz
# ✓ Loaded index 342: landscape_index_342_amount_44280.npz
# ✓ Loaded index 343: landscape_index_343_amount_44550.npz
# ✓ Loaded index 344: landscape_index_344_amount_44820.npz
# ✓ Loaded index 345: landscape_index_345_amount_45090.npz
# ✓ Loaded index 346: landscape_index_346_amount_45360.npz
# ✓ Loaded index 347: landscape_index_347_amount_45630.npz
# ✓ Loaded index 348: landscape_index_348_amount_45900.npz
# ✓ Loaded index 349: landscape_index_349_amount_46170.npz
# ✓ Loaded index 350: landscape_index_350_amount_46440.npz
# ✓ Loaded index 351: landscape_index_351_amount_46710.npz
# ✓ Loaded index 352: landscape_index_352_amount_46980.npz
# ✓ Loaded index 353: landscape_index_353_amount_47250.npz
# ✓ Loaded index 354: landscape_index_354_amount_47520.npz
# ✓ Loaded index 355: landscape_index_355_amount_47790.npz
# ✓ Loaded index 356: landscape_index_356_amount_48060.npz
# ✓ Loaded index 357: landscape_index_357_amount_48330.npz
# ✓ Loaded index 358: landscape_index_358_amount_48600.npz
# ✓ Loaded index 359: landscape_index_359_amount_48870.npz
# ✓ Loaded index 360: landscape_index_360_amount_49140.npz
# ✓ Loaded index 361: landscape_index_361_amount_49410.npz
# ✓ Loaded index 362: landscape_index_362_amount_49680.npz
# ✓ Loaded index 363: landscape_index_363_amount_49950.npz
# ✓ Loaded index 364: landscape_index_364_amount_50220.npz
# ✓ Loaded index 365: landscape_index_365_amount_50490.npz
# ✓ Loaded index 366: landscape_index_366_amount_50760.npz
# ✓ Loaded index 367: landscape_index_367_amount_51030.npz
# ✓ Loaded index 368: landscape_index_368_amount_51300.npz
# ✓ Loaded index 369: landscape_index_369_amount_51570.npz
# ✓ Loaded index 370: landscape_index_370_amount_51840.npz
# ✓ Loaded index 371: landscape_index_371_amount_52110.npz
# ✓ Loaded index 372: landscape_index_372_amount_52380.npz
# ✓ Loaded index 373: landscape_index_373_amount_52650.npz
# ✓ Loaded index 374: landscape_index_374_amount_52920.npz
# ✓ Loaded index 375: landscape_index_375_amount_53190.npz
# ✓ Loaded index 376: landscape_index_376_amount_53460.npz
# ✓ Loaded index 377: landscape_index_377_amount_53730.npz
# ✓ Loaded index 378: landscape_index_378_amount_54000.npz
# ✓ Loaded index 379: landscape_index_379_amount_54270.npz
# ✓ Loaded index 380: landscape_index_380_amount_54540.npz
# ✓ Loaded index 381: landscape_index_381_amount_54810.npz
# ✓ Loaded index 382: landscape_index_382_amount_55080.npz
# ✓ Loaded index 383: landscape_index_383_amount_55350.npz
# ✓ Loaded index 384: landscape_index_384_amount_55620.npz
# ✓ Loaded index 385: landscape_index_385_amount_55890.npz
# ✓ Loaded index 386: landscape_index_386_amount_56160.npz
# ✓ Loaded index 387: landscape_index_387_amount_56430.npz
# ✓ Loaded index 388: landscape_index_388_amount_56700.npz
# ✓ Loaded index 389: landscape_index_389_amount_56970.npz
# ✓ Loaded index 390: landscape_index_390_amount_57240.npz
# ✓ Loaded index 391: landscape_index_391_amount_57510.npz
# ✓ Loaded index 392: landscape_index_392_amount_57780.npz
# ✓ Loaded index 393: landscape_index_393_amount_58050.npz
# ✓ Loaded index 394: landscape_index_394_amount_58320.npz
# ✓ Loaded index 395: landscape_index_395_amount_58590.npz
# ✓ Loaded index 396: landscape_index_396_amount_58860.npz
# ✓ Loaded index 397: landscape_index_397_amount_59130.npz
# ✓ Loaded index 398: landscape_index_398_amount_59400.npz
# ✓ Loaded index 399: landscape_index_399_amount_59670.npz
# ✓ Loaded index 400: landscape_index_400_amount_59940.npz
# Successfully loaded 401 loss landscapes

# %%
# Create directories for different plot types
plot_dirs = {
    'dynamic_vmin': 'plots_dynamic_vmin',
    'fixed_vmin_large': 'plots_fixed_vmin_large', 
    'fixed_vmin_small': 'plots_fixed_vmin_small', 
}

for dir_name in plot_dirs.values():
    Path(dir_name).mkdir(parents=True, exist_ok=True)

# Find global min and max across ALL landscapes for consistent fixed scaling
global_vmin_smallest = float('inf')
global_vmin_largest = float('-inf')
all_vmax = float('-inf')

for idx in range(len(loss_grids_list)):
    if 0 <= idx < len(loss_grids_list):
        loss_grid = loss_grids_list[idx]
        current_min = loss_grid[loss_grid > 0].min()
        current_max = loss_grid.max()
        global_vmin_smallest = min(global_vmin_smallest, current_min)
        global_vmin_largest = max(global_vmin_largest, current_min)
        all_vmax = max(all_vmax, current_max)

print(f"Global min across selected landscapes (smallest value, features are indistinguishable with low variability): {global_vmin_smallest:.6f}")
print(f"Global min across selected landscapes (largest value that captures the variability in the most constant version): {global_vmin_largest:.6f}")
print(f"Global max across ALL landscapes: {all_vmax:.6f}")

# Generate all three types of plots for each index

start_time = time.time()

for idx in range(len(loss_grids_list)):
    if idx < 0 or idx >= len(loss_grids_list):
        continue
    
    additional_data = additional_data_amounts[idx]
    loss_grid = loss_grids_list[idx]
    
    print(f"\n=== Generating plots for index {idx}, additional data: {additional_data} ===")
    print(f"Local min: {loss_grid[loss_grid > 0].min():.6f}, Local max: {loss_grid.max():.6f}")
    
    # 1. 2D plot with dynamic vmin (local scaling)
    plot_2d_loss_landscape_3model(
        C1_grid=C1_grid,
        C2_grid=C2_grid,
        loss_grid=loss_grid,
        span_low=span_low,
        span_high=span_high,
        additional_data=additional_data,
        model_labels=model_labels,
        vmin=None,  # Dynamic - uses local min
        vmax=20, 
        output_path=f"{plot_dirs['dynamic_vmin']}/landscape_2d_index_{idx:03d}_amount_{additional_data}.png",
        show=False
    )
    
    # 2. 2D plot with fixed vmin (global scaling)
    plot_2d_loss_landscape_3model(
        C1_grid=C1_grid,
        C2_grid=C2_grid,
        loss_grid=loss_grid,
        span_low=span_low,
        span_high=span_high,
        additional_data=additional_data,
        model_labels=model_labels,
        vmin=global_vmin_largest,  # Fixed global min
        vmax=20, 
        output_path=f"{plot_dirs['fixed_vmin_large']}/landscape_2d_index_{idx:03d}_amount_{additional_data}.png",
        show=False
    )

    # 3. 2D plot with fixed vmin (global scaling)
    plot_2d_loss_landscape_3model(
        C1_grid=C1_grid,
        C2_grid=C2_grid,
        loss_grid=loss_grid,
        span_low=span_low,
        span_high=span_high,
        additional_data=additional_data,
        model_labels=model_labels,
        vmin=global_vmin_smallest,  # Fixed global min
        vmax=20, 
        output_path=f"{plot_dirs['fixed_vmin_small']}/landscape_2d_index_{idx:03d}_amount_{additional_data}.png",
        show=False
    )

end_time = time.time()
elapsed = end_time - start_time

print(f"\n=== Total time for plotting all loss landscapes: {elapsed:.2f} seconds ({elapsed/60:.2f} minutes) ===")
print("\n✓ All plots generated successfully!")
# Out:
# Global min across selected landscapes (smallest value, features are indistinguishable with low variability): 0.000113
# Global min across selected landscapes (largest value that captures the variability in the most constant version): 0.002054
# Global max across ALL landscapes: 15.162881
#
# === Generating plots for index 0, additional data: 540 ===
# Local min: 0.000113, Local max: 15.162881
#
# === Generating plots for index 1, additional data: 567 ===
# Local min: 0.000415, Local max: 14.884861
#
# === Generating plots for index 2, additional data: 594 ===
# Local min: 0.000407, Local max: 14.915216
#
# === Generating plots for index 3, additional data: 621 ===
# Local min: 0.000402, Local max: 14.833491
#
# === Generating plots for index 4, additional data: 648 ===
# Local min: 0.000401, Local max: 14.650093
#
# === Generating plots for index 5, additional data: 675 ===
# Local min: 0.000410, Local max: 14.708021
#
# === Generating plots for index 6, additional data: 702 ===
# Local min: 0.000405, Local max: 14.424446
#
# === Generating plots for index 7, additional data: 729 ===
# Local min: 0.000410, Local max: 14.224459
#
# === Generating plots for index 8, additional data: 756 ===
# Local min: 0.000409, Local max: 14.137380
#
# === Generating plots for index 9, additional data: 783 ===
# Local min: 0.000398, Local max: 13.963421
#
# === Generating plots for index 10, additional data: 810 ===
# Local min: 0.000396, Local max: 13.965937
#
# === Generating plots for index 11, additional data: 837 ===
# Local min: 0.000399, Local max: 14.008257
#
# === Generating plots for index 12, additional data: 864 ===
# Local min: 0.000394, Local max: 13.890175
#
# === Generating plots for index 13, additional data: 891 ===
# Local min: 0.000388, Local max: 14.167477
#
# === Generating plots for index 14, additional data: 918 ===
# Local min: 0.000385, Local max: 14.182150
#
# === Generating plots for index 15, additional data: 945 ===
# Local min: 0.000380, Local max: 14.317689
#
# === Generating plots for index 16, additional data: 972 ===
# Local min: 0.000376, Local max: 14.255750
#
# === Generating plots for index 17, additional data: 999 ===
# Local min: 0.000377, Local max: 14.330840
#
# === Generating plots for index 18, additional data: 1026 ===
# Local min: 0.000378, Local max: 14.343338
#
# === Generating plots for index 19, additional data: 1053 ===
# Local min: 0.000377, Local max: 14.163670
#
# === Generating plots for index 20, additional data: 1080 ===
# Local min: 0.000376, Local max: 14.116695
#
# === Generating plots for index 21, additional data: 1107 ===
# Local min: 0.000372, Local max: 14.155882
#
# === Generating plots for index 22, additional data: 1134 ===
# Local min: 0.000369, Local max: 14.095178
#
# === Generating plots for index 23, additional data: 1161 ===
# Local min: 0.000364, Local max: 14.134801
#
# === Generating plots for index 24, additional data: 1188 ===
# Local min: 0.000360, Local max: 14.165562
#
# === Generating plots for index 25, additional data: 1215 ===
# Local min: 0.000355, Local max: 14.217655
#
# === Generating plots for index 26, additional data: 1242 ===
# Local min: 0.000354, Local max: 14.150071
#
# === Generating plots for index 27, additional data: 1269 ===
# Local min: 0.000356, Local max: 14.292407
#
# === Generating plots for index 28, additional data: 1296 ===
# Local min: 0.000355, Local max: 14.347492
#
# === Generating plots for index 29, additional data: 1323 ===
# Local min: 0.000352, Local max: 14.195550
#
# === Generating plots for index 30, additional data: 1350 ===
# Local min: 0.000350, Local max: 14.218195
#
# === Generating plots for index 31, additional data: 1377 ===
# Local min: 0.000353, Local max: 14.242341
#
# === Generating plots for index 32, additional data: 1404 ===
# Local min: 0.000353, Local max: 14.261665
#
# === Generating plots for index 33, additional data: 1431 ===
# Local min: 0.000364, Local max: 14.385474
#
# === Generating plots for index 34, additional data: 1458 ===
# Local min: 0.000362, Local max: 14.334626
#
# === Generating plots for index 35, additional data: 1485 ===
# Local min: 0.000360, Local max: 14.365618
#
# === Generating plots for index 36, additional data: 1512 ===
# Local min: 0.000358, Local max: 14.440067
#
# === Generating plots for index 37, additional data: 1539 ===
# Local min: 0.000352, Local max: 14.492735
#
# === Generating plots for index 38, additional data: 1566 ===
# Local min: 0.000350, Local max: 14.423843
#
# === Generating plots for index 39, additional data: 1593 ===
# Local min: 0.000348, Local max: 14.532734
#
# === Generating plots for index 40, additional data: 1620 ===
# Local min: 0.000347, Local max: 14.450086
#
# === Generating plots for index 41, additional data: 1647 ===
# Local min: 0.000343, Local max: 14.526186
#
# === Generating plots for index 42, additional data: 1674 ===
# Local min: 0.000355, Local max: 14.467599
#
# === Generating plots for index 43, additional data: 1701 ===
# Local min: 0.000355, Local max: 14.424659
#
# === Generating plots for index 44, additional data: 1728 ===
# Local min: 0.000351, Local max: 14.519630
#
# === Generating plots for index 45, additional data: 1755 ===
# Local min: 0.000348, Local max: 14.521493
#
# === Generating plots for index 46, additional data: 1782 ===
# Local min: 0.000346, Local max: 14.589306
#
# === Generating plots for index 47, additional data: 1809 ===
# Local min: 0.000345, Local max: 14.599563
#
# === Generating plots for index 48, additional data: 1836 ===
# Local min: 0.000345, Local max: 14.526387
#
# === Generating plots for index 49, additional data: 1863 ===
# Local min: 0.000341, Local max: 14.477085
#
# === Generating plots for index 50, additional data: 1890 ===
# Local min: 0.000338, Local max: 14.467270
#
# === Generating plots for index 51, additional data: 1917 ===
# Local min: 0.000337, Local max: 14.532881
#
# === Generating plots for index 52, additional data: 1944 ===
# Local min: 0.000334, Local max: 14.575349
#
# === Generating plots for index 53, additional data: 1971 ===
# Local min: 0.000336, Local max: 14.585994
#
# === Generating plots for index 54, additional data: 1998 ===
# Local min: 0.000333, Local max: 14.642011
#
# === Generating plots for index 55, additional data: 2025 ===
# Local min: 0.000332, Local max: 14.618498
#
# === Generating plots for index 56, additional data: 2052 ===
# Local min: 0.000328, Local max: 14.593744
#
# === Generating plots for index 57, additional data: 2079 ===
# Local min: 0.000326, Local max: 14.639387
#
# === Generating plots for index 58, additional data: 2106 ===
# Local min: 0.000324, Local max: 14.675854
#
# === Generating plots for index 59, additional data: 2133 ===
# Local min: 0.000323, Local max: 14.754972
#
# === Generating plots for index 60, additional data: 2160 ===
# Local min: 0.000327, Local max: 14.736411
#
# === Generating plots for index 61, additional data: 2187 ===
# Local min: 0.000324, Local max: 14.710694
#
# === Generating plots for index 62, additional data: 2214 ===
# Local min: 0.000326, Local max: 14.662315
#
# === Generating plots for index 63, additional data: 2241 ===
# Local min: 0.000325, Local max: 14.612513
#
# === Generating plots for index 64, additional data: 2268 ===
# Local min: 0.000325, Local max: 14.626599
#
# === Generating plots for index 65, additional data: 2295 ===
# Local min: 0.000324, Local max: 14.628520
#
# === Generating plots for index 66, additional data: 2322 ===
# Local min: 0.000324, Local max: 14.543406
#
# === Generating plots for index 67, additional data: 2349 ===
# Local min: 0.000321, Local max: 14.567272
#
# === Generating plots for index 68, additional data: 2376 ===
# Local min: 0.000323, Local max: 14.585220
#
# === Generating plots for index 69, additional data: 2403 ===
# Local min: 0.000324, Local max: 14.639396
#
# === Generating plots for index 70, additional data: 2430 ===
# Local min: 0.000322, Local max: 14.641000
#
# === Generating plots for index 71, additional data: 2457 ===
# Local min: 0.000322, Local max: 14.576193
#
# === Generating plots for index 72, additional data: 2484 ===
# Local min: 0.000323, Local max: 14.597274
#
# === Generating plots for index 73, additional data: 2511 ===
# Local min: 0.000320, Local max: 14.646450
#
# === Generating plots for index 74, additional data: 2538 ===
# Local min: 0.000319, Local max: 14.604099
#
# === Generating plots for index 75, additional data: 2565 ===
# Local min: 0.000317, Local max: 14.667371
#
# === Generating plots for index 76, additional data: 2592 ===
# Local min: 0.000315, Local max: 14.685341
#
# === Generating plots for index 77, additional data: 2619 ===
# Local min: 0.000314, Local max: 14.664893
#
# === Generating plots for index 78, additional data: 2646 ===
# Local min: 0.000318, Local max: 14.631371
#
# === Generating plots for index 79, additional data: 2673 ===
# Local min: 0.000317, Local max: 14.612817
#
# === Generating plots for index 80, additional data: 2700 ===
# Local min: 0.000315, Local max: 14.571628
#
# === Generating plots for index 81, additional data: 2727 ===
# Local min: 0.000316, Local max: 14.557883
#
# === Generating plots for index 82, additional data: 2754 ===
# Local min: 0.000314, Local max: 14.587098
#
# === Generating plots for index 83, additional data: 2781 ===
# Local min: 0.000317, Local max: 14.625299
#
# === Generating plots for index 84, additional data: 2808 ===
# Local min: 0.000316, Local max: 14.684659
#
# === Generating plots for index 85, additional data: 2835 ===
# Local min: 0.000314, Local max: 14.631059
#
# === Generating plots for index 86, additional data: 2862 ===
# Local min: 0.000318, Local max: 14.587042
#
# === Generating plots for index 87, additional data: 2889 ===
# Local min: 0.000319, Local max: 14.549630
#
# === Generating plots for index 88, additional data: 2916 ===
# Local min: 0.000317, Local max: 14.477892
#
# === Generating plots for index 89, additional data: 2943 ===
# Local min: 0.000317, Local max: 14.471068
#
# === Generating plots for index 90, additional data: 2970 ===
# Local min: 0.000315, Local max: 14.432885
#
# === Generating plots for index 91, additional data: 2997 ===
# Local min: 0.000314, Local max: 14.482239
#
# === Generating plots for index 92, additional data: 3024 ===
# Local min: 0.000313, Local max: 14.469583
#
# === Generating plots for index 93, additional data: 3051 ===
# Local min: 0.000313, Local max: 14.513258
#
# === Generating plots for index 94, additional data: 3078 ===
# Local min: 0.000317, Local max: 14.558507
#
# === Generating plots for index 95, additional data: 3105 ===
# Local min: 0.000315, Local max: 14.497576
#
# === Generating plots for index 96, additional data: 3132 ===
# Local min: 0.000315, Local max: 14.486279
#
# === Generating plots for index 97, additional data: 3159 ===
# Local min: 0.000315, Local max: 14.449215
#
# === Generating plots for index 98, additional data: 3186 ===
# Local min: 0.000315, Local max: 14.424786
#
# === Generating plots for index 99, additional data: 3213 ===
# Local min: 0.000315, Local max: 14.391246
#
# === Generating plots for index 100, additional data: 3240 ===
# Local min: 0.000315, Local max: 14.369429
#
# === Generating plots for index 101, additional data: 3267 ===
# Local min: 0.000315, Local max: 14.355457
#
# === Generating plots for index 102, additional data: 3294 ===
# Local min: 0.000314, Local max: 14.380870
#
# === Generating plots for index 103, additional data: 3321 ===
# Local min: 0.000313, Local max: 14.326810
#
# === Generating plots for index 104, additional data: 3348 ===
# Local min: 0.000312, Local max: 14.341006
#
# === Generating plots for index 105, additional data: 3375 ===
# Local min: 0.000310, Local max: 14.324615
#
# === Generating plots for index 106, additional data: 3402 ===
# Local min: 0.000309, Local max: 14.287426
#
# === Generating plots for index 107, additional data: 3429 ===
# Local min: 0.000307, Local max: 14.267383
#
# === Generating plots for index 108, additional data: 3456 ===
# Local min: 0.000307, Local max: 14.270508
#
# === Generating plots for index 109, additional data: 3483 ===
# Local min: 0.000307, Local max: 14.255676
#
# === Generating plots for index 110, additional data: 3510 ===
# Local min: 0.000306, Local max: 14.249020
#
# === Generating plots for index 111, additional data: 3537 ===
# Local min: 0.000306, Local max: 14.231127
#
# === Generating plots for index 112, additional data: 3564 ===
# Local min: 0.000305, Local max: 14.210337
#
# === Generating plots for index 113, additional data: 3591 ===
# Local min: 0.000304, Local max: 14.215388
#
# === Generating plots for index 114, additional data: 3618 ===
# Local min: 0.000304, Local max: 14.184277
#
# === Generating plots for index 115, additional data: 3645 ===
# Local min: 0.000302, Local max: 14.192855
#
# === Generating plots for index 116, additional data: 3672 ===
# Local min: 0.000302, Local max: 14.162216
#
# === Generating plots for index 117, additional data: 3699 ===
# Local min: 0.000300, Local max: 14.194550
#
# === Generating plots for index 118, additional data: 3726 ===
# Local min: 0.000299, Local max: 14.179939
#
# === Generating plots for index 119, additional data: 3753 ===
# Local min: 0.000299, Local max: 14.190229
#
# === Generating plots for index 120, additional data: 3780 ===
# Local min: 0.000298, Local max: 14.182141
#
# === Generating plots for index 121, additional data: 3807 ===
# Local min: 0.000298, Local max: 14.157252
#
# === Generating plots for index 122, additional data: 3834 ===
# Local min: 0.000298, Local max: 14.164740
#
# === Generating plots for index 123, additional data: 3861 ===
# Local min: 0.000297, Local max: 14.212021
#
# === Generating plots for index 124, additional data: 3888 ===
# Local min: 0.000296, Local max: 14.195202
#
# === Generating plots for index 125, additional data: 3915 ===
# Local min: 0.000295, Local max: 14.229061
#
# === Generating plots for index 126, additional data: 3942 ===
# Local min: 0.000297, Local max: 14.265843
#
# === Generating plots for index 127, additional data: 3969 ===
# Local min: 0.000297, Local max: 14.313988
#
# === Generating plots for index 128, additional data: 3996 ===
# Local min: 0.000297, Local max: 14.302481
#
# === Generating plots for index 129, additional data: 4023 ===
# Local min: 0.000296, Local max: 14.316998
#
# === Generating plots for index 130, additional data: 4050 ===
# Local min: 0.000295, Local max: 14.365254
#
# === Generating plots for index 131, additional data: 4077 ===
# Local min: 0.000294, Local max: 14.364409
#
# === Generating plots for index 132, additional data: 4104 ===
# Local min: 0.000295, Local max: 14.358815
#
# === Generating plots for index 133, additional data: 4131 ===
# Local min: 0.000295, Local max: 14.367030
#
# === Generating plots for index 134, additional data: 4158 ===
# Local min: 0.000295, Local max: 14.364455
#
# === Generating plots for index 135, additional data: 4185 ===
# Local min: 0.000294, Local max: 14.356143
#
# === Generating plots for index 136, additional data: 4212 ===
# Local min: 0.000294, Local max: 14.324407
#
# === Generating plots for index 137, additional data: 4239 ===
# Local min: 0.000293, Local max: 14.323296
#
# === Generating plots for index 138, additional data: 4266 ===
# Local min: 0.000294, Local max: 14.328702
#
# === Generating plots for index 139, additional data: 4293 ===
# Local min: 0.000294, Local max: 14.362983
#
# === Generating plots for index 140, additional data: 4320 ===
# Local min: 0.000293, Local max: 14.401468
#
# === Generating plots for index 141, additional data: 4347 ===
# Local min: 0.000293, Local max: 14.368400
#
# === Generating plots for index 142, additional data: 4374 ===
# Local min: 0.000293, Local max: 14.347985
#
# === Generating plots for index 143, additional data: 4401 ===
# Local min: 0.000292, Local max: 14.332181
#
# === Generating plots for index 144, additional data: 4428 ===
# Local min: 0.000292, Local max: 14.330257
#
# === Generating plots for index 145, additional data: 4455 ===
# Local min: 0.000291, Local max: 14.301458
#
# === Generating plots for index 146, additional data: 4482 ===
# Local min: 0.000290, Local max: 14.305335
#
# === Generating plots for index 147, additional data: 4509 ===
# Local min: 0.000290, Local max: 14.294376
#
# === Generating plots for index 148, additional data: 4536 ===
# Local min: 0.000289, Local max: 14.268449
#
# === Generating plots for index 149, additional data: 4563 ===
# Local min: 0.000288, Local max: 14.283310
#
# === Generating plots for index 150, additional data: 4590 ===
# Local min: 0.000287, Local max: 14.272915
#
# === Generating plots for index 151, additional data: 4617 ===
# Local min: 0.000287, Local max: 14.241840
#
# === Generating plots for index 152, additional data: 4644 ===
# Local min: 0.000286, Local max: 14.262305
#
# === Generating plots for index 153, additional data: 4671 ===
# Local min: 0.000286, Local max: 14.283271
#
# === Generating plots for index 154, additional data: 4698 ===
# Local min: 0.000286, Local max: 14.280677
#
# === Generating plots for index 155, additional data: 4725 ===
# Local min: 0.000286, Local max: 14.251364
#
# === Generating plots for index 156, additional data: 4752 ===
# Local min: 0.000288, Local max: 14.275092
#
# === Generating plots for index 157, additional data: 4779 ===
# Local min: 0.000288, Local max: 14.247631
#
# === Generating plots for index 158, additional data: 4806 ===
# Local min: 0.000288, Local max: 14.214724
#
# === Generating plots for index 159, additional data: 4833 ===
# Local min: 0.000287, Local max: 14.186747
#
# === Generating plots for index 160, additional data: 4860 ===
# Local min: 0.000287, Local max: 14.226496
#
# === Generating plots for index 161, additional data: 4887 ===
# Local min: 0.000288, Local max: 14.229408
#
# === Generating plots for index 162, additional data: 4914 ===
# Local min: 0.000289, Local max: 14.276339
#
# === Generating plots for index 163, additional data: 4941 ===
# Local min: 0.000288, Local max: 14.285459
#
# === Generating plots for index 164, additional data: 4968 ===
# Local min: 0.000288, Local max: 14.280089
#
# === Generating plots for index 165, additional data: 4995 ===
# Local min: 0.000287, Local max: 14.274165
#
# === Generating plots for index 166, additional data: 5022 ===
# Local min: 0.000286, Local max: 14.297450
#
# === Generating plots for index 167, additional data: 5049 ===
# Local min: 0.000286, Local max: 14.291589
#
# === Generating plots for index 168, additional data: 5076 ===
# Local min: 0.000285, Local max: 14.291337
#
# === Generating plots for index 169, additional data: 5103 ===
# Local min: 0.000284, Local max: 14.290953
#
# === Generating plots for index 170, additional data: 5130 ===
# Local min: 0.000286, Local max: 14.301222
#
# === Generating plots for index 171, additional data: 5157 ===
# Local min: 0.000285, Local max: 14.324700
#
# === Generating plots for index 172, additional data: 5184 ===
# Local min: 0.000285, Local max: 14.311803
#
# === Generating plots for index 173, additional data: 5211 ===
# Local min: 0.000284, Local max: 14.287333
#
# === Generating plots for index 174, additional data: 5238 ===
# Local min: 0.000284, Local max: 14.277160
#
# === Generating plots for index 175, additional data: 5265 ===
# Local min: 0.000283, Local max: 14.269156
#
# === Generating plots for index 176, additional data: 5292 ===
# Local min: 0.000284, Local max: 14.270508
#
# === Generating plots for index 177, additional data: 5319 ===
# Local min: 0.000283, Local max: 14.257663
#
# === Generating plots for index 178, additional data: 5346 ===
# Local min: 0.000284, Local max: 14.267406
#
# === Generating plots for index 179, additional data: 5373 ===
# Local min: 0.000285, Local max: 14.280203
#
# === Generating plots for index 180, additional data: 5400 ===
# Local min: 0.000285, Local max: 14.279180
#
# === Generating plots for index 181, additional data: 5427 ===
# Local min: 0.000284, Local max: 14.298646
#
# === Generating plots for index 182, additional data: 5454 ===
# Local min: 0.000284, Local max: 14.322215
#
# === Generating plots for index 183, additional data: 5481 ===
# Local min: 0.000284, Local max: 14.289399
#
# === Generating plots for index 184, additional data: 5508 ===
# Local min: 0.000283, Local max: 14.266068
#
# === Generating plots for index 185, additional data: 5535 ===
# Local min: 0.000284, Local max: 14.253649
#
# === Generating plots for index 186, additional data: 5562 ===
# Local min: 0.000284, Local max: 14.250147
#
# === Generating plots for index 187, additional data: 5589 ===
# Local min: 0.000283, Local max: 14.230882
#
# === Generating plots for index 188, additional data: 5616 ===
# Local min: 0.000282, Local max: 14.250392
#
# === Generating plots for index 189, additional data: 5643 ===
# Local min: 0.000282, Local max: 14.257418
#
# === Generating plots for index 190, additional data: 5670 ===
# Local min: 0.000282, Local max: 14.272562
#
# === Generating plots for index 191, additional data: 5697 ===
# Local min: 0.000283, Local max: 14.248124
#
# === Generating plots for index 192, additional data: 5724 ===
# Local min: 0.000283, Local max: 14.250111
#
# === Generating plots for index 193, additional data: 5751 ===
# Local min: 0.000282, Local max: 14.253180
#
# === Generating plots for index 194, additional data: 5778 ===
# Local min: 0.000282, Local max: 14.241632
#
# === Generating plots for index 195, additional data: 5805 ===
# Local min: 0.000282, Local max: 14.254344
#
# === Generating plots for index 196, additional data: 5832 ===
# Local min: 0.000281, Local max: 14.243669
#
# === Generating plots for index 197, additional data: 5859 ===
# Local min: 0.000283, Local max: 14.247783
#
# === Generating plots for index 198, additional data: 5886 ===
# Local min: 0.000282, Local max: 14.245672
#
# === Generating plots for index 199, additional data: 5913 ===
# Local min: 0.000283, Local max: 14.217802
#
# === Generating plots for index 200, additional data: 5940 ===
# Local min: 0.000282, Local max: 14.197509
#
# === Generating plots for index 201, additional data: 6210 ===
# Local min: 0.001977, Local max: 14.176114
#
# === Generating plots for index 202, additional data: 6480 ===
# Local min: 0.002005, Local max: 14.182421
#
# === Generating plots for index 203, additional data: 6750 ===
# Local min: 0.002002, Local max: 14.195795
#
# === Generating plots for index 204, additional data: 7020 ===
# Local min: 0.001996, Local max: 14.197261
#
# === Generating plots for index 205, additional data: 7290 ===
# Local min: 0.002010, Local max: 14.180374
#
# === Generating plots for index 206, additional data: 7560 ===
# Local min: 0.001984, Local max: 14.222530
#
# === Generating plots for index 207, additional data: 7830 ===
# Local min: 0.001979, Local max: 14.228755
#
# === Generating plots for index 208, additional data: 8100 ===
# Local min: 0.001978, Local max: 14.210570
#
# === Generating plots for index 209, additional data: 8370 ===
# Local min: 0.001965, Local max: 14.240818
#
# === Generating plots for index 210, additional data: 8640 ===
# Local min: 0.001948, Local max: 14.220446
#
# === Generating plots for index 211, additional data: 8910 ===
# Local min: 0.001968, Local max: 14.304096
#
# === Generating plots for index 212, additional data: 9180 ===
# Local min: 0.001996, Local max: 14.313537
#
# === Generating plots for index 213, additional data: 9450 ===
# Local min: 0.001975, Local max: 14.359587
#
# === Generating plots for index 214, additional data: 9720 ===
# Local min: 0.001986, Local max: 14.385860
#
# === Generating plots for index 215, additional data: 9990 ===
# Local min: 0.001975, Local max: 14.409285
#
# === Generating plots for index 216, additional data: 10260 ===
# Local min: 0.001989, Local max: 14.431164
#
# === Generating plots for index 217, additional data: 10530 ===
# Local min: 0.001982, Local max: 14.420457
#
# === Generating plots for index 218, additional data: 10800 ===
# Local min: 0.001964, Local max: 14.426146
#
# === Generating plots for index 219, additional data: 11070 ===
# Local min: 0.001944, Local max: 14.406657
#
# === Generating plots for index 220, additional data: 11340 ===
# Local min: 0.001956, Local max: 14.428829
#
# === Generating plots for index 221, additional data: 11610 ===
# Local min: 0.001960, Local max: 14.472764
#
# === Generating plots for index 222, additional data: 11880 ===
# Local min: 0.001949, Local max: 14.490319
#
# === Generating plots for index 223, additional data: 12150 ===
# Local min: 0.001965, Local max: 14.506967
#
# === Generating plots for index 224, additional data: 12420 ===
# Local min: 0.001966, Local max: 14.557656
#
# === Generating plots for index 225, additional data: 12690 ===
# Local min: 0.001946, Local max: 14.537176
#
# === Generating plots for index 226, additional data: 12960 ===
# Local min: 0.001973, Local max: 14.503758
#
# === Generating plots for index 227, additional data: 13230 ===
# Local min: 0.001975, Local max: 14.450568
#
# === Generating plots for index 228, additional data: 13500 ===
# Local min: 0.001962, Local max: 14.454934
#
# === Generating plots for index 229, additional data: 13770 ===
# Local min: 0.001961, Local max: 14.455445
#
# === Generating plots for index 230, additional data: 14040 ===
# Local min: 0.001944, Local max: 14.436851
#
# === Generating plots for index 231, additional data: 14310 ===
# Local min: 0.001938, Local max: 14.415046
#
# === Generating plots for index 232, additional data: 14580 ===
# Local min: 0.001931, Local max: 14.434365
#
# === Generating plots for index 233, additional data: 14850 ===
# Local min: 0.001926, Local max: 14.434178
#
# === Generating plots for index 234, additional data: 15120 ===
# Local min: 0.001920, Local max: 14.439541
#
# === Generating plots for index 235, additional data: 15390 ===
# Local min: 0.001912, Local max: 14.426421
#
# === Generating plots for index 236, additional data: 15660 ===
# Local min: 0.001910, Local max: 14.462982
#
# === Generating plots for index 237, additional data: 15930 ===
# Local min: 0.001922, Local max: 14.479975
#
# === Generating plots for index 238, additional data: 16200 ===
# Local min: 0.001918, Local max: 14.486758
#
# === Generating plots for index 239, additional data: 16470 ===
# Local min: 0.001908, Local max: 14.490133
#
# === Generating plots for index 240, additional data: 16740 ===
# Local min: 0.001901, Local max: 14.507474
#
# === Generating plots for index 241, additional data: 17010 ===
# Local min: 0.001920, Local max: 14.533550
#
# === Generating plots for index 242, additional data: 17280 ===
# Local min: 0.001919, Local max: 14.489130
#
# === Generating plots for index 243, additional data: 17550 ===
# Local min: 0.001924, Local max: 14.530292
#
# === Generating plots for index 244, additional data: 17820 ===
# Local min: 0.001914, Local max: 14.524608
#
# === Generating plots for index 245, additional data: 18090 ===
# Local min: 0.001918, Local max: 14.557946
#
# === Generating plots for index 246, additional data: 18360 ===
# Local min: 0.001929, Local max: 14.578607
#
# === Generating plots for index 247, additional data: 18630 ===
# Local min: 0.001924, Local max: 14.609654
#
# === Generating plots for index 248, additional data: 18900 ===
# Local min: 0.001914, Local max: 14.624138
#
# === Generating plots for index 249, additional data: 19170 ===
# Local min: 0.001928, Local max: 14.626660
#
# === Generating plots for index 250, additional data: 19440 ===
# Local min: 0.001931, Local max: 14.613628
#
# === Generating plots for index 251, additional data: 19710 ===
# Local min: 0.001922, Local max: 14.588045
#
# === Generating plots for index 252, additional data: 19980 ===
# Local min: 0.001924, Local max: 14.603505
#
# === Generating plots for index 253, additional data: 20250 ===
# Local min: 0.001942, Local max: 14.609524
#
# === Generating plots for index 254, additional data: 20520 ===
# Local min: 0.001961, Local max: 14.607057
#
# === Generating plots for index 255, additional data: 20790 ===
# Local min: 0.001964, Local max: 14.633367
#
# === Generating plots for index 256, additional data: 21060 ===
# Local min: 0.001963, Local max: 14.613217
#
# === Generating plots for index 257, additional data: 21330 ===
# Local min: 0.001973, Local max: 14.607089
#
# === Generating plots for index 258, additional data: 21600 ===
# Local min: 0.001968, Local max: 14.633597
#
# === Generating plots for index 259, additional data: 21870 ===
# Local min: 0.001974, Local max: 14.623742
#
# === Generating plots for index 260, additional data: 22140 ===
# Local min: 0.001976, Local max: 14.618548
#
# === Generating plots for index 261, additional data: 22410 ===
# Local min: 0.001988, Local max: 14.624357
#
# === Generating plots for index 262, additional data: 22680 ===
# Local min: 0.001988, Local max: 14.645486
#
# === Generating plots for index 263, additional data: 22950 ===
# Local min: 0.001986, Local max: 14.653777
#
# === Generating plots for index 264, additional data: 23220 ===
# Local min: 0.002003, Local max: 14.668707
#
# === Generating plots for index 265, additional data: 23490 ===
# Local min: 0.002010, Local max: 14.652601
#
# === Generating plots for index 266, additional data: 23760 ===
# Local min: 0.002009, Local max: 14.678705
#
# === Generating plots for index 267, additional data: 24030 ===
# Local min: 0.002025, Local max: 14.677316
#
# === Generating plots for index 268, additional data: 24300 ===
# Local min: 0.002027, Local max: 14.658387
#
# === Generating plots for index 269, additional data: 24570 ===
# Local min: 0.002020, Local max: 14.662307
#
# === Generating plots for index 270, additional data: 24840 ===
# Local min: 0.002022, Local max: 14.645411
#
# === Generating plots for index 271, additional data: 25110 ===
# Local min: 0.002022, Local max: 14.634065
#
# === Generating plots for index 272, additional data: 25380 ===
# Local min: 0.002027, Local max: 14.646442
#
# === Generating plots for index 273, additional data: 25650 ===
# Local min: 0.002029, Local max: 14.644709
#
# === Generating plots for index 274, additional data: 25920 ===
# Local min: 0.002034, Local max: 14.642927
#
# === Generating plots for index 275, additional data: 26190 ===
# Local min: 0.002032, Local max: 14.649151
#
# === Generating plots for index 276, additional data: 26460 ===
# Local min: 0.002025, Local max: 14.662306
#
# === Generating plots for index 277, additional data: 26730 ===
# Local min: 0.002029, Local max: 14.665358
#
# === Generating plots for index 278, additional data: 27000 ===
# Local min: 0.002024, Local max: 14.668306
#
# === Generating plots for index 279, additional data: 27270 ===
# Local min: 0.002036, Local max: 14.680758
#
# === Generating plots for index 280, additional data: 27540 ===
# Local min: 0.002038, Local max: 14.669994
#
# === Generating plots for index 281, additional data: 27810 ===
# Local min: 0.002030, Local max: 14.672310
#
# === Generating plots for index 282, additional data: 28080 ===
# Local min: 0.002025, Local max: 14.657996
#
# === Generating plots for index 283, additional data: 28350 ===
# Local min: 0.002022, Local max: 14.636781
#
# === Generating plots for index 284, additional data: 28620 ===
# Local min: 0.002018, Local max: 14.619438
#
# === Generating plots for index 285, additional data: 28890 ===
# Local min: 0.002018, Local max: 14.628137
#
# === Generating plots for index 286, additional data: 29160 ===
# Local min: 0.002017, Local max: 14.617986
#
# === Generating plots for index 287, additional data: 29430 ===
# Local min: 0.002012, Local max: 14.624289
#
# === Generating plots for index 288, additional data: 29700 ===
# Local min: 0.002017, Local max: 14.660313
#
# === Generating plots for index 289, additional data: 29970 ===
# Local min: 0.002018, Local max: 14.654962
#
# === Generating plots for index 290, additional data: 30240 ===
# Local min: 0.002016, Local max: 14.648818
#
# === Generating plots for index 291, additional data: 30510 ===
# Local min: 0.002018, Local max: 14.659536
#
# === Generating plots for index 292, additional data: 30780 ===
# Local min: 0.002016, Local max: 14.667357
#
# === Generating plots for index 293, additional data: 31050 ===
# Local min: 0.002011, Local max: 14.669065
#
# === Generating plots for index 294, additional data: 31320 ===
# Local min: 0.002013, Local max: 14.675987
#
# === Generating plots for index 295, additional data: 31590 ===
# Local min: 0.002011, Local max: 14.689741
#
# === Generating plots for index 296, additional data: 31860 ===
# Local min: 0.002015, Local max: 14.699689
#
# === Generating plots for index 297, additional data: 32130 ===
# Local min: 0.002028, Local max: 14.713707
#
# === Generating plots for index 298, additional data: 32400 ===
# Local min: 0.002026, Local max: 14.712543
#
# === Generating plots for index 299, additional data: 32670 ===
# Local min: 0.002022, Local max: 14.695665
#
# === Generating plots for index 300, additional data: 32940 ===
# Local min: 0.002021, Local max: 14.698448
#
# === Generating plots for index 301, additional data: 33210 ===
# Local min: 0.002024, Local max: 14.697257
#
# === Generating plots for index 302, additional data: 33480 ===
# Local min: 0.002029, Local max: 14.702053
#
# === Generating plots for index 303, additional data: 33750 ===
# Local min: 0.002029, Local max: 14.715426
#
# === Generating plots for index 304, additional data: 34020 ===
# Local min: 0.002035, Local max: 14.720023
#
# === Generating plots for index 305, additional data: 34290 ===
# Local min: 0.002032, Local max: 14.714154
#
# === Generating plots for index 306, additional data: 34560 ===
# Local min: 0.002040, Local max: 14.721459
#
# === Generating plots for index 307, additional data: 34830 ===
# Local min: 0.002032, Local max: 14.705442
#
# === Generating plots for index 308, additional data: 35100 ===
# Local min: 0.002045, Local max: 14.701968
#
# === Generating plots for index 309, additional data: 35370 ===
# Local min: 0.002042, Local max: 14.685318
#
# === Generating plots for index 310, additional data: 35640 ===
# Local min: 0.002036, Local max: 14.689722
#
# === Generating plots for index 311, additional data: 35910 ===
# Local min: 0.002033, Local max: 14.686367
#
# === Generating plots for index 312, additional data: 36180 ===
# Local min: 0.002028, Local max: 14.690152
#
# === Generating plots for index 313, additional data: 36450 ===
# Local min: 0.002027, Local max: 14.689664
#
# === Generating plots for index 314, additional data: 36720 ===
# Local min: 0.002027, Local max: 14.673783
#
# === Generating plots for index 315, additional data: 36990 ===
# Local min: 0.002027, Local max: 14.696137
#
# === Generating plots for index 316, additional data: 37260 ===
# Local min: 0.002024, Local max: 14.697287
#
# === Generating plots for index 317, additional data: 37530 ===
# Local min: 0.002020, Local max: 14.706644
#
# === Generating plots for index 318, additional data: 37800 ===
# Local min: 0.002014, Local max: 14.701815
#
# === Generating plots for index 319, additional data: 38070 ===
# Local min: 0.002025, Local max: 14.699826
#
# === Generating plots for index 320, additional data: 38340 ===
# Local min: 0.002016, Local max: 14.689119
#
# === Generating plots for index 321, additional data: 38610 ===
# Local min: 0.002028, Local max: 14.699066
#
# === Generating plots for index 322, additional data: 38880 ===
# Local min: 0.002020, Local max: 14.700279
#
# === Generating plots for index 323, additional data: 39150 ===
# Local min: 0.002027, Local max: 14.715621
#
# === Generating plots for index 324, additional data: 39420 ===
# Local min: 0.002026, Local max: 14.701921
#
# === Generating plots for index 325, additional data: 39690 ===
# Local min: 0.002021, Local max: 14.702796
#
# === Generating plots for index 326, additional data: 39960 ===
# Local min: 0.002035, Local max: 14.699176
#
# === Generating plots for index 327, additional data: 40230 ===
# Local min: 0.002033, Local max: 14.724531
#
# === Generating plots for index 328, additional data: 40500 ===
# Local min: 0.002031, Local max: 14.720322
#
# === Generating plots for index 329, additional data: 40770 ===
# Local min: 0.002030, Local max: 14.736273
#
# === Generating plots for index 330, additional data: 41040 ===
# Local min: 0.002037, Local max: 14.739355
#
# === Generating plots for index 331, additional data: 41310 ===
# Local min: 0.002038, Local max: 14.743488
#
# === Generating plots for index 332, additional data: 41580 ===
# Local min: 0.002042, Local max: 14.738508
#
# === Generating plots for index 333, additional data: 41850 ===
# Local min: 0.002047, Local max: 14.731762
#
# === Generating plots for index 334, additional data: 42120 ===
# Local min: 0.002053, Local max: 14.730589
#
# === Generating plots for index 335, additional data: 42390 ===
# Local min: 0.002054, Local max: 14.718160
#
# === Generating plots for index 336, additional data: 42660 ===
# Local min: 0.002053, Local max: 14.709332
#
# === Generating plots for index 337, additional data: 42930 ===
# Local min: 0.002050, Local max: 14.712066
#
# === Generating plots for index 338, additional data: 43200 ===
# Local min: 0.002048, Local max: 14.727398
#
# === Generating plots for index 339, additional data: 43470 ===
# Local min: 0.002051, Local max: 14.737824
#
# === Generating plots for index 340, additional data: 43740 ===
# Local min: 0.002050, Local max: 14.733136
#
# === Generating plots for index 341, additional data: 44010 ===
# Local min: 0.002047, Local max: 14.724353
#
# === Generating plots for index 342, additional data: 44280 ===
# Local min: 0.002045, Local max: 14.732347
#
# === Generating plots for index 343, additional data: 44550 ===
# Local min: 0.002041, Local max: 14.729246
#
# === Generating plots for index 344, additional data: 44820 ===
# Local min: 0.002043, Local max: 14.751657
#
# === Generating plots for index 345, additional data: 45090 ===
# Local min: 0.002041, Local max: 14.747299
#
# === Generating plots for index 346, additional data: 45360 ===
# Local min: 0.002039, Local max: 14.749612
#
# === Generating plots for index 347, additional data: 45630 ===
# Local min: 0.002035, Local max: 14.754350
#
# === Generating plots for index 348, additional data: 45900 ===
# Local min: 0.002032, Local max: 14.762786
#
# === Generating plots for index 349, additional data: 46170 ===
# Local min: 0.002027, Local max: 14.751805
#
# === Generating plots for index 350, additional data: 46440 ===
# Local min: 0.002028, Local max: 14.745411
#
# === Generating plots for index 351, additional data: 46710 ===
# Local min: 0.002023, Local max: 14.737754
#
# === Generating plots for index 352, additional data: 46980 ===
# Local min: 0.002019, Local max: 14.732554
#
# === Generating plots for index 353, additional data: 47250 ===
# Local min: 0.002013, Local max: 14.736850
#
# === Generating plots for index 354, additional data: 47520 ===
# Local min: 0.002012, Local max: 14.733743
#
# === Generating plots for index 355, additional data: 47790 ===
# Local min: 0.002010, Local max: 14.728547
#
# === Generating plots for index 356, additional data: 48060 ===
# Local min: 0.002014, Local max: 14.729940
#
# === Generating plots for index 357, additional data: 48330 ===
# Local min: 0.002014, Local max: 14.719216
#
# === Generating plots for index 358, additional data: 48600 ===
# Local min: 0.002013, Local max: 14.724209
#
# === Generating plots for index 359, additional data: 48870 ===
# Local min: 0.002011, Local max: 14.732201
#
# === Generating plots for index 360, additional data: 49140 ===
# Local min: 0.002008, Local max: 14.728369
#
# === Generating plots for index 361, additional data: 49410 ===
# Local min: 0.002011, Local max: 14.729809
#
# === Generating plots for index 362, additional data: 49680 ===
# Local min: 0.002011, Local max: 14.716962
#
# === Generating plots for index 363, additional data: 49950 ===
# Local min: 0.002008, Local max: 14.701627
#
# === Generating plots for index 364, additional data: 50220 ===
# Local min: 0.002006, Local max: 14.697971
#
# === Generating plots for index 365, additional data: 50490 ===
# Local min: 0.002003, Local max: 14.695136
#
# === Generating plots for index 366, additional data: 50760 ===
# Local min: 0.002005, Local max: 14.690533
#
# === Generating plots for index 367, additional data: 51030 ===
# Local min: 0.002005, Local max: 14.687258
#
# === Generating plots for index 368, additional data: 51300 ===
# Local min: 0.001999, Local max: 14.676841
#
# === Generating plots for index 369, additional data: 51570 ===
# Local min: 0.002009, Local max: 14.681900
#
# === Generating plots for index 370, additional data: 51840 ===
# Local min: 0.002003, Local max: 14.674937
#
# === Generating plots for index 371, additional data: 52110 ===
# Local min: 0.001996, Local max: 14.684284
#
# === Generating plots for index 372, additional data: 52380 ===
# Local min: 0.001992, Local max: 14.694557
#
# === Generating plots for index 373, additional data: 52650 ===
# Local min: 0.001997, Local max: 14.681051
#
# === Generating plots for index 374, additional data: 52920 ===
# Local min: 0.002000, Local max: 14.683163
#
# === Generating plots for index 375, additional data: 53190 ===
# Local min: 0.001998, Local max: 14.677671
#
# === Generating plots for index 376, additional data: 53460 ===
# Local min: 0.002007, Local max: 14.678609
#
# === Generating plots for index 377, additional data: 53730 ===
# Local min: 0.002007, Local max: 14.677749
#
# === Generating plots for index 378, additional data: 54000 ===
# Local min: 0.002003, Local max: 14.674484
#
# === Generating plots for index 379, additional data: 54270 ===
# Local min: 0.002002, Local max: 14.669150
#
# === Generating plots for index 380, additional data: 54540 ===
# Local min: 0.002000, Local max: 14.663441
#
# === Generating plots for index 381, additional data: 54810 ===
# Local min: 0.002000, Local max: 14.660042
#
# === Generating plots for index 382, additional data: 55080 ===
# Local min: 0.001998, Local max: 14.655781
#
# === Generating plots for index 383, additional data: 55350 ===
# Local min: 0.001998, Local max: 14.659616
#
# === Generating plots for index 384, additional data: 55620 ===
# Local min: 0.001999, Local max: 14.660374
#
# === Generating plots for index 385, additional data: 55890 ===
# Local min: 0.002005, Local max: 14.653310
#
# === Generating plots for index 386, additional data: 56160 ===
# Local min: 0.002004, Local max: 14.653411
#
# === Generating plots for index 387, additional data: 56430 ===
# Local min: 0.002003, Local max: 14.648567
#
# === Generating plots for index 388, additional data: 56700 ===
# Local min: 0.002002, Local max: 14.648943
#
# === Generating plots for index 389, additional data: 56970 ===
# Local min: 0.002001, Local max: 14.646017
#
# === Generating plots for index 390, additional data: 57240 ===
# Local min: 0.002002, Local max: 14.658072
#
# === Generating plots for index 391, additional data: 57510 ===
# Local min: 0.002004, Local max: 14.654962
#
# === Generating plots for index 392, additional data: 57780 ===
# Local min: 0.002002, Local max: 14.661141
#
# === Generating plots for index 393, additional data: 58050 ===
# Local min: 0.002003, Local max: 14.664781
#
# === Generating plots for index 394, additional data: 58320 ===
# Local min: 0.002001, Local max: 14.673857
#
# === Generating plots for index 395, additional data: 58590 ===
# Local min: 0.001997, Local max: 14.668818
#
# === Generating plots for index 396, additional data: 58860 ===
# Local min: 0.001998, Local max: 14.669851
#
# === Generating plots for index 397, additional data: 59130 ===
# Local min: 0.001995, Local max: 14.674620
#
# === Generating plots for index 398, additional data: 59400 ===
# Local min: 0.001995, Local max: 14.688837
#
# === Generating plots for index 399, additional data: 59670 ===
# Local min: 0.001994, Local max: 14.677530
#
# === Generating plots for index 400, additional data: 59940 ===
# Local min: 0.001992, Local max: 14.693702
#
# === Total time for plotting all loss landscapes: 728.26 seconds (12.14 minutes) ===
#
# ✓ All plots generated successfully!
