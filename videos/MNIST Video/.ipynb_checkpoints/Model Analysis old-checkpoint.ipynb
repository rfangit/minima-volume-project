# %% [markdown]
# # Model Analysis
#
# This program takes in datasets and models, and computes the loss landscapes over varying amounts of data.

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

import time
import glob

# Importing our existing funcs
import os
import sys
from pathlib import Path

from minima_volume.dataset_funcs import ( load_models_and_data )

from minima_volume.landscape_videos import (
    compute_loss_landscape_3models,
    plot_2d_loss_landscape_3model,
    compute_loss_landscapes_varying_data,
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Model

# %%
# User specifies the model module name
import MNIST_model_data as model_module

# Generate dataset
#x_base, y_base, x_test, y_test = model_module.get_dataset(
#    device = device
#)

# MNIST specific initialization parameters
hidden_dims = [256, 128]

# Grab model
model_template = model_module.get_model(hidden_dims=hidden_dims, device=device, seed=0)

# Grab loss and metrics
loss_fn = model_module.get_loss_fn()
other_metrics = model_module.get_additional_metrics()

# %% [markdown]
# ## Loading Model and Datasets

# %%
# Get the relative path
target_dir = Path("models_and_data") #current directory

# Lists to store loaded models and additional data
loaded_models, loaded_additional_data, loaded_dataset = load_models_and_data(model_template=model_template, target_dir=target_dir, device="cpu")

# Print dataset information
print(f"Dataset type: {loaded_dataset['dataset_type']}")
print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")

# Print tensor shapes
print("\nTensor shapes:")
for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
    if loaded_dataset[key] is not None:
        print(f"  {key}: {loaded_dataset[key].shape}")
    else:
        print(f"  {key}: None")
# Out:
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_additional_0.pt
#   - model_additional_1940.pt
#   - model_additional_19940.pt
#   - model_additional_540.pt
#   - model_additional_5940.pt
#   - model_additional_59940.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_0.pt
# Successfully loaded: model_additional_0.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_1940.pt
# Successfully loaded: model_additional_1940.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_19940.pt
# Successfully loaded: model_additional_19940.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_540.pt
# Successfully loaded: model_additional_540.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_5940.pt
# Successfully loaded: model_additional_5940.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_59940.pt
# Successfully loaded: model_additional_59940.pt
#
# Model data loaded from all models:
# Model 0 (model_additional_0.pt):
#   - Additional data: 0
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 1 (model_additional_1940.pt):
#   - Additional data: 1940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 2 (model_additional_19940.pt):
#   - Additional data: 19940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 3 (model_additional_540.pt):
#   - Additional data: 540
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 4 (model_additional_5940.pt):
#   - Additional data: 5940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 5 (model_additional_59940.pt):
#   - Additional data: 59940
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
#
# Loading dataset...
# Using dataset file: dataset.pt
# ✅ Dataset loaded from models_and_data\dataset.pt
# Dataset type: data
# Dataset quantities: [0, 540, 1940, 5940, 19940, 59940]
#
# Tensor shapes:
#   x_base_train: torch.Size([60, 1, 28, 28])
#   y_base_train: torch.Size([60])
#   x_additional: torch.Size([59940, 1, 28, 28])
#   y_additional: torch.Size([59940])
#   x_test: torch.Size([10000, 1, 28, 28])
#   y_test: torch.Size([10000])

# %% [markdown]
# ## Plotting Parameters
#
# Determines what models to use.

# %%
index1 = 3
index2 = 4
index3 = 5
index_list = [index1, index2, index3]

print(
    f"Loading models trained with: "
    f"{loaded_additional_data[index1]['additional_data']}, "
    f"{loaded_additional_data[index2]['additional_data']}, "
    f"{loaded_additional_data[index3]['additional_data']}"
)

model_0 = loaded_models[index1]
model_1 = loaded_models[index2]
model_2 = loaded_models[index3]

print("=== Selected Models ===")
dataset_type = loaded_dataset['dataset_type']
model_labels = [
    f"Model Trained with {loaded_additional_data[index1]['additional_data']} {dataset_type}",
    f"Model Trained with {loaded_additional_data[index2]['additional_data']} {dataset_type}",
    f"Model Trained with {loaded_additional_data[index3]['additional_data']} {dataset_type}"
]

# Prepare dataset with additional_data = 0 (base dataset only)
x_base_train = loaded_dataset['x_base_train']
y_base_train = loaded_dataset['y_base_train']
x_additional = loaded_dataset['x_additional']
y_additional = loaded_dataset['y_additional']
# Out:
# Loading models trained with: 540, 5940, 59940
# === Selected Models ===

# %% [markdown]
# ## Loss Surface Generation

# %% [markdown]
# First, a sample visualization.

# %%
# Create quick_view directory
quick_view_dir = Path("quick_view")
quick_view_dir.mkdir(exist_ok=True)

# Create grid coefficients [-0.5, 1.5] with 80x80 points
N = 80
span_low = -0.5
span_high = 1.5

x = np.linspace(span_low, span_high, N)
y = np.linspace(span_low, span_high, N)
C1_grid, C2_grid = np.meshgrid(x, y)
grid_coefficients = (C1_grid, C2_grid)

print(f"Grid size: {N}x{N}, Range: [{span_low}, {span_high}]")

loss_grids = []

# Now begin assembling the datasets and computing different loss surfaces for this grid.
print("\n=== Generating Loss Landscape ===")
for i in range(3):
    x_train = torch.cat([x_base_train, x_additional[:loaded_additional_data[index_list[i]]['additional_data']]], dim=0)  # additional_data = 0
    y_train = torch.cat([y_base_train, y_additional[:loaded_additional_data[index_list[i]]['additional_data']]], dim=0)  # additional_data = 0

    print(f"Dataset size: {len(x_train)} samples")

    loss_grid, perturbation_vectors = compute_loss_landscape_3models(
        model_0=model_0,
        model_1=model_1,
        model_2=model_2,
        grid_coefficients=grid_coefficients,
        x_train=x_train,
        y_train=y_train,
        loss_fn=loss_fn,
        output_dir=quick_view_dir,
        filename=f"dataset_{loaded_additional_data[index_list[i]]['additional_data']}.npz"
    )
    loss_grids.append(loss_grid)

print("✓ Loss landscape generated and saved")

# Sample plot 
print("=== Plotting Loss Landscapes ===")

for i in range(3):
    # Plot 2D loss landscape
    plot_2d_loss_landscape_3model(
        C1_grid=C1_grid,
        C2_grid=C2_grid, 
        loss_grid=loss_grids[i],
        span_low=span_low,
        span_high=span_high,
        output_path=f"quick_view/loss_landscape_{loaded_additional_data[index_list[i]]['additional_data']}.png",
        additional_data = loaded_additional_data[index_list[i]]['additional_data'],
        model_labels = model_labels,
        show = True
    )
# Out:
# Grid size: 80x80, Range: [-0.5, 1.5]
#
# === Generating Loss Landscape ===
# Dataset size: 600 samples
# Dataset size: 6000 samples
# Dataset size: 60000 samples
# ✓ Loss landscape generated and saved
# === Plotting Loss Landscapes ===

# %% [markdown]
# ## Loss Landscape Computation Across Datasets
#
# Loss landscape computation.

# %%
# Create storage directory
varying_dataset_dir = Path("varying_dataset")
varying_dataset_dir.mkdir(exist_ok=True)

# Define the additional data amounts to test
# This can be varied depending on the use case!!
# Example input
anchor_points = [600, 6000, 60000]   # specify 2, 3, or more points
steps_per_segment = 100               # how many intervals between each pair

additional_data_amounts = []

for i in range(len(anchor_points) - 1):
    start, end = anchor_points[i], anchor_points[i+1]
    # linspace includes both start and end, so skip first element except first segment
    segment = np.linspace(start, end, steps_per_segment + 1, dtype=int)
    if i > 0:
        segment = segment[1:]  # avoid repeating the start of each segment
    additional_data_amounts.extend(segment.tolist())

print(additional_data_amounts)

# Create grid
N = 80
span_low, span_high = -0.5, 1.5
x = np.linspace(span_low, span_high, N)
y = np.linspace(span_low, span_high, N)
C1_grid, C2_grid = np.meshgrid(x, y)
grid_coefficients = (C1_grid, C2_grid)

print(f"Grid size: {N}x{N}, Range: [{span_low}, {span_high}]")
# Out:
# [600, 654, 708, 762, 816, 870, 924, 978, 1032, 1086, 1140, 1194, 1248, 1302, 1356, 1410, 1464, 1518, 1572, 1626, 1680, 1734, 1788, 1842, 1896, 1950, 2004, 2058, 2112, 2166, 2220, 2274, 2328, 2382, 2436, 2490, 2544, 2598, 2652, 2706, 2760, 2814, 2868, 2922, 2976, 3030, 3084, 3138, 3192, 3246, 3300, 3354, 3408, 3462, 3516, 3570, 3624, 3678, 3732, 3786, 3840, 3894, 3948, 4002, 4056, 4110, 4164, 4218, 4272, 4326, 4380, 4434, 4488, 4542, 4596, 4650, 4704, 4758, 4812, 4866, 4920, 4974, 5028, 5082, 5136, 5190, 5244, 5298, 5352, 5406, 5460, 5514, 5568, 5622, 5676, 5730, 5784, 5838, 5892, 5946, 6000, 6540, 7080, 7620, 8160, 8700, 9240, 9780, 10320, 10860, 11400, 11940, 12480, 13020, 13560, 14100, 14640, 15180, 15720, 16260, 16800, 17340, 17880, 18420, 18960, 19500, 20040, 20580, 21120, 21660, 22200, 22740, 23280, 23820, 24360, 24900, 25440, 25980, 26520, 27060, 27600, 28140, 28680, 29220, 29760, 30300, 30840, 31380, 31920, 32460, 33000, 33540, 34080, 34620, 35160, 35700, 36240, 36780, 37320, 37860, 38400, 38940, 39480, 40020, 40560, 41100, 41640, 42180, 42720, 43260, 43800, 44340, 44880, 45420, 45960, 46500, 47040, 47580, 48120, 48660, 49200, 49740, 50280, 50820, 51360, 51900, 52440, 52980, 53520, 54060, 54600, 55140, 55680, 56220, 56760, 57300, 57840, 58380, 58920, 59460, 60000]
# Grid size: 80x80, Range: [-0.5, 1.5]

# %%
# Compute all loss landscapes
loss_grids_list = compute_loss_landscapes_varying_data(
    model_0=model_0,
    model_1=model_1,
    model_2=model_2,
    grid_coefficients=grid_coefficients,
    x_base=x_base_train,
    y_base=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    additional_data_amounts=additional_data_amounts,
    loss_fn=loss_fn,
    output_dir=varying_dataset_dir,
    base_filename="landscape"
)

print(f"✓ Completed all {len(loss_grids_list)} loss landscapes")
# Out:
# === Computing loss landscapes for 201 data amounts ===
# Processing additional data amount 1/201: 600
#   Dataset size: 660 samples
#   ✓ Completed and saved as landscape_index_0_amount_600.npz
# Processing additional data amount 2/201: 654
#   Dataset size: 714 samples
#   ✓ Completed and saved as landscape_index_1_amount_654.npz
# Processing additional data amount 3/201: 708
#   Dataset size: 768 samples
#   ✓ Completed and saved as landscape_index_2_amount_708.npz
# Processing additional data amount 4/201: 762
#   Dataset size: 822 samples
#   ✓ Completed and saved as landscape_index_3_amount_762.npz
# Processing additional data amount 5/201: 816
#   Dataset size: 876 samples
#   ✓ Completed and saved as landscape_index_4_amount_816.npz
# Processing additional data amount 6/201: 870
#   Dataset size: 930 samples
#   ✓ Completed and saved as landscape_index_5_amount_870.npz
# Processing additional data amount 7/201: 924
#   Dataset size: 984 samples
#   ✓ Completed and saved as landscape_index_6_amount_924.npz
# Processing additional data amount 8/201: 978
#   Dataset size: 1038 samples
#   ✓ Completed and saved as landscape_index_7_amount_978.npz
# Processing additional data amount 9/201: 1032
#   Dataset size: 1092 samples
#   ✓ Completed and saved as landscape_index_8_amount_1032.npz
# Processing additional data amount 10/201: 1086
#   Dataset size: 1146 samples
#   ✓ Completed and saved as landscape_index_9_amount_1086.npz
# Processing additional data amount 11/201: 1140
#   Dataset size: 1200 samples
#   ✓ Completed and saved as landscape_index_10_amount_1140.npz
# Processing additional data amount 12/201: 1194
#   Dataset size: 1254 samples
#   ✓ Completed and saved as landscape_index_11_amount_1194.npz
# Processing additional data amount 13/201: 1248
#   Dataset size: 1308 samples
#   ✓ Completed and saved as landscape_index_12_amount_1248.npz
# Processing additional data amount 14/201: 1302
#   Dataset size: 1362 samples
#   ✓ Completed and saved as landscape_index_13_amount_1302.npz
# Processing additional data amount 15/201: 1356
#   Dataset size: 1416 samples
#   ✓ Completed and saved as landscape_index_14_amount_1356.npz
# Processing additional data amount 16/201: 1410
#   Dataset size: 1470 samples
#   ✓ Completed and saved as landscape_index_15_amount_1410.npz
# Processing additional data amount 17/201: 1464
#   Dataset size: 1524 samples
#   ✓ Completed and saved as landscape_index_16_amount_1464.npz
# Processing additional data amount 18/201: 1518
#   Dataset size: 1578 samples
#   ✓ Completed and saved as landscape_index_17_amount_1518.npz
# Processing additional data amount 19/201: 1572
#   Dataset size: 1632 samples
#   ✓ Completed and saved as landscape_index_18_amount_1572.npz
# Processing additional data amount 20/201: 1626
#   Dataset size: 1686 samples
#   ✓ Completed and saved as landscape_index_19_amount_1626.npz
# Processing additional data amount 21/201: 1680
#   Dataset size: 1740 samples
#   ✓ Completed and saved as landscape_index_20_amount_1680.npz
# Processing additional data amount 22/201: 1734
#   Dataset size: 1794 samples
#   ✓ Completed and saved as landscape_index_21_amount_1734.npz
# Processing additional data amount 23/201: 1788
#   Dataset size: 1848 samples
#   ✓ Completed and saved as landscape_index_22_amount_1788.npz
# Processing additional data amount 24/201: 1842
#   Dataset size: 1902 samples
#   ✓ Completed and saved as landscape_index_23_amount_1842.npz
# Processing additional data amount 25/201: 1896
#   Dataset size: 1956 samples
#   ✓ Completed and saved as landscape_index_24_amount_1896.npz
# Processing additional data amount 26/201: 1950
#   Dataset size: 2010 samples
#   ✓ Completed and saved as landscape_index_25_amount_1950.npz
# Processing additional data amount 27/201: 2004
#   Dataset size: 2064 samples
#   ✓ Completed and saved as landscape_index_26_amount_2004.npz
# Processing additional data amount 28/201: 2058
#   Dataset size: 2118 samples
#   ✓ Completed and saved as landscape_index_27_amount_2058.npz
# Processing additional data amount 29/201: 2112
#   Dataset size: 2172 samples
#   ✓ Completed and saved as landscape_index_28_amount_2112.npz
# Processing additional data amount 30/201: 2166
#   Dataset size: 2226 samples
#   ✓ Completed and saved as landscape_index_29_amount_2166.npz
# Processing additional data amount 31/201: 2220
#   Dataset size: 2280 samples
#   ✓ Completed and saved as landscape_index_30_amount_2220.npz
# Processing additional data amount 32/201: 2274
#   Dataset size: 2334 samples
#   ✓ Completed and saved as landscape_index_31_amount_2274.npz
# Processing additional data amount 33/201: 2328
#   Dataset size: 2388 samples
#   ✓ Completed and saved as landscape_index_32_amount_2328.npz
# Processing additional data amount 34/201: 2382
#   Dataset size: 2442 samples
#   ✓ Completed and saved as landscape_index_33_amount_2382.npz
# Processing additional data amount 35/201: 2436
#   Dataset size: 2496 samples
#   ✓ Completed and saved as landscape_index_34_amount_2436.npz
# Processing additional data amount 36/201: 2490
#   Dataset size: 2550 samples
#   ✓ Completed and saved as landscape_index_35_amount_2490.npz
# Processing additional data amount 37/201: 2544
#   Dataset size: 2604 samples
#   ✓ Completed and saved as landscape_index_36_amount_2544.npz
# Processing additional data amount 38/201: 2598
#   Dataset size: 2658 samples
#   ✓ Completed and saved as landscape_index_37_amount_2598.npz
# Processing additional data amount 39/201: 2652
#   Dataset size: 2712 samples
#   ✓ Completed and saved as landscape_index_38_amount_2652.npz
# Processing additional data amount 40/201: 2706
#   Dataset size: 2766 samples
#   ✓ Completed and saved as landscape_index_39_amount_2706.npz
# Processing additional data amount 41/201: 2760
#   Dataset size: 2820 samples
#   ✓ Completed and saved as landscape_index_40_amount_2760.npz
# Processing additional data amount 42/201: 2814
#   Dataset size: 2874 samples
#   ✓ Completed and saved as landscape_index_41_amount_2814.npz
# Processing additional data amount 43/201: 2868
#   Dataset size: 2928 samples
#   ✓ Completed and saved as landscape_index_42_amount_2868.npz
# Processing additional data amount 44/201: 2922
#   Dataset size: 2982 samples
#   ✓ Completed and saved as landscape_index_43_amount_2922.npz
# Processing additional data amount 45/201: 2976
#   Dataset size: 3036 samples
#   ✓ Completed and saved as landscape_index_44_amount_2976.npz
# Processing additional data amount 46/201: 3030
#   Dataset size: 3090 samples
#   ✓ Completed and saved as landscape_index_45_amount_3030.npz
# Processing additional data amount 47/201: 3084
#   Dataset size: 3144 samples
#   ✓ Completed and saved as landscape_index_46_amount_3084.npz
# Processing additional data amount 48/201: 3138
#   Dataset size: 3198 samples
#   ✓ Completed and saved as landscape_index_47_amount_3138.npz
# Processing additional data amount 49/201: 3192
#   Dataset size: 3252 samples
#   ✓ Completed and saved as landscape_index_48_amount_3192.npz
# Processing additional data amount 50/201: 3246
#   Dataset size: 3306 samples
#   ✓ Completed and saved as landscape_index_49_amount_3246.npz
# Processing additional data amount 51/201: 3300
#   Dataset size: 3360 samples
#   ✓ Completed and saved as landscape_index_50_amount_3300.npz
# Processing additional data amount 52/201: 3354
#   Dataset size: 3414 samples
#   ✓ Completed and saved as landscape_index_51_amount_3354.npz
# Processing additional data amount 53/201: 3408
#   Dataset size: 3468 samples
#   ✓ Completed and saved as landscape_index_52_amount_3408.npz
# Processing additional data amount 54/201: 3462
#   Dataset size: 3522 samples
#   ✓ Completed and saved as landscape_index_53_amount_3462.npz
# Processing additional data amount 55/201: 3516
#   Dataset size: 3576 samples
#   ✓ Completed and saved as landscape_index_54_amount_3516.npz
# Processing additional data amount 56/201: 3570
#   Dataset size: 3630 samples
#   ✓ Completed and saved as landscape_index_55_amount_3570.npz
# Processing additional data amount 57/201: 3624
#   Dataset size: 3684 samples
#   ✓ Completed and saved as landscape_index_56_amount_3624.npz
# Processing additional data amount 58/201: 3678
#   Dataset size: 3738 samples
#   ✓ Completed and saved as landscape_index_57_amount_3678.npz
# Processing additional data amount 59/201: 3732
#   Dataset size: 3792 samples
#   ✓ Completed and saved as landscape_index_58_amount_3732.npz
# Processing additional data amount 60/201: 3786
#   Dataset size: 3846 samples
#   ✓ Completed and saved as landscape_index_59_amount_3786.npz
# Processing additional data amount 61/201: 3840
#   Dataset size: 3900 samples
#   ✓ Completed and saved as landscape_index_60_amount_3840.npz
# Processing additional data amount 62/201: 3894
#   Dataset size: 3954 samples
#   ✓ Completed and saved as landscape_index_61_amount_3894.npz
# Processing additional data amount 63/201: 3948
#   Dataset size: 4008 samples
#   ✓ Completed and saved as landscape_index_62_amount_3948.npz
# Processing additional data amount 64/201: 4002
#   Dataset size: 4062 samples
#   ✓ Completed and saved as landscape_index_63_amount_4002.npz
# Processing additional data amount 65/201: 4056
#   Dataset size: 4116 samples
#   ✓ Completed and saved as landscape_index_64_amount_4056.npz
# Processing additional data amount 66/201: 4110
#   Dataset size: 4170 samples
#   ✓ Completed and saved as landscape_index_65_amount_4110.npz
# Processing additional data amount 67/201: 4164
#   Dataset size: 4224 samples
#   ✓ Completed and saved as landscape_index_66_amount_4164.npz
# Processing additional data amount 68/201: 4218
#   Dataset size: 4278 samples
#   ✓ Completed and saved as landscape_index_67_amount_4218.npz
# Processing additional data amount 69/201: 4272
#   Dataset size: 4332 samples
#   ✓ Completed and saved as landscape_index_68_amount_4272.npz
# Processing additional data amount 70/201: 4326
#   Dataset size: 4386 samples
#   ✓ Completed and saved as landscape_index_69_amount_4326.npz
# Processing additional data amount 71/201: 4380
#   Dataset size: 4440 samples
#   ✓ Completed and saved as landscape_index_70_amount_4380.npz
# Processing additional data amount 72/201: 4434
#   Dataset size: 4494 samples
#   ✓ Completed and saved as landscape_index_71_amount_4434.npz
# Processing additional data amount 73/201: 4488
#   Dataset size: 4548 samples
#   ✓ Completed and saved as landscape_index_72_amount_4488.npz
# Processing additional data amount 74/201: 4542
#   Dataset size: 4602 samples
#   ✓ Completed and saved as landscape_index_73_amount_4542.npz
# Processing additional data amount 75/201: 4596
#   Dataset size: 4656 samples
#   ✓ Completed and saved as landscape_index_74_amount_4596.npz
# Processing additional data amount 76/201: 4650
#   Dataset size: 4710 samples
#   ✓ Completed and saved as landscape_index_75_amount_4650.npz
# Processing additional data amount 77/201: 4704
#   Dataset size: 4764 samples
#   ✓ Completed and saved as landscape_index_76_amount_4704.npz
# Processing additional data amount 78/201: 4758
#   Dataset size: 4818 samples
#   ✓ Completed and saved as landscape_index_77_amount_4758.npz
# Processing additional data amount 79/201: 4812
#   Dataset size: 4872 samples
#   ✓ Completed and saved as landscape_index_78_amount_4812.npz
# Processing additional data amount 80/201: 4866
#   Dataset size: 4926 samples
#   ✓ Completed and saved as landscape_index_79_amount_4866.npz
# Processing additional data amount 81/201: 4920
#   Dataset size: 4980 samples
#   ✓ Completed and saved as landscape_index_80_amount_4920.npz
# Processing additional data amount 82/201: 4974
#   Dataset size: 5034 samples
#   ✓ Completed and saved as landscape_index_81_amount_4974.npz
# Processing additional data amount 83/201: 5028
#   Dataset size: 5088 samples
#   ✓ Completed and saved as landscape_index_82_amount_5028.npz
# Processing additional data amount 84/201: 5082
#   Dataset size: 5142 samples
#   ✓ Completed and saved as landscape_index_83_amount_5082.npz
# Processing additional data amount 85/201: 5136
#   Dataset size: 5196 samples
#   ✓ Completed and saved as landscape_index_84_amount_5136.npz
# Processing additional data amount 86/201: 5190
#   Dataset size: 5250 samples
#   ✓ Completed and saved as landscape_index_85_amount_5190.npz
# Processing additional data amount 87/201: 5244
#   Dataset size: 5304 samples
#   ✓ Completed and saved as landscape_index_86_amount_5244.npz
# Processing additional data amount 88/201: 5298
#   Dataset size: 5358 samples
#   ✓ Completed and saved as landscape_index_87_amount_5298.npz
# Processing additional data amount 89/201: 5352
#   Dataset size: 5412 samples
#   ✓ Completed and saved as landscape_index_88_amount_5352.npz
# Processing additional data amount 90/201: 5406
#   Dataset size: 5466 samples
#   ✓ Completed and saved as landscape_index_89_amount_5406.npz
# Processing additional data amount 91/201: 5460
#   Dataset size: 5520 samples
#   ✓ Completed and saved as landscape_index_90_amount_5460.npz
# Processing additional data amount 92/201: 5514
#   Dataset size: 5574 samples
#   ✓ Completed and saved as landscape_index_91_amount_5514.npz
# Processing additional data amount 93/201: 5568
#   Dataset size: 5628 samples
#   ✓ Completed and saved as landscape_index_92_amount_5568.npz
# Processing additional data amount 94/201: 5622
#   Dataset size: 5682 samples
#   ✓ Completed and saved as landscape_index_93_amount_5622.npz
# Processing additional data amount 95/201: 5676
#   Dataset size: 5736 samples
#   ✓ Completed and saved as landscape_index_94_amount_5676.npz
# Processing additional data amount 96/201: 5730
#   Dataset size: 5790 samples
#   ✓ Completed and saved as landscape_index_95_amount_5730.npz
# Processing additional data amount 97/201: 5784
#   Dataset size: 5844 samples
#   ✓ Completed and saved as landscape_index_96_amount_5784.npz
# Processing additional data amount 98/201: 5838
#   Dataset size: 5898 samples
#   ✓ Completed and saved as landscape_index_97_amount_5838.npz
# Processing additional data amount 99/201: 5892
#   Dataset size: 5952 samples
#   ✓ Completed and saved as landscape_index_98_amount_5892.npz
# Processing additional data amount 100/201: 5946
#   Dataset size: 6006 samples
#   ✓ Completed and saved as landscape_index_99_amount_5946.npz
# Processing additional data amount 101/201: 6000
#   Dataset size: 6060 samples
#   ✓ Completed and saved as landscape_index_100_amount_6000.npz
# Processing additional data amount 102/201: 6540
#   Dataset size: 6600 samples
#   ✓ Completed and saved as landscape_index_101_amount_6540.npz
# Processing additional data amount 103/201: 7080
#   Dataset size: 7140 samples
#   ✓ Completed and saved as landscape_index_102_amount_7080.npz
# Processing additional data amount 104/201: 7620
#   Dataset size: 7680 samples
#   ✓ Completed and saved as landscape_index_103_amount_7620.npz
# Processing additional data amount 105/201: 8160
#   Dataset size: 8220 samples
#   ✓ Completed and saved as landscape_index_104_amount_8160.npz
# Processing additional data amount 106/201: 8700
#   Dataset size: 8760 samples
#   ✓ Completed and saved as landscape_index_105_amount_8700.npz
# Processing additional data amount 107/201: 9240
#   Dataset size: 9300 samples
#   ✓ Completed and saved as landscape_index_106_amount_9240.npz
# Processing additional data amount 108/201: 9780
#   Dataset size: 9840 samples
#   ✓ Completed and saved as landscape_index_107_amount_9780.npz
# Processing additional data amount 109/201: 10320
#   Dataset size: 10380 samples
#   ✓ Completed and saved as landscape_index_108_amount_10320.npz
# Processing additional data amount 110/201: 10860
#   Dataset size: 10920 samples
#   ✓ Completed and saved as landscape_index_109_amount_10860.npz
# Processing additional data amount 111/201: 11400
#   Dataset size: 11460 samples
#   ✓ Completed and saved as landscape_index_110_amount_11400.npz
# Processing additional data amount 112/201: 11940
#   Dataset size: 12000 samples
#   ✓ Completed and saved as landscape_index_111_amount_11940.npz
# Processing additional data amount 113/201: 12480
#   Dataset size: 12540 samples
#   ✓ Completed and saved as landscape_index_112_amount_12480.npz
# Processing additional data amount 114/201: 13020
#   Dataset size: 13080 samples
#   ✓ Completed and saved as landscape_index_113_amount_13020.npz
# Processing additional data amount 115/201: 13560
#   Dataset size: 13620 samples
#   ✓ Completed and saved as landscape_index_114_amount_13560.npz
# Processing additional data amount 116/201: 14100
#   Dataset size: 14160 samples
#   ✓ Completed and saved as landscape_index_115_amount_14100.npz
# Processing additional data amount 117/201: 14640
#   Dataset size: 14700 samples
#   ✓ Completed and saved as landscape_index_116_amount_14640.npz
# Processing additional data amount 118/201: 15180
#   Dataset size: 15240 samples
#   ✓ Completed and saved as landscape_index_117_amount_15180.npz
# Processing additional data amount 119/201: 15720
#   Dataset size: 15780 samples
#   ✓ Completed and saved as landscape_index_118_amount_15720.npz
# Processing additional data amount 120/201: 16260
#   Dataset size: 16320 samples
#   ✓ Completed and saved as landscape_index_119_amount_16260.npz
# Processing additional data amount 121/201: 16800
#   Dataset size: 16860 samples
#   ✓ Completed and saved as landscape_index_120_amount_16800.npz
# Processing additional data amount 122/201: 17340
#   Dataset size: 17400 samples
#   ✓ Completed and saved as landscape_index_121_amount_17340.npz
# Processing additional data amount 123/201: 17880
#   Dataset size: 17940 samples
#   ✓ Completed and saved as landscape_index_122_amount_17880.npz
# Processing additional data amount 124/201: 18420
#   Dataset size: 18480 samples
#   ✓ Completed and saved as landscape_index_123_amount_18420.npz
# Processing additional data amount 125/201: 18960
#   Dataset size: 19020 samples
#   ✓ Completed and saved as landscape_index_124_amount_18960.npz
# Processing additional data amount 126/201: 19500
#   Dataset size: 19560 samples
#   ✓ Completed and saved as landscape_index_125_amount_19500.npz
# Processing additional data amount 127/201: 20040
#   Dataset size: 20100 samples
#   ✓ Completed and saved as landscape_index_126_amount_20040.npz
# Processing additional data amount 128/201: 20580
#   Dataset size: 20640 samples
#   ✓ Completed and saved as landscape_index_127_amount_20580.npz
# Processing additional data amount 129/201: 21120
#   Dataset size: 21180 samples
#   ✓ Completed and saved as landscape_index_128_amount_21120.npz
# Processing additional data amount 130/201: 21660
#   Dataset size: 21720 samples
#   ✓ Completed and saved as landscape_index_129_amount_21660.npz
# Processing additional data amount 131/201: 22200
#   Dataset size: 22260 samples
#   ✓ Completed and saved as landscape_index_130_amount_22200.npz
# Processing additional data amount 132/201: 22740
#   Dataset size: 22800 samples
#   ✓ Completed and saved as landscape_index_131_amount_22740.npz
# Processing additional data amount 133/201: 23280
#   Dataset size: 23340 samples
#   ✓ Completed and saved as landscape_index_132_amount_23280.npz
# Processing additional data amount 134/201: 23820
#   Dataset size: 23880 samples
#   ✓ Completed and saved as landscape_index_133_amount_23820.npz
# Processing additional data amount 135/201: 24360
#   Dataset size: 24420 samples
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Compute all loss landscapes
# ----> 2 loss_grids_list = compute_loss_landscapes_varying_data(
#       3     model_0=model_0,
#       4     model_1=model_1,
#       5     model_2=model_2,
#       6     grid_coefficients=grid_coefficients,
#       7     x_base=x_base_train,
#       8     y_base=y_base_train,
#       9     x_additional=x_additional,
#      10     y_additional=y_additional,
#      11     additional_data_amounts=additional_data_amounts,
#      12     loss_fn=loss_fn,
#      13     output_dir=varying_dataset_dir,
#      14     base_filename="landscape"
#      15 )
#      17 print(f"✓ Completed all {len(loss_grids_list)} loss landscapes")
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\landscape_videos.py:174, in compute_loss_landscapes_varying_data(model_0, model_1, model_2, grid_coefficients, x_base, y_base, x_additional, y_additional, additional_data_amounts, loss_fn, output_dir, base_filename)
#     171 filename = f"{base_filename}_index_{i}_amount_{additional_data}.npz"
#     173 # Generate loss landscape
# --> 174 loss_grid, _, _ = loss_landscape_2d(
#     175     model=model_0,
#     176     points=x_landscape,
#     177     labels=y_landscape,
#     178     loss_fn=loss_fn,
#     179     perturbation_vectors=perturbation_vectors,
#     180     grid_coefficients=grid_coefficients,
#     181     output_dir=output_dir,
#     182     filename=filename
#     183 )
#     185 loss_grids.append(loss_grid)
#     186 print(f"  ✓ Completed and saved as {filename}")
#
# File L:\Programming\ARC\minima_volume_project\minima_volume\perturb_funcs.py:751, in loss_landscape_2d(model, points, labels, loss_fn, perturbation_vectors, grid_coefficients, output_dir, filename)
#     749 # Compute loss
#     750 with torch.no_grad():
# --> 751     logits = model(points)
#     752     loss = loss_fn(logits, labels)
#     753     loss_grid[i,j] = loss.item()
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File L:\Programming\ARC\minima_volume_project\videos\MNIST Logarithmic Video\MNIST_model_data.py:84, in MNIST_MLP.forward(self, x)
#      82 def forward(self, x):
#      83     x = torch.flatten(x, 1)
# ---> 84     return self.model(x)
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File L:\Programming\diffusion-env\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
