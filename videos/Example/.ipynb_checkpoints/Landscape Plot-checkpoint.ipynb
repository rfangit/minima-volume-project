# %% [markdown]
# # Model Analysis
#
# This program takes in a folder name with datasets and models, and in that folder generates a series of images and videos describing how the loss landscape changes over time.

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

import time
import glob

# Importing our existing funcs
import os
import sys
from pathlib import Path

from minima_volume.dataset_funcs import ( load_models_and_data )

from minima_volume.landscape_videos import (
    plot_2d_loss_landscape_3model,
    plot_3d_loss_landscape,
    load_computed_loss_landscapes,
)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Model

# %%
# User specifies the model module name
import swiss_model_data as model_module

model_seed = 0 # filler for the template

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn_per_sample = model_module.get_loss_fn_per_sample()

# %% [markdown]
# ## Loading Model and Datasets

# %%
# Get the relative path
target_dir = Path("models_and_data") #current directory

# Lists to store loaded models and additional data
loaded_models, loaded_additional_data, loaded_dataset = load_models_and_data(model_template=model_template, target_dir=target_dir, device="cpu")

# Print dataset information
print(f"Dataset type: {loaded_dataset['dataset_type']}")
print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")

# Print tensor shapes
print("\nTensor shapes:")
for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
    if loaded_dataset[key] is not None:
        print(f"  {key}: {loaded_dataset[key].shape}")
    else:
        print(f"  {key}: None")
# Out:
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_additional_0.pt
#   - model_additional_180.pt
#   - model_additional_30.pt
#   - model_additional_380.pt
#   - model_additional_780.pt
#   - model_additional_80.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_0.pt
# Successfully loaded: model_additional_0.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_180.pt
# Successfully loaded: model_additional_180.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_30.pt
# Successfully loaded: model_additional_30.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_380.pt
# Successfully loaded: model_additional_380.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_780.pt
# Successfully loaded: model_additional_780.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_80.pt
# Successfully loaded: model_additional_80.pt
#
# Model data loaded from all models:
# Model 0 (model_additional_0.pt):
#   - Additional data: 0
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 1 (model_additional_180.pt):
#   - Additional data: 180
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 2 (model_additional_30.pt):
#   - Additional data: 30
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 3 (model_additional_380.pt):
#   - Additional data: 380
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 4 (model_additional_780.pt):
#   - Additional data: 780
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 5 (model_additional_80.pt):
#   - Additional data: 80
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
#
# Loading dataset...
# Using dataset file: dataset.pt
# ✅ Dataset loaded from models_and_data\dataset.pt
# Dataset type: data
# Dataset quantities: [0, 30, 80, 180, 380, 780]
#
# Tensor shapes:
#   x_base_train: torch.Size([20, 2])
#   y_base_train: torch.Size([20])
#   x_additional: torch.Size([780, 2])
#   y_additional: torch.Size([780])
#   x_test: torch.Size([4000, 2])
#   y_test: torch.Size([4000])

# %% [markdown]
# ## Plotting Parameters
#
# Determines what models to use.

# %%
index1 = 0
index2 = 1
index3 = 4
index_list = [index1, index2, index3]

print(
    f"Loading models trained with: "
    f"{loaded_additional_data[index1]['additional_data']}, "
    f"{loaded_additional_data[index2]['additional_data']}, "
    f"{loaded_additional_data[index3]['additional_data']}"
)

model_0 = loaded_models[index1]
model_1 = loaded_models[index2]
model_2 = loaded_models[index3]

print("=== Selected Models ===")
dataset_type = loaded_dataset['dataset_type']
model_labels = [
    f"Model Trained with {loaded_additional_data[index1]['additional_data']} {dataset_type}",
    f"Model Trained with {loaded_additional_data[index2]['additional_data']} {dataset_type}",
    f"Model Trained with {loaded_additional_data[index3]['additional_data']} {dataset_type}"
]

# Prepare dataset with additional_data = 0 (base dataset only)
x_base_train = loaded_dataset['x_base_train']
y_base_train = loaded_dataset['y_base_train']
x_additional = loaded_dataset['x_additional']
y_additional = loaded_dataset['y_additional']
# Out:
# Loading models trained with: 0, 180, 780
# === Selected Models ===

# %% [markdown]
# ## Loss Landscape Parameters
#
# Loss landscapes have been computed, here's parameters to help plot.

# %%
# Create storage directory
varying_dataset_dir = Path("varying_dataset")
varying_dataset_dir.mkdir(exist_ok=True)

# Define the additional data amounts to test
# This can be varied depending on the use case!!
additional_data_amounts = range(len(x_additional)+1)

# Create grid
N = 80
span_low, span_high = -0.5, 1.5
x = np.linspace(span_low, span_high, N)
y = np.linspace(span_low, span_high, N)
C1_grid, C2_grid = np.meshgrid(x, y)
grid_coefficients = (C1_grid, C2_grid)

print(f"Grid size: {N}x{N}, Range: [{span_low}, {span_high}]")
# Out:
# Grid size: 80x80, Range: [-0.5, 1.5]

# %% [markdown]
# ## Visualization
#
# Load from folder and then visualize.

# %%
# Load specific indexes
loss_grids_list, C1_grid, C2_grid = load_computed_loss_landscapes(
    output_dir=varying_dataset_dir,
    indexes_to_load=range(len(additional_data_amounts))
)
# Out:
# ✓ Loaded index 0: landscape_index_0_amount_0.npz
# ✓ Loaded index 1: landscape_index_1_amount_1.npz
# ✓ Loaded index 2: landscape_index_2_amount_2.npz
# ✓ Loaded index 3: landscape_index_3_amount_3.npz
# ✓ Loaded index 4: landscape_index_4_amount_4.npz
# ✓ Loaded index 5: landscape_index_5_amount_5.npz
# ✓ Loaded index 6: landscape_index_6_amount_6.npz
# ✓ Loaded index 7: landscape_index_7_amount_7.npz
# ✓ Loaded index 8: landscape_index_8_amount_8.npz
# ✓ Loaded index 9: landscape_index_9_amount_9.npz
# ✓ Loaded index 10: landscape_index_10_amount_10.npz
# ✓ Loaded index 11: landscape_index_11_amount_11.npz
# ✓ Loaded index 12: landscape_index_12_amount_12.npz
# ✓ Loaded index 13: landscape_index_13_amount_13.npz
# ✓ Loaded index 14: landscape_index_14_amount_14.npz
# ✓ Loaded index 15: landscape_index_15_amount_15.npz
# ✓ Loaded index 16: landscape_index_16_amount_16.npz
# ✓ Loaded index 17: landscape_index_17_amount_17.npz
# ✓ Loaded index 18: landscape_index_18_amount_18.npz
# ✓ Loaded index 19: landscape_index_19_amount_19.npz
# ✓ Loaded index 20: landscape_index_20_amount_20.npz
# ✓ Loaded index 21: landscape_index_21_amount_21.npz
# ✓ Loaded index 22: landscape_index_22_amount_22.npz
# ✓ Loaded index 23: landscape_index_23_amount_23.npz
# ✓ Loaded index 24: landscape_index_24_amount_24.npz
# ✓ Loaded index 25: landscape_index_25_amount_25.npz
# ✓ Loaded index 26: landscape_index_26_amount_26.npz
# ✓ Loaded index 27: landscape_index_27_amount_27.npz
# ✓ Loaded index 28: landscape_index_28_amount_28.npz
# ✓ Loaded index 29: landscape_index_29_amount_29.npz
# ✓ Loaded index 30: landscape_index_30_amount_30.npz
# ✓ Loaded index 31: landscape_index_31_amount_31.npz
# ✓ Loaded index 32: landscape_index_32_amount_32.npz
# ✓ Loaded index 33: landscape_index_33_amount_33.npz
# ✓ Loaded index 34: landscape_index_34_amount_34.npz
# ✓ Loaded index 35: landscape_index_35_amount_35.npz
# ✓ Loaded index 36: landscape_index_36_amount_36.npz
# ✓ Loaded index 37: landscape_index_37_amount_37.npz
# ✓ Loaded index 38: landscape_index_38_amount_38.npz
# ✓ Loaded index 39: landscape_index_39_amount_39.npz
# ✓ Loaded index 40: landscape_index_40_amount_40.npz
# ✓ Loaded index 41: landscape_index_41_amount_41.npz
# ✓ Loaded index 42: landscape_index_42_amount_42.npz
# ✓ Loaded index 43: landscape_index_43_amount_43.npz
# ✓ Loaded index 44: landscape_index_44_amount_44.npz
# ✓ Loaded index 45: landscape_index_45_amount_45.npz
# ✓ Loaded index 46: landscape_index_46_amount_46.npz
# ✓ Loaded index 47: landscape_index_47_amount_47.npz
# ✓ Loaded index 48: landscape_index_48_amount_48.npz
# ✓ Loaded index 49: landscape_index_49_amount_49.npz
# ✓ Loaded index 50: landscape_index_50_amount_50.npz
# ✓ Loaded index 51: landscape_index_51_amount_51.npz
# ✓ Loaded index 52: landscape_index_52_amount_52.npz
# ✓ Loaded index 53: landscape_index_53_amount_53.npz
# ✓ Loaded index 54: landscape_index_54_amount_54.npz
# ✓ Loaded index 55: landscape_index_55_amount_55.npz
# ✓ Loaded index 56: landscape_index_56_amount_56.npz
# ✓ Loaded index 57: landscape_index_57_amount_57.npz
# ✓ Loaded index 58: landscape_index_58_amount_58.npz
# ✓ Loaded index 59: landscape_index_59_amount_59.npz
# ✓ Loaded index 60: landscape_index_60_amount_60.npz
# ✓ Loaded index 61: landscape_index_61_amount_61.npz
# ✓ Loaded index 62: landscape_index_62_amount_62.npz
# ✓ Loaded index 63: landscape_index_63_amount_63.npz
# ✓ Loaded index 64: landscape_index_64_amount_64.npz
# ✓ Loaded index 65: landscape_index_65_amount_65.npz
# ✓ Loaded index 66: landscape_index_66_amount_66.npz
# ✓ Loaded index 67: landscape_index_67_amount_67.npz
# ✓ Loaded index 68: landscape_index_68_amount_68.npz
# ✓ Loaded index 69: landscape_index_69_amount_69.npz
# ✓ Loaded index 70: landscape_index_70_amount_70.npz
# ✓ Loaded index 71: landscape_index_71_amount_71.npz
# ✓ Loaded index 72: landscape_index_72_amount_72.npz
# ✓ Loaded index 73: landscape_index_73_amount_73.npz
# ✓ Loaded index 74: landscape_index_74_amount_74.npz
# ✓ Loaded index 75: landscape_index_75_amount_75.npz
# ✓ Loaded index 76: landscape_index_76_amount_76.npz
# ✓ Loaded index 77: landscape_index_77_amount_77.npz
# ✓ Loaded index 78: landscape_index_78_amount_78.npz
# ✓ Loaded index 79: landscape_index_79_amount_79.npz
# ✓ Loaded index 80: landscape_index_80_amount_80.npz
# ✓ Loaded index 81: landscape_index_81_amount_81.npz
# ✓ Loaded index 82: landscape_index_82_amount_82.npz
# ✓ Loaded index 83: landscape_index_83_amount_83.npz
# ✓ Loaded index 84: landscape_index_84_amount_84.npz
# ✓ Loaded index 85: landscape_index_85_amount_85.npz
# ✓ Loaded index 86: landscape_index_86_amount_86.npz
# ✓ Loaded index 87: landscape_index_87_amount_87.npz
# ✓ Loaded index 88: landscape_index_88_amount_88.npz
# ✓ Loaded index 89: landscape_index_89_amount_89.npz
# ✓ Loaded index 90: landscape_index_90_amount_90.npz
# ✓ Loaded index 91: landscape_index_91_amount_91.npz
# ✓ Loaded index 92: landscape_index_92_amount_92.npz
# ✓ Loaded index 93: landscape_index_93_amount_93.npz
# ✓ Loaded index 94: landscape_index_94_amount_94.npz
# ✓ Loaded index 95: landscape_index_95_amount_95.npz
# ✓ Loaded index 96: landscape_index_96_amount_96.npz
# ✓ Loaded index 97: landscape_index_97_amount_97.npz
# ✓ Loaded index 98: landscape_index_98_amount_98.npz
# ✓ Loaded index 99: landscape_index_99_amount_99.npz
# ✓ Loaded index 100: landscape_index_100_amount_100.npz
# ✓ Loaded index 101: landscape_index_101_amount_101.npz
# ✓ Loaded index 102: landscape_index_102_amount_102.npz
# ✓ Loaded index 103: landscape_index_103_amount_103.npz
# ✓ Loaded index 104: landscape_index_104_amount_104.npz
# ✓ Loaded index 105: landscape_index_105_amount_105.npz
# ✓ Loaded index 106: landscape_index_106_amount_106.npz
# ✓ Loaded index 107: landscape_index_107_amount_107.npz
# ✓ Loaded index 108: landscape_index_108_amount_108.npz
# ✓ Loaded index 109: landscape_index_109_amount_109.npz
# ✓ Loaded index 110: landscape_index_110_amount_110.npz
# ✓ Loaded index 111: landscape_index_111_amount_111.npz
# ✓ Loaded index 112: landscape_index_112_amount_112.npz
# ✓ Loaded index 113: landscape_index_113_amount_113.npz
# ✓ Loaded index 114: landscape_index_114_amount_114.npz
# ✓ Loaded index 115: landscape_index_115_amount_115.npz
# ✓ Loaded index 116: landscape_index_116_amount_116.npz
# ✓ Loaded index 117: landscape_index_117_amount_117.npz
# ✓ Loaded index 118: landscape_index_118_amount_118.npz
# ✓ Loaded index 119: landscape_index_119_amount_119.npz
# ✓ Loaded index 120: landscape_index_120_amount_120.npz
# ✓ Loaded index 121: landscape_index_121_amount_121.npz
# ✓ Loaded index 122: landscape_index_122_amount_122.npz
# ✓ Loaded index 123: landscape_index_123_amount_123.npz
# ✓ Loaded index 124: landscape_index_124_amount_124.npz
# ✓ Loaded index 125: landscape_index_125_amount_125.npz
# ✓ Loaded index 126: landscape_index_126_amount_126.npz
# ✓ Loaded index 127: landscape_index_127_amount_127.npz
# ✓ Loaded index 128: landscape_index_128_amount_128.npz
# ✓ Loaded index 129: landscape_index_129_amount_129.npz
# ✓ Loaded index 130: landscape_index_130_amount_130.npz
# ✓ Loaded index 131: landscape_index_131_amount_131.npz
# ✓ Loaded index 132: landscape_index_132_amount_132.npz
# ✓ Loaded index 133: landscape_index_133_amount_133.npz
# ✓ Loaded index 134: landscape_index_134_amount_134.npz
# ✓ Loaded index 135: landscape_index_135_amount_135.npz
# ✓ Loaded index 136: landscape_index_136_amount_136.npz
# ✓ Loaded index 137: landscape_index_137_amount_137.npz
# ✓ Loaded index 138: landscape_index_138_amount_138.npz
# ✓ Loaded index 139: landscape_index_139_amount_139.npz
# ✓ Loaded index 140: landscape_index_140_amount_140.npz
# ✓ Loaded index 141: landscape_index_141_amount_141.npz
# ✓ Loaded index 142: landscape_index_142_amount_142.npz
# ✓ Loaded index 143: landscape_index_143_amount_143.npz
# ✓ Loaded index 144: landscape_index_144_amount_144.npz
# ✓ Loaded index 145: landscape_index_145_amount_145.npz
# ✓ Loaded index 146: landscape_index_146_amount_146.npz
# ✓ Loaded index 147: landscape_index_147_amount_147.npz
# ✓ Loaded index 148: landscape_index_148_amount_148.npz
# ✓ Loaded index 149: landscape_index_149_amount_149.npz
# ✓ Loaded index 150: landscape_index_150_amount_150.npz
# ✓ Loaded index 151: landscape_index_151_amount_151.npz
# ✓ Loaded index 152: landscape_index_152_amount_152.npz
# ✓ Loaded index 153: landscape_index_153_amount_153.npz
# ✓ Loaded index 154: landscape_index_154_amount_154.npz
# ✓ Loaded index 155: landscape_index_155_amount_155.npz
# ✓ Loaded index 156: landscape_index_156_amount_156.npz
# ✓ Loaded index 157: landscape_index_157_amount_157.npz
# ✓ Loaded index 158: landscape_index_158_amount_158.npz
# ✓ Loaded index 159: landscape_index_159_amount_159.npz
# ✓ Loaded index 160: landscape_index_160_amount_160.npz
# ✓ Loaded index 161: landscape_index_161_amount_161.npz
# ✓ Loaded index 162: landscape_index_162_amount_162.npz
# ✓ Loaded index 163: landscape_index_163_amount_163.npz
# ✓ Loaded index 164: landscape_index_164_amount_164.npz
# ✓ Loaded index 165: landscape_index_165_amount_165.npz
# ✓ Loaded index 166: landscape_index_166_amount_166.npz
# ✓ Loaded index 167: landscape_index_167_amount_167.npz
# ✓ Loaded index 168: landscape_index_168_amount_168.npz
# ✓ Loaded index 169: landscape_index_169_amount_169.npz
# ✓ Loaded index 170: landscape_index_170_amount_170.npz
# ✓ Loaded index 171: landscape_index_171_amount_171.npz
# ✓ Loaded index 172: landscape_index_172_amount_172.npz
# ✓ Loaded index 173: landscape_index_173_amount_173.npz
# ✓ Loaded index 174: landscape_index_174_amount_174.npz
# ✓ Loaded index 175: landscape_index_175_amount_175.npz
# ✓ Loaded index 176: landscape_index_176_amount_176.npz
# ✓ Loaded index 177: landscape_index_177_amount_177.npz
# ✓ Loaded index 178: landscape_index_178_amount_178.npz
# ✓ Loaded index 179: landscape_index_179_amount_179.npz
# ✓ Loaded index 180: landscape_index_180_amount_180.npz
# ✓ Loaded index 181: landscape_index_181_amount_181.npz
# ✓ Loaded index 182: landscape_index_182_amount_182.npz
# ✓ Loaded index 183: landscape_index_183_amount_183.npz
# ✓ Loaded index 184: landscape_index_184_amount_184.npz
# ✓ Loaded index 185: landscape_index_185_amount_185.npz
# ✓ Loaded index 186: landscape_index_186_amount_186.npz
# ✓ Loaded index 187: landscape_index_187_amount_187.npz
# ✓ Loaded index 188: landscape_index_188_amount_188.npz
# ✓ Loaded index 189: landscape_index_189_amount_189.npz
# ✓ Loaded index 190: landscape_index_190_amount_190.npz
# ✓ Loaded index 191: landscape_index_191_amount_191.npz
# ✓ Loaded index 192: landscape_index_192_amount_192.npz
# ✓ Loaded index 193: landscape_index_193_amount_193.npz
# ✓ Loaded index 194: landscape_index_194_amount_194.npz
# ✓ Loaded index 195: landscape_index_195_amount_195.npz
# ✓ Loaded index 196: landscape_index_196_amount_196.npz
# ✓ Loaded index 197: landscape_index_197_amount_197.npz
# ✓ Loaded index 198: landscape_index_198_amount_198.npz
# ✓ Loaded index 199: landscape_index_199_amount_199.npz
# ✓ Loaded index 200: landscape_index_200_amount_200.npz
# ✓ Loaded index 201: landscape_index_201_amount_201.npz
# ✓ Loaded index 202: landscape_index_202_amount_202.npz
# ✓ Loaded index 203: landscape_index_203_amount_203.npz
# ✓ Loaded index 204: landscape_index_204_amount_204.npz
# ✓ Loaded index 205: landscape_index_205_amount_205.npz
# ✓ Loaded index 206: landscape_index_206_amount_206.npz
# ✓ Loaded index 207: landscape_index_207_amount_207.npz
# ✓ Loaded index 208: landscape_index_208_amount_208.npz
# ✓ Loaded index 209: landscape_index_209_amount_209.npz
# ✓ Loaded index 210: landscape_index_210_amount_210.npz
# ✓ Loaded index 211: landscape_index_211_amount_211.npz
# ✓ Loaded index 212: landscape_index_212_amount_212.npz
# ✓ Loaded index 213: landscape_index_213_amount_213.npz
# ✓ Loaded index 214: landscape_index_214_amount_214.npz
# ✓ Loaded index 215: landscape_index_215_amount_215.npz
# ✓ Loaded index 216: landscape_index_216_amount_216.npz
# ✓ Loaded index 217: landscape_index_217_amount_217.npz
# ✓ Loaded index 218: landscape_index_218_amount_218.npz
# ✓ Loaded index 219: landscape_index_219_amount_219.npz
# ✓ Loaded index 220: landscape_index_220_amount_220.npz
# ✓ Loaded index 221: landscape_index_221_amount_221.npz
# ✓ Loaded index 222: landscape_index_222_amount_222.npz
# ✓ Loaded index 223: landscape_index_223_amount_223.npz
# ✓ Loaded index 224: landscape_index_224_amount_224.npz
# ✓ Loaded index 225: landscape_index_225_amount_225.npz
# ✓ Loaded index 226: landscape_index_226_amount_226.npz
# ✓ Loaded index 227: landscape_index_227_amount_227.npz
# ✓ Loaded index 228: landscape_index_228_amount_228.npz
# ✓ Loaded index 229: landscape_index_229_amount_229.npz
# ✓ Loaded index 230: landscape_index_230_amount_230.npz
# ✓ Loaded index 231: landscape_index_231_amount_231.npz
# ✓ Loaded index 232: landscape_index_232_amount_232.npz
# ✓ Loaded index 233: landscape_index_233_amount_233.npz
# ✓ Loaded index 234: landscape_index_234_amount_234.npz
# ✓ Loaded index 235: landscape_index_235_amount_235.npz
# ✓ Loaded index 236: landscape_index_236_amount_236.npz
# ✓ Loaded index 237: landscape_index_237_amount_237.npz
# ✓ Loaded index 238: landscape_index_238_amount_238.npz
# ✓ Loaded index 239: landscape_index_239_amount_239.npz
# ✓ Loaded index 240: landscape_index_240_amount_240.npz
# ✓ Loaded index 241: landscape_index_241_amount_241.npz
# ✓ Loaded index 242: landscape_index_242_amount_242.npz
# ✓ Loaded index 243: landscape_index_243_amount_243.npz
# ✓ Loaded index 244: landscape_index_244_amount_244.npz
# ✓ Loaded index 245: landscape_index_245_amount_245.npz
# ✓ Loaded index 246: landscape_index_246_amount_246.npz
# ✓ Loaded index 247: landscape_index_247_amount_247.npz
# ✓ Loaded index 248: landscape_index_248_amount_248.npz
# ✓ Loaded index 249: landscape_index_249_amount_249.npz
# ✓ Loaded index 250: landscape_index_250_amount_250.npz
# ✓ Loaded index 251: landscape_index_251_amount_251.npz
# ✓ Loaded index 252: landscape_index_252_amount_252.npz
# ✓ Loaded index 253: landscape_index_253_amount_253.npz
# ✓ Loaded index 254: landscape_index_254_amount_254.npz
# ✓ Loaded index 255: landscape_index_255_amount_255.npz
# ✓ Loaded index 256: landscape_index_256_amount_256.npz
# ✓ Loaded index 257: landscape_index_257_amount_257.npz
# ✓ Loaded index 258: landscape_index_258_amount_258.npz
# ✓ Loaded index 259: landscape_index_259_amount_259.npz
# ✓ Loaded index 260: landscape_index_260_amount_260.npz
# ✓ Loaded index 261: landscape_index_261_amount_261.npz
# ✓ Loaded index 262: landscape_index_262_amount_262.npz
# ✓ Loaded index 263: landscape_index_263_amount_263.npz
# ✓ Loaded index 264: landscape_index_264_amount_264.npz
# ✓ Loaded index 265: landscape_index_265_amount_265.npz
# ✓ Loaded index 266: landscape_index_266_amount_266.npz
# ✓ Loaded index 267: landscape_index_267_amount_267.npz
# ✓ Loaded index 268: landscape_index_268_amount_268.npz
# ✓ Loaded index 269: landscape_index_269_amount_269.npz
# ✓ Loaded index 270: landscape_index_270_amount_270.npz
# ✓ Loaded index 271: landscape_index_271_amount_271.npz
# ✓ Loaded index 272: landscape_index_272_amount_272.npz
# ✓ Loaded index 273: landscape_index_273_amount_273.npz
# ✓ Loaded index 274: landscape_index_274_amount_274.npz
# ✓ Loaded index 275: landscape_index_275_amount_275.npz
# ✓ Loaded index 276: landscape_index_276_amount_276.npz
# ✓ Loaded index 277: landscape_index_277_amount_277.npz
# ✓ Loaded index 278: landscape_index_278_amount_278.npz
# ✓ Loaded index 279: landscape_index_279_amount_279.npz
# ✓ Loaded index 280: landscape_index_280_amount_280.npz
# ✓ Loaded index 281: landscape_index_281_amount_281.npz
# ✓ Loaded index 282: landscape_index_282_amount_282.npz
# ✓ Loaded index 283: landscape_index_283_amount_283.npz
# ✓ Loaded index 284: landscape_index_284_amount_284.npz
# ✓ Loaded index 285: landscape_index_285_amount_285.npz
# ✓ Loaded index 286: landscape_index_286_amount_286.npz
# ✓ Loaded index 287: landscape_index_287_amount_287.npz
# ✓ Loaded index 288: landscape_index_288_amount_288.npz
# ✓ Loaded index 289: landscape_index_289_amount_289.npz
# ✓ Loaded index 290: landscape_index_290_amount_290.npz
# ✓ Loaded index 291: landscape_index_291_amount_291.npz
# ✓ Loaded index 292: landscape_index_292_amount_292.npz
# ✓ Loaded index 293: landscape_index_293_amount_293.npz
# ✓ Loaded index 294: landscape_index_294_amount_294.npz
# ✓ Loaded index 295: landscape_index_295_amount_295.npz
# ✓ Loaded index 296: landscape_index_296_amount_296.npz
# ✓ Loaded index 297: landscape_index_297_amount_297.npz
# ✓ Loaded index 298: landscape_index_298_amount_298.npz
# ✓ Loaded index 299: landscape_index_299_amount_299.npz
# ✓ Loaded index 300: landscape_index_300_amount_300.npz
# ✓ Loaded index 301: landscape_index_301_amount_301.npz
# ✓ Loaded index 302: landscape_index_302_amount_302.npz
# ✓ Loaded index 303: landscape_index_303_amount_303.npz
# ✓ Loaded index 304: landscape_index_304_amount_304.npz
# ✓ Loaded index 305: landscape_index_305_amount_305.npz
# ✓ Loaded index 306: landscape_index_306_amount_306.npz
# ✓ Loaded index 307: landscape_index_307_amount_307.npz
# ✓ Loaded index 308: landscape_index_308_amount_308.npz
# ✓ Loaded index 309: landscape_index_309_amount_309.npz
# ✓ Loaded index 310: landscape_index_310_amount_310.npz
# ✓ Loaded index 311: landscape_index_311_amount_311.npz
# ✓ Loaded index 312: landscape_index_312_amount_312.npz
# ✓ Loaded index 313: landscape_index_313_amount_313.npz
# ✓ Loaded index 314: landscape_index_314_amount_314.npz
# ✓ Loaded index 315: landscape_index_315_amount_315.npz
# ✓ Loaded index 316: landscape_index_316_amount_316.npz
# ✓ Loaded index 317: landscape_index_317_amount_317.npz
# ✓ Loaded index 318: landscape_index_318_amount_318.npz
# ✓ Loaded index 319: landscape_index_319_amount_319.npz
# ✓ Loaded index 320: landscape_index_320_amount_320.npz
# ✓ Loaded index 321: landscape_index_321_amount_321.npz
# ✓ Loaded index 322: landscape_index_322_amount_322.npz
# ✓ Loaded index 323: landscape_index_323_amount_323.npz
# ✓ Loaded index 324: landscape_index_324_amount_324.npz
# ✓ Loaded index 325: landscape_index_325_amount_325.npz
# ✓ Loaded index 326: landscape_index_326_amount_326.npz
# ✓ Loaded index 327: landscape_index_327_amount_327.npz
# ✓ Loaded index 328: landscape_index_328_amount_328.npz
# ✓ Loaded index 329: landscape_index_329_amount_329.npz
# ✓ Loaded index 330: landscape_index_330_amount_330.npz
# ✓ Loaded index 331: landscape_index_331_amount_331.npz
# ✓ Loaded index 332: landscape_index_332_amount_332.npz
# ✓ Loaded index 333: landscape_index_333_amount_333.npz
# ✓ Loaded index 334: landscape_index_334_amount_334.npz
# ✓ Loaded index 335: landscape_index_335_amount_335.npz
# ✓ Loaded index 336: landscape_index_336_amount_336.npz
# ✓ Loaded index 337: landscape_index_337_amount_337.npz
# ✓ Loaded index 338: landscape_index_338_amount_338.npz
# ✓ Loaded index 339: landscape_index_339_amount_339.npz
# ✓ Loaded index 340: landscape_index_340_amount_340.npz
# ✓ Loaded index 341: landscape_index_341_amount_341.npz
# ✓ Loaded index 342: landscape_index_342_amount_342.npz
# ✓ Loaded index 343: landscape_index_343_amount_343.npz
# ✓ Loaded index 344: landscape_index_344_amount_344.npz
# ✓ Loaded index 345: landscape_index_345_amount_345.npz
# ✓ Loaded index 346: landscape_index_346_amount_346.npz
# ✓ Loaded index 347: landscape_index_347_amount_347.npz
# ✓ Loaded index 348: landscape_index_348_amount_348.npz
# ✓ Loaded index 349: landscape_index_349_amount_349.npz
# ✓ Loaded index 350: landscape_index_350_amount_350.npz
# ✓ Loaded index 351: landscape_index_351_amount_351.npz
# ✓ Loaded index 352: landscape_index_352_amount_352.npz
# ✓ Loaded index 353: landscape_index_353_amount_353.npz
# ✓ Loaded index 354: landscape_index_354_amount_354.npz
# ✓ Loaded index 355: landscape_index_355_amount_355.npz
# ✓ Loaded index 356: landscape_index_356_amount_356.npz
# ✓ Loaded index 357: landscape_index_357_amount_357.npz
# ✓ Loaded index 358: landscape_index_358_amount_358.npz
# ✓ Loaded index 359: landscape_index_359_amount_359.npz
# ✓ Loaded index 360: landscape_index_360_amount_360.npz
# ✓ Loaded index 361: landscape_index_361_amount_361.npz
# ✓ Loaded index 362: landscape_index_362_amount_362.npz
# ✓ Loaded index 363: landscape_index_363_amount_363.npz
# ✓ Loaded index 364: landscape_index_364_amount_364.npz
# ✓ Loaded index 365: landscape_index_365_amount_365.npz
# ✓ Loaded index 366: landscape_index_366_amount_366.npz
# ✓ Loaded index 367: landscape_index_367_amount_367.npz
# ✓ Loaded index 368: landscape_index_368_amount_368.npz
# ✓ Loaded index 369: landscape_index_369_amount_369.npz
# ✓ Loaded index 370: landscape_index_370_amount_370.npz
# ✓ Loaded index 371: landscape_index_371_amount_371.npz
# ✓ Loaded index 372: landscape_index_372_amount_372.npz
# ✓ Loaded index 373: landscape_index_373_amount_373.npz
# ✓ Loaded index 374: landscape_index_374_amount_374.npz
# ✓ Loaded index 375: landscape_index_375_amount_375.npz
# ✓ Loaded index 376: landscape_index_376_amount_376.npz
# ✓ Loaded index 377: landscape_index_377_amount_377.npz
# ✓ Loaded index 378: landscape_index_378_amount_378.npz
# ✓ Loaded index 379: landscape_index_379_amount_379.npz
# ✓ Loaded index 380: landscape_index_380_amount_380.npz
# ✓ Loaded index 381: landscape_index_381_amount_381.npz
# ✓ Loaded index 382: landscape_index_382_amount_382.npz
# ✓ Loaded index 383: landscape_index_383_amount_383.npz
# ✓ Loaded index 384: landscape_index_384_amount_384.npz
# ✓ Loaded index 385: landscape_index_385_amount_385.npz
# ✓ Loaded index 386: landscape_index_386_amount_386.npz
# ✓ Loaded index 387: landscape_index_387_amount_387.npz
# ✓ Loaded index 388: landscape_index_388_amount_388.npz
# ✓ Loaded index 389: landscape_index_389_amount_389.npz
# ✓ Loaded index 390: landscape_index_390_amount_390.npz
# ✓ Loaded index 391: landscape_index_391_amount_391.npz
# ✓ Loaded index 392: landscape_index_392_amount_392.npz
# ✓ Loaded index 393: landscape_index_393_amount_393.npz
# ✓ Loaded index 394: landscape_index_394_amount_394.npz
# ✓ Loaded index 395: landscape_index_395_amount_395.npz
# ✓ Loaded index 396: landscape_index_396_amount_396.npz
# ✓ Loaded index 397: landscape_index_397_amount_397.npz
# ✓ Loaded index 398: landscape_index_398_amount_398.npz
# ✓ Loaded index 399: landscape_index_399_amount_399.npz
# ✓ Loaded index 400: landscape_index_400_amount_400.npz
# ✓ Loaded index 401: landscape_index_401_amount_401.npz
# ✓ Loaded index 402: landscape_index_402_amount_402.npz
# ✓ Loaded index 403: landscape_index_403_amount_403.npz
# ✓ Loaded index 404: landscape_index_404_amount_404.npz
# ✓ Loaded index 405: landscape_index_405_amount_405.npz
# ✓ Loaded index 406: landscape_index_406_amount_406.npz
# ✓ Loaded index 407: landscape_index_407_amount_407.npz
# ✓ Loaded index 408: landscape_index_408_amount_408.npz
# ✓ Loaded index 409: landscape_index_409_amount_409.npz
# ✓ Loaded index 410: landscape_index_410_amount_410.npz
# ✓ Loaded index 411: landscape_index_411_amount_411.npz
# ✓ Loaded index 412: landscape_index_412_amount_412.npz
# ✓ Loaded index 413: landscape_index_413_amount_413.npz
# ✓ Loaded index 414: landscape_index_414_amount_414.npz
# ✓ Loaded index 415: landscape_index_415_amount_415.npz
# ✓ Loaded index 416: landscape_index_416_amount_416.npz
# ✓ Loaded index 417: landscape_index_417_amount_417.npz
# ✓ Loaded index 418: landscape_index_418_amount_418.npz
# ✓ Loaded index 419: landscape_index_419_amount_419.npz
# ✓ Loaded index 420: landscape_index_420_amount_420.npz
# ✓ Loaded index 421: landscape_index_421_amount_421.npz
# ✓ Loaded index 422: landscape_index_422_amount_422.npz
# ✓ Loaded index 423: landscape_index_423_amount_423.npz
# ✓ Loaded index 424: landscape_index_424_amount_424.npz
# ✓ Loaded index 425: landscape_index_425_amount_425.npz
# ✓ Loaded index 426: landscape_index_426_amount_426.npz
# ✓ Loaded index 427: landscape_index_427_amount_427.npz
# ✓ Loaded index 428: landscape_index_428_amount_428.npz
# ✓ Loaded index 429: landscape_index_429_amount_429.npz
# ✓ Loaded index 430: landscape_index_430_amount_430.npz
# ✓ Loaded index 431: landscape_index_431_amount_431.npz
# ✓ Loaded index 432: landscape_index_432_amount_432.npz
# ✓ Loaded index 433: landscape_index_433_amount_433.npz
# ✓ Loaded index 434: landscape_index_434_amount_434.npz
# ✓ Loaded index 435: landscape_index_435_amount_435.npz
# ✓ Loaded index 436: landscape_index_436_amount_436.npz
# ✓ Loaded index 437: landscape_index_437_amount_437.npz
# ✓ Loaded index 438: landscape_index_438_amount_438.npz
# ✓ Loaded index 439: landscape_index_439_amount_439.npz
# ✓ Loaded index 440: landscape_index_440_amount_440.npz
# ✓ Loaded index 441: landscape_index_441_amount_441.npz
# ✓ Loaded index 442: landscape_index_442_amount_442.npz
# ✓ Loaded index 443: landscape_index_443_amount_443.npz
# ✓ Loaded index 444: landscape_index_444_amount_444.npz
# ✓ Loaded index 445: landscape_index_445_amount_445.npz
# ✓ Loaded index 446: landscape_index_446_amount_446.npz
# ✓ Loaded index 447: landscape_index_447_amount_447.npz
# ✓ Loaded index 448: landscape_index_448_amount_448.npz
# ✓ Loaded index 449: landscape_index_449_amount_449.npz
# ✓ Loaded index 450: landscape_index_450_amount_450.npz
# ✓ Loaded index 451: landscape_index_451_amount_451.npz
# ✓ Loaded index 452: landscape_index_452_amount_452.npz
# ✓ Loaded index 453: landscape_index_453_amount_453.npz
# ✓ Loaded index 454: landscape_index_454_amount_454.npz
# ✓ Loaded index 455: landscape_index_455_amount_455.npz
# ✓ Loaded index 456: landscape_index_456_amount_456.npz
# ✓ Loaded index 457: landscape_index_457_amount_457.npz
# ✓ Loaded index 458: landscape_index_458_amount_458.npz
# ✓ Loaded index 459: landscape_index_459_amount_459.npz
# ✓ Loaded index 460: landscape_index_460_amount_460.npz
# ✓ Loaded index 461: landscape_index_461_amount_461.npz
# ✓ Loaded index 462: landscape_index_462_amount_462.npz
# ✓ Loaded index 463: landscape_index_463_amount_463.npz
# ✓ Loaded index 464: landscape_index_464_amount_464.npz
# ✓ Loaded index 465: landscape_index_465_amount_465.npz
# ✓ Loaded index 466: landscape_index_466_amount_466.npz
# ✓ Loaded index 467: landscape_index_467_amount_467.npz
# ✓ Loaded index 468: landscape_index_468_amount_468.npz
# ✓ Loaded index 469: landscape_index_469_amount_469.npz
# ✓ Loaded index 470: landscape_index_470_amount_470.npz
# ✓ Loaded index 471: landscape_index_471_amount_471.npz
# ✓ Loaded index 472: landscape_index_472_amount_472.npz
# ✓ Loaded index 473: landscape_index_473_amount_473.npz
# ✓ Loaded index 474: landscape_index_474_amount_474.npz
# ✓ Loaded index 475: landscape_index_475_amount_475.npz
# ✓ Loaded index 476: landscape_index_476_amount_476.npz
# ✓ Loaded index 477: landscape_index_477_amount_477.npz
# ✓ Loaded index 478: landscape_index_478_amount_478.npz
# ✓ Loaded index 479: landscape_index_479_amount_479.npz
# ✓ Loaded index 480: landscape_index_480_amount_480.npz
# ✓ Loaded index 481: landscape_index_481_amount_481.npz
# ✓ Loaded index 482: landscape_index_482_amount_482.npz
# ✓ Loaded index 483: landscape_index_483_amount_483.npz
# ✓ Loaded index 484: landscape_index_484_amount_484.npz
# ✓ Loaded index 485: landscape_index_485_amount_485.npz
# ✓ Loaded index 486: landscape_index_486_amount_486.npz
# ✓ Loaded index 487: landscape_index_487_amount_487.npz
# ✓ Loaded index 488: landscape_index_488_amount_488.npz
# ✓ Loaded index 489: landscape_index_489_amount_489.npz
# ✓ Loaded index 490: landscape_index_490_amount_490.npz
# ✓ Loaded index 491: landscape_index_491_amount_491.npz
# ✓ Loaded index 492: landscape_index_492_amount_492.npz
# ✓ Loaded index 493: landscape_index_493_amount_493.npz
# ✓ Loaded index 494: landscape_index_494_amount_494.npz
# ✓ Loaded index 495: landscape_index_495_amount_495.npz
# ✓ Loaded index 496: landscape_index_496_amount_496.npz
# ✓ Loaded index 497: landscape_index_497_amount_497.npz
# ✓ Loaded index 498: landscape_index_498_amount_498.npz
# ✓ Loaded index 499: landscape_index_499_amount_499.npz
# ✓ Loaded index 500: landscape_index_500_amount_500.npz
# ✓ Loaded index 501: landscape_index_501_amount_501.npz
# ✓ Loaded index 502: landscape_index_502_amount_502.npz
# ✓ Loaded index 503: landscape_index_503_amount_503.npz
# ✓ Loaded index 504: landscape_index_504_amount_504.npz
# ✓ Loaded index 505: landscape_index_505_amount_505.npz
# ✓ Loaded index 506: landscape_index_506_amount_506.npz
# ✓ Loaded index 507: landscape_index_507_amount_507.npz
# ✓ Loaded index 508: landscape_index_508_amount_508.npz
# ✓ Loaded index 509: landscape_index_509_amount_509.npz
# ✓ Loaded index 510: landscape_index_510_amount_510.npz
# ✓ Loaded index 511: landscape_index_511_amount_511.npz
# ✓ Loaded index 512: landscape_index_512_amount_512.npz
# ✓ Loaded index 513: landscape_index_513_amount_513.npz
# ✓ Loaded index 514: landscape_index_514_amount_514.npz
# ✓ Loaded index 515: landscape_index_515_amount_515.npz
# ✓ Loaded index 516: landscape_index_516_amount_516.npz
# ✓ Loaded index 517: landscape_index_517_amount_517.npz
# ✓ Loaded index 518: landscape_index_518_amount_518.npz
# ✓ Loaded index 519: landscape_index_519_amount_519.npz
# ✓ Loaded index 520: landscape_index_520_amount_520.npz
# ✓ Loaded index 521: landscape_index_521_amount_521.npz
# ✓ Loaded index 522: landscape_index_522_amount_522.npz
# ✓ Loaded index 523: landscape_index_523_amount_523.npz
# ✓ Loaded index 524: landscape_index_524_amount_524.npz
# ✓ Loaded index 525: landscape_index_525_amount_525.npz
# ✓ Loaded index 526: landscape_index_526_amount_526.npz
# ✓ Loaded index 527: landscape_index_527_amount_527.npz
# ✓ Loaded index 528: landscape_index_528_amount_528.npz
# ✓ Loaded index 529: landscape_index_529_amount_529.npz
# ✓ Loaded index 530: landscape_index_530_amount_530.npz
# ✓ Loaded index 531: landscape_index_531_amount_531.npz
# ✓ Loaded index 532: landscape_index_532_amount_532.npz
# ✓ Loaded index 533: landscape_index_533_amount_533.npz
# ✓ Loaded index 534: landscape_index_534_amount_534.npz
# ✓ Loaded index 535: landscape_index_535_amount_535.npz
# ✓ Loaded index 536: landscape_index_536_amount_536.npz
# ✓ Loaded index 537: landscape_index_537_amount_537.npz
# ✓ Loaded index 538: landscape_index_538_amount_538.npz
# ✓ Loaded index 539: landscape_index_539_amount_539.npz
# ✓ Loaded index 540: landscape_index_540_amount_540.npz
# ✓ Loaded index 541: landscape_index_541_amount_541.npz
# ✓ Loaded index 542: landscape_index_542_amount_542.npz
# ✓ Loaded index 543: landscape_index_543_amount_543.npz
# ✓ Loaded index 544: landscape_index_544_amount_544.npz
# ✓ Loaded index 545: landscape_index_545_amount_545.npz
# ✓ Loaded index 546: landscape_index_546_amount_546.npz
# ✓ Loaded index 547: landscape_index_547_amount_547.npz
# ✓ Loaded index 548: landscape_index_548_amount_548.npz
# ✓ Loaded index 549: landscape_index_549_amount_549.npz
# ✓ Loaded index 550: landscape_index_550_amount_550.npz
# ✓ Loaded index 551: landscape_index_551_amount_551.npz
# ✓ Loaded index 552: landscape_index_552_amount_552.npz
# ✓ Loaded index 553: landscape_index_553_amount_553.npz
# ✓ Loaded index 554: landscape_index_554_amount_554.npz
# ✓ Loaded index 555: landscape_index_555_amount_555.npz
# ✓ Loaded index 556: landscape_index_556_amount_556.npz
# ✓ Loaded index 557: landscape_index_557_amount_557.npz
# ✓ Loaded index 558: landscape_index_558_amount_558.npz
# ✓ Loaded index 559: landscape_index_559_amount_559.npz
# ✓ Loaded index 560: landscape_index_560_amount_560.npz
# ✓ Loaded index 561: landscape_index_561_amount_561.npz
# ✓ Loaded index 562: landscape_index_562_amount_562.npz
# ✓ Loaded index 563: landscape_index_563_amount_563.npz
# ✓ Loaded index 564: landscape_index_564_amount_564.npz
# ✓ Loaded index 565: landscape_index_565_amount_565.npz
# ✓ Loaded index 566: landscape_index_566_amount_566.npz
# ✓ Loaded index 567: landscape_index_567_amount_567.npz
# ✓ Loaded index 568: landscape_index_568_amount_568.npz
# ✓ Loaded index 569: landscape_index_569_amount_569.npz
# ✓ Loaded index 570: landscape_index_570_amount_570.npz
# ✓ Loaded index 571: landscape_index_571_amount_571.npz
# ✓ Loaded index 572: landscape_index_572_amount_572.npz
# ✓ Loaded index 573: landscape_index_573_amount_573.npz
# ✓ Loaded index 574: landscape_index_574_amount_574.npz
# ✓ Loaded index 575: landscape_index_575_amount_575.npz
# ✓ Loaded index 576: landscape_index_576_amount_576.npz
# ✓ Loaded index 577: landscape_index_577_amount_577.npz
# ✓ Loaded index 578: landscape_index_578_amount_578.npz
# ✓ Loaded index 579: landscape_index_579_amount_579.npz
# ✓ Loaded index 580: landscape_index_580_amount_580.npz
# ✓ Loaded index 581: landscape_index_581_amount_581.npz
# ✓ Loaded index 582: landscape_index_582_amount_582.npz
# ✓ Loaded index 583: landscape_index_583_amount_583.npz
# ✓ Loaded index 584: landscape_index_584_amount_584.npz
# ✓ Loaded index 585: landscape_index_585_amount_585.npz
# ✓ Loaded index 586: landscape_index_586_amount_586.npz
# ✓ Loaded index 587: landscape_index_587_amount_587.npz
# ✓ Loaded index 588: landscape_index_588_amount_588.npz
# ✓ Loaded index 589: landscape_index_589_amount_589.npz
# ✓ Loaded index 590: landscape_index_590_amount_590.npz
# ✓ Loaded index 591: landscape_index_591_amount_591.npz
# ✓ Loaded index 592: landscape_index_592_amount_592.npz
# ✓ Loaded index 593: landscape_index_593_amount_593.npz
# ✓ Loaded index 594: landscape_index_594_amount_594.npz
# ✓ Loaded index 595: landscape_index_595_amount_595.npz
# ✓ Loaded index 596: landscape_index_596_amount_596.npz
# ✓ Loaded index 597: landscape_index_597_amount_597.npz
# ✓ Loaded index 598: landscape_index_598_amount_598.npz
# ✓ Loaded index 599: landscape_index_599_amount_599.npz
# ✓ Loaded index 600: landscape_index_600_amount_600.npz
# ✓ Loaded index 601: landscape_index_601_amount_601.npz
# ✓ Loaded index 602: landscape_index_602_amount_602.npz
# ✓ Loaded index 603: landscape_index_603_amount_603.npz
# ✓ Loaded index 604: landscape_index_604_amount_604.npz
# ✓ Loaded index 605: landscape_index_605_amount_605.npz
# ✓ Loaded index 606: landscape_index_606_amount_606.npz
# ✓ Loaded index 607: landscape_index_607_amount_607.npz
# ✓ Loaded index 608: landscape_index_608_amount_608.npz
# ✓ Loaded index 609: landscape_index_609_amount_609.npz
# ✓ Loaded index 610: landscape_index_610_amount_610.npz
# ✓ Loaded index 611: landscape_index_611_amount_611.npz
# ✓ Loaded index 612: landscape_index_612_amount_612.npz
# ✓ Loaded index 613: landscape_index_613_amount_613.npz
# ✓ Loaded index 614: landscape_index_614_amount_614.npz
# ✓ Loaded index 615: landscape_index_615_amount_615.npz
# ✓ Loaded index 616: landscape_index_616_amount_616.npz
# ✓ Loaded index 617: landscape_index_617_amount_617.npz
# ✓ Loaded index 618: landscape_index_618_amount_618.npz
# ✓ Loaded index 619: landscape_index_619_amount_619.npz
# ✓ Loaded index 620: landscape_index_620_amount_620.npz
# ✓ Loaded index 621: landscape_index_621_amount_621.npz
# ✓ Loaded index 622: landscape_index_622_amount_622.npz
# ✓ Loaded index 623: landscape_index_623_amount_623.npz
# ✓ Loaded index 624: landscape_index_624_amount_624.npz
# ✓ Loaded index 625: landscape_index_625_amount_625.npz
# ✓ Loaded index 626: landscape_index_626_amount_626.npz
# ✓ Loaded index 627: landscape_index_627_amount_627.npz
# ✓ Loaded index 628: landscape_index_628_amount_628.npz
# ✓ Loaded index 629: landscape_index_629_amount_629.npz
# ✓ Loaded index 630: landscape_index_630_amount_630.npz
# ✓ Loaded index 631: landscape_index_631_amount_631.npz
# ✓ Loaded index 632: landscape_index_632_amount_632.npz
# ✓ Loaded index 633: landscape_index_633_amount_633.npz
# ✓ Loaded index 634: landscape_index_634_amount_634.npz
# ✓ Loaded index 635: landscape_index_635_amount_635.npz
# ✓ Loaded index 636: landscape_index_636_amount_636.npz
# ✓ Loaded index 637: landscape_index_637_amount_637.npz
# ✓ Loaded index 638: landscape_index_638_amount_638.npz
# ✓ Loaded index 639: landscape_index_639_amount_639.npz
# ✓ Loaded index 640: landscape_index_640_amount_640.npz
# ✓ Loaded index 641: landscape_index_641_amount_641.npz
# ✓ Loaded index 642: landscape_index_642_amount_642.npz
# ✓ Loaded index 643: landscape_index_643_amount_643.npz
# ✓ Loaded index 644: landscape_index_644_amount_644.npz
# ✓ Loaded index 645: landscape_index_645_amount_645.npz
# ✓ Loaded index 646: landscape_index_646_amount_646.npz
# ✓ Loaded index 647: landscape_index_647_amount_647.npz
# ✓ Loaded index 648: landscape_index_648_amount_648.npz
# ✓ Loaded index 649: landscape_index_649_amount_649.npz
# ✓ Loaded index 650: landscape_index_650_amount_650.npz
# ✓ Loaded index 651: landscape_index_651_amount_651.npz
# ✓ Loaded index 652: landscape_index_652_amount_652.npz
# ✓ Loaded index 653: landscape_index_653_amount_653.npz
# ✓ Loaded index 654: landscape_index_654_amount_654.npz
# ✓ Loaded index 655: landscape_index_655_amount_655.npz
# ✓ Loaded index 656: landscape_index_656_amount_656.npz
# ✓ Loaded index 657: landscape_index_657_amount_657.npz
# ✓ Loaded index 658: landscape_index_658_amount_658.npz
# ✓ Loaded index 659: landscape_index_659_amount_659.npz
# ✓ Loaded index 660: landscape_index_660_amount_660.npz
# ✓ Loaded index 661: landscape_index_661_amount_661.npz
# ✓ Loaded index 662: landscape_index_662_amount_662.npz
# ✓ Loaded index 663: landscape_index_663_amount_663.npz
# ✓ Loaded index 664: landscape_index_664_amount_664.npz
# ✓ Loaded index 665: landscape_index_665_amount_665.npz
# ✓ Loaded index 666: landscape_index_666_amount_666.npz
# ✓ Loaded index 667: landscape_index_667_amount_667.npz
# ✓ Loaded index 668: landscape_index_668_amount_668.npz
# ✓ Loaded index 669: landscape_index_669_amount_669.npz
# ✓ Loaded index 670: landscape_index_670_amount_670.npz
# ✓ Loaded index 671: landscape_index_671_amount_671.npz
# ✓ Loaded index 672: landscape_index_672_amount_672.npz
# ✓ Loaded index 673: landscape_index_673_amount_673.npz
# ✓ Loaded index 674: landscape_index_674_amount_674.npz
# ✓ Loaded index 675: landscape_index_675_amount_675.npz
# ✓ Loaded index 676: landscape_index_676_amount_676.npz
# ✓ Loaded index 677: landscape_index_677_amount_677.npz
# ✓ Loaded index 678: landscape_index_678_amount_678.npz
# ✓ Loaded index 679: landscape_index_679_amount_679.npz
# ✓ Loaded index 680: landscape_index_680_amount_680.npz
# ✓ Loaded index 681: landscape_index_681_amount_681.npz
# ✓ Loaded index 682: landscape_index_682_amount_682.npz
# ✓ Loaded index 683: landscape_index_683_amount_683.npz
# ✓ Loaded index 684: landscape_index_684_amount_684.npz
# ✓ Loaded index 685: landscape_index_685_amount_685.npz
# ✓ Loaded index 686: landscape_index_686_amount_686.npz
# ✓ Loaded index 687: landscape_index_687_amount_687.npz
# ✓ Loaded index 688: landscape_index_688_amount_688.npz
# ✓ Loaded index 689: landscape_index_689_amount_689.npz
# ✓ Loaded index 690: landscape_index_690_amount_690.npz
# ✓ Loaded index 691: landscape_index_691_amount_691.npz
# ✓ Loaded index 692: landscape_index_692_amount_692.npz
# ✓ Loaded index 693: landscape_index_693_amount_693.npz
# ✓ Loaded index 694: landscape_index_694_amount_694.npz
# ✓ Loaded index 695: landscape_index_695_amount_695.npz
# ✓ Loaded index 696: landscape_index_696_amount_696.npz
# ✓ Loaded index 697: landscape_index_697_amount_697.npz
# ✓ Loaded index 698: landscape_index_698_amount_698.npz
# ✓ Loaded index 699: landscape_index_699_amount_699.npz
# ✓ Loaded index 700: landscape_index_700_amount_700.npz
# ✓ Loaded index 701: landscape_index_701_amount_701.npz
# ✓ Loaded index 702: landscape_index_702_amount_702.npz
# ✓ Loaded index 703: landscape_index_703_amount_703.npz
# ✓ Loaded index 704: landscape_index_704_amount_704.npz
# ✓ Loaded index 705: landscape_index_705_amount_705.npz
# ✓ Loaded index 706: landscape_index_706_amount_706.npz
# ✓ Loaded index 707: landscape_index_707_amount_707.npz
# ✓ Loaded index 708: landscape_index_708_amount_708.npz
# ✓ Loaded index 709: landscape_index_709_amount_709.npz
# ✓ Loaded index 710: landscape_index_710_amount_710.npz
# ✓ Loaded index 711: landscape_index_711_amount_711.npz
# ✓ Loaded index 712: landscape_index_712_amount_712.npz
# ✓ Loaded index 713: landscape_index_713_amount_713.npz
# ✓ Loaded index 714: landscape_index_714_amount_714.npz
# ✓ Loaded index 715: landscape_index_715_amount_715.npz
# ✓ Loaded index 716: landscape_index_716_amount_716.npz
# ✓ Loaded index 717: landscape_index_717_amount_717.npz
# ✓ Loaded index 718: landscape_index_718_amount_718.npz
# ✓ Loaded index 719: landscape_index_719_amount_719.npz
# ✓ Loaded index 720: landscape_index_720_amount_720.npz
# ✓ Loaded index 721: landscape_index_721_amount_721.npz
# ✓ Loaded index 722: landscape_index_722_amount_722.npz
# ✓ Loaded index 723: landscape_index_723_amount_723.npz
# ✓ Loaded index 724: landscape_index_724_amount_724.npz
# ✓ Loaded index 725: landscape_index_725_amount_725.npz
# ✓ Loaded index 726: landscape_index_726_amount_726.npz
# ✓ Loaded index 727: landscape_index_727_amount_727.npz
# ✓ Loaded index 728: landscape_index_728_amount_728.npz
# ✓ Loaded index 729: landscape_index_729_amount_729.npz
# ✓ Loaded index 730: landscape_index_730_amount_730.npz
# ✓ Loaded index 731: landscape_index_731_amount_731.npz
# ✓ Loaded index 732: landscape_index_732_amount_732.npz
# ✓ Loaded index 733: landscape_index_733_amount_733.npz
# ✓ Loaded index 734: landscape_index_734_amount_734.npz
# ✓ Loaded index 735: landscape_index_735_amount_735.npz
# ✓ Loaded index 736: landscape_index_736_amount_736.npz
# ✓ Loaded index 737: landscape_index_737_amount_737.npz
# ✓ Loaded index 738: landscape_index_738_amount_738.npz
# ✓ Loaded index 739: landscape_index_739_amount_739.npz
# ✓ Loaded index 740: landscape_index_740_amount_740.npz
# ✓ Loaded index 741: landscape_index_741_amount_741.npz
# ✓ Loaded index 742: landscape_index_742_amount_742.npz
# ✓ Loaded index 743: landscape_index_743_amount_743.npz
# ✓ Loaded index 744: landscape_index_744_amount_744.npz
# ✓ Loaded index 745: landscape_index_745_amount_745.npz
# ✓ Loaded index 746: landscape_index_746_amount_746.npz
# ✓ Loaded index 747: landscape_index_747_amount_747.npz
# ✓ Loaded index 748: landscape_index_748_amount_748.npz
# ✓ Loaded index 749: landscape_index_749_amount_749.npz
# ✓ Loaded index 750: landscape_index_750_amount_750.npz
# ✓ Loaded index 751: landscape_index_751_amount_751.npz
# ✓ Loaded index 752: landscape_index_752_amount_752.npz
# ✓ Loaded index 753: landscape_index_753_amount_753.npz
# ✓ Loaded index 754: landscape_index_754_amount_754.npz
# ✓ Loaded index 755: landscape_index_755_amount_755.npz
# ✓ Loaded index 756: landscape_index_756_amount_756.npz
# ✓ Loaded index 757: landscape_index_757_amount_757.npz
# ✓ Loaded index 758: landscape_index_758_amount_758.npz
# ✓ Loaded index 759: landscape_index_759_amount_759.npz
# ✓ Loaded index 760: landscape_index_760_amount_760.npz
# ✓ Loaded index 761: landscape_index_761_amount_761.npz
# ✓ Loaded index 762: landscape_index_762_amount_762.npz
# ✓ Loaded index 763: landscape_index_763_amount_763.npz
# ✓ Loaded index 764: landscape_index_764_amount_764.npz
# ✓ Loaded index 765: landscape_index_765_amount_765.npz
# ✓ Loaded index 766: landscape_index_766_amount_766.npz
# ✓ Loaded index 767: landscape_index_767_amount_767.npz
# ✓ Loaded index 768: landscape_index_768_amount_768.npz
# ✓ Loaded index 769: landscape_index_769_amount_769.npz
# ✓ Loaded index 770: landscape_index_770_amount_770.npz
# ✓ Loaded index 771: landscape_index_771_amount_771.npz
# ✓ Loaded index 772: landscape_index_772_amount_772.npz
# ✓ Loaded index 773: landscape_index_773_amount_773.npz
# ✓ Loaded index 774: landscape_index_774_amount_774.npz
# ✓ Loaded index 775: landscape_index_775_amount_775.npz
# ✓ Loaded index 776: landscape_index_776_amount_776.npz
# ✓ Loaded index 777: landscape_index_777_amount_777.npz
# ✓ Loaded index 778: landscape_index_778_amount_778.npz
# ✓ Loaded index 779: landscape_index_779_amount_779.npz
# ✓ Loaded index 780: landscape_index_780_amount_780.npz
# Successfully loaded 781 loss landscapes

# %%
# Create directories for different plot types
plot_dirs = {
    'dynamic_vmin': 'plots_dynamic_vmin',
    'fixed_vmin_large': 'plots_fixed_vmin_large', 
    'fixed_vmin_small': 'plots_fixed_vmin_small', 
    '3d': 'plots_3d',
}

for dir_name in plot_dirs.values():
    Path(dir_name).mkdir(parents=True, exist_ok=True)

# Find global min and max across ALL landscapes for consistent fixed scaling
global_vmin_smallest = float('inf')
global_vmin_largest = float('-inf')
all_vmax = float('-inf')

for idx in range(len(loss_grids_list)):
    if 0 <= idx < len(loss_grids_list):
        loss_grid = loss_grids_list[idx]
        current_min = loss_grid[loss_grid > 0].min()
        current_max = loss_grid.max()
        global_vmin_smallest = min(global_vmin_smallest, current_min)
        global_vmin_largest = max(global_vmin_largest, current_min)
        all_vmax = max(all_vmax, current_max)

print(f"Global min across selected landscapes (smallest value, features are indistinguishable with low variability): {global_vmin_smallest:.6f}")
print(f"Global min across selected landscapes (largest value that captures the variability in the most constant version): {global_vmin_largest:.6f}")
print(f"Global max across ALL landscapes: {all_vmax:.6f}")

# Generate all three types of plots for each index

start_time = time.time()

for idx in range(len(loss_grids_list)):
    if idx < 0 or idx >= len(loss_grids_list):
        continue
    
    additional_data = additional_data_amounts[idx]
    loss_grid = loss_grids_list[idx]
    
    print(f"\n=== Generating plots for index {idx}, additional data: {additional_data} ===")
    print(f"Local min: {loss_grid[loss_grid > 0].min():.6f}, Local max: {loss_grid.max():.6f}")
    
    # 1. 2D plot with dynamic vmin (local scaling)
    plot_2d_loss_landscape_3model(
        C1_grid=C1_grid,
        C2_grid=C2_grid,
        loss_grid=loss_grid,
        span_low=span_low,
        span_high=span_high,
        additional_data=additional_data,
        model_labels=model_labels,
        vmin=None,  # Dynamic - uses local min
        vmax=20, 
        output_path=f"{plot_dirs['dynamic_vmin']}/landscape_2d_index_{idx:03d}_amount_{additional_data}.png",
        show=False
    )
    
    # 2. 2D plot with fixed vmin (global scaling)
    plot_2d_loss_landscape_3model(
        C1_grid=C1_grid,
        C2_grid=C2_grid,
        loss_grid=loss_grid,
        span_low=span_low,
        span_high=span_high,
        additional_data=additional_data,
        model_labels=model_labels,
        vmin=global_vmin_largest,  # Fixed global min
        vmax=20, 
        output_path=f"{plot_dirs['fixed_vmin_large']}/landscape_2d_index_{idx:03d}_amount_{additional_data}.png",
        show=False
    )

    # 3. 2D plot with fixed vmin (global scaling)
    plot_2d_loss_landscape_3model(
        C1_grid=C1_grid,
        C2_grid=C2_grid,
        loss_grid=loss_grid,
        span_low=span_low,
        span_high=span_high,
        additional_data=additional_data,
        model_labels=model_labels,
        vmin=global_vmin_smallest,  # Fixed global min
        vmax=20, 
        output_path=f"{plot_dirs['fixed_vmin_small']}/landscape_2d_index_{idx:03d}_amount_{additional_data}.png",
        show=False
    )
    
    # 4. 3D plot without vmin/vmax constraints
    plot_3d_loss_landscape(
        C1_grid=C1_grid,
        C2_grid=C2_grid,
        loss_grid=loss_grid,
        span_low=span_low,
        span_high=span_high,
        additional_data=additional_data,
        model_labels=model_labels,
        output_path=f"{plot_dirs['3d']}/landscape_3d_index_{idx:03d}_amount_{additional_data}.png",
        show=False
    )

end_time = time.time()
elapsed = end_time - start_time

print(f"\n=== Total time for plotting all loss landscapes: {elapsed:.2f} seconds ({elapsed/60:.2f} minutes) ===")
print("\n✓ All plots generated successfully!")
# Out:
# Global min across selected landscapes (smallest value, features are indistinguishable with low variability): 0.000055
# Global min across selected landscapes (largest value that captures the variability in the most constant version): 0.000300
# Global max across ALL landscapes: 96.429459
#
# === Generating plots for index 0, additional data: 0 ===
# Local min: 0.000055, Local max: 94.768593
#
# === Generating plots for index 1, additional data: 1 ===
# Local min: 0.000057, Local max: 93.152565
#
# === Generating plots for index 2, additional data: 2 ===
# Local min: 0.000058, Local max: 90.697433
#
# === Generating plots for index 3, additional data: 3 ===
# Local min: 0.000064, Local max: 86.754066
#
# === Generating plots for index 4, additional data: 4 ===
# Local min: 0.000063, Local max: 84.745445
#
# === Generating plots for index 5, additional data: 5 ===
# Local min: 0.000068, Local max: 81.355621
#
# === Generating plots for index 6, additional data: 6 ===
# Local min: 0.000071, Local max: 78.533691
#
# === Generating plots for index 7, additional data: 7 ===
# Local min: 0.000070, Local max: 75.625038
#
# === Generating plots for index 8, additional data: 8 ===
# Local min: 0.000069, Local max: 72.924141
#
# === Generating plots for index 9, additional data: 9 ===
# Local min: 0.000068, Local max: 70.409515
#
# === Generating plots for index 10, additional data: 10 ===
# Local min: 0.000066, Local max: 79.012459
#
# === Generating plots for index 11, additional data: 11 ===
# Local min: 0.000064, Local max: 80.871025
#
# === Generating plots for index 12, additional data: 12 ===
# Local min: 0.000062, Local max: 82.684128
#
# === Generating plots for index 13, additional data: 13 ===
# Local min: 0.000060, Local max: 80.178551
#
# === Generating plots for index 14, additional data: 14 ===
# Local min: 0.000061, Local max: 83.413986
#
# === Generating plots for index 15, additional data: 15 ===
# Local min: 0.000062, Local max: 96.429459
#
# === Generating plots for index 16, additional data: 16 ===
# Local min: 0.000062, Local max: 93.750862
#
# === Generating plots for index 17, additional data: 17 ===
# Local min: 0.000073, Local max: 92.559273
#
# === Generating plots for index 18, additional data: 18 ===
# Local min: 0.000072, Local max: 90.123718
#
# === Generating plots for index 19, additional data: 19 ===
# Local min: 0.000076, Local max: 87.812851
#
# === Generating plots for index 20, additional data: 20 ===
# Local min: 0.000074, Local max: 86.113327
#
# === Generating plots for index 21, additional data: 21 ===
# Local min: 0.000072, Local max: 84.013008
#
# === Generating plots for index 22, additional data: 22 ===
# Local min: 0.000087, Local max: 82.012695
#
# === Generating plots for index 23, additional data: 23 ===
# Local min: 0.000090, Local max: 80.928589
#
# === Generating plots for index 24, additional data: 24 ===
# Local min: 0.000100, Local max: 79.089302
#
# === Generating plots for index 25, additional data: 25 ===
# Local min: 0.000098, Local max: 85.026672
#
# === Generating plots for index 26, additional data: 26 ===
# Local min: 0.000099, Local max: 85.841698
#
# === Generating plots for index 27, additional data: 27 ===
# Local min: 0.000100, Local max: 84.015282
#
# === Generating plots for index 28, additional data: 28 ===
# Local min: 0.000098, Local max: 82.264961
#
# === Generating plots for index 29, additional data: 29 ===
# Local min: 0.000097, Local max: 80.586082
#
# === Generating plots for index 30, additional data: 30 ===
# Local min: 0.000095, Local max: 78.974365
#
# === Generating plots for index 31, additional data: 31 ===
# Local min: 0.000094, Local max: 80.034409
#
# === Generating plots for index 32, additional data: 32 ===
# Local min: 0.000093, Local max: 78.495285
#
# === Generating plots for index 33, additional data: 33 ===
# Local min: 0.000091, Local max: 77.014244
#
# === Generating plots for index 34, additional data: 34 ===
# Local min: 0.000091, Local max: 75.588051
#
# === Generating plots for index 35, additional data: 35 ===
# Local min: 0.000105, Local max: 74.213722
#
# === Generating plots for index 36, additional data: 36 ===
# Local min: 0.000105, Local max: 73.568253
#
# === Generating plots for index 37, additional data: 37 ===
# Local min: 0.000104, Local max: 72.277580
#
# === Generating plots for index 38, additional data: 38 ===
# Local min: 0.000104, Local max: 71.031418
#
# === Generating plots for index 39, additional data: 39 ===
# Local min: 0.000113, Local max: 70.460114
#
# === Generating plots for index 40, additional data: 40 ===
# Local min: 0.000111, Local max: 69.288010
#
# === Generating plots for index 41, additional data: 41 ===
# Local min: 0.000110, Local max: 71.189354
#
# === Generating plots for index 42, additional data: 42 ===
# Local min: 0.000108, Local max: 71.176758
#
# === Generating plots for index 43, additional data: 43 ===
# Local min: 0.000107, Local max: 70.046967
#
# === Generating plots for index 44, additional data: 44 ===
# Local min: 0.000106, Local max: 68.952484
#
# === Generating plots for index 45, additional data: 45 ===
# Local min: 0.000106, Local max: 68.356194
#
# === Generating plots for index 46, additional data: 46 ===
# Local min: 0.000112, Local max: 76.147743
#
# === Generating plots for index 47, additional data: 47 ===
# Local min: 0.000111, Local max: 75.011208
#
# === Generating plots for index 48, additional data: 48 ===
# Local min: 0.000110, Local max: 74.685219
#
# === Generating plots for index 49, additional data: 49 ===
# Local min: 0.000108, Local max: 75.309303
#
# === Generating plots for index 50, additional data: 50 ===
# Local min: 0.000108, Local max: 79.445282
#
# === Generating plots for index 51, additional data: 51 ===
# Local min: 0.000106, Local max: 78.405235
#
# === Generating plots for index 52, additional data: 52 ===
# Local min: 0.000105, Local max: 78.404312
#
# === Generating plots for index 53, additional data: 53 ===
# Local min: 0.000104, Local max: 77.330276
#
# === Generating plots for index 54, additional data: 54 ===
# Local min: 0.000103, Local max: 76.285278
#
# === Generating plots for index 55, additional data: 55 ===
# Local min: 0.000106, Local max: 75.268135
#
# === Generating plots for index 56, additional data: 56 ===
# Local min: 0.000109, Local max: 74.277771
#
# === Generating plots for index 57, additional data: 57 ===
# Local min: 0.000113, Local max: 73.745781
#
# === Generating plots for index 58, additional data: 58 ===
# Local min: 0.000112, Local max: 74.984291
#
# === Generating plots for index 59, additional data: 59 ===
# Local min: 0.000111, Local max: 74.035126
#
# === Generating plots for index 60, additional data: 60 ===
# Local min: 0.000110, Local max: 73.436218
#
# === Generating plots for index 61, additional data: 61 ===
# Local min: 0.000109, Local max: 72.529602
#
# === Generating plots for index 62, additional data: 62 ===
# Local min: 0.000110, Local max: 75.548218
#
# === Generating plots for index 63, additional data: 63 ===
# Local min: 0.000108, Local max: 74.638000
#
# === Generating plots for index 64, additional data: 64 ===
# Local min: 0.000109, Local max: 73.749451
#
# === Generating plots for index 65, additional data: 65 ===
# Local min: 0.000108, Local max: 73.180893
#
# === Generating plots for index 66, additional data: 66 ===
# Local min: 0.000108, Local max: 72.329956
#
# === Generating plots for index 67, additional data: 67 ===
# Local min: 0.000107, Local max: 71.706253
#
# === Generating plots for index 68, additional data: 68 ===
# Local min: 0.000106, Local max: 70.891403
#
# === Generating plots for index 69, additional data: 69 ===
# Local min: 0.000105, Local max: 70.094872
#
# === Generating plots for index 70, additional data: 70 ===
# Local min: 0.000105, Local max: 69.953415
#
# === Generating plots for index 71, additional data: 71 ===
# Local min: 0.000118, Local max: 69.184700
#
# === Generating plots for index 72, additional data: 72 ===
# Local min: 0.000118, Local max: 68.432693
#
# === Generating plots for index 73, additional data: 73 ===
# Local min: 0.000117, Local max: 67.696854
#
# === Generating plots for index 74, additional data: 74 ===
# Local min: 0.000140, Local max: 67.125656
#
# === Generating plots for index 75, additional data: 75 ===
# Local min: 0.000166, Local max: 66.833344
#
# === Generating plots for index 76, additional data: 76 ===
# Local min: 0.000167, Local max: 66.137161
#
# === Generating plots for index 77, additional data: 77 ===
# Local min: 0.000166, Local max: 65.726883
#
# === Generating plots for index 78, additional data: 78 ===
# Local min: 0.000165, Local max: 68.080383
#
# === Generating plots for index 79, additional data: 79 ===
# Local min: 0.000185, Local max: 67.392700
#
# === Generating plots for index 80, additional data: 80 ===
# Local min: 0.000183, Local max: 66.718773
#
# === Generating plots for index 81, additional data: 81 ===
# Local min: 0.000183, Local max: 66.058189
#
# === Generating plots for index 82, additional data: 82 ===
# Local min: 0.000182, Local max: 65.690216
#
# === Generating plots for index 83, additional data: 83 ===
# Local min: 0.000181, Local max: 67.028915
#
# === Generating plots for index 84, additional data: 84 ===
# Local min: 0.000195, Local max: 66.522537
#
# === Generating plots for index 85, additional data: 85 ===
# Local min: 0.000194, Local max: 65.888985
#
# === Generating plots for index 86, additional data: 86 ===
# Local min: 0.000193, Local max: 65.267395
#
# === Generating plots for index 87, additional data: 87 ===
# Local min: 0.000192, Local max: 64.657425
#
# === Generating plots for index 88, additional data: 88 ===
# Local min: 0.000201, Local max: 64.407227
#
# === Generating plots for index 89, additional data: 89 ===
# Local min: 0.000200, Local max: 65.390465
#
# === Generating plots for index 90, additional data: 90 ===
# Local min: 0.000198, Local max: 64.796005
#
# === Generating plots for index 91, additional data: 91 ===
# Local min: 0.000197, Local max: 64.338791
#
# === Generating plots for index 92, additional data: 92 ===
# Local min: 0.000195, Local max: 64.459915
#
# === Generating plots for index 93, additional data: 93 ===
# Local min: 0.000194, Local max: 64.835846
#
# === Generating plots for index 94, additional data: 94 ===
# Local min: 0.000192, Local max: 64.267105
#
# === Generating plots for index 95, additional data: 95 ===
# Local min: 0.000192, Local max: 63.708263
#
# === Generating plots for index 96, additional data: 96 ===
# Local min: 0.000192, Local max: 63.371334
#
# === Generating plots for index 97, additional data: 97 ===
# Local min: 0.000191, Local max: 64.025604
#
# === Generating plots for index 98, additional data: 98 ===
# Local min: 0.000191, Local max: 63.483017
#
# === Generating plots for index 99, additional data: 99 ===
# Local min: 0.000190, Local max: 65.447670
#
# === Generating plots for index 100, additional data: 100 ===
# Local min: 0.000188, Local max: 64.902275
#
# === Generating plots for index 101, additional data: 101 ===
# Local min: 0.000199, Local max: 64.484253
#
# === Generating plots for index 102, additional data: 102 ===
# Local min: 0.000197, Local max: 66.319984
#
# === Generating plots for index 103, additional data: 103 ===
# Local min: 0.000196, Local max: 65.780800
#
# === Generating plots for index 104, additional data: 104 ===
# Local min: 0.000197, Local max: 66.681847
#
# === Generating plots for index 105, additional data: 105 ===
# Local min: 0.000196, Local max: 67.022461
#
# === Generating plots for index 106, additional data: 106 ===
# Local min: 0.000194, Local max: 66.683563
#
# === Generating plots for index 107, additional data: 107 ===
# Local min: 0.000193, Local max: 66.158493
#
# === Generating plots for index 108, additional data: 108 ===
# Local min: 0.000191, Local max: 66.022949
#
# === Generating plots for index 109, additional data: 109 ===
# Local min: 0.000190, Local max: 66.658134
#
# === Generating plots for index 110, additional data: 110 ===
# Local min: 0.000188, Local max: 67.519211
#
# === Generating plots for index 111, additional data: 111 ===
# Local min: 0.000196, Local max: 67.892090
#
# === Generating plots for index 112, additional data: 112 ===
# Local min: 0.000195, Local max: 68.043602
#
# === Generating plots for index 113, additional data: 113 ===
# Local min: 0.000194, Local max: 67.886909
#
# === Generating plots for index 114, additional data: 114 ===
# Local min: 0.000192, Local max: 67.380287
#
# === Generating plots for index 115, additional data: 115 ===
# Local min: 0.000194, Local max: 66.881180
#
# === Generating plots for index 116, additional data: 116 ===
# Local min: 0.000194, Local max: 69.029236
#
# === Generating plots for index 117, additional data: 117 ===
# Local min: 0.000193, Local max: 68.525375
#
# === Generating plots for index 118, additional data: 118 ===
# Local min: 0.000191, Local max: 68.028816
#
# === Generating plots for index 119, additional data: 119 ===
# Local min: 0.000190, Local max: 68.808121
#
# === Generating plots for index 120, additional data: 120 ===
# Local min: 0.000190, Local max: 68.316650
#
# === Generating plots for index 121, additional data: 121 ===
# Local min: 0.000190, Local max: 69.285187
#
# === Generating plots for index 122, additional data: 122 ===
# Local min: 0.000190, Local max: 69.086052
#
# === Generating plots for index 123, additional data: 123 ===
# Local min: 0.000189, Local max: 68.602936
#
# === Generating plots for index 124, additional data: 124 ===
# Local min: 0.000188, Local max: 68.126526
#
# === Generating plots for index 125, additional data: 125 ===
# Local min: 0.000188, Local max: 67.656685
#
# === Generating plots for index 126, additional data: 126 ===
# Local min: 0.000188, Local max: 67.193283
#
# === Generating plots for index 127, additional data: 127 ===
# Local min: 0.000186, Local max: 66.736191
#
# === Generating plots for index 128, additional data: 128 ===
# Local min: 0.000185, Local max: 66.615509
#
# === Generating plots for index 129, additional data: 129 ===
# Local min: 0.000184, Local max: 66.524040
#
# === Generating plots for index 130, additional data: 130 ===
# Local min: 0.000184, Local max: 66.080544
#
# === Generating plots for index 131, additional data: 131 ===
# Local min: 0.000184, Local max: 68.696022
#
# === Generating plots for index 132, additional data: 132 ===
# Local min: 0.000187, Local max: 68.486778
#
# === Generating plots for index 133, additional data: 133 ===
# Local min: 0.000186, Local max: 68.039154
#
# === Generating plots for index 134, additional data: 134 ===
# Local min: 0.000185, Local max: 68.823196
#
# === Generating plots for index 135, additional data: 135 ===
# Local min: 0.000184, Local max: 69.478294
#
# === Generating plots for index 136, additional data: 136 ===
# Local min: 0.000184, Local max: 72.204918
#
# === Generating plots for index 137, additional data: 137 ===
# Local min: 0.000183, Local max: 71.745018
#
# === Generating plots for index 138, additional data: 138 ===
# Local min: 0.000183, Local max: 72.401794
#
# === Generating plots for index 139, additional data: 139 ===
# Local min: 0.000182, Local max: 71.946434
#
# === Generating plots for index 140, additional data: 140 ===
# Local min: 0.000183, Local max: 71.496765
#
# === Generating plots for index 141, additional data: 141 ===
# Local min: 0.000183, Local max: 71.052689
#
# === Generating plots for index 142, additional data: 142 ===
# Local min: 0.000182, Local max: 70.614090
#
# === Generating plots for index 143, additional data: 143 ===
# Local min: 0.000181, Local max: 70.180870
#
# === Generating plots for index 144, additional data: 144 ===
# Local min: 0.000180, Local max: 69.752945
#
# === Generating plots for index 145, additional data: 145 ===
# Local min: 0.000179, Local max: 69.486931
#
# === Generating plots for index 146, additional data: 146 ===
# Local min: 0.000179, Local max: 69.975670
#
# === Generating plots for index 147, additional data: 147 ===
# Local min: 0.000178, Local max: 70.191978
#
# === Generating plots for index 148, additional data: 148 ===
# Local min: 0.000177, Local max: 70.708855
#
# === Generating plots for index 149, additional data: 149 ===
# Local min: 0.000176, Local max: 70.603897
#
# === Generating plots for index 150, additional data: 150 ===
# Local min: 0.000175, Local max: 71.586693
#
# === Generating plots for index 151, additional data: 151 ===
# Local min: 0.000174, Local max: 71.168053
#
# === Generating plots for index 152, additional data: 152 ===
# Local min: 0.000174, Local max: 70.754288
#
# === Generating plots for index 153, additional data: 153 ===
# Local min: 0.000173, Local max: 70.345299
#
# === Generating plots for index 154, additional data: 154 ===
# Local min: 0.000175, Local max: 69.941017
#
# === Generating plots for index 155, additional data: 155 ===
# Local min: 0.000175, Local max: 71.273529
#
# === Generating plots for index 156, additional data: 156 ===
# Local min: 0.000174, Local max: 70.868553
#
# === Generating plots for index 157, additional data: 157 ===
# Local min: 0.000173, Local max: 70.468163
#
# === Generating plots for index 158, additional data: 158 ===
# Local min: 0.000174, Local max: 70.072273
#
# === Generating plots for index 159, additional data: 159 ===
# Local min: 0.000173, Local max: 70.982071
#
# === Generating plots for index 160, additional data: 160 ===
# Local min: 0.000172, Local max: 70.587723
#
# === Generating plots for index 161, additional data: 161 ===
# Local min: 0.000171, Local max: 70.197739
#
# === Generating plots for index 162, additional data: 162 ===
# Local min: 0.000171, Local max: 69.812035
#
# === Generating plots for index 163, additional data: 163 ===
# Local min: 0.000170, Local max: 69.430550
#
# === Generating plots for index 164, additional data: 164 ===
# Local min: 0.000169, Local max: 69.053207
#
# === Generating plots for index 165, additional data: 165 ===
# Local min: 0.000169, Local max: 68.679947
#
# === Generating plots for index 166, additional data: 166 ===
# Local min: 0.000168, Local max: 68.310699
#
# === Generating plots for index 167, additional data: 167 ===
# Local min: 0.000167, Local max: 68.638565
#
# === Generating plots for index 168, additional data: 168 ===
# Local min: 0.000166, Local max: 68.554504
#
# === Generating plots for index 169, additional data: 169 ===
# Local min: 0.000165, Local max: 68.191780
#
# === Generating plots for index 170, additional data: 170 ===
# Local min: 0.000165, Local max: 67.832878
#
# === Generating plots for index 171, additional data: 171 ===
# Local min: 0.000164, Local max: 68.875893
#
# === Generating plots for index 172, additional data: 172 ===
# Local min: 0.000163, Local max: 68.517159
#
# === Generating plots for index 173, additional data: 173 ===
# Local min: 0.000162, Local max: 68.162148
#
# === Generating plots for index 174, additional data: 174 ===
# Local min: 0.000161, Local max: 69.113365
#
# === Generating plots for index 175, additional data: 175 ===
# Local min: 0.000161, Local max: 69.404976
#
# === Generating plots for index 176, additional data: 176 ===
# Local min: 0.000160, Local max: 70.228195
#
# === Generating plots for index 177, additional data: 177 ===
# Local min: 0.000162, Local max: 70.298599
#
# === Generating plots for index 178, additional data: 178 ===
# Local min: 0.000161, Local max: 72.378220
#
# === Generating plots for index 179, additional data: 179 ===
# Local min: 0.000160, Local max: 72.792305
#
# === Generating plots for index 180, additional data: 180 ===
# Local min: 0.000160, Local max: 72.428345
#
# === Generating plots for index 181, additional data: 181 ===
# Local min: 0.000159, Local max: 73.055641
#
# === Generating plots for index 182, additional data: 182 ===
# Local min: 0.000158, Local max: 72.693985
#
# === Generating plots for index 183, additional data: 183 ===
# Local min: 0.000158, Local max: 74.563210
#
# === Generating plots for index 184, additional data: 184 ===
# Local min: 0.000158, Local max: 74.337868
#
# === Generating plots for index 185, additional data: 185 ===
# Local min: 0.000162, Local max: 74.991920
#
# === Generating plots for index 186, additional data: 186 ===
# Local min: 0.000161, Local max: 74.627884
#
# === Generating plots for index 187, additional data: 187 ===
# Local min: 0.000161, Local max: 75.127937
#
# === Generating plots for index 188, additional data: 188 ===
# Local min: 0.000160, Local max: 74.875465
#
# === Generating plots for index 189, additional data: 189 ===
# Local min: 0.000159, Local max: 74.821922
#
# === Generating plots for index 190, additional data: 190 ===
# Local min: 0.000159, Local max: 74.465630
#
# === Generating plots for index 191, additional data: 191 ===
# Local min: 0.000159, Local max: 74.452812
#
# === Generating plots for index 192, additional data: 192 ===
# Local min: 0.000159, Local max: 74.314590
#
# === Generating plots for index 193, additional data: 193 ===
# Local min: 0.000158, Local max: 74.445229
#
# === Generating plots for index 194, additional data: 194 ===
# Local min: 0.000161, Local max: 74.097359
#
# === Generating plots for index 195, additional data: 195 ===
# Local min: 0.000160, Local max: 73.752716
#
# === Generating plots for index 196, additional data: 196 ===
# Local min: 0.000160, Local max: 74.065056
#
# === Generating plots for index 197, additional data: 197 ===
# Local min: 0.000160, Local max: 74.240074
#
# === Generating plots for index 198, additional data: 198 ===
# Local min: 0.000228, Local max: 73.899529
#
# === Generating plots for index 199, additional data: 199 ===
# Local min: 0.000227, Local max: 73.562088
#
# === Generating plots for index 200, additional data: 200 ===
# Local min: 0.000233, Local max: 73.890282
#
# === Generating plots for index 201, additional data: 201 ===
# Local min: 0.000232, Local max: 73.555931
#
# === Generating plots for index 202, additional data: 202 ===
# Local min: 0.000231, Local max: 73.644562
#
# === Generating plots for index 203, additional data: 203 ===
# Local min: 0.000230, Local max: 73.351585
#
# === Generating plots for index 204, additional data: 204 ===
# Local min: 0.000233, Local max: 73.188232
#
# === Generating plots for index 205, additional data: 205 ===
# Local min: 0.000232, Local max: 75.294518
#
# === Generating plots for index 206, additional data: 206 ===
# Local min: 0.000231, Local max: 75.099609
#
# === Generating plots for index 207, additional data: 207 ===
# Local min: 0.000230, Local max: 75.593262
#
# === Generating plots for index 208, additional data: 208 ===
# Local min: 0.000230, Local max: 75.261711
#
# === Generating plots for index 209, additional data: 209 ===
# Local min: 0.000229, Local max: 75.182823
#
# === Generating plots for index 210, additional data: 210 ===
# Local min: 0.000228, Local max: 75.052582
#
# === Generating plots for index 211, additional data: 211 ===
# Local min: 0.000227, Local max: 74.727676
#
# === Generating plots for index 212, additional data: 212 ===
# Local min: 0.000226, Local max: 74.405579
#
# === Generating plots for index 213, additional data: 213 ===
# Local min: 0.000226, Local max: 74.086243
#
# === Generating plots for index 214, additional data: 214 ===
# Local min: 0.000225, Local max: 74.588226
#
# === Generating plots for index 215, additional data: 215 ===
# Local min: 0.000224, Local max: 74.677376
#
# === Generating plots for index 216, additional data: 216 ===
# Local min: 0.000223, Local max: 74.360947
#
# === Generating plots for index 217, additional data: 217 ===
# Local min: 0.000222, Local max: 74.580910
#
# === Generating plots for index 218, additional data: 218 ===
# Local min: 0.000222, Local max: 74.267548
#
# === Generating plots for index 219, additional data: 219 ===
# Local min: 0.000221, Local max: 73.956802
#
# === Generating plots for index 220, additional data: 220 ===
# Local min: 0.000220, Local max: 73.648682
#
# === Generating plots for index 221, additional data: 221 ===
# Local min: 0.000219, Local max: 75.588821
#
# === Generating plots for index 222, additional data: 222 ===
# Local min: 0.000219, Local max: 75.876968
#
# === Generating plots for index 223, additional data: 223 ===
# Local min: 0.000218, Local max: 75.771309
#
# === Generating plots for index 224, additional data: 224 ===
# Local min: 0.000217, Local max: 75.460770
#
# === Generating plots for index 225, additional data: 225 ===
# Local min: 0.000216, Local max: 75.278358
#
# === Generating plots for index 226, additional data: 226 ===
# Local min: 0.000215, Local max: 75.799919
#
# === Generating plots for index 227, additional data: 227 ===
# Local min: 0.000220, Local max: 75.744461
#
# === Generating plots for index 228, additional data: 228 ===
# Local min: 0.000222, Local max: 75.439041
#
# === Generating plots for index 229, additional data: 229 ===
# Local min: 0.000295, Local max: 75.136078
#
# === Generating plots for index 230, additional data: 230 ===
# Local min: 0.000300, Local max: 75.086464
#
# === Generating plots for index 231, additional data: 231 ===
# Local min: 0.000299, Local max: 74.822861
#
# === Generating plots for index 232, additional data: 232 ===
# Local min: 0.000298, Local max: 74.525940
#
# === Generating plots for index 233, additional data: 233 ===
# Local min: 0.000299, Local max: 74.410210
#
# === Generating plots for index 234, additional data: 234 ===
# Local min: 0.000297, Local max: 74.495522
#
# === Generating plots for index 235, additional data: 235 ===
# Local min: 0.000296, Local max: 74.910637
#
# === Generating plots for index 236, additional data: 236 ===
# Local min: 0.000295, Local max: 75.141098
#
# === Generating plots for index 237, additional data: 237 ===
# Local min: 0.000294, Local max: 74.930145
#
# === Generating plots for index 238, additional data: 238 ===
# Local min: 0.000294, Local max: 76.302505
#
# === Generating plots for index 239, additional data: 239 ===
# Local min: 0.000293, Local max: 76.076996
#
# === Generating plots for index 240, additional data: 240 ===
# Local min: 0.000292, Local max: 75.784393
#
# === Generating plots for index 241, additional data: 241 ===
# Local min: 0.000291, Local max: 75.960876
#
# === Generating plots for index 242, additional data: 242 ===
# Local min: 0.000290, Local max: 75.670952
#
# === Generating plots for index 243, additional data: 243 ===
# Local min: 0.000290, Local max: 77.307304
#
# === Generating plots for index 244, additional data: 244 ===
# Local min: 0.000289, Local max: 77.014473
#
# === Generating plots for index 245, additional data: 245 ===
# Local min: 0.000288, Local max: 76.723846
#
# === Generating plots for index 246, additional data: 246 ===
# Local min: 0.000287, Local max: 77.125954
#
# === Generating plots for index 247, additional data: 247 ===
# Local min: 0.000286, Local max: 76.837090
#
# === Generating plots for index 248, additional data: 248 ===
# Local min: 0.000286, Local max: 76.550385
#
# === Generating plots for index 249, additional data: 249 ===
# Local min: 0.000286, Local max: 76.265816
#
# === Generating plots for index 250, additional data: 250 ===
# Local min: 0.000285, Local max: 75.983345
#
# === Generating plots for index 251, additional data: 251 ===
# Local min: 0.000284, Local max: 75.702965
#
# === Generating plots for index 252, additional data: 252 ===
# Local min: 0.000283, Local max: 75.424644
#
# === Generating plots for index 253, additional data: 253 ===
# Local min: 0.000282, Local max: 75.206215
#
# === Generating plots for index 254, additional data: 254 ===
# Local min: 0.000281, Local max: 76.137520
#
# === Generating plots for index 255, additional data: 255 ===
# Local min: 0.000280, Local max: 75.991310
#
# === Generating plots for index 256, additional data: 256 ===
# Local min: 0.000279, Local max: 75.908401
#
# === Generating plots for index 257, additional data: 257 ===
# Local min: 0.000279, Local max: 76.157562
#
# === Generating plots for index 258, additional data: 258 ===
# Local min: 0.000278, Local max: 75.883614
#
# === Generating plots for index 259, additional data: 259 ===
# Local min: 0.000278, Local max: 75.611626
#
# === Generating plots for index 260, additional data: 260 ===
# Local min: 0.000279, Local max: 75.473007
#
# === Generating plots for index 261, additional data: 261 ===
# Local min: 0.000278, Local max: 75.204414
#
# === Generating plots for index 262, additional data: 262 ===
# Local min: 0.000277, Local max: 74.937737
#
# === Generating plots for index 263, additional data: 263 ===
# Local min: 0.000276, Local max: 74.672935
#
# === Generating plots for index 264, additional data: 264 ===
# Local min: 0.000275, Local max: 75.586861
#
# === Generating plots for index 265, additional data: 265 ===
# Local min: 0.000275, Local max: 77.140167
#
# === Generating plots for index 266, additional data: 266 ===
# Local min: 0.000276, Local max: 77.035614
#
# === Generating plots for index 267, additional data: 267 ===
# Local min: 0.000275, Local max: 77.108856
#
# === Generating plots for index 268, additional data: 268 ===
# Local min: 0.000274, Local max: 76.841110
#
# === Generating plots for index 269, additional data: 269 ===
# Local min: 0.000278, Local max: 76.575226
#
# === Generating plots for index 270, additional data: 270 ===
# Local min: 0.000277, Local max: 76.368805
#
# === Generating plots for index 271, additional data: 271 ===
# Local min: 0.000277, Local max: 76.106369
#
# === Generating plots for index 272, additional data: 272 ===
# Local min: 0.000276, Local max: 76.017998
#
# === Generating plots for index 273, additional data: 273 ===
# Local min: 0.000275, Local max: 76.461609
#
# === Generating plots for index 274, additional data: 274 ===
# Local min: 0.000274, Local max: 76.201553
#
# === Generating plots for index 275, additional data: 275 ===
# Local min: 0.000273, Local max: 76.518768
#
# === Generating plots for index 276, additional data: 276 ===
# Local min: 0.000280, Local max: 76.260262
#
# === Generating plots for index 277, additional data: 277 ===
# Local min: 0.000279, Local max: 76.003494
#
# === Generating plots for index 278, additional data: 278 ===
# Local min: 0.000279, Local max: 76.270363
#
# === Generating plots for index 279, additional data: 279 ===
# Local min: 0.000278, Local max: 76.015282
#
# === Generating plots for index 280, additional data: 280 ===
# Local min: 0.000277, Local max: 76.408379
#
# === Generating plots for index 281, additional data: 281 ===
# Local min: 0.000277, Local max: 76.154533
#
# === Generating plots for index 282, additional data: 282 ===
# Local min: 0.000276, Local max: 75.902367
#
# === Generating plots for index 283, additional data: 283 ===
# Local min: 0.000275, Local max: 75.651863
#
# === Generating plots for index 284, additional data: 284 ===
# Local min: 0.000277, Local max: 75.551697
#
# === Generating plots for index 285, additional data: 285 ===
# Local min: 0.000278, Local max: 75.427338
#
# === Generating plots for index 286, additional data: 286 ===
# Local min: 0.000277, Local max: 75.180840
#
# === Generating plots for index 287, additional data: 287 ===
# Local min: 0.000276, Local max: 75.055977
#
# === Generating plots for index 288, additional data: 288 ===
# Local min: 0.000275, Local max: 75.885796
#
# === Generating plots for index 289, additional data: 289 ===
# Local min: 0.000274, Local max: 75.760338
#
# === Generating plots for index 290, additional data: 290 ===
# Local min: 0.000274, Local max: 75.552567
#
# === Generating plots for index 291, additional data: 291 ===
# Local min: 0.000273, Local max: 75.621307
#
# === Generating plots for index 292, additional data: 292 ===
# Local min: 0.000272, Local max: 75.378929
#
# === Generating plots for index 293, additional data: 293 ===
# Local min: 0.000271, Local max: 75.138107
#
# === Generating plots for index 294, additional data: 294 ===
# Local min: 0.000271, Local max: 75.017410
#
# === Generating plots for index 295, additional data: 295 ===
# Local min: 0.000270, Local max: 74.779259
#
# === Generating plots for index 296, additional data: 296 ===
# Local min: 0.000270, Local max: 74.542618
#
# === Generating plots for index 297, additional data: 297 ===
# Local min: 0.000269, Local max: 74.307465
#
# === Generating plots for index 298, additional data: 298 ===
# Local min: 0.000268, Local max: 74.073792
#
# === Generating plots for index 299, additional data: 299 ===
# Local min: 0.000267, Local max: 73.841591
#
# === Generating plots for index 300, additional data: 300 ===
# Local min: 0.000267, Local max: 73.610878
#
# === Generating plots for index 301, additional data: 301 ===
# Local min: 0.000266, Local max: 73.381561
#
# === Generating plots for index 302, additional data: 302 ===
# Local min: 0.000265, Local max: 74.058365
#
# === Generating plots for index 303, additional data: 303 ===
# Local min: 0.000265, Local max: 73.829079
#
# === Generating plots for index 304, additional data: 304 ===
# Local min: 0.000264, Local max: 73.760536
#
# === Generating plots for index 305, additional data: 305 ===
# Local min: 0.000263, Local max: 74.075729
#
# === Generating plots for index 306, additional data: 306 ===
# Local min: 0.000263, Local max: 75.103981
#
# === Generating plots for index 307, additional data: 307 ===
# Local min: 0.000262, Local max: 74.874306
#
# === Generating plots for index 308, additional data: 308 ===
# Local min: 0.000261, Local max: 75.086754
#
# === Generating plots for index 309, additional data: 309 ===
# Local min: 0.000261, Local max: 74.993134
#
# === Generating plots for index 310, additional data: 310 ===
# Local min: 0.000260, Local max: 74.778046
#
# === Generating plots for index 311, additional data: 311 ===
# Local min: 0.000260, Local max: 74.573334
#
# === Generating plots for index 312, additional data: 312 ===
# Local min: 0.000260, Local max: 74.349319
#
# === Generating plots for index 313, additional data: 313 ===
# Local min: 0.000259, Local max: 74.126053
#
# === Generating plots for index 314, additional data: 314 ===
# Local min: 0.000259, Local max: 74.017288
#
# === Generating plots for index 315, additional data: 315 ===
# Local min: 0.000258, Local max: 74.057487
#
# === Generating plots for index 316, additional data: 316 ===
# Local min: 0.000257, Local max: 74.341698
#
# === Generating plots for index 317, additional data: 317 ===
# Local min: 0.000257, Local max: 74.121101
#
# === Generating plots for index 318, additional data: 318 ===
# Local min: 0.000257, Local max: 73.901810
#
# === Generating plots for index 319, additional data: 319 ===
# Local min: 0.000257, Local max: 73.740517
#
# === Generating plots for index 320, additional data: 320 ===
# Local min: 0.000256, Local max: 73.669464
#
# === Generating plots for index 321, additional data: 321 ===
# Local min: 0.000255, Local max: 73.453415
#
# === Generating plots for index 322, additional data: 322 ===
# Local min: 0.000254, Local max: 73.238647
#
# === Generating plots for index 323, additional data: 323 ===
# Local min: 0.000255, Local max: 73.025124
#
# === Generating plots for index 324, additional data: 324 ===
# Local min: 0.000254, Local max: 72.862381
#
# === Generating plots for index 325, additional data: 325 ===
# Local min: 0.000253, Local max: 72.651184
#
# === Generating plots for index 326, additional data: 326 ===
# Local min: 0.000253, Local max: 72.441208
#
# === Generating plots for index 327, additional data: 327 ===
# Local min: 0.000252, Local max: 72.232445
#
# === Generating plots for index 328, additional data: 328 ===
# Local min: 0.000251, Local max: 72.024879
#
# === Generating plots for index 329, additional data: 329 ===
# Local min: 0.000251, Local max: 71.818504
#
# === Generating plots for index 330, additional data: 330 ===
# Local min: 0.000251, Local max: 71.613312
#
# === Generating plots for index 331, additional data: 331 ===
# Local min: 0.000250, Local max: 71.409279
#
# === Generating plots for index 332, additional data: 332 ===
# Local min: 0.000249, Local max: 71.326332
#
# === Generating plots for index 333, additional data: 333 ===
# Local min: 0.000249, Local max: 71.662407
#
# === Generating plots for index 334, additional data: 334 ===
# Local min: 0.000249, Local max: 71.459984
#
# === Generating plots for index 335, additional data: 335 ===
# Local min: 0.000249, Local max: 72.158546
#
# === Generating plots for index 336, additional data: 336 ===
# Local min: 0.000249, Local max: 71.991493
#
# === Generating plots for index 337, additional data: 337 ===
# Local min: 0.000248, Local max: 71.945335
#
# === Generating plots for index 338, additional data: 338 ===
# Local min: 0.000248, Local max: 71.852600
#
# === Generating plots for index 339, additional data: 339 ===
# Local min: 0.000248, Local max: 71.652451
#
# === Generating plots for index 340, additional data: 340 ===
# Local min: 0.000248, Local max: 71.453415
#
# === Generating plots for index 341, additional data: 341 ===
# Local min: 0.000247, Local max: 71.255486
#
# === Generating plots for index 342, additional data: 342 ===
# Local min: 0.000247, Local max: 71.063095
#
# === Generating plots for index 343, additional data: 343 ===
# Local min: 0.000246, Local max: 70.867332
#
# === Generating plots for index 344, additional data: 344 ===
# Local min: 0.000245, Local max: 70.672646
#
# === Generating plots for index 345, additional data: 345 ===
# Local min: 0.000245, Local max: 70.613625
#
# === Generating plots for index 346, additional data: 346 ===
# Local min: 0.000245, Local max: 70.839798
#
# === Generating plots for index 347, additional data: 347 ===
# Local min: 0.000244, Local max: 70.646774
#
# === Generating plots for index 348, additional data: 348 ===
# Local min: 0.000244, Local max: 70.469162
#
# === Generating plots for index 349, additional data: 349 ===
# Local min: 0.000243, Local max: 70.521477
#
# === Generating plots for index 350, additional data: 350 ===
# Local min: 0.000247, Local max: 71.392151
#
# === Generating plots for index 351, additional data: 351 ===
# Local min: 0.000247, Local max: 71.974312
#
# === Generating plots for index 352, additional data: 352 ===
# Local min: 0.000246, Local max: 71.973839
#
# === Generating plots for index 353, additional data: 353 ===
# Local min: 0.000245, Local max: 71.928871
#
# === Generating plots for index 354, additional data: 354 ===
# Local min: 0.000245, Local max: 71.835533
#
# === Generating plots for index 355, additional data: 355 ===
# Local min: 0.000246, Local max: 72.083847
#
# === Generating plots for index 356, additional data: 356 ===
# Local min: 0.000245, Local max: 71.892136
#
# === Generating plots for index 357, additional data: 357 ===
# Local min: 0.000244, Local max: 72.554039
#
# === Generating plots for index 358, additional data: 358 ===
# Local min: 0.000245, Local max: 72.420448
#
# === Generating plots for index 359, additional data: 359 ===
# Local min: 0.000247, Local max: 72.329414
#
# === Generating plots for index 360, additional data: 360 ===
# Local min: 0.000249, Local max: 72.258469
#
# === Generating plots for index 361, additional data: 361 ===
# Local min: 0.000248, Local max: 72.123413
#
# === Generating plots for index 362, additional data: 362 ===
# Local min: 0.000248, Local max: 71.934608
#
# === Generating plots for index 363, additional data: 363 ===
# Local min: 0.000247, Local max: 72.034409
#
# === Generating plots for index 364, additional data: 364 ===
# Local min: 0.000247, Local max: 72.208046
#
# === Generating plots for index 365, additional data: 365 ===
# Local min: 0.000246, Local max: 72.343590
#
# === Generating plots for index 366, additional data: 366 ===
# Local min: 0.000248, Local max: 72.156166
#
# === Generating plots for index 367, additional data: 367 ===
# Local min: 0.000247, Local max: 71.969719
#
# === Generating plots for index 368, additional data: 368 ===
# Local min: 0.000247, Local max: 71.784233
#
# === Generating plots for index 369, additional data: 369 ===
# Local min: 0.000247, Local max: 71.599693
#
# === Generating plots for index 370, additional data: 370 ===
# Local min: 0.000246, Local max: 71.416107
#
# === Generating plots for index 371, additional data: 371 ===
# Local min: 0.000246, Local max: 71.233459
#
# === Generating plots for index 372, additional data: 372 ===
# Local min: 0.000245, Local max: 71.051750
#
# === Generating plots for index 373, additional data: 373 ===
# Local min: 0.000245, Local max: 70.870956
#
# === Generating plots for index 374, additional data: 374 ===
# Local min: 0.000244, Local max: 70.889610
#
# === Generating plots for index 375, additional data: 375 ===
# Local min: 0.000244, Local max: 71.137596
#
# === Generating plots for index 376, additional data: 376 ===
# Local min: 0.000243, Local max: 71.279762
#
# === Generating plots for index 377, additional data: 377 ===
# Local min: 0.000243, Local max: 72.361275
#
# === Generating plots for index 378, additional data: 378 ===
# Local min: 0.000243, Local max: 73.588074
#
# === Generating plots for index 379, additional data: 379 ===
# Local min: 0.000242, Local max: 73.403648
#
# === Generating plots for index 380, additional data: 380 ===
# Local min: 0.000243, Local max: 73.253136
#
# === Generating plots for index 381, additional data: 381 ===
# Local min: 0.000242, Local max: 73.070457
#
# === Generating plots for index 382, additional data: 382 ===
# Local min: 0.000243, Local max: 73.634224
#
# === Generating plots for index 383, additional data: 383 ===
# Local min: 0.000243, Local max: 73.547653
#
# === Generating plots for index 384, additional data: 384 ===
# Local min: 0.000242, Local max: 73.421669
#
# === Generating plots for index 385, additional data: 385 ===
# Local min: 0.000242, Local max: 73.240387
#
# === Generating plots for index 386, additional data: 386 ===
# Local min: 0.000242, Local max: 73.059990
#
# === Generating plots for index 387, additional data: 387 ===
# Local min: 0.000241, Local max: 72.909851
#
# === Generating plots for index 388, additional data: 388 ===
# Local min: 0.000241, Local max: 73.046631
#
# === Generating plots for index 389, additional data: 389 ===
# Local min: 0.000240, Local max: 72.868034
#
# === Generating plots for index 390, additional data: 390 ===
# Local min: 0.000240, Local max: 73.162582
#
# === Generating plots for index 391, additional data: 391 ===
# Local min: 0.000240, Local max: 72.984573
#
# === Generating plots for index 392, additional data: 392 ===
# Local min: 0.000240, Local max: 73.501091
#
# === Generating plots for index 393, additional data: 393 ===
# Local min: 0.000239, Local max: 73.323120
#
# === Generating plots for index 394, additional data: 394 ===
# Local min: 0.000239, Local max: 73.261093
#
# === Generating plots for index 395, additional data: 395 ===
# Local min: 0.000238, Local max: 73.084564
#
# === Generating plots for index 396, additional data: 396 ===
# Local min: 0.000241, Local max: 73.003166
#
# === Generating plots for index 397, additional data: 397 ===
# Local min: 0.000243, Local max: 72.828094
#
# === Generating plots for index 398, additional data: 398 ===
# Local min: 0.000242, Local max: 72.903008
#
# === Generating plots for index 399, additional data: 399 ===
# Local min: 0.000242, Local max: 72.729012
#
# === Generating plots for index 400, additional data: 400 ===
# Local min: 0.000241, Local max: 72.640976
#
# === Generating plots for index 401, additional data: 401 ===
# Local min: 0.000241, Local max: 72.468437
#
# === Generating plots for index 402, additional data: 402 ===
# Local min: 0.000240, Local max: 72.296707
#
# === Generating plots for index 403, additional data: 403 ===
# Local min: 0.000240, Local max: 72.125793
#
# === Generating plots for index 404, additional data: 404 ===
# Local min: 0.000239, Local max: 71.955681
#
# === Generating plots for index 405, additional data: 405 ===
# Local min: 0.000239, Local max: 72.449860
#
# === Generating plots for index 406, additional data: 406 ===
# Local min: 0.000239, Local max: 72.279785
#
# === Generating plots for index 407, additional data: 407 ===
# Local min: 0.000239, Local max: 72.110512
#
# === Generating plots for index 408, additional data: 408 ===
# Local min: 0.000238, Local max: 72.362671
#
# === Generating plots for index 409, additional data: 409 ===
# Local min: 0.000238, Local max: 72.225502
#
# === Generating plots for index 410, additional data: 410 ===
# Local min: 0.000238, Local max: 72.371269
#
# === Generating plots for index 411, additional data: 411 ===
# Local min: 0.000242, Local max: 72.203354
#
# === Generating plots for index 412, additional data: 412 ===
# Local min: 0.000241, Local max: 72.046616
#
# === Generating plots for index 413, additional data: 413 ===
# Local min: 0.000241, Local max: 71.880226
#
# === Generating plots for index 414, additional data: 414 ===
# Local min: 0.000246, Local max: 71.714600
#
# === Generating plots for index 415, additional data: 415 ===
# Local min: 0.000246, Local max: 71.549736
#
# === Generating plots for index 416, additional data: 416 ===
# Local min: 0.000246, Local max: 72.311333
#
# === Generating plots for index 417, additional data: 417 ===
# Local min: 0.000245, Local max: 72.145897
#
# === Generating plots for index 418, additional data: 418 ===
# Local min: 0.000245, Local max: 71.981178
#
# === Generating plots for index 419, additional data: 419 ===
# Local min: 0.000244, Local max: 71.817215
#
# === Generating plots for index 420, additional data: 420 ===
# Local min: 0.000244, Local max: 73.012482
#
# === Generating plots for index 421, additional data: 421 ===
# Local min: 0.000244, Local max: 72.846924
#
# === Generating plots for index 422, additional data: 422 ===
# Local min: 0.000243, Local max: 72.694687
#
# === Generating plots for index 423, additional data: 423 ===
# Local min: 0.000243, Local max: 72.530594
#
# === Generating plots for index 424, additional data: 424 ===
# Local min: 0.000245, Local max: 72.367233
#
# === Generating plots for index 425, additional data: 425 ===
# Local min: 0.000244, Local max: 72.204613
#
# === Generating plots for index 426, additional data: 426 ===
# Local min: 0.000245, Local max: 72.130196
#
# === Generating plots for index 427, additional data: 427 ===
# Local min: 0.000244, Local max: 71.968826
#
# === Generating plots for index 428, additional data: 428 ===
# Local min: 0.000244, Local max: 71.928207
#
# === Generating plots for index 429, additional data: 429 ===
# Local min: 0.000244, Local max: 71.812943
#
# === Generating plots for index 430, additional data: 430 ===
# Local min: 0.000244, Local max: 71.736809
#
# === Generating plots for index 431, additional data: 431 ===
# Local min: 0.000243, Local max: 71.577744
#
# === Generating plots for index 432, additional data: 432 ===
# Local min: 0.000243, Local max: 71.420059
#
# === Generating plots for index 433, additional data: 433 ===
# Local min: 0.000243, Local max: 71.313766
#
# === Generating plots for index 434, additional data: 434 ===
# Local min: 0.000243, Local max: 71.468979
#
# === Generating plots for index 435, additional data: 435 ===
# Local min: 0.000242, Local max: 71.311905
#
# === Generating plots for index 436, additional data: 436 ===
# Local min: 0.000242, Local max: 71.359955
#
# === Generating plots for index 437, additional data: 437 ===
# Local min: 0.000242, Local max: 71.203804
#
# === Generating plots for index 438, additional data: 438 ===
# Local min: 0.000241, Local max: 71.048340
#
# === Generating plots for index 439, additional data: 439 ===
# Local min: 0.000241, Local max: 70.893547
#
# === Generating plots for index 440, additional data: 440 ===
# Local min: 0.000240, Local max: 70.739433
#
# === Generating plots for index 441, additional data: 441 ===
# Local min: 0.000240, Local max: 70.666031
#
# === Generating plots for index 442, additional data: 442 ===
# Local min: 0.000239, Local max: 70.543625
#
# === Generating plots for index 443, additional data: 443 ===
# Local min: 0.000239, Local max: 70.391266
#
# === Generating plots for index 444, additional data: 444 ===
# Local min: 0.000239, Local max: 70.689720
#
# === Generating plots for index 445, additional data: 445 ===
# Local min: 0.000238, Local max: 71.281105
#
# === Generating plots for index 446, additional data: 446 ===
# Local min: 0.000238, Local max: 71.128143
#
# === Generating plots for index 447, additional data: 447 ===
# Local min: 0.000237, Local max: 70.975838
#
# === Generating plots for index 448, additional data: 448 ===
# Local min: 0.000237, Local max: 71.251457
#
# === Generating plots for index 449, additional data: 449 ===
# Local min: 0.000237, Local max: 71.099541
#
# === Generating plots for index 450, additional data: 450 ===
# Local min: 0.000237, Local max: 70.948265
#
# === Generating plots for index 451, additional data: 451 ===
# Local min: 0.000236, Local max: 70.818222
#
# === Generating plots for index 452, additional data: 452 ===
# Local min: 0.000236, Local max: 70.712334
#
# === Generating plots for index 453, additional data: 453 ===
# Local min: 0.000236, Local max: 70.978958
#
# === Generating plots for index 454, additional data: 454 ===
# Local min: 0.000236, Local max: 70.937737
#
# === Generating plots for index 455, additional data: 455 ===
# Local min: 0.000235, Local max: 70.870789
#
# === Generating plots for index 456, additional data: 456 ===
# Local min: 0.000235, Local max: 70.872269
#
# === Generating plots for index 457, additional data: 457 ===
# Local min: 0.000235, Local max: 70.776024
#
# === Generating plots for index 458, additional data: 458 ===
# Local min: 0.000234, Local max: 70.908257
#
# === Generating plots for index 459, additional data: 459 ===
# Local min: 0.000237, Local max: 70.864044
#
# === Generating plots for index 460, additional data: 460 ===
# ...
# Local min: 0.000238, Local max: 75.549133
#
# === Generating plots for index 629, additional data: 629 ===
# Local min: 0.000237, Local max: 75.631134
#
# === Generating plots for index 630, additional data: 630 ===
# Local min: 0.000237, Local max: 75.548225
#
# === Generating plots for index 631, additional data: 631 ===
# Local min: 0.000237, Local max: 75.432175
#
# === Generating plots for index 632, additional data: 632 ===
# Local min: 0.000237, Local max: 76.094330
#
# === Generating plots for index 633, additional data: 633 ===
# Local min: 0.000237, Local max: 76.141251
#
# === Generating plots for index 634, additional data: 634 ===
# Local min: 0.000237, Local max: 76.801178
#
# === Generating plots for index 635, additional data: 635 ===
# Local min: 0.000237, Local max: 76.737183
#
# === Generating plots for index 636, additional data: 636 ===
# Local min: 0.000236, Local max: 77.217262
#
# === Generating plots for index 637, additional data: 637 ===
# Local min: 0.000236, Local max: 77.099731
#
# === Generating plots for index 638, additional data: 638 ===
# Local min: 0.000237, Local max: 76.982559
#
# === Generating plots for index 639, additional data: 639 ===
# Local min: 0.000237, Local max: 76.865738
#
# === Generating plots for index 640, additional data: 640 ===
# Local min: 0.000236, Local max: 76.749275
#
# === Generating plots for index 641, additional data: 641 ===
# Local min: 0.000237, Local max: 77.283012
#
# === Generating plots for index 642, additional data: 642 ===
# Local min: 0.000236, Local max: 77.675064
#
# === Generating plots for index 643, additional data: 643 ===
# Local min: 0.000236, Local max: 77.557907
#
# === Generating plots for index 644, additional data: 644 ===
# Local min: 0.000236, Local max: 77.441109
#
# === Generating plots for index 645, additional data: 645 ===
# Local min: 0.000235, Local max: 77.606705
#
# === Generating plots for index 646, additional data: 646 ===
# Local min: 0.000235, Local max: 78.170883
#
# === Generating plots for index 647, additional data: 647 ===
# Local min: 0.000235, Local max: 78.053726
#
# === Generating plots for index 648, additional data: 648 ===
# Local min: 0.000235, Local max: 77.936882
#
# === Generating plots for index 649, additional data: 649 ===
# Local min: 0.000235, Local max: 77.820381
#
# === Generating plots for index 650, additional data: 650 ===
# Local min: 0.000235, Local max: 77.704231
#
# === Generating plots for index 651, additional data: 651 ===
# Local min: 0.000235, Local max: 77.588432
#
# === Generating plots for index 652, additional data: 652 ===
# Local min: 0.000234, Local max: 77.680557
#
# === Generating plots for index 653, additional data: 653 ===
# Local min: 0.000234, Local max: 77.776215
#
# === Generating plots for index 654, additional data: 654 ===
# Local min: 0.000234, Local max: 77.660820
#
# === Generating plots for index 655, additional data: 655 ===
# Local min: 0.000234, Local max: 77.963852
#
# === Generating plots for index 656, additional data: 656 ===
# Local min: 0.000233, Local max: 77.848526
#
# === Generating plots for index 657, additional data: 657 ===
# Local min: 0.000233, Local max: 77.733536
#
# === Generating plots for index 658, additional data: 658 ===
# Local min: 0.000233, Local max: 77.618881
#
# === Generating plots for index 659, additional data: 659 ===
# Local min: 0.000232, Local max: 77.512161
#
# === Generating plots for index 660, additional data: 660 ===
# Local min: 0.000232, Local max: 77.537338
#
# === Generating plots for index 661, additional data: 661 ===
# Local min: 0.000232, Local max: 77.423485
#
# === Generating plots for index 662, additional data: 662 ===
# Local min: 0.000232, Local max: 77.389374
#
# === Generating plots for index 663, additional data: 663 ===
# Local min: 0.000231, Local max: 77.276070
#
# === Generating plots for index 664, additional data: 664 ===
# Local min: 0.000231, Local max: 77.195480
#
# === Generating plots for index 665, additional data: 665 ===
# Local min: 0.000231, Local max: 77.082779
#
# === Generating plots for index 666, additional data: 666 ===
# Local min: 0.000230, Local max: 77.239799
#
# === Generating plots for index 667, additional data: 667 ===
# Local min: 0.000230, Local max: 77.187134
#
# === Generating plots for index 668, additional data: 668 ===
# Local min: 0.000230, Local max: 77.358223
#
# === Generating plots for index 669, additional data: 669 ===
# Local min: 0.000230, Local max: 77.245949
#
# === Generating plots for index 670, additional data: 670 ===
# Local min: 0.000230, Local max: 77.159065
#
# === Generating plots for index 671, additional data: 671 ===
# Local min: 0.000230, Local max: 77.256485
#
# === Generating plots for index 672, additional data: 672 ===
# Local min: 0.000232, Local max: 77.144844
#
# === Generating plots for index 673, additional data: 673 ===
# Local min: 0.000231, Local max: 77.112602
#
# === Generating plots for index 674, additional data: 674 ===
# Local min: 0.000231, Local max: 77.001495
#
# === Generating plots for index 675, additional data: 675 ===
# Local min: 0.000231, Local max: 76.890701
#
# === Generating plots for index 676, additional data: 676 ===
# Local min: 0.000230, Local max: 76.780220
#
# === Generating plots for index 677, additional data: 677 ===
# Local min: 0.000230, Local max: 76.761604
#
# === Generating plots for index 678, additional data: 678 ===
# Local min: 0.000230, Local max: 76.875153
#
# === Generating plots for index 679, additional data: 679 ===
# Local min: 0.000230, Local max: 76.765175
#
# === Generating plots for index 680, additional data: 680 ===
# Local min: 0.000230, Local max: 76.926582
#
# === Generating plots for index 681, additional data: 681 ===
# Local min: 0.000230, Local max: 77.328651
#
# === Generating plots for index 682, additional data: 682 ===
# Local min: 0.000229, Local max: 77.743004
#
# === Generating plots for index 683, additional data: 683 ===
# Local min: 0.000229, Local max: 77.848969
#
# === Generating plots for index 684, additional data: 684 ===
# Local min: 0.000229, Local max: 78.027046
#
# === Generating plots for index 685, additional data: 685 ===
# Local min: 0.000229, Local max: 77.916367
#
# === Generating plots for index 686, additional data: 686 ===
# Local min: 0.000235, Local max: 77.806007
#
# === Generating plots for index 687, additional data: 687 ===
# Local min: 0.000234, Local max: 77.695953
#
# === Generating plots for index 688, additional data: 688 ===
# Local min: 0.000234, Local max: 77.586212
#
# === Generating plots for index 689, additional data: 689 ===
# Local min: 0.000234, Local max: 77.725945
#
# === Generating plots for index 690, additional data: 690 ===
# Local min: 0.000234, Local max: 77.752235
#
# === Generating plots for index 691, additional data: 691 ===
# Local min: 0.000233, Local max: 78.127739
#
# === Generating plots for index 692, additional data: 692 ===
# Local min: 0.000233, Local max: 78.374779
#
# === Generating plots for index 693, additional data: 693 ===
# Local min: 0.000233, Local max: 78.305222
#
# === Generating plots for index 694, additional data: 694 ===
# Local min: 0.000233, Local max: 78.241158
#
# === Generating plots for index 695, additional data: 695 ===
# Local min: 0.000233, Local max: 78.162674
#
# === Generating plots for index 696, additional data: 696 ===
# Local min: 0.000233, Local max: 78.053513
#
# === Generating plots for index 697, additional data: 697 ===
# Local min: 0.000232, Local max: 78.377983
#
# === Generating plots for index 698, additional data: 698 ===
# Local min: 0.000232, Local max: 78.268822
#
# === Generating plots for index 699, additional data: 699 ===
# Local min: 0.000232, Local max: 78.159966
#
# === Generating plots for index 700, additional data: 700 ===
# Local min: 0.000232, Local max: 78.105804
#
# === Generating plots for index 701, additional data: 701 ===
# Local min: 0.000231, Local max: 77.997475
#
# === Generating plots for index 702, additional data: 702 ===
# Local min: 0.000231, Local max: 77.936493
#
# === Generating plots for index 703, additional data: 703 ===
# Local min: 0.000233, Local max: 77.828697
#
# === Generating plots for index 704, additional data: 704 ===
# Local min: 0.000233, Local max: 77.721199
#
# === Generating plots for index 705, additional data: 705 ===
# Local min: 0.000232, Local max: 77.889771
#
# === Generating plots for index 706, additional data: 706 ===
# Local min: 0.000232, Local max: 77.782486
#
# === Generating plots for index 707, additional data: 707 ===
# Local min: 0.000232, Local max: 77.940399
#
# === Generating plots for index 708, additional data: 708 ===
# Local min: 0.000231, Local max: 77.987923
#
# === Generating plots for index 709, additional data: 709 ===
# Local min: 0.000231, Local max: 77.880943
#
# === Generating plots for index 710, additional data: 710 ===
# Local min: 0.000232, Local max: 77.774254
#
# === Generating plots for index 711, additional data: 711 ===
# Local min: 0.000232, Local max: 77.734940
#
# === Generating plots for index 712, additional data: 712 ===
# Local min: 0.000232, Local max: 77.664139
#
# === Generating plots for index 713, additional data: 713 ===
# Local min: 0.000232, Local max: 77.607803
#
# === Generating plots for index 714, additional data: 714 ===
# Local min: 0.000233, Local max: 77.502068
#
# === Generating plots for index 715, additional data: 715 ===
# Local min: 0.000233, Local max: 77.396622
#
# === Generating plots for index 716, additional data: 716 ===
# Local min: 0.000232, Local max: 77.329620
#
# === Generating plots for index 717, additional data: 717 ===
# Local min: 0.000232, Local max: 77.893639
#
# === Generating plots for index 718, additional data: 718 ===
# Local min: 0.000233, Local max: 77.788094
#
# === Generating plots for index 719, additional data: 719 ===
# Local min: 0.000233, Local max: 77.682831
#
# === Generating plots for index 720, additional data: 720 ===
# Local min: 0.000232, Local max: 77.577850
#
# === Generating plots for index 721, additional data: 721 ===
# Local min: 0.000232, Local max: 77.473160
#
# === Generating plots for index 722, additional data: 722 ===
# Local min: 0.000232, Local max: 77.368744
#
# === Generating plots for index 723, additional data: 723 ===
# Local min: 0.000232, Local max: 77.264618
#
# === Generating plots for index 724, additional data: 724 ===
# Local min: 0.000232, Local max: 77.706161
#
# === Generating plots for index 725, additional data: 725 ===
# Local min: 0.000231, Local max: 77.741562
#
# === Generating plots for index 726, additional data: 726 ===
# Local min: 0.000231, Local max: 77.644958
#
# === Generating plots for index 727, additional data: 727 ===
# Local min: 0.000231, Local max: 77.541016
#
# === Generating plots for index 728, additional data: 728 ===
# Local min: 0.000231, Local max: 77.437355
#
# === Generating plots for index 729, additional data: 729 ===
# Local min: 0.000231, Local max: 77.333969
#
# === Generating plots for index 730, additional data: 730 ===
# Local min: 0.000231, Local max: 77.431274
#
# === Generating plots for index 731, additional data: 731 ===
# Local min: 0.000231, Local max: 77.989670
#
# === Generating plots for index 732, additional data: 732 ===
# Local min: 0.000230, Local max: 77.885971
#
# === Generating plots for index 733, additional data: 733 ===
# Local min: 0.000230, Local max: 77.911720
#
# === Generating plots for index 734, additional data: 734 ===
# Local min: 0.000230, Local max: 77.881676
#
# === Generating plots for index 735, additional data: 735 ===
# Local min: 0.000229, Local max: 77.810806
#
# === Generating plots for index 736, additional data: 736 ===
# Local min: 0.000229, Local max: 77.707878
#
# === Generating plots for index 737, additional data: 737 ===
# Local min: 0.000229, Local max: 77.605225
#
# === Generating plots for index 738, additional data: 738 ===
# Local min: 0.000229, Local max: 77.502846
#
# === Generating plots for index 739, additional data: 739 ===
# Local min: 0.000229, Local max: 77.426468
#
# === Generating plots for index 740, additional data: 740 ===
# Local min: 0.000229, Local max: 77.392441
#
# === Generating plots for index 741, additional data: 741 ===
# Local min: 0.000229, Local max: 77.419716
#
# === Generating plots for index 742, additional data: 742 ===
# Local min: 0.000229, Local max: 77.318115
#
# === Generating plots for index 743, additional data: 743 ===
# Local min: 0.000228, Local max: 77.216782
#
# === Generating plots for index 744, additional data: 744 ===
# Local min: 0.000230, Local max: 77.115715
#
# === Generating plots for index 745, additional data: 745 ===
# Local min: 0.000230, Local max: 77.063164
#
# === Generating plots for index 746, additional data: 746 ===
# Local min: 0.000230, Local max: 76.962563
#
# === Generating plots for index 747, additional data: 747 ===
# Local min: 0.000231, Local max: 76.862213
#
# === Generating plots for index 748, additional data: 748 ===
# Local min: 0.000230, Local max: 77.022224
#
# === Generating plots for index 749, additional data: 749 ===
# Local min: 0.000230, Local max: 77.364281
#
# === Generating plots for index 750, additional data: 750 ===
# Local min: 0.000230, Local max: 77.334358
#
# === Generating plots for index 751, additional data: 751 ===
# Local min: 0.000229, Local max: 77.234055
#
# === Generating plots for index 752, additional data: 752 ===
# Local min: 0.000229, Local max: 77.386253
#
# === Generating plots for index 753, additional data: 753 ===
# Local min: 0.000229, Local max: 77.286140
#
# === Generating plots for index 754, additional data: 754 ===
# Local min: 0.000229, Local max: 77.186287
#
# === Generating plots for index 755, additional data: 755 ===
# Local min: 0.000228, Local max: 77.280090
#
# === Generating plots for index 756, additional data: 756 ===
# Local min: 0.000229, Local max: 77.180511
#
# === Generating plots for index 757, additional data: 757 ===
# Local min: 0.000229, Local max: 77.131210
#
# === Generating plots for index 758, additional data: 758 ===
# Local min: 0.000229, Local max: 77.032074
#
# === Generating plots for index 759, additional data: 759 ===
# Local min: 0.000235, Local max: 76.933189
#
# === Generating plots for index 760, additional data: 760 ===
# Local min: 0.000235, Local max: 76.834557
#
# === Generating plots for index 761, additional data: 761 ===
# Local min: 0.000235, Local max: 76.911713
#
# === Generating plots for index 762, additional data: 762 ===
# Local min: 0.000235, Local max: 76.970558
#
# === Generating plots for index 763, additional data: 763 ===
# Local min: 0.000234, Local max: 76.872253
#
# === Generating plots for index 764, additional data: 764 ===
# Local min: 0.000234, Local max: 76.774208
#
# === Generating plots for index 765, additional data: 765 ===
# Local min: 0.000234, Local max: 76.676407
#
# === Generating plots for index 766, additional data: 766 ===
# Local min: 0.000234, Local max: 76.578857
#
# === Generating plots for index 767, additional data: 767 ===
# Local min: 0.000234, Local max: 76.481552
#
# === Generating plots for index 768, additional data: 768 ===
# Local min: 0.000235, Local max: 76.417000
#
# === Generating plots for index 769, additional data: 769 ===
# Local min: 0.000234, Local max: 76.320152
#
# === Generating plots for index 770, additional data: 770 ===
# Local min: 0.000234, Local max: 76.223541
#
# === Generating plots for index 771, additional data: 771 ===
# Local min: 0.000234, Local max: 76.127174
#
# === Generating plots for index 772, additional data: 772 ===
# Local min: 0.000234, Local max: 76.104973
#
# === Generating plots for index 773, additional data: 773 ===
# Local min: 0.000234, Local max: 76.009003
#
# === Generating plots for index 774, additional data: 774 ===
# Local min: 0.000233, Local max: 75.962105
#
# === Generating plots for index 775, additional data: 775 ===
# Local min: 0.000233, Local max: 75.866562
#
# === Generating plots for index 776, additional data: 776 ===
# Local min: 0.000233, Local max: 75.860741
#
# === Generating plots for index 777, additional data: 777 ===
# Local min: 0.000235, Local max: 75.765556
#
# === Generating plots for index 778, additional data: 778 ===
# Local min: 0.000235, Local max: 75.717339
#
# === Generating plots for index 779, additional data: 779 ===
# Local min: 0.000237, Local max: 75.622574
#
# === Generating plots for index 780, additional data: 780 ===
# Local min: 0.000237, Local max: 75.528046
#
# === Total time for plotting all loss landscapes: 2900.41 seconds (48.34 minutes) ===
#
# ✓ All plots generated successfully!
