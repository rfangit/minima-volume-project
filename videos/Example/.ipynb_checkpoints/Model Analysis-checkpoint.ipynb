# %% [markdown]
# # Model Analysis
#
# This program takes in datasets and models, and computes the loss landscapes over varying amounts of data.

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

import time
import glob

# Importing our existing funcs
import os
import sys
from pathlib import Path

from minima_volume.dataset_funcs import ( load_models_and_data )

from minima_volume.landscape_videos import (
    compute_loss_landscape_3models,
    plot_2d_loss_landscape_3model,
    compute_loss_landscapes_varying_data,
    compute_loss_landscape_3models_varying_data,
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Model

# %%
# User specifies the model module name
import swiss_model_data as model_module

model_seed = 0 # filler for the template

# Swiss specific initialization parameters
input_dim = 2
output_dim = 1
hidden_dims = [32]*5

# Grab model
model_template = model_module.get_model(input_dim=input_dim, hidden_dims=hidden_dims, output_dim=output_dim, device=device, seed=model_seed)

# Grab loss and metrics
loss_fn_per_sample = model_module.get_loss_fn_per_sample()

# %% [markdown]
# ## Loading Model and Datasets

# %%
# Get the relative path
target_dir = Path("models_and_data") #current directory

# Lists to store loaded models and additional data
loaded_models, loaded_additional_data, loaded_dataset = load_models_and_data(model_template=model_template, target_dir=target_dir, device="cpu")

# Print dataset information
print(f"Dataset type: {loaded_dataset['dataset_type']}")
print(f"Dataset quantities: {loaded_dataset['dataset_quantities']}")

# Print tensor shapes
print("\nTensor shapes:")
for key in ["x_base_train", "y_base_train", "x_additional", "y_additional", "x_test", "y_test"]:
    if loaded_dataset[key] is not None:
        print(f"  {key}: {loaded_dataset[key].shape}")
    else:
        print(f"  {key}: None")
# Out:
# Looking for models and dataset in: models_and_data
# Found 6 model files:
#   - model_additional_0.pt
#   - model_additional_180.pt
#   - model_additional_30.pt
#   - model_additional_380.pt
#   - model_additional_780.pt
#   - model_additional_80.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_0.pt
# Successfully loaded: model_additional_0.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_180.pt
# Successfully loaded: model_additional_180.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_30.pt
# Successfully loaded: model_additional_30.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_380.pt
# Successfully loaded: model_additional_380.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_780.pt
# Successfully loaded: model_additional_780.pt
# ✅ Model loaded into provided instance from models_and_data\model_additional_80.pt
# Successfully loaded: model_additional_80.pt
#
# Model data loaded from all models:
# Model 0 (model_additional_0.pt):
#   - Additional data: 0
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 1 (model_additional_180.pt):
#   - Additional data: 180
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 2 (model_additional_30.pt):
#   - Additional data: 30
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 3 (model_additional_380.pt):
#   - Additional data: 380
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 4 (model_additional_780.pt):
#   - Additional data: 780
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
# Model 5 (model_additional_80.pt):
#   - Additional data: 80
#   - Dataset type: data
#   - Training accuracies: 500 entries
#   - Test accuracies: 500 entries
#
# Loading dataset...
# Using dataset file: dataset.pt
# ✅ Dataset loaded from models_and_data\dataset.pt
# Dataset type: data
# Dataset quantities: [0, 30, 80, 180, 380, 780]
#
# Tensor shapes:
#   x_base_train: torch.Size([20, 2])
#   y_base_train: torch.Size([20])
#   x_additional: torch.Size([780, 2])
#   y_additional: torch.Size([780])
#   x_test: torch.Size([4000, 2])
#   y_test: torch.Size([4000])

# %% [markdown]
# ## Plotting Parameters
#
# Determines what models to use.

# %%
index1 = 0
index2 = 1
index3 = 4
index_list = [index1, index2, index3]

print(
    f"Loading models trained with: "
    f"{loaded_additional_data[index1]['additional_data']}, "
    f"{loaded_additional_data[index2]['additional_data']}, "
    f"{loaded_additional_data[index3]['additional_data']}"
)

model_0 = loaded_models[index1]
model_1 = loaded_models[index2]
model_2 = loaded_models[index3]

print("=== Selected Models ===")
dataset_type = loaded_dataset['dataset_type']
model_labels = [
    f"Model Trained with {loaded_additional_data[index1]['additional_data']} {dataset_type}",
    f"Model Trained with {loaded_additional_data[index2]['additional_data']} {dataset_type}",
    f"Model Trained with {loaded_additional_data[index3]['additional_data']} {dataset_type}"
]

# Prepare dataset with additional_data = 0 (base dataset only)
x_base_train = loaded_dataset['x_base_train']
y_base_train = loaded_dataset['y_base_train']
x_additional = loaded_dataset['x_additional']
y_additional = loaded_dataset['y_additional']
# Out:
# Loading models trained with: 0, 180, 780
# === Selected Models ===

# %% [markdown]
# ## Loss Surface Generation

# %% [markdown]
# First, a sample visualization.

# %%
# Create quick_view directory
quick_view_dir = Path("quick_view")
quick_view_dir.mkdir(exist_ok=True)

# Create grid coefficients [-0.5, 1.5] with 80x80 points
N = 80
span_low = -0.5
span_high = 1.5

x = np.linspace(span_low, span_high, N)
y = np.linspace(span_low, span_high, N)
C1_grid, C2_grid = np.meshgrid(x, y)
grid_coefficients = (C1_grid, C2_grid)

print(f"Grid size: {N}x{N}, Range: [{span_low}, {span_high}]")

loss_grids = []

# Now begin assembling the datasets and computing different loss surfaces for this grid.
print("\n=== Generating Loss Landscape ===")
additional_data_amounts = [loaded_additional_data[index1]['additional_data'], 
                           loaded_additional_data[index2]['additional_data'], 
                           loaded_additional_data[index3]['additional_data']]
loss_grid_list, C1_grid, C2_grid = compute_loss_landscape_3models_varying_data( model_0=model_0,
                                                                                model_1=model_1,
                                                                                model_2=model_2,
                                                                                grid_coefficients=grid_coefficients,
                                                                                x_base = x_base_train,
                                                                                y_base = y_base_train,
                                                                                x_additional = x_additional,
                                                                                y_additional = y_additional,
                                                                                additional_data_amounts = additional_data_amounts,
                                                                                loss_fn_per_sample = loss_fn_per_sample,
                                                                                output_dir=quick_view_dir,
                                                                                base_filename="landscape" )

print("✓ Loss landscape generated and saved")

# Sample plot 
print("=== Plotting Loss Landscapes ===")

for i in range(3):
    # Plot 2D loss landscape
    plot_2d_loss_landscape_3model(
        C1_grid=C1_grid,
        C2_grid=C2_grid, 
        loss_grid=loss_grid_list[i],
        span_low=span_low,
        span_high=span_high,
        output_path=f"quick_view/loss_landscape_{loaded_additional_data[index_list[i]]['additional_data']}.png",
        additional_data = loaded_additional_data[index_list[i]]['additional_data'],
        model_labels = model_labels,
        show = True
    )
# Out:
# Grid size: 80x80, Range: [-0.5, 1.5]
#
# === Generating Loss Landscape ===
# === Computing loss landscapes for 3 data amounts ===
#   ✓ Saved loss landscape for amount=0 as landscape_index_0_amount_0.npz
#   ✓ Saved loss landscape for amount=180 as landscape_index_1_amount_180.npz
#   ✓ Saved loss landscape for amount=780 as landscape_index_2_amount_780.npz
# ✓ Loss landscape generated and saved
# === Plotting Loss Landscapes ===

# %% [markdown]
# ## Loss Landscape Computation Across Datasets
#
# Loss landscape computation.

# %%
# Create storage directory
varying_dataset_dir = Path("varying_dataset")
varying_dataset_dir.mkdir(exist_ok=True)

# Define the additional data amounts to test
# This can be varied depending on the use case!!
additional_data_amounts = range(len(x_additional)+1)

# Create grid
N = 80
span_low, span_high = -0.5, 1.5
x = np.linspace(span_low, span_high, N)
y = np.linspace(span_low, span_high, N)
C1_grid, C2_grid = np.meshgrid(x, y)
grid_coefficients = (C1_grid, C2_grid)

print(f"Grid size: {N}x{N}, Range: [{span_low}, {span_high}]")
# Out:
# Grid size: 80x80, Range: [-0.5, 1.5]
# === Computing loss landscapes for 781 data amounts ===
#   ✓ Saved loss landscape for amount=0 as landscape_index_0_amount_0.npz
#   ✓ Saved loss landscape for amount=1 as landscape_index_1_amount_1.npz
#   ✓ Saved loss landscape for amount=2 as landscape_index_2_amount_2.npz
#   ✓ Saved loss landscape for amount=3 as landscape_index_3_amount_3.npz
#   ✓ Saved loss landscape for amount=4 as landscape_index_4_amount_4.npz
#   ✓ Saved loss landscape for amount=5 as landscape_index_5_amount_5.npz
#   ✓ Saved loss landscape for amount=6 as landscape_index_6_amount_6.npz
#   ✓ Saved loss landscape for amount=7 as landscape_index_7_amount_7.npz
#   ✓ Saved loss landscape for amount=8 as landscape_index_8_amount_8.npz
#   ✓ Saved loss landscape for amount=9 as landscape_index_9_amount_9.npz
#   ✓ Saved loss landscape for amount=10 as landscape_index_10_amount_10.npz
#   ✓ Saved loss landscape for amount=11 as landscape_index_11_amount_11.npz
#   ✓ Saved loss landscape for amount=12 as landscape_index_12_amount_12.npz
#   ✓ Saved loss landscape for amount=13 as landscape_index_13_amount_13.npz
#   ✓ Saved loss landscape for amount=14 as landscape_index_14_amount_14.npz
#   ✓ Saved loss landscape for amount=15 as landscape_index_15_amount_15.npz
#   ✓ Saved loss landscape for amount=16 as landscape_index_16_amount_16.npz
#   ✓ Saved loss landscape for amount=17 as landscape_index_17_amount_17.npz
#   ✓ Saved loss landscape for amount=18 as landscape_index_18_amount_18.npz
#   ✓ Saved loss landscape for amount=19 as landscape_index_19_amount_19.npz
#   ✓ Saved loss landscape for amount=20 as landscape_index_20_amount_20.npz
#   ✓ Saved loss landscape for amount=21 as landscape_index_21_amount_21.npz
#   ✓ Saved loss landscape for amount=22 as landscape_index_22_amount_22.npz
#   ✓ Saved loss landscape for amount=23 as landscape_index_23_amount_23.npz
#   ✓ Saved loss landscape for amount=24 as landscape_index_24_amount_24.npz
#   ✓ Saved loss landscape for amount=25 as landscape_index_25_amount_25.npz
#   ✓ Saved loss landscape for amount=26 as landscape_index_26_amount_26.npz
#   ✓ Saved loss landscape for amount=27 as landscape_index_27_amount_27.npz
#   ✓ Saved loss landscape for amount=28 as landscape_index_28_amount_28.npz
#   ✓ Saved loss landscape for amount=29 as landscape_index_29_amount_29.npz
#   ✓ Saved loss landscape for amount=30 as landscape_index_30_amount_30.npz
#   ✓ Saved loss landscape for amount=31 as landscape_index_31_amount_31.npz
#   ✓ Saved loss landscape for amount=32 as landscape_index_32_amount_32.npz
#   ✓ Saved loss landscape for amount=33 as landscape_index_33_amount_33.npz
#   ✓ Saved loss landscape for amount=34 as landscape_index_34_amount_34.npz
#   ✓ Saved loss landscape for amount=35 as landscape_index_35_amount_35.npz
#   ✓ Saved loss landscape for amount=36 as landscape_index_36_amount_36.npz
#   ✓ Saved loss landscape for amount=37 as landscape_index_37_amount_37.npz
#   ✓ Saved loss landscape for amount=38 as landscape_index_38_amount_38.npz
#   ✓ Saved loss landscape for amount=39 as landscape_index_39_amount_39.npz
#   ✓ Saved loss landscape for amount=40 as landscape_index_40_amount_40.npz
#   ✓ Saved loss landscape for amount=41 as landscape_index_41_amount_41.npz
#   ✓ Saved loss landscape for amount=42 as landscape_index_42_amount_42.npz
#   ✓ Saved loss landscape for amount=43 as landscape_index_43_amount_43.npz
#   ✓ Saved loss landscape for amount=44 as landscape_index_44_amount_44.npz
#   ✓ Saved loss landscape for amount=45 as landscape_index_45_amount_45.npz
#   ✓ Saved loss landscape for amount=46 as landscape_index_46_amount_46.npz
#   ✓ Saved loss landscape for amount=47 as landscape_index_47_amount_47.npz
#   ✓ Saved loss landscape for amount=48 as landscape_index_48_amount_48.npz
#   ✓ Saved loss landscape for amount=49 as landscape_index_49_amount_49.npz
#   ✓ Saved loss landscape for amount=50 as landscape_index_50_amount_50.npz
#   ✓ Saved loss landscape for amount=51 as landscape_index_51_amount_51.npz
#   ✓ Saved loss landscape for amount=52 as landscape_index_52_amount_52.npz
#   ✓ Saved loss landscape for amount=53 as landscape_index_53_amount_53.npz
#   ✓ Saved loss landscape for amount=54 as landscape_index_54_amount_54.npz
#   ✓ Saved loss landscape for amount=55 as landscape_index_55_amount_55.npz
#   ✓ Saved loss landscape for amount=56 as landscape_index_56_amount_56.npz
#   ✓ Saved loss landscape for amount=57 as landscape_index_57_amount_57.npz
#   ✓ Saved loss landscape for amount=58 as landscape_index_58_amount_58.npz
#   ✓ Saved loss landscape for amount=59 as landscape_index_59_amount_59.npz
#   ✓ Saved loss landscape for amount=60 as landscape_index_60_amount_60.npz
#   ✓ Saved loss landscape for amount=61 as landscape_index_61_amount_61.npz
#   ✓ Saved loss landscape for amount=62 as landscape_index_62_amount_62.npz
#   ✓ Saved loss landscape for amount=63 as landscape_index_63_amount_63.npz
#   ✓ Saved loss landscape for amount=64 as landscape_index_64_amount_64.npz
#   ✓ Saved loss landscape for amount=65 as landscape_index_65_amount_65.npz
#   ✓ Saved loss landscape for amount=66 as landscape_index_66_amount_66.npz
#   ✓ Saved loss landscape for amount=67 as landscape_index_67_amount_67.npz
#   ✓ Saved loss landscape for amount=68 as landscape_index_68_amount_68.npz
#   ✓ Saved loss landscape for amount=69 as landscape_index_69_amount_69.npz
#   ✓ Saved loss landscape for amount=70 as landscape_index_70_amount_70.npz
#   ✓ Saved loss landscape for amount=71 as landscape_index_71_amount_71.npz
#   ✓ Saved loss landscape for amount=72 as landscape_index_72_amount_72.npz
#   ✓ Saved loss landscape for amount=73 as landscape_index_73_amount_73.npz
#   ✓ Saved loss landscape for amount=74 as landscape_index_74_amount_74.npz
#   ✓ Saved loss landscape for amount=75 as landscape_index_75_amount_75.npz
#   ✓ Saved loss landscape for amount=76 as landscape_index_76_amount_76.npz
#   ✓ Saved loss landscape for amount=77 as landscape_index_77_amount_77.npz
#   ✓ Saved loss landscape for amount=78 as landscape_index_78_amount_78.npz
#   ✓ Saved loss landscape for amount=79 as landscape_index_79_amount_79.npz
#   ✓ Saved loss landscape for amount=80 as landscape_index_80_amount_80.npz
#   ✓ Saved loss landscape for amount=81 as landscape_index_81_amount_81.npz
#   ✓ Saved loss landscape for amount=82 as landscape_index_82_amount_82.npz
#   ✓ Saved loss landscape for amount=83 as landscape_index_83_amount_83.npz
#   ✓ Saved loss landscape for amount=84 as landscape_index_84_amount_84.npz
#   ✓ Saved loss landscape for amount=85 as landscape_index_85_amount_85.npz
#   ✓ Saved loss landscape for amount=86 as landscape_index_86_amount_86.npz
#   ✓ Saved loss landscape for amount=87 as landscape_index_87_amount_87.npz
#   ✓ Saved loss landscape for amount=88 as landscape_index_88_amount_88.npz
#   ✓ Saved loss landscape for amount=89 as landscape_index_89_amount_89.npz
#   ✓ Saved loss landscape for amount=90 as landscape_index_90_amount_90.npz
#   ✓ Saved loss landscape for amount=91 as landscape_index_91_amount_91.npz
#   ✓ Saved loss landscape for amount=92 as landscape_index_92_amount_92.npz
#   ✓ Saved loss landscape for amount=93 as landscape_index_93_amount_93.npz
#   ✓ Saved loss landscape for amount=94 as landscape_index_94_amount_94.npz
#   ✓ Saved loss landscape for amount=95 as landscape_index_95_amount_95.npz
#   ✓ Saved loss landscape for amount=96 as landscape_index_96_amount_96.npz
#   ✓ Saved loss landscape for amount=97 as landscape_index_97_amount_97.npz
#   ✓ Saved loss landscape for amount=98 as landscape_index_98_amount_98.npz
#   ✓ Saved loss landscape for amount=99 as landscape_index_99_amount_99.npz
#   ✓ Saved loss landscape for amount=100 as landscape_index_100_amount_100.npz
#   ✓ Saved loss landscape for amount=101 as landscape_index_101_amount_101.npz
#   ✓ Saved loss landscape for amount=102 as landscape_index_102_amount_102.npz
#   ✓ Saved loss landscape for amount=103 as landscape_index_103_amount_103.npz
#   ✓ Saved loss landscape for amount=104 as landscape_index_104_amount_104.npz
#   ✓ Saved loss landscape for amount=105 as landscape_index_105_amount_105.npz
#   ✓ Saved loss landscape for amount=106 as landscape_index_106_amount_106.npz
#   ✓ Saved loss landscape for amount=107 as landscape_index_107_amount_107.npz
#   ✓ Saved loss landscape for amount=108 as landscape_index_108_amount_108.npz
#   ✓ Saved loss landscape for amount=109 as landscape_index_109_amount_109.npz
#   ✓ Saved loss landscape for amount=110 as landscape_index_110_amount_110.npz
#   ✓ Saved loss landscape for amount=111 as landscape_index_111_amount_111.npz
#   ✓ Saved loss landscape for amount=112 as landscape_index_112_amount_112.npz
#   ✓ Saved loss landscape for amount=113 as landscape_index_113_amount_113.npz
#   ✓ Saved loss landscape for amount=114 as landscape_index_114_amount_114.npz
#   ✓ Saved loss landscape for amount=115 as landscape_index_115_amount_115.npz
#   ✓ Saved loss landscape for amount=116 as landscape_index_116_amount_116.npz
#   ✓ Saved loss landscape for amount=117 as landscape_index_117_amount_117.npz
#   ✓ Saved loss landscape for amount=118 as landscape_index_118_amount_118.npz
#   ✓ Saved loss landscape for amount=119 as landscape_index_119_amount_119.npz
#   ✓ Saved loss landscape for amount=120 as landscape_index_120_amount_120.npz
#   ✓ Saved loss landscape for amount=121 as landscape_index_121_amount_121.npz
#   ✓ Saved loss landscape for amount=122 as landscape_index_122_amount_122.npz
#   ✓ Saved loss landscape for amount=123 as landscape_index_123_amount_123.npz
#   ✓ Saved loss landscape for amount=124 as landscape_index_124_amount_124.npz
#   ✓ Saved loss landscape for amount=125 as landscape_index_125_amount_125.npz
#   ✓ Saved loss landscape for amount=126 as landscape_index_126_amount_126.npz
#   ✓ Saved loss landscape for amount=127 as landscape_index_127_amount_127.npz
#   ✓ Saved loss landscape for amount=128 as landscape_index_128_amount_128.npz
#   ✓ Saved loss landscape for amount=129 as landscape_index_129_amount_129.npz
#   ✓ Saved loss landscape for amount=130 as landscape_index_130_amount_130.npz
#   ✓ Saved loss landscape for amount=131 as landscape_index_131_amount_131.npz
#   ✓ Saved loss landscape for amount=132 as landscape_index_132_amount_132.npz
#   ✓ Saved loss landscape for amount=133 as landscape_index_133_amount_133.npz
#   ✓ Saved loss landscape for amount=134 as landscape_index_134_amount_134.npz
#   ✓ Saved loss landscape for amount=135 as landscape_index_135_amount_135.npz
#   ✓ Saved loss landscape for amount=136 as landscape_index_136_amount_136.npz
#   ✓ Saved loss landscape for amount=137 as landscape_index_137_amount_137.npz
#   ✓ Saved loss landscape for amount=138 as landscape_index_138_amount_138.npz
#   ✓ Saved loss landscape for amount=139 as landscape_index_139_amount_139.npz
#   ✓ Saved loss landscape for amount=140 as landscape_index_140_amount_140.npz
#   ✓ Saved loss landscape for amount=141 as landscape_index_141_amount_141.npz
#   ✓ Saved loss landscape for amount=142 as landscape_index_142_amount_142.npz
#   ✓ Saved loss landscape for amount=143 as landscape_index_143_amount_143.npz
#   ✓ Saved loss landscape for amount=144 as landscape_index_144_amount_144.npz
#   ✓ Saved loss landscape for amount=145 as landscape_index_145_amount_145.npz
#   ✓ Saved loss landscape for amount=146 as landscape_index_146_amount_146.npz
#   ✓ Saved loss landscape for amount=147 as landscape_index_147_amount_147.npz
#   ✓ Saved loss landscape for amount=148 as landscape_index_148_amount_148.npz
#   ✓ Saved loss landscape for amount=149 as landscape_index_149_amount_149.npz
#   ✓ Saved loss landscape for amount=150 as landscape_index_150_amount_150.npz
#   ✓ Saved loss landscape for amount=151 as landscape_index_151_amount_151.npz
#   ✓ Saved loss landscape for amount=152 as landscape_index_152_amount_152.npz
#   ✓ Saved loss landscape for amount=153 as landscape_index_153_amount_153.npz
#   ✓ Saved loss landscape for amount=154 as landscape_index_154_amount_154.npz
#   ✓ Saved loss landscape for amount=155 as landscape_index_155_amount_155.npz
#   ✓ Saved loss landscape for amount=156 as landscape_index_156_amount_156.npz
#   ✓ Saved loss landscape for amount=157 as landscape_index_157_amount_157.npz
#   ✓ Saved loss landscape for amount=158 as landscape_index_158_amount_158.npz
#   ✓ Saved loss landscape for amount=159 as landscape_index_159_amount_159.npz
#   ✓ Saved loss landscape for amount=160 as landscape_index_160_amount_160.npz
#   ✓ Saved loss landscape for amount=161 as landscape_index_161_amount_161.npz
#   ✓ Saved loss landscape for amount=162 as landscape_index_162_amount_162.npz
#   ✓ Saved loss landscape for amount=163 as landscape_index_163_amount_163.npz
#   ✓ Saved loss landscape for amount=164 as landscape_index_164_amount_164.npz
#   ✓ Saved loss landscape for amount=165 as landscape_index_165_amount_165.npz
#   ✓ Saved loss landscape for amount=166 as landscape_index_166_amount_166.npz
#   ✓ Saved loss landscape for amount=167 as landscape_index_167_amount_167.npz
#   ✓ Saved loss landscape for amount=168 as landscape_index_168_amount_168.npz
#   ✓ Saved loss landscape for amount=169 as landscape_index_169_amount_169.npz
#   ✓ Saved loss landscape for amount=170 as landscape_index_170_amount_170.npz
#   ✓ Saved loss landscape for amount=171 as landscape_index_171_amount_171.npz
#   ✓ Saved loss landscape for amount=172 as landscape_index_172_amount_172.npz
#   ✓ Saved loss landscape for amount=173 as landscape_index_173_amount_173.npz
#   ✓ Saved loss landscape for amount=174 as landscape_index_174_amount_174.npz
#   ✓ Saved loss landscape for amount=175 as landscape_index_175_amount_175.npz
#   ✓ Saved loss landscape for amount=176 as landscape_index_176_amount_176.npz
#   ✓ Saved loss landscape for amount=177 as landscape_index_177_amount_177.npz
#   ✓ Saved loss landscape for amount=178 as landscape_index_178_amount_178.npz
#   ✓ Saved loss landscape for amount=179 as landscape_index_179_amount_179.npz
#   ✓ Saved loss landscape for amount=180 as landscape_index_180_amount_180.npz
#   ✓ Saved loss landscape for amount=181 as landscape_index_181_amount_181.npz
#   ✓ Saved loss landscape for amount=182 as landscape_index_182_amount_182.npz
#   ✓ Saved loss landscape for amount=183 as landscape_index_183_amount_183.npz
#   ✓ Saved loss landscape for amount=184 as landscape_index_184_amount_184.npz
#   ✓ Saved loss landscape for amount=185 as landscape_index_185_amount_185.npz
#   ✓ Saved loss landscape for amount=186 as landscape_index_186_amount_186.npz
#   ✓ Saved loss landscape for amount=187 as landscape_index_187_amount_187.npz
#   ✓ Saved loss landscape for amount=188 as landscape_index_188_amount_188.npz
#   ✓ Saved loss landscape for amount=189 as landscape_index_189_amount_189.npz
#   ✓ Saved loss landscape for amount=190 as landscape_index_190_amount_190.npz
#   ✓ Saved loss landscape for amount=191 as landscape_index_191_amount_191.npz
#   ✓ Saved loss landscape for amount=192 as landscape_index_192_amount_192.npz
#   ✓ Saved loss landscape for amount=193 as landscape_index_193_amount_193.npz
#   ✓ Saved loss landscape for amount=194 as landscape_index_194_amount_194.npz
#   ✓ Saved loss landscape for amount=195 as landscape_index_195_amount_195.npz
#   ✓ Saved loss landscape for amount=196 as landscape_index_196_amount_196.npz
#   ✓ Saved loss landscape for amount=197 as landscape_index_197_amount_197.npz
#   ✓ Saved loss landscape for amount=198 as landscape_index_198_amount_198.npz
#   ✓ Saved loss landscape for amount=199 as landscape_index_199_amount_199.npz
#   ✓ Saved loss landscape for amount=200 as landscape_index_200_amount_200.npz
#   ✓ Saved loss landscape for amount=201 as landscape_index_201_amount_201.npz
#   ✓ Saved loss landscape for amount=202 as landscape_index_202_amount_202.npz
#   ✓ Saved loss landscape for amount=203 as landscape_index_203_amount_203.npz
#   ✓ Saved loss landscape for amount=204 as landscape_index_204_amount_204.npz
#   ✓ Saved loss landscape for amount=205 as landscape_index_205_amount_205.npz
#   ✓ Saved loss landscape for amount=206 as landscape_index_206_amount_206.npz
#   ✓ Saved loss landscape for amount=207 as landscape_index_207_amount_207.npz
#   ✓ Saved loss landscape for amount=208 as landscape_index_208_amount_208.npz
#   ✓ Saved loss landscape for amount=209 as landscape_index_209_amount_209.npz
#   ✓ Saved loss landscape for amount=210 as landscape_index_210_amount_210.npz
#   ✓ Saved loss landscape for amount=211 as landscape_index_211_amount_211.npz
#   ✓ Saved loss landscape for amount=212 as landscape_index_212_amount_212.npz
#   ✓ Saved loss landscape for amount=213 as landscape_index_213_amount_213.npz
#   ✓ Saved loss landscape for amount=214 as landscape_index_214_amount_214.npz
#   ✓ Saved loss landscape for amount=215 as landscape_index_215_amount_215.npz
#   ✓ Saved loss landscape for amount=216 as landscape_index_216_amount_216.npz
#   ✓ Saved loss landscape for amount=217 as landscape_index_217_amount_217.npz
#   ✓ Saved loss landscape for amount=218 as landscape_index_218_amount_218.npz
#   ✓ Saved loss landscape for amount=219 as landscape_index_219_amount_219.npz
#   ✓ Saved loss landscape for amount=220 as landscape_index_220_amount_220.npz
#   ✓ Saved loss landscape for amount=221 as landscape_index_221_amount_221.npz
#   ✓ Saved loss landscape for amount=222 as landscape_index_222_amount_222.npz
#   ✓ Saved loss landscape for amount=223 as landscape_index_223_amount_223.npz
#   ✓ Saved loss landscape for amount=224 as landscape_index_224_amount_224.npz
#   ✓ Saved loss landscape for amount=225 as landscape_index_225_amount_225.npz
#   ✓ Saved loss landscape for amount=226 as landscape_index_226_amount_226.npz
#   ✓ Saved loss landscape for amount=227 as landscape_index_227_amount_227.npz
#   ✓ Saved loss landscape for amount=228 as landscape_index_228_amount_228.npz
#   ✓ Saved loss landscape for amount=229 as landscape_index_229_amount_229.npz
#   ✓ Saved loss landscape for amount=230 as landscape_index_230_amount_230.npz
#   ✓ Saved loss landscape for amount=231 as landscape_index_231_amount_231.npz
#   ✓ Saved loss landscape for amount=232 as landscape_index_232_amount_232.npz
#   ✓ Saved loss landscape for amount=233 as landscape_index_233_amount_233.npz
#   ✓ Saved loss landscape for amount=234 as landscape_index_234_amount_234.npz
#   ✓ Saved loss landscape for amount=235 as landscape_index_235_amount_235.npz
#   ✓ Saved loss landscape for amount=236 as landscape_index_236_amount_236.npz
#   ✓ Saved loss landscape for amount=237 as landscape_index_237_amount_237.npz
#   ✓ Saved loss landscape for amount=238 as landscape_index_238_amount_238.npz
#   ✓ Saved loss landscape for amount=239 as landscape_index_239_amount_239.npz
#   ✓ Saved loss landscape for amount=240 as landscape_index_240_amount_240.npz
#   ✓ Saved loss landscape for amount=241 as landscape_index_241_amount_241.npz
#   ✓ Saved loss landscape for amount=242 as landscape_index_242_amount_242.npz
#   ✓ Saved loss landscape for amount=243 as landscape_index_243_amount_243.npz
#   ✓ Saved loss landscape for amount=244 as landscape_index_244_amount_244.npz
#   ✓ Saved loss landscape for amount=245 as landscape_index_245_amount_245.npz
#   ✓ Saved loss landscape for amount=246 as landscape_index_246_amount_246.npz
#   ✓ Saved loss landscape for amount=247 as landscape_index_247_amount_247.npz
#   ✓ Saved loss landscape for amount=248 as landscape_index_248_amount_248.npz
#   ✓ Saved loss landscape for amount=249 as landscape_index_249_amount_249.npz
#   ✓ Saved loss landscape for amount=250 as landscape_index_250_amount_250.npz
#   ✓ Saved loss landscape for amount=251 as landscape_index_251_amount_251.npz
#   ✓ Saved loss landscape for amount=252 as landscape_index_252_amount_252.npz
#   ✓ Saved loss landscape for amount=253 as landscape_index_253_amount_253.npz
#   ✓ Saved loss landscape for amount=254 as landscape_index_254_amount_254.npz
#   ✓ Saved loss landscape for amount=255 as landscape_index_255_amount_255.npz
#   ✓ Saved loss landscape for amount=256 as landscape_index_256_amount_256.npz
#   ✓ Saved loss landscape for amount=257 as landscape_index_257_amount_257.npz
#   ✓ Saved loss landscape for amount=258 as landscape_index_258_amount_258.npz
#   ✓ Saved loss landscape for amount=259 as landscape_index_259_amount_259.npz
#   ✓ Saved loss landscape for amount=260 as landscape_index_260_amount_260.npz
#   ✓ Saved loss landscape for amount=261 as landscape_index_261_amount_261.npz
#   ✓ Saved loss landscape for amount=262 as landscape_index_262_amount_262.npz
#   ✓ Saved loss landscape for amount=263 as landscape_index_263_amount_263.npz
#   ✓ Saved loss landscape for amount=264 as landscape_index_264_amount_264.npz
#   ✓ Saved loss landscape for amount=265 as landscape_index_265_amount_265.npz
#   ✓ Saved loss landscape for amount=266 as landscape_index_266_amount_266.npz
#   ✓ Saved loss landscape for amount=267 as landscape_index_267_amount_267.npz
#   ✓ Saved loss landscape for amount=268 as landscape_index_268_amount_268.npz
#   ✓ Saved loss landscape for amount=269 as landscape_index_269_amount_269.npz
#   ✓ Saved loss landscape for amount=270 as landscape_index_270_amount_270.npz
#   ✓ Saved loss landscape for amount=271 as landscape_index_271_amount_271.npz
#   ✓ Saved loss landscape for amount=272 as landscape_index_272_amount_272.npz
#   ✓ Saved loss landscape for amount=273 as landscape_index_273_amount_273.npz
#   ✓ Saved loss landscape for amount=274 as landscape_index_274_amount_274.npz
#   ✓ Saved loss landscape for amount=275 as landscape_index_275_amount_275.npz
#   ✓ Saved loss landscape for amount=276 as landscape_index_276_amount_276.npz
#   ✓ Saved loss landscape for amount=277 as landscape_index_277_amount_277.npz
#   ✓ Saved loss landscape for amount=278 as landscape_index_278_amount_278.npz
#   ✓ Saved loss landscape for amount=279 as landscape_index_279_amount_279.npz
#   ✓ Saved loss landscape for amount=280 as landscape_index_280_amount_280.npz
#   ✓ Saved loss landscape for amount=281 as landscape_index_281_amount_281.npz
#   ✓ Saved loss landscape for amount=282 as landscape_index_282_amount_282.npz
#   ✓ Saved loss landscape for amount=283 as landscape_index_283_amount_283.npz
#   ✓ Saved loss landscape for amount=284 as landscape_index_284_amount_284.npz
#   ✓ Saved loss landscape for amount=285 as landscape_index_285_amount_285.npz
#   ✓ Saved loss landscape for amount=286 as landscape_index_286_amount_286.npz
#   ✓ Saved loss landscape for amount=287 as landscape_index_287_amount_287.npz
#   ✓ Saved loss landscape for amount=288 as landscape_index_288_amount_288.npz
#   ✓ Saved loss landscape for amount=289 as landscape_index_289_amount_289.npz
#   ✓ Saved loss landscape for amount=290 as landscape_index_290_amount_290.npz
#   ✓ Saved loss landscape for amount=291 as landscape_index_291_amount_291.npz
#   ✓ Saved loss landscape for amount=292 as landscape_index_292_amount_292.npz
#   ✓ Saved loss landscape for amount=293 as landscape_index_293_amount_293.npz
#   ✓ Saved loss landscape for amount=294 as landscape_index_294_amount_294.npz
#   ✓ Saved loss landscape for amount=295 as landscape_index_295_amount_295.npz
#   ✓ Saved loss landscape for amount=296 as landscape_index_296_amount_296.npz
#   ✓ Saved loss landscape for amount=297 as landscape_index_297_amount_297.npz
#   ✓ Saved loss landscape for amount=298 as landscape_index_298_amount_298.npz
#   ✓ Saved loss landscape for amount=299 as landscape_index_299_amount_299.npz
#   ✓ Saved loss landscape for amount=300 as landscape_index_300_amount_300.npz
#   ✓ Saved loss landscape for amount=301 as landscape_index_301_amount_301.npz
#   ✓ Saved loss landscape for amount=302 as landscape_index_302_amount_302.npz
#   ✓ Saved loss landscape for amount=303 as landscape_index_303_amount_303.npz
#   ✓ Saved loss landscape for amount=304 as landscape_index_304_amount_304.npz
#   ✓ Saved loss landscape for amount=305 as landscape_index_305_amount_305.npz
#   ✓ Saved loss landscape for amount=306 as landscape_index_306_amount_306.npz
#   ✓ Saved loss landscape for amount=307 as landscape_index_307_amount_307.npz
#   ✓ Saved loss landscape for amount=308 as landscape_index_308_amount_308.npz
#   ✓ Saved loss landscape for amount=309 as landscape_index_309_amount_309.npz
#   ✓ Saved loss landscape for amount=310 as landscape_index_310_amount_310.npz
#   ✓ Saved loss landscape for amount=311 as landscape_index_311_amount_311.npz
#   ✓ Saved loss landscape for amount=312 as landscape_index_312_amount_312.npz
#   ✓ Saved loss landscape for amount=313 as landscape_index_313_amount_313.npz
#   ✓ Saved loss landscape for amount=314 as landscape_index_314_amount_314.npz
#   ✓ Saved loss landscape for amount=315 as landscape_index_315_amount_315.npz
#   ✓ Saved loss landscape for amount=316 as landscape_index_316_amount_316.npz
#   ✓ Saved loss landscape for amount=317 as landscape_index_317_amount_317.npz
#   ✓ Saved loss landscape for amount=318 as landscape_index_318_amount_318.npz
#   ✓ Saved loss landscape for amount=319 as landscape_index_319_amount_319.npz
#   ✓ Saved loss landscape for amount=320 as landscape_index_320_amount_320.npz
#   ✓ Saved loss landscape for amount=321 as landscape_index_321_amount_321.npz
#   ✓ Saved loss landscape for amount=322 as landscape_index_322_amount_322.npz
#   ✓ Saved loss landscape for amount=323 as landscape_index_323_amount_323.npz
#   ✓ Saved loss landscape for amount=324 as landscape_index_324_amount_324.npz
#   ✓ Saved loss landscape for amount=325 as landscape_index_325_amount_325.npz
#   ✓ Saved loss landscape for amount=326 as landscape_index_326_amount_326.npz
#   ✓ Saved loss landscape for amount=327 as landscape_index_327_amount_327.npz
#   ✓ Saved loss landscape for amount=328 as landscape_index_328_amount_328.npz
#   ✓ Saved loss landscape for amount=329 as landscape_index_329_amount_329.npz
#   ✓ Saved loss landscape for amount=330 as landscape_index_330_amount_330.npz
#   ✓ Saved loss landscape for amount=331 as landscape_index_331_amount_331.npz
#   ✓ Saved loss landscape for amount=332 as landscape_index_332_amount_332.npz
#   ✓ Saved loss landscape for amount=333 as landscape_index_333_amount_333.npz
#   ✓ Saved loss landscape for amount=334 as landscape_index_334_amount_334.npz
#   ✓ Saved loss landscape for amount=335 as landscape_index_335_amount_335.npz
#   ✓ Saved loss landscape for amount=336 as landscape_index_336_amount_336.npz
#   ✓ Saved loss landscape for amount=337 as landscape_index_337_amount_337.npz
#   ✓ Saved loss landscape for amount=338 as landscape_index_338_amount_338.npz
#   ✓ Saved loss landscape for amount=339 as landscape_index_339_amount_339.npz
#   ✓ Saved loss landscape for amount=340 as landscape_index_340_amount_340.npz
#   ✓ Saved loss landscape for amount=341 as landscape_index_341_amount_341.npz
#   ✓ Saved loss landscape for amount=342 as landscape_index_342_amount_342.npz
#   ✓ Saved loss landscape for amount=343 as landscape_index_343_amount_343.npz
#   ✓ Saved loss landscape for amount=344 as landscape_index_344_amount_344.npz
#   ✓ Saved loss landscape for amount=345 as landscape_index_345_amount_345.npz
#   ✓ Saved loss landscape for amount=346 as landscape_index_346_amount_346.npz
#   ✓ Saved loss landscape for amount=347 as landscape_index_347_amount_347.npz
#   ✓ Saved loss landscape for amount=348 as landscape_index_348_amount_348.npz
#   ✓ Saved loss landscape for amount=349 as landscape_index_349_amount_349.npz
#   ✓ Saved loss landscape for amount=350 as landscape_index_350_amount_350.npz
#   ✓ Saved loss landscape for amount=351 as landscape_index_351_amount_351.npz
#   ✓ Saved loss landscape for amount=352 as landscape_index_352_amount_352.npz
#   ✓ Saved loss landscape for amount=353 as landscape_index_353_amount_353.npz
#   ✓ Saved loss landscape for amount=354 as landscape_index_354_amount_354.npz
#   ✓ Saved loss landscape for amount=355 as landscape_index_355_amount_355.npz
#   ✓ Saved loss landscape for amount=356 as landscape_index_356_amount_356.npz
#   ✓ Saved loss landscape for amount=357 as landscape_index_357_amount_357.npz
#   ✓ Saved loss landscape for amount=358 as landscape_index_358_amount_358.npz
#   ✓ Saved loss landscape for amount=359 as landscape_index_359_amount_359.npz
#   ✓ Saved loss landscape for amount=360 as landscape_index_360_amount_360.npz
#   ✓ Saved loss landscape for amount=361 as landscape_index_361_amount_361.npz
#   ✓ Saved loss landscape for amount=362 as landscape_index_362_amount_362.npz
#   ✓ Saved loss landscape for amount=363 as landscape_index_363_amount_363.npz
#   ✓ Saved loss landscape for amount=364 as landscape_index_364_amount_364.npz
#   ✓ Saved loss landscape for amount=365 as landscape_index_365_amount_365.npz
#   ✓ Saved loss landscape for amount=366 as landscape_index_366_amount_366.npz
#   ✓ Saved loss landscape for amount=367 as landscape_index_367_amount_367.npz
#   ✓ Saved loss landscape for amount=368 as landscape_index_368_amount_368.npz
#   ✓ Saved loss landscape for amount=369 as landscape_index_369_amount_369.npz
#   ✓ Saved loss landscape for amount=370 as landscape_index_370_amount_370.npz
#   ✓ Saved loss landscape for amount=371 as landscape_index_371_amount_371.npz
#   ✓ Saved loss landscape for amount=372 as landscape_index_372_amount_372.npz
#   ✓ Saved loss landscape for amount=373 as landscape_index_373_amount_373.npz
#   ✓ Saved loss landscape for amount=374 as landscape_index_374_amount_374.npz
#   ✓ Saved loss landscape for amount=375 as landscape_index_375_amount_375.npz
#   ✓ Saved loss landscape for amount=376 as landscape_index_376_amount_376.npz
#   ✓ Saved loss landscape for amount=377 as landscape_index_377_amount_377.npz
#   ✓ Saved loss landscape for amount=378 as landscape_index_378_amount_378.npz
#   ✓ Saved loss landscape for amount=379 as landscape_index_379_amount_379.npz
#   ✓ Saved loss landscape for amount=380 as landscape_index_380_amount_380.npz
#   ✓ Saved loss landscape for amount=381 as landscape_index_381_amount_381.npz
#   ✓ Saved loss landscape for amount=382 as landscape_index_382_amount_382.npz
#   ✓ Saved loss landscape for amount=383 as landscape_index_383_amount_383.npz
#   ✓ Saved loss landscape for amount=384 as landscape_index_384_amount_384.npz
#   ✓ Saved loss landscape for amount=385 as landscape_index_385_amount_385.npz
#   ✓ Saved loss landscape for amount=386 as landscape_index_386_amount_386.npz
#   ✓ Saved loss landscape for amount=387 as landscape_index_387_amount_387.npz
#   ✓ Saved loss landscape for amount=388 as landscape_index_388_amount_388.npz
#   ✓ Saved loss landscape for amount=389 as landscape_index_389_amount_389.npz
#   ✓ Saved loss landscape for amount=390 as landscape_index_390_amount_390.npz
#   ✓ Saved loss landscape for amount=391 as landscape_index_391_amount_391.npz
#   ✓ Saved loss landscape for amount=392 as landscape_index_392_amount_392.npz
#   ✓ Saved loss landscape for amount=393 as landscape_index_393_amount_393.npz
#   ✓ Saved loss landscape for amount=394 as landscape_index_394_amount_394.npz
#   ✓ Saved loss landscape for amount=395 as landscape_index_395_amount_395.npz
#   ✓ Saved loss landscape for amount=396 as landscape_index_396_amount_396.npz
#   ✓ Saved loss landscape for amount=397 as landscape_index_397_amount_397.npz
#   ✓ Saved loss landscape for amount=398 as landscape_index_398_amount_398.npz
#   ✓ Saved loss landscape for amount=399 as landscape_index_399_amount_399.npz
#   ✓ Saved loss landscape for amount=400 as landscape_index_400_amount_400.npz
#   ✓ Saved loss landscape for amount=401 as landscape_index_401_amount_401.npz
#   ✓ Saved loss landscape for amount=402 as landscape_index_402_amount_402.npz
#   ✓ Saved loss landscape for amount=403 as landscape_index_403_amount_403.npz
#   ✓ Saved loss landscape for amount=404 as landscape_index_404_amount_404.npz
#   ✓ Saved loss landscape for amount=405 as landscape_index_405_amount_405.npz
#   ✓ Saved loss landscape for amount=406 as landscape_index_406_amount_406.npz
#   ✓ Saved loss landscape for amount=407 as landscape_index_407_amount_407.npz
#   ✓ Saved loss landscape for amount=408 as landscape_index_408_amount_408.npz
#   ✓ Saved loss landscape for amount=409 as landscape_index_409_amount_409.npz
#   ✓ Saved loss landscape for amount=410 as landscape_index_410_amount_410.npz
#   ✓ Saved loss landscape for amount=411 as landscape_index_411_amount_411.npz
#   ✓ Saved loss landscape for amount=412 as landscape_index_412_amount_412.npz
#   ✓ Saved loss landscape for amount=413 as landscape_index_413_amount_413.npz
#   ✓ Saved loss landscape for amount=414 as landscape_index_414_amount_414.npz
#   ✓ Saved loss landscape for amount=415 as landscape_index_415_amount_415.npz
#   ✓ Saved loss landscape for amount=416 as landscape_index_416_amount_416.npz
#   ✓ Saved loss landscape for amount=417 as landscape_index_417_amount_417.npz
#   ✓ Saved loss landscape for amount=418 as landscape_index_418_amount_418.npz
#   ✓ Saved loss landscape for amount=419 as landscape_index_419_amount_419.npz
#   ✓ Saved loss landscape for amount=420 as landscape_index_420_amount_420.npz
#   ✓ Saved loss landscape for amount=421 as landscape_index_421_amount_421.npz
#   ✓ Saved loss landscape for amount=422 as landscape_index_422_amount_422.npz
#   ✓ Saved loss landscape for amount=423 as landscape_index_423_amount_423.npz
#   ✓ Saved loss landscape for amount=424 as landscape_index_424_amount_424.npz
#   ✓ Saved loss landscape for amount=425 as landscape_index_425_amount_425.npz
#   ✓ Saved loss landscape for amount=426 as landscape_index_426_amount_426.npz
#   ✓ Saved loss landscape for amount=427 as landscape_index_427_amount_427.npz
#   ✓ Saved loss landscape for amount=428 as landscape_index_428_amount_428.npz
#   ✓ Saved loss landscape for amount=429 as landscape_index_429_amount_429.npz
#   ✓ Saved loss landscape for amount=430 as landscape_index_430_amount_430.npz
#   ✓ Saved loss landscape for amount=431 as landscape_index_431_amount_431.npz
#   ✓ Saved loss landscape for amount=432 as landscape_index_432_amount_432.npz
#   ✓ Saved loss landscape for amount=433 as landscape_index_433_amount_433.npz
#   ✓ Saved loss landscape for amount=434 as landscape_index_434_amount_434.npz
#   ✓ Saved loss landscape for amount=435 as landscape_index_435_amount_435.npz
#   ✓ Saved loss landscape for amount=436 as landscape_index_436_amount_436.npz
#   ✓ Saved loss landscape for amount=437 as landscape_index_437_amount_437.npz
#   ✓ Saved loss landscape for amount=438 as landscape_index_438_amount_438.npz
#   ✓ Saved loss landscape for amount=439 as landscape_index_439_amount_439.npz
#   ✓ Saved loss landscape for amount=440 as landscape_index_440_amount_440.npz
#   ✓ Saved loss landscape for amount=441 as landscape_index_441_amount_441.npz
#   ✓ Saved loss landscape for amount=442 as landscape_index_442_amount_442.npz
#   ✓ Saved loss landscape for amount=443 as landscape_index_443_amount_443.npz
#   ✓ Saved loss landscape for amount=444 as landscape_index_444_amount_444.npz
#   ✓ Saved loss landscape for amount=445 as landscape_index_445_amount_445.npz
#   ✓ Saved loss landscape for amount=446 as landscape_index_446_amount_446.npz
#   ✓ Saved loss landscape for amount=447 as landscape_index_447_amount_447.npz
#   ✓ Saved loss landscape for amount=448 as landscape_index_448_amount_448.npz
#   ✓ Saved loss landscape for amount=449 as landscape_index_449_amount_449.npz
#   ✓ Saved loss landscape for amount=450 as landscape_index_450_amount_450.npz
#   ✓ Saved loss landscape for amount=451 as landscape_index_451_amount_451.npz
#   ✓ Saved loss landscape for amount=452 as landscape_index_452_amount_452.npz
#   ✓ Saved loss landscape for amount=453 as landscape_index_453_amount_453.npz
#   ✓ Saved loss landscape for amount=454 as landscape_index_454_amount_454.npz
#   ✓ Saved loss landscape for amount=455 as landscape_index_455_amount_455.npz
#   ✓ Saved loss landscape for amount=456 as landscape_index_456_amount_456.npz
#   ✓ Saved loss landscape for amount=457 as landscape_index_457_amount_457.npz
#   ✓ Saved loss landscape for amount=458 as landscape_index_458_amount_458.npz
#   ✓ Saved loss landscape for amount=459 as landscape_index_459_amount_459.npz
#   ✓ Saved loss landscape for amount=460 as landscape_index_460_amount_460.npz
#   ✓ Saved loss landscape for amount=461 as landscape_index_461_amount_461.npz
#   ✓ Saved loss landscape for amount=462 as landscape_index_462_amount_462.npz
#   ✓ Saved loss landscape for amount=463 as landscape_index_463_amount_463.npz
#   ✓ Saved loss landscape for amount=464 as landscape_index_464_amount_464.npz
#   ✓ Saved loss landscape for amount=465 as landscape_index_465_amount_465.npz
#   ✓ Saved loss landscape for amount=466 as landscape_index_466_amount_466.npz
#   ✓ Saved loss landscape for amount=467 as landscape_index_467_amount_467.npz
#   ✓ Saved loss landscape for amount=468 as landscape_index_468_amount_468.npz
#   ✓ Saved loss landscape for amount=469 as landscape_index_469_amount_469.npz
#   ✓ Saved loss landscape for amount=470 as landscape_index_470_amount_470.npz
#   ✓ Saved loss landscape for amount=471 as landscape_index_471_amount_471.npz
#   ✓ Saved loss landscape for amount=472 as landscape_index_472_amount_472.npz
#   ✓ Saved loss landscape for amount=473 as landscape_index_473_amount_473.npz
#   ✓ Saved loss landscape for amount=474 as landscape_index_474_amount_474.npz
#   ✓ Saved loss landscape for amount=475 as landscape_index_475_amount_475.npz
#   ✓ Saved loss landscape for amount=476 as landscape_index_476_amount_476.npz
#   ✓ Saved loss landscape for amount=477 as landscape_index_477_amount_477.npz
#   ✓ Saved loss landscape for amount=478 as landscape_index_478_amount_478.npz
#   ✓ Saved loss landscape for amount=479 as landscape_index_479_amount_479.npz
#   ✓ Saved loss landscape for amount=480 as landscape_index_480_amount_480.npz
#   ✓ Saved loss landscape for amount=481 as landscape_index_481_amount_481.npz
#   ✓ Saved loss landscape for amount=482 as landscape_index_482_amount_482.npz
#   ✓ Saved loss landscape for amount=483 as landscape_index_483_amount_483.npz
#   ✓ Saved loss landscape for amount=484 as landscape_index_484_amount_484.npz
#   ✓ Saved loss landscape for amount=485 as landscape_index_485_amount_485.npz
#   ✓ Saved loss landscape for amount=486 as landscape_index_486_amount_486.npz
#   ✓ Saved loss landscape for amount=487 as landscape_index_487_amount_487.npz
#   ✓ Saved loss landscape for amount=488 as landscape_index_488_amount_488.npz
#   ✓ Saved loss landscape for amount=489 as landscape_index_489_amount_489.npz
#   ✓ Saved loss landscape for amount=490 as landscape_index_490_amount_490.npz
#   ✓ Saved loss landscape for amount=491 as landscape_index_491_amount_491.npz
#   ✓ Saved loss landscape for amount=492 as landscape_index_492_amount_492.npz
#   ✓ Saved loss landscape for amount=493 as landscape_index_493_amount_493.npz
#   ✓ Saved loss landscape for amount=494 as landscape_index_494_amount_494.npz
#   ✓ Saved loss landscape for amount=495 as landscape_index_495_amount_495.npz
#   ✓ Saved loss landscape for amount=496 as landscape_index_496_amount_496.npz
#   ✓ Saved loss landscape for amount=497 as landscape_index_497_amount_497.npz
#   ✓ Saved loss landscape for amount=498 as landscape_index_498_amount_498.npz
#   ✓ Saved loss landscape for amount=499 as landscape_index_499_amount_499.npz
#   ✓ Saved loss landscape for amount=500 as landscape_index_500_amount_500.npz
#   ✓ Saved loss landscape for amount=501 as landscape_index_501_amount_501.npz
#   ✓ Saved loss landscape for amount=502 as landscape_index_502_amount_502.npz
#   ✓ Saved loss landscape for amount=503 as landscape_index_503_amount_503.npz
#   ✓ Saved loss landscape for amount=504 as landscape_index_504_amount_504.npz
#   ✓ Saved loss landscape for amount=505 as landscape_index_505_amount_505.npz
#   ✓ Saved loss landscape for amount=506 as landscape_index_506_amount_506.npz
#   ✓ Saved loss landscape for amount=507 as landscape_index_507_amount_507.npz
#   ✓ Saved loss landscape for amount=508 as landscape_index_508_amount_508.npz
#   ✓ Saved loss landscape for amount=509 as landscape_index_509_amount_509.npz
#   ✓ Saved loss landscape for amount=510 as landscape_index_510_amount_510.npz
#   ✓ Saved loss landscape for amount=511 as landscape_index_511_amount_511.npz
#   ✓ Saved loss landscape for amount=512 as landscape_index_512_amount_512.npz
#   ✓ Saved loss landscape for amount=513 as landscape_index_513_amount_513.npz
#   ✓ Saved loss landscape for amount=514 as landscape_index_514_amount_514.npz
#   ✓ Saved loss landscape for amount=515 as landscape_index_515_amount_515.npz
#   ✓ Saved loss landscape for amount=516 as landscape_index_516_amount_516.npz
#   ✓ Saved loss landscape for amount=517 as landscape_index_517_amount_517.npz
#   ✓ Saved loss landscape for amount=518 as landscape_index_518_amount_518.npz
#   ✓ Saved loss landscape for amount=519 as landscape_index_519_amount_519.npz
#   ✓ Saved loss landscape for amount=520 as landscape_index_520_amount_520.npz
#   ✓ Saved loss landscape for amount=521 as landscape_index_521_amount_521.npz
#   ✓ Saved loss landscape for amount=522 as landscape_index_522_amount_522.npz
#   ✓ Saved loss landscape for amount=523 as landscape_index_523_amount_523.npz
#   ✓ Saved loss landscape for amount=524 as landscape_index_524_amount_524.npz
#   ✓ Saved loss landscape for amount=525 as landscape_index_525_amount_525.npz
#   ✓ Saved loss landscape for amount=526 as landscape_index_526_amount_526.npz
#   ✓ Saved loss landscape for amount=527 as landscape_index_527_amount_527.npz
#   ✓ Saved loss landscape for amount=528 as landscape_index_528_amount_528.npz
#   ✓ Saved loss landscape for amount=529 as landscape_index_529_amount_529.npz
#   ✓ Saved loss landscape for amount=530 as landscape_index_530_amount_530.npz
#   ✓ Saved loss landscape for amount=531 as landscape_index_531_amount_531.npz
#   ✓ Saved loss landscape for amount=532 as landscape_index_532_amount_532.npz
#   ✓ Saved loss landscape for amount=533 as landscape_index_533_amount_533.npz
#   ✓ Saved loss landscape for amount=534 as landscape_index_534_amount_534.npz
#   ✓ Saved loss landscape for amount=535 as landscape_index_535_amount_535.npz
#   ✓ Saved loss landscape for amount=536 as landscape_index_536_amount_536.npz
#   ✓ Saved loss landscape for amount=537 as landscape_index_537_amount_537.npz
#   ✓ Saved loss landscape for amount=538 as landscape_index_538_amount_538.npz
#   ✓ Saved loss landscape for amount=539 as landscape_index_539_amount_539.npz
#   ✓ Saved loss landscape for amount=540 as landscape_index_540_amount_540.npz
#   ✓ Saved loss landscape for amount=541 as landscape_index_541_amount_541.npz
#   ✓ Saved loss landscape for amount=542 as landscape_index_542_amount_542.npz
#   ✓ Saved loss landscape for amount=543 as landscape_index_543_amount_543.npz
#   ✓ Saved loss landscape for amount=544 as landscape_index_544_amount_544.npz
#   ✓ Saved loss landscape for amount=545 as landscape_index_545_amount_545.npz
#   ✓ Saved loss landscape for amount=546 as landscape_index_546_amount_546.npz
#   ✓ Saved loss landscape for amount=547 as landscape_index_547_amount_547.npz
#   ✓ Saved loss landscape for amount=548 as landscape_index_548_amount_548.npz
#   ✓ Saved loss landscape for amount=549 as landscape_index_549_amount_549.npz
#   ✓ Saved loss landscape for amount=550 as landscape_index_550_amount_550.npz
#   ✓ Saved loss landscape for amount=551 as landscape_index_551_amount_551.npz
#   ✓ Saved loss landscape for amount=552 as landscape_index_552_amount_552.npz
#   ✓ Saved loss landscape for amount=553 as landscape_index_553_amount_553.npz
#   ✓ Saved loss landscape for amount=554 as landscape_index_554_amount_554.npz
#   ✓ Saved loss landscape for amount=555 as landscape_index_555_amount_555.npz
#   ✓ Saved loss landscape for amount=556 as landscape_index_556_amount_556.npz
#   ✓ Saved loss landscape for amount=557 as landscape_index_557_amount_557.npz
#   ✓ Saved loss landscape for amount=558 as landscape_index_558_amount_558.npz
#   ✓ Saved loss landscape for amount=559 as landscape_index_559_amount_559.npz
#   ✓ Saved loss landscape for amount=560 as landscape_index_560_amount_560.npz
#   ✓ Saved loss landscape for amount=561 as landscape_index_561_amount_561.npz
#   ✓ Saved loss landscape for amount=562 as landscape_index_562_amount_562.npz
#   ✓ Saved loss landscape for amount=563 as landscape_index_563_amount_563.npz
#   ✓ Saved loss landscape for amount=564 as landscape_index_564_amount_564.npz
#   ✓ Saved loss landscape for amount=565 as landscape_index_565_amount_565.npz
#   ✓ Saved loss landscape for amount=566 as landscape_index_566_amount_566.npz
#   ✓ Saved loss landscape for amount=567 as landscape_index_567_amount_567.npz
#   ✓ Saved loss landscape for amount=568 as landscape_index_568_amount_568.npz
#   ✓ Saved loss landscape for amount=569 as landscape_index_569_amount_569.npz
#   ✓ Saved loss landscape for amount=570 as landscape_index_570_amount_570.npz
#   ✓ Saved loss landscape for amount=571 as landscape_index_571_amount_571.npz
#   ✓ Saved loss landscape for amount=572 as landscape_index_572_amount_572.npz
#   ✓ Saved loss landscape for amount=573 as landscape_index_573_amount_573.npz
#   ✓ Saved loss landscape for amount=574 as landscape_index_574_amount_574.npz
#   ✓ Saved loss landscape for amount=575 as landscape_index_575_amount_575.npz
#   ✓ Saved loss landscape for amount=576 as landscape_index_576_amount_576.npz
#   ✓ Saved loss landscape for amount=577 as landscape_index_577_amount_577.npz
#   ✓ Saved loss landscape for amount=578 as landscape_index_578_amount_578.npz
#   ✓ Saved loss landscape for amount=579 as landscape_index_579_amount_579.npz
#   ✓ Saved loss landscape for amount=580 as landscape_index_580_amount_580.npz
#   ✓ Saved loss landscape for amount=581 as landscape_index_581_amount_581.npz
#   ✓ Saved loss landscape for amount=582 as landscape_index_582_amount_582.npz
#   ✓ Saved loss landscape for amount=583 as landscape_index_583_amount_583.npz
#   ✓ Saved loss landscape for amount=584 as landscape_index_584_amount_584.npz
#   ✓ Saved loss landscape for amount=585 as landscape_index_585_amount_585.npz
#   ✓ Saved loss landscape for amount=586 as landscape_index_586_amount_586.npz
#   ✓ Saved loss landscape for amount=587 as landscape_index_587_amount_587.npz
#   ✓ Saved loss landscape for amount=588 as landscape_index_588_amount_588.npz
#   ✓ Saved loss landscape for amount=589 as landscape_index_589_amount_589.npz
#   ✓ Saved loss landscape for amount=590 as landscape_index_590_amount_590.npz
#   ✓ Saved loss landscape for amount=591 as landscape_index_591_amount_591.npz
#   ✓ Saved loss landscape for amount=592 as landscape_index_592_amount_592.npz
#   ✓ Saved loss landscape for amount=593 as landscape_index_593_amount_593.npz
#   ✓ Saved loss landscape for amount=594 as landscape_index_594_amount_594.npz
#   ✓ Saved loss landscape for amount=595 as landscape_index_595_amount_595.npz
#   ✓ Saved loss landscape for amount=596 as landscape_index_596_amount_596.npz
#   ✓ Saved loss landscape for amount=597 as landscape_index_597_amount_597.npz
#   ✓ Saved loss landscape for amount=598 as landscape_index_598_amount_598.npz
#   ✓ Saved loss landscape for amount=599 as landscape_index_599_amount_599.npz
#   ✓ Saved loss landscape for amount=600 as landscape_index_600_amount_600.npz
#   ✓ Saved loss landscape for amount=601 as landscape_index_601_amount_601.npz
#   ✓ Saved loss landscape for amount=602 as landscape_index_602_amount_602.npz
#   ✓ Saved loss landscape for amount=603 as landscape_index_603_amount_603.npz
#   ✓ Saved loss landscape for amount=604 as landscape_index_604_amount_604.npz
#   ✓ Saved loss landscape for amount=605 as landscape_index_605_amount_605.npz
#   ✓ Saved loss landscape for amount=606 as landscape_index_606_amount_606.npz
#   ✓ Saved loss landscape for amount=607 as landscape_index_607_amount_607.npz
#   ✓ Saved loss landscape for amount=608 as landscape_index_608_amount_608.npz
#   ✓ Saved loss landscape for amount=609 as landscape_index_609_amount_609.npz
#   ✓ Saved loss landscape for amount=610 as landscape_index_610_amount_610.npz
#   ✓ Saved loss landscape for amount=611 as landscape_index_611_amount_611.npz
#   ✓ Saved loss landscape for amount=612 as landscape_index_612_amount_612.npz
#   ✓ Saved loss landscape for amount=613 as landscape_index_613_amount_613.npz
#   ✓ Saved loss landscape for amount=614 as landscape_index_614_amount_614.npz
#   ✓ Saved loss landscape for amount=615 as landscape_index_615_amount_615.npz
#   ✓ Saved loss landscape for amount=616 as landscape_index_616_amount_616.npz
#   ✓ Saved loss landscape for amount=617 as landscape_index_617_amount_617.npz
#   ✓ Saved loss landscape for amount=618 as landscape_index_618_amount_618.npz
#   ✓ Saved loss landscape for amount=619 as landscape_index_619_amount_619.npz
#   ✓ Saved loss landscape for amount=620 as landscape_index_620_amount_620.npz
#   ✓ Saved loss landscape for amount=621 as landscape_index_621_amount_621.npz
#   ✓ Saved loss landscape for amount=622 as landscape_index_622_amount_622.npz
#   ✓ Saved loss landscape for amount=623 as landscape_index_623_amount_623.npz
#   ✓ Saved loss landscape for amount=624 as landscape_index_624_amount_624.npz
#   ✓ Saved loss landscape for amount=625 as landscape_index_625_amount_625.npz
#   ✓ Saved loss landscape for amount=626 as landscape_index_626_amount_626.npz
#   ✓ Saved loss landscape for amount=627 as landscape_index_627_amount_627.npz
#   ✓ Saved loss landscape for amount=628 as landscape_index_628_amount_628.npz
#   ✓ Saved loss landscape for amount=629 as landscape_index_629_amount_629.npz
#   ✓ Saved loss landscape for amount=630 as landscape_index_630_amount_630.npz
#   ✓ Saved loss landscape for amount=631 as landscape_index_631_amount_631.npz
#   ✓ Saved loss landscape for amount=632 as landscape_index_632_amount_632.npz
#   ✓ Saved loss landscape for amount=633 as landscape_index_633_amount_633.npz
#   ✓ Saved loss landscape for amount=634 as landscape_index_634_amount_634.npz
#   ✓ Saved loss landscape for amount=635 as landscape_index_635_amount_635.npz
#   ✓ Saved loss landscape for amount=636 as landscape_index_636_amount_636.npz
#   ✓ Saved loss landscape for amount=637 as landscape_index_637_amount_637.npz
#   ✓ Saved loss landscape for amount=638 as landscape_index_638_amount_638.npz
#   ✓ Saved loss landscape for amount=639 as landscape_index_639_amount_639.npz
#   ✓ Saved loss landscape for amount=640 as landscape_index_640_amount_640.npz
#   ✓ Saved loss landscape for amount=641 as landscape_index_641_amount_641.npz
#   ✓ Saved loss landscape for amount=642 as landscape_index_642_amount_642.npz
#   ✓ Saved loss landscape for amount=643 as landscape_index_643_amount_643.npz
#   ✓ Saved loss landscape for amount=644 as landscape_index_644_amount_644.npz
#   ✓ Saved loss landscape for amount=645 as landscape_index_645_amount_645.npz
#   ✓ Saved loss landscape for amount=646 as landscape_index_646_amount_646.npz
#   ✓ Saved loss landscape for amount=647 as landscape_index_647_amount_647.npz
#   ✓ Saved loss landscape for amount=648 as landscape_index_648_amount_648.npz
#   ✓ Saved loss landscape for amount=649 as landscape_index_649_amount_649.npz
#   ✓ Saved loss landscape for amount=650 as landscape_index_650_amount_650.npz
#   ✓ Saved loss landscape for amount=651 as landscape_index_651_amount_651.npz
#   ✓ Saved loss landscape for amount=652 as landscape_index_652_amount_652.npz
#   ✓ Saved loss landscape for amount=653 as landscape_index_653_amount_653.npz
#   ✓ Saved loss landscape for amount=654 as landscape_index_654_amount_654.npz
#   ✓ Saved loss landscape for amount=655 as landscape_index_655_amount_655.npz
#   ✓ Saved loss landscape for amount=656 as landscape_index_656_amount_656.npz
#   ✓ Saved loss landscape for amount=657 as landscape_index_657_amount_657.npz
#   ✓ Saved loss landscape for amount=658 as landscape_index_658_amount_658.npz
#   ✓ Saved loss landscape for amount=659 as landscape_index_659_amount_659.npz
#   ✓ Saved loss landscape for amount=660 as landscape_index_660_amount_660.npz
#   ✓ Saved loss landscape for amount=661 as landscape_index_661_amount_661.npz
#   ✓ Saved loss landscape for amount=662 as landscape_index_662_amount_662.npz
#   ✓ Saved loss landscape for amount=663 as landscape_index_663_amount_663.npz
#   ✓ Saved loss landscape for amount=664 as landscape_index_664_amount_664.npz
#   ✓ Saved loss landscape for amount=665 as landscape_index_665_amount_665.npz
#   ✓ Saved loss landscape for amount=666 as landscape_index_666_amount_666.npz
#   ✓ Saved loss landscape for amount=667 as landscape_index_667_amount_667.npz
#   ✓ Saved loss landscape for amount=668 as landscape_index_668_amount_668.npz
#   ✓ Saved loss landscape for amount=669 as landscape_index_669_amount_669.npz
#   ✓ Saved loss landscape for amount=670 as landscape_index_670_amount_670.npz
#   ✓ Saved loss landscape for amount=671 as landscape_index_671_amount_671.npz
#   ✓ Saved loss landscape for amount=672 as landscape_index_672_amount_672.npz
#   ✓ Saved loss landscape for amount=673 as landscape_index_673_amount_673.npz
#   ✓ Saved loss landscape for amount=674 as landscape_index_674_amount_674.npz
#   ✓ Saved loss landscape for amount=675 as landscape_index_675_amount_675.npz
#   ✓ Saved loss landscape for amount=676 as landscape_index_676_amount_676.npz
#   ✓ Saved loss landscape for amount=677 as landscape_index_677_amount_677.npz
#   ✓ Saved loss landscape for amount=678 as landscape_index_678_amount_678.npz
#   ✓ Saved loss landscape for amount=679 as landscape_index_679_amount_679.npz
#   ✓ Saved loss landscape for amount=680 as landscape_index_680_amount_680.npz
#   ✓ Saved loss landscape for amount=681 as landscape_index_681_amount_681.npz
#   ✓ Saved loss landscape for amount=682 as landscape_index_682_amount_682.npz
#   ✓ Saved loss landscape for amount=683 as landscape_index_683_amount_683.npz
#   ✓ Saved loss landscape for amount=684 as landscape_index_684_amount_684.npz
#   ✓ Saved loss landscape for amount=685 as landscape_index_685_amount_685.npz
#   ✓ Saved loss landscape for amount=686 as landscape_index_686_amount_686.npz
#   ✓ Saved loss landscape for amount=687 as landscape_index_687_amount_687.npz
#   ✓ Saved loss landscape for amount=688 as landscape_index_688_amount_688.npz
#   ✓ Saved loss landscape for amount=689 as landscape_index_689_amount_689.npz
#   ✓ Saved loss landscape for amount=690 as landscape_index_690_amount_690.npz
#   ✓ Saved loss landscape for amount=691 as landscape_index_691_amount_691.npz
#   ✓ Saved loss landscape for amount=692 as landscape_index_692_amount_692.npz
#   ✓ Saved loss landscape for amount=693 as landscape_index_693_amount_693.npz
#   ✓ Saved loss landscape for amount=694 as landscape_index_694_amount_694.npz
#   ✓ Saved loss landscape for amount=695 as landscape_index_695_amount_695.npz
#   ✓ Saved loss landscape for amount=696 as landscape_index_696_amount_696.npz
#   ✓ Saved loss landscape for amount=697 as landscape_index_697_amount_697.npz
#   ✓ Saved loss landscape for amount=698 as landscape_index_698_amount_698.npz
#   ✓ Saved loss landscape for amount=699 as landscape_index_699_amount_699.npz
#   ✓ Saved loss landscape for amount=700 as landscape_index_700_amount_700.npz
#   ✓ Saved loss landscape for amount=701 as landscape_index_701_amount_701.npz
#   ✓ Saved loss landscape for amount=702 as landscape_index_702_amount_702.npz
#   ✓ Saved loss landscape for amount=703 as landscape_index_703_amount_703.npz
#   ✓ Saved loss landscape for amount=704 as landscape_index_704_amount_704.npz
#   ✓ Saved loss landscape for amount=705 as landscape_index_705_amount_705.npz
#   ✓ Saved loss landscape for amount=706 as landscape_index_706_amount_706.npz
#   ✓ Saved loss landscape for amount=707 as landscape_index_707_amount_707.npz
#   ✓ Saved loss landscape for amount=708 as landscape_index_708_amount_708.npz
#   ✓ Saved loss landscape for amount=709 as landscape_index_709_amount_709.npz
#   ✓ Saved loss landscape for amount=710 as landscape_index_710_amount_710.npz
#   ✓ Saved loss landscape for amount=711 as landscape_index_711_amount_711.npz
#   ✓ Saved loss landscape for amount=712 as landscape_index_712_amount_712.npz
#   ✓ Saved loss landscape for amount=713 as landscape_index_713_amount_713.npz
#   ✓ Saved loss landscape for amount=714 as landscape_index_714_amount_714.npz
#   ✓ Saved loss landscape for amount=715 as landscape_index_715_amount_715.npz
#   ✓ Saved loss landscape for amount=716 as landscape_index_716_amount_716.npz
#   ✓ Saved loss landscape for amount=717 as landscape_index_717_amount_717.npz
#   ✓ Saved loss landscape for amount=718 as landscape_index_718_amount_718.npz
#   ✓ Saved loss landscape for amount=719 as landscape_index_719_amount_719.npz
#   ✓ Saved loss landscape for amount=720 as landscape_index_720_amount_720.npz
#   ✓ Saved loss landscape for amount=721 as landscape_index_721_amount_721.npz
#   ✓ Saved loss landscape for amount=722 as landscape_index_722_amount_722.npz
#   ✓ Saved loss landscape for amount=723 as landscape_index_723_amount_723.npz
#   ✓ Saved loss landscape for amount=724 as landscape_index_724_amount_724.npz
#   ✓ Saved loss landscape for amount=725 as landscape_index_725_amount_725.npz
#   ✓ Saved loss landscape for amount=726 as landscape_index_726_amount_726.npz
#   ✓ Saved loss landscape for amount=727 as landscape_index_727_amount_727.npz
#   ✓ Saved loss landscape for amount=728 as landscape_index_728_amount_728.npz
#   ✓ Saved loss landscape for amount=729 as landscape_index_729_amount_729.npz
#   ✓ Saved loss landscape for amount=730 as landscape_index_730_amount_730.npz
#   ✓ Saved loss landscape for amount=731 as landscape_index_731_amount_731.npz
#   ✓ Saved loss landscape for amount=732 as landscape_index_732_amount_732.npz
#   ✓ Saved loss landscape for amount=733 as landscape_index_733_amount_733.npz
#   ✓ Saved loss landscape for amount=734 as landscape_index_734_amount_734.npz
#   ✓ Saved loss landscape for amount=735 as landscape_index_735_amount_735.npz
#   ✓ Saved loss landscape for amount=736 as landscape_index_736_amount_736.npz
#   ✓ Saved loss landscape for amount=737 as landscape_index_737_amount_737.npz
#   ✓ Saved loss landscape for amount=738 as landscape_index_738_amount_738.npz
#   ✓ Saved loss landscape for amount=739 as landscape_index_739_amount_739.npz
#   ✓ Saved loss landscape for amount=740 as landscape_index_740_amount_740.npz
#   ✓ Saved loss landscape for amount=741 as landscape_index_741_amount_741.npz
#   ✓ Saved loss landscape for amount=742 as landscape_index_742_amount_742.npz
#   ✓ Saved loss landscape for amount=743 as landscape_index_743_amount_743.npz
#   ✓ Saved loss landscape for amount=744 as landscape_index_744_amount_744.npz
#   ✓ Saved loss landscape for amount=745 as landscape_index_745_amount_745.npz
#   ✓ Saved loss landscape for amount=746 as landscape_index_746_amount_746.npz
#   ✓ Saved loss landscape for amount=747 as landscape_index_747_amount_747.npz
#   ✓ Saved loss landscape for amount=748 as landscape_index_748_amount_748.npz
#   ✓ Saved loss landscape for amount=749 as landscape_index_749_amount_749.npz
#   ✓ Saved loss landscape for amount=750 as landscape_index_750_amount_750.npz
#   ✓ Saved loss landscape for amount=751 as landscape_index_751_amount_751.npz
#   ✓ Saved loss landscape for amount=752 as landscape_index_752_amount_752.npz
#   ✓ Saved loss landscape for amount=753 as landscape_index_753_amount_753.npz
#   ✓ Saved loss landscape for amount=754 as landscape_index_754_amount_754.npz
#   ✓ Saved loss landscape for amount=755 as landscape_index_755_amount_755.npz
#   ✓ Saved loss landscape for amount=756 as landscape_index_756_amount_756.npz
#   ✓ Saved loss landscape for amount=757 as landscape_index_757_amount_757.npz
#   ✓ Saved loss landscape for amount=758 as landscape_index_758_amount_758.npz
#   ✓ Saved loss landscape for amount=759 as landscape_index_759_amount_759.npz
#   ✓ Saved loss landscape for amount=760 as landscape_index_760_amount_760.npz
#   ✓ Saved loss landscape for amount=761 as landscape_index_761_amount_761.npz
#   ✓ Saved loss landscape for amount=762 as landscape_index_762_amount_762.npz
#   ✓ Saved loss landscape for amount=763 as landscape_index_763_amount_763.npz
#   ✓ Saved loss landscape for amount=764 as landscape_index_764_amount_764.npz
#   ✓ Saved loss landscape for amount=765 as landscape_index_765_amount_765.npz
#   ✓ Saved loss landscape for amount=766 as landscape_index_766_amount_766.npz
#   ✓ Saved loss landscape for amount=767 as landscape_index_767_amount_767.npz
#   ✓ Saved loss landscape for amount=768 as landscape_index_768_amount_768.npz
#   ✓ Saved loss landscape for amount=769 as landscape_index_769_amount_769.npz
#   ✓ Saved loss landscape for amount=770 as landscape_index_770_amount_770.npz
#   ✓ Saved loss landscape for amount=771 as landscape_index_771_amount_771.npz
#   ✓ Saved loss landscape for amount=772 as landscape_index_772_amount_772.npz
#   ✓ Saved loss landscape for amount=773 as landscape_index_773_amount_773.npz
#   ✓ Saved loss landscape for amount=774 as landscape_index_774_amount_774.npz
#   ✓ Saved loss landscape for amount=775 as landscape_index_775_amount_775.npz
#   ✓ Saved loss landscape for amount=776 as landscape_index_776_amount_776.npz
#   ✓ Saved loss landscape for amount=777 as landscape_index_777_amount_777.npz
#   ✓ Saved loss landscape for amount=778 as landscape_index_778_amount_778.npz
#   ✓ Saved loss landscape for amount=779 as landscape_index_779_amount_779.npz
#   ✓ Saved loss landscape for amount=780 as landscape_index_780_amount_780.npz
#
# === Total time for computing all loss landscapes: 157.36 seconds (2.62 minutes) ===
# ✓ Completed all 3 loss landscapes

# %%
# Compute all loss landscapes
start_time = time.time()
loss_grids_list = compute_loss_landscape_3models_varying_data(
    model_0=model_0,
    model_1=model_1,
    model_2=model_2,
    grid_coefficients=grid_coefficients,
    x_base=x_base_train,
    y_base=y_base_train,
    x_additional=x_additional,
    y_additional=y_additional,
    additional_data_amounts=additional_data_amounts,
    loss_fn_per_sample=loss_fn_per_sample,
    output_dir=varying_dataset_dir,
    base_filename="landscape"
)
end_time = time.time()
elapsed = end_time - start_time

print(f"\n=== Total time for computing all loss landscapes: {elapsed:.2f} seconds ({elapsed/60:.2f} minutes) ===")
print(f"✓ Completed all {len(loss_grids_list)} loss landscapes")
